# %%
import numpy as np
import torch
import gymnasium as gym
from torch import nn
import matplotlib.pyplot as plt

# %%
# helper function to convert numpy arrays to tensors
def t(x): return torch.from_numpy(x).float()

# %%
# Actor module, categorical actions only
class Actor(nn.Module):
    def __init__(self, state_dim, n_actions):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.Tanh(),
            nn.Linear(64, 32),
            nn.Tanh(),
            nn.Linear(32, n_actions),
            nn.Softmax()
        )
    
    def forward(self, X):
        return self.model(X)

# %%
# Critic module
class Critic(nn.Module):
    def __init__(self, state_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )
    
    def forward(self, X):
        return self.model(X)

# %%
# Memory
# Stores results from the networks, instead of calculating the operations again from states, etc.
class Memory():
    def __init__(self):
        self.log_probs = []
        self.values = []
        self.rewards = []
        self.dones = []

    def add(self, log_prob, value, reward, done):
        self.log_probs.append(log_prob)
        self.values.append(value)
        self.rewards.append(reward)
        self.dones.append(done)
    
    def clear(self):
        self.log_probs.clear()
        self.values.clear()
        self.rewards.clear()
        self.dones.clear()  
    
    def _zip(self):
        return zip(self.log_probs,
                self.values,
                self.rewards,
                self.dones)
    
    def __iter__(self):
        for data in self._zip():
            return data
    
    def reversed(self):
        for data in list(self._zip())[::-1]:
            yield data
    
    def __len__(self):
        return len(self.rewards)

# %%
env = gym.make("CartPole-v1")

# %%
# config
state_dim = env.observation_space.shape[0]
n_actions = env.action_space.n
actor = Actor(state_dim, n_actions)
critic = Critic(state_dim)
adam_actor = torch.optim.Adam(actor.parameters(), lr=1e-3)
adam_critic = torch.optim.Adam(critic.parameters(), lr=1e-3)
gamma = 0.99
memory = Memory()
max_steps = 200

# %%
# train function
def train(memory, q_val):
    values = torch.stack(memory.values)
    q_vals = np.zeros((len(memory), 1))
    
    # target values are calculated backward
    # it's super important to handle correctly done states,
    # for those cases we want our to target to be equal to the reward only
    for i, (_, _, reward, done) in enumerate(memory.reversed()):
        q_val = reward + gamma*q_val*(1.0-done)
        q_vals[len(memory)-1 - i] = q_val # store values from the end to the beginning
        
    advantage = torch.Tensor(q_vals) - values
    
    critic_loss = advantage.pow(2).mean()
    adam_critic.zero_grad()
    critic_loss.backward()
    adam_critic.step()
    
    actor_loss = (-torch.stack(memory.log_probs)*advantage.detach()).mean()
    adam_actor.zero_grad()
    actor_loss.backward()
    adam_actor.step()

# %%
episode_rewards = []

for i in range(500):
    done = False
    total_reward = 0
    state, _ = env.reset()
    steps = 0

    while not done:
        probs = actor(t(state))
        dist = torch.distributions.Categorical(probs=probs)
        action = dist.sample()
        
        print(probs)
        print(dist.probs)
        print(action.item())
        print(dist.log_prob(action))
        print("-" * 50)
        next_state, reward, done, _, info = env.step(action.detach().data.numpy())
        
        total_reward += reward
        steps += 1
        memory.add(dist.log_prob(action), critic(t(state)), reward, done)
        
        state = next_state
        
        # train if done or num steps > max_steps
        if done or (steps % max_steps == 0):
            last_q_val = critic(t(next_state)).detach().data.numpy()
            train(memory, last_q_val)
            memory.clear()
            
    episode_rewards.append(total_reward)
# Out:
# /home/eduardo/Workspace/CacheVideoPredict360/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# tensor([0.5909, 0.4091], grad_fn=<SoftmaxBackward0>)
# tensor([0.5909, 0.4091], grad_fn=<DivBackward0>)
# 1
# tensor(-0.8939, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9233, 0.0767], grad_fn=<SoftmaxBackward0>)
# tensor([0.9233, 0.0767], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0799, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6514, 0.3486], grad_fn=<SoftmaxBackward0>)
# tensor([0.6514, 0.3486], grad_fn=<DivBackward0>)
# 1
# tensor(-1.0537, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9379, 0.0621], grad_fn=<SoftmaxBackward0>)
# tensor([0.9379, 0.0621], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0641, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7134, 0.2866], grad_fn=<SoftmaxBackward0>)
# tensor([0.7134, 0.2866], grad_fn=<DivBackward0>)
# 1
# tensor(-1.2497, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9508, 0.0492], grad_fn=<SoftmaxBackward0>)
# tensor([0.9508, 0.0492], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0505, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7743, 0.2257], grad_fn=<SoftmaxBackward0>)
# tensor([0.7743, 0.2257], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2558, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3247, 0.6753], grad_fn=<SoftmaxBackward0>)
# tensor([0.3247, 0.6753], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3926, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8198, 0.1802], grad_fn=<SoftmaxBackward0>)
# tensor([0.8198, 0.1802], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1987, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3916, 0.6084], grad_fn=<SoftmaxBackward0>)
# tensor([0.3916, 0.6084], grad_fn=<DivBackward0>)
# 0
# tensor(-0.9374, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0897, 0.9103], grad_fn=<SoftmaxBackward0>)
# tensor([0.0897, 0.9103], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0940, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4441, 0.5559], grad_fn=<SoftmaxBackward0>)
# tensor([0.4441, 0.5559], grad_fn=<DivBackward0>)
# 0
# tensor(-0.8117, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1043, 0.8957], grad_fn=<SoftmaxBackward0>)
# tensor([0.1043, 0.8957], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1101, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4854, 0.5146], grad_fn=<SoftmaxBackward0>)
# tensor([0.4854, 0.5146], grad_fn=<DivBackward0>)
# 0
# tensor(-0.7228, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1168, 0.8832], grad_fn=<SoftmaxBackward0>)
# tensor([0.1168, 0.8832], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1241, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5156, 0.4844], grad_fn=<SoftmaxBackward0>)
# tensor([0.5156, 0.4844], grad_fn=<DivBackward0>)
# 1
# tensor(-0.7249, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8980, 0.1020], grad_fn=<SoftmaxBackward0>)
# tensor([0.8980, 0.1020], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1076, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5552, 0.4448], grad_fn=<SoftmaxBackward0>)
# tensor([0.5552, 0.4448], grad_fn=<DivBackward0>)
# 1
# tensor(-0.8101, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9107, 0.0893], grad_fn=<SoftmaxBackward0>)
# tensor([0.9107, 0.0893], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0935, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5989, 0.4011], grad_fn=<SoftmaxBackward0>)
# tensor([0.5989, 0.4011], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5127, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1679, 0.8321], grad_fn=<SoftmaxBackward0>)
# tensor([0.1679, 0.8321], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1838, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6284, 0.3716], grad_fn=<SoftmaxBackward0>)
# tensor([0.6284, 0.3716], grad_fn=<DivBackward0>)
# 1
# tensor(-0.9900, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9294, 0.0706], grad_fn=<SoftmaxBackward0>)
# tensor([0.9294, 0.0706], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0732, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6681, 0.3319], grad_fn=<SoftmaxBackward0>)
# tensor([0.6681, 0.3319], grad_fn=<DivBackward0>)
# 0
# tensor(-0.4032, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2118, 0.7882], grad_fn=<SoftmaxBackward0>)
# tensor([0.2118, 0.7882], grad_fn=<DivBackward0>)
# 0
# tensor(-1.5519, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0441, 0.9559], grad_fn=<SoftmaxBackward0>)
# tensor([0.0441, 0.9559], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0451, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2188, 0.7812], grad_fn=<SoftmaxBackward0>)
# tensor([0.2188, 0.7812], grad_fn=<DivBackward0>)
# 0
# tensor(-1.5197, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0442, 0.9558], grad_fn=<SoftmaxBackward0>)
# tensor([0.0442, 0.9558], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0452, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2133, 0.7867], grad_fn=<SoftmaxBackward0>)
# tensor([0.2133, 0.7867], grad_fn=<DivBackward0>)
# 0
# tensor(-1.5450, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0420, 0.9580], grad_fn=<SoftmaxBackward0>)
# tensor([0.0420, 0.9580], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0429, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1963, 0.8037], grad_fn=<SoftmaxBackward0>)
# tensor([0.1963, 0.8037], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2185, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6479, 0.3521], grad_fn=<SoftmaxBackward0>)
# tensor([0.6479, 0.3521], grad_fn=<DivBackward0>)
# 1
# tensor(-1.0438, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9272, 0.0728], grad_fn=<SoftmaxBackward0>)
# tensor([0.9272, 0.0728], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0756, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6387, 0.3613], grad_fn=<SoftmaxBackward0>)
# tensor([0.6387, 0.3613], grad_fn=<DivBackward0>)
# 0
# tensor(-0.4484, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1773, 0.8227], grad_fn=<SoftmaxBackward0>)
# tensor([0.1773, 0.8227], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1951, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6190, 0.3810], grad_fn=<SoftmaxBackward0>)
# tensor([0.6190, 0.3810], grad_fn=<DivBackward0>)
# 0
# tensor(-0.4797, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1646, 0.8354], grad_fn=<SoftmaxBackward0>)
# tensor([0.1646, 0.8354], grad_fn=<DivBackward0>)
# 0
# tensor(-1.8043, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0320, 0.9680], grad_fn=<SoftmaxBackward0>)
# tensor([0.0320, 0.9680], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0325, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1409, 0.8591], grad_fn=<SoftmaxBackward0>)
# tensor([0.1409, 0.8591], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1518, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5337, 0.4663], grad_fn=<SoftmaxBackward0>)
# tensor([0.5337, 0.4663], grad_fn=<DivBackward0>)
# 0
# tensor(-0.6279, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1197, 0.8803], grad_fn=<SoftmaxBackward0>)
# tensor([0.1197, 0.8803], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1275, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4785, 0.5215], grad_fn=<SoftmaxBackward0>)
# tensor([0.4785, 0.5215], grad_fn=<DivBackward0>)
# 1
# tensor(-0.6511, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8662, 0.1338], grad_fn=<SoftmaxBackward0>)
# tensor([0.8662, 0.1338], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1437, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4347, 0.5653], grad_fn=<SoftmaxBackward0>)
# tensor([0.4347, 0.5653], grad_fn=<DivBackward0>)
# 0
# tensor(-0.8332, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0867, 0.9133], grad_fn=<SoftmaxBackward0>)
# tensor([0.0867, 0.9133], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0907, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3774, 0.6226], grad_fn=<SoftmaxBackward0>)
# tensor([0.3774, 0.6226], grad_fn=<DivBackward0>)
# 0
# tensor(-0.9744, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0707, 0.9293], grad_fn=<SoftmaxBackward0>)
# tensor([0.0707, 0.9293], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0733, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3141, 0.6859], grad_fn=<SoftmaxBackward0>)
# tensor([0.3141, 0.6859], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3770, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7642, 0.2358], grad_fn=<SoftmaxBackward0>)
# tensor([0.7642, 0.2358], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2689, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2628, 0.7372], grad_fn=<SoftmaxBackward0>)
# tensor([0.2628, 0.7372], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3049, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7174, 0.2826], grad_fn=<SoftmaxBackward0>)
# tensor([0.7174, 0.2826], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3322, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2177, 0.7823], grad_fn=<SoftmaxBackward0>)
# tensor([0.2177, 0.7823], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2455, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6638, 0.3362], grad_fn=<SoftmaxBackward0>)
# tensor([0.6638, 0.3362], grad_fn=<DivBackward0>)
# 1
# tensor(-1.0900, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9259, 0.0741], grad_fn=<SoftmaxBackward0>)
# tensor([0.9259, 0.0741], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0770, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6216, 0.3784], grad_fn=<SoftmaxBackward0>)
# tensor([0.6216, 0.3784], grad_fn=<DivBackward0>)
# 1
# tensor(-0.9717, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9161, 0.0839], grad_fn=<SoftmaxBackward0>)
# tensor([0.9161, 0.0839], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0876, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5874, 0.4126], grad_fn=<SoftmaxBackward0>)
# tensor([0.5874, 0.4126], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5321, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1411, 0.8589], grad_fn=<SoftmaxBackward0>)
# tensor([0.1411, 0.8589], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1521, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5418, 0.4582], grad_fn=<SoftmaxBackward0>)
# tensor([0.5418, 0.4582], grad_fn=<DivBackward0>)
# 0
# tensor(-0.6129, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1205, 0.8795], grad_fn=<SoftmaxBackward0>)
# tensor([0.1205, 0.8795], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1284, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4894, 0.5106], grad_fn=<SoftmaxBackward0>)
# tensor([0.4894, 0.5106], grad_fn=<DivBackward0>)
# 0
# tensor(-0.7145, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1007, 0.8993], grad_fn=<SoftmaxBackward0>)
# tensor([0.1007, 0.8993], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1062, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4303, 0.5697], grad_fn=<SoftmaxBackward0>)
# tensor([0.4303, 0.5697], grad_fn=<DivBackward0>)
# 0
# tensor(-0.8433, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0822, 0.9178], grad_fn=<SoftmaxBackward0>)
# tensor([0.0822, 0.9178], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0858, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3653, 0.6347], grad_fn=<SoftmaxBackward0>)
# tensor([0.3653, 0.6347], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4546, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8042, 0.1958], grad_fn=<SoftmaxBackward0>)
# tensor([0.8042, 0.1958], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2179, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3136, 0.6864], grad_fn=<SoftmaxBackward0>)
# tensor([0.3136, 0.6864], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3763, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7686, 0.2314], grad_fn=<SoftmaxBackward0>)
# tensor([0.7686, 0.2314], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2632, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2685, 0.7315], grad_fn=<SoftmaxBackward0>)
# tensor([0.2685, 0.7315], grad_fn=<DivBackward0>)
# 0
# tensor(-1.3148, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0462, 0.9538], grad_fn=<SoftmaxBackward0>)
# tensor([0.0462, 0.9538], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0473, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2156, 0.7844], grad_fn=<SoftmaxBackward0>)
# tensor([0.2156, 0.7844], grad_fn=<DivBackward0>)
# 0
# tensor(-1.5342, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0363, 0.9637], grad_fn=<SoftmaxBackward0>)
# tensor([0.0363, 0.9637], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0370, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1636, 0.8364], grad_fn=<SoftmaxBackward0>)
# tensor([0.1636, 0.8364], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1786, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5714, 0.4286], grad_fn=<SoftmaxBackward0>)
# tensor([0.5714, 0.4286], grad_fn=<DivBackward0>)
# 1
# tensor(-0.8472, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8950, 0.1050], grad_fn=<SoftmaxBackward0>)
# tensor([0.8950, 0.1050], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1109, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5048, 0.4952], grad_fn=<SoftmaxBackward0>)
# tensor([0.5048, 0.4952], grad_fn=<DivBackward0>)
# 1
# tensor(-0.7027, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8731, 0.1269], grad_fn=<SoftmaxBackward0>)
# tensor([0.8731, 0.1269], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1357, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4465, 0.5535], grad_fn=<SoftmaxBackward0>)
# tensor([0.4465, 0.5535], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5915, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8503, 0.1497], grad_fn=<SoftmaxBackward0>)
# tensor([0.8503, 0.1497], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1622, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3965, 0.6035], grad_fn=<SoftmaxBackward0>)
# tensor([0.3965, 0.6035], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5050, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8269, 0.1731], grad_fn=<SoftmaxBackward0>)
# tensor([0.8269, 0.1731], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1900, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3538, 0.6462], grad_fn=<SoftmaxBackward0>)
# tensor([0.3538, 0.6462], grad_fn=<DivBackward0>)
# 0
# tensor(-1.0389, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0628, 0.9372], grad_fn=<SoftmaxBackward0>)
# tensor([0.0628, 0.9372], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0649, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3003, 0.6997], grad_fn=<SoftmaxBackward0>)
# tensor([0.3003, 0.6997], grad_fn=<DivBackward0>)
# 0
# tensor(-1.2029, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0510, 0.9490], grad_fn=<SoftmaxBackward0>)
# tensor([0.0510, 0.9490], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0523, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2437, 0.7563], grad_fn=<SoftmaxBackward0>)
# tensor([0.2437, 0.7563], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2794, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7001, 0.2999], grad_fn=<SoftmaxBackward0>)
# tensor([0.7001, 0.2999], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3565, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1997, 0.8003], grad_fn=<SoftmaxBackward0>)
# tensor([0.1997, 0.8003], grad_fn=<DivBackward0>)
# 0
# tensor(-1.6111, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0330, 0.9670], grad_fn=<SoftmaxBackward0>)
# tensor([0.0330, 0.9670], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0335, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1521, 0.8479], grad_fn=<SoftmaxBackward0>)
# tensor([0.1521, 0.8479], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1650, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5540, 0.4460], grad_fn=<SoftmaxBackward0>)
# tensor([0.5540, 0.4460], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5905, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1162, 0.8838], grad_fn=<SoftmaxBackward0>)
# tensor([0.1162, 0.8838], grad_fn=<DivBackward0>)
# 0
# tensor(-2.1521, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0201, 0.9799], grad_fn=<SoftmaxBackward0>)
# tensor([0.0201, 0.9799], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0203, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0819, 0.9181], grad_fn=<SoftmaxBackward0>)
# tensor([0.0819, 0.9181], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0854, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3549, 0.6451], grad_fn=<SoftmaxBackward0>)
# tensor([0.3549, 0.6451], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4384, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7850, 0.2150], grad_fn=<SoftmaxBackward0>)
# tensor([0.7850, 0.2150], grad_fn=<DivBackward0>)
# 1
# tensor(-1.5369, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9499, 0.0501], grad_fn=<SoftmaxBackward0>)
# tensor([0.9499, 0.0501], grad_fn=<DivBackward0>)
# 1
# tensor(-2.9930, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9851, 0.0149], grad_fn=<SoftmaxBackward0>)
# tensor([0.9851, 0.0149], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0150, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9439, 0.0561], grad_fn=<SoftmaxBackward0>)
# tensor([0.9439, 0.0561], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0577, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7153, 0.2847], grad_fn=<SoftmaxBackward0>)
# tensor([0.7153, 0.2847], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3350, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2167, 0.7833], grad_fn=<SoftmaxBackward0>)
# tensor([0.2167, 0.7833], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2443, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6783, 0.3217], grad_fn=<SoftmaxBackward0>)
# tensor([0.6783, 0.3217], grad_fn=<DivBackward0>)
# 1
# tensor(-1.1342, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9302, 0.0698], grad_fn=<SoftmaxBackward0>)
# tensor([0.9302, 0.0698], grad_fn=<DivBackward0>)
# 1
# tensor(-2.6623, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9820, 0.0180], grad_fn=<SoftmaxBackward0>)
# tensor([0.9820, 0.0180], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0181, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9309, 0.0691], grad_fn=<SoftmaxBackward0>)
# tensor([0.9309, 0.0691], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0716, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6688, 0.3312], grad_fn=<SoftmaxBackward0>)
# tensor([0.6688, 0.3312], grad_fn=<DivBackward0>)
# 0
# tensor(-0.4023, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1914, 0.8086], grad_fn=<SoftmaxBackward0>)
# tensor([0.1914, 0.8086], grad_fn=<DivBackward0>)
# 0
# tensor(-1.6534, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0337, 0.9663], grad_fn=<SoftmaxBackward0>)
# tensor([0.0337, 0.9663], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0342, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1751, 0.8249], grad_fn=<SoftmaxBackward0>)
# tensor([0.1751, 0.8249], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1925, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6298, 0.3702], grad_fn=<SoftmaxBackward0>)
# tensor([0.6298, 0.3702], grad_fn=<DivBackward0>)
# 1
# tensor(-0.9938, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9212, 0.0788], grad_fn=<SoftmaxBackward0>)
# tensor([0.9212, 0.0788], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0821, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6240, 0.3760], grad_fn=<SoftmaxBackward0>)
# tensor([0.6240, 0.3760], grad_fn=<DivBackward0>)
# 0
# tensor(-0.4716, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1606, 0.8394], grad_fn=<SoftmaxBackward0>)
# tensor([0.1606, 0.8394], grad_fn=<DivBackward0>)
# 0
# tensor(-1.8289, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0283, 0.9717], grad_fn=<SoftmaxBackward0>)
# tensor([0.0283, 0.9717], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0287, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1418, 0.8582], grad_fn=<SoftmaxBackward0>)
# tensor([0.1418, 0.8582], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1529, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5618, 0.4382], grad_fn=<SoftmaxBackward0>)
# tensor([0.5618, 0.4382], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5765, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1253, 0.8747], grad_fn=<SoftmaxBackward0>)
# tensor([0.1253, 0.8747], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1339, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5215, 0.4785], grad_fn=<SoftmaxBackward0>)
# tensor([0.5215, 0.4785], grad_fn=<DivBackward0>)
# 1
# tensor(-0.7371, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8861, 0.1139], grad_fn=<SoftmaxBackward0>)
# tensor([0.8861, 0.1139], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1209, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4946, 0.5054], grad_fn=<SoftmaxBackward0>)
# tensor([0.4946, 0.5054], grad_fn=<DivBackward0>)
# 1
# tensor(-0.6823, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8780, 0.1220], grad_fn=<SoftmaxBackward0>)
# tensor([0.8780, 0.1220], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1301, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4744, 0.5256], grad_fn=<SoftmaxBackward0>)
# tensor([0.4744, 0.5256], grad_fn=<DivBackward0>)
# 1
# tensor(-0.6431, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8717, 0.1283], grad_fn=<SoftmaxBackward0>)
# tensor([0.8717, 0.1283], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1373, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4601, 0.5399], grad_fn=<SoftmaxBackward0>)
# tensor([0.4601, 0.5399], grad_fn=<DivBackward0>)
# 0
# tensor(-0.7762, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0913, 0.9087], grad_fn=<SoftmaxBackward0>)
# tensor([0.0913, 0.9087], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0957, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4310, 0.5690], grad_fn=<SoftmaxBackward0>)
# tensor([0.4310, 0.5690], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5638, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8526, 0.1474], grad_fn=<SoftmaxBackward0>)
# tensor([0.8526, 0.1474], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1595, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4123, 0.5877], grad_fn=<SoftmaxBackward0>)
# tensor([0.4123, 0.5877], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5316, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8449, 0.1551], grad_fn=<SoftmaxBackward0>)
# tensor([0.8449, 0.1551], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1686, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3974, 0.6026], grad_fn=<SoftmaxBackward0>)
# tensor([0.3974, 0.6026], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5065, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8384, 0.1616], grad_fn=<SoftmaxBackward0>)
# tensor([0.8384, 0.1616], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1763, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3854, 0.6146], grad_fn=<SoftmaxBackward0>)
# tensor([0.3854, 0.6146], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4869, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8329, 0.1671], grad_fn=<SoftmaxBackward0>)
# tensor([0.8329, 0.1671], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1828, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3758, 0.6242], grad_fn=<SoftmaxBackward0>)
# tensor([0.3758, 0.6242], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4713, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8283, 0.1717], grad_fn=<SoftmaxBackward0>)
# tensor([0.8283, 0.1717], grad_fn=<DivBackward0>)
# 1
# tensor(-1.7621, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9645, 0.0355], grad_fn=<SoftmaxBackward0>)
# tensor([0.9645, 0.0355], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0361, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8351, 0.1649], grad_fn=<SoftmaxBackward0>)
# tensor([0.8351, 0.1649], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1802, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3871, 0.6129], grad_fn=<SoftmaxBackward0>)
# tensor([0.3871, 0.6129], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4896, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8392, 0.1608], grad_fn=<SoftmaxBackward0>)
# tensor([0.8392, 0.1608], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1753, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3954, 0.6046], grad_fn=<SoftmaxBackward0>)
# tensor([0.3954, 0.6046], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5031, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8437, 0.1563], grad_fn=<SoftmaxBackward0>)
# tensor([0.8437, 0.1563], grad_fn=<DivBackward0>)
# 1
# tensor(-1.8561, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9683, 0.0317], grad_fn=<SoftmaxBackward0>)
# tensor([0.9683, 0.0317], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0322, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8580, 0.1420], grad_fn=<SoftmaxBackward0>)
# tensor([0.8580, 0.1420], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1531, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4426, 0.5574], grad_fn=<SoftmaxBackward0>)
# tensor([0.4426, 0.5574], grad_fn=<DivBackward0>)
# 0
# tensor(-0.8150, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0920, 0.9080], grad_fn=<SoftmaxBackward0>)
# tensor([0.0920, 0.9080], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0965, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4492, 0.5508], grad_fn=<SoftmaxBackward0>)
# tensor([0.4492, 0.5508], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5964, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8691, 0.1309], grad_fn=<SoftmaxBackward0>)
# tensor([0.8691, 0.1309], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1403, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4633, 0.5367], grad_fn=<SoftmaxBackward0>)
# tensor([0.4633, 0.5367], grad_fn=<DivBackward0>)
# 1
# tensor(-0.6224, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8751, 0.1249], grad_fn=<SoftmaxBackward0>)
# tensor([0.8751, 0.1249], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1335, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4793, 0.5207], grad_fn=<SoftmaxBackward0>)
# tensor([0.4793, 0.5207], grad_fn=<DivBackward0>)
# 0
# tensor(-0.7355, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1026, 0.8974], grad_fn=<SoftmaxBackward0>)
# tensor([0.1026, 0.8974], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1082, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4767, 0.5233], grad_fn=<SoftmaxBackward0>)
# tensor([0.4767, 0.5233], grad_fn=<DivBackward0>)
# 0
# tensor(-0.7409, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0999, 0.9001], grad_fn=<SoftmaxBackward0>)
# tensor([0.0999, 0.9001], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1052, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4615, 0.5385], grad_fn=<SoftmaxBackward0>)
# tensor([0.4615, 0.5385], grad_fn=<DivBackward0>)
# 0
# tensor(-0.7733, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0933, 0.9067], grad_fn=<SoftmaxBackward0>)
# tensor([0.0933, 0.9067], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0980, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4335, 0.5665], grad_fn=<SoftmaxBackward0>)
# tensor([0.4335, 0.5665], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5682, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8540, 0.1460], grad_fn=<SoftmaxBackward0>)
# tensor([0.8540, 0.1460], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1578, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4122, 0.5878], grad_fn=<SoftmaxBackward0>)
# tensor([0.4122, 0.5878], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5314, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8438, 0.1562], grad_fn=<SoftmaxBackward0>)
# tensor([0.8438, 0.1562], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1699, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3912, 0.6088], grad_fn=<SoftmaxBackward0>)
# tensor([0.3912, 0.6088], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4963, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8325, 0.1675], grad_fn=<SoftmaxBackward0>)
# tensor([0.8325, 0.1675], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1833, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3697, 0.6303], grad_fn=<SoftmaxBackward0>)
# tensor([0.3697, 0.6303], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4616, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8198, 0.1802], grad_fn=<SoftmaxBackward0>)
# tensor([0.8198, 0.1802], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1987, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3472, 0.6528], grad_fn=<SoftmaxBackward0>)
# tensor([0.3472, 0.6528], grad_fn=<DivBackward0>)
# 0
# tensor(-1.0579, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0629, 0.9371], grad_fn=<SoftmaxBackward0>)
# tensor([0.0629, 0.9371], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0649, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3057, 0.6943], grad_fn=<SoftmaxBackward0>)
# tensor([0.3057, 0.6943], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3649, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7685, 0.2315], grad_fn=<SoftmaxBackward0>)
# tensor([0.7685, 0.2315], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2633, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2692, 0.7308], grad_fn=<SoftmaxBackward0>)
# tensor([0.2692, 0.7308], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3136, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7340, 0.2660], grad_fn=<SoftmaxBackward0>)
# tensor([0.7340, 0.2660], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3092, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2323, 0.7677], grad_fn=<SoftmaxBackward0>)
# tensor([0.2323, 0.7677], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2643, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6910, 0.3090], grad_fn=<SoftmaxBackward0>)
# tensor([0.6910, 0.3090], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3696, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1955, 0.8045], grad_fn=<SoftmaxBackward0>)
# tensor([0.1955, 0.8045], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2175, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6373, 0.3627], grad_fn=<SoftmaxBackward0>)
# tensor([0.6373, 0.3627], grad_fn=<DivBackward0>)
# 1
# tensor(-1.0142, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9169, 0.0831], grad_fn=<SoftmaxBackward0>)
# tensor([0.9169, 0.0831], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0868, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5901, 0.4099], grad_fn=<SoftmaxBackward0>)
# tensor([0.5901, 0.4099], grad_fn=<DivBackward0>)
# 1
# tensor(-0.8917, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9035, 0.0965], grad_fn=<SoftmaxBackward0>)
# tensor([0.9035, 0.0965], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1014, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5443, 0.4557], grad_fn=<SoftmaxBackward0>)
# tensor([0.5443, 0.4557], grad_fn=<DivBackward0>)
# 1
# tensor(-0.7859, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8888, 0.1112], grad_fn=<SoftmaxBackward0>)
# tensor([0.8888, 0.1112], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1179, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4996, 0.5004], grad_fn=<SoftmaxBackward0>)
# tensor([0.4996, 0.5004], grad_fn=<DivBackward0>)
# 0
# tensor(-0.6940, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1034, 0.8966], grad_fn=<SoftmaxBackward0>)
# tensor([0.1034, 0.8966], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1091, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4355, 0.5645], grad_fn=<SoftmaxBackward0>)
# tensor([0.4355, 0.5645], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5718, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8398, 0.1602], grad_fn=<SoftmaxBackward0>)
# tensor([0.8398, 0.1602], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1746, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3782, 0.6218], grad_fn=<SoftmaxBackward0>)
# tensor([0.3782, 0.6218], grad_fn=<DivBackward0>)
# 0
# tensor(-0.9724, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0683, 0.9317], grad_fn=<SoftmaxBackward0>)
# tensor([0.0683, 0.9317], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0708, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3047, 0.6953], grad_fn=<SoftmaxBackward0>)
# tensor([0.3047, 0.6953], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3633, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7458, 0.2542], grad_fn=<SoftmaxBackward0>)
# tensor([0.7458, 0.2542], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2933, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2415, 0.7585], grad_fn=<SoftmaxBackward0>)
# tensor([0.2415, 0.7585], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2764, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6780, 0.3220], grad_fn=<SoftmaxBackward0>)
# tensor([0.6780, 0.3220], grad_fn=<DivBackward0>)
# 1
# tensor(-1.1331, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9216, 0.0784], grad_fn=<SoftmaxBackward0>)
# tensor([0.9216, 0.0784], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0817, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6110, 0.3890], grad_fn=<SoftmaxBackward0>)
# tensor([0.6110, 0.3890], grad_fn=<DivBackward0>)
# 0
# tensor(-0.4927, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1473, 0.8527], grad_fn=<SoftmaxBackward0>)
# tensor([0.1473, 0.8527], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1593, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5223, 0.4777], grad_fn=<SoftmaxBackward0>)
# tensor([0.5223, 0.4777], grad_fn=<DivBackward0>)
# 0
# tensor(-0.6495, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1084, 0.8916], grad_fn=<SoftmaxBackward0>)
# tensor([0.1084, 0.8916], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1147, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4191, 0.5809], grad_fn=<SoftmaxBackward0>)
# tensor([0.4191, 0.5809], grad_fn=<DivBackward0>)
# 0
# tensor(-0.8697, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0762, 0.9238], grad_fn=<SoftmaxBackward0>)
# tensor([0.0762, 0.9238], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0793, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3094, 0.6906], grad_fn=<SoftmaxBackward0>)
# tensor([0.3094, 0.6906], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3701, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7255, 0.2745], grad_fn=<SoftmaxBackward0>)
# tensor([0.7255, 0.2745], grad_fn=<DivBackward0>)
# 1
# tensor(-1.2928, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9277, 0.0723], grad_fn=<SoftmaxBackward0>)
# tensor([0.9277, 0.0723], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0750, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6380, 0.3620], grad_fn=<SoftmaxBackward0>)
# tensor([0.6380, 0.3620], grad_fn=<DivBackward0>)
# 0
# tensor(-0.4494, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1607, 0.8393], grad_fn=<SoftmaxBackward0>)
# tensor([0.1607, 0.8393], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1752, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5196, 0.4804], grad_fn=<SoftmaxBackward0>)
# tensor([0.5196, 0.4804], grad_fn=<DivBackward0>)
# 1
# tensor(-0.7331, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8530, 0.1470], grad_fn=<SoftmaxBackward0>)
# tensor([0.8530, 0.1470], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1590, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4078, 0.5922], grad_fn=<SoftmaxBackward0>)
# tensor([0.4078, 0.5922], grad_fn=<DivBackward0>)
# 0
# tensor(-0.8970, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0744, 0.9256], grad_fn=<SoftmaxBackward0>)
# tensor([0.0744, 0.9256], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0773, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2870, 0.7130], grad_fn=<SoftmaxBackward0>)
# tensor([0.2870, 0.7130], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3383, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6854, 0.3146], grad_fn=<SoftmaxBackward0>)
# tensor([0.6854, 0.3146], grad_fn=<DivBackward0>)
# 1
# tensor(-1.1565, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9092, 0.0908], grad_fn=<SoftmaxBackward0>)
# tensor([0.9092, 0.0908], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0952, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5746, 0.4254], grad_fn=<SoftmaxBackward0>)
# tensor([0.5746, 0.4254], grad_fn=<DivBackward0>)
# 1
# tensor(-0.8547, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8686, 0.1314], grad_fn=<SoftmaxBackward0>)
# tensor([0.8686, 0.1314], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1409, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4557, 0.5443], grad_fn=<SoftmaxBackward0>)
# tensor([0.4557, 0.5443], grad_fn=<DivBackward0>)
# 0
# tensor(-0.7860, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0898, 0.9102], grad_fn=<SoftmaxBackward0>)
# tensor([0.0898, 0.9102], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0941, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3232, 0.6768], grad_fn=<SoftmaxBackward0>)
# tensor([0.3232, 0.6768], grad_fn=<DivBackward0>)
# 0
# tensor(-1.1296, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0563, 0.9437], grad_fn=<SoftmaxBackward0>)
# tensor([0.0563, 0.9437], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0579, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2037, 0.7963], grad_fn=<SoftmaxBackward0>)
# tensor([0.2037, 0.7963], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2278, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5505, 0.4495], grad_fn=<SoftmaxBackward0>)
# tensor([0.5505, 0.4495], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5969, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1220, 0.8780], grad_fn=<SoftmaxBackward0>)
# tensor([0.1220, 0.8780], grad_fn=<DivBackward0>)
# 0
# tensor(-2.1040, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0216, 0.9784], grad_fn=<SoftmaxBackward0>)
# tensor([0.0216, 0.9784], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0218, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0651, 0.9349], grad_fn=<SoftmaxBackward0>)
# tensor([0.0651, 0.9349], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0674, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2125, 0.7875], grad_fn=<SoftmaxBackward0>)
# tensor([0.2125, 0.7875], grad_fn=<DivBackward0>)
# 0
# tensor(-1.5489, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0348, 0.9652], grad_fn=<SoftmaxBackward0>)
# tensor([0.0348, 0.9652], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0355, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6038, 0.3962], grad_fn=<SoftmaxBackward0>)
# tensor([0.6038, 0.3962], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5046, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1490, 0.8510], grad_fn=<SoftmaxBackward0>)
# tensor([0.1490, 0.8510], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1613, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5669, 0.4331], grad_fn=<SoftmaxBackward0>)
# tensor([0.5669, 0.4331], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5676, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1307, 0.8693], grad_fn=<SoftmaxBackward0>)
# tensor([0.1307, 0.8693], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1400, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5226, 0.4774], grad_fn=<SoftmaxBackward0>)
# tensor([0.5226, 0.4774], grad_fn=<DivBackward0>)
# 1
# tensor(-0.7394, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8878, 0.1122], grad_fn=<SoftmaxBackward0>)
# tensor([0.8878, 0.1122], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1190, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4903, 0.5097], grad_fn=<SoftmaxBackward0>)
# tensor([0.4903, 0.5097], grad_fn=<DivBackward0>)
# 0
# tensor(-0.7127, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1018, 0.8982], grad_fn=<SoftmaxBackward0>)
# tensor([0.1018, 0.8982], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1074, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4439, 0.5561], grad_fn=<SoftmaxBackward0>)
# tensor([0.4439, 0.5561], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5868, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8557, 0.1443], grad_fn=<SoftmaxBackward0>)
# tensor([0.8557, 0.1443], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1558, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4086, 0.5914], grad_fn=<SoftmaxBackward0>)
# tensor([0.4086, 0.5914], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5253, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8398, 0.1602], grad_fn=<SoftmaxBackward0>)
# tensor([0.8398, 0.1602], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1745, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3779, 0.6221], grad_fn=<SoftmaxBackward0>)
# tensor([0.3779, 0.6221], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4746, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8241, 0.1759], grad_fn=<SoftmaxBackward0>)
# tensor([0.8241, 0.1759], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1934, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3508, 0.6492], grad_fn=<SoftmaxBackward0>)
# tensor([0.3508, 0.6492], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4320, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8085, 0.1915], grad_fn=<SoftmaxBackward0>)
# tensor([0.8085, 0.1915], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2126, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3265, 0.6735], grad_fn=<SoftmaxBackward0>)
# tensor([0.3265, 0.6735], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3953, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7927, 0.2073], grad_fn=<SoftmaxBackward0>)
# tensor([0.7927, 0.2073], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2323, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3044, 0.6956], grad_fn=<SoftmaxBackward0>)
# tensor([0.3044, 0.6956], grad_fn=<DivBackward0>)
# 0
# tensor(-1.1895, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0546, 0.9454], grad_fn=<SoftmaxBackward0>)
# tensor([0.0546, 0.9454], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0562, grad_fn=<SqueezeBackward1>)
# ...
# tensor([0.4136, 0.5864], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5338, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8346, 0.1654], grad_fn=<SoftmaxBackward0>)
# tensor([0.8346, 0.1654], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1808, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3555, 0.6445], grad_fn=<SoftmaxBackward0>)
# tensor([0.3555, 0.6445], grad_fn=<DivBackward0>)
# 0
# tensor(-1.0342, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0592, 0.9408], grad_fn=<SoftmaxBackward0>)
# tensor([0.0592, 0.9408], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0611, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2852, 0.7148], grad_fn=<SoftmaxBackward0>)
# tensor([0.2852, 0.7148], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3358, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7413, 0.2587], grad_fn=<SoftmaxBackward0>)
# tensor([0.7413, 0.2587], grad_fn=<DivBackward0>)
# 1
# tensor(-1.3521, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9418, 0.0582], grad_fn=<SoftmaxBackward0>)
# tensor([0.9418, 0.0582], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0600, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6958, 0.3042], grad_fn=<SoftmaxBackward0>)
# tensor([0.6958, 0.3042], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3627, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1936, 0.8064], grad_fn=<SoftmaxBackward0>)
# tensor([0.1936, 0.8064], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2152, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6361, 0.3639], grad_fn=<SoftmaxBackward0>)
# tensor([0.6361, 0.3639], grad_fn=<DivBackward0>)
# 0
# tensor(-0.4524, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1547, 0.8453], grad_fn=<SoftmaxBackward0>)
# tensor([0.1547, 0.8453], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1680, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5648, 0.4352], grad_fn=<SoftmaxBackward0>)
# tensor([0.5648, 0.4352], grad_fn=<DivBackward0>)
# 1
# tensor(-0.8319, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8923, 0.1077], grad_fn=<SoftmaxBackward0>)
# tensor([0.8923, 0.1077], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1140, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5018, 0.4982], grad_fn=<SoftmaxBackward0>)
# tensor([0.5018, 0.4982], grad_fn=<DivBackward0>)
# 0
# tensor(-0.6895, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0986, 0.9014], grad_fn=<SoftmaxBackward0>)
# tensor([0.0986, 0.9014], grad_fn=<DivBackward0>)
# 0
# tensor(-2.3169, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0175, 0.9825], grad_fn=<SoftmaxBackward0>)
# tensor([0.0175, 0.9825], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0176, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0700, 0.9300], grad_fn=<SoftmaxBackward0>)
# tensor([0.0700, 0.9300], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0726, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3109, 0.6891], grad_fn=<SoftmaxBackward0>)
# tensor([0.3109, 0.6891], grad_fn=<DivBackward0>)
# 0
# tensor(-1.1682, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0490, 0.9510], grad_fn=<SoftmaxBackward0>)
# tensor([0.0490, 0.9510], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0503, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2181, 0.7819], grad_fn=<SoftmaxBackward0>)
# tensor([0.2181, 0.7819], grad_fn=<DivBackward0>)
# 0
# tensor(-1.5227, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0332, 0.9668], grad_fn=<SoftmaxBackward0>)
# tensor([0.0332, 0.9668], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0337, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1401, 0.8599], grad_fn=<SoftmaxBackward0>)
# tensor([0.1401, 0.8599], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1510, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4903, 0.5097], grad_fn=<SoftmaxBackward0>)
# tensor([0.4903, 0.5097], grad_fn=<DivBackward0>)
# 1
# tensor(-0.6739, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8425, 0.1575], grad_fn=<SoftmaxBackward0>)
# tensor([0.8425, 0.1575], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1714, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3664, 0.6336], grad_fn=<SoftmaxBackward0>)
# tensor([0.3664, 0.6336], grad_fn=<DivBackward0>)
# 1
# tensor(-0.4564, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7705, 0.2295], grad_fn=<SoftmaxBackward0>)
# tensor([0.7705, 0.2295], grad_fn=<DivBackward0>)
# 1
# tensor(-1.4720, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9390, 0.0610], grad_fn=<SoftmaxBackward0>)
# tensor([0.9390, 0.0610], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0630, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6893, 0.3107], grad_fn=<SoftmaxBackward0>)
# tensor([0.6893, 0.3107], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3720, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1893, 0.8107], grad_fn=<SoftmaxBackward0>)
# tensor([0.1893, 0.8107], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2099, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5825, 0.4175], grad_fn=<SoftmaxBackward0>)
# tensor([0.5825, 0.4175], grad_fn=<DivBackward0>)
# 1
# tensor(-0.8734, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8802, 0.1198], grad_fn=<SoftmaxBackward0>)
# tensor([0.8802, 0.1198], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1276, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4770, 0.5230], grad_fn=<SoftmaxBackward0>)
# tensor([0.4770, 0.5230], grad_fn=<DivBackward0>)
# 1
# tensor(-0.6482, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8351, 0.1649], grad_fn=<SoftmaxBackward0>)
# tensor([0.8351, 0.1649], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1803, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3757, 0.6243], grad_fn=<SoftmaxBackward0>)
# tensor([0.3757, 0.6243], grad_fn=<DivBackward0>)
# 0
# tensor(-0.9790, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0655, 0.9345], grad_fn=<SoftmaxBackward0>)
# tensor([0.0655, 0.9345], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0678, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2688, 0.7312], grad_fn=<SoftmaxBackward0>)
# tensor([0.2688, 0.7312], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3131, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6744, 0.3256], grad_fn=<SoftmaxBackward0>)
# tensor([0.6744, 0.3256], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3940, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1863, 0.8137], grad_fn=<SoftmaxBackward0>)
# tensor([0.1863, 0.8137], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2061, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5589, 0.4411], grad_fn=<SoftmaxBackward0>)
# tensor([0.5589, 0.4411], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5819, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1235, 0.8765], grad_fn=<SoftmaxBackward0>)
# tensor([0.1235, 0.8765], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1318, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4263, 0.5737], grad_fn=<SoftmaxBackward0>)
# tensor([0.4263, 0.5737], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5556, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7900, 0.2100], grad_fn=<SoftmaxBackward0>)
# tensor([0.7900, 0.2100], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2357, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3091, 0.6909], grad_fn=<SoftmaxBackward0>)
# tensor([0.3091, 0.6909], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3697, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6980, 0.3020], grad_fn=<SoftmaxBackward0>)
# tensor([0.6980, 0.3020], grad_fn=<DivBackward0>)
# 0
# tensor(-0.3595, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2093, 0.7907], grad_fn=<SoftmaxBackward0>)
# tensor([0.2093, 0.7907], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2349, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5753, 0.4247], grad_fn=<SoftmaxBackward0>)
# tensor([0.5753, 0.4247], grad_fn=<DivBackward0>)
# 0
# tensor(-0.5529, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1358, 0.8642], grad_fn=<SoftmaxBackward0>)
# tensor([0.1358, 0.8642], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1459, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4349, 0.5651], grad_fn=<SoftmaxBackward0>)
# tensor([0.4349, 0.5651], grad_fn=<DivBackward0>)
# 0
# tensor(-0.8325, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0842, 0.9158], grad_fn=<SoftmaxBackward0>)
# tensor([0.0842, 0.9158], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0880, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2939, 0.7061], grad_fn=<SoftmaxBackward0>)
# tensor([0.2939, 0.7061], grad_fn=<DivBackward0>)
# 1
# tensor(-0.3480, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.6584, 0.3416], grad_fn=<SoftmaxBackward0>)
# tensor([0.6584, 0.3416], grad_fn=<DivBackward0>)
# 1
# tensor(-1.0740, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8846, 0.1154], grad_fn=<SoftmaxBackward0>)
# tensor([0.8846, 0.1154], grad_fn=<DivBackward0>)
# 1
# tensor(-2.1593, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.9598, 0.0402], grad_fn=<SoftmaxBackward0>)
# tensor([0.9598, 0.0402], grad_fn=<DivBackward0>)
# 0
# tensor(-0.0410, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.8344, 0.1656], grad_fn=<SoftmaxBackward0>)
# tensor([0.8344, 0.1656], grad_fn=<DivBackward0>)
# 0
# tensor(-0.1811, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.4153, 0.5847], grad_fn=<SoftmaxBackward0>)
# tensor([0.4153, 0.5847], grad_fn=<DivBackward0>)
# 1
# tensor(-0.5366, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7611, 0.2389], grad_fn=<SoftmaxBackward0>)
# tensor([0.7611, 0.2389], grad_fn=<DivBackward0>)
# 0
# tensor(-0.2730, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3013, 0.6987], grad_fn=<SoftmaxBackward0>)
# tensor([0.3013, 0.6987], grad_fn=<DivBackward0>)
# 0
# tensor(-1.1996, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0567, 0.9433], grad_fn=<SoftmaxBackward0>)
# tensor([0.0567, 0.9433], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0583, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1941, 0.8059], grad_fn=<SoftmaxBackward0>)
# tensor([0.1941, 0.8059], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2159, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5098, 0.4902], grad_fn=<SoftmaxBackward0>)
# tensor([0.5098, 0.4902], grad_fn=<DivBackward0>)
# 0
# tensor(-0.6737, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.1197, 0.8803], grad_fn=<SoftmaxBackward0>)
# tensor([0.1197, 0.8803], grad_fn=<DivBackward0>)
# 1
# tensor(-0.1275, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.3564, 0.6436], grad_fn=<SoftmaxBackward0>)
# tensor([0.3564, 0.6436], grad_fn=<DivBackward0>)
# 0
# tensor(-1.0318, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.0703, 0.9297], grad_fn=<SoftmaxBackward0>)
# tensor([0.0703, 0.9297], grad_fn=<DivBackward0>)
# 1
# tensor(-0.0729, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.2183, 0.7817], grad_fn=<SoftmaxBackward0>)
# tensor([0.2183, 0.7817], grad_fn=<DivBackward0>)
# 1
# tensor(-0.2463, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.5178, 0.4822], grad_fn=<SoftmaxBackward0>)
# tensor([0.5178, 0.4822], grad_fn=<DivBackward0>)
# 1
# tensor(-0.7294, grad_fn=<SqueezeBackward1>)
# --------------------------------------------------
# tensor([0.7915, 0.2085], grad_fn=<SoftmaxBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 15
#      12 action = dist.sample()
#      14 print(probs)
# ---> 15 print(dist.probs)
#      16 print(action.item())
#      17 print(dist.log_prob(action))
#
# File ~/Workspace/CacheVideoPredict360/.venv/lib/python3.12/site-packages/torch/_tensor.py:568, in Tensor.__repr__(self, tensor_contents)
#     564     return handle_torch_function(
#     565         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     566     )
#     567 # All strings are unicode in Python 3.
# --> 568 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File ~/Workspace/CacheVideoPredict360/.venv/lib/python3.12/site-packages/torch/_tensor_str.py:722, in _str(self, tensor_contents)
#     720 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     721     guard = torch._C._DisableFuncTorch()  # noqa: F841
# --> 722     return _str_intern(self, tensor_contents=tensor_contents)
#
# File ~/Workspace/CacheVideoPredict360/.venv/lib/python3.12/site-packages/torch/_tensor_str.py:643, in _str_intern(inp, tensor_contents)
#     641                     tensor_str = _tensor_str(self.to_dense(), indent)
#     642                 else:
# --> 643                     tensor_str = _tensor_str(self, indent)
#     645 if self.layout != torch.strided:
#     646     suffixes.append("layout=" + str(self.layout))
#
# File ~/Workspace/CacheVideoPredict360/.venv/lib/python3.12/site-packages/torch/_tensor_str.py:375, in _tensor_str(self, indent)
#     371     return _tensor_str_with_formatter(
#     372         self, indent, summarize, real_formatter, imag_formatter
#     373     )
#     374 else:
# --> 375     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     376     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File ~/Workspace/CacheVideoPredict360/.venv/lib/python3.12/site-packages/torch/_tensor_str.py:137, in _Formatter.__init__(self, tensor)
#     134 self.sci_mode = False
#     135 self.max_width = 1
# --> 137 with torch.no_grad():
#     138     tensor_view = tensor.reshape(-1)
#     140 if not self.floating_dtype:
#
# File ~/Workspace/CacheVideoPredict360/.venv/lib/python3.12/site-packages/torch/autograd/grad_mode.py:82, in no_grad.__enter__(self)
#      80 def __enter__(self) -> None:
#      81     self.prev = torch.is_grad_enabled()
# ---> 82     torch.set_grad_enabled(False)
#
# File ~/Workspace/CacheVideoPredict360/.venv/lib/python3.12/site-packages/torch/autograd/grad_mode.py:184, in set_grad_enabled.__init__(self, mode)
#     143 class set_grad_enabled(_DecoratorContextManager):
#     144     r"""Context-manager that sets gradient calculation on or off.
#     145
#     146     ``set_grad_enabled`` will enable or disable grads based on its argument :attr:`mode`.
#    (...)    181
#     182     """
# --> 184     def __init__(self, mode: bool) -> None:
#     185         self.prev = torch.is_grad_enabled()
#     186         self.mode = mode
#
# KeyboardInterrupt:

# %%
plt.scatter(np.arange(len(episode_rewards)), episode_rewards, s=2)
plt.title("Total reward per episode (episodic)")
plt.ylabel("reward")
plt.xlabel("episode")
plt.show()
