# %%
import csv
import copy
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd

from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import Any, Dict, Counter, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torch_optimizer as optim_extra

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv
    from LabUserRequest import UserRequestEvents
    from LabEnvWrapperKunkali import EnvWrapper

import os
import sys

sources_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if sources_path not in sys.path:
    sys.path.append(sources_path)

import Common.config as config
import Common.datatypes as datatypes
import Common.debugger as debugger
import Common.utils as utils

import importlib

importlib.reload(config)
importlib.reload(datatypes)
importlib.reload(debugger)
importlib.reload(utils)
# Out:
# <module 'Common.utils' from '/home/eduardo/Workspace/CacheVideoPredict360/Sources/Common/utils.py'>

# %%
UserTransition = datatypes.UserTransition
CachePolicy = datatypes.CachePolicy
CacheKey = datatypes.CacheKey

cfg = config.Config()
cfg.filename = f"drl_focus_eps{cfg.epsilon_decay}_lrdecay{cfg.learning_rate_decay}.csv"

debugger = debugger.debug

# %%
class DrlPolicy(CachePolicy):
    def __init__(self, cfg: Any = None):
        self.cfg = cfg
        self.cur_size = 0

        self.video_idx = [-1] * self.cfg.cache_size
        self.tile_idx = [[-1] * self.cfg.viewport for _ in range(self.cfg.cache_size)]

    def get(self, key: CacheKey) -> Any:
        return self.cache.get(key, None)

    def put(self, key: int, value: Any, size: int) -> list:
        """
        key   -> slot index
        value -> (video_id, tiles)
        size  -> fixed as 1 slot
        """
        slot = key
        new_video, _ = value

        if new_video in self.video_idx:
            # old_video_slot = self.video_idx.index(new_video)
            # if old_video_slot != slot:
                # # Swap video positions
                # self.video_idx[slot], self.video_idx[old_video_slot] = (
                #     self.video_idx[old_video_slot],
                #     self.video_idx[slot],
                # )

                # # Swap tile mapping accordingly
                # self.tile_idx[slot], self.tile_idx[old_video_slot] = (
                #     self.tile_idx[old_video_slot],
                #     self.tile_idx[slot],
                # )

            self.cur_size = sum(1 for v in self.video_idx if v != -1)
            return []

        self.video_idx[slot] = new_video
        self.tile_idx[slot] = [-1] * self.cfg.viewport

        self.cur_size = sum(1 for v in self.video_idx if v != -1)
        return []

    def contains(self, key: CacheKey) -> bool:
        return key in self.video_idx

    def remove(self, key: CacheKey) -> bool:
        if key in self.video_idx:
            idx = self.video_idx.index(key)
            self.video_idx[idx] = -1
            self.tile_idx[idx] = [-1] * self.cfg.viewport
            self.cur_size = sum(1 for v in self.video_idx if v != -1)
            return True
        return False

    def clear(self) -> None:
        self.video_idx = [-1] * self.cfg.cache_size
        self.tile_idx = [[-1] * self.cfg.viewport for _ in range(self.cfg.cache_size)]
        self.cur_size = 0

    def keys(self):
        return self.video_idx
    
    def get_capacity(self) -> int:
        return self.cur_size
    
    def update_size(self):
        self.cur_size = sum(1 for v in self.video_idx if v != -1)

    def stats(self) -> Dict[str, Any]:
        return {
            'current_size': self.cur_size,
            'capacity': self.cfg.cache_size,
            'num_items': len([v for v in self.video_idx if v != -1])
        }

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ReplayBuffer:
    def __init__(self, capacity: int = 2000):
        self.memory = deque(maxlen=capacity)
    
    def push(self, s, a, r, ns, d):
        self.memory.append((s, a, r, ns, d))
    
    def sample(self, batch_size: int):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

class NStepReplayBuffer:
    def __init__(self, capacity, n_step, gamma):
        self.memory = deque(maxlen=capacity)
        self.n_step_buffer = deque(maxlen=n_step)
        self.n_step = n_step
        self.gamma = gamma

    def push(self, s, a, r, ns, done):
        self.n_step_buffer.append((s, a, r, ns, done))
        if len(self.n_step_buffer) < self.n_step:
            return
        
        # Compute N-step discounted reward
        # G = r1 + gamma*r2 + ... + gamma^(n-1)*rn
        reward, next_state, done_ = self._get_n_step_info()
        state, action, _, _, _ = self.n_step_buffer[0]
        self.memory.append((state, action, reward, next_state, done_))

    def _get_n_step_info(self):
        reward = 0
        for i, transition in enumerate(self.n_step_buffer):
            reward += (self.gamma ** i) * transition[2]
        return reward, self.n_step_buffer[-1][3], self.n_step_buffer[-1][4]
    
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int, hidden_dim: int = 128):
        super().__init__()
        hidden = hidden_dim
        self.fc1 = nn.Linear(state_dim, hidden)
        self.fc2 = nn.Linear(hidden, hidden)
        self.out = nn.Linear(hidden, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.out(x)


class MultiHeadQNetwork(nn.Module):
    def __init__(self, state_dim, action_dim, num_heads=4, hidden_dim=128):
        super().__init__()

        # shared encoder
        self.shared = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU()
        )

        # independent heads
        self.heads = nn.ModuleList([
            nn.Linear(hidden_dim, action_dim)
            for _ in range(num_heads)
        ])

    def forward(self, x):
        z = self.shared(x)
        return torch.stack([h(z) for h in self.heads], dim=1)

class MetaController:
    def __init__(self, cfg):
        self.cfg = cfg
        self.step = 0
        self.n_step = cfg.n_step
        self.state_dim = cfg.state_dim_meta
        self.num_actions = cfg.num_goals   # capacity + 1

        self.gamma = cfg.gamma
        self.epsilon = cfg.epsilon_start
        self.epsilon_min = cfg.epsilon_min
        self.epsilon_decay = cfg.epsilon_decay
        self.batch_size = cfg.batch_size
        self.tau = cfg.tau

        self.buffer = NStepReplayBuffer(cfg.buffer_capacity, self.n_step, self.gamma)

        self.policy_net = QNetwork(self.state_dim, self.num_actions).to(device)
        self.target_net = QNetwork(self.state_dim, self.num_actions).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=cfg.learning_rate)

        self.scheduler = optim.lr_scheduler.ExponentialLR(
            self.optimizer, gamma=cfg.learning_rate_decay
        )

        self.loss_fn = nn.MSELoss()
        self.nb_interval = cfg.nb_interval

    def select_action(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, self.num_actions - 1)

        with torch.no_grad():
            state_t = torch.tensor(state, dtype=torch.float32).to(device).unsqueeze(0)
            qvals = self.policy_net(state_t)
            return qvals.argmax().item()

    def remember(self, s, a, r, ns, done):
        self.buffer.push(s, a, r, ns, done)

    def train_step(self):
        self.step += 1
        if self.step % self.nb_interval == 0 and \
           len(self.buffer) >= self.batch_size:
            self.learn()

    def learn(self):
        batch = self.buffer.sample(self.batch_size)
        s, a, r, ns, d = zip(*batch)

        s = torch.tensor(np.stack(s), dtype=torch.float32).to(device)
        ns = torch.tensor(np.stack(ns), dtype=torch.float32).to(device)
        a = torch.tensor(a, dtype=torch.int64).to(device)
        r = torch.tensor(r, dtype=torch.float32).to(device)
        d = torch.tensor(d, dtype=torch.float32).to(device)

        with torch.no_grad():
            next_q = self.target_net(ns).max(1)[0]
            n_step_gamma = self.gamma ** self.n_step
            q_target = r + self.gamma * next_q * (1.0 - d)

        q_expected = self.policy_net(s).gather(1, a.unsqueeze(1)).squeeze(1)

        loss = self.loss_fn(q_expected, q_target)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.scheduler.step()
        self.update_target()

        debugger.log('train_loss', loss.item())
        debugger.log('epsilon', self.epsilon)
        debugger.log('learning_rate', self.scheduler.get_last_lr()[0])

    def update_target(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def soft_update(self):
        for tparam, pparam in zip(self.target_net.parameters(), self.policy_net.parameters()):
            tparam.data.copy_(tparam.data * (1.0 - self.tau) + pparam.data * self.tau)

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        
class Controller:
    def __init__(self, cfg):
        self.cfg = cfg
        self.step = 0
        self.state_dim = cfg.state_dim_ctrl
        self.low_dim = cfg.num_low_actions
        
        self.gamma = cfg.gamma
        self.epsilon = cfg.epsilon_start
        self.epsilon_min = cfg.epsilon_min
        self.epsilon_decay = cfg.epsilon_decay
        self.batch_size = cfg.batch_size
        self.tau = cfg.tau

        self.buffer = ReplayBuffer(cfg.buffer_capacity)

        self.policy_net = MultiHeadQNetwork(
            self.state_dim,
            self.low_dim,
            num_heads=4
        ).to(device)
        self.target_net = MultiHeadQNetwork(
            self.state_dim,
            self.low_dim,
            num_heads=4
        ).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=cfg.learning_rate)

        self.scheduler = optim.lr_scheduler.ExponentialLR(
            self.optimizer, gamma=cfg.learning_rate_decay
        )

        self.loss_fn = nn.MSELoss()
        self.nb_interval = cfg.nb_interval

    def select_action(self, state):
        if random.random() < self.epsilon:
            return [random.randint(0, self.low_dim - 1) for _ in range(4)]
        
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        with torch.no_grad():
            qvals = self.policy_net(state)   # (1, 4, actions)
            actions = qvals.argmax(dim=2).squeeze(0)
            return actions.tolist()
        
    def remember(self, s, action, r, ns, done):
        self.buffer.push(s, action, r, ns, done)

    def train_step(self):
        self.step += 1
        if self.step % self.nb_interval == 0 and \
           len(self.buffer) >= self.batch_size:
            self.learn()

    def learn(self):
        batch = self.buffer.sample(self.batch_size)
        s, a, r, ns, d = zip(*batch)

        s = torch.tensor(np.stack(s), dtype=torch.float32).to(device)
        ns = torch.tensor(np.stack(ns), dtype=torch.float32).to(device)
        a = torch.tensor(np.stack(a), dtype=torch.long).to(device)
        r = torch.tensor(r, dtype=torch.float32).to(device).unsqueeze(1)
        d = torch.tensor(d, dtype=torch.float32).to(device).unsqueeze(1)

        # ---------- target ----------
        with torch.no_grad():
            next_q = self.target_net(ns)
            q_max_next = next_q.max(dim=2)[0]
            q_target = r + self.gamma * q_max_next * (1 - d)

        # ---------- expected ----------
        q_expected = self.policy_net(s).gather(2, a.unsqueeze(2)).squeeze(2)

        loss = self.loss_fn(q_expected, q_target)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.scheduler.step()
        self.update_target()

        debugger.log('train_loss_ctrl', loss.item())
        debugger.log('epsilon_ctrl', self.epsilon)
        debugger.log('learning_rate_ctrl', self.scheduler.get_last_lr()[0])
        
    def update_target(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def soft_update(self):
        for tparam, pparam in zip(self.target_net.parameters(), self.policy_net.parameters()):
            tparam.data.copy_(
                tparam.data * (1.0 - self.tau) + pparam.data * self.tau
            )

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def reset_step(self):
        self.step = 0

# %%
class FeatureAdapter:
    def __init__(self, env: CacheEngineEnv, cfg: Any):
        self.env = env
        self.cfg = cfg

        self.video_hist_short = deque(maxlen=cfg.h_short)
        self.video_hist_long = deque(maxlen=cfg.h_long)
        self.tile_hist_short = deque(maxlen=cfg.h_short * cfg.viewport)
        self.tile_hist_long = deque(maxlen=cfg.h_long * cfg.viewport)
        self.tiles_hist_short = deque(maxlen=cfg.h_short)
        self.tiles_hist_long = deque(maxlen=cfg.h_long)

        self.video_freq_short = defaultdict(int)
        self.video_freq_long = defaultdict(int)
        self.tile_freq_short = defaultdict(int)
        self.tile_freq_long = defaultdict(int)
        self.tiles_freq_short = defaultdict(int)
        self.tiles_freq_long = defaultdict(int)

        self.ch_video_hist = deque(maxlen=cfg.h_long)
        self.ch_viewport_hist = deque(maxlen=cfg.h_long)
        
    def reset_history(self):
        queues = (
            self.video_hist_short,
            self.video_hist_long,
            self.tiles_hist_short,
            self.tiles_hist_long,
            self.tile_hist_short,
            self.tile_hist_long,
            self.ch_video_hist,
            self.ch_viewport_hist,            
        )
        freqs = (
            self.video_freq_short,
            self.video_freq_long,
            self.tiles_freq_short,
            self.tiles_freq_long,
            self.tile_freq_short,
            self.tile_freq_long,
        )
        
        for q in queues:
            q.clear()
        for f in freqs:
            f.clear()

    def update_history(self, vid: int, tiles: list[int]):       
        self._update_window(self.video_hist_short, self.video_freq_short, vid)
        self._update_window(self.video_hist_long, self.video_freq_long, vid)

        tiles = tuple(tiles) if tiles is not None else None

        if tiles is None:
            return

        self._update_window(self.tiles_hist_short, self.tiles_freq_short, tiles)
        self._update_window(self.tiles_hist_long, self.tiles_freq_long, tiles)

        for tile in tiles:
            self._update_window(self.tile_hist_short, self.tile_freq_short, (vid, tile))
            self._update_window(self.tile_hist_long, self.tile_freq_long, (vid, tile))

    def update_history_single(self, item):
        if isinstance(item, int):
            self._update_window(self.video_hist_short, self.video_freq_short, item)
            self._update_window(self.video_hist_long, self.video_freq_long, item)
        elif isinstance(item, tuple) and len(item) == 2:
            self._update_window(self.tile_hist_short, self.tile_freq_short, item)
            self._update_window(self.tile_hist_long, self.tile_freq_long, item)
        elif isinstance(item, tuple) and all(isinstance(i, int) for i in item):
            self._update_window(self.tiles_hist_short, self.tiles_freq_short, item)
            self._update_window(self.tiles_hist_long, self.tiles_freq_long, item)

    def update_ch_history(self, vid: int, viewport: list[int]) -> None:
        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        hit = 1 if vid in video_cache_index else 0
        self.ch_video_hist.append(hit)
        
        if not hit:
            viewport_vector = [0,0,0,0]
        else:
            idx = video_cache_index.index(vid)
            cached_tiles = tile_cache_index[idx]
            viewport_vector = [1 if tile in cached_tiles else 0 for tile in viewport]
            
        self.ch_viewport_hist.append(viewport_vector)

    def compute_reward_layer_0(self, window_size: int = None) -> float:
        if window_size is None:
            window_size = len(self.ch_video_hist)

        ch_video_list = list(self.ch_video_hist)[-window_size:]
        psnr_layer_0 = 30 * sum(ch_video_list)
        
        return psnr_layer_0 / len(ch_video_list) if ch_video_list else 0

    def compute_reward_layer_1(self, window_size: int = None) -> float:
        if window_size is None:
            window_size = len(self.ch_viewport_hist)

        ch_viewport_list = list(self.ch_viewport_hist)[-window_size:]
        psnr_layer_1 = 2.5 * sum(sum(viewport) for viewport in ch_viewport_list)

        return psnr_layer_1 / len(ch_viewport_list) if ch_viewport_list else 0

    def compute_reward(self, window_size: int = None) -> float:
        if window_size is None:
            window_size = len(self.ch_video_hist)
        
        ch_video_list = list(self.ch_video_hist)[-window_size:]
        ch_viewport_list = list(self.ch_viewport_hist)[-window_size:]

        psnr_layer_0 = 30 * sum(ch_video_list)
        psnr_layer_1 = 2.5 * sum(sum(viewport) for viewport in ch_viewport_list)

        total_items = len(ch_video_list)
        return (psnr_layer_0 + psnr_layer_1) / total_items if total_items > 0 else 0

    def _update_window(self, hist_queue: deque, freq_dict: Dict, item):
        if len(hist_queue) == hist_queue.maxlen:
            old_item = hist_queue.popleft()
            freq_dict[old_item] -= 1
            if freq_dict[old_item] == 0:
                del freq_dict[old_item]
        hist_queue.append(item)
        freq_dict[item] += 1

# %%
class NetworkAdapter:
    def __init__(self, env: EnvWrapper, feature_adapter: FeatureAdapter, cfg: Any):
        self.env = env
        self.cfg = cfg
        self.features = feature_adapter

        self.C = self.cfg.cache_size  # paper's cache capacity (videos)
        self.k = self.cfg.viewport    # paper's tiles per video (enhancement)

        print(f"NetworkAdapter initialized with capacity: {self.C} videos, {self.k} tiles per video")

    def build_observation(self, vid: int, viewport: list = None) -> np.ndarray:
        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        if viewport is None:
            
            x_s = np.zeros(self.C, dtype=np.float32)
            x_l = np.zeros(self.C, dtype=np.float32)

            for vid_i, v in enumerate(video_cache_index):
                if v == -1:
                    continue
                x_s[vid_i] = self.features.video_freq_short.get(v, 0)
                x_l[vid_i] = self.features.video_freq_long.get(v, 0)

            z_s = np.array(
                [self.features.video_freq_short.get(vid, 0)], dtype=np.float32
            )
            z_l = np.array(
                [self.features.video_freq_long.get(vid, 0)], dtype=np.float32
            )

            features = np.log1p(np.concatenate([x_s, x_l, z_s, z_l], axis=0))
            return features
        else:            
            y_s = np.zeros(self.C * self.k, dtype=np.float32)
            y_l = np.zeros(self.C * self.k, dtype=np.float32)

            for vid_i, v in enumerate(video_cache_index):
                if v == -1:
                    continue

                tiles = tile_cache_index[vid_i]
                for til_i, t in enumerate(tiles):
                    if t == -1:
                        continue
                    y_s[vid_i * self.k + til_i] = self.features.tile_freq_short.get((v, t), 0)
                    y_l[vid_i * self.k + til_i] = self.features.tile_freq_long.get((v, t), 0)

            z_s = np.zeros(len(viewport), dtype=np.float32)
            z_l = np.zeros(len(viewport), dtype=np.float32)

            for i, tile in enumerate(viewport):
                z_s[i] = self.features.tile_freq_short.get((vid, tile), 0)
                z_l[i] = self.features.tile_freq_long.get((vid, tile), 0)

            features = np.log1p(np.concatenate([y_s, y_l, z_s, z_l], axis=0))
            return features

    def reset(self):
        
        obs, info = self.env.reset()
        self.features.reset_history()

        return obs, info
    
    def env_is_done(self) -> bool:
        return self.env.users_env.all_users_done()

# %%
def save_training_results(
    path_,
    filename,
    ep, 
    total_reward, 
    cache_hits, 
    cache_misses,
    base_hits,
    base_misses,
    enh_hits,
    enh_misses,
    agent
):
    with open(os.path.join(path_, filename), 'a', newline='') as f:
        fieldnames = [
            'episode', 
            'total_reward', 
            'cache_hits', 
            'cache_misses', 
            'base_hits',
            'base_misses',
            'enh_hits',
            'enh_misses',
            'epsilon',
            'lr'
        ]
        writer_results = csv.DictWriter(f, fieldnames=fieldnames)

        if ep == 0:
            writer_results.writeheader()
        
        writer_results.writerow({
            'episode': ep,
            'total_reward': round(float(total_reward), 2),
            'cache_hits': cache_hits,
            'cache_misses': cache_misses,
            'base_hits': base_hits,
            'base_misses': base_misses,
            'enh_hits': enh_hits,
            'enh_misses': enh_misses,
            'lr': f"{agent.scheduler.get_last_lr()[0]:.10f}" if agent else None,
            'epsilon': round(float(agent.epsilon), 4) if agent else None
        })

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, float, int, int]:
    enh_hits = info.get("enh_layer_hits", 0)
    base_hits = info.get("base_layer_hits", 0)
    enh_misses = info.get("enh_layer_misses", 0)
    base_misses = info.get("base_layer_misses", 0)

    return reward, (enh_hits + base_hits), (enh_misses + base_misses), base_hits, base_misses, enh_hits, enh_misses

def build_latency_model(cfg):
    """Build and return the MultiDULatencyModel."""
    P = cfg.n_nodes
    max_U = cfg.n_users

    return MultiDULatencyModel(
        P=P,
        max_U=max_U,
        R_M_D=80e6,
        R_C_M=125e6,
        mu=2e7,
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float),
        rhoT_p=[0.2],
        lambda_p=[0.05],
        du_fixed_delay=0.001,
        mec_fixed_delay=0.005,
        cloud_fixed_delay=0.1
    )

def build_environment(cfg):
    """Construct the full multi-component environment wrapper."""
    du_caches = []

    # DRL Caching Policy
    policy = DrlPolicy(cfg=cfg)

    # MEC Cache Engine
    mec_cache = CacheEngineEnv(
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n_gops=cfg.n_gops,
        cache_capacity=cfg.cache_capacity,
        policy=policy
    )

    # User request generator
    users_env = UserRequestEvents(
        n_nodes=cfg.n_nodes,
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_gops=cfg.n_gops,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n=cfg.n,
        m=cfg.m,
        arrival_rate=cfg.arrival_rate,
        zipf_alpha=cfg.zipf_alpha
    )

    # Latency Model
    latency_model = build_latency_model(cfg)

    # Wrapping all into the main training environment
    return EnvWrapper(
        cfg=cfg,
        n=cfg.n,
        m=cfg.m,
        n_layers=cfg.n_layers,
        users_env=users_env,
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=latency_model,
        theta=cfg.theta,
        lam=cfg.lam,
        max_steps=cfg.max_steps,
        prefetch_fn=lambda cache, action: cache.drl_prefetching_kulkarni(action),
        reward_fn=lambda env, reqs: env.compute_reward(reqs),
        debugger=debugger
    )

# %%
def run_episode(episode, env, meta, ctrl, net_adapter, cfg):
    """Run one full training episode."""
    _, info = net_adapter.reset()

    cache_hits = cache_misses = 0
    soft_hits = total_reward = 0.0
    base_hits = base_misses = 0
    enh_hits = enh_misses = 0
    
    info = env.warmup_phase(net_adapter)

    for step in count():
        req_state = info["user_request"]

        _, reward, _, info = env.step(meta, ctrl, net_adapter, req_state)

        delta_r, hits, misses, bs_hits, bs_misses, e_hits, e_misses = update_metrics(info, reward)
        total_reward += delta_r
        cache_hits += hits
        cache_misses += misses
        base_hits += bs_hits
        base_misses += bs_misses
        enh_hits += e_hits
        enh_misses += e_misses

        if net_adapter.env_is_done():
            break
    
        debugger.log('cache_hits', hits)
        debugger.log('cache_misses', misses)
        debugger.log('step_reward', reward)
        debugger.log('cumulative_reward', total_reward)
    
    return total_reward, cache_hits, cache_misses, base_hits, base_misses, enh_hits, enh_misses

def train(cfg):
    print("\n--- Starting DRL Caching System ---")

    env = build_environment(cfg)

    meta = MetaController(cfg)
    ctrl = Controller(cfg)

    feature_adapter = FeatureAdapter(env, cfg)
    net_adapter = NetworkAdapter(env, feature_adapter, cfg)

    date_dir = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M")

    for episode in range(cfg.n_episodes):

        total_reward, hits, misses, base_hits, base_misses, enh_hits, enh_misses = run_episode(
            episode, env, meta, ctrl, net_adapter, cfg
        )

        ctrl.update_epsilon()
        meta.update_epsilon()

        save_training_results(
            path_=cfg.path_results,
            filename=cfg.filename,
            ep=episode,
            total_reward=total_reward,
            cache_hits=hits,
            cache_misses=misses,
            base_hits=base_hits,
            base_misses=base_misses,
            enh_hits=enh_hits,
            enh_misses=enh_misses,
            agent=meta
        )

        hit_rate = hits / (hits + misses + 1e-9)
        base_hit_rate = base_hits / (base_hits + base_misses)
        print(
            f"--- Episode {episode} | TR: {total_reward:.2f} | CHR: {hit_rate:.2f} | "
            f"BHR: {base_hit_rate:.2f} | EHR: {enh_hits / (enh_hits + enh_misses + 1e-9):.2f} ---"
        )

        debug_path = os.path.join(cfg.path_results, date_dir)
        os.makedirs(debug_path, exist_ok=True)
        
        # debugger.histogram("base_layer", "Base Controller Decisions")
        # debugger.histogram("enh_layer_1", "Enh Layer 1 Controller Decisions")
        # debugger.histogram("enh_layer_2", "Enh Layer 2 Controller Decisions")
        # debugger.histogram("enh_layer_3", "Enh Layer 3 Controller Decisions")
        # debugger.histogram("enh_layer_4", "Enh Layer 4 Controller Decisions")

        debugger.save_results(filepath=f"{debug_path}/debug_ep{episode}")
        debugger.clear()

if __name__ == "__main__":
    train(cfg)
# Out:
# --- Starting DRL Caching System ---
# NetworkAdapter initialized with capacity: 50 videos, 4 tiles per video
# --- Episode 0 | TR: 178209.25 | CHR: 0.44 | BHR: 0.51 | EHR: 0.22 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep0
# --- Episode 1 | TR: 199042.90 | CHR: 0.47 | BHR: 0.54 | EHR: 0.26 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep1
# --- Episode 2 | TR: 182786.60 | CHR: 0.44 | BHR: 0.50 | EHR: 0.25 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep2
# --- Episode 3 | TR: 169862.40 | CHR: 0.44 | BHR: 0.50 | EHR: 0.23 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep3
# --- Episode 4 | TR: 170715.59 | CHR: 0.46 | BHR: 0.53 | EHR: 0.25 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep4
# --- Episode 5 | TR: 189185.93 | CHR: 0.46 | BHR: 0.54 | EHR: 0.24 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep5
# --- Episode 6 | TR: 204565.82 | CHR: 0.48 | BHR: 0.55 | EHR: 0.27 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep6
# --- Episode 7 | TR: 165672.04 | CHR: 0.44 | BHR: 0.49 | EHR: 0.26 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep7
# --- Episode 8 | TR: 182106.24 | CHR: 0.48 | BHR: 0.55 | EHR: 0.27 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep8
# --- Episode 9 | TR: 189032.29 | CHR: 0.45 | BHR: 0.52 | EHR: 0.25 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep9
# --- Episode 10 | TR: 188034.63 | CHR: 0.46 | BHR: 0.53 | EHR: 0.25 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep10
# --- Episode 11 | TR: 184216.96 | CHR: 0.46 | BHR: 0.53 | EHR: 0.25 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep11
# --- Episode 12 | TR: 187390.59 | CHR: 0.46 | BHR: 0.52 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep12
# --- Episode 13 | TR: 181183.60 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep13
# --- Episode 14 | TR: 193330.36 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep14
# --- Episode 15 | TR: 198160.94 | CHR: 0.48 | BHR: 0.54 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep15
# --- Episode 16 | TR: 203953.62 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep16
# --- Episode 17 | TR: 181638.54 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep17
# --- Episode 18 | TR: 192711.40 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep18
# --- Episode 19 | TR: 188466.60 | CHR: 0.44 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep19
# --- Episode 20 | TR: 188121.51 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep20
# --- Episode 21 | TR: 186390.85 | CHR: 0.44 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep21
# --- Episode 22 | TR: 165488.47 | CHR: 0.45 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep22
# --- Episode 23 | TR: 171230.67 | CHR: 0.44 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep23
# --- Episode 24 | TR: 183202.19 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep24
# --- Episode 25 | TR: 198527.86 | CHR: 0.50 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep25
# --- Episode 26 | TR: 183661.29 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep26
# --- Episode 27 | TR: 210585.88 | CHR: 0.50 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep27
# --- Episode 28 | TR: 190095.83 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep28
# --- Episode 29 | TR: 168544.70 | CHR: 0.44 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep29
# --- Episode 30 | TR: 199924.38 | CHR: 0.48 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep30
# --- Episode 31 | TR: 178853.93 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep31
# --- Episode 32 | TR: 183510.12 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep32
# --- Episode 33 | TR: 181351.47 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep33
# --- Episode 34 | TR: 178790.20 | CHR: 0.45 | BHR: 0.51 | EHR: 0.27 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep34
# --- Episode 35 | TR: 208114.31 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep35
# --- Episode 36 | TR: 177741.33 | CHR: 0.46 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep36
# --- Episode 37 | TR: 185768.34 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep37
# --- Episode 38 | TR: 166407.68 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep38
# --- Episode 39 | TR: 174067.08 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep39
# --- Episode 40 | TR: 179663.18 | CHR: 0.48 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep40
# --- Episode 41 | TR: 173535.35 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep41
# --- Episode 42 | TR: 165821.77 | CHR: 0.46 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep42
# --- Episode 43 | TR: 164282.05 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep43
# --- Episode 44 | TR: 182479.64 | CHR: 0.46 | BHR: 0.52 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep44
# --- Episode 45 | TR: 185487.92 | CHR: 0.49 | BHR: 0.54 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep45
# --- Episode 46 | TR: 195692.31 | CHR: 0.49 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep46
# --- Episode 47 | TR: 166920.80 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep47
# --- Episode 48 | TR: 174563.01 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep48
# --- Episode 49 | TR: 176215.76 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep49
# --- Episode 50 | TR: 191587.69 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep50
# --- Episode 51 | TR: 168854.34 | CHR: 0.46 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep51
# --- Episode 52 | TR: 175105.06 | CHR: 0.47 | BHR: 0.53 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep52
# --- Episode 53 | TR: 196441.35 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep53
# --- Episode 54 | TR: 181647.59 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep54
# --- Episode 55 | TR: 167424.80 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep55
# --- Episode 56 | TR: 198891.23 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep56
# --- Episode 57 | TR: 196809.77 | CHR: 0.48 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep57
# --- Episode 58 | TR: 186265.45 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep58
# --- Episode 59 | TR: 169108.73 | CHR: 0.42 | BHR: 0.47 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep59
# --- Episode 60 | TR: 172222.41 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep60
# --- Episode 61 | TR: 182941.18 | CHR: 0.44 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep61
# --- Episode 62 | TR: 180706.71 | CHR: 0.46 | BHR: 0.52 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep62
# --- Episode 63 | TR: 165651.21 | CHR: 0.44 | BHR: 0.49 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep63
# --- Episode 64 | TR: 167125.18 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep64
# --- Episode 65 | TR: 176427.92 | CHR: 0.47 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep65
# --- Episode 66 | TR: 174954.22 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep66
# --- Episode 67 | TR: 171422.61 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep67
# --- Episode 68 | TR: 178378.18 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep68
# --- Episode 69 | TR: 171368.72 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep69
# --- Episode 70 | TR: 187242.55 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep70
# --- Episode 71 | TR: 183326.65 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep71
# --- Episode 72 | TR: 201623.12 | CHR: 0.48 | BHR: 0.54 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep72
# --- Episode 73 | TR: 179127.95 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep73
# --- Episode 74 | TR: 178587.58 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep74
# --- Episode 75 | TR: 186983.48 | CHR: 0.46 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep75
# --- Episode 76 | TR: 198832.40 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep76
# --- Episode 77 | TR: 185306.28 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep77
# --- Episode 78 | TR: 175970.29 | CHR: 0.47 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep78
# --- Episode 79 | TR: 203006.63 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep79
# --- Episode 80 | TR: 183789.34 | CHR: 0.45 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep80
# --- Episode 81 | TR: 180919.79 | CHR: 0.47 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep81
# --- Episode 82 | TR: 195403.26 | CHR: 0.46 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep82
# --- Episode 83 | TR: 191008.24 | CHR: 0.51 | BHR: 0.57 | EHR: 0.32 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep83
# --- Episode 84 | TR: 187632.36 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep84
# --- Episode 85 | TR: 187513.49 | CHR: 0.47 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep85
# --- Episode 86 | TR: 198396.61 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep86
# --- Episode 87 | TR: 182975.48 | CHR: 0.47 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep87
# --- Episode 88 | TR: 184955.64 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep88
# --- Episode 89 | TR: 185058.47 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep89
# --- Episode 90 | TR: 186778.44 | CHR: 0.50 | BHR: 0.56 | EHR: 0.32 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep90
# --- Episode 91 | TR: 182452.24 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep91
# --- Episode 92 | TR: 182626.80 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep92
# --- Episode 93 | TR: 208890.65 | CHR: 0.50 | BHR: 0.57 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep93
# --- Episode 94 | TR: 180840.38 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep94
# --- Episode 95 | TR: 181498.57 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep95
# --- Episode 96 | TR: 202968.59 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep96
# --- Episode 97 | TR: 179380.16 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep97
# --- Episode 98 | TR: 181726.96 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep98
# --- Episode 99 | TR: 167364.31 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep99
# --- Episode 100 | TR: 184073.19 | CHR: 0.46 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep100
# --- Episode 101 | TR: 189847.08 | CHR: 0.47 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep101
# --- Episode 102 | TR: 174049.87 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep102
# --- Episode 103 | TR: 199271.61 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep103
# --- Episode 104 | TR: 198694.88 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep104
# --- Episode 105 | TR: 199236.62 | CHR: 0.49 | BHR: 0.55 | EHR: 0.32 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep105
# --- Episode 106 | TR: 199093.90 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep106
# --- Episode 107 | TR: 177548.39 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep107
# --- Episode 108 | TR: 174979.06 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep108
# --- Episode 109 | TR: 184631.57 | CHR: 0.47 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep109
# --- Episode 110 | TR: 188668.49 | CHR: 0.50 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep110
# --- Episode 111 | TR: 200127.71 | CHR: 0.50 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep111
# --- Episode 112 | TR: 190622.93 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep112
# --- Episode 113 | TR: 184364.29 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep113
# --- Episode 114 | TR: 169370.76 | CHR: 0.44 | BHR: 0.49 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep114
# --- Episode 115 | TR: 192564.00 | CHR: 0.49 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep115
# --- Episode 116 | TR: 171424.10 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep116
# --- Episode 117 | TR: 197389.61 | CHR: 0.48 | BHR: 0.54 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep117
# --- Episode 118 | TR: 180392.03 | CHR: 0.46 | BHR: 0.53 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep118
# --- Episode 119 | TR: 177458.79 | CHR: 0.46 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep119
# --- Episode 120 | TR: 185853.19 | CHR: 0.49 | BHR: 0.55 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep120
# --- Episode 121 | TR: 169263.25 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep121
# --- Episode 122 | TR: 176994.14 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep122
# --- Episode 123 | TR: 189885.58 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep123
# --- Episode 124 | TR: 178654.23 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep124
# --- Episode 125 | TR: 168614.29 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep125
# --- Episode 126 | TR: 157710.62 | CHR: 0.44 | BHR: 0.49 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep126
# --- Episode 127 | TR: 193496.23 | CHR: 0.49 | BHR: 0.55 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep127
# --- Episode 128 | TR: 180751.51 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep128
# --- Episode 129 | TR: 184830.04 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep129
# --- Episode 130 | TR: 185925.56 | CHR: 0.44 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep130
# --- Episode 131 | TR: 166695.11 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep131
# --- Episode 132 | TR: 179629.17 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep132
# --- Episode 133 | TR: 169367.22 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep133
# --- Episode 134 | TR: 186966.41 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep134
# --- Episode 135 | TR: 194759.88 | CHR: 0.49 | BHR: 0.55 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep135
# --- Episode 136 | TR: 196361.74 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep136
# --- Episode 137 | TR: 220674.28 | CHR: 0.51 | BHR: 0.57 | EHR: 0.32 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep137
# --- Episode 138 | TR: 201693.55 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep138
# --- Episode 139 | TR: 183338.51 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep139
# --- Episode 140 | TR: 198179.12 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep140
# --- Episode 141 | TR: 183615.29 | CHR: 0.43 | BHR: 0.49 | EHR: 0.27 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep141
# --- Episode 142 | TR: 181542.97 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep142
# --- Episode 143 | TR: 184732.02 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep143
# --- Episode 144 | TR: 172401.17 | CHR: 0.44 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep144
# --- Episode 145 | TR: 190100.06 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep145
# --- Episode 146 | TR: 175064.89 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep146
# --- Episode 147 | TR: 172059.21 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep147
# --- Episode 148 | TR: 173597.54 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep148
# --- Episode 149 | TR: 195074.74 | CHR: 0.48 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep149
# --- Episode 150 | TR: 175931.16 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep150
# --- Episode 151 | TR: 185885.57 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep151
# --- Episode 152 | TR: 182587.00 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep152
# --- Episode 153 | TR: 181638.35 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep153
# --- Episode 154 | TR: 189373.14 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep154
# --- Episode 155 | TR: 191662.87 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep155
# --- Episode 156 | TR: 166198.29 | CHR: 0.44 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep156
# --- Episode 157 | TR: 197133.70 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep157
# --- Episode 158 | TR: 193211.00 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep158
# --- Episode 159 | TR: 187944.66 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep159
# --- Episode 160 | TR: 184563.55 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep160
# --- Episode 161 | TR: 190887.45 | CHR: 0.49 | BHR: 0.55 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep161
# --- Episode 162 | TR: 210627.52 | CHR: 0.50 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep162
# --- Episode 163 | TR: 175782.16 | CHR: 0.47 | BHR: 0.53 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep163
# --- Episode 164 | TR: 177916.07 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep164
# --- Episode 165 | TR: 168989.97 | CHR: 0.43 | BHR: 0.48 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep165
# --- Episode 166 | TR: 188426.65 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep166
# --- Episode 167 | TR: 173841.13 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep167
# --- Episode 168 | TR: 189186.33 | CHR: 0.46 | BHR: 0.52 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep168
# --- Episode 169 | TR: 173481.18 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep169
# --- Episode 170 | TR: 186329.68 | CHR: 0.47 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep170
# --- Episode 171 | TR: 186941.37 | CHR: 0.46 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep171
# --- Episode 172 | TR: 182720.59 | CHR: 0.45 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep172
# --- Episode 173 | TR: 199986.75 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep173
# --- Episode 174 | TR: 183689.51 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep174
# --- Episode 175 | TR: 193075.71 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep175
# --- Episode 176 | TR: 183575.66 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep176
# --- Episode 177 | TR: 188947.84 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep177
# --- Episode 178 | TR: 201314.42 | CHR: 0.50 | BHR: 0.56 | EHR: 0.32 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep178
# --- Episode 179 | TR: 199159.92 | CHR: 0.50 | BHR: 0.56 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep179
# --- Episode 180 | TR: 201768.17 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep180
# --- Episode 181 | TR: 176817.49 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep181
# --- Episode 182 | TR: 177819.89 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep182
# --- Episode 183 | TR: 187168.28 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep183
# --- Episode 184 | TR: 163549.45 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep184
# --- Episode 185 | TR: 184483.01 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep185
# --- Episode 186 | TR: 184478.59 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep186
# --- Episode 187 | TR: 185224.23 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep187
# --- Episode 188 | TR: 177610.32 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep188
# --- Episode 189 | TR: 184645.94 | CHR: 0.46 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep189
# --- Episode 190 | TR: 181311.54 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep190
# --- Episode 191 | TR: 196249.28 | CHR: 0.50 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep191
# --- Episode 192 | TR: 177634.79 | CHR: 0.45 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep192
# --- Episode 193 | TR: 202365.16 | CHR: 0.48 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep193
# --- Episode 194 | TR: 181711.81 | CHR: 0.48 | BHR: 0.54 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep194
# --- Episode 195 | TR: 158812.72 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep195
# --- Episode 196 | TR: 166206.62 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep196
# --- Episode 197 | TR: 183338.63 | CHR: 0.46 | BHR: 0.52 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep197
# --- Episode 198 | TR: 196565.90 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep198
# --- Episode 199 | TR: 190425.23 | CHR: 0.48 | BHR: 0.54 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep199
# --- Episode 200 | TR: 183093.38 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep200
# --- Episode 201 | TR: 200447.62 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep201
# --- Episode 202 | TR: 178953.11 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep202
# --- Episode 203 | TR: 181015.95 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep203
# --- Episode 204 | TR: 192373.42 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep204
# --- Episode 205 | TR: 174372.15 | CHR: 0.45 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep205
# --- Episode 206 | TR: 186510.55 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep206
# --- Episode 207 | TR: 184104.29 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep207
# --- Episode 208 | TR: 172136.64 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep208
# --- Episode 209 | TR: 186143.29 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep209
# --- Episode 210 | TR: 177974.60 | CHR: 0.46 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep210
# --- Episode 211 | TR: 191607.45 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep211
# --- Episode 212 | TR: 190082.06 | CHR: 0.50 | BHR: 0.57 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep212
# --- Episode 213 | TR: 196840.36 | CHR: 0.48 | BHR: 0.53 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep213
# --- Episode 214 | TR: 184163.11 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep214
# --- Episode 215 | TR: 189008.60 | CHR: 0.48 | BHR: 0.55 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep215
# --- Episode 216 | TR: 179362.52 | CHR: 0.44 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep216
# --- Episode 217 | TR: 196981.90 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep217
# --- Episode 218 | TR: 178086.66 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep218
# --- Episode 219 | TR: 175751.51 | CHR: 0.45 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep219
# --- Episode 220 | TR: 207127.53 | CHR: 0.49 | BHR: 0.55 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep220
# --- Episode 221 | TR: 178412.10 | CHR: 0.45 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep221
# --- Episode 222 | TR: 194998.77 | CHR: 0.50 | BHR: 0.56 | EHR: 0.32 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep222
# --- Episode 223 | TR: 182951.11 | CHR: 0.48 | BHR: 0.54 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep223
# --- Episode 224 | TR: 166218.63 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep224
# --- Episode 225 | TR: 188658.30 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep225
# --- Episode 226 | TR: 164960.86 | CHR: 0.43 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep226
# --- Episode 227 | TR: 188703.04 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep227
# --- Episode 228 | TR: 177719.40 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep228
# --- Episode 229 | TR: 177603.84 | CHR: 0.46 | BHR: 0.52 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep229
# --- Episode 230 | TR: 203253.27 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep230
# --- Episode 231 | TR: 208718.16 | CHR: 0.49 | BHR: 0.55 | EHR: 0.32 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep231
# --- Episode 232 | TR: 197216.56 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep232
# --- Episode 233 | TR: 173934.32 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep233
# --- Episode 234 | TR: 169962.71 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep234
# --- Episode 235 | TR: 200633.54 | CHR: 0.50 | BHR: 0.56 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep235
# --- Episode 236 | TR: 170102.76 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep236
# --- Episode 237 | TR: 184386.90 | CHR: 0.45 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep237
# --- Episode 238 | TR: 188557.29 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep238
# --- Episode 239 | TR: 182622.52 | CHR: 0.44 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep239
# --- Episode 240 | TR: 164063.54 | CHR: 0.44 | BHR: 0.49 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep240
# --- Episode 241 | TR: 187291.79 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep241
# --- Episode 242 | TR: 202047.02 | CHR: 0.47 | BHR: 0.53 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep242
# --- Episode 243 | TR: 180825.64 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep243
# --- Episode 244 | TR: 180023.48 | CHR: 0.47 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep244
# --- Episode 245 | TR: 195864.98 | CHR: 0.50 | BHR: 0.56 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep245
# --- Episode 246 | TR: 167664.22 | CHR: 0.45 | BHR: 0.51 | EHR: 0.27 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep246
# --- Episode 247 | TR: 189882.17 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep247
# --- Episode 248 | TR: 173649.00 | CHR: 0.44 | BHR: 0.49 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep248
# --- Episode 249 | TR: 177869.91 | CHR: 0.46 | BHR: 0.52 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep249
# --- Episode 250 | TR: 190254.03 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep250
# --- Episode 251 | TR: 154678.80 | CHR: 0.43 | BHR: 0.48 | EHR: 0.27 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep251
# --- Episode 252 | TR: 180110.91 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep252
# --- Episode 253 | TR: 192168.62 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep253
# --- Episode 254 | TR: 176511.95 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep254
# --- Episode 255 | TR: 183091.19 | CHR: 0.46 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep255
# --- Episode 256 | TR: 173281.47 | CHR: 0.47 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep256
# --- Episode 257 | TR: 169674.96 | CHR: 0.46 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep257
# --- Episode 258 | TR: 188229.08 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep258
# --- Episode 259 | TR: 176715.09 | CHR: 0.44 | BHR: 0.49 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep259
# --- Episode 260 | TR: 182011.76 | CHR: 0.47 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep260
# --- Episode 261 | TR: 194229.42 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep261
# --- Episode 262 | TR: 195292.67 | CHR: 0.51 | BHR: 0.58 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep262
# --- Episode 263 | TR: 180545.57 | CHR: 0.46 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep263
# --- Episode 264 | TR: 182601.49 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep264
# --- Episode 265 | TR: 185688.00 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep265
# --- Episode 266 | TR: 154703.19 | CHR: 0.41 | BHR: 0.45 | EHR: 0.27 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep266
# --- Episode 267 | TR: 170399.17 | CHR: 0.45 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep267
# --- Episode 268 | TR: 196263.57 | CHR: 0.49 | BHR: 0.54 | EHR: 0.31 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep268
# --- Episode 269 | TR: 188884.96 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep269
# --- Episode 270 | TR: 180596.89 | CHR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep270
# --- Episode 271 | TR: 169793.55 | CHR: 0.44 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep271
# --- Episode 272 | TR: 168088.05 | CHR: 0.45 | BHR: 0.50 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep272
# --- Episode 273 | TR: 182053.97 | CHR: 0.46 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep273
# --- Episode 274 | TR: 171998.40 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep274
# --- Episode 275 | TR: 172229.52 | CHR: 0.44 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep275
# --- Episode 276 | TR: 180770.61 | CHR: 0.47 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep276
# --- Episode 277 | TR: 170927.49 | CHR: 0.43 | BHR: 0.49 | EHR: 0.27 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep277
# --- Episode 278 | TR: 184993.83 | CHR: 0.48 | BHR: 0.55 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep278
# --- Episode 279 | TR: 175347.68 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep279
# --- Episode 280 | TR: 183307.11 | CHR: 0.46 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep280
# --- Episode 281 | TR: 187836.49 | CHR: 0.46 | BHR: 0.52 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep281
# --- Episode 282 | TR: 191930.19 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep282
# --- Episode 283 | TR: 169592.13 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep283
# --- Episode 284 | TR: 190970.45 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep284
# --- Episode 285 | TR: 180947.65 | CHR: 0.46 | BHR: 0.51 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep285
# --- Episode 286 | TR: 195128.75 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep286
# --- Episode 287 | TR: 180338.80 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep287
# --- Episode 288 | TR: 189821.20 | CHR: 0.49 | BHR: 0.56 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep288
# --- Episode 289 | TR: 178703.04 | CHR: 0.46 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep289
# --- Episode 290 | TR: 180899.72 | CHR: 0.46 | BHR: 0.51 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep290
# --- Episode 291 | TR: 181613.07 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep291
# --- Episode 292 | TR: 179381.65 | CHR: 0.46 | BHR: 0.52 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep292
# --- Episode 293 | TR: 176928.42 | CHR: 0.46 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep293
# --- Episode 294 | TR: 164832.57 | CHR: 0.45 | BHR: 0.50 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep294
# --- Episode 295 | TR: 178049.09 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep295
# --- Episode 296 | TR: 186314.71 | CHR: 0.48 | BHR: 0.54 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep296
# --- Episode 297 | TR: 179790.47 | CHR: 0.44 | BHR: 0.49 | EHR: 0.28 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep297
# --- Episode 298 | TR: 191482.04 | CHR: 0.48 | BHR: 0.54 | EHR: 0.30 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep298
# --- Episode 299 | TR: 177204.98 | CHR: 0.45 | BHR: 0.51 | EHR: 0.29 ---
# Results saved to /home/eduardo/Workspace/CacheVideoPredict360/Results/2026-02-22_08-51/debug_ep299

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

# Professional color for line plots
PRIMARY_COLOR = "#2b7bba"

# ----------------------------------------------------------------
# 2. Data Loading & Smoothing
# ----------------------------------------------------------------
cfg.filename = f"drl_kulkani_eps{cfg.epsilon_decay}_lrdecay{cfg.learning_rate_decay}.csv"
cfg.filename = "drl_kulkani_eps0.1_lrdecay0.9999_c50_ar200.0_z0.8.csv"
path = cfg.path_results + "/" + cfg.filename

print(f"Loading data from: {path}")

df = pd.read_csv(path)

total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
df["hit_rate"] = (df["cache_hits"] / total) * 100
df["miss_rate"] = (df["cache_misses"] / total) * 100

# Metrics to plot
metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
window_size = 10  # Adjust smoothing window as needed

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
# Adjusted figsize for a 4-column row (standard for full-width paper figures)
fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

for ax, col in zip(axes, metrics):
    # Plot raw data with transparency (alpha)
    ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, alpha=0.3, linewidth=0.8, label='Raw')
    
    # Plot moving average for clearer trend (except for epsilon which is usually linear)
    if col != "epsilon":
        smoothed = df[col].rolling(window=window_size).mean()
        ax.plot(df["episode"], smoothed, color=PRIMARY_COLOR, linewidth=1.5, label='Trend')
    else:
        # Just a solid line for Epsilon
        ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, linewidth=1.5)

    # Stylistic cleanup
    ax.set_title(col.replace("_", " ").title(), fontweight="bold")
    ax.set_xlabel("Episode")
    
    # Remove redundant Y-labels to save space, or keep for clarity
    ax.set_ylabel("Value") 
    
    series = df[col].dropna()
    if not series.empty:
        ymin = series.min()
        ymax = series.max()
        pad = (ymax - ymin) * 0.05 if ymax != ymin else 1.0
        ax.set_ylim(bottom=0)

    ax.grid(axis='y', linestyle='--', alpha=0.3)
    
    # Tufte-style: remove top/right spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# Optional: Add a single legend to the first plot if needed
# axes[0].legend(frameon=False)

plt.show()
fig.savefig("drl_caching_metrics.png", dpi=300)
# Out:
# Loading data from: /home/eduardo/Workspace/CacheVideoPredict360/Results/drl_kulkani_eps0.1_lrdecay0.9999_c50_ar200.0_z0.8.csv
