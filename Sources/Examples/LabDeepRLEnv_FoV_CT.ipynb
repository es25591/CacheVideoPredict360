# %%
import os
import csv
import sys
import math
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from time import sleep
from collections import deque
from itertools import count
from typing import List

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv
    from LabUserTileRequest import UserTileRequestEvents
    from LabEnvWrapper import EnvWrapper

# sys.path.append(r'c:\Users\es25591\Workspace\CacheVideoPredict360\Sources')
sys.path.append('/home/eduardo/Workspace/CacheVideoPredict360/Sources')
from Common.Utils import save_training_results

# %%
# Check PyTorch GPU availability and basic operation
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Using device: {torch.cuda.get_device_name(torch.cuda.current_device())}")
    x = torch.randn(2, 2, device="cuda")
    y = torch.randn(2, 2, device="cuda")
    print("Sample CUDA tensor sum:\n", (x + y))
else:
    print("GPU not detected; running on CPU.")
# Out:
# CUDA available: False
# GPU not detected; running on CPU.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        # state shape: (seq_len, input_size)
        self.memory.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

class LSTM_DQN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1):
        super(LSTM_DQN, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # LSTM Layer: Takes sequence of viewports
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        
        # Fully Connected Layer: Maps LSTM output to Q-values (one per tile index)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden=None):
        # x shape: (batch, seq_len, input_size)
        
        # LSTM output shape: (batch, seq_len, hidden_size)
        lstm_out, hidden = self.lstm(x, hidden)
        
        # We only care about the output of the last time step for prediction
        last_time_step = lstm_out[:, -1, :]
        
        # Q-values
        q_values = self.fc(last_time_step)
        return q_values, hidden

class DQNAgent:
    def __init__(
        self, 
        n_tiles, 
        seq_len, 
        learning_rate=1e-3, 
        gamma=0.99,
        batch_size=64,
        capacity=10000,
        epsilon_start=1.0,
        epsilon_min=0.05,
        epsilon_decay=0.995
    ):
        self.n_tiles = n_tiles
        self.seq_len = seq_len
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        
        self.policy_net = LSTM_DQN(n_tiles, 32, n_tiles + 1).to(device)
        self.target_net = LSTM_DQN(n_tiles, 32, n_tiles + 1).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        
        self.optimizer = optim.Adam(
            self.policy_net.parameters(), 
            lr=learning_rate
        )

        self.criterion = nn.MSELoss()
        self.memory = ReplayMemory(capacity=capacity)
        self.batch_size = batch_size

    def select_action(self, state_seq):
        """
        state_seq: numpy array of shape (seq_len, n_tiles)
        Returns: integer index of the predicted center tile
        """
        if random.random() < self.epsilon:
            return random.randrange(self.n_tiles), None
        else:
            with torch.no_grad():
                state_tensor = torch.FloatTensor(state_seq).unsqueeze(0).to(device)
                q_values, _ = self.policy_net(state_tensor)
                return q_values.argmax().item(), q_values.cpu().numpy()

    def train_step(self):
        if len(self.memory) < self.batch_size:
            return 0.0
        
        batch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        # Convert to tensors
        states = torch.FloatTensor(np.array(states)).to(device)      # (B, Seq, Input)
        next_states = torch.FloatTensor(np.array(next_states)).to(device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(device)  # (B, 1)
        rewards = torch.FloatTensor(rewards).to(device)
        dones = torch.FloatTensor(np.array(dones, dtype=np.float32)).to(device)

        # Compute Q(s, a)
        q_values, _ = self.policy_net(states)
        state_action_values = q_values.gather(1, actions).squeeze(1)

        # Compute V(s')
        with torch.no_grad():
            next_q_values, _ = self.target_net(next_states)
            next_state_values = next_q_values.max(1)[0]
            expected_state_action_values = rewards + (self.gamma * next_state_values * (1 - dones))

        # Loss and Optimize
        loss = self.criterion(state_action_values, expected_state_action_values)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        return loss.item()

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        
    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# %%
def index_to_fov_mask(center_idx, n):
    """
    Converts a predicted center tile index into a binary mask of neighbors.
    Simulates a 3x3 (or specific FOV) grid around the center.
    """
    mask = np.zeros(n*n, dtype=int)
    
    # Grid coordinates
    cy, cx = divmod(center_idx, n)
    
    # Define a simple FOV range (e.g., center + immediate neighbors)
    # Adjust range to match the desired viewport size (roughly 90 deg)
    for dy in [-1, 0, 1]:
        for dx in [-1, 0, 1]:
            ny, nx = cy + dy, cx + dx
            if 0 <= ny < n and 0 <= nx < n:
                mask[ny * n + nx] = 1
                
    return mask

# %%
if __name__ == "__main__":
    n_episodes = 2000
    n_nodes = 10
    n_users = 100
    step_size = 5.0
    arrival_rate = 15.0  # users per second
    alpha = 2.0
    n_videos = 100
    n_gops = 60
    n_layers = 2
    n = 4
    n_tiles = n * n
    max_capacity = 150e6  # 150 MB

    # Hyperparameters for RL
    epsilon_start = 1.0
    epsilon_min = 0.05
    epsilon_decay = 0.985
    gamma = 0.99
    learning_rate = 1e-3
    batch_size = 64
    capacity = 10000
    window_len = 5  # LSTM sequence length (history window)

    # CPT parameters
    theta = 0.5
    lam = 3.7183

    # du_caches = [
    #     CacheEngineEnv(
    #         n_users=n_users,
    #         n_videos=n_videos,
    #         n_layers=n_layers,
    #         n_tiles=n_tiles,
    #         n_gops=n_gops,
    #         cache_capacity=max_capacity,
    #     ) for _ in range(n_nodes)
    # ]
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=n_users,
        n_videos=n_videos,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n_gops=n_gops,
        cache_capacity=max_capacity,
    )

    # Initialize User Environment
    users_env = UserTileRequestEvents(
        n_nodes=n_nodes,
        n_users=n_users,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n=n,
        users_viewport_tiles=None,
        requested_videos=None,
        users_arrivals=None,
        arrival_rate=arrival_rate
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,   # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 40e6, dtype=float),    # 320 Mbps -> 40e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,    # 1 ms
        mec_fixed_delay=0.005,   # 5 ms
        cloud_fixed_delay=0.1   # 100 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=theta,
        lam=lam
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    agent = DQNAgent(
        n_tiles=n_tiles, 
        seq_len=window_len,
        learning_rate=learning_rate,
        gamma=gamma,
        batch_size=batch_size,
        capacity=capacity,
        epsilon_start=epsilon_start,
        epsilon_min=epsilon_min,
        epsilon_decay=epsilon_decay
    )

    results = []
    scores = []
    active_users_log = []  # Track active users per step

    for ep in range(n_episodes):

        obs, info = env.reset()

        user_histories = {
            u: deque(
                [np.zeros(n*n) for _ in range(window_len)], maxlen=window_len
            ) for u in range(n_users)
        }

        cache_hits = 0
        cache_misses = 0
        enhanced_layer_cache_hits = 0
        enhanced_layer_cache_misses = 0
        base_layer_cache_hits = 0
        base_layer_cache_misses = 0
        total_reward = 0.0
        avg_psnr = []

        for step in count():

            # --- AGENT ACTIONS ---
            reqs_state = info['users_requests']
            active_users = [
                (req['u'], req['video'], req['gop']) 
                for req in reqs_state if req['gop'] < n_gops
            ]

            actions = []
            user_action_indices = {}

            for u, video, gop in active_users:
                cur_state_seq = np.array(user_histories[u])

                # Agent chooses center tile
                center_tile_idx, q_values = agent.select_action(cur_state_seq)
                user_action_indices[u] = center_tile_idx

                if center_tile_idx == n_tiles:
                    predicted_viewport = np.ones(n*n, dtype=int)
                else:
                    # Convert center tile to mask for the Env
                    predicted_viewport = index_to_fov_mask(center_idx=center_tile_idx, n=n)

                actions.append({
                    'user': u,
                    'gop': gop,
                    'video': video,
                    'tiles': predicted_viewport
                })

            # --- STEP ENV ---
            obs, rewards, done, info = env.step(actions)

            total_reward += float(rewards)
            enhanced_layer_cache_hits += info["enh_layer_cache_hits"]
            enhanced_layer_cache_misses += info["enh_layer_cache_misses"]
            base_layer_cache_hits += info["base_layer_cache_hits"]
            base_layer_cache_misses += info["base_layer_cache_misses"]
            avg_psnr.append(info.get("average_psnr", 0.0))

            step_reward = float(rewards) / max(1, len(active_users))

            # --- TRAINING / HISTORY UPDATE ---
            reqs_next_state = info['users_requests']

            for u, video, gop in active_users:
                state_seq = np.array(user_histories[u])

                actual_viewport = np.zeros(n*n)
                target_indices = [
                    tile['tile'] 
                    for req in reqs_next_state 
                    if req['u'] == u 
                    for tile in req['tiles'] 
                    if tile['layer'] == 1
                ]
                actual_viewport[target_indices] = 1
                
                user_histories[u].append(actual_viewport)
                next_state_seq = np.array(user_histories[u])
                
                dones = (gop == n_gops)
                agent.memory.push(
                    state_seq,
                    user_action_indices[u], 
                    step_reward, 
                    next_state_seq, 
                    dones
                )
            
            agent.train_step()
            
            # print(f"Step {step}, Active Users: {len(active_users)}")
            # print(f"Request State: {reqs_state}")
            # print(f"Action: {actions}")
            # print(f"Next Request State: {reqs_next_state}")
            # print(
            #     f"Reward: {rewards}, "
            #     f"Cache Hits: {enhanced_layer_cache_hits + base_layer_cache_hits}, "
            #     f"Cache Misses: {enhanced_layer_cache_misses + base_layer_cache_misses}"
            # )
            # print("-----")
            
            if done:
                break

        # Update Target Network and Decay Epsilon
        if ep % 5 == 0:
            agent.update_target_network()

        agent.update_epsilon()

        avg_psnr = [x for x in avg_psnr if x != 0.0]

        cache_hits = enhanced_layer_cache_hits + base_layer_cache_hits
        cache_misses = enhanced_layer_cache_misses + base_layer_cache_misses

        print(
            f"Episode {ep+1}/{n_episodes}, "
            f"Total Reward: {total_reward:.4f}, "
            f"cache_hits: {cache_hits}, "
            f"cache_misses: {cache_misses}, "
            f"enh_layer_cache_hits: {enhanced_layer_cache_hits}, "
            f"enh_layer_cache_misses: {enhanced_layer_cache_misses}, "
            f"base_layer_cache_hits: {base_layer_cache_hits}, "
            f"base_layer_cache_misses: {base_layer_cache_misses}, "
            f"Average PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}, "
            f"Epsilon: {agent.epsilon:.4f}"
        )

        filename = (
            f"fov_predictor_E{n_episodes}_"
            f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
            f"cap{int(max_capacity/1e6)}MB_AR{arrival_rate}.csv"
        )

        save_training_results(
            # path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
            path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
            filename=filename,
            ep=ep,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            enhanced_layer_cache_hits=enhanced_layer_cache_hits,
            enhanced_layer_cache_misses=enhanced_layer_cache_misses,
            base_layer_cache_hits=base_layer_cache_hits,
            base_layer_cache_misses=base_layer_cache_misses,
            avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
            agent=agent
        )

        scores.append(total_reward)

        results.append({
            "episode": ep,
            "total_reward": total_reward,
            "cache_hits": cache_hits,
            "cache_misses": cache_misses,
        })
# Out:
# Experiment ===================
# Total users: 100
# Cache capacity: 500000000.0MB
# Video matrix: 100x2x16
# ==============================
#
# Episode 1/2000, Total Reward: 6650.3228, cache_hits: 108817, cache_misses: 11995, enh_layer_cache_hits: 12817, enh_layer_cache_misses: 11995, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.78, Epsilon: 0.9850
# Episode 2/2000, Total Reward: 6626.7502, cache_hits: 108864, cache_misses: 12011, enh_layer_cache_hits: 12864, enh_layer_cache_misses: 12011, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.66, Epsilon: 0.9702
# Episode 3/2000, Total Reward: 6838.4942, cache_hits: 108974, cache_misses: 11900, enh_layer_cache_hits: 12974, enh_layer_cache_misses: 11900, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.94, Epsilon: 0.9557
# Episode 4/2000, Total Reward: 6719.7488, cache_hits: 109327, cache_misses: 11580, enh_layer_cache_hits: 13327, enh_layer_cache_misses: 11580, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.95, Epsilon: 0.9413
# Episode 5/2000, Total Reward: 7224.7035, cache_hits: 109784, cache_misses: 11044, enh_layer_cache_hits: 13784, enh_layer_cache_misses: 11044, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.89, Epsilon: 0.9272
# Episode 6/2000, Total Reward: 7446.7161, cache_hits: 109721, cache_misses: 11097, enh_layer_cache_hits: 13721, enh_layer_cache_misses: 11097, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.62, Epsilon: 0.9133
# Episode 7/2000, Total Reward: 7152.8003, cache_hits: 109616, cache_misses: 11256, enh_layer_cache_hits: 13616, enh_layer_cache_misses: 11256, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.06, Epsilon: 0.8996
# Episode 8/2000, Total Reward: 6978.1211, cache_hits: 109501, cache_misses: 11401, enh_layer_cache_hits: 13501, enh_layer_cache_misses: 11401, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.89, Epsilon: 0.8861
# Episode 9/2000, Total Reward: 7156.2676, cache_hits: 109773, cache_misses: 11144, enh_layer_cache_hits: 13773, enh_layer_cache_misses: 11144, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.01, Epsilon: 0.8728
# Episode 10/2000, Total Reward: 7315.8173, cache_hits: 110385, cache_misses: 10509, enh_layer_cache_hits: 14385, enh_layer_cache_misses: 10509, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.36, Epsilon: 0.8597
# Episode 11/2000, Total Reward: 7467.2203, cache_hits: 110406, cache_misses: 10300, enh_layer_cache_hits: 14406, enh_layer_cache_misses: 10300, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.85, Epsilon: 0.8468
# Episode 12/2000, Total Reward: 8397.1098, cache_hits: 110791, cache_misses: 9829, enh_layer_cache_hits: 14791, enh_layer_cache_misses: 9829, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.36, Epsilon: 0.8341
# Episode 13/2000, Total Reward: 7383.9714, cache_hits: 110311, cache_misses: 10641, enh_layer_cache_hits: 14311, enh_layer_cache_misses: 10641, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.70, Epsilon: 0.8216
# Episode 14/2000, Total Reward: 7654.6309, cache_hits: 110644, cache_misses: 10138, enh_layer_cache_hits: 14644, enh_layer_cache_misses: 10138, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.15, Epsilon: 0.8093
# Episode 15/2000, Total Reward: 8351.5989, cache_hits: 111203, cache_misses: 9514, enh_layer_cache_hits: 15203, enh_layer_cache_misses: 9514, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.45, Epsilon: 0.7972
# Episode 16/2000, Total Reward: 7527.3007, cache_hits: 110905, cache_misses: 9960, enh_layer_cache_hits: 14905, enh_layer_cache_misses: 9960, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.91, Epsilon: 0.7852
# Episode 17/2000, Total Reward: 7441.2099, cache_hits: 110533, cache_misses: 10374, enh_layer_cache_hits: 14533, enh_layer_cache_misses: 10374, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.84, Epsilon: 0.7734
# Episode 18/2000, Total Reward: 7866.5739, cache_hits: 111184, cache_misses: 9835, enh_layer_cache_hits: 15184, enh_layer_cache_misses: 9835, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.21, Epsilon: 0.7618
# Episode 19/2000, Total Reward: 7885.5704, cache_hits: 110954, cache_misses: 9853, enh_layer_cache_hits: 14954, enh_layer_cache_misses: 9853, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.36, Epsilon: 0.7504
# Episode 20/2000, Total Reward: 7851.4089, cache_hits: 110951, cache_misses: 9905, enh_layer_cache_hits: 14951, enh_layer_cache_misses: 9905, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.22, Epsilon: 0.7391
# Episode 21/2000, Total Reward: 7838.4352, cache_hits: 111017, cache_misses: 9806, enh_layer_cache_hits: 15017, enh_layer_cache_misses: 9806, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.54, Epsilon: 0.7280
# Episode 22/2000, Total Reward: 8090.1967, cache_hits: 111407, cache_misses: 9690, enh_layer_cache_hits: 15407, enh_layer_cache_misses: 9690, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.23, Epsilon: 0.7171
# Episode 23/2000, Total Reward: 8348.4931, cache_hits: 111445, cache_misses: 9465, enh_layer_cache_hits: 15445, enh_layer_cache_misses: 9465, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.57, Epsilon: 0.7064
# Episode 24/2000, Total Reward: 7650.3583, cache_hits: 110924, cache_misses: 9956, enh_layer_cache_hits: 14924, enh_layer_cache_misses: 9956, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.36, Epsilon: 0.6958
# Episode 25/2000, Total Reward: 7747.6356, cache_hits: 111234, cache_misses: 9650, enh_layer_cache_hits: 15234, enh_layer_cache_misses: 9650, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.36, Epsilon: 0.6853
# Episode 26/2000, Total Reward: 8500.5816, cache_hits: 112049, cache_misses: 8783, enh_layer_cache_hits: 16049, enh_layer_cache_misses: 8783, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.35, Epsilon: 0.6751
# Episode 27/2000, Total Reward: 7910.9929, cache_hits: 111621, cache_misses: 9343, enh_layer_cache_hits: 15621, enh_layer_cache_misses: 9343, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.45, Epsilon: 0.6649
# Episode 28/2000, Total Reward: 7948.9607, cache_hits: 111272, cache_misses: 9440, enh_layer_cache_hits: 15272, enh_layer_cache_misses: 9440, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.01, Epsilon: 0.6550
# Episode 29/2000, Total Reward: 8238.3155, cache_hits: 111948, cache_misses: 8796, enh_layer_cache_hits: 15948, enh_layer_cache_misses: 8796, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.46, Epsilon: 0.6451
# Episode 30/2000, Total Reward: 8671.3043, cache_hits: 112160, cache_misses: 8639, enh_layer_cache_hits: 16160, enh_layer_cache_misses: 8639, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.58, Epsilon: 0.6355
# Episode 31/2000, Total Reward: 8528.0724, cache_hits: 112019, cache_misses: 8912, enh_layer_cache_hits: 16019, enh_layer_cache_misses: 8912, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.83, Epsilon: 0.6259
# Episode 32/2000, Total Reward: 7967.7187, cache_hits: 111950, cache_misses: 8953, enh_layer_cache_hits: 15950, enh_layer_cache_misses: 8953, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.54, Epsilon: 0.6165
# Episode 33/2000, Total Reward: 8475.2279, cache_hits: 112426, cache_misses: 8315, enh_layer_cache_hits: 16426, enh_layer_cache_misses: 8315, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.56, Epsilon: 0.6073
# Episode 34/2000, Total Reward: 8496.4119, cache_hits: 112331, cache_misses: 8483, enh_layer_cache_hits: 16331, enh_layer_cache_misses: 8483, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.43, Epsilon: 0.5982
# Episode 35/2000, Total Reward: 8144.8531, cache_hits: 112222, cache_misses: 8604, enh_layer_cache_hits: 16222, enh_layer_cache_misses: 8604, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.47, Epsilon: 0.5892
# Episode 36/2000, Total Reward: 8150.5423, cache_hits: 112478, cache_misses: 8490, enh_layer_cache_hits: 16478, enh_layer_cache_misses: 8490, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.16, Epsilon: 0.5804
# Episode 37/2000, Total Reward: 8506.4173, cache_hits: 112664, cache_misses: 8116, enh_layer_cache_hits: 16664, enh_layer_cache_misses: 8116, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.64, Epsilon: 0.5717
# Episode 38/2000, Total Reward: 8715.1746, cache_hits: 112625, cache_misses: 8196, enh_layer_cache_hits: 16625, enh_layer_cache_misses: 8196, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.57, Epsilon: 0.5631
# Episode 39/2000, Total Reward: 8817.6203, cache_hits: 112951, cache_misses: 7933, enh_layer_cache_hits: 16951, enh_layer_cache_misses: 7933, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.85, Epsilon: 0.5546
# Episode 40/2000, Total Reward: 8321.1709, cache_hits: 112369, cache_misses: 8517, enh_layer_cache_hits: 16369, enh_layer_cache_misses: 8517, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.36, Epsilon: 0.5463
# Episode 41/2000, Total Reward: 8924.5759, cache_hits: 112920, cache_misses: 7902, enh_layer_cache_hits: 16920, enh_layer_cache_misses: 7902, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.60, Epsilon: 0.5381
# Episode 42/2000, Total Reward: 8957.7367, cache_hits: 113343, cache_misses: 7441, enh_layer_cache_hits: 17343, enh_layer_cache_misses: 7441, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.59, Epsilon: 0.5301
# Episode 43/2000, Total Reward: 8508.5772, cache_hits: 112759, cache_misses: 7997, enh_layer_cache_hits: 16759, enh_layer_cache_misses: 7997, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.63, Epsilon: 0.5221
# Episode 44/2000, Total Reward: 9023.5590, cache_hits: 113098, cache_misses: 7766, enh_layer_cache_hits: 17098, enh_layer_cache_misses: 7766, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.74, Epsilon: 0.5143
# Episode 45/2000, Total Reward: 8123.3026, cache_hits: 112548, cache_misses: 8510, enh_layer_cache_hits: 16548, enh_layer_cache_misses: 8510, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.53, Epsilon: 0.5066
# Episode 46/2000, Total Reward: 8615.5554, cache_hits: 113193, cache_misses: 7596, enh_layer_cache_hits: 17193, enh_layer_cache_misses: 7596, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.98, Epsilon: 0.4990
# Episode 47/2000, Total Reward: 8952.5378, cache_hits: 113150, cache_misses: 7887, enh_layer_cache_hits: 17150, enh_layer_cache_misses: 7887, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.73, Epsilon: 0.4915
# Episode 48/2000, Total Reward: 8777.1130, cache_hits: 113720, cache_misses: 6920, enh_layer_cache_hits: 17720, enh_layer_cache_misses: 6920, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.83, Epsilon: 0.4841
# Episode 49/2000, Total Reward: 9190.0422, cache_hits: 113776, cache_misses: 7079, enh_layer_cache_hits: 17776, enh_layer_cache_misses: 7079, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.77, Epsilon: 0.4768
# Episode 50/2000, Total Reward: 9023.4004, cache_hits: 113290, cache_misses: 7614, enh_layer_cache_hits: 17290, enh_layer_cache_misses: 7614, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.79, Epsilon: 0.4697
# Episode 51/2000, Total Reward: 9059.0612, cache_hits: 112821, cache_misses: 7990, enh_layer_cache_hits: 16821, enh_layer_cache_misses: 7990, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.87, Epsilon: 0.4626
# Episode 52/2000, Total Reward: 9296.7909, cache_hits: 113284, cache_misses: 7720, enh_layer_cache_hits: 17284, enh_layer_cache_misses: 7720, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.75, Epsilon: 0.4557
# Episode 53/2000, Total Reward: 9233.6748, cache_hits: 113776, cache_misses: 7041, enh_layer_cache_hits: 17776, enh_layer_cache_misses: 7041, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.69, Epsilon: 0.4489
# Episode 54/2000, Total Reward: 8840.1003, cache_hits: 113385, cache_misses: 7444, enh_layer_cache_hits: 17385, enh_layer_cache_misses: 7444, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.79, Epsilon: 0.4421
# Episode 55/2000, Total Reward: 9415.1399, cache_hits: 114171, cache_misses: 6678, enh_layer_cache_hits: 18171, enh_layer_cache_misses: 6678, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.99, Epsilon: 0.4355
# Episode 56/2000, Total Reward: 9326.4661, cache_hits: 114276, cache_misses: 6544, enh_layer_cache_hits: 18276, enh_layer_cache_misses: 6544, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.79, Epsilon: 0.4290
# Episode 57/2000, Total Reward: 9536.2474, cache_hits: 113823, cache_misses: 7044, enh_layer_cache_hits: 17823, enh_layer_cache_misses: 7044, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.88, Epsilon: 0.4225
# Episode 58/2000, Total Reward: 9059.6200, cache_hits: 113419, cache_misses: 7367, enh_layer_cache_hits: 17419, enh_layer_cache_misses: 7367, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.08, Epsilon: 0.4162
# Episode 59/2000, Total Reward: 9353.0902, cache_hits: 114003, cache_misses: 6863, enh_layer_cache_hits: 18003, enh_layer_cache_misses: 6863, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.87, Epsilon: 0.4100
# Episode 60/2000, Total Reward: 9205.3043, cache_hits: 114223, cache_misses: 6540, enh_layer_cache_hits: 18223, enh_layer_cache_misses: 6540, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.77, Epsilon: 0.4038
# Episode 61/2000, Total Reward: 9241.4852, cache_hits: 113699, cache_misses: 7019, enh_layer_cache_hits: 17699, enh_layer_cache_misses: 7019, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.12, Epsilon: 0.3977
# Episode 62/2000, Total Reward: 9062.5922, cache_hits: 114255, cache_misses: 6670, enh_layer_cache_hits: 18255, enh_layer_cache_misses: 6670, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.78, Epsilon: 0.3918
# Episode 63/2000, Total Reward: 9327.0364, cache_hits: 114038, cache_misses: 6911, enh_layer_cache_hits: 18038, enh_layer_cache_misses: 6911, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.86, Epsilon: 0.3859
# Episode 64/2000, Total Reward: 9246.9363, cache_hits: 113844, cache_misses: 6895, enh_layer_cache_hits: 17844, enh_layer_cache_misses: 6895, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.82, Epsilon: 0.3801
# Episode 65/2000, Total Reward: 9038.1422, cache_hits: 114245, cache_misses: 6723, enh_layer_cache_hits: 18245, enh_layer_cache_misses: 6723, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.45, Epsilon: 0.3744
# Episode 66/2000, Total Reward: 9045.2173, cache_hits: 114031, cache_misses: 6767, enh_layer_cache_hits: 18031, enh_layer_cache_misses: 6767, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.82, Epsilon: 0.3688
# Episode 67/2000, Total Reward: 9011.7162, cache_hits: 113874, cache_misses: 6948, enh_layer_cache_hits: 17874, enh_layer_cache_misses: 6948, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.86, Epsilon: 0.3633
# Episode 68/2000, Total Reward: 8985.6199, cache_hits: 114358, cache_misses: 6511, enh_layer_cache_hits: 18358, enh_layer_cache_misses: 6511, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.72, Epsilon: 0.3578
# Episode 69/2000, Total Reward: 9056.7462, cache_hits: 114505, cache_misses: 6403, enh_layer_cache_hits: 18505, enh_layer_cache_misses: 6403, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.06, Epsilon: 0.3525
# Episode 70/2000, Total Reward: 9671.7747, cache_hits: 114604, cache_misses: 6348, enh_layer_cache_hits: 18604, enh_layer_cache_misses: 6348, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.16, Epsilon: 0.3472
# Episode 71/2000, Total Reward: 9003.9012, cache_hits: 113908, cache_misses: 6977, enh_layer_cache_hits: 17908, enh_layer_cache_misses: 6977, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.80, Epsilon: 0.3420
# Episode 72/2000, Total Reward: 9271.4298, cache_hits: 114423, cache_misses: 6352, enh_layer_cache_hits: 18423, enh_layer_cache_misses: 6352, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.78, Epsilon: 0.3368
# Episode 73/2000, Total Reward: 9261.9107, cache_hits: 114077, cache_misses: 6646, enh_layer_cache_hits: 18077, enh_layer_cache_misses: 6646, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.80, Epsilon: 0.3318
# Episode 74/2000, Total Reward: 9654.4229, cache_hits: 114884, cache_misses: 5871, enh_layer_cache_hits: 18884, enh_layer_cache_misses: 5871, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.34, Epsilon: 0.3268
# Episode 75/2000, Total Reward: 9621.8680, cache_hits: 114809, cache_misses: 6068, enh_layer_cache_hits: 18809, enh_layer_cache_misses: 6068, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.02, Epsilon: 0.3219
# Episode 76/2000, Total Reward: 9652.1766, cache_hits: 114549, cache_misses: 6259, enh_layer_cache_hits: 18549, enh_layer_cache_misses: 6259, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.90, Epsilon: 0.3171
# Episode 77/2000, Total Reward: 9278.1755, cache_hits: 114382, cache_misses: 6599, enh_layer_cache_hits: 18382, enh_layer_cache_misses: 6599, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.73, Epsilon: 0.3123
# Episode 78/2000, Total Reward: 10120.3821, cache_hits: 115136, cache_misses: 5671, enh_layer_cache_hits: 19136, enh_layer_cache_misses: 5671, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42, Epsilon: 0.3076
# Episode 79/2000, Total Reward: 9098.8758, cache_hits: 114465, cache_misses: 6558, enh_layer_cache_hits: 18465, enh_layer_cache_misses: 6558, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.88, Epsilon: 0.3030
# Episode 80/2000, Total Reward: 9406.2453, cache_hits: 114481, cache_misses: 6258, enh_layer_cache_hits: 18481, enh_layer_cache_misses: 6258, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.96, Epsilon: 0.2985
# Episode 81/2000, Total Reward: 9866.7297, cache_hits: 114931, cache_misses: 6117, enh_layer_cache_hits: 18931, enh_layer_cache_misses: 6117, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.80, Epsilon: 0.2940
# Episode 82/2000, Total Reward: 9229.6357, cache_hits: 114419, cache_misses: 6383, enh_layer_cache_hits: 18419, enh_layer_cache_misses: 6383, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.06, Epsilon: 0.2896
# Episode 83/2000, Total Reward: 10056.0722, cache_hits: 115423, cache_misses: 5321, enh_layer_cache_hits: 19423, enh_layer_cache_misses: 5321, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.17, Epsilon: 0.2852
# Episode 84/2000, Total Reward: 9803.9820, cache_hits: 115235, cache_misses: 5462, enh_layer_cache_hits: 19235, enh_layer_cache_misses: 5462, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.19, Epsilon: 0.2810
# Episode 85/2000, Total Reward: 9720.8514, cache_hits: 115462, cache_misses: 5385, enh_layer_cache_hits: 19462, enh_layer_cache_misses: 5385, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.09, Epsilon: 0.2767
# Episode 86/2000, Total Reward: 9181.5981, cache_hits: 114903, cache_misses: 6105, enh_layer_cache_hits: 18903, enh_layer_cache_misses: 6105, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.86, Epsilon: 0.2726
# Episode 87/2000, Total Reward: 9634.2400, cache_hits: 114876, cache_misses: 5908, enh_layer_cache_hits: 18876, enh_layer_cache_misses: 5908, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.00, Epsilon: 0.2685
# Episode 88/2000, Total Reward: 9794.6682, cache_hits: 115278, cache_misses: 5470, enh_layer_cache_hits: 19278, enh_layer_cache_misses: 5470, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.24, Epsilon: 0.2645
# Episode 89/2000, Total Reward: 9839.8693, cache_hits: 115036, cache_misses: 5865, enh_layer_cache_hits: 19036, enh_layer_cache_misses: 5865, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.18, Epsilon: 0.2605
# Episode 90/2000, Total Reward: 9364.8551, cache_hits: 114409, cache_misses: 6373, enh_layer_cache_hits: 18409, enh_layer_cache_misses: 6373, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.84, Epsilon: 0.2566
# Episode 91/2000, Total Reward: 9516.9113, cache_hits: 114917, cache_misses: 5860, enh_layer_cache_hits: 18917, enh_layer_cache_misses: 5860, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.13, Epsilon: 0.2528
# Episode 92/2000, Total Reward: 9680.5202, cache_hits: 115532, cache_misses: 5303, enh_layer_cache_hits: 19532, enh_layer_cache_misses: 5303, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.27, Epsilon: 0.2490
# Episode 93/2000, Total Reward: 9922.6261, cache_hits: 114995, cache_misses: 5814, enh_layer_cache_hits: 18995, enh_layer_cache_misses: 5814, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.20, Epsilon: 0.2452
# Episode 94/2000, Total Reward: 9556.9657, cache_hits: 115276, cache_misses: 5715, enh_layer_cache_hits: 19276, enh_layer_cache_misses: 5715, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.23, Epsilon: 0.2415
# Episode 95/2000, Total Reward: 10194.7640, cache_hits: 115634, cache_misses: 5324, enh_layer_cache_hits: 19634, enh_layer_cache_misses: 5324, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.11, Epsilon: 0.2379
# Episode 96/2000, Total Reward: 9610.4496, cache_hits: 115103, cache_misses: 5783, enh_layer_cache_hits: 19103, enh_layer_cache_misses: 5783, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.10, Epsilon: 0.2344
# Episode 97/2000, Total Reward: 9499.9268, cache_hits: 115201, cache_misses: 5731, enh_layer_cache_hits: 19201, enh_layer_cache_misses: 5731, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.00, Epsilon: 0.2308
# Episode 98/2000, Total Reward: 9980.9712, cache_hits: 115560, cache_misses: 5247, enh_layer_cache_hits: 19560, enh_layer_cache_misses: 5247, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.14, Epsilon: 0.2274
# Episode 99/2000, Total Reward: 9637.5632, cache_hits: 115008, cache_misses: 5811, enh_layer_cache_hits: 19008, enh_layer_cache_misses: 5811, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.05, Epsilon: 0.2240
# Episode 100/2000, Total Reward: 9696.3854, cache_hits: 115407, cache_misses: 5499, enh_layer_cache_hits: 19407, enh_layer_cache_misses: 5499, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.16, Epsilon: 0.2206
# Episode 101/2000, Total Reward: 9950.7893, cache_hits: 115639, cache_misses: 5231, enh_layer_cache_hits: 19639, enh_layer_cache_misses: 5231, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.12, Epsilon: 0.2173
# Episode 102/2000, Total Reward: 10026.2408, cache_hits: 115849, cache_misses: 4868, enh_layer_cache_hits: 19849, enh_layer_cache_misses: 4868, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.19, Epsilon: 0.2140
# Episode 103/2000, Total Reward: 9577.2811, cache_hits: 115024, cache_misses: 5708, enh_layer_cache_hits: 19024, enh_layer_cache_misses: 5708, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.74, Epsilon: 0.2108
# Episode 104/2000, Total Reward: 10517.5230, cache_hits: 116008, cache_misses: 4831, enh_layer_cache_hits: 20008, enh_layer_cache_misses: 4831, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45, Epsilon: 0.2077
# Episode 105/2000, Total Reward: 10107.5994, cache_hits: 115302, cache_misses: 5573, enh_layer_cache_hits: 19302, enh_layer_cache_misses: 5573, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.16, Epsilon: 0.2046
# Episode 106/2000, Total Reward: 9695.3732, cache_hits: 115327, cache_misses: 5594, enh_layer_cache_hits: 19327, enh_layer_cache_misses: 5594, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.79, Epsilon: 0.2015
# Episode 107/2000, Total Reward: 9447.6806, cache_hits: 115259, cache_misses: 5691, enh_layer_cache_hits: 19259, enh_layer_cache_misses: 5691, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.08, Epsilon: 0.1985
# Episode 108/2000, Total Reward: 10255.1956, cache_hits: 115736, cache_misses: 5127, enh_layer_cache_hits: 19736, enh_layer_cache_misses: 5127, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.31, Epsilon: 0.1955
# Episode 109/2000, Total Reward: 9931.7479, cache_hits: 115685, cache_misses: 5185, enh_layer_cache_hits: 19685, enh_layer_cache_misses: 5185, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.23, Epsilon: 0.1926
# Episode 110/2000, Total Reward: 10234.4870, cache_hits: 115966, cache_misses: 4746, enh_layer_cache_hits: 19966, enh_layer_cache_misses: 4746, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43, Epsilon: 0.1897
# Episode 111/2000, Total Reward: 9806.0678, cache_hits: 115916, cache_misses: 4852, enh_layer_cache_hits: 19916, enh_layer_cache_misses: 4852, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.26, Epsilon: 0.1868
# Episode 112/2000, Total Reward: 9263.8130, cache_hits: 115292, cache_misses: 5499, enh_layer_cache_hits: 19292, enh_layer_cache_misses: 5499, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.84, Epsilon: 0.1840
# Episode 113/2000, Total Reward: 9789.7595, cache_hits: 115512, cache_misses: 5293, enh_layer_cache_hits: 19512, enh_layer_cache_misses: 5293, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.01, Epsilon: 0.1813
# Episode 114/2000, Total Reward: 10309.3853, cache_hits: 115803, cache_misses: 4966, enh_layer_cache_hits: 19803, enh_layer_cache_misses: 4966, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.20, Epsilon: 0.1785
# Episode 115/2000, Total Reward: 9920.7341, cache_hits: 115343, cache_misses: 5444, enh_layer_cache_hits: 19343, enh_layer_cache_misses: 5444, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.26, Epsilon: 0.1759
# Episode 116/2000, Total Reward: 10110.4419, cache_hits: 115373, cache_misses: 5531, enh_layer_cache_hits: 19373, enh_layer_cache_misses: 5531, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.06, Epsilon: 0.1732
# Episode 117/2000, Total Reward: 9518.5325, cache_hits: 115205, cache_misses: 5747, enh_layer_cache_hits: 19205, enh_layer_cache_misses: 5747, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.06, Epsilon: 0.1706
# Episode 118/2000, Total Reward: 9649.8209, cache_hits: 115210, cache_misses: 5494, enh_layer_cache_hits: 19210, enh_layer_cache_misses: 5494, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.11, Epsilon: 0.1681
# Episode 119/2000, Total Reward: 9531.6773, cache_hits: 115422, cache_misses: 5432, enh_layer_cache_hits: 19422, enh_layer_cache_misses: 5432, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.89, Epsilon: 0.1655
# Episode 120/2000, Total Reward: 9809.1776, cache_hits: 115977, cache_misses: 5011, enh_layer_cache_hits: 19977, enh_layer_cache_misses: 5011, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35, Epsilon: 0.1631
# Episode 121/2000, Total Reward: 10477.6362, cache_hits: 115847, cache_misses: 4953, enh_layer_cache_hits: 19847, enh_layer_cache_misses: 4953, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45, Epsilon: 0.1606
# Episode 122/2000, Total Reward: 10148.7203, cache_hits: 115285, cache_misses: 5835, enh_layer_cache_hits: 19285, enh_layer_cache_misses: 5835, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.32, Epsilon: 0.1582
# Episode 123/2000, Total Reward: 10089.2297, cache_hits: 115792, cache_misses: 5003, enh_layer_cache_hits: 19792, enh_layer_cache_misses: 5003, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48, Epsilon: 0.1558
# Episode 124/2000, Total Reward: 9597.9148, cache_hits: 115416, cache_misses: 5271, enh_layer_cache_hits: 19416, enh_layer_cache_misses: 5271, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.41, Epsilon: 0.1535
# Episode 125/2000, Total Reward: 10070.1041, cache_hits: 116160, cache_misses: 4513, enh_layer_cache_hits: 20160, enh_layer_cache_misses: 4513, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.13, Epsilon: 0.1512
# Episode 126/2000, Total Reward: 10289.1956, cache_hits: 115793, cache_misses: 5025, enh_layer_cache_hits: 19793, enh_layer_cache_misses: 5025, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39, Epsilon: 0.1489
# Episode 127/2000, Total Reward: 10298.6392, cache_hits: 116119, cache_misses: 4736, enh_layer_cache_hits: 20119, enh_layer_cache_misses: 4736, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.18, Epsilon: 0.1467
# Episode 128/2000, Total Reward: 9938.5351, cache_hits: 115930, cache_misses: 4934, enh_layer_cache_hits: 19930, enh_layer_cache_misses: 4934, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.28, Epsilon: 0.1445
# Episode 129/2000, Total Reward: 10548.1984, cache_hits: 116273, cache_misses: 4677, enh_layer_cache_hits: 20273, enh_layer_cache_misses: 4677, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39, Epsilon: 0.1423
# Episode 130/2000, Total Reward: 9786.7048, cache_hits: 115759, cache_misses: 5082, enh_layer_cache_hits: 19759, enh_layer_cache_misses: 5082, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35, Epsilon: 0.1402
# Episode 131/2000, Total Reward: 9768.3950, cache_hits: 115856, cache_misses: 4790, enh_layer_cache_hits: 19856, enh_layer_cache_misses: 4790, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.14, Epsilon: 0.1381
# Episode 132/2000, Total Reward: 9562.2133, cache_hits: 115274, cache_misses: 5594, enh_layer_cache_hits: 19274, enh_layer_cache_misses: 5594, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.97, Epsilon: 0.1360
# Episode 133/2000, Total Reward: 10390.1261, cache_hits: 116154, cache_misses: 4799, enh_layer_cache_hits: 20154, enh_layer_cache_misses: 4799, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35, Epsilon: 0.1340
# Episode 134/2000, Total Reward: 9912.6977, cache_hits: 116316, cache_misses: 4495, enh_layer_cache_hits: 20316, enh_layer_cache_misses: 4495, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.24, Epsilon: 0.1320
# Episode 135/2000, Total Reward: 10152.7887, cache_hits: 116514, cache_misses: 4357, enh_layer_cache_hits: 20514, enh_layer_cache_misses: 4357, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44, Epsilon: 0.1300
# Episode 136/2000, Total Reward: 10146.2913, cache_hits: 116063, cache_misses: 5039, enh_layer_cache_hits: 20063, enh_layer_cache_misses: 5039, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.24, Epsilon: 0.1280
# Episode 137/2000, Total Reward: 10702.6954, cache_hits: 116546, cache_misses: 4425, enh_layer_cache_hits: 20546, enh_layer_cache_misses: 4425, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.18, Epsilon: 0.1261
# Episode 138/2000, Total Reward: 10120.2221, cache_hits: 116096, cache_misses: 4851, enh_layer_cache_hits: 20096, enh_layer_cache_misses: 4851, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.33, Epsilon: 0.1242
# Episode 139/2000, Total Reward: 9787.4749, cache_hits: 116027, cache_misses: 4867, enh_layer_cache_hits: 20027, enh_layer_cache_misses: 4867, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.17, Epsilon: 0.1224
# Episode 140/2000, Total Reward: 10130.2734, cache_hits: 116144, cache_misses: 4871, enh_layer_cache_hits: 20144, enh_layer_cache_misses: 4871, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.24, Epsilon: 0.1205
# Episode 141/2000, Total Reward: 10436.0636, cache_hits: 115947, cache_misses: 4849, enh_layer_cache_hits: 19947, enh_layer_cache_misses: 4849, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.25, Epsilon: 0.1187
# Episode 142/2000, Total Reward: 10198.6787, cache_hits: 116791, cache_misses: 4090, enh_layer_cache_hits: 20791, enh_layer_cache_misses: 4090, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.23, Epsilon: 0.1169
# Episode 143/2000, Total Reward: 10421.7684, cache_hits: 116374, cache_misses: 4532, enh_layer_cache_hits: 20374, enh_layer_cache_misses: 4532, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.14, Epsilon: 0.1152
# Episode 144/2000, Total Reward: 10182.2062, cache_hits: 116067, cache_misses: 4685, enh_layer_cache_hits: 20067, enh_layer_cache_misses: 4685, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.29, Epsilon: 0.1135
# Episode 145/2000, Total Reward: 10271.8556, cache_hits: 116072, cache_misses: 4878, enh_layer_cache_hits: 20072, enh_layer_cache_misses: 4878, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54, Epsilon: 0.1118
# Episode 146/2000, Total Reward: 10356.9928, cache_hits: 116913, cache_misses: 4005, enh_layer_cache_hits: 20913, enh_layer_cache_misses: 4005, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54, Epsilon: 0.1101
# Episode 147/2000, Total Reward: 10058.8578, cache_hits: 116477, cache_misses: 4548, enh_layer_cache_hits: 20477, enh_layer_cache_misses: 4548, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.13, Epsilon: 0.1084
# Episode 148/2000, Total Reward: 9995.5839, cache_hits: 116063, cache_misses: 4838, enh_layer_cache_hits: 20063, enh_layer_cache_misses: 4838, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.22, Epsilon: 0.1068
# Episode 149/2000, Total Reward: 10661.2682, cache_hits: 116372, cache_misses: 4362, enh_layer_cache_hits: 20372, enh_layer_cache_misses: 4362, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39, Epsilon: 0.1052
# Episode 150/2000, Total Reward: 10614.2795, cache_hits: 116615, cache_misses: 4212, enh_layer_cache_hits: 20615, enh_layer_cache_misses: 4212, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43, Epsilon: 0.1036
# Episode 151/2000, Total Reward: 10241.9306, cache_hits: 116169, cache_misses: 4672, enh_layer_cache_hits: 20169, enh_layer_cache_misses: 4672, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44, Epsilon: 0.1021
# Episode 152/2000, Total Reward: 10553.1845, cache_hits: 116146, cache_misses: 4662, enh_layer_cache_hits: 20146, enh_layer_cache_misses: 4662, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.13, Epsilon: 0.1005
# Episode 153/2000, Total Reward: 9781.8483, cache_hits: 116185, cache_misses: 4607, enh_layer_cache_hits: 20185, enh_layer_cache_misses: 4607, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.03, Epsilon: 0.0990
# Episode 154/2000, Total Reward: 10285.6508, cache_hits: 116760, cache_misses: 4167, enh_layer_cache_hits: 20760, enh_layer_cache_misses: 4167, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39, Epsilon: 0.0975
# Episode 155/2000, Total Reward: 10160.6899, cache_hits: 116296, cache_misses: 4534, enh_layer_cache_hits: 20296, enh_layer_cache_misses: 4534, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47, Epsilon: 0.0961
# Episode 156/2000, Total Reward: 10167.3244, cache_hits: 116644, cache_misses: 4248, enh_layer_cache_hits: 20644, enh_layer_cache_misses: 4248, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53, Epsilon: 0.0946
# Episode 157/2000, Total Reward: 10311.2651, cache_hits: 116621, cache_misses: 4264, enh_layer_cache_hits: 20621, enh_layer_cache_misses: 4264, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54, Epsilon: 0.0932
# Episode 158/2000, Total Reward: 10288.4357, cache_hits: 116813, cache_misses: 3903, enh_layer_cache_hits: 20813, enh_layer_cache_misses: 3903, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40, Epsilon: 0.0918
# Episode 159/2000, Total Reward: 11016.0491, cache_hits: 117224, cache_misses: 3483, enh_layer_cache_hits: 21224, enh_layer_cache_misses: 3483, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.0904
# Episode 160/2000, Total Reward: 10545.9071, cache_hits: 116600, cache_misses: 4075, enh_layer_cache_hits: 20600, enh_layer_cache_misses: 4075, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.31, Epsilon: 0.0891
# Episode 161/2000, Total Reward: 10953.3327, cache_hits: 116353, cache_misses: 4678, enh_layer_cache_hits: 20353, enh_layer_cache_misses: 4678, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38, Epsilon: 0.0877
# Episode 162/2000, Total Reward: 9961.5151, cache_hits: 115295, cache_misses: 5542, enh_layer_cache_hits: 19295, enh_layer_cache_misses: 5542, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.93, Epsilon: 0.0864
# Episode 163/2000, Total Reward: 10329.8377, cache_hits: 116545, cache_misses: 4326, enh_layer_cache_hits: 20545, enh_layer_cache_misses: 4326, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.32, Epsilon: 0.0851
# Episode 164/2000, Total Reward: 9981.4287, cache_hits: 116267, cache_misses: 4562, enh_layer_cache_hits: 20267, enh_layer_cache_misses: 4562, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.36, Epsilon: 0.0839
# Episode 165/2000, Total Reward: 10333.2886, cache_hits: 117061, cache_misses: 3821, enh_layer_cache_hits: 21061, enh_layer_cache_misses: 3821, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58, Epsilon: 0.0826
# Episode 166/2000, Total Reward: 9943.4113, cache_hits: 116779, cache_misses: 4128, enh_layer_cache_hits: 20779, enh_layer_cache_misses: 4128, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.36, Epsilon: 0.0814
# Episode 167/2000, Total Reward: 10425.8132, cache_hits: 116802, cache_misses: 4060, enh_layer_cache_hits: 20802, enh_layer_cache_misses: 4060, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40, Epsilon: 0.0801
# Episode 168/2000, Total Reward: 10580.3535, cache_hits: 116561, cache_misses: 4257, enh_layer_cache_hits: 20561, enh_layer_cache_misses: 4257, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45, Epsilon: 0.0789
# Episode 169/2000, Total Reward: 11153.4655, cache_hits: 116695, cache_misses: 4067, enh_layer_cache_hits: 20695, enh_layer_cache_misses: 4067, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52, Epsilon: 0.0778
# Episode 170/2000, Total Reward: 10185.9521, cache_hits: 116363, cache_misses: 4519, enh_layer_cache_hits: 20363, enh_layer_cache_misses: 4519, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.10, Epsilon: 0.0766
# Episode 171/2000, Total Reward: 9790.8390, cache_hits: 116156, cache_misses: 4744, enh_layer_cache_hits: 20156, enh_layer_cache_misses: 4744, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 37.90, Epsilon: 0.0754
# Episode 172/2000, Total Reward: 10621.4985, cache_hits: 116819, cache_misses: 4075, enh_layer_cache_hits: 20819, enh_layer_cache_misses: 4075, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54, Epsilon: 0.0743
# Episode 173/2000, Total Reward: 10164.4706, cache_hits: 115909, cache_misses: 4849, enh_layer_cache_hits: 19909, enh_layer_cache_misses: 4849, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.12, Epsilon: 0.0732
# Episode 174/2000, Total Reward: 10368.7409, cache_hits: 116568, cache_misses: 4251, enh_layer_cache_hits: 20568, enh_layer_cache_misses: 4251, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.23, Epsilon: 0.0721
# Episode 175/2000, Total Reward: 9967.6094, cache_hits: 117036, cache_misses: 3704, enh_layer_cache_hits: 21036, enh_layer_cache_misses: 3704, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.28, Epsilon: 0.0710
# Episode 176/2000, Total Reward: 10144.9566, cache_hits: 115954, cache_misses: 5028, enh_layer_cache_hits: 19954, enh_layer_cache_misses: 5028, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.28, Epsilon: 0.0699
# Episode 177/2000, Total Reward: 10150.8984, cache_hits: 116831, cache_misses: 4048, enh_layer_cache_hits: 20831, enh_layer_cache_misses: 4048, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.31, Epsilon: 0.0689
# Episode 178/2000, Total Reward: 10447.9547, cache_hits: 116922, cache_misses: 3804, enh_layer_cache_hits: 20922, enh_layer_cache_misses: 3804, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.33, Epsilon: 0.0679
# Episode 179/2000, Total Reward: 10172.9734, cache_hits: 116204, cache_misses: 4573, enh_layer_cache_hits: 20204, enh_layer_cache_misses: 4573, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.06, Epsilon: 0.0668
# Episode 180/2000, Total Reward: 10223.1594, cache_hits: 116778, cache_misses: 3910, enh_layer_cache_hits: 20778, enh_layer_cache_misses: 3910, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.04, Epsilon: 0.0658
# Episode 181/2000, Total Reward: 10126.7962, cache_hits: 116655, cache_misses: 4146, enh_layer_cache_hits: 20655, enh_layer_cache_misses: 4146, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.31, Epsilon: 0.0649
# Episode 182/2000, Total Reward: 10347.2991, cache_hits: 116358, cache_misses: 4417, enh_layer_cache_hits: 20358, enh_layer_cache_misses: 4417, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.32, Epsilon: 0.0639
# Episode 183/2000, Total Reward: 10003.7047, cache_hits: 116398, cache_misses: 4587, enh_layer_cache_hits: 20398, enh_layer_cache_misses: 4587, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40, Epsilon: 0.0629
# Episode 184/2000, Total Reward: 10092.9484, cache_hits: 116656, cache_misses: 4192, enh_layer_cache_hits: 20656, enh_layer_cache_misses: 4192, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39, Epsilon: 0.0620
# Episode 185/2000, Total Reward: 10628.6901, cache_hits: 116937, cache_misses: 3969, enh_layer_cache_hits: 20937, enh_layer_cache_misses: 3969, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56, Epsilon: 0.0611
# Episode 186/2000, Total Reward: 9947.5078, cache_hits: 116511, cache_misses: 4493, enh_layer_cache_hits: 20511, enh_layer_cache_misses: 4493, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.23, Epsilon: 0.0601
# Episode 187/2000, Total Reward: 10014.7738, cache_hits: 116424, cache_misses: 4421, enh_layer_cache_hits: 20424, enh_layer_cache_misses: 4421, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.18, Epsilon: 0.0592
# Episode 188/2000, Total Reward: 10248.8930, cache_hits: 116622, cache_misses: 4318, enh_layer_cache_hits: 20622, enh_layer_cache_misses: 4318, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.24, Epsilon: 0.0583
# Episode 189/2000, Total Reward: 10290.6593, cache_hits: 116712, cache_misses: 4117, enh_layer_cache_hits: 20712, enh_layer_cache_misses: 4117, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.36, Epsilon: 0.0575
# Episode 190/2000, Total Reward: 10753.2053, cache_hits: 116522, cache_misses: 4276, enh_layer_cache_hits: 20522, enh_layer_cache_misses: 4276, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.36, Epsilon: 0.0566
# Episode 191/2000, Total Reward: 10520.4978, cache_hits: 116673, cache_misses: 4293, enh_layer_cache_hits: 20673, enh_layer_cache_misses: 4293, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.25, Epsilon: 0.0558
# Episode 192/2000, Total Reward: 10494.6273, cache_hits: 117083, cache_misses: 3627, enh_layer_cache_hits: 21083, enh_layer_cache_misses: 3627, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49, Epsilon: 0.0549
# Episode 193/2000, Total Reward: 10390.9295, cache_hits: 116552, cache_misses: 4354, enh_layer_cache_hits: 20552, enh_layer_cache_misses: 4354, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46, Epsilon: 0.0541
# Episode 194/2000, Total Reward: 10148.6902, cache_hits: 116684, cache_misses: 4136, enh_layer_cache_hits: 20684, enh_layer_cache_misses: 4136, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.22, Epsilon: 0.0533
# Episode 195/2000, Total Reward: 10403.3481, cache_hits: 116379, cache_misses: 4297, enh_layer_cache_hits: 20379, enh_layer_cache_misses: 4297, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.18, Epsilon: 0.0525
# Episode 196/2000, Total Reward: 10323.7424, cache_hits: 116410, cache_misses: 4541, enh_layer_cache_hits: 20410, enh_layer_cache_misses: 4541, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.25, Epsilon: 0.0517
# Episode 197/2000, Total Reward: 10488.5714, cache_hits: 116098, cache_misses: 4826, enh_layer_cache_hits: 20098, enh_layer_cache_misses: 4826, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57, Epsilon: 0.0509
# Episode 198/2000, Total Reward: 9785.6538, cache_hits: 116246, cache_misses: 4491, enh_layer_cache_hits: 20246, enh_layer_cache_misses: 4491, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.19, Epsilon: 0.0502
# Episode 199/2000, Total Reward: 10842.5926, cache_hits: 116962, cache_misses: 3815, enh_layer_cache_hits: 20962, enh_layer_cache_misses: 3815, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.30, Epsilon: 0.0500
# Episode 200/2000, Total Reward: 10102.0260, cache_hits: 116375, cache_misses: 4549, enh_layer_cache_hits: 20375, enh_layer_cache_misses: 4549, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35, Epsilon: 0.0500
# Episode 201/2000, Total Reward: 11102.8260, cache_hits: 117234, cache_misses: 3654, enh_layer_cache_hits: 21234, enh_layer_cache_misses: 3654, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0500
# ...
# Episode 581/2000, Total Reward: 10431.0082, cache_hits: 117029, cache_misses: 3806, enh_layer_cache_hits: 21029, enh_layer_cache_misses: 3806, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.22, Epsilon: 0.0500
# Episode 582/2000, Total Reward: 10495.5537, cache_hits: 116696, cache_misses: 4126, enh_layer_cache_hits: 20696, enh_layer_cache_misses: 4126, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51, Epsilon: 0.0500
# Episode 583/2000, Total Reward: 10627.4692, cache_hits: 117177, cache_misses: 3642, enh_layer_cache_hits: 21177, enh_layer_cache_misses: 3642, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52, Epsilon: 0.0500
# Episode 584/2000, Total Reward: 10475.6532, cache_hits: 116335, cache_misses: 4542, enh_layer_cache_hits: 20335, enh_layer_cache_misses: 4542, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.30, Epsilon: 0.0500
# Episode 585/2000, Total Reward: 10736.5072, cache_hits: 116771, cache_misses: 4086, enh_layer_cache_hits: 20771, enh_layer_cache_misses: 4086, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38, Epsilon: 0.0500
# Episode 586/2000, Total Reward: 10410.5984, cache_hits: 116849, cache_misses: 3913, enh_layer_cache_hits: 20849, enh_layer_cache_misses: 3913, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43, Epsilon: 0.0500
# Episode 587/2000, Total Reward: 10209.4290, cache_hits: 116407, cache_misses: 4429, enh_layer_cache_hits: 20407, enh_layer_cache_misses: 4429, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.13, Epsilon: 0.0500
# Episode 588/2000, Total Reward: 10523.2852, cache_hits: 117047, cache_misses: 3556, enh_layer_cache_hits: 21047, enh_layer_cache_misses: 3556, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58, Epsilon: 0.0500
# Episode 589/2000, Total Reward: 10442.0436, cache_hits: 116378, cache_misses: 4442, enh_layer_cache_hits: 20378, enh_layer_cache_misses: 4442, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50, Epsilon: 0.0500
# Episode 590/2000, Total Reward: 10943.7599, cache_hits: 116812, cache_misses: 4180, enh_layer_cache_hits: 20812, enh_layer_cache_misses: 4180, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67, Epsilon: 0.0500
# Episode 591/2000, Total Reward: 9717.7139, cache_hits: 116068, cache_misses: 4690, enh_layer_cache_hits: 20068, enh_layer_cache_misses: 4690, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.06, Epsilon: 0.0500
# Episode 592/2000, Total Reward: 10623.8027, cache_hits: 116338, cache_misses: 4558, enh_layer_cache_hits: 20338, enh_layer_cache_misses: 4558, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47, Epsilon: 0.0500
# Episode 593/2000, Total Reward: 10242.5271, cache_hits: 117069, cache_misses: 3621, enh_layer_cache_hits: 21069, enh_layer_cache_misses: 3621, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38, Epsilon: 0.0500
# Episode 594/2000, Total Reward: 11132.8116, cache_hits: 117256, cache_misses: 3461, enh_layer_cache_hits: 21256, enh_layer_cache_misses: 3461, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59, Epsilon: 0.0500
# Episode 595/2000, Total Reward: 10164.0647, cache_hits: 116926, cache_misses: 3889, enh_layer_cache_hits: 20926, enh_layer_cache_misses: 3889, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.33, Epsilon: 0.0500
# Episode 596/2000, Total Reward: 10592.5469, cache_hits: 116895, cache_misses: 3951, enh_layer_cache_hits: 20895, enh_layer_cache_misses: 3951, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.28, Epsilon: 0.0500
# Episode 597/2000, Total Reward: 10802.2043, cache_hits: 116892, cache_misses: 4061, enh_layer_cache_hits: 20892, enh_layer_cache_misses: 4061, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63, Epsilon: 0.0500
# Episode 598/2000, Total Reward: 10352.9413, cache_hits: 116607, cache_misses: 4486, enh_layer_cache_hits: 20607, enh_layer_cache_misses: 4486, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.14, Epsilon: 0.0500
# Episode 599/2000, Total Reward: 10203.8010, cache_hits: 116750, cache_misses: 4163, enh_layer_cache_hits: 20750, enh_layer_cache_misses: 4163, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.15, Epsilon: 0.0500
# Episode 600/2000, Total Reward: 10657.2254, cache_hits: 116491, cache_misses: 4313, enh_layer_cache_hits: 20491, enh_layer_cache_misses: 4313, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64, Epsilon: 0.0500
# Episode 601/2000, Total Reward: 10484.1362, cache_hits: 116985, cache_misses: 3773, enh_layer_cache_hits: 20985, enh_layer_cache_misses: 3773, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56, Epsilon: 0.0500
# Episode 602/2000, Total Reward: 10553.9821, cache_hits: 116724, cache_misses: 4118, enh_layer_cache_hits: 20724, enh_layer_cache_misses: 4118, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.32, Epsilon: 0.0500
# Episode 603/2000, Total Reward: 10832.0745, cache_hits: 116091, cache_misses: 4706, enh_layer_cache_hits: 20091, enh_layer_cache_misses: 4706, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47, Epsilon: 0.0500
# Episode 604/2000, Total Reward: 10202.0422, cache_hits: 116081, cache_misses: 4682, enh_layer_cache_hits: 20081, enh_layer_cache_misses: 4682, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.28, Epsilon: 0.0500
# Episode 605/2000, Total Reward: 10545.5499, cache_hits: 117357, cache_misses: 3584, enh_layer_cache_hits: 21357, enh_layer_cache_misses: 3584, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.55, Epsilon: 0.0500
# Episode 606/2000, Total Reward: 10841.0972, cache_hits: 116941, cache_misses: 3836, enh_layer_cache_hits: 20941, enh_layer_cache_misses: 3836, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62, Epsilon: 0.0500
# Episode 607/2000, Total Reward: 9845.5431, cache_hits: 116778, cache_misses: 4080, enh_layer_cache_hits: 20778, enh_layer_cache_misses: 4080, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.33, Epsilon: 0.0500
# Episode 608/2000, Total Reward: 10210.7594, cache_hits: 116550, cache_misses: 4165, enh_layer_cache_hits: 20550, enh_layer_cache_misses: 4165, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.29, Epsilon: 0.0500
# Episode 609/2000, Total Reward: 10520.7976, cache_hits: 116937, cache_misses: 3888, enh_layer_cache_hits: 20937, enh_layer_cache_misses: 3888, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43, Epsilon: 0.0500
# Episode 610/2000, Total Reward: 10414.1706, cache_hits: 116481, cache_misses: 4295, enh_layer_cache_hits: 20481, enh_layer_cache_misses: 4295, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47, Epsilon: 0.0500
# Episode 611/2000, Total Reward: 10728.2873, cache_hits: 116784, cache_misses: 3988, enh_layer_cache_hits: 20784, enh_layer_cache_misses: 3988, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42, Epsilon: 0.0500
# Episode 612/2000, Total Reward: 10808.4461, cache_hits: 116779, cache_misses: 4168, enh_layer_cache_hits: 20779, enh_layer_cache_misses: 4168, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.29, Epsilon: 0.0500
# Episode 613/2000, Total Reward: 9956.2396, cache_hits: 116287, cache_misses: 4681, enh_layer_cache_hits: 20287, enh_layer_cache_misses: 4681, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.17, Epsilon: 0.0500
# Episode 614/2000, Total Reward: 10112.6939, cache_hits: 116349, cache_misses: 4685, enh_layer_cache_hits: 20349, enh_layer_cache_misses: 4685, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.30, Epsilon: 0.0500
# Episode 615/2000, Total Reward: 10588.2738, cache_hits: 117116, cache_misses: 3731, enh_layer_cache_hits: 21116, enh_layer_cache_misses: 3731, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40, Epsilon: 0.0500
# Episode 616/2000, Total Reward: 9758.1938, cache_hits: 116458, cache_misses: 4274, enh_layer_cache_hits: 20458, enh_layer_cache_misses: 4274, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.25, Epsilon: 0.0500
# Episode 617/2000, Total Reward: 10799.4732, cache_hits: 116397, cache_misses: 4365, enh_layer_cache_hits: 20397, enh_layer_cache_misses: 4365, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39, Epsilon: 0.0500
# Episode 618/2000, Total Reward: 10362.6354, cache_hits: 116511, cache_misses: 4351, enh_layer_cache_hits: 20511, enh_layer_cache_misses: 4351, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62, Epsilon: 0.0500
# Episode 619/2000, Total Reward: 10845.1748, cache_hits: 117075, cache_misses: 3846, enh_layer_cache_hits: 21075, enh_layer_cache_misses: 3846, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62, Epsilon: 0.0500
# Episode 620/2000, Total Reward: 10457.9580, cache_hits: 116882, cache_misses: 3994, enh_layer_cache_hits: 20882, enh_layer_cache_misses: 3994, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40, Epsilon: 0.0500
# Episode 621/2000, Total Reward: 10644.7935, cache_hits: 117028, cache_misses: 3887, enh_layer_cache_hits: 21028, enh_layer_cache_misses: 3887, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35, Epsilon: 0.0500
# Episode 622/2000, Total Reward: 10888.9788, cache_hits: 116950, cache_misses: 3874, enh_layer_cache_hits: 20950, enh_layer_cache_misses: 3874, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46, Epsilon: 0.0500
# Episode 623/2000, Total Reward: 10220.0045, cache_hits: 116672, cache_misses: 4251, enh_layer_cache_hits: 20672, enh_layer_cache_misses: 4251, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.41, Epsilon: 0.0500
# Episode 624/2000, Total Reward: 10573.3200, cache_hits: 116545, cache_misses: 4367, enh_layer_cache_hits: 20545, enh_layer_cache_misses: 4367, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.15, Epsilon: 0.0500
# Episode 625/2000, Total Reward: 11027.9842, cache_hits: 117047, cache_misses: 3653, enh_layer_cache_hits: 21047, enh_layer_cache_misses: 3653, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0500
# Episode 626/2000, Total Reward: 10828.3107, cache_hits: 117054, cache_misses: 3621, enh_layer_cache_hits: 21054, enh_layer_cache_misses: 3621, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0500
# Episode 627/2000, Total Reward: 10024.7442, cache_hits: 117063, cache_misses: 3837, enh_layer_cache_hits: 21063, enh_layer_cache_misses: 3837, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.32, Epsilon: 0.0500
# Episode 628/2000, Total Reward: 10065.9823, cache_hits: 116691, cache_misses: 4183, enh_layer_cache_hits: 20691, enh_layer_cache_misses: 4183, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38, Epsilon: 0.0500
# Episode 629/2000, Total Reward: 10556.6129, cache_hits: 116280, cache_misses: 4629, enh_layer_cache_hits: 20280, enh_layer_cache_misses: 4629, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.55, Epsilon: 0.0500
# Episode 630/2000, Total Reward: 10695.2604, cache_hits: 116673, cache_misses: 4134, enh_layer_cache_hits: 20673, enh_layer_cache_misses: 4134, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40, Epsilon: 0.0500
# Episode 631/2000, Total Reward: 10474.1244, cache_hits: 116412, cache_misses: 4372, enh_layer_cache_hits: 20412, enh_layer_cache_misses: 4372, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51, Epsilon: 0.0500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 153
#     150 cur_state_seq = np.array(user_histories[u])
#     152 # Agent chooses center tile
# --> 153 center_tile_idx, q_values = agent.select_action(cur_state_seq)
#     154 user_action_indices[u] = center_tile_idx
#     156 if center_tile_idx == n_tiles:
#
# Cell In[4], line 87, in DQNAgent.select_action(self, state_seq)
#      85 with torch.no_grad():
#      86     state_tensor = torch.FloatTensor(state_seq).unsqueeze(0).to(device)
# ---> 87     q_values, _ = self.policy_net(state_tensor)
#      88     return q_values.argmax().item(), q_values.cpu().numpy()
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# Cell In[4], line 34, in LSTM_DQN.forward(self, x, hidden)
#      30 def forward(self, x, hidden=None):
#      31     # x shape: (batch, seq_len, input_size)
#      32
#      33     # LSTM output shape: (batch, seq_len, hidden_size)
# ---> 34     lstm_out, hidden = self.lstm(x, hidden)
#      36     # We only care about the output of the last time step for prediction
#      37     last_time_step = lstm_out[:, -1, :]
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\torch\nn\modules\rnn.py:1089, in LSTM.forward(self, input, hx)
#    1087 unsorted_indices = None
#    1088 if hx is None:
# -> 1089     h_zeros = torch.zeros(
#    1090         self.num_layers * num_directions,
#    1091         max_batch_size,
#    1092         real_hidden_size,
#    1093         dtype=input.dtype,
#    1094         device=input.device,
#    1095     )
#    1096     c_zeros = torch.zeros(
#    1097         self.num_layers * num_directions,
#    1098         max_batch_size,
#    (...)   1101         device=input.device,
#    1102     )
#    1103     hx = (h_zeros, c_zeros)
#
# KeyboardInterrupt:

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# 1. Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_yscale('log') 
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# 2. Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_yscale('log') 
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# 3. Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_yscale('log')
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_296811/3657158268.py:17: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_296811/3657158268.py:27: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_296811/3657158268.py:37: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[2].set_ylim(bottom=0)

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]
    base_totals = [h + m for h, m in zip(base_hits, base_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]
    base_hit_rate = [safe_pct(h, t) for h, t in zip(base_hits, base_totals)]
    base_miss_rate = [safe_pct(m, t) for m, t in zip(base_misses, base_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)
    base_ylim = (0, 100)

    fig, axes = plt.subplots(3, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Base Layer: Hit rate
    axes[1, 0].plot(episodes, base_hit_rate, label="Base hit rate (%)", color="green", alpha=0.9)
    axes[1, 0].set_title("Base Layer Hit Rate")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Rate (%)")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Base Layer: Miss rate
    axes[1, 1].plot(episodes, base_miss_rate, label="Base miss rate (%)", color="orange", alpha=0.9)
    axes[1, 1].set_title("Base Layer Miss Rate")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Rate (%)")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    # Reward title
    axes[2, 0].plot(episodes, rewards, label="Episode reward", color="purple", alpha=0.9)
    axes[2, 0].set_title("Episode Rewards")
    axes[2, 0].set_xlabel("Episode")
    axes[2, 0].set_ylabel("Reward")
    axes[2, 0].grid(True, alpha=0.3)
    axes[2, 0].legend()

    # Average PSNR
    axes[2, 1].plot(episodes, psnr, label="Average PSNR", color="brown", alpha=0.9)
    axes[2, 1].set_title("Average PSNR per Episode")
    axes[2, 1].set_xlabel("Episode")
    axes[2, 1].set_ylabel("PSNR (dB)")
    axes[2, 1].grid(True, alpha=0.3)
    axes[2, 1].legend()


    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.0.csv'
    
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Reward title
    axes[1, 0].plot(episodes, rewards, label="Episode reward", color="purple", alpha=0.9)
    axes[1, 0].set_title("Episode Rewards")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Reward")
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Average PSNR
    axes[1, 1].plot(episodes, psnr, label="Average PSNR", color="brown", alpha=0.9)
    axes[1, 1].set_title("Average PSNR per Episode")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("PSNR (dB)")
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.0.csv'
    
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    csv_path_lsr = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_path_lsr += r'\fov_lsr_U100_V100_G60_L2_N4_cap500MB_AR15.csv'

    episodes_lsr, enhanced_hits_lsr, enhanced_misses_lsr, base_hits_lsr, base_misses_lsr, rewards_lsr, psnr_lsr = read_results(csv_path_lsr)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="DRL-LRU", color="blue", alpha=0.9)
    axes[0, 0].plot(episodes_lsr, [safe_pct(h, h + m) for h, m in zip(enhanced_hits_lsr, enhanced_misses_lsr)], label="LSR-LRU", color="red")
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="DRL-LRU", color="blue", alpha=0.9)
    axes[0, 1].plot(episodes_lsr, [safe_pct(m, h + m) for h, m in zip(enhanced_hits_lsr, enhanced_misses_lsr)], label="LSR-LRU", color="red")
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Reward title
    axes[1, 0].plot(episodes, rewards, label="DRL-LRU", color="blue", alpha=0.9)
    axes[1, 0].set_title("Rewards")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Reward")
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Average PSNR
    axes[1, 1].plot(episodes, psnr, label="DRL-LRU", color="blue", alpha=0.9)
    axes[1, 1].plot(episodes_lsr, psnr_lsr, label="LSR-LRU", color="red")
    axes[1, 1].set_title("Average PSNR")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("PSNR (dB)")
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.csv'
    
    out_path = None

    title = "FOV Predictor Double DQN Agent Cache Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
