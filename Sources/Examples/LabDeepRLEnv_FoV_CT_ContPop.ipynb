# %%
import os
import csv
import sys
import math
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd


from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import List

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv, LruPolicy, SvcLruPolicy
    from LabUserTileRequest import UserTileRequestEvents
    from LabEnvWrapper import EnvWrapper

# sys.path.append(r'c:\Users\es25591\Workspace\CacheVideoPredict360\Sources')
sys.path.append('/home/eduardo/Workspace/CacheVideoPredict360/Sources')
from Common.Utils import save_training_results

# %%
class PopularityAware(nn.Module):
    def __init__(self, n_tiles, hidden_size, output_size, num_layers=1):
        super().__init__()
        
        self.lstm = nn.LSTM(n_tiles, hidden_size, num_layers, batch_first=True)
        
        self.fc = nn.Linear(1, 8)
    
        self.fc_combined = nn.Linear(hidden_size + 8, 64)
        self.fc_out = nn.Linear(64, output_size)
    
    def forward(self, x_trajectory, x_popularity):
        # 1. Process trajectory with LSTM
        lstm_out, _ = self.lstm(x_trajectory)
        lstm_out = lstm_out[:, -1, :]  # Take the last output of the LSTM

        # 2. Process popularity with a fully connected layer
        pop_out = F.relu(self.fc(x_popularity))
        
        # 3. Combine both outputs
        combined = torch.cat((lstm_out, pop_out), dim=1)
        
        x = F.relu(self.fc_combined(combined))
        q_values = self.fc_out(x)
        
        return q_values, None

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        # state shape: (seq_len, input_size)
        self.memory.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

class DQNAgent:
    def __init__(
        self, 
        n_tiles, 
        seq_len, 
        learning_rate=1e-3, 
        gamma=0.99,
        batch_size=64,
        capacity=10000,
        epsilon_start=1.0,
        epsilon_min=0.05,
        epsilon_decay=0.995
    ):
        self.n_tiles = n_tiles
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        
        # Initialize standard LSTM_DQN with the new input dimension
        self.policy_net = PopularityAware(n_tiles, 128, n_tiles + 1).to(device)
        self.target_net = PopularityAware(n_tiles, 128, n_tiles + 1).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        
        self.optimizer = optim.Adam(
            self.policy_net.parameters(), 
            lr=learning_rate
        )

        self.criterion = nn.MSELoss()
        self.memory = ReplayMemory(capacity=capacity)
        self.batch_size = batch_size

    def select_action(self, state):
        trajectory, popularity = state
        
        if random.random() < self.epsilon:
            return random.randrange(self.n_tiles + 1), None
        else:
            with torch.no_grad():
                state_trajectory_t = torch.FloatTensor(trajectory).unsqueeze(0).to(device)
                state_popularity_t = torch.FloatTensor([popularity]).unsqueeze(0).to(device)
                
                q_values, _ = self.policy_net(state_trajectory_t, state_popularity_t)
                
                return q_values.argmax().item(), q_values.cpu().numpy()

    def select_optimal_action(self, state):        
        trajectory, popularity = state

        with torch.no_grad():
            state_trajectory_t = torch.FloatTensor(trajectory).unsqueeze(0).to(device)
            state_popularity_t = torch.FloatTensor([popularity]).unsqueeze(0).to(device)
            
            q_values, _ = self.policy_net(state_trajectory_t, state_popularity_t)
            
            return q_values.argmax().item(), q_values.cpu().numpy()

    def train_step(self):
        if len(self.memory) < self.batch_size:
            return 0.0
        
        batch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        # 1. Prepare Current States
        state_seqs = torch.FloatTensor(np.array([s[0] for s in states])).to(device)
        state_pops = torch.FloatTensor(np.array([s[1] for s in states])).unsqueeze(1).to(device)
        
        next_seqs = torch.FloatTensor(np.array([s[0] for s in next_states])).to(device)
        next_pops = torch.FloatTensor(np.array([s[1] for s in next_states])).unsqueeze(1).to(device)

        actions = torch.LongTensor(actions).unsqueeze(1).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        dones = torch.FloatTensor(np.array(dones, dtype=np.float32)).to(device)
        
        # --- Q-VALUE CALCULATION ---
        q_values, _ = self.policy_net(state_seqs, state_pops)
        state_action_values = q_values.gather(1, actions).squeeze(1)

        with torch.no_grad():
            next_q_values, _ = self.target_net(next_seqs, next_pops)
            next_state_values = next_q_values.max(1)[0]
            expected_state_action_values = rewards + (self.gamma * next_state_values * (1 - dones))

        loss = self.criterion(state_action_values, expected_state_action_values)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        return loss.item()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

# %%
def index_to_fov_mask(center_idx, n):
    mask = np.zeros(n*n, dtype=int)    
    cy, cx = divmod(center_idx, n)
    
    for dy in [-1, 0, 1]:
        for dx in [-1, 0, 1]:
            ny, nx = cy + dy, cx + dx
            if 0 <= ny < n and 0 <= nx < n:
                mask[ny * n + nx] = 1
                
    return mask

# %%
if __name__ == "__main__":
    n_episodes = 200
    n_nodes = 3
    n_users = 200
    step_size = 10.0
    arrival_rate = 10.0  # users per second
    alpha = 2.0
    n_videos = 500
    n_gops = 60
    n_layers = 2
    n = 4
    n_tiles = n * n
    max_capacity = 500e6  # 500 MB

    # Hyperparameters for RL
    epsilon_start = 1.0
    epsilon_min = 0.005
    epsilon_decay = 0.985
    gamma = 0.99
    learning_rate = 1e-3
    batch_size = 32
    capacity = 10000
    window_len = 5  # LSTM sequence length (history window)

    # CPT parameters
    theta = 0.5
    lam = 3.7183

    # du_caches = [
    #     CacheEngineEnv(
    #         n_users=n_users,
    #         n_videos=n_videos,
    #         n_layers=n_layers,
    #         n_tiles=n_tiles,
    #         n_gops=n_gops,
    #         cache_capacity=max_capacity,
    #     ) for _ in range(n_nodes)
    # ]
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=n_users,
        n_videos=n_videos,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n_gops=n_gops,
        cache_capacity=max_capacity,
        # policy=SvcLruPolicy(max_size=max_capacity)
    )

    # Initialize User Environment
    users_env = UserTileRequestEvents(
        n_nodes=n_nodes,
        n_users=n_users,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n=n,
        users_viewport_tiles=None,
        requested_videos=None,
        users_arrivals=None,
        arrival_rate=arrival_rate,
        alpha=alpha
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,  # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 40e6, dtype=float),    # 320 Mbps -> 40e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,  # 1 ms
        mec_fixed_delay=0.005, # 5 ms
        cloud_fixed_delay=0.1  # 100 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=theta,
        lam=lam
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    agent = DQNAgent(
        n_tiles=n_tiles, 
        seq_len=window_len,
        learning_rate=learning_rate,
        gamma=gamma,
        batch_size=batch_size,
        capacity=capacity,
        epsilon_start=epsilon_start,
        epsilon_min=epsilon_min,
        epsilon_decay=epsilon_decay
    )

    results = []
    scores = []
    cache_log = [] # Track active users per step

    for ep in range(n_episodes):

        obs, info = env.reset()

        user_histories = {
            u: deque(maxlen=window_len) for u in range(n_users)
        }
        for u in range(n_users):
            for _ in range(window_len):
                # Fill with zeros: [0, 0, ..., 0] of size n*n
                user_histories[u].append(np.zeros(n*n, dtype=int))

        cache_hits = 0
        cache_misses = 0
        enhanced_layer_cache_hits = 0
        enhanced_layer_cache_misses = 0
        base_layer_cache_hits = 0
        base_layer_cache_misses = 0
        total_reward = 0.0
        avg_psnr = []

        for step in count():

            # --- AGENT ACTIONS ---
            reqs_state = info['users_requests']
            active_users = [
                (
                    req['u'], 
                    req['video'], 
                    req['gop'],
                    info['content_popularity'][0][req['video']] / sum(info['content_popularity'][0])
                ) for req in reqs_state if req['gop'] < n_gops
            ]

            actions = []
            user_action_indices = {}

            for u, video, gop, vid_pop in active_users:
                state = np.array(user_histories[u])
                state = (state, vid_pop)

                # Agent chooses center tile
                center_tile_idx, q_values = agent.select_action(state)
                user_action_indices[u] = center_tile_idx

                if center_tile_idx == n_tiles:
                    predicted_viewport = np.zeros(n*n, dtype=int)
                else:
                    predicted_viewport = index_to_fov_mask(center_idx=center_tile_idx, n=n)

                actions.append({
                    'user': u,
                    'gop': gop,
                    'video': video,
                    'tiles': predicted_viewport
                })

            # --- STEP ENV ---
            obs, rewards, done, info = env.step(actions)

            total_reward += float(rewards)
            enhanced_layer_cache_hits += info["enh_layer_cache_hits"]
            enhanced_layer_cache_misses += info["enh_layer_cache_misses"]
            base_layer_cache_hits += info["base_layer_cache_hits"]
            base_layer_cache_misses += info["base_layer_cache_misses"]
            avg_psnr.append(info.get("average_psnr", 0.0))

            step_reward = float(rewards) / max(1, len(active_users))

            # --- TRAINING / HISTORY UPDATE ---
            reqs_next_state = info['users_requests']

            for u, video, gop, pop_val in active_users:
                state = (np.array(user_histories[u]), pop_val)

                next_pop_val = info['content_popularity'][0][video]
                next_pop_val = next_pop_val / sum(info['content_popularity'][0])
 
                target_indices = [
                    tile['tile'] 
                    for req in reqs_next_state 
                    if req['u'] == u 
                    for tile in req['tiles'] 
                    if tile['layer'] == 1
                ]
                actual_viewport = np.array([
                    1 if i in target_indices else 0 for i in range(n*n)
                ])
                user_histories[u].append(actual_viewport)
                
                dones = (gop == n_gops)
                
                next_state = np.array(user_histories[u])
                next_state = (next_state, next_pop_val)

                agent.memory.push(
                    state,  # Pushing the tuple (Seq, Pop)
                    user_action_indices[u],
                    step_reward,
                    next_state,
                    dones
                )

            agent.train_step()
            
            if done:
                break

        # Update Target Network and Decay Epsilon
        if ep % 5 == 0:
            agent.update_target_network()

        agent.update_epsilon()

        avg_psnr = [x for x in avg_psnr if x != 0.0]

        cache_hits = enhanced_layer_cache_hits + base_layer_cache_hits
        cache_misses = enhanced_layer_cache_misses + base_layer_cache_misses

        print(
            f"Episode {ep+1}/{n_episodes}, "
            f"Total Reward: {total_reward:.2f}, "
            f"cache_hits: {cache_hits}, "
            f"cache_misses: {cache_misses}, "
            f"enh_layer_cache_hits: {enhanced_layer_cache_hits}, "
            f"enh_layer_cache_misses: {enhanced_layer_cache_misses}, "
            f"base_layer_cache_hits: {base_layer_cache_hits}, "
            f"base_layer_cache_misses: {base_layer_cache_misses}, "
            f"Average PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}, "
            f"Epsilon: {agent.epsilon:.4f}"
        )
        
        filename = (
            f"fov_predictor_ct_cp_E{n_episodes}_"
            f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
            f"cap{int(max_capacity/1e6)}MB_AR{arrival_rate}_Z{alpha*10}.csv"
        )

        save_training_results(
            path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
            # path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
            filename=filename,
            ep=ep,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            enhanced_layer_cache_hits=enhanced_layer_cache_hits,
            enhanced_layer_cache_misses=enhanced_layer_cache_misses,
            base_layer_cache_hits=base_layer_cache_hits,
            base_layer_cache_misses=base_layer_cache_misses,
            avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
            agent=agent
        )

        scores.append(total_reward)

        results.append({
            "episode": ep,
            "total_reward": total_reward,
            "cache_hits": cache_hits,
            "cache_misses": cache_misses,
        })
# Out:
# Experiment ===================
# Total users: 200
# Cache capacity: 500000000.0MB
# Video matrix: 500x2x16
# ==============================
#
# Episode 1/200, Total Reward: 21362.63, cache_hits: 220853, cache_misses: 20707, enh_layer_cache_hits: 28853, enh_layer_cache_misses: 20707, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.05, Epsilon: 0.9850
# Episode 2/200, Total Reward: 20206.92, cache_hits: 220546, cache_misses: 21106, enh_layer_cache_hits: 28546, enh_layer_cache_misses: 21106, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.17, Epsilon: 0.9702
# Episode 3/200, Total Reward: 21394.71, cache_hits: 221256, cache_misses: 20595, enh_layer_cache_hits: 29256, enh_layer_cache_misses: 20595, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.9557
# Episode 4/200, Total Reward: 21312.06, cache_hits: 221209, cache_misses: 20521, enh_layer_cache_hits: 29209, enh_layer_cache_misses: 20521, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.9413
# Episode 5/200, Total Reward: 20491.00, cache_hits: 220808, cache_misses: 20842, enh_layer_cache_hits: 28808, enh_layer_cache_misses: 20842, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.9272
# Episode 6/200, Total Reward: 21259.43, cache_hits: 221297, cache_misses: 20405, enh_layer_cache_hits: 29297, enh_layer_cache_misses: 20405, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.11, Epsilon: 0.9133
# Episode 7/200, Total Reward: 19976.10, cache_hits: 220269, cache_misses: 21511, enh_layer_cache_hits: 28269, enh_layer_cache_misses: 21511, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.15, Epsilon: 0.8996
# Episode 8/200, Total Reward: 20898.61, cache_hits: 221382, cache_misses: 20314, enh_layer_cache_hits: 29382, enh_layer_cache_misses: 20314, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.15, Epsilon: 0.8861
# Episode 9/200, Total Reward: 20838.52, cache_hits: 221163, cache_misses: 20423, enh_layer_cache_hits: 29163, enh_layer_cache_misses: 20423, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.15, Epsilon: 0.8728
# Episode 10/200, Total Reward: 20296.83, cache_hits: 221065, cache_misses: 20690, enh_layer_cache_hits: 29065, enh_layer_cache_misses: 20690, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.18, Epsilon: 0.8597
# Episode 11/200, Total Reward: 21514.98, cache_hits: 221970, cache_misses: 19826, enh_layer_cache_hits: 29970, enh_layer_cache_misses: 19826, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.8468
# Episode 12/200, Total Reward: 23190.46, cache_hits: 223274, cache_misses: 18568, enh_layer_cache_hits: 31274, enh_layer_cache_misses: 18568, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.18, Epsilon: 0.8341
# Episode 13/200, Total Reward: 20199.05, cache_hits: 220921, cache_misses: 20887, enh_layer_cache_hits: 28921, enh_layer_cache_misses: 20887, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.12, Epsilon: 0.8216
# Episode 14/200, Total Reward: 21827.91, cache_hits: 222781, cache_misses: 18867, enh_layer_cache_hits: 30781, enh_layer_cache_misses: 18867, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.8093
# Episode 15/200, Total Reward: 22860.92, cache_hits: 223422, cache_misses: 18203, enh_layer_cache_hits: 31422, enh_layer_cache_misses: 18203, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.7972
# Episode 16/200, Total Reward: 20958.25, cache_hits: 222018, cache_misses: 19678, enh_layer_cache_hits: 30018, enh_layer_cache_misses: 19678, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.7852
# Episode 17/200, Total Reward: 20784.50, cache_hits: 222093, cache_misses: 19588, enh_layer_cache_hits: 30093, enh_layer_cache_misses: 19588, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.16, Epsilon: 0.7734
# Episode 18/200, Total Reward: 22684.33, cache_hits: 223127, cache_misses: 18489, enh_layer_cache_hits: 31127, enh_layer_cache_misses: 18489, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.7618
# Episode 19/200, Total Reward: 23166.30, cache_hits: 224252, cache_misses: 17430, enh_layer_cache_hits: 32252, enh_layer_cache_misses: 17430, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.7504
# Episode 20/200, Total Reward: 22934.98, cache_hits: 223115, cache_misses: 18433, enh_layer_cache_hits: 31115, enh_layer_cache_misses: 18433, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.10, Epsilon: 0.7391
# Episode 21/200, Total Reward: 22310.40, cache_hits: 223871, cache_misses: 17782, enh_layer_cache_hits: 31871, enh_layer_cache_misses: 17782, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.17, Epsilon: 0.7280
# Episode 22/200, Total Reward: 22078.40, cache_hits: 223285, cache_misses: 18523, enh_layer_cache_hits: 31285, enh_layer_cache_misses: 18523, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.11, Epsilon: 0.7171
# Episode 23/200, Total Reward: 22489.12, cache_hits: 223212, cache_misses: 18585, enh_layer_cache_hits: 31212, enh_layer_cache_misses: 18585, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.7064
# Episode 24/200, Total Reward: 23155.71, cache_hits: 224622, cache_misses: 17137, enh_layer_cache_hits: 32622, enh_layer_cache_misses: 17137, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.6958
# Episode 25/200, Total Reward: 23753.81, cache_hits: 224561, cache_misses: 17258, enh_layer_cache_hits: 32561, enh_layer_cache_misses: 17258, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.6853
# Episode 26/200, Total Reward: 22851.37, cache_hits: 223860, cache_misses: 17773, enh_layer_cache_hits: 31860, enh_layer_cache_misses: 17773, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.6751
# Episode 27/200, Total Reward: 23557.40, cache_hits: 224579, cache_misses: 17186, enh_layer_cache_hits: 32579, enh_layer_cache_misses: 17186, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.6649
# Episode 28/200, Total Reward: 22090.65, cache_hits: 224160, cache_misses: 17610, enh_layer_cache_hits: 32160, enh_layer_cache_misses: 17610, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.15, Epsilon: 0.6550
# Episode 29/200, Total Reward: 22306.99, cache_hits: 224536, cache_misses: 17151, enh_layer_cache_hits: 32536, enh_layer_cache_misses: 17151, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.6451
# Episode 30/200, Total Reward: 24096.96, cache_hits: 225363, cache_misses: 16289, enh_layer_cache_hits: 33363, enh_layer_cache_misses: 16289, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.6355
# Episode 31/200, Total Reward: 22457.58, cache_hits: 224187, cache_misses: 17503, enh_layer_cache_hits: 32187, enh_layer_cache_misses: 17503, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.11, Epsilon: 0.6259
# Episode 32/200, Total Reward: 22908.07, cache_hits: 224965, cache_misses: 16658, enh_layer_cache_hits: 32965, enh_layer_cache_misses: 16658, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.18, Epsilon: 0.6165
# Episode 33/200, Total Reward: 22966.34, cache_hits: 224591, cache_misses: 16903, enh_layer_cache_hits: 32591, enh_layer_cache_misses: 16903, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.18, Epsilon: 0.6073
# Episode 34/200, Total Reward: 24933.07, cache_hits: 225775, cache_misses: 16180, enh_layer_cache_hits: 33775, enh_layer_cache_misses: 16180, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.5982
# Episode 35/200, Total Reward: 24185.28, cache_hits: 225758, cache_misses: 15934, enh_layer_cache_hits: 33758, enh_layer_cache_misses: 15934, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.14, Epsilon: 0.5892
# Episode 36/200, Total Reward: 23770.48, cache_hits: 225507, cache_misses: 16294, enh_layer_cache_hits: 33507, enh_layer_cache_misses: 16294, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.5804
# Episode 37/200, Total Reward: 22770.15, cache_hits: 224748, cache_misses: 16876, enh_layer_cache_hits: 32748, enh_layer_cache_misses: 16876, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.5717
# Episode 38/200, Total Reward: 25305.85, cache_hits: 226161, cache_misses: 15445, enh_layer_cache_hits: 34161, enh_layer_cache_misses: 15445, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.5631
# Episode 39/200, Total Reward: 22964.28, cache_hits: 225608, cache_misses: 16001, enh_layer_cache_hits: 33608, enh_layer_cache_misses: 16001, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.5546
# Episode 40/200, Total Reward: 24753.69, cache_hits: 226324, cache_misses: 15288, enh_layer_cache_hits: 34324, enh_layer_cache_misses: 15288, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.5463
# Episode 41/200, Total Reward: 22399.04, cache_hits: 225348, cache_misses: 16295, enh_layer_cache_hits: 33348, enh_layer_cache_misses: 16295, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.5381
# Episode 42/200, Total Reward: 23778.85, cache_hits: 225888, cache_misses: 15956, enh_layer_cache_hits: 33888, enh_layer_cache_misses: 15956, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.15, Epsilon: 0.5301
# Episode 43/200, Total Reward: 24355.12, cache_hits: 225662, cache_misses: 16085, enh_layer_cache_hits: 33662, enh_layer_cache_misses: 16085, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.5221
# Episode 44/200, Total Reward: 24564.29, cache_hits: 226353, cache_misses: 15435, enh_layer_cache_hits: 34353, enh_layer_cache_misses: 15435, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.5143
# Episode 45/200, Total Reward: 22201.98, cache_hits: 225319, cache_misses: 16282, enh_layer_cache_hits: 33319, enh_layer_cache_misses: 16282, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.15, Epsilon: 0.5066
# Episode 46/200, Total Reward: 24864.42, cache_hits: 226459, cache_misses: 15067, enh_layer_cache_hits: 34459, enh_layer_cache_misses: 15067, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.18, Epsilon: 0.4990
# Episode 47/200, Total Reward: 24897.81, cache_hits: 226181, cache_misses: 15569, enh_layer_cache_hits: 34181, enh_layer_cache_misses: 15569, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.4915
# Episode 48/200, Total Reward: 24036.38, cache_hits: 226389, cache_misses: 15316, enh_layer_cache_hits: 34389, enh_layer_cache_misses: 15316, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.4841
# Episode 49/200, Total Reward: 25758.33, cache_hits: 227438, cache_misses: 14052, enh_layer_cache_hits: 35438, enh_layer_cache_misses: 14052, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.4768
# Episode 50/200, Total Reward: 25224.62, cache_hits: 226616, cache_misses: 15053, enh_layer_cache_hits: 34616, enh_layer_cache_misses: 15053, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.4697
# Episode 51/200, Total Reward: 26154.88, cache_hits: 228375, cache_misses: 13392, enh_layer_cache_hits: 36375, enh_layer_cache_misses: 13392, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.4626
# Episode 52/200, Total Reward: 24096.66, cache_hits: 226465, cache_misses: 15289, enh_layer_cache_hits: 34465, enh_layer_cache_misses: 15289, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.4557
# Episode 53/200, Total Reward: 25178.36, cache_hits: 227461, cache_misses: 14240, enh_layer_cache_hits: 35461, enh_layer_cache_misses: 14240, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.4489
# Episode 54/200, Total Reward: 25388.87, cache_hits: 227703, cache_misses: 14047, enh_layer_cache_hits: 35703, enh_layer_cache_misses: 14047, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.14, Epsilon: 0.4421
# Episode 55/200, Total Reward: 24407.25, cache_hits: 227190, cache_misses: 14529, enh_layer_cache_hits: 35190, enh_layer_cache_misses: 14529, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.4355
# Episode 56/200, Total Reward: 25162.75, cache_hits: 227398, cache_misses: 14274, enh_layer_cache_hits: 35398, enh_layer_cache_misses: 14274, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.4290
# Episode 57/200, Total Reward: 25100.43, cache_hits: 228109, cache_misses: 13433, enh_layer_cache_hits: 36109, enh_layer_cache_misses: 13433, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.4225
# Episode 58/200, Total Reward: 25215.04, cache_hits: 227490, cache_misses: 14160, enh_layer_cache_hits: 35490, enh_layer_cache_misses: 14160, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.11, Epsilon: 0.4162
# Episode 59/200, Total Reward: 24181.58, cache_hits: 227033, cache_misses: 14693, enh_layer_cache_hits: 35033, enh_layer_cache_misses: 14693, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.17, Epsilon: 0.4100
# Episode 60/200, Total Reward: 24797.23, cache_hits: 228136, cache_misses: 13537, enh_layer_cache_hits: 36136, enh_layer_cache_misses: 13537, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.4038
# Episode 61/200, Total Reward: 24978.62, cache_hits: 227913, cache_misses: 13785, enh_layer_cache_hits: 35913, enh_layer_cache_misses: 13785, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.3977
# Episode 62/200, Total Reward: 24863.56, cache_hits: 227615, cache_misses: 14119, enh_layer_cache_hits: 35615, enh_layer_cache_misses: 14119, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.3918
# Episode 63/200, Total Reward: 24808.41, cache_hits: 227389, cache_misses: 14265, enh_layer_cache_hits: 35389, enh_layer_cache_misses: 14265, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.17, Epsilon: 0.3859
# Episode 64/200, Total Reward: 24194.05, cache_hits: 227469, cache_misses: 14105, enh_layer_cache_hits: 35469, enh_layer_cache_misses: 14105, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.3801
# Episode 65/200, Total Reward: 24487.98, cache_hits: 228396, cache_misses: 13115, enh_layer_cache_hits: 36396, enh_layer_cache_misses: 13115, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.3744
# Episode 66/200, Total Reward: 25607.27, cache_hits: 228065, cache_misses: 13544, enh_layer_cache_hits: 36065, enh_layer_cache_misses: 13544, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.3688
# Episode 67/200, Total Reward: 26112.28, cache_hits: 228713, cache_misses: 13180, enh_layer_cache_hits: 36713, enh_layer_cache_misses: 13180, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.3633
# Episode 68/200, Total Reward: 25502.04, cache_hits: 228604, cache_misses: 12938, enh_layer_cache_hits: 36604, enh_layer_cache_misses: 12938, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.3578
# Episode 69/200, Total Reward: 25364.14, cache_hits: 227840, cache_misses: 13842, enh_layer_cache_hits: 35840, enh_layer_cache_misses: 13842, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.3525
# Episode 70/200, Total Reward: 24802.00, cache_hits: 228200, cache_misses: 13596, enh_layer_cache_hits: 36200, enh_layer_cache_misses: 13596, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.3472
# Episode 71/200, Total Reward: 25500.63, cache_hits: 228705, cache_misses: 12838, enh_layer_cache_hits: 36705, enh_layer_cache_misses: 12838, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.3420
# Episode 72/200, Total Reward: 25124.27, cache_hits: 228168, cache_misses: 13442, enh_layer_cache_hits: 36168, enh_layer_cache_misses: 13442, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.3368
# Episode 73/200, Total Reward: 24975.83, cache_hits: 228950, cache_misses: 12679, enh_layer_cache_hits: 36950, enh_layer_cache_misses: 12679, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.15, Epsilon: 0.3318
# Episode 74/200, Total Reward: 25870.41, cache_hits: 228846, cache_misses: 12938, enh_layer_cache_hits: 36846, enh_layer_cache_misses: 12938, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.3268
# Episode 75/200, Total Reward: 26176.58, cache_hits: 229374, cache_misses: 12144, enh_layer_cache_hits: 37374, enh_layer_cache_misses: 12144, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.3219
# Episode 76/200, Total Reward: 25918.76, cache_hits: 229363, cache_misses: 12043, enh_layer_cache_hits: 37363, enh_layer_cache_misses: 12043, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.3171
# Episode 77/200, Total Reward: 25993.97, cache_hits: 228712, cache_misses: 12884, enh_layer_cache_hits: 36712, enh_layer_cache_misses: 12884, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.3123
# Episode 78/200, Total Reward: 25177.12, cache_hits: 228614, cache_misses: 12962, enh_layer_cache_hits: 36614, enh_layer_cache_misses: 12962, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.04, Epsilon: 0.3076
# Episode 79/200, Total Reward: 25873.36, cache_hits: 228734, cache_misses: 13011, enh_layer_cache_hits: 36734, enh_layer_cache_misses: 13011, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.3030
# Episode 80/200, Total Reward: 25407.75, cache_hits: 228605, cache_misses: 12968, enh_layer_cache_hits: 36605, enh_layer_cache_misses: 12968, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.2985
# Episode 81/200, Total Reward: 26084.63, cache_hits: 229167, cache_misses: 12518, enh_layer_cache_hits: 37167, enh_layer_cache_misses: 12518, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.2940
# Episode 82/200, Total Reward: 26271.09, cache_hits: 229363, cache_misses: 12475, enh_layer_cache_hits: 37363, enh_layer_cache_misses: 12475, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.2896
# Episode 83/200, Total Reward: 25792.44, cache_hits: 229363, cache_misses: 12437, enh_layer_cache_hits: 37363, enh_layer_cache_misses: 12437, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.2852
# Episode 84/200, Total Reward: 26326.31, cache_hits: 230031, cache_misses: 11626, enh_layer_cache_hits: 38031, enh_layer_cache_misses: 11626, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.2810
# Episode 85/200, Total Reward: 26031.34, cache_hits: 229924, cache_misses: 11929, enh_layer_cache_hits: 37924, enh_layer_cache_misses: 11929, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.2767
# Episode 86/200, Total Reward: 25758.01, cache_hits: 229435, cache_misses: 12398, enh_layer_cache_hits: 37435, enh_layer_cache_misses: 12398, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.2726
# Episode 87/200, Total Reward: 24129.79, cache_hits: 229086, cache_misses: 12464, enh_layer_cache_hits: 37086, enh_layer_cache_misses: 12464, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.18, Epsilon: 0.2685
# Episode 88/200, Total Reward: 25559.62, cache_hits: 229076, cache_misses: 12722, enh_layer_cache_hits: 37076, enh_layer_cache_misses: 12722, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.2645
# Episode 89/200, Total Reward: 26178.89, cache_hits: 230102, cache_misses: 11629, enh_layer_cache_hits: 38102, enh_layer_cache_misses: 11629, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.2605
# Episode 90/200, Total Reward: 25650.11, cache_hits: 229866, cache_misses: 11906, enh_layer_cache_hits: 37866, enh_layer_cache_misses: 11906, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.2566
# Episode 91/200, Total Reward: 26688.13, cache_hits: 229998, cache_misses: 11715, enh_layer_cache_hits: 37998, enh_layer_cache_misses: 11715, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.2528
# Episode 92/200, Total Reward: 26387.21, cache_hits: 229193, cache_misses: 12567, enh_layer_cache_hits: 37193, enh_layer_cache_misses: 12567, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.2490
# Episode 93/200, Total Reward: 26304.80, cache_hits: 230344, cache_misses: 11415, enh_layer_cache_hits: 38344, enh_layer_cache_misses: 11415, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.17, Epsilon: 0.2452
# Episode 94/200, Total Reward: 25848.44, cache_hits: 229168, cache_misses: 12555, enh_layer_cache_hits: 37168, enh_layer_cache_misses: 12555, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.16, Epsilon: 0.2415
# Episode 95/200, Total Reward: 26275.35, cache_hits: 229410, cache_misses: 12357, enh_layer_cache_hits: 37410, enh_layer_cache_misses: 12357, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.11, Epsilon: 0.2379
# Episode 96/200, Total Reward: 25729.38, cache_hits: 230935, cache_misses: 10817, enh_layer_cache_hits: 38935, enh_layer_cache_misses: 10817, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.2344
# Episode 97/200, Total Reward: 26572.77, cache_hits: 229369, cache_misses: 12515, enh_layer_cache_hits: 37369, enh_layer_cache_misses: 12515, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.2308
# Episode 98/200, Total Reward: 26399.89, cache_hits: 230244, cache_misses: 11339, enh_layer_cache_hits: 38244, enh_layer_cache_misses: 11339, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.2274
# Episode 99/200, Total Reward: 26395.53, cache_hits: 229873, cache_misses: 11834, enh_layer_cache_hits: 37873, enh_layer_cache_misses: 11834, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.2240
# Episode 100/200, Total Reward: 26478.95, cache_hits: 230388, cache_misses: 11384, enh_layer_cache_hits: 38388, enh_layer_cache_misses: 11384, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.2206
# Episode 101/200, Total Reward: 27364.72, cache_hits: 230721, cache_misses: 11075, enh_layer_cache_hits: 38721, enh_layer_cache_misses: 11075, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.2173
# Episode 102/200, Total Reward: 25726.14, cache_hits: 230904, cache_misses: 10767, enh_layer_cache_hits: 38904, enh_layer_cache_misses: 10767, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.2140
# Episode 103/200, Total Reward: 25391.67, cache_hits: 229642, cache_misses: 11888, enh_layer_cache_hits: 37642, enh_layer_cache_misses: 11888, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.16, Epsilon: 0.2108
# Episode 104/200, Total Reward: 26350.11, cache_hits: 230536, cache_misses: 11179, enh_layer_cache_hits: 38536, enh_layer_cache_misses: 11179, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.20, Epsilon: 0.2077
# Episode 105/200, Total Reward: 26471.36, cache_hits: 231068, cache_misses: 10581, enh_layer_cache_hits: 39068, enh_layer_cache_misses: 10581, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.2046
# Episode 106/200, Total Reward: 26873.05, cache_hits: 231054, cache_misses: 10639, enh_layer_cache_hits: 39054, enh_layer_cache_misses: 10639, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.2015
# Episode 107/200, Total Reward: 26987.10, cache_hits: 229603, cache_misses: 11971, enh_layer_cache_hits: 37603, enh_layer_cache_misses: 11971, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.1985
# Episode 108/200, Total Reward: 26381.04, cache_hits: 230613, cache_misses: 11127, enh_layer_cache_hits: 38613, enh_layer_cache_misses: 11127, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.1955
# Episode 109/200, Total Reward: 27044.22, cache_hits: 231087, cache_misses: 10784, enh_layer_cache_hits: 39087, enh_layer_cache_misses: 10784, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.1926
# Episode 110/200, Total Reward: 25728.82, cache_hits: 230733, cache_misses: 10958, enh_layer_cache_hits: 38733, enh_layer_cache_misses: 10958, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.1897
# Episode 111/200, Total Reward: 27268.14, cache_hits: 231128, cache_misses: 10641, enh_layer_cache_hits: 39128, enh_layer_cache_misses: 10641, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.1868
# Episode 112/200, Total Reward: 26695.27, cache_hits: 231067, cache_misses: 10614, enh_layer_cache_hits: 39067, enh_layer_cache_misses: 10614, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.1840
# Episode 113/200, Total Reward: 26913.48, cache_hits: 230690, cache_misses: 11123, enh_layer_cache_hits: 38690, enh_layer_cache_misses: 11123, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.1813
# Episode 114/200, Total Reward: 27369.78, cache_hits: 231568, cache_misses: 10310, enh_layer_cache_hits: 39568, enh_layer_cache_misses: 10310, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.1785
# Episode 115/200, Total Reward: 25924.03, cache_hits: 230898, cache_misses: 10906, enh_layer_cache_hits: 38898, enh_layer_cache_misses: 10906, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.1759
# Episode 116/200, Total Reward: 25501.55, cache_hits: 230157, cache_misses: 11354, enh_layer_cache_hits: 38157, enh_layer_cache_misses: 11354, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.1732
# Episode 117/200, Total Reward: 27013.80, cache_hits: 230529, cache_misses: 11069, enh_layer_cache_hits: 38529, enh_layer_cache_misses: 11069, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.1706
# Episode 118/200, Total Reward: 27720.98, cache_hits: 231947, cache_misses: 9653, enh_layer_cache_hits: 39947, enh_layer_cache_misses: 9653, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.1681
# Episode 119/200, Total Reward: 27744.12, cache_hits: 231595, cache_misses: 10145, enh_layer_cache_hits: 39595, enh_layer_cache_misses: 10145, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.1655
# Episode 120/200, Total Reward: 27570.96, cache_hits: 231325, cache_misses: 10284, enh_layer_cache_hits: 39325, enh_layer_cache_misses: 10284, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.1631
# Episode 121/200, Total Reward: 27112.86, cache_hits: 231124, cache_misses: 10624, enh_layer_cache_hits: 39124, enh_layer_cache_misses: 10624, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.1606
# Episode 122/200, Total Reward: 27152.58, cache_hits: 231026, cache_misses: 10713, enh_layer_cache_hits: 39026, enh_layer_cache_misses: 10713, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.1582
# Episode 123/200, Total Reward: 26228.24, cache_hits: 230801, cache_misses: 10922, enh_layer_cache_hits: 38801, enh_layer_cache_misses: 10922, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.1558
# Episode 124/200, Total Reward: 27698.55, cache_hits: 232283, cache_misses: 9297, enh_layer_cache_hits: 40283, enh_layer_cache_misses: 9297, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.1535
# Episode 125/200, Total Reward: 27766.64, cache_hits: 231808, cache_misses: 9961, enh_layer_cache_hits: 39808, enh_layer_cache_misses: 9961, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.1512
# Episode 126/200, Total Reward: 27226.56, cache_hits: 231355, cache_misses: 10278, enh_layer_cache_hits: 39355, enh_layer_cache_misses: 10278, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.1489
# Episode 127/200, Total Reward: 25705.48, cache_hits: 231219, cache_misses: 10519, enh_layer_cache_hits: 39219, enh_layer_cache_misses: 10519, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.1467
# Episode 128/200, Total Reward: 27437.38, cache_hits: 230850, cache_misses: 10677, enh_layer_cache_hits: 38850, enh_layer_cache_misses: 10677, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.1445
# Episode 129/200, Total Reward: 26716.88, cache_hits: 231024, cache_misses: 10513, enh_layer_cache_hits: 39024, enh_layer_cache_misses: 10513, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.1423
# Episode 130/200, Total Reward: 27003.35, cache_hits: 230845, cache_misses: 10605, enh_layer_cache_hits: 38845, enh_layer_cache_misses: 10605, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.1402
# Episode 131/200, Total Reward: 26864.84, cache_hits: 231142, cache_misses: 10480, enh_layer_cache_hits: 39142, enh_layer_cache_misses: 10480, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.1381
# Episode 132/200, Total Reward: 26877.20, cache_hits: 231675, cache_misses: 10017, enh_layer_cache_hits: 39675, enh_layer_cache_misses: 10017, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.1360
# Episode 133/200, Total Reward: 26063.54, cache_hits: 231200, cache_misses: 10608, enh_layer_cache_hits: 39200, enh_layer_cache_misses: 10608, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.1340
# Episode 134/200, Total Reward: 27528.88, cache_hits: 231748, cache_misses: 9847, enh_layer_cache_hits: 39748, enh_layer_cache_misses: 9847, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.29, Epsilon: 0.1320
# Episode 135/200, Total Reward: 26635.53, cache_hits: 231349, cache_misses: 10446, enh_layer_cache_hits: 39349, enh_layer_cache_misses: 10446, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.1300
# Episode 136/200, Total Reward: 27654.29, cache_hits: 232336, cache_misses: 9499, enh_layer_cache_hits: 40336, enh_layer_cache_misses: 9499, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.1280
# Episode 137/200, Total Reward: 27182.53, cache_hits: 232139, cache_misses: 9647, enh_layer_cache_hits: 40139, enh_layer_cache_misses: 9647, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.1261
# Episode 138/200, Total Reward: 27503.28, cache_hits: 231823, cache_misses: 9871, enh_layer_cache_hits: 39823, enh_layer_cache_misses: 9871, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.1242
# Episode 139/200, Total Reward: 28816.30, cache_hits: 232536, cache_misses: 9237, enh_layer_cache_hits: 40536, enh_layer_cache_misses: 9237, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.1224
# Episode 140/200, Total Reward: 27390.44, cache_hits: 231238, cache_misses: 10484, enh_layer_cache_hits: 39238, enh_layer_cache_misses: 10484, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.1205
# Episode 141/200, Total Reward: 26019.69, cache_hits: 231712, cache_misses: 9952, enh_layer_cache_hits: 39712, enh_layer_cache_misses: 9952, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.1187
# Episode 142/200, Total Reward: 27415.42, cache_hits: 230708, cache_misses: 10998, enh_layer_cache_hits: 38708, enh_layer_cache_misses: 10998, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.1169
# Episode 143/200, Total Reward: 26917.23, cache_hits: 231369, cache_misses: 10475, enh_layer_cache_hits: 39369, enh_layer_cache_misses: 10475, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.1152
# Episode 144/200, Total Reward: 26607.65, cache_hits: 231595, cache_misses: 10051, enh_layer_cache_hits: 39595, enh_layer_cache_misses: 10051, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.1135
# Episode 145/200, Total Reward: 27558.29, cache_hits: 232179, cache_misses: 9350, enh_layer_cache_hits: 40179, enh_layer_cache_misses: 9350, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.1118
# Episode 146/200, Total Reward: 27923.72, cache_hits: 232378, cache_misses: 9352, enh_layer_cache_hits: 40378, enh_layer_cache_misses: 9352, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.29, Epsilon: 0.1101
# Episode 147/200, Total Reward: 28040.19, cache_hits: 232091, cache_misses: 9414, enh_layer_cache_hits: 40091, enh_layer_cache_misses: 9414, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.29, Epsilon: 0.1084
# Episode 148/200, Total Reward: 27168.16, cache_hits: 231271, cache_misses: 10469, enh_layer_cache_hits: 39271, enh_layer_cache_misses: 10469, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.1068
# Episode 149/200, Total Reward: 26637.72, cache_hits: 232735, cache_misses: 9046, enh_layer_cache_hits: 40735, enh_layer_cache_misses: 9046, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.30, Epsilon: 0.1052
# Episode 150/200, Total Reward: 27170.47, cache_hits: 231197, cache_misses: 10373, enh_layer_cache_hits: 39197, enh_layer_cache_misses: 10373, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.21, Epsilon: 0.1036
# Episode 151/200, Total Reward: 26680.19, cache_hits: 231064, cache_misses: 10869, enh_layer_cache_hits: 39064, enh_layer_cache_misses: 10869, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.1021
# Episode 152/200, Total Reward: 27211.36, cache_hits: 231773, cache_misses: 9870, enh_layer_cache_hits: 39773, enh_layer_cache_misses: 9870, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.1005
# Episode 153/200, Total Reward: 28905.15, cache_hits: 231491, cache_misses: 10066, enh_layer_cache_hits: 39491, enh_layer_cache_misses: 10066, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.0990
# Episode 154/200, Total Reward: 27613.85, cache_hits: 232110, cache_misses: 9583, enh_layer_cache_hits: 40110, enh_layer_cache_misses: 9583, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.0975
# Episode 155/200, Total Reward: 28439.56, cache_hits: 231563, cache_misses: 10069, enh_layer_cache_hits: 39563, enh_layer_cache_misses: 10069, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0961
# Episode 156/200, Total Reward: 27500.91, cache_hits: 232283, cache_misses: 9420, enh_layer_cache_hits: 40283, enh_layer_cache_misses: 9420, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0946
# Episode 157/200, Total Reward: 28300.15, cache_hits: 232893, cache_misses: 8929, enh_layer_cache_hits: 40893, enh_layer_cache_misses: 8929, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.29, Epsilon: 0.0932
# Episode 158/200, Total Reward: 28733.23, cache_hits: 232253, cache_misses: 9268, enh_layer_cache_hits: 40253, enh_layer_cache_misses: 9268, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0918
# Episode 159/200, Total Reward: 27964.14, cache_hits: 232210, cache_misses: 9293, enh_layer_cache_hits: 40210, enh_layer_cache_misses: 9293, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.0904
# Episode 160/200, Total Reward: 26641.38, cache_hits: 232195, cache_misses: 9752, enh_layer_cache_hits: 40195, enh_layer_cache_misses: 9752, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.0891
# Episode 161/200, Total Reward: 27686.27, cache_hits: 232753, cache_misses: 9064, enh_layer_cache_hits: 40753, enh_layer_cache_misses: 9064, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.17, Epsilon: 0.0877
# Episode 162/200, Total Reward: 27832.02, cache_hits: 231727, cache_misses: 10024, enh_layer_cache_hits: 39727, enh_layer_cache_misses: 10024, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0864
# Episode 163/200, Total Reward: 28045.70, cache_hits: 232363, cache_misses: 9326, enh_layer_cache_hits: 40363, enh_layer_cache_misses: 9326, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.0851
# Episode 164/200, Total Reward: 27573.51, cache_hits: 232272, cache_misses: 9430, enh_layer_cache_hits: 40272, enh_layer_cache_misses: 9430, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.19, Epsilon: 0.0839
# Episode 165/200, Total Reward: 26537.84, cache_hits: 231872, cache_misses: 9959, enh_layer_cache_hits: 39872, enh_layer_cache_misses: 9959, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.0826
# Episode 166/200, Total Reward: 28342.72, cache_hits: 232793, cache_misses: 8939, enh_layer_cache_hits: 40793, enh_layer_cache_misses: 8939, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.0814
# Episode 167/200, Total Reward: 28013.70, cache_hits: 232783, cache_misses: 8825, enh_layer_cache_hits: 40783, enh_layer_cache_misses: 8825, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.0801
# Episode 168/200, Total Reward: 28454.01, cache_hits: 232232, cache_misses: 9607, enh_layer_cache_hits: 40232, enh_layer_cache_misses: 9607, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.30, Epsilon: 0.0789
# Episode 169/200, Total Reward: 26851.82, cache_hits: 232235, cache_misses: 9357, enh_layer_cache_hits: 40235, enh_layer_cache_misses: 9357, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0778
# Episode 170/200, Total Reward: 28066.89, cache_hits: 232117, cache_misses: 9525, enh_layer_cache_hits: 40117, enh_layer_cache_misses: 9525, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.0766
# Episode 171/200, Total Reward: 26604.22, cache_hits: 232092, cache_misses: 9547, enh_layer_cache_hits: 40092, enh_layer_cache_misses: 9547, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.0754
# Episode 172/200, Total Reward: 26754.22, cache_hits: 231059, cache_misses: 10626, enh_layer_cache_hits: 39059, enh_layer_cache_misses: 10626, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.0743
# Episode 173/200, Total Reward: 29027.21, cache_hits: 232543, cache_misses: 9072, enh_layer_cache_hits: 40543, enh_layer_cache_misses: 9072, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.30, Epsilon: 0.0732
# Episode 174/200, Total Reward: 26812.48, cache_hits: 232589, cache_misses: 9061, enh_layer_cache_hits: 40589, enh_layer_cache_misses: 9061, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0721
# Episode 175/200, Total Reward: 27326.23, cache_hits: 232437, cache_misses: 9218, enh_layer_cache_hits: 40437, enh_layer_cache_misses: 9218, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.0710
# Episode 176/200, Total Reward: 28728.97, cache_hits: 232176, cache_misses: 9418, enh_layer_cache_hits: 40176, enh_layer_cache_misses: 9418, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.0699
# Episode 177/200, Total Reward: 27598.35, cache_hits: 232964, cache_misses: 8782, enh_layer_cache_hits: 40964, enh_layer_cache_misses: 8782, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0689
# Episode 178/200, Total Reward: 27559.13, cache_hits: 232148, cache_misses: 9552, enh_layer_cache_hits: 40148, enh_layer_cache_misses: 9552, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.0679
# Episode 179/200, Total Reward: 28308.26, cache_hits: 232240, cache_misses: 9515, enh_layer_cache_hits: 40240, enh_layer_cache_misses: 9515, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.0668
# Episode 180/200, Total Reward: 27358.20, cache_hits: 232539, cache_misses: 9032, enh_layer_cache_hits: 40539, enh_layer_cache_misses: 9032, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.29, Epsilon: 0.0658
# Episode 181/200, Total Reward: 27294.69, cache_hits: 232820, cache_misses: 8755, enh_layer_cache_hits: 40820, enh_layer_cache_misses: 8755, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.18, Epsilon: 0.0649
# Episode 182/200, Total Reward: 26848.61, cache_hits: 231465, cache_misses: 10247, enh_layer_cache_hits: 39465, enh_layer_cache_misses: 10247, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.30, Epsilon: 0.0639
# Episode 183/200, Total Reward: 26939.65, cache_hits: 232947, cache_misses: 8852, enh_layer_cache_hits: 40947, enh_layer_cache_misses: 8852, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.29, Epsilon: 0.0629
# Episode 184/200, Total Reward: 27188.79, cache_hits: 232611, cache_misses: 9141, enh_layer_cache_hits: 40611, enh_layer_cache_misses: 9141, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.0620
# Episode 185/200, Total Reward: 28466.88, cache_hits: 233156, cache_misses: 8303, enh_layer_cache_hits: 41156, enh_layer_cache_misses: 8303, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.0611
# Episode 186/200, Total Reward: 27833.40, cache_hits: 233276, cache_misses: 8563, enh_layer_cache_hits: 41276, enh_layer_cache_misses: 8563, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.23, Epsilon: 0.0601
# Episode 187/200, Total Reward: 26700.67, cache_hits: 231592, cache_misses: 10010, enh_layer_cache_hits: 39592, enh_layer_cache_misses: 10010, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.22, Epsilon: 0.0592
# Episode 188/200, Total Reward: 27439.92, cache_hits: 232698, cache_misses: 8892, enh_layer_cache_hits: 40698, enh_layer_cache_misses: 8892, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.30, Epsilon: 0.0583
# Episode 189/200, Total Reward: 28473.89, cache_hits: 232551, cache_misses: 9223, enh_layer_cache_hits: 40551, enh_layer_cache_misses: 9223, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.29, Epsilon: 0.0575
# Episode 190/200, Total Reward: 26918.70, cache_hits: 232501, cache_misses: 9171, enh_layer_cache_hits: 40501, enh_layer_cache_misses: 9171, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.0566
# Episode 191/200, Total Reward: 27488.52, cache_hits: 232807, cache_misses: 8885, enh_layer_cache_hits: 40807, enh_layer_cache_misses: 8885, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0558
# Episode 192/200, Total Reward: 27996.38, cache_hits: 231570, cache_misses: 9884, enh_layer_cache_hits: 39570, enh_layer_cache_misses: 9884, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.0549
# Episode 193/200, Total Reward: 27853.23, cache_hits: 232974, cache_misses: 8757, enh_layer_cache_hits: 40974, enh_layer_cache_misses: 8757, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.0541
# Episode 194/200, Total Reward: 28323.27, cache_hits: 233341, cache_misses: 8330, enh_layer_cache_hits: 41341, enh_layer_cache_misses: 8330, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.32, Epsilon: 0.0533
# Episode 195/200, Total Reward: 28214.84, cache_hits: 233192, cache_misses: 8444, enh_layer_cache_hits: 41192, enh_layer_cache_misses: 8444, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.0525
# Episode 196/200, Total Reward: 27456.30, cache_hits: 232624, cache_misses: 9122, enh_layer_cache_hits: 40624, enh_layer_cache_misses: 9122, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.27, Epsilon: 0.0517
# Episode 197/200, Total Reward: 27503.51, cache_hits: 232478, cache_misses: 9047, enh_layer_cache_hits: 40478, enh_layer_cache_misses: 9047, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.28, Epsilon: 0.0509
# Episode 198/200, Total Reward: 27316.34, cache_hits: 232300, cache_misses: 9622, enh_layer_cache_hits: 40300, enh_layer_cache_misses: 9622, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.24, Epsilon: 0.0502
# Episode 199/200, Total Reward: 27138.31, cache_hits: 231800, cache_misses: 9875, enh_layer_cache_hits: 39800, enh_layer_cache_misses: 9875, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.25, Epsilon: 0.0494
# Episode 200/200, Total Reward: 28665.61, cache_hits: 232832, cache_misses: 9064, enh_layer_cache_hits: 40832, enh_layer_cache_misses: 9064, base_layer_cache_hits: 192000, base_layer_cache_misses: 0, Average PSNR: 39.26, Epsilon: 0.0487

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# 1. Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_yscale('log') 
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# 2. Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_yscale('log') 
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# 3. Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_yscale('log')
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6113/3657158268.py:17: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_6113/3657158268.py:27: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_6113/3657158268.py:37: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[2].set_ylim(bottom=0)

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
eval_episodes = 100

results_eval = []
scores_eval = []

for ep in range(eval_episodes):
    obs, info = env.reset()
    user_histories = {
        u: deque([np.zeros(n * n) for _ in range(window_len)], maxlen=window_len)
        for u in range(n_users)
    }

    enhanced_hits = enhanced_misses = 0
    base_hits = base_misses = 0
    total_reward = 0.0
    avg_psnr = []

    for step in count():
        # --- AGENT ACTIONS ---
        reqs_state = info['users_requests']
        active_users = [
            (
                req['u'], 
                req['video'], 
                req['gop'],
                info['content_popularity'][0][req['video']] / sum(info['content_popularity'][0])
            ) for req in reqs_state if req['gop'] < n_gops
        ]

        actions = []
        user_action_indices = {}

        for u, video, gop, vid_pop in active_users:
            state = np.array(user_histories[u])
            state = (state, vid_pop)

            # Agent chooses center tile
            center_tile_idx, q_values = agent.select_action(state)
            user_action_indices[u] = center_tile_idx

            if center_tile_idx == n_tiles:
                predicted_viewport = np.zeros(n*n, dtype=int)
            else:
                predicted_viewport = index_to_fov_mask(center_idx=center_tile_idx, n=n)

            actions.append({
                'user': u,
                'gop': gop,
                'video': video,
                'tiles': predicted_viewport
            })

        obs, rewards, done, info = env.step(actions)

        total_reward += float(rewards)
        enhanced_hits += info["enh_layer_cache_hits"]
        enhanced_misses += info["enh_layer_cache_misses"]
        base_hits += info["base_layer_cache_hits"]
        base_misses += info["base_layer_cache_misses"]
        avg_psnr.append(info.get("average_psnr", 0.0))

        if done:
            break

    avg_psnr = [x for x in avg_psnr if x != 0.0]
    cache_hits_ep = enhanced_hits + base_hits
    cache_misses_ep = enhanced_misses + base_misses

    print(
        f"Episode {ep+1}/{eval_episodes} | "
        f"Reward: {total_reward:.2f} | "
        f"cache_hits: {cache_hits_ep} | cache_misses: {cache_misses_ep} | "
        f"Enhanced(H/M): {enhanced_hits}/{enhanced_misses} | "
        f"Base(H/M): {base_hits}/{base_misses} | "
        f"Avg PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}"
    )

    scores_eval.append(total_reward)
    results_eval.append(
        {"episode": ep, "cache_hits": cache_hits_ep, "cache_misses": cache_misses_ep, "reward": total_reward}
    )
    
    filename_eval = (
        f"fov_predictor_opt_E{eval_episodes}_"
        f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
        f"cap{int(max_capacity/1e6)}MB_AR{arrival_rate}_eval.csv"
    )
    
    save_training_results(
        path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
        # path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
        filename=filename_eval,
        ep=ep,
        total_reward=total_reward,
        cache_hits=cache_hits_ep,
        cache_misses=cache_misses_ep,
        enhanced_layer_cache_hits=enhanced_hits,
        enhanced_layer_cache_misses=enhanced_misses,
        base_layer_cache_hits=base_hits,
        base_layer_cache_misses=base_misses,
        avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
        agent=agent
    )
# Out:
# [Optimal] Episode 1/100 | Reward: 20907.20 | cache_hits: 233194 | cache_misses: 8665 | Enhanced(H/M): 41194/8665 | Base(H/M): 192000/0 | Avg PSNR: 39.27
# [Optimal] Episode 2/100 | Reward: 21323.93 | cache_hits: 233863 | cache_misses: 7796 | Enhanced(H/M): 41863/7796 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 3/100 | Reward: 21673.01 | cache_hits: 233494 | cache_misses: 8116 | Enhanced(H/M): 41494/8116 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 4/100 | Reward: 20652.04 | cache_hits: 233232 | cache_misses: 8388 | Enhanced(H/M): 41232/8388 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 5/100 | Reward: 21863.77 | cache_hits: 233880 | cache_misses: 7734 | Enhanced(H/M): 41880/7734 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 6/100 | Reward: 21686.78 | cache_hits: 233954 | cache_misses: 7652 | Enhanced(H/M): 41954/7652 | Base(H/M): 192000/0 | Avg PSNR: 39.33
# [Optimal] Episode 7/100 | Reward: 20909.13 | cache_hits: 232978 | cache_misses: 8785 | Enhanced(H/M): 40978/8785 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 8/100 | Reward: 21043.76 | cache_hits: 233774 | cache_misses: 7872 | Enhanced(H/M): 41774/7872 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 9/100 | Reward: 20714.14 | cache_hits: 233144 | cache_misses: 8593 | Enhanced(H/M): 41144/8593 | Base(H/M): 192000/0 | Avg PSNR: 39.28
# [Optimal] Episode 10/100 | Reward: 21335.72 | cache_hits: 233871 | cache_misses: 7600 | Enhanced(H/M): 41871/7600 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 11/100 | Reward: 21214.32 | cache_hits: 233018 | cache_misses: 8675 | Enhanced(H/M): 41018/8675 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 12/100 | Reward: 21081.11 | cache_hits: 233839 | cache_misses: 7923 | Enhanced(H/M): 41839/7923 | Base(H/M): 192000/0 | Avg PSNR: 39.28
# [Optimal] Episode 13/100 | Reward: 21812.64 | cache_hits: 233802 | cache_misses: 7683 | Enhanced(H/M): 41802/7683 | Base(H/M): 192000/0 | Avg PSNR: 39.32
# [Optimal] Episode 14/100 | Reward: 21784.58 | cache_hits: 233507 | cache_misses: 8312 | Enhanced(H/M): 41507/8312 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 15/100 | Reward: 20916.53 | cache_hits: 233486 | cache_misses: 8332 | Enhanced(H/M): 41486/8332 | Base(H/M): 192000/0 | Avg PSNR: 39.27
# [Optimal] Episode 16/100 | Reward: 21689.81 | cache_hits: 233178 | cache_misses: 8514 | Enhanced(H/M): 41178/8514 | Base(H/M): 192000/0 | Avg PSNR: 39.26
# [Optimal] Episode 17/100 | Reward: 21348.94 | cache_hits: 232843 | cache_misses: 8846 | Enhanced(H/M): 40843/8846 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 18/100 | Reward: 21174.98 | cache_hits: 232746 | cache_misses: 9002 | Enhanced(H/M): 40746/9002 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 19/100 | Reward: 21590.25 | cache_hits: 233438 | cache_misses: 8239 | Enhanced(H/M): 41438/8239 | Base(H/M): 192000/0 | Avg PSNR: 39.33
# [Optimal] Episode 20/100 | Reward: 21493.12 | cache_hits: 233607 | cache_misses: 8051 | Enhanced(H/M): 41607/8051 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 21/100 | Reward: 21393.78 | cache_hits: 233568 | cache_misses: 8049 | Enhanced(H/M): 41568/8049 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 22/100 | Reward: 21616.47 | cache_hits: 233959 | cache_misses: 7780 | Enhanced(H/M): 41959/7780 | Base(H/M): 192000/0 | Avg PSNR: 39.32
# [Optimal] Episode 23/100 | Reward: 20816.99 | cache_hits: 233362 | cache_misses: 8193 | Enhanced(H/M): 41362/8193 | Base(H/M): 192000/0 | Avg PSNR: 39.27
# [Optimal] Episode 24/100 | Reward: 21181.26 | cache_hits: 233146 | cache_misses: 8472 | Enhanced(H/M): 41146/8472 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 25/100 | Reward: 21465.91 | cache_hits: 233161 | cache_misses: 8487 | Enhanced(H/M): 41161/8487 | Base(H/M): 192000/0 | Avg PSNR: 39.33
# [Optimal] Episode 26/100 | Reward: 21545.41 | cache_hits: 233248 | cache_misses: 8375 | Enhanced(H/M): 41248/8375 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 27/100 | Reward: 21251.81 | cache_hits: 233438 | cache_misses: 8315 | Enhanced(H/M): 41438/8315 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 28/100 | Reward: 21600.36 | cache_hits: 233334 | cache_misses: 8239 | Enhanced(H/M): 41334/8239 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 29/100 | Reward: 21568.92 | cache_hits: 234267 | cache_misses: 7522 | Enhanced(H/M): 42267/7522 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 30/100 | Reward: 21677.88 | cache_hits: 234090 | cache_misses: 7443 | Enhanced(H/M): 42090/7443 | Base(H/M): 192000/0 | Avg PSNR: 39.27
# [Optimal] Episode 31/100 | Reward: 21023.98 | cache_hits: 233577 | cache_misses: 8241 | Enhanced(H/M): 41577/8241 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 32/100 | Reward: 21740.48 | cache_hits: 233523 | cache_misses: 8291 | Enhanced(H/M): 41523/8291 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 33/100 | Reward: 21130.43 | cache_hits: 233011 | cache_misses: 8760 | Enhanced(H/M): 41011/8760 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 34/100 | Reward: 21166.22 | cache_hits: 233237 | cache_misses: 8365 | Enhanced(H/M): 41237/8365 | Base(H/M): 192000/0 | Avg PSNR: 39.27
# [Optimal] Episode 35/100 | Reward: 21272.30 | cache_hits: 233517 | cache_misses: 8182 | Enhanced(H/M): 41517/8182 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 36/100 | Reward: 21014.85 | cache_hits: 233108 | cache_misses: 8573 | Enhanced(H/M): 41108/8573 | Base(H/M): 192000/0 | Avg PSNR: 39.28
# [Optimal] Episode 37/100 | Reward: 21399.92 | cache_hits: 233817 | cache_misses: 7687 | Enhanced(H/M): 41817/7687 | Base(H/M): 192000/0 | Avg PSNR: 39.32
# [Optimal] Episode 38/100 | Reward: 21763.52 | cache_hits: 233879 | cache_misses: 7618 | Enhanced(H/M): 41879/7618 | Base(H/M): 192000/0 | Avg PSNR: 39.33
# [Optimal] Episode 39/100 | Reward: 21765.51 | cache_hits: 233340 | cache_misses: 8163 | Enhanced(H/M): 41340/8163 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 40/100 | Reward: 21161.72 | cache_hits: 233435 | cache_misses: 8240 | Enhanced(H/M): 41435/8240 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 41/100 | Reward: 21366.88 | cache_hits: 234379 | cache_misses: 7304 | Enhanced(H/M): 42379/7304 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 42/100 | Reward: 21353.56 | cache_hits: 233835 | cache_misses: 7621 | Enhanced(H/M): 41835/7621 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 43/100 | Reward: 21592.92 | cache_hits: 233351 | cache_misses: 8273 | Enhanced(H/M): 41351/8273 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 44/100 | Reward: 21527.63 | cache_hits: 233971 | cache_misses: 7647 | Enhanced(H/M): 41971/7647 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 45/100 | Reward: 21582.26 | cache_hits: 233865 | cache_misses: 7829 | Enhanced(H/M): 41865/7829 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 46/100 | Reward: 21459.47 | cache_hits: 233890 | cache_misses: 7618 | Enhanced(H/M): 41890/7618 | Base(H/M): 192000/0 | Avg PSNR: 39.32
# [Optimal] Episode 47/100 | Reward: 21124.55 | cache_hits: 233308 | cache_misses: 8301 | Enhanced(H/M): 41308/8301 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 48/100 | Reward: 21773.14 | cache_hits: 233625 | cache_misses: 8001 | Enhanced(H/M): 41625/8001 | Base(H/M): 192000/0 | Avg PSNR: 39.32
# [Optimal] Episode 49/100 | Reward: 21599.86 | cache_hits: 233958 | cache_misses: 7856 | Enhanced(H/M): 41958/7856 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 50/100 | Reward: 21380.34 | cache_hits: 233562 | cache_misses: 8206 | Enhanced(H/M): 41562/8206 | Base(H/M): 192000/0 | Avg PSNR: 39.33
# [Optimal] Episode 51/100 | Reward: 22267.41 | cache_hits: 234104 | cache_misses: 7571 | Enhanced(H/M): 42104/7571 | Base(H/M): 192000/0 | Avg PSNR: 39.34
# [Optimal] Episode 52/100 | Reward: 21045.45 | cache_hits: 233308 | cache_misses: 8410 | Enhanced(H/M): 41308/8410 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 53/100 | Reward: 20953.55 | cache_hits: 233076 | cache_misses: 8477 | Enhanced(H/M): 41076/8477 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 54/100 | Reward: 21287.15 | cache_hits: 233203 | cache_misses: 8343 | Enhanced(H/M): 41203/8343 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 55/100 | Reward: 21851.89 | cache_hits: 233872 | cache_misses: 7872 | Enhanced(H/M): 41872/7872 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 56/100 | Reward: 21180.93 | cache_hits: 233313 | cache_misses: 8483 | Enhanced(H/M): 41313/8483 | Base(H/M): 192000/0 | Avg PSNR: 39.28
# [Optimal] Episode 57/100 | Reward: 21511.30 | cache_hits: 233185 | cache_misses: 8404 | Enhanced(H/M): 41185/8404 | Base(H/M): 192000/0 | Avg PSNR: 39.34
# [Optimal] Episode 58/100 | Reward: 21321.47 | cache_hits: 233565 | cache_misses: 7974 | Enhanced(H/M): 41565/7974 | Base(H/M): 192000/0 | Avg PSNR: 39.28
# [Optimal] Episode 59/100 | Reward: 20333.20 | cache_hits: 233138 | cache_misses: 8773 | Enhanced(H/M): 41138/8773 | Base(H/M): 192000/0 | Avg PSNR: 39.28
# [Optimal] Episode 60/100 | Reward: 20823.07 | cache_hits: 233028 | cache_misses: 8814 | Enhanced(H/M): 41028/8814 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 61/100 | Reward: 21143.01 | cache_hits: 233794 | cache_misses: 7700 | Enhanced(H/M): 41794/7700 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 62/100 | Reward: 22167.80 | cache_hits: 233909 | cache_misses: 7919 | Enhanced(H/M): 41909/7919 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 63/100 | Reward: 21635.12 | cache_hits: 233467 | cache_misses: 8090 | Enhanced(H/M): 41467/8090 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 64/100 | Reward: 21453.11 | cache_hits: 233654 | cache_misses: 7813 | Enhanced(H/M): 41654/7813 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 65/100 | Reward: 21545.67 | cache_hits: 234450 | cache_misses: 7065 | Enhanced(H/M): 42450/7065 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 66/100 | Reward: 21834.23 | cache_hits: 233954 | cache_misses: 7763 | Enhanced(H/M): 41954/7763 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 67/100 | Reward: 21861.73 | cache_hits: 234273 | cache_misses: 7257 | Enhanced(H/M): 42273/7257 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 68/100 | Reward: 20944.36 | cache_hits: 233443 | cache_misses: 8144 | Enhanced(H/M): 41443/8144 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 69/100 | Reward: 21832.31 | cache_hits: 234272 | cache_misses: 7483 | Enhanced(H/M): 42272/7483 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 70/100 | Reward: 21781.21 | cache_hits: 234122 | cache_misses: 7523 | Enhanced(H/M): 42122/7523 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 71/100 | Reward: 21812.05 | cache_hits: 233459 | cache_misses: 8237 | Enhanced(H/M): 41459/8237 | Base(H/M): 192000/0 | Avg PSNR: 39.32
# [Optimal] Episode 72/100 | Reward: 21143.96 | cache_hits: 233107 | cache_misses: 8630 | Enhanced(H/M): 41107/8630 | Base(H/M): 192000/0 | Avg PSNR: 39.33
# [Optimal] Episode 73/100 | Reward: 21141.75 | cache_hits: 233674 | cache_misses: 8053 | Enhanced(H/M): 41674/8053 | Base(H/M): 192000/0 | Avg PSNR: 39.34
# [Optimal] Episode 74/100 | Reward: 21203.15 | cache_hits: 233747 | cache_misses: 7888 | Enhanced(H/M): 41747/7888 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 75/100 | Reward: 21251.00 | cache_hits: 233193 | cache_misses: 8398 | Enhanced(H/M): 41193/8398 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 76/100 | Reward: 21481.63 | cache_hits: 233370 | cache_misses: 8409 | Enhanced(H/M): 41370/8409 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 77/100 | Reward: 21261.16 | cache_hits: 232853 | cache_misses: 8851 | Enhanced(H/M): 40853/8851 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 78/100 | Reward: 21110.72 | cache_hits: 233642 | cache_misses: 8194 | Enhanced(H/M): 41642/8194 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 79/100 | Reward: 20419.65 | cache_hits: 233459 | cache_misses: 8313 | Enhanced(H/M): 41459/8313 | Base(H/M): 192000/0 | Avg PSNR: 39.27
# [Optimal] Episode 80/100 | Reward: 21433.19 | cache_hits: 233689 | cache_misses: 7930 | Enhanced(H/M): 41689/7930 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 81/100 | Reward: 21691.54 | cache_hits: 233421 | cache_misses: 8205 | Enhanced(H/M): 41421/8205 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 82/100 | Reward: 21385.09 | cache_hits: 233784 | cache_misses: 7830 | Enhanced(H/M): 41784/7830 | Base(H/M): 192000/0 | Avg PSNR: 39.28
# [Optimal] Episode 83/100 | Reward: 21874.53 | cache_hits: 233891 | cache_misses: 7791 | Enhanced(H/M): 41891/7791 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 84/100 | Reward: 20979.17 | cache_hits: 233572 | cache_misses: 7998 | Enhanced(H/M): 41572/7998 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 85/100 | Reward: 20961.78 | cache_hits: 233495 | cache_misses: 7954 | Enhanced(H/M): 41495/7954 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 86/100 | Reward: 21631.07 | cache_hits: 233928 | cache_misses: 7649 | Enhanced(H/M): 41928/7649 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 87/100 | Reward: 21333.17 | cache_hits: 233683 | cache_misses: 7924 | Enhanced(H/M): 41683/7924 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 88/100 | Reward: 21570.90 | cache_hits: 233691 | cache_misses: 8013 | Enhanced(H/M): 41691/8013 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 89/100 | Reward: 22321.71 | cache_hits: 233624 | cache_misses: 7895 | Enhanced(H/M): 41624/7895 | Base(H/M): 192000/0 | Avg PSNR: 39.34
# [Optimal] Episode 90/100 | Reward: 21315.26 | cache_hits: 233806 | cache_misses: 7778 | Enhanced(H/M): 41806/7778 | Base(H/M): 192000/0 | Avg PSNR: 39.28
# [Optimal] Episode 91/100 | Reward: 21240.19 | cache_hits: 233057 | cache_misses: 8569 | Enhanced(H/M): 41057/8569 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 92/100 | Reward: 21101.18 | cache_hits: 233076 | cache_misses: 8377 | Enhanced(H/M): 41076/8377 | Base(H/M): 192000/0 | Avg PSNR: 39.30
# [Optimal] Episode 93/100 | Reward: 21063.84 | cache_hits: 233325 | cache_misses: 8369 | Enhanced(H/M): 41325/8369 | Base(H/M): 192000/0 | Avg PSNR: 39.32
# [Optimal] Episode 94/100 | Reward: 20714.80 | cache_hits: 233447 | cache_misses: 8185 | Enhanced(H/M): 41447/8185 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 95/100 | Reward: 21156.82 | cache_hits: 233244 | cache_misses: 8484 | Enhanced(H/M): 41244/8484 | Base(H/M): 192000/0 | Avg PSNR: 39.29
# [Optimal] Episode 96/100 | Reward: 21990.51 | cache_hits: 234625 | cache_misses: 7030 | Enhanced(H/M): 42625/7030 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 97/100 | Reward: 21438.51 | cache_hits: 233450 | cache_misses: 7953 | Enhanced(H/M): 41450/7953 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 98/100 | Reward: 21232.07 | cache_hits: 233245 | cache_misses: 8436 | Enhanced(H/M): 41245/8436 | Base(H/M): 192000/0 | Avg PSNR: 39.33
# [Optimal] Episode 99/100 | Reward: 21593.88 | cache_hits: 233378 | cache_misses: 8147 | Enhanced(H/M): 41378/8147 | Base(H/M): 192000/0 | Avg PSNR: 39.31
# [Optimal] Episode 100/100 | Reward: 21385.60 | cache_hits: 233043 | cache_misses: 8657 | Enhanced(H/M): 41043/8657 | Base(H/M): 192000/0 | Avg PSNR: 39.32

# %%
def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]
    base_totals = [h + m for h, m in zip(base_hits, base_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]
    base_hit_rate = [safe_pct(h, t) for h, t in zip(base_hits, base_totals)]
    base_miss_rate = [safe_pct(m, t) for m, t in zip(base_misses, base_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)
    base_ylim = (0, 100)

    fig, axes = plt.subplots(3, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Base Layer: Hit rate
    axes[1, 0].plot(episodes, base_hit_rate, label="Base hit rate (%)", color="green", alpha=0.9)
    axes[1, 0].set_title("Base Layer Hit Rate")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Rate (%)")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Base Layer: Miss rate
    axes[1, 1].plot(episodes, base_miss_rate, label="Base miss rate (%)", color="orange", alpha=0.9)
    axes[1, 1].set_title("Base Layer Miss Rate")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Rate (%)")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    # Reward title
    axes[2, 0].plot(episodes, rewards, label="Episode reward", color="purple", alpha=0.9)
    axes[2, 0].set_title("Episode Rewards")
    axes[2, 0].set_xlabel("Episode")
    axes[2, 0].set_ylabel("Reward")
    axes[2, 0].grid(True, alpha=0.3)
    axes[2, 0].legend()

    # Average PSNR
    axes[2, 1].plot(episodes, psnr, label="Average PSNR", color="brown", alpha=0.9)
    axes[2, 1].set_title("Average PSNR per Episode")
    axes[2, 1].set_xlabel("Episode")
    axes[2, 1].set_ylabel("PSNR (dB)")
    axes[2, 1].grid(True, alpha=0.3)
    axes[2, 1].legend()


    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.0.csv'
    
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 143
#     139 out_path = None
#     141 title = "FOV Predictor DQN Agent Cache Layers Performance"
# --> 143 plot_cache_layers(
#     144     csv_filepath,
#     145     out_path=None,
#     146     title=title
#     147 )
#
# Cell In[32], line 52, in plot_cache_layers(csv_path, out_path, title)
#      47 def plot_cache_layers(
#      48     csv_path: str,
#      49     out_path: str | None = None,
#      50     title: str | None = None,
#      51 ):
# ---> 52     episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)
#      54     # Compute per-episode percentages
#      55     def safe_pct(num, den):
#
# Cell In[32], line 11, in read_results(csv_path)
#       8 avg_psnr: List[float] = []
#      10 if not os.path.exists(csv_path):
# ---> 11     raise FileNotFoundError(f"CSV file not found: {csv_path}")
#      13 with open(csv_path, "r", newline="") as f:
#      14     reader = csv.DictReader(f)
#
# FileNotFoundError: CSV file not found: c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.0.csv

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Reward title
    axes[1, 0].plot(episodes, rewards, label="Episode reward", color="purple", alpha=0.9)
    axes[1, 0].set_title("Episode Rewards")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Reward")
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Average PSNR
    axes[1, 1].plot(episodes, psnr, label="Average PSNR", color="brown", alpha=0.9)
    axes[1, 1].set_title("Average PSNR per Episode")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("PSNR (dB)")
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    # csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += '/fov_predictor_ct_cp_E200_U200_V500_G60_L2_N4_cap500MB_AR10.0.csv'
    
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # csv_path_lsr = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    # csv_path_lsr += r'\fov_lsr_U100_V100_G60_L2_N4_cap500MB_AR15.csv'

    csv_path_lsr = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_path_lsr += '/fov_lsr_U200_V500_G60_L2_N4_cap500MB_AR10.csv'
    

    episodes_lsr, enhanced_hits_lsr, enhanced_misses_lsr, base_hits_lsr, base_misses_lsr, rewards_lsr, psnr_lsr = read_results(csv_path_lsr)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="DRL-LRU", color="blue", alpha=0.9)
    axes[0, 0].plot(episodes_lsr, [safe_pct(h, h + m) for h, m in zip(enhanced_hits_lsr, enhanced_misses_lsr)], label="LSR-LRU", color="red")
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="DRL-LRU", color="blue", alpha=0.9)
    axes[0, 1].plot(episodes_lsr, [safe_pct(m, h + m) for h, m in zip(enhanced_hits_lsr, enhanced_misses_lsr)], label="LSR-LRU", color="red")
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Reward title
    axes[1, 0].plot(episodes, rewards, label="DRL-LRU", color="blue", alpha=0.9)
    axes[1, 0].set_title("Rewards")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Reward")
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Average PSNR
    axes[1, 1].plot(episodes, psnr, label="DRL-LRU", color="blue", alpha=0.9)
    axes[1, 1].plot(episodes_lsr, psnr_lsr, label="LSR-LRU", color="red")
    axes[1, 1].set_title("Average PSNR")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("PSNR (dB)")
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    # csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.csv'
    
    csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath += '/fov_predictor_ct_cp_E200_U200_V500_G60_L2_N4_cap500MB_AR10.0.csv'
    
    out_path = None

    title = "FOV Predictor Double DQN Agent Cache Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
