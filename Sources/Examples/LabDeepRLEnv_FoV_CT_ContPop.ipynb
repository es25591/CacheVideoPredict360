# %%
import os
import csv
import sys
import math
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd


from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import List

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv, LruPolicy, SvcLruPolicy
    from LabUserTileRequest import UserTileRequestEvents
    from LabEnvWrapper import EnvWrapper

# sys.path.append(r'c:\Users\es25591\Workspace\CacheVideoPredict360\Sources')
sys.path.append('/home/eduardo/Workspace/CacheVideoPredict360/Sources')
from Common.Utils import save_training_results

# %%
class PopularityAware(nn.Module):
    def __init__(self, n_tiles, hidden_size, output_size, num_layers=1):
        super().__init__()
        
        self.lstm = nn.LSTM(n_tiles, hidden_size, num_layers, batch_first=True)
        
        self.fc = nn.Linear(1, 8)
    
        self.fc_combined = nn.Linear(hidden_size + 8, 64)
        self.fc_out = nn.Linear(64, output_size)
    
    def forward(self, x_trajectory, x_popularity):
        # 1. Process trajectory with LSTM
        lstm_out, _ = self.lstm(x_trajectory)
        lstm_out = lstm_out[:, -1, :]  # Take the last output of the LSTM

        # 2. Process popularity with a fully connected layer
        pop_out = F.relu(self.fc(x_popularity))
        
        # 3. Combine both outputs
        combined = torch.cat((lstm_out, pop_out), dim=1)
        
        x = F.relu(self.fc_combined(combined))
        q_values = self.fc_out(x)
        
        return q_values, None

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        # state shape: (seq_len, input_size)
        self.memory.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

class DQNAgent:
    def __init__(
        self, 
        n_tiles, 
        seq_len, 
        learning_rate=1e-3, 
        gamma=0.99,
        batch_size=64,
        capacity=10000,
        epsilon_start=1.0,
        epsilon_min=0.05,
        epsilon_decay=0.995
    ):
        self.n_tiles = n_tiles
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        
        # Initialize standard LSTM_DQN with the new input dimension
        self.policy_net = PopularityAware(n_tiles, 128, n_tiles + 1).to(device)
        self.target_net = PopularityAware(n_tiles, 128, n_tiles + 1).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        
        self.optimizer = optim.Adam(
            self.policy_net.parameters(), 
            lr=learning_rate
        )

        self.criterion = nn.MSELoss()
        self.memory = ReplayMemory(capacity=capacity)
        self.batch_size = batch_size

    def select_action(self, state):
        trajectory, popularity = state
        
        if random.random() < self.epsilon:
            return random.randrange(self.n_tiles + 1), None
        else:
            with torch.no_grad():
                state_trajectory_t = torch.FloatTensor(trajectory).unsqueeze(0).to(device)
                state_popularity_t = torch.FloatTensor([popularity]).unsqueeze(0).to(device)
                
                q_values, _ = self.policy_net(state_trajectory_t, state_popularity_t)
                
                return q_values.argmax().item(), q_values.cpu().numpy()

    def select_optimal_action(self, state):        
        trajectory, popularity = state

        with torch.no_grad():
            state_trajectory_t = torch.FloatTensor(trajectory).unsqueeze(0).to(device)
            state_popularity_t = torch.FloatTensor([popularity]).unsqueeze(0).to(device)
            
            q_values, _ = self.policy_net(state_trajectory_t, state_popularity_t)
            
            return q_values.argmax().item(), q_values.cpu().numpy()

    def train_step(self):
        if len(self.memory) < self.batch_size:
            return 0.0
        
        batch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        # 1. Prepare Current States
        state_seqs = torch.FloatTensor(np.array([s[0] for s in states])).to(device)
        state_pops = torch.FloatTensor(np.array([s[1] for s in states])).unsqueeze(1).to(device)
        
        next_seqs = torch.FloatTensor(np.array([s[0] for s in next_states])).to(device)
        next_pops = torch.FloatTensor(np.array([s[1] for s in next_states])).unsqueeze(1).to(device)

        actions = torch.LongTensor(actions).unsqueeze(1).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        dones = torch.FloatTensor(np.array(dones, dtype=np.float32)).to(device)
        
        # --- Q-VALUE CALCULATION ---
        q_values, _ = self.policy_net(state_seqs, state_pops)
        state_action_values = q_values.gather(1, actions).squeeze(1)

        with torch.no_grad():
            next_q_values, _ = self.target_net(next_seqs, next_pops)
            next_state_values = next_q_values.max(1)[0]
            expected_state_action_values = rewards + (self.gamma * next_state_values * (1 - dones))

        loss = self.criterion(state_action_values, expected_state_action_values)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        return loss.item()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

# %%
def index_to_fov_mask(center_idx, n, m):
    mask = np.zeros(n*m, dtype=int)
    cy, cx = divmod(center_idx, n)
    
    for dy in [-1, 0, 1]:
        for dx in [-1, 0, 1]:
            ny, nx = cy + dy, cx + dx
            if 0 <= ny < m and 0 <= nx < n:
                mask[ny * m + nx] = 1

    return mask

# %%
if __name__ == "__main__":
    n_episodes = 300
    n_nodes = 3
    n_users = 200
    step_size = 10.0
    arrival_rate = 10.0  # users per second
    alpha = 0.5
    n_videos = 500
    n_gops = 30
    n_layers = 2
    n = 4
    m = 3
    n_tiles = n * m
    max_capacity = 500e6  # 500 MB

    # Hyperparameters for RL
    epsilon_start = 1.0
    epsilon_min = 0.005
    epsilon_decay = 0.987
    gamma = 0.99
    learning_rate = 1e-3
    batch_size = 32
    capacity = 10000
    window_len = 3  # LSTM sequence length (history window)

    # CPT parameters
    theta = 0.5
    lam = 3.7183

    # du_caches = [
    #     CacheEngineEnv(
    #         n_users=n_users,
    #         n_videos=n_videos,
    #         n_layers=n_layers,
    #         n_tiles=n_tiles,
    #         n_gops=n_gops,
    #         cache_capacity=max_capacity,
    #     ) for _ in range(n_nodes)
    # ]
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=n_users,
        n_videos=n_videos,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n_gops=n_gops,
        cache_capacity=max_capacity,
        # policy=SvcLruPolicy(max_size=max_capacity)
    )

    # Initialize User Environment
    users_env = UserTileRequestEvents(
        n_nodes=n_nodes,
        n_users=n_users,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n=n,
        m=m,
        users_viewport_tiles=None,
        requested_videos=None,
        users_arrivals=None,
        arrival_rate=arrival_rate,
        alpha=alpha
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,  # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),    # 160 Mbps -> 20e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,  # 1 ms
        mec_fixed_delay=0.005, # 5 ms
        cloud_fixed_delay=0.1  # 100 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=theta,
        lam=lam
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    agent = DQNAgent(
        n_tiles=n_tiles, 
        seq_len=window_len,
        learning_rate=learning_rate,
        gamma=gamma,
        batch_size=batch_size,
        capacity=capacity,
        epsilon_start=epsilon_start,
        epsilon_min=epsilon_min,
        epsilon_decay=epsilon_decay
    )

    results = []
    scores = []
    cache_log = [] # Track active users per step

    for ep in range(n_episodes):

        obs, info = env.reset()

        user_histories = {
            u: deque(maxlen=window_len) for u in range(n_users)
        }
        for u in range(n_users):
            for _ in range(window_len):
                user_histories[u].append(np.zeros(n*m, dtype=int))

        cache_hits = 0
        cache_misses = 0
        enhanced_layer_cache_hits = 0
        enhanced_layer_cache_misses = 0
        base_layer_cache_hits = 0
        base_layer_cache_misses = 0
        total_reward = 0.0
        avg_psnr = []

        for step in count():

            # --- AGENT ACTIONS ---
            reqs_state = info['users_requests']
            active_users = [
                (
                    req['u'], 
                    req['video'], 
                    req['gop'],
                    info['content_popularity'][0][req['video']] / sum(info['content_popularity'][0])
                ) for req in reqs_state if req['gop'] < n_gops
            ]

            actions = []
            user_action_indices = {}

            for u, video, gop, vid_pop in active_users:
                state = np.array(user_histories[u])
                state = (state, vid_pop)

                # Agent chooses center tile
                center_tile_idx, q_values = agent.select_action(state)
                user_action_indices[u] = center_tile_idx

                if center_tile_idx == n_tiles:
                    predicted_viewport = np.zeros(n*m, dtype=int)
                else:
                    predicted_viewport = index_to_fov_mask(center_idx=center_tile_idx, n=n, m=m)

                actions.append({
                    'user': u,
                    'gop': gop,
                    'video': video,
                    'tiles': predicted_viewport
                })

            # --- STEP ENV ---
            obs, rewards, done, info = env.step(actions)

            total_reward += float(rewards)
            enhanced_layer_cache_hits += info["enh_layer_cache_hits"]
            enhanced_layer_cache_misses += info["enh_layer_cache_misses"]
            base_layer_cache_hits += info["base_layer_cache_hits"]
            base_layer_cache_misses += info["base_layer_cache_misses"]
            avg_psnr.append(info.get("average_psnr", 0.0))

            step_reward = float(rewards) / max(1, len(active_users))

            # --- TRAINING / HISTORY UPDATE ---
            reqs_next_state = info['users_requests']

            for u, video, gop, pop_val in active_users:
                state = (np.array(user_histories[u]), pop_val)

                next_pop_val = info['content_popularity'][0][video]
                next_pop_val = next_pop_val / sum(info['content_popularity'][0])
 
                target_indices = [
                    tile['tile'] 
                    for req in reqs_next_state 
                    if req['u'] == u 
                    for tile in req['tiles'] 
                    if tile['layer'] == 1
                ]
                actual_viewport = np.array([
                    1 if i in target_indices else 0 for i in range(n*m)
                ])
                user_histories[u].append(actual_viewport)
                
                dones = (gop == n_gops)
                
                next_state = np.array(user_histories[u])
                next_state = (next_state, next_pop_val)

                agent.memory.push(
                    state, 
                    user_action_indices[u],
                    step_reward,
                    next_state,
                    dones
                )

            agent.train_step()
            
            if done:
                break

        # Update Target Network and Decay Epsilon
        if ep % 5 == 0:
            agent.update_target_network()

        agent.update_epsilon()
 
        avg_psnr = [x for x in avg_psnr if x != 0.0]

        cache_hits = enhanced_layer_cache_hits + base_layer_cache_hits
        cache_misses = enhanced_layer_cache_misses + base_layer_cache_misses

        print(
            f"Episode {ep+1}/{n_episodes}, "
            f"Total Reward: {total_reward:.2f}, "
            f"cache_hits: {cache_hits}, "
            f"cache_misses: {cache_misses}, "
            f"enh_layer_cache_hits: {enhanced_layer_cache_hits}, "
            f"enh_layer_cache_misses: {enhanced_layer_cache_misses}, "
            f"base_layer_cache_hits: {base_layer_cache_hits}, "
            f"base_layer_cache_misses: {base_layer_cache_misses}, "
            f"Average PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}, "
            f"Epsilon: {agent.epsilon:.4f}"
        )
        
        filename = (
            f"fov_predictor_ct_cp_E{n_episodes}_"
            f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
            f"cap{int(max_capacity/1e6)}MB_AR{arrival_rate}_Z{alpha}.csv"
        )

        save_training_results(
            path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
            # path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
            filename=filename,
            ep=ep,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            enhanced_layer_cache_hits=enhanced_layer_cache_hits,
            enhanced_layer_cache_misses=enhanced_layer_cache_misses,
            base_layer_cache_hits=base_layer_cache_hits,
            base_layer_cache_misses=base_layer_cache_misses,
            avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
            agent=agent
        )

        scores.append(total_reward)

        results.append({
            "episode": ep,
            "total_reward": total_reward,
            "cache_hits": cache_hits,
            "cache_misses": cache_misses,
        })
# Out:
# Experiment ===================
# Total users: 200
# Cache capacity: 500000000.0MB
# Video matrix: 500x2x16
# ==============================
#
# Episode 1/300, Total Reward: 6573.07, cache_hits: 86114, cache_misses: 9886, enh_layer_cache_hits: 14114, enh_layer_cache_misses: 9886, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.9870
# Episode 2/300, Total Reward: 6611.48, cache_hits: 86022, cache_misses: 9978, enh_layer_cache_hits: 14022, enh_layer_cache_misses: 9978, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.9742
# Episode 3/300, Total Reward: 6584.99, cache_hits: 86031, cache_misses: 9969, enh_layer_cache_hits: 14031, enh_layer_cache_misses: 9969, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.9615
# Episode 4/300, Total Reward: 6846.16, cache_hits: 86411, cache_misses: 9589, enh_layer_cache_hits: 14411, enh_layer_cache_misses: 9589, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.9490
# Episode 5/300, Total Reward: 6803.09, cache_hits: 86426, cache_misses: 9574, enh_layer_cache_hits: 14426, enh_layer_cache_misses: 9574, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68, Epsilon: 0.9367
# Episode 6/300, Total Reward: 7018.72, cache_hits: 86729, cache_misses: 9271, enh_layer_cache_hits: 14729, enh_layer_cache_misses: 9271, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.9245
# Episode 7/300, Total Reward: 6664.88, cache_hits: 86513, cache_misses: 9487, enh_layer_cache_hits: 14513, enh_layer_cache_misses: 9487, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.66, Epsilon: 0.9125
# Episode 8/300, Total Reward: 6900.99, cache_hits: 86685, cache_misses: 9315, enh_layer_cache_hits: 14685, enh_layer_cache_misses: 9315, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.9006
# Episode 9/300, Total Reward: 6636.07, cache_hits: 86889, cache_misses: 9111, enh_layer_cache_hits: 14889, enh_layer_cache_misses: 9111, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.60, Epsilon: 0.8889
# Episode 10/300, Total Reward: 7180.28, cache_hits: 86906, cache_misses: 9094, enh_layer_cache_hits: 14906, enh_layer_cache_misses: 9094, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.8773
# Episode 11/300, Total Reward: 7297.67, cache_hits: 87362, cache_misses: 8638, enh_layer_cache_hits: 15362, enh_layer_cache_misses: 8638, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.8659
# Episode 12/300, Total Reward: 7187.09, cache_hits: 86997, cache_misses: 9003, enh_layer_cache_hits: 14997, enh_layer_cache_misses: 9003, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.8547
# Episode 13/300, Total Reward: 7177.74, cache_hits: 87087, cache_misses: 8913, enh_layer_cache_hits: 15087, enh_layer_cache_misses: 8913, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.8436
# Episode 14/300, Total Reward: 7250.32, cache_hits: 87238, cache_misses: 8762, enh_layer_cache_hits: 15238, enh_layer_cache_misses: 8762, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.8326
# Episode 15/300, Total Reward: 7529.02, cache_hits: 87398, cache_misses: 8602, enh_layer_cache_hits: 15398, enh_layer_cache_misses: 8602, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.8218
# Episode 16/300, Total Reward: 7674.33, cache_hits: 87744, cache_misses: 8256, enh_layer_cache_hits: 15744, enh_layer_cache_misses: 8256, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.8111
# Episode 17/300, Total Reward: 7256.18, cache_hits: 87447, cache_misses: 8553, enh_layer_cache_hits: 15447, enh_layer_cache_misses: 8553, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.8006
# Episode 18/300, Total Reward: 7481.11, cache_hits: 87535, cache_misses: 8465, enh_layer_cache_hits: 15535, enh_layer_cache_misses: 8465, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.7901
# Episode 19/300, Total Reward: 7520.88, cache_hits: 87834, cache_misses: 8166, enh_layer_cache_hits: 15834, enh_layer_cache_misses: 8166, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.7799
# Episode 20/300, Total Reward: 7397.57, cache_hits: 87711, cache_misses: 8289, enh_layer_cache_hits: 15711, enh_layer_cache_misses: 8289, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.7697
# Episode 21/300, Total Reward: 7801.72, cache_hits: 88053, cache_misses: 7947, enh_layer_cache_hits: 16053, enh_layer_cache_misses: 7947, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.7597
# Episode 22/300, Total Reward: 7709.29, cache_hits: 87965, cache_misses: 8035, enh_layer_cache_hits: 15965, enh_layer_cache_misses: 8035, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.7499
# Episode 23/300, Total Reward: 7808.13, cache_hits: 88009, cache_misses: 7991, enh_layer_cache_hits: 16009, enh_layer_cache_misses: 7991, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.7401
# Episode 24/300, Total Reward: 7892.96, cache_hits: 88191, cache_misses: 7809, enh_layer_cache_hits: 16191, enh_layer_cache_misses: 7809, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.7305
# Episode 25/300, Total Reward: 8005.63, cache_hits: 88398, cache_misses: 7602, enh_layer_cache_hits: 16398, enh_layer_cache_misses: 7602, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.7210
# Episode 26/300, Total Reward: 7770.50, cache_hits: 88285, cache_misses: 7715, enh_layer_cache_hits: 16285, enh_layer_cache_misses: 7715, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.7116
# Episode 27/300, Total Reward: 7754.12, cache_hits: 88302, cache_misses: 7698, enh_layer_cache_hits: 16302, enh_layer_cache_misses: 7698, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.7024
# Episode 28/300, Total Reward: 7954.17, cache_hits: 88282, cache_misses: 7718, enh_layer_cache_hits: 16282, enh_layer_cache_misses: 7718, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.6932
# Episode 29/300, Total Reward: 8067.34, cache_hits: 88598, cache_misses: 7402, enh_layer_cache_hits: 16598, enh_layer_cache_misses: 7402, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.6842
# Episode 30/300, Total Reward: 7911.03, cache_hits: 88488, cache_misses: 7512, enh_layer_cache_hits: 16488, enh_layer_cache_misses: 7512, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.6753
# Episode 31/300, Total Reward: 8196.00, cache_hits: 88737, cache_misses: 7263, enh_layer_cache_hits: 16737, enh_layer_cache_misses: 7263, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.6665
# Episode 32/300, Total Reward: 8193.20, cache_hits: 89027, cache_misses: 6973, enh_layer_cache_hits: 17027, enh_layer_cache_misses: 6973, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67, Epsilon: 0.6579
# Episode 33/300, Total Reward: 8205.85, cache_hits: 88683, cache_misses: 7317, enh_layer_cache_hits: 16683, enh_layer_cache_misses: 7317, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.6493
# Episode 34/300, Total Reward: 8296.36, cache_hits: 88782, cache_misses: 7218, enh_layer_cache_hits: 16782, enh_layer_cache_misses: 7218, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.6409
# Episode 35/300, Total Reward: 8050.54, cache_hits: 88938, cache_misses: 7062, enh_layer_cache_hits: 16938, enh_layer_cache_misses: 7062, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.6326
# Episode 36/300, Total Reward: 8324.78, cache_hits: 89179, cache_misses: 6821, enh_layer_cache_hits: 17179, enh_layer_cache_misses: 6821, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.6243
# Episode 37/300, Total Reward: 8423.87, cache_hits: 89148, cache_misses: 6852, enh_layer_cache_hits: 17148, enh_layer_cache_misses: 6852, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.6162
# Episode 38/300, Total Reward: 8341.11, cache_hits: 89379, cache_misses: 6621, enh_layer_cache_hits: 17379, enh_layer_cache_misses: 6621, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68, Epsilon: 0.6082
# Episode 39/300, Total Reward: 8234.58, cache_hits: 89150, cache_misses: 6850, enh_layer_cache_hits: 17150, enh_layer_cache_misses: 6850, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.6003
# Episode 40/300, Total Reward: 8337.39, cache_hits: 89296, cache_misses: 6704, enh_layer_cache_hits: 17296, enh_layer_cache_misses: 6704, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.5925
# Episode 41/300, Total Reward: 8387.38, cache_hits: 89494, cache_misses: 6506, enh_layer_cache_hits: 17494, enh_layer_cache_misses: 6506, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.5848
# Episode 42/300, Total Reward: 8528.75, cache_hits: 89296, cache_misses: 6704, enh_layer_cache_hits: 17296, enh_layer_cache_misses: 6704, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.5772
# Episode 43/300, Total Reward: 8683.37, cache_hits: 89606, cache_misses: 6394, enh_layer_cache_hits: 17606, enh_layer_cache_misses: 6394, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.5697
# Episode 44/300, Total Reward: 8728.36, cache_hits: 89603, cache_misses: 6397, enh_layer_cache_hits: 17603, enh_layer_cache_misses: 6397, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.5623
# Episode 45/300, Total Reward: 8744.82, cache_hits: 89775, cache_misses: 6225, enh_layer_cache_hits: 17775, enh_layer_cache_misses: 6225, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.5550
# Episode 46/300, Total Reward: 8556.39, cache_hits: 89674, cache_misses: 6326, enh_layer_cache_hits: 17674, enh_layer_cache_misses: 6326, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.5478
# Episode 47/300, Total Reward: 9047.59, cache_hits: 89900, cache_misses: 6100, enh_layer_cache_hits: 17900, enh_layer_cache_misses: 6100, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.5406
# Episode 48/300, Total Reward: 8454.37, cache_hits: 89910, cache_misses: 6090, enh_layer_cache_hits: 17910, enh_layer_cache_misses: 6090, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.5336
# Episode 49/300, Total Reward: 8594.72, cache_hits: 89493, cache_misses: 6507, enh_layer_cache_hits: 17493, enh_layer_cache_misses: 6507, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.5267
# Episode 50/300, Total Reward: 8872.89, cache_hits: 89933, cache_misses: 6067, enh_layer_cache_hits: 17933, enh_layer_cache_misses: 6067, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.5198
# Episode 51/300, Total Reward: 8871.76, cache_hits: 89895, cache_misses: 6105, enh_layer_cache_hits: 17895, enh_layer_cache_misses: 6105, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.5131
# Episode 52/300, Total Reward: 8944.92, cache_hits: 90115, cache_misses: 5885, enh_layer_cache_hits: 18115, enh_layer_cache_misses: 5885, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68, Epsilon: 0.5064
# Episode 53/300, Total Reward: 8798.19, cache_hits: 90210, cache_misses: 5790, enh_layer_cache_hits: 18210, enh_layer_cache_misses: 5790, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.4998
# Episode 54/300, Total Reward: 9055.00, cache_hits: 90330, cache_misses: 5670, enh_layer_cache_hits: 18330, enh_layer_cache_misses: 5670, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.4933
# Episode 55/300, Total Reward: 9114.37, cache_hits: 90289, cache_misses: 5711, enh_layer_cache_hits: 18289, enh_layer_cache_misses: 5711, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.4869
# Episode 56/300, Total Reward: 9071.99, cache_hits: 90350, cache_misses: 5650, enh_layer_cache_hits: 18350, enh_layer_cache_misses: 5650, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.4806
# Episode 57/300, Total Reward: 8741.93, cache_hits: 90223, cache_misses: 5777, enh_layer_cache_hits: 18223, enh_layer_cache_misses: 5777, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.4743
# Episode 58/300, Total Reward: 9133.37, cache_hits: 90254, cache_misses: 5746, enh_layer_cache_hits: 18254, enh_layer_cache_misses: 5746, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.4682
# Episode 59/300, Total Reward: 9218.34, cache_hits: 90477, cache_misses: 5523, enh_layer_cache_hits: 18477, enh_layer_cache_misses: 5523, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.4621
# Episode 60/300, Total Reward: 9086.85, cache_hits: 90737, cache_misses: 5263, enh_layer_cache_hits: 18737, enh_layer_cache_misses: 5263, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.4561
# Episode 61/300, Total Reward: 9240.08, cache_hits: 90760, cache_misses: 5240, enh_layer_cache_hits: 18760, enh_layer_cache_misses: 5240, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.4501
# Episode 62/300, Total Reward: 9481.35, cache_hits: 90654, cache_misses: 5346, enh_layer_cache_hits: 18654, enh_layer_cache_misses: 5346, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.4443
# Episode 63/300, Total Reward: 9213.38, cache_hits: 90752, cache_misses: 5248, enh_layer_cache_hits: 18752, enh_layer_cache_misses: 5248, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68, Epsilon: 0.4385
# Episode 64/300, Total Reward: 9407.24, cache_hits: 90570, cache_misses: 5430, enh_layer_cache_hits: 18570, enh_layer_cache_misses: 5430, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.4328
# Episode 65/300, Total Reward: 9078.27, cache_hits: 90645, cache_misses: 5355, enh_layer_cache_hits: 18645, enh_layer_cache_misses: 5355, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.4272
# Episode 66/300, Total Reward: 8886.43, cache_hits: 90684, cache_misses: 5316, enh_layer_cache_hits: 18684, enh_layer_cache_misses: 5316, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.4216
# Episode 67/300, Total Reward: 9056.95, cache_hits: 90546, cache_misses: 5454, enh_layer_cache_hits: 18546, enh_layer_cache_misses: 5454, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.4161
# Episode 68/300, Total Reward: 9299.36, cache_hits: 91053, cache_misses: 4947, enh_layer_cache_hits: 19053, enh_layer_cache_misses: 4947, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.4107
# Episode 69/300, Total Reward: 9272.03, cache_hits: 90997, cache_misses: 5003, enh_layer_cache_hits: 18997, enh_layer_cache_misses: 5003, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.4054
# Episode 70/300, Total Reward: 9442.43, cache_hits: 90886, cache_misses: 5114, enh_layer_cache_hits: 18886, enh_layer_cache_misses: 5114, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.4001
# Episode 71/300, Total Reward: 9131.68, cache_hits: 90725, cache_misses: 5275, enh_layer_cache_hits: 18725, enh_layer_cache_misses: 5275, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.3949
# Episode 72/300, Total Reward: 9495.73, cache_hits: 91016, cache_misses: 4984, enh_layer_cache_hits: 19016, enh_layer_cache_misses: 4984, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.3898
# Episode 73/300, Total Reward: 9711.63, cache_hits: 91299, cache_misses: 4701, enh_layer_cache_hits: 19299, enh_layer_cache_misses: 4701, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.3847
# Episode 74/300, Total Reward: 9516.35, cache_hits: 91262, cache_misses: 4738, enh_layer_cache_hits: 19262, enh_layer_cache_misses: 4738, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.3797
# Episode 75/300, Total Reward: 9563.27, cache_hits: 91103, cache_misses: 4897, enh_layer_cache_hits: 19103, enh_layer_cache_misses: 4897, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.3748
# Episode 76/300, Total Reward: 9763.41, cache_hits: 91239, cache_misses: 4761, enh_layer_cache_hits: 19239, enh_layer_cache_misses: 4761, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.3699
# Episode 77/300, Total Reward: 9525.34, cache_hits: 91311, cache_misses: 4689, enh_layer_cache_hits: 19311, enh_layer_cache_misses: 4689, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.3651
# Episode 78/300, Total Reward: 9802.10, cache_hits: 91676, cache_misses: 4324, enh_layer_cache_hits: 19676, enh_layer_cache_misses: 4324, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.3604
# Episode 79/300, Total Reward: 9653.57, cache_hits: 91385, cache_misses: 4615, enh_layer_cache_hits: 19385, enh_layer_cache_misses: 4615, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.3557
# Episode 80/300, Total Reward: 9341.48, cache_hits: 91334, cache_misses: 4666, enh_layer_cache_hits: 19334, enh_layer_cache_misses: 4666, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.3511
# Episode 81/300, Total Reward: 9404.45, cache_hits: 91341, cache_misses: 4659, enh_layer_cache_hits: 19341, enh_layer_cache_misses: 4659, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.3465
# Episode 82/300, Total Reward: 9551.25, cache_hits: 91340, cache_misses: 4660, enh_layer_cache_hits: 19340, enh_layer_cache_misses: 4660, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.3420
# Episode 83/300, Total Reward: 9474.51, cache_hits: 91503, cache_misses: 4497, enh_layer_cache_hits: 19503, enh_layer_cache_misses: 4497, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.3375
# Episode 84/300, Total Reward: 9496.96, cache_hits: 91342, cache_misses: 4658, enh_layer_cache_hits: 19342, enh_layer_cache_misses: 4658, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.3332
# Episode 85/300, Total Reward: 9840.05, cache_hits: 91643, cache_misses: 4357, enh_layer_cache_hits: 19643, enh_layer_cache_misses: 4357, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.3288
# Episode 86/300, Total Reward: 9651.78, cache_hits: 91648, cache_misses: 4352, enh_layer_cache_hits: 19648, enh_layer_cache_misses: 4352, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.3245
# Episode 87/300, Total Reward: 9845.63, cache_hits: 91541, cache_misses: 4459, enh_layer_cache_hits: 19541, enh_layer_cache_misses: 4459, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.3203
# Episode 88/300, Total Reward: 10102.54, cache_hits: 91739, cache_misses: 4261, enh_layer_cache_hits: 19739, enh_layer_cache_misses: 4261, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.3162
# Episode 89/300, Total Reward: 9730.77, cache_hits: 91706, cache_misses: 4294, enh_layer_cache_hits: 19706, enh_layer_cache_misses: 4294, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.3121
# Episode 90/300, Total Reward: 9604.18, cache_hits: 91444, cache_misses: 4556, enh_layer_cache_hits: 19444, enh_layer_cache_misses: 4556, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80, Epsilon: 0.3080
# Episode 91/300, Total Reward: 9670.62, cache_hits: 91566, cache_misses: 4434, enh_layer_cache_hits: 19566, enh_layer_cache_misses: 4434, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.3040
# Episode 92/300, Total Reward: 9836.63, cache_hits: 91890, cache_misses: 4110, enh_layer_cache_hits: 19890, enh_layer_cache_misses: 4110, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.3000
# Episode 93/300, Total Reward: 9822.36, cache_hits: 91976, cache_misses: 4024, enh_layer_cache_hits: 19976, enh_layer_cache_misses: 4024, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.2961
# Episode 94/300, Total Reward: 9840.10, cache_hits: 91593, cache_misses: 4407, enh_layer_cache_hits: 19593, enh_layer_cache_misses: 4407, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.2923
# Episode 95/300, Total Reward: 9800.70, cache_hits: 91844, cache_misses: 4156, enh_layer_cache_hits: 19844, enh_layer_cache_misses: 4156, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.2885
# Episode 96/300, Total Reward: 10119.32, cache_hits: 91791, cache_misses: 4209, enh_layer_cache_hits: 19791, enh_layer_cache_misses: 4209, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80, Epsilon: 0.2847
# Episode 97/300, Total Reward: 10178.15, cache_hits: 92055, cache_misses: 3945, enh_layer_cache_hits: 20055, enh_layer_cache_misses: 3945, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.2810
# Episode 98/300, Total Reward: 9719.35, cache_hits: 91842, cache_misses: 4158, enh_layer_cache_hits: 19842, enh_layer_cache_misses: 4158, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.2774
# Episode 99/300, Total Reward: 9883.46, cache_hits: 92214, cache_misses: 3786, enh_layer_cache_hits: 20214, enh_layer_cache_misses: 3786, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.2738
# Episode 100/300, Total Reward: 9969.95, cache_hits: 91957, cache_misses: 4043, enh_layer_cache_hits: 19957, enh_layer_cache_misses: 4043, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.2702
# Episode 101/300, Total Reward: 9751.55, cache_hits: 92097, cache_misses: 3903, enh_layer_cache_hits: 20097, enh_layer_cache_misses: 3903, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.2667
# Episode 102/300, Total Reward: 9856.71, cache_hits: 91754, cache_misses: 4246, enh_layer_cache_hits: 19754, enh_layer_cache_misses: 4246, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.2632
# Episode 103/300, Total Reward: 10113.52, cache_hits: 91997, cache_misses: 4003, enh_layer_cache_hits: 19997, enh_layer_cache_misses: 4003, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.2598
# Episode 104/300, Total Reward: 10169.12, cache_hits: 92290, cache_misses: 3710, enh_layer_cache_hits: 20290, enh_layer_cache_misses: 3710, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.2564
# Episode 105/300, Total Reward: 10237.78, cache_hits: 92253, cache_misses: 3747, enh_layer_cache_hits: 20253, enh_layer_cache_misses: 3747, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.2531
# Episode 106/300, Total Reward: 9960.59, cache_hits: 92205, cache_misses: 3795, enh_layer_cache_hits: 20205, enh_layer_cache_misses: 3795, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.2498
# Episode 107/300, Total Reward: 10334.55, cache_hits: 92545, cache_misses: 3455, enh_layer_cache_hits: 20545, enh_layer_cache_misses: 3455, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.2466
# Episode 108/300, Total Reward: 10185.31, cache_hits: 92402, cache_misses: 3598, enh_layer_cache_hits: 20402, enh_layer_cache_misses: 3598, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.2434
# Episode 109/300, Total Reward: 10359.01, cache_hits: 92408, cache_misses: 3592, enh_layer_cache_hits: 20408, enh_layer_cache_misses: 3592, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.2402
# Episode 110/300, Total Reward: 10130.27, cache_hits: 92260, cache_misses: 3740, enh_layer_cache_hits: 20260, enh_layer_cache_misses: 3740, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.2371
# Episode 111/300, Total Reward: 10207.76, cache_hits: 92313, cache_misses: 3687, enh_layer_cache_hits: 20313, enh_layer_cache_misses: 3687, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.2340
# Episode 112/300, Total Reward: 10147.88, cache_hits: 92716, cache_misses: 3284, enh_layer_cache_hits: 20716, enh_layer_cache_misses: 3284, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.2310
# Episode 113/300, Total Reward: 9874.39, cache_hits: 91957, cache_misses: 4043, enh_layer_cache_hits: 19957, enh_layer_cache_misses: 4043, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.2279
# Episode 114/300, Total Reward: 10318.05, cache_hits: 92651, cache_misses: 3349, enh_layer_cache_hits: 20651, enh_layer_cache_misses: 3349, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.2250
# Episode 115/300, Total Reward: 10018.30, cache_hits: 92170, cache_misses: 3830, enh_layer_cache_hits: 20170, enh_layer_cache_misses: 3830, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.2221
# Episode 116/300, Total Reward: 10469.00, cache_hits: 92509, cache_misses: 3491, enh_layer_cache_hits: 20509, enh_layer_cache_misses: 3491, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.2192
# Episode 117/300, Total Reward: 10427.27, cache_hits: 92544, cache_misses: 3456, enh_layer_cache_hits: 20544, enh_layer_cache_misses: 3456, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.2163
# Episode 118/300, Total Reward: 10607.18, cache_hits: 92700, cache_misses: 3300, enh_layer_cache_hits: 20700, enh_layer_cache_misses: 3300, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.2135
# Episode 119/300, Total Reward: 10796.48, cache_hits: 92879, cache_misses: 3121, enh_layer_cache_hits: 20879, enh_layer_cache_misses: 3121, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.2107
# Episode 120/300, Total Reward: 10478.38, cache_hits: 92655, cache_misses: 3345, enh_layer_cache_hits: 20655, enh_layer_cache_misses: 3345, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.2080
# Episode 121/300, Total Reward: 10387.31, cache_hits: 92468, cache_misses: 3532, enh_layer_cache_hits: 20468, enh_layer_cache_misses: 3532, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.2053
# Episode 122/300, Total Reward: 10421.25, cache_hits: 92741, cache_misses: 3259, enh_layer_cache_hits: 20741, enh_layer_cache_misses: 3259, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.2026
# Episode 123/300, Total Reward: 10367.39, cache_hits: 92669, cache_misses: 3331, enh_layer_cache_hits: 20669, enh_layer_cache_misses: 3331, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.2000
# Episode 124/300, Total Reward: 10498.74, cache_hits: 92671, cache_misses: 3329, enh_layer_cache_hits: 20671, enh_layer_cache_misses: 3329, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.1974
# Episode 125/300, Total Reward: 10513.32, cache_hits: 92901, cache_misses: 3099, enh_layer_cache_hits: 20901, enh_layer_cache_misses: 3099, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.1948
# Episode 126/300, Total Reward: 10221.75, cache_hits: 92685, cache_misses: 3315, enh_layer_cache_hits: 20685, enh_layer_cache_misses: 3315, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.1923
# Episode 127/300, Total Reward: 10539.63, cache_hits: 92581, cache_misses: 3419, enh_layer_cache_hits: 20581, enh_layer_cache_misses: 3419, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.1898
# Episode 128/300, Total Reward: 10462.00, cache_hits: 92933, cache_misses: 3067, enh_layer_cache_hits: 20933, enh_layer_cache_misses: 3067, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.1873
# Episode 129/300, Total Reward: 10225.32, cache_hits: 92659, cache_misses: 3341, enh_layer_cache_hits: 20659, enh_layer_cache_misses: 3341, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.1849
# Episode 130/300, Total Reward: 10650.89, cache_hits: 93147, cache_misses: 2853, enh_layer_cache_hits: 21147, enh_layer_cache_misses: 2853, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.1825
# Episode 131/300, Total Reward: 10258.61, cache_hits: 92520, cache_misses: 3480, enh_layer_cache_hits: 20520, enh_layer_cache_misses: 3480, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.1801
# Episode 132/300, Total Reward: 10543.28, cache_hits: 92880, cache_misses: 3120, enh_layer_cache_hits: 20880, enh_layer_cache_misses: 3120, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.1778
# Episode 133/300, Total Reward: 10929.05, cache_hits: 93161, cache_misses: 2839, enh_layer_cache_hits: 21161, enh_layer_cache_misses: 2839, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.1755
# Episode 134/300, Total Reward: 10521.02, cache_hits: 92985, cache_misses: 3015, enh_layer_cache_hits: 20985, enh_layer_cache_misses: 3015, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.1732
# Episode 135/300, Total Reward: 10422.52, cache_hits: 93100, cache_misses: 2900, enh_layer_cache_hits: 21100, enh_layer_cache_misses: 2900, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.1709
# Episode 136/300, Total Reward: 10097.86, cache_hits: 92591, cache_misses: 3409, enh_layer_cache_hits: 20591, enh_layer_cache_misses: 3409, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.1687
# Episode 137/300, Total Reward: 10418.96, cache_hits: 93174, cache_misses: 2826, enh_layer_cache_hits: 21174, enh_layer_cache_misses: 2826, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.1665
# Episode 138/300, Total Reward: 10457.97, cache_hits: 92746, cache_misses: 3254, enh_layer_cache_hits: 20746, enh_layer_cache_misses: 3254, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.1643
# Episode 139/300, Total Reward: 10346.22, cache_hits: 92941, cache_misses: 3059, enh_layer_cache_hits: 20941, enh_layer_cache_misses: 3059, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.1622
# Episode 140/300, Total Reward: 10671.44, cache_hits: 93094, cache_misses: 2906, enh_layer_cache_hits: 21094, enh_layer_cache_misses: 2906, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.1601
# Episode 141/300, Total Reward: 10384.39, cache_hits: 92767, cache_misses: 3233, enh_layer_cache_hits: 20767, enh_layer_cache_misses: 3233, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.1580
# Episode 142/300, Total Reward: 10763.69, cache_hits: 92979, cache_misses: 3021, enh_layer_cache_hits: 20979, enh_layer_cache_misses: 3021, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.83, Epsilon: 0.1560
# Episode 143/300, Total Reward: 10329.75, cache_hits: 92939, cache_misses: 3061, enh_layer_cache_hits: 20939, enh_layer_cache_misses: 3061, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68, Epsilon: 0.1539
# Episode 144/300, Total Reward: 10825.21, cache_hits: 93286, cache_misses: 2714, enh_layer_cache_hits: 21286, enh_layer_cache_misses: 2714, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.1519
# Episode 145/300, Total Reward: 10371.84, cache_hits: 92789, cache_misses: 3211, enh_layer_cache_hits: 20789, enh_layer_cache_misses: 3211, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.1500
# Episode 146/300, Total Reward: 10272.35, cache_hits: 93168, cache_misses: 2832, enh_layer_cache_hits: 21168, enh_layer_cache_misses: 2832, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.1480
# Episode 147/300, Total Reward: 10913.21, cache_hits: 93239, cache_misses: 2761, enh_layer_cache_hits: 21239, enh_layer_cache_misses: 2761, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.1461
# Episode 148/300, Total Reward: 10457.53, cache_hits: 93122, cache_misses: 2878, enh_layer_cache_hits: 21122, enh_layer_cache_misses: 2878, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.1442
# Episode 149/300, Total Reward: 10412.49, cache_hits: 93031, cache_misses: 2969, enh_layer_cache_hits: 21031, enh_layer_cache_misses: 2969, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.1423
# Episode 150/300, Total Reward: 11022.68, cache_hits: 93208, cache_misses: 2792, enh_layer_cache_hits: 21208, enh_layer_cache_misses: 2792, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.1405
# Episode 151/300, Total Reward: 10376.36, cache_hits: 93094, cache_misses: 2906, enh_layer_cache_hits: 21094, enh_layer_cache_misses: 2906, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.1386
# Episode 152/300, Total Reward: 10697.56, cache_hits: 93167, cache_misses: 2833, enh_layer_cache_hits: 21167, enh_layer_cache_misses: 2833, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.81, Epsilon: 0.1368
# Episode 153/300, Total Reward: 10647.81, cache_hits: 93189, cache_misses: 2811, enh_layer_cache_hits: 21189, enh_layer_cache_misses: 2811, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.1351
# Episode 154/300, Total Reward: 10646.39, cache_hits: 93106, cache_misses: 2894, enh_layer_cache_hits: 21106, enh_layer_cache_misses: 2894, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.1333
# Episode 155/300, Total Reward: 10702.78, cache_hits: 93213, cache_misses: 2787, enh_layer_cache_hits: 21213, enh_layer_cache_misses: 2787, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69, Epsilon: 0.1316
# Episode 156/300, Total Reward: 10948.75, cache_hits: 93508, cache_misses: 2492, enh_layer_cache_hits: 21508, enh_layer_cache_misses: 2492, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.1299
# Episode 157/300, Total Reward: 10717.73, cache_hits: 93284, cache_misses: 2716, enh_layer_cache_hits: 21284, enh_layer_cache_misses: 2716, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.1282
# Episode 158/300, Total Reward: 10398.92, cache_hits: 93033, cache_misses: 2967, enh_layer_cache_hits: 21033, enh_layer_cache_misses: 2967, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.1265
# Episode 159/300, Total Reward: 10852.53, cache_hits: 93210, cache_misses: 2790, enh_layer_cache_hits: 21210, enh_layer_cache_misses: 2790, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80, Epsilon: 0.1249
# Episode 160/300, Total Reward: 10666.30, cache_hits: 93301, cache_misses: 2699, enh_layer_cache_hits: 21301, enh_layer_cache_misses: 2699, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.1232
# Episode 161/300, Total Reward: 10624.71, cache_hits: 93366, cache_misses: 2634, enh_layer_cache_hits: 21366, enh_layer_cache_misses: 2634, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.1216
# Episode 162/300, Total Reward: 10820.63, cache_hits: 93272, cache_misses: 2728, enh_layer_cache_hits: 21272, enh_layer_cache_misses: 2728, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.1201
# Episode 163/300, Total Reward: 10761.96, cache_hits: 93385, cache_misses: 2615, enh_layer_cache_hits: 21385, enh_layer_cache_misses: 2615, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.1185
# Episode 164/300, Total Reward: 10843.10, cache_hits: 93333, cache_misses: 2667, enh_layer_cache_hits: 21333, enh_layer_cache_misses: 2667, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.81, Epsilon: 0.1170
# Episode 165/300, Total Reward: 10531.14, cache_hits: 93500, cache_misses: 2500, enh_layer_cache_hits: 21500, enh_layer_cache_misses: 2500, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.1154
# Episode 166/300, Total Reward: 10638.25, cache_hits: 93075, cache_misses: 2925, enh_layer_cache_hits: 21075, enh_layer_cache_misses: 2925, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.1139
# Episode 167/300, Total Reward: 11162.88, cache_hits: 93468, cache_misses: 2532, enh_layer_cache_hits: 21468, enh_layer_cache_misses: 2532, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.81, Epsilon: 0.1125
# Episode 168/300, Total Reward: 10931.69, cache_hits: 93551, cache_misses: 2449, enh_layer_cache_hits: 21551, enh_layer_cache_misses: 2449, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.1110
# Episode 169/300, Total Reward: 10774.18, cache_hits: 93426, cache_misses: 2574, enh_layer_cache_hits: 21426, enh_layer_cache_misses: 2574, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.1095
# Episode 170/300, Total Reward: 10545.03, cache_hits: 93673, cache_misses: 2327, enh_layer_cache_hits: 21673, enh_layer_cache_misses: 2327, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.1081
# Episode 171/300, Total Reward: 10384.97, cache_hits: 93142, cache_misses: 2858, enh_layer_cache_hits: 21142, enh_layer_cache_misses: 2858, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.1067
# Episode 172/300, Total Reward: 10562.97, cache_hits: 93210, cache_misses: 2790, enh_layer_cache_hits: 21210, enh_layer_cache_misses: 2790, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.1053
# Episode 173/300, Total Reward: 11099.07, cache_hits: 93716, cache_misses: 2284, enh_layer_cache_hits: 21716, enh_layer_cache_misses: 2284, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.1040
# Episode 174/300, Total Reward: 10975.02, cache_hits: 93692, cache_misses: 2308, enh_layer_cache_hits: 21692, enh_layer_cache_misses: 2308, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.1026
# Episode 175/300, Total Reward: 11047.39, cache_hits: 93694, cache_misses: 2306, enh_layer_cache_hits: 21694, enh_layer_cache_misses: 2306, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.1013
# Episode 176/300, Total Reward: 10904.91, cache_hits: 93445, cache_misses: 2555, enh_layer_cache_hits: 21445, enh_layer_cache_misses: 2555, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.1000
# Episode 177/300, Total Reward: 10932.89, cache_hits: 93722, cache_misses: 2278, enh_layer_cache_hits: 21722, enh_layer_cache_misses: 2278, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0987
# Episode 178/300, Total Reward: 11233.47, cache_hits: 93490, cache_misses: 2510, enh_layer_cache_hits: 21490, enh_layer_cache_misses: 2510, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0974
# Episode 179/300, Total Reward: 11395.46, cache_hits: 93829, cache_misses: 2171, enh_layer_cache_hits: 21829, enh_layer_cache_misses: 2171, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80, Epsilon: 0.0961
# Episode 180/300, Total Reward: 10778.40, cache_hits: 93481, cache_misses: 2519, enh_layer_cache_hits: 21481, enh_layer_cache_misses: 2519, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0949
# Episode 181/300, Total Reward: 10581.38, cache_hits: 93574, cache_misses: 2426, enh_layer_cache_hits: 21574, enh_layer_cache_misses: 2426, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0936
# Episode 182/300, Total Reward: 10955.72, cache_hits: 93614, cache_misses: 2386, enh_layer_cache_hits: 21614, enh_layer_cache_misses: 2386, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0924
# Episode 183/300, Total Reward: 11190.65, cache_hits: 93781, cache_misses: 2219, enh_layer_cache_hits: 21781, enh_layer_cache_misses: 2219, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0912
# Episode 184/300, Total Reward: 10998.92, cache_hits: 93514, cache_misses: 2486, enh_layer_cache_hits: 21514, enh_layer_cache_misses: 2486, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0900
# Episode 185/300, Total Reward: 10592.34, cache_hits: 93538, cache_misses: 2462, enh_layer_cache_hits: 21538, enh_layer_cache_misses: 2462, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.0889
# Episode 186/300, Total Reward: 10609.75, cache_hits: 93193, cache_misses: 2807, enh_layer_cache_hits: 21193, enh_layer_cache_misses: 2807, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68, Epsilon: 0.0877
# Episode 187/300, Total Reward: 10777.71, cache_hits: 93672, cache_misses: 2328, enh_layer_cache_hits: 21672, enh_layer_cache_misses: 2328, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0866
# Episode 188/300, Total Reward: 10966.90, cache_hits: 93635, cache_misses: 2365, enh_layer_cache_hits: 21635, enh_layer_cache_misses: 2365, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0854
# Episode 189/300, Total Reward: 10626.02, cache_hits: 93468, cache_misses: 2532, enh_layer_cache_hits: 21468, enh_layer_cache_misses: 2532, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.0843
# Episode 190/300, Total Reward: 10665.19, cache_hits: 93825, cache_misses: 2175, enh_layer_cache_hits: 21825, enh_layer_cache_misses: 2175, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.0832
# Episode 191/300, Total Reward: 10902.84, cache_hits: 93522, cache_misses: 2478, enh_layer_cache_hits: 21522, enh_layer_cache_misses: 2478, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.0821
# Episode 192/300, Total Reward: 11001.47, cache_hits: 93726, cache_misses: 2274, enh_layer_cache_hits: 21726, enh_layer_cache_misses: 2274, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0811
# Episode 193/300, Total Reward: 10996.34, cache_hits: 93769, cache_misses: 2231, enh_layer_cache_hits: 21769, enh_layer_cache_misses: 2231, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.0800
# Episode 194/300, Total Reward: 10776.92, cache_hits: 93735, cache_misses: 2265, enh_layer_cache_hits: 21735, enh_layer_cache_misses: 2265, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0790
# Episode 195/300, Total Reward: 10968.54, cache_hits: 93799, cache_misses: 2201, enh_layer_cache_hits: 21799, enh_layer_cache_misses: 2201, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0780
# Episode 196/300, Total Reward: 10851.61, cache_hits: 93648, cache_misses: 2352, enh_layer_cache_hits: 21648, enh_layer_cache_misses: 2352, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0769
# Episode 197/300, Total Reward: 10607.98, cache_hits: 93468, cache_misses: 2532, enh_layer_cache_hits: 21468, enh_layer_cache_misses: 2532, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.0759
# Episode 198/300, Total Reward: 10813.09, cache_hits: 93462, cache_misses: 2538, enh_layer_cache_hits: 21462, enh_layer_cache_misses: 2538, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0750
# Episode 199/300, Total Reward: 11234.22, cache_hits: 93893, cache_misses: 2107, enh_layer_cache_hits: 21893, enh_layer_cache_misses: 2107, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0740
# Episode 200/300, Total Reward: 11015.74, cache_hits: 93823, cache_misses: 2177, enh_layer_cache_hits: 21823, enh_layer_cache_misses: 2177, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.0730
# Episode 201/300, Total Reward: 10899.56, cache_hits: 93747, cache_misses: 2253, enh_layer_cache_hits: 21747, enh_layer_cache_misses: 2253, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0721
# Episode 202/300, Total Reward: 11052.60, cache_hits: 93553, cache_misses: 2447, enh_layer_cache_hits: 21553, enh_layer_cache_misses: 2447, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0711
# Episode 203/300, Total Reward: 11010.27, cache_hits: 93824, cache_misses: 2176, enh_layer_cache_hits: 21824, enh_layer_cache_misses: 2176, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0702
# Episode 204/300, Total Reward: 10474.25, cache_hits: 93622, cache_misses: 2378, enh_layer_cache_hits: 21622, enh_layer_cache_misses: 2378, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0693
# Episode 205/300, Total Reward: 10636.06, cache_hits: 93522, cache_misses: 2478, enh_layer_cache_hits: 21522, enh_layer_cache_misses: 2478, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68, Epsilon: 0.0684
# ...
# Episode 233/300, Total Reward: 10860.86, cache_hits: 93609, cache_misses: 2391, enh_layer_cache_hits: 21609, enh_layer_cache_misses: 2391, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0474
# Episode 234/300, Total Reward: 11472.52, cache_hits: 94367, cache_misses: 1633, enh_layer_cache_hits: 22367, enh_layer_cache_misses: 1633, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0468
# Episode 235/300, Total Reward: 11154.20, cache_hits: 93882, cache_misses: 2118, enh_layer_cache_hits: 21882, enh_layer_cache_misses: 2118, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80, Epsilon: 0.0462
# Episode 236/300, Total Reward: 11385.95, cache_hits: 94127, cache_misses: 1873, enh_layer_cache_hits: 22127, enh_layer_cache_misses: 1873, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.0456
# Episode 237/300, Total Reward: 11248.72, cache_hits: 94199, cache_misses: 1801, enh_layer_cache_hits: 22199, enh_layer_cache_misses: 1801, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0450
# Episode 238/300, Total Reward: 10965.71, cache_hits: 93938, cache_misses: 2062, enh_layer_cache_hits: 21938, enh_layer_cache_misses: 2062, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0444
# Episode 239/300, Total Reward: 11082.28, cache_hits: 93783, cache_misses: 2217, enh_layer_cache_hits: 21783, enh_layer_cache_misses: 2217, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0438
# Episode 240/300, Total Reward: 10944.51, cache_hits: 94123, cache_misses: 1877, enh_layer_cache_hits: 22123, enh_layer_cache_misses: 1877, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0433
# Episode 241/300, Total Reward: 10390.27, cache_hits: 93442, cache_misses: 2558, enh_layer_cache_hits: 21442, enh_layer_cache_misses: 2558, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0427
# Episode 242/300, Total Reward: 11185.94, cache_hits: 94132, cache_misses: 1868, enh_layer_cache_hits: 22132, enh_layer_cache_misses: 1868, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0421
# Episode 243/300, Total Reward: 11018.78, cache_hits: 94011, cache_misses: 1989, enh_layer_cache_hits: 22011, enh_layer_cache_misses: 1989, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0416
# Episode 244/300, Total Reward: 10812.46, cache_hits: 93519, cache_misses: 2481, enh_layer_cache_hits: 21519, enh_layer_cache_misses: 2481, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.0411
# Episode 245/300, Total Reward: 11569.08, cache_hits: 94199, cache_misses: 1801, enh_layer_cache_hits: 22199, enh_layer_cache_misses: 1801, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0405
# Episode 246/300, Total Reward: 11453.65, cache_hits: 94149, cache_misses: 1851, enh_layer_cache_hits: 22149, enh_layer_cache_misses: 1851, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0400
# Episode 247/300, Total Reward: 10922.46, cache_hits: 93993, cache_misses: 2007, enh_layer_cache_hits: 21993, enh_layer_cache_misses: 2007, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0395
# Episode 248/300, Total Reward: 10975.34, cache_hits: 94099, cache_misses: 1901, enh_layer_cache_hits: 22099, enh_layer_cache_misses: 1901, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0390
# Episode 249/300, Total Reward: 11118.69, cache_hits: 93860, cache_misses: 2140, enh_layer_cache_hits: 21860, enh_layer_cache_misses: 2140, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.0385
# Episode 250/300, Total Reward: 11209.64, cache_hits: 94257, cache_misses: 1743, enh_layer_cache_hits: 22257, enh_layer_cache_misses: 1743, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.0380
# Episode 251/300, Total Reward: 11397.70, cache_hits: 94008, cache_misses: 1992, enh_layer_cache_hits: 22008, enh_layer_cache_misses: 1992, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.0375
# Episode 252/300, Total Reward: 11246.64, cache_hits: 94239, cache_misses: 1761, enh_layer_cache_hits: 22239, enh_layer_cache_misses: 1761, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0370
# Episode 253/300, Total Reward: 11264.19, cache_hits: 94259, cache_misses: 1741, enh_layer_cache_hits: 22259, enh_layer_cache_misses: 1741, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.0365
# Episode 254/300, Total Reward: 11346.65, cache_hits: 94155, cache_misses: 1845, enh_layer_cache_hits: 22155, enh_layer_cache_misses: 1845, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0360
# Episode 255/300, Total Reward: 11164.66, cache_hits: 94158, cache_misses: 1842, enh_layer_cache_hits: 22158, enh_layer_cache_misses: 1842, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0356
# Episode 256/300, Total Reward: 11061.05, cache_hits: 93928, cache_misses: 2072, enh_layer_cache_hits: 21928, enh_layer_cache_misses: 2072, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.0351
# Episode 257/300, Total Reward: 11022.76, cache_hits: 94104, cache_misses: 1896, enh_layer_cache_hits: 22104, enh_layer_cache_misses: 1896, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.0346
# Episode 258/300, Total Reward: 10963.27, cache_hits: 94053, cache_misses: 1947, enh_layer_cache_hits: 22053, enh_layer_cache_misses: 1947, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.81, Epsilon: 0.0342
# Episode 259/300, Total Reward: 11234.07, cache_hits: 93857, cache_misses: 2143, enh_layer_cache_hits: 21857, enh_layer_cache_misses: 2143, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0337
# Episode 260/300, Total Reward: 10879.09, cache_hits: 94118, cache_misses: 1882, enh_layer_cache_hits: 22118, enh_layer_cache_misses: 1882, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0333
# Episode 261/300, Total Reward: 10967.69, cache_hits: 93920, cache_misses: 2080, enh_layer_cache_hits: 21920, enh_layer_cache_misses: 2080, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.0329
# Episode 262/300, Total Reward: 11066.40, cache_hits: 93883, cache_misses: 2117, enh_layer_cache_hits: 21883, enh_layer_cache_misses: 2117, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0324
# Episode 263/300, Total Reward: 11154.80, cache_hits: 94060, cache_misses: 1940, enh_layer_cache_hits: 22060, enh_layer_cache_misses: 1940, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0320
# Episode 264/300, Total Reward: 11050.30, cache_hits: 94349, cache_misses: 1651, enh_layer_cache_hits: 22349, enh_layer_cache_misses: 1651, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0316
# Episode 265/300, Total Reward: 10760.61, cache_hits: 93964, cache_misses: 2036, enh_layer_cache_hits: 21964, enh_layer_cache_misses: 2036, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70, Epsilon: 0.0312
# Episode 266/300, Total Reward: 10919.02, cache_hits: 93957, cache_misses: 2043, enh_layer_cache_hits: 21957, enh_layer_cache_misses: 2043, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0308
# Episode 267/300, Total Reward: 11640.17, cache_hits: 94514, cache_misses: 1486, enh_layer_cache_hits: 22514, enh_layer_cache_misses: 1486, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.0304
# Episode 268/300, Total Reward: 11326.02, cache_hits: 94209, cache_misses: 1791, enh_layer_cache_hits: 22209, enh_layer_cache_misses: 1791, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0300
# Episode 269/300, Total Reward: 11066.85, cache_hits: 93746, cache_misses: 2254, enh_layer_cache_hits: 21746, enh_layer_cache_misses: 2254, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0296
# Episode 270/300, Total Reward: 11626.96, cache_hits: 94479, cache_misses: 1521, enh_layer_cache_hits: 22479, enh_layer_cache_misses: 1521, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0292
# Episode 271/300, Total Reward: 11067.42, cache_hits: 94108, cache_misses: 1892, enh_layer_cache_hits: 22108, enh_layer_cache_misses: 1892, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0288
# Episode 272/300, Total Reward: 11366.90, cache_hits: 93868, cache_misses: 2132, enh_layer_cache_hits: 21868, enh_layer_cache_misses: 2132, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0285
# Episode 273/300, Total Reward: 10935.67, cache_hits: 93722, cache_misses: 2278, enh_layer_cache_hits: 21722, enh_layer_cache_misses: 2278, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0281
# Episode 274/300, Total Reward: 11140.41, cache_hits: 94211, cache_misses: 1789, enh_layer_cache_hits: 22211, enh_layer_cache_misses: 1789, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0277
# Episode 275/300, Total Reward: 11313.85, cache_hits: 93861, cache_misses: 2139, enh_layer_cache_hits: 21861, enh_layer_cache_misses: 2139, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0274
# Episode 276/300, Total Reward: 11089.24, cache_hits: 93947, cache_misses: 2053, enh_layer_cache_hits: 21947, enh_layer_cache_misses: 2053, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0270
# Episode 277/300, Total Reward: 11421.24, cache_hits: 94229, cache_misses: 1771, enh_layer_cache_hits: 22229, enh_layer_cache_misses: 1771, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0267
# Episode 278/300, Total Reward: 11227.26, cache_hits: 94113, cache_misses: 1887, enh_layer_cache_hits: 22113, enh_layer_cache_misses: 1887, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.0263
# Episode 279/300, Total Reward: 11053.77, cache_hits: 94015, cache_misses: 1985, enh_layer_cache_hits: 22015, enh_layer_cache_misses: 1985, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0260
# Episode 280/300, Total Reward: 11246.66, cache_hits: 94505, cache_misses: 1495, enh_layer_cache_hits: 22505, enh_layer_cache_misses: 1495, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0256
# Episode 281/300, Total Reward: 11203.58, cache_hits: 93925, cache_misses: 2075, enh_layer_cache_hits: 21925, enh_layer_cache_misses: 2075, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.0253
# Episode 282/300, Total Reward: 11820.64, cache_hits: 94159, cache_misses: 1841, enh_layer_cache_hits: 22159, enh_layer_cache_misses: 1841, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0250
# Episode 283/300, Total Reward: 11306.40, cache_hits: 94320, cache_misses: 1680, enh_layer_cache_hits: 22320, enh_layer_cache_misses: 1680, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74, Epsilon: 0.0246
# Episode 284/300, Total Reward: 11303.62, cache_hits: 94283, cache_misses: 1717, enh_layer_cache_hits: 22283, enh_layer_cache_misses: 1717, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.0243
# Episode 285/300, Total Reward: 11260.21, cache_hits: 93954, cache_misses: 2046, enh_layer_cache_hits: 21954, enh_layer_cache_misses: 2046, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0240
# Episode 286/300, Total Reward: 11144.00, cache_hits: 94318, cache_misses: 1682, enh_layer_cache_hits: 22318, enh_layer_cache_misses: 1682, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0237
# Episode 287/300, Total Reward: 11380.78, cache_hits: 94354, cache_misses: 1646, enh_layer_cache_hits: 22354, enh_layer_cache_misses: 1646, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0234
# Episode 288/300, Total Reward: 11219.21, cache_hits: 94038, cache_misses: 1962, enh_layer_cache_hits: 22038, enh_layer_cache_misses: 1962, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73, Epsilon: 0.0231
# Episode 289/300, Total Reward: 11619.95, cache_hits: 94314, cache_misses: 1686, enh_layer_cache_hits: 22314, enh_layer_cache_misses: 1686, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78, Epsilon: 0.0228
# Episode 290/300, Total Reward: 10718.95, cache_hits: 93479, cache_misses: 2521, enh_layer_cache_hits: 21479, enh_layer_cache_misses: 2521, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0225
# Episode 291/300, Total Reward: 11340.31, cache_hits: 94126, cache_misses: 1874, enh_layer_cache_hits: 22126, enh_layer_cache_misses: 1874, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75, Epsilon: 0.0222
# Episode 292/300, Total Reward: 11159.29, cache_hits: 94279, cache_misses: 1721, enh_layer_cache_hits: 22279, enh_layer_cache_misses: 1721, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0219
# Episode 293/300, Total Reward: 11289.95, cache_hits: 94163, cache_misses: 1837, enh_layer_cache_hits: 22163, enh_layer_cache_misses: 1837, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0216
# Episode 294/300, Total Reward: 11076.35, cache_hits: 93976, cache_misses: 2024, enh_layer_cache_hits: 21976, enh_layer_cache_misses: 2024, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0213
# Episode 295/300, Total Reward: 11176.89, cache_hits: 94354, cache_misses: 1646, enh_layer_cache_hits: 22354, enh_layer_cache_misses: 1646, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76, Epsilon: 0.0211
# Episode 296/300, Total Reward: 11303.47, cache_hits: 94502, cache_misses: 1498, enh_layer_cache_hits: 22502, enh_layer_cache_misses: 1498, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0208
# Episode 297/300, Total Reward: 11448.98, cache_hits: 93948, cache_misses: 2052, enh_layer_cache_hits: 21948, enh_layer_cache_misses: 2052, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79, Epsilon: 0.0205
# Episode 298/300, Total Reward: 11207.09, cache_hits: 94284, cache_misses: 1716, enh_layer_cache_hits: 22284, enh_layer_cache_misses: 1716, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71, Epsilon: 0.0203
# Episode 299/300, Total Reward: 11250.48, cache_hits: 94250, cache_misses: 1750, enh_layer_cache_hits: 22250, enh_layer_cache_misses: 1750, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72, Epsilon: 0.0200
# Episode 300/300, Total Reward: 10819.39, cache_hits: 94113, cache_misses: 1887, enh_layer_cache_hits: 22113, enh_layer_cache_misses: 1887, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77, Epsilon: 0.0197

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# 1. Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_yscale('log') 
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# 2. Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_yscale('log') 
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# 3. Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_yscale('log')
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.savefig('/home/eduardo/Workspace/CacheVideoPredict360/Results/training_rewards_v1.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_5511/550198990.py:17: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_5511/550198990.py:27: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_5511/550198990.py:37: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[2].set_ylim(bottom=0)

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.savefig('/home/eduardo/Workspace/CacheVideoPredict360/Results/training_rewards_v2.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
eval_episodes = 100
n = 4
m = 3
results_eval = []
scores_eval = []

for ep in range(eval_episodes):
    obs, info = env.reset()
    user_histories = {
        u: deque([np.zeros(n * m) for _ in range(window_len)], maxlen=window_len)
        for u in range(n_users)
    }

    enhanced_hits = enhanced_misses = 0
    base_hits = base_misses = 0
    total_reward = 0.0
    avg_psnr = []

    for step in count():
        # --- AGENT ACTIONS ---
        reqs_state = info['users_requests']
        active_users = [
            (
                req['u'], 
                req['video'], 
                req['gop'],
                info['content_popularity'][0][req['video']] / sum(info['content_popularity'][0])
            ) for req in reqs_state if req['gop'] < n_gops
        ]

        actions = []
        user_action_indices = {}

        for u, video, gop, vid_pop in active_users:
            state = np.array(user_histories[u])
            state = (state, vid_pop)

            # Agent chooses center tile
            center_tile_idx, q_values = agent.select_action(state)
            user_action_indices[u] = center_tile_idx

            if center_tile_idx == n_tiles:
                predicted_viewport = np.zeros(n*m, dtype=int)
            else:
                predicted_viewport = index_to_fov_mask(center_idx=center_tile_idx, n=n, m=m)

            actions.append({
                'user': u,
                'gop': gop,
                'video': video,
                'tiles': predicted_viewport
            })

        obs, rewards, done, info = env.step(actions)

        total_reward += float(rewards)
        enhanced_hits += info["enh_layer_cache_hits"]
        enhanced_misses += info["enh_layer_cache_misses"]
        base_hits += info["base_layer_cache_hits"]
        base_misses += info["base_layer_cache_misses"]
        avg_psnr.append(info.get("average_psnr", 0.0))

        if done:
            break

    avg_psnr = [x for x in avg_psnr if x != 0.0]
    cache_hits_ep = enhanced_hits + base_hits
    cache_misses_ep = enhanced_misses + base_misses

    print(
        f"Episode {ep+1}/{eval_episodes} | "
        f"Reward: {total_reward:.2f} | "
        f"cache_hits: {cache_hits_ep} | cache_misses: {cache_misses_ep} | "
        f"Enhanced(H/M): {enhanced_hits}/{enhanced_misses} | "
        f"Base(H/M): {base_hits}/{base_misses} | "
        f"Avg PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}"
    )

    scores_eval.append(total_reward)
    results_eval.append(
        {"episode": ep, "cache_hits": cache_hits_ep, "cache_misses": cache_misses_ep, "reward": total_reward}
    )
    
    filename_eval = (
        f"fov_predictor_opt_E{eval_episodes}_"
        f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
        f"cap{int(max_capacity/1e6)}MB_AR{arrival_rate}_Z{alpha}_eval.csv"
    )
    
    save_training_results(
        path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
        # path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
        filename=filename_eval,
        ep=ep,
        total_reward=total_reward,
        cache_hits=cache_hits_ep,
        cache_misses=cache_misses_ep,
        enhanced_layer_cache_hits=enhanced_hits,
        enhanced_layer_cache_misses=enhanced_misses,
        base_layer_cache_hits=base_hits,
        base_layer_cache_misses=base_misses,
        avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
        agent=agent
    )
# Out:
# Episode 1/100 | Reward: 7689.80 | cache_hits: 88137 | cache_misses: 7863 | Enhanced(H/M): 16137/7863 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 2/100 | Reward: 7925.39 | cache_hits: 88544 | cache_misses: 7456 | Enhanced(H/M): 16544/7456 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 3/100 | Reward: 8174.00 | cache_hits: 88549 | cache_misses: 7451 | Enhanced(H/M): 16549/7451 | Base(H/M): 72000/0 | Avg PSNR: 38.70
# Episode 4/100 | Reward: 7838.97 | cache_hits: 88154 | cache_misses: 7846 | Enhanced(H/M): 16154/7846 | Base(H/M): 72000/0 | Avg PSNR: 38.82
# Episode 5/100 | Reward: 7931.37 | cache_hits: 88451 | cache_misses: 7549 | Enhanced(H/M): 16451/7549 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 6/100 | Reward: 8013.56 | cache_hits: 88495 | cache_misses: 7505 | Enhanced(H/M): 16495/7505 | Base(H/M): 72000/0 | Avg PSNR: 38.78
# Episode 7/100 | Reward: 7868.89 | cache_hits: 88352 | cache_misses: 7648 | Enhanced(H/M): 16352/7648 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 8/100 | Reward: 7781.93 | cache_hits: 88312 | cache_misses: 7688 | Enhanced(H/M): 16312/7688 | Base(H/M): 72000/0 | Avg PSNR: 38.76
# Episode 9/100 | Reward: 7793.35 | cache_hits: 88329 | cache_misses: 7671 | Enhanced(H/M): 16329/7671 | Base(H/M): 72000/0 | Avg PSNR: 38.71
# Episode 10/100 | Reward: 7937.57 | cache_hits: 88517 | cache_misses: 7483 | Enhanced(H/M): 16517/7483 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 11/100 | Reward: 7699.94 | cache_hits: 88273 | cache_misses: 7727 | Enhanced(H/M): 16273/7727 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 12/100 | Reward: 8068.46 | cache_hits: 88384 | cache_misses: 7616 | Enhanced(H/M): 16384/7616 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 13/100 | Reward: 7751.35 | cache_hits: 88257 | cache_misses: 7743 | Enhanced(H/M): 16257/7743 | Base(H/M): 72000/0 | Avg PSNR: 38.78
# Episode 14/100 | Reward: 7861.29 | cache_hits: 88373 | cache_misses: 7627 | Enhanced(H/M): 16373/7627 | Base(H/M): 72000/0 | Avg PSNR: 38.76
# Episode 15/100 | Reward: 7724.43 | cache_hits: 88291 | cache_misses: 7709 | Enhanced(H/M): 16291/7709 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 16/100 | Reward: 7645.58 | cache_hits: 88456 | cache_misses: 7544 | Enhanced(H/M): 16456/7544 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 17/100 | Reward: 7962.34 | cache_hits: 88550 | cache_misses: 7450 | Enhanced(H/M): 16550/7450 | Base(H/M): 72000/0 | Avg PSNR: 38.78
# Episode 18/100 | Reward: 7637.77 | cache_hits: 88280 | cache_misses: 7720 | Enhanced(H/M): 16280/7720 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 19/100 | Reward: 8011.71 | cache_hits: 88405 | cache_misses: 7595 | Enhanced(H/M): 16405/7595 | Base(H/M): 72000/0 | Avg PSNR: 38.81
# Episode 20/100 | Reward: 8090.18 | cache_hits: 88437 | cache_misses: 7563 | Enhanced(H/M): 16437/7563 | Base(H/M): 72000/0 | Avg PSNR: 38.78
# Episode 21/100 | Reward: 7671.43 | cache_hits: 88182 | cache_misses: 7818 | Enhanced(H/M): 16182/7818 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 22/100 | Reward: 7691.39 | cache_hits: 88379 | cache_misses: 7621 | Enhanced(H/M): 16379/7621 | Base(H/M): 72000/0 | Avg PSNR: 38.72
# Episode 23/100 | Reward: 7762.18 | cache_hits: 88228 | cache_misses: 7772 | Enhanced(H/M): 16228/7772 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 24/100 | Reward: 8081.83 | cache_hits: 88388 | cache_misses: 7612 | Enhanced(H/M): 16388/7612 | Base(H/M): 72000/0 | Avg PSNR: 38.78
# Episode 25/100 | Reward: 7779.20 | cache_hits: 88373 | cache_misses: 7627 | Enhanced(H/M): 16373/7627 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 26/100 | Reward: 7629.69 | cache_hits: 88190 | cache_misses: 7810 | Enhanced(H/M): 16190/7810 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 27/100 | Reward: 7672.62 | cache_hits: 88318 | cache_misses: 7682 | Enhanced(H/M): 16318/7682 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 28/100 | Reward: 7722.75 | cache_hits: 88073 | cache_misses: 7927 | Enhanced(H/M): 16073/7927 | Base(H/M): 72000/0 | Avg PSNR: 38.78
# Episode 29/100 | Reward: 7602.50 | cache_hits: 88069 | cache_misses: 7931 | Enhanced(H/M): 16069/7931 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 30/100 | Reward: 7852.64 | cache_hits: 88162 | cache_misses: 7838 | Enhanced(H/M): 16162/7838 | Base(H/M): 72000/0 | Avg PSNR: 38.76
# Episode 31/100 | Reward: 7730.32 | cache_hits: 88434 | cache_misses: 7566 | Enhanced(H/M): 16434/7566 | Base(H/M): 72000/0 | Avg PSNR: 38.76
# Episode 32/100 | Reward: 8101.56 | cache_hits: 88460 | cache_misses: 7540 | Enhanced(H/M): 16460/7540 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 33/100 | Reward: 7871.24 | cache_hits: 88514 | cache_misses: 7486 | Enhanced(H/M): 16514/7486 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 34/100 | Reward: 8088.40 | cache_hits: 88429 | cache_misses: 7571 | Enhanced(H/M): 16429/7571 | Base(H/M): 72000/0 | Avg PSNR: 38.80
# Episode 35/100 | Reward: 8060.37 | cache_hits: 88627 | cache_misses: 7373 | Enhanced(H/M): 16627/7373 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 36/100 | Reward: 8017.11 | cache_hits: 88378 | cache_misses: 7622 | Enhanced(H/M): 16378/7622 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 37/100 | Reward: 7579.37 | cache_hits: 88493 | cache_misses: 7507 | Enhanced(H/M): 16493/7507 | Base(H/M): 72000/0 | Avg PSNR: 38.68
# Episode 38/100 | Reward: 7959.30 | cache_hits: 88420 | cache_misses: 7580 | Enhanced(H/M): 16420/7580 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 39/100 | Reward: 7790.11 | cache_hits: 88332 | cache_misses: 7668 | Enhanced(H/M): 16332/7668 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 40/100 | Reward: 7874.40 | cache_hits: 88525 | cache_misses: 7475 | Enhanced(H/M): 16525/7475 | Base(H/M): 72000/0 | Avg PSNR: 38.72
# Episode 41/100 | Reward: 7738.75 | cache_hits: 88228 | cache_misses: 7772 | Enhanced(H/M): 16228/7772 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 42/100 | Reward: 7820.14 | cache_hits: 88326 | cache_misses: 7674 | Enhanced(H/M): 16326/7674 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 43/100 | Reward: 7920.33 | cache_hits: 88403 | cache_misses: 7597 | Enhanced(H/M): 16403/7597 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 44/100 | Reward: 8056.53 | cache_hits: 88372 | cache_misses: 7628 | Enhanced(H/M): 16372/7628 | Base(H/M): 72000/0 | Avg PSNR: 38.81
# Episode 45/100 | Reward: 7801.46 | cache_hits: 88196 | cache_misses: 7804 | Enhanced(H/M): 16196/7804 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 46/100 | Reward: 7956.38 | cache_hits: 88300 | cache_misses: 7700 | Enhanced(H/M): 16300/7700 | Base(H/M): 72000/0 | Avg PSNR: 38.72
# Episode 47/100 | Reward: 8048.12 | cache_hits: 88501 | cache_misses: 7499 | Enhanced(H/M): 16501/7499 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 48/100 | Reward: 7949.13 | cache_hits: 88472 | cache_misses: 7528 | Enhanced(H/M): 16472/7528 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 49/100 | Reward: 7792.93 | cache_hits: 88313 | cache_misses: 7687 | Enhanced(H/M): 16313/7687 | Base(H/M): 72000/0 | Avg PSNR: 38.72
# Episode 50/100 | Reward: 7925.67 | cache_hits: 88324 | cache_misses: 7676 | Enhanced(H/M): 16324/7676 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 51/100 | Reward: 7838.00 | cache_hits: 88385 | cache_misses: 7615 | Enhanced(H/M): 16385/7615 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 52/100 | Reward: 7810.68 | cache_hits: 88366 | cache_misses: 7634 | Enhanced(H/M): 16366/7634 | Base(H/M): 72000/0 | Avg PSNR: 38.72
# Episode 53/100 | Reward: 7772.79 | cache_hits: 88272 | cache_misses: 7728 | Enhanced(H/M): 16272/7728 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 54/100 | Reward: 7876.49 | cache_hits: 88527 | cache_misses: 7473 | Enhanced(H/M): 16527/7473 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 55/100 | Reward: 8092.41 | cache_hits: 88587 | cache_misses: 7413 | Enhanced(H/M): 16587/7413 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 56/100 | Reward: 7782.64 | cache_hits: 88464 | cache_misses: 7536 | Enhanced(H/M): 16464/7536 | Base(H/M): 72000/0 | Avg PSNR: 38.72
# Episode 57/100 | Reward: 8023.55 | cache_hits: 88434 | cache_misses: 7566 | Enhanced(H/M): 16434/7566 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 58/100 | Reward: 7904.94 | cache_hits: 88437 | cache_misses: 7563 | Enhanced(H/M): 16437/7563 | Base(H/M): 72000/0 | Avg PSNR: 38.82
# Episode 59/100 | Reward: 7717.76 | cache_hits: 88295 | cache_misses: 7705 | Enhanced(H/M): 16295/7705 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 60/100 | Reward: 7859.80 | cache_hits: 88266 | cache_misses: 7734 | Enhanced(H/M): 16266/7734 | Base(H/M): 72000/0 | Avg PSNR: 38.78
# Episode 61/100 | Reward: 8106.65 | cache_hits: 88382 | cache_misses: 7618 | Enhanced(H/M): 16382/7618 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 62/100 | Reward: 7830.77 | cache_hits: 88306 | cache_misses: 7694 | Enhanced(H/M): 16306/7694 | Base(H/M): 72000/0 | Avg PSNR: 38.76
# Episode 63/100 | Reward: 7865.13 | cache_hits: 88437 | cache_misses: 7563 | Enhanced(H/M): 16437/7563 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 64/100 | Reward: 7980.32 | cache_hits: 88440 | cache_misses: 7560 | Enhanced(H/M): 16440/7560 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 65/100 | Reward: 7662.48 | cache_hits: 88260 | cache_misses: 7740 | Enhanced(H/M): 16260/7740 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 66/100 | Reward: 7618.28 | cache_hits: 88041 | cache_misses: 7959 | Enhanced(H/M): 16041/7959 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 67/100 | Reward: 8018.85 | cache_hits: 88706 | cache_misses: 7294 | Enhanced(H/M): 16706/7294 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 68/100 | Reward: 7766.36 | cache_hits: 88392 | cache_misses: 7608 | Enhanced(H/M): 16392/7608 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 69/100 | Reward: 7759.64 | cache_hits: 88309 | cache_misses: 7691 | Enhanced(H/M): 16309/7691 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 70/100 | Reward: 7711.51 | cache_hits: 88500 | cache_misses: 7500 | Enhanced(H/M): 16500/7500 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 71/100 | Reward: 8031.30 | cache_hits: 88312 | cache_misses: 7688 | Enhanced(H/M): 16312/7688 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 72/100 | Reward: 7819.66 | cache_hits: 88346 | cache_misses: 7654 | Enhanced(H/M): 16346/7654 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 73/100 | Reward: 7944.39 | cache_hits: 88475 | cache_misses: 7525 | Enhanced(H/M): 16475/7525 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 74/100 | Reward: 7766.84 | cache_hits: 88229 | cache_misses: 7771 | Enhanced(H/M): 16229/7771 | Base(H/M): 72000/0 | Avg PSNR: 38.76
# Episode 75/100 | Reward: 7835.03 | cache_hits: 88158 | cache_misses: 7842 | Enhanced(H/M): 16158/7842 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 76/100 | Reward: 7841.82 | cache_hits: 88339 | cache_misses: 7661 | Enhanced(H/M): 16339/7661 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 77/100 | Reward: 7794.69 | cache_hits: 88337 | cache_misses: 7663 | Enhanced(H/M): 16337/7663 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 78/100 | Reward: 7855.68 | cache_hits: 88309 | cache_misses: 7691 | Enhanced(H/M): 16309/7691 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 79/100 | Reward: 7742.03 | cache_hits: 88311 | cache_misses: 7689 | Enhanced(H/M): 16311/7689 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 80/100 | Reward: 7698.79 | cache_hits: 88311 | cache_misses: 7689 | Enhanced(H/M): 16311/7689 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 81/100 | Reward: 7947.79 | cache_hits: 88384 | cache_misses: 7616 | Enhanced(H/M): 16384/7616 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 82/100 | Reward: 7715.39 | cache_hits: 88073 | cache_misses: 7927 | Enhanced(H/M): 16073/7927 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 83/100 | Reward: 7963.17 | cache_hits: 88546 | cache_misses: 7454 | Enhanced(H/M): 16546/7454 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 84/100 | Reward: 8020.02 | cache_hits: 88479 | cache_misses: 7521 | Enhanced(H/M): 16479/7521 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 85/100 | Reward: 8005.54 | cache_hits: 88530 | cache_misses: 7470 | Enhanced(H/M): 16530/7470 | Base(H/M): 72000/0 | Avg PSNR: 38.77
# Episode 86/100 | Reward: 7966.92 | cache_hits: 88439 | cache_misses: 7561 | Enhanced(H/M): 16439/7561 | Base(H/M): 72000/0 | Avg PSNR: 38.69
# Episode 87/100 | Reward: 7870.64 | cache_hits: 88353 | cache_misses: 7647 | Enhanced(H/M): 16353/7647 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 88/100 | Reward: 8136.47 | cache_hits: 88599 | cache_misses: 7401 | Enhanced(H/M): 16599/7401 | Base(H/M): 72000/0 | Avg PSNR: 38.75
# Episode 89/100 | Reward: 7792.03 | cache_hits: 88202 | cache_misses: 7798 | Enhanced(H/M): 16202/7798 | Base(H/M): 72000/0 | Avg PSNR: 38.71
# Episode 90/100 | Reward: 8015.91 | cache_hits: 88334 | cache_misses: 7666 | Enhanced(H/M): 16334/7666 | Base(H/M): 72000/0 | Avg PSNR: 38.71
# Episode 91/100 | Reward: 8038.31 | cache_hits: 88667 | cache_misses: 7333 | Enhanced(H/M): 16667/7333 | Base(H/M): 72000/0 | Avg PSNR: 38.74
# Episode 92/100 | Reward: 8029.07 | cache_hits: 88311 | cache_misses: 7689 | Enhanced(H/M): 16311/7689 | Base(H/M): 72000/0 | Avg PSNR: 38.76
# Episode 93/100 | Reward: 7799.41 | cache_hits: 88377 | cache_misses: 7623 | Enhanced(H/M): 16377/7623 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 94/100 | Reward: 7965.37 | cache_hits: 88567 | cache_misses: 7433 | Enhanced(H/M): 16567/7433 | Base(H/M): 72000/0 | Avg PSNR: 38.69
# Episode 95/100 | Reward: 7892.54 | cache_hits: 88276 | cache_misses: 7724 | Enhanced(H/M): 16276/7724 | Base(H/M): 72000/0 | Avg PSNR: 38.73
# Episode 96/100 | Reward: 7815.72 | cache_hits: 88325 | cache_misses: 7675 | Enhanced(H/M): 16325/7675 | Base(H/M): 72000/0 | Avg PSNR: 38.79
# Episode 97/100 | Reward: 7837.67 | cache_hits: 88524 | cache_misses: 7476 | Enhanced(H/M): 16524/7476 | Base(H/M): 72000/0 | Avg PSNR: 38.71
# Episode 98/100 | Reward: 7984.12 | cache_hits: 88614 | cache_misses: 7386 | Enhanced(H/M): 16614/7386 | Base(H/M): 72000/0 | Avg PSNR: 38.76
# Episode 99/100 | Reward: 7957.79 | cache_hits: 88458 | cache_misses: 7542 | Enhanced(H/M): 16458/7542 | Base(H/M): 72000/0 | Avg PSNR: 38.71
# Episode 100/100 | Reward: 7563.26 | cache_hits: 88185 | cache_misses: 7815 | Enhanced(H/M): 16185/7815 | Base(H/M): 72000/0 | Avg PSNR: 38.71

# %%
def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]
    base_totals = [h + m for h, m in zip(base_hits, base_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]
    base_hit_rate = [safe_pct(h, t) for h, t in zip(base_hits, base_totals)]
    base_miss_rate = [safe_pct(m, t) for m, t in zip(base_misses, base_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)
    base_ylim = (0, 100)

    fig, axes = plt.subplots(3, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Base Layer: Hit rate
    axes[1, 0].plot(episodes, base_hit_rate, label="Base hit rate (%)", color="green", alpha=0.9)
    axes[1, 0].set_title("Base Layer Hit Rate")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Rate (%)")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Base Layer: Miss rate
    axes[1, 1].plot(episodes, base_miss_rate, label="Base miss rate (%)", color="orange", alpha=0.9)
    axes[1, 1].set_title("Base Layer Miss Rate")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Rate (%)")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    # Reward title
    axes[2, 0].plot(episodes, rewards, label="Episode reward", color="purple", alpha=0.9)
    axes[2, 0].set_title("Episode Rewards")
    axes[2, 0].set_xlabel("Episode")
    axes[2, 0].set_ylabel("Reward")
    axes[2, 0].grid(True, alpha=0.3)
    axes[2, 0].legend()

    # Average PSNR
    axes[2, 1].plot(episodes, psnr, label="Average PSNR", color="brown", alpha=0.9)
    axes[2, 1].set_title("Average PSNR per Episode")
    axes[2, 1].set_xlabel("Episode")
    axes[2, 1].set_ylabel("PSNR (dB)")
    axes[2, 1].grid(True, alpha=0.3)
    axes[2, 1].legend()


    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath += '/fov_predictor_ct_cp_E300_U200_V500_G30_L2_N4_cap500MB_AR10.0_Z1.0.csv'

    # csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    # csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.0.csv'
    
    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path='/home/eduardo/Workspace/CacheVideoPredict360/Results/cache_layers_analysis.png', 
        title=title
    )

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Reward title
    axes[1, 0].plot(episodes, rewards, label="Episode reward", color="purple", alpha=0.9)
    axes[1, 0].set_title("Episode Rewards")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Reward")
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Average PSNR
    axes[1, 1].plot(episodes, psnr, label="Average PSNR", color="brown", alpha=0.9)
    axes[1, 1].set_title("Average PSNR per Episode")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("PSNR (dB)")
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    # csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += '/fov_predictor_ct_cp_E200_U200_V500_G60_L2_N4_cap500MB_AR10.0.csv'
    
    out_path = '/home/eduardo/Workspace/CacheVideoPredict360/Results/cache_layers_v2.png'

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=out_path, 
        title=title
    )

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # csv_path_lsr = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    # csv_path_lsr += r'\fov_lsr_U100_V100_G60_L2_N4_cap500MB_AR15.csv'

    csv_path_lsr = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_path_lsr += '/fov_lsr_U200_V500_G30_L2_N4_cap500MB_AR15_Z0.5.csv'
    episodes_lsr, enhanced_hits_lsr, enhanced_misses_lsr, base_hits_lsr, base_misses_lsr, rewards_lsr, psnr_lsr = read_results(csv_path_lsr)

    csv_path_eval = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_path_eval += '/fov_predictor_opt_E100_U200_V500_G30_L2_N4_cap500MB_AR10.0_Z0.5_eval.csv'
    episodes_eval, enhanced_hits_eval, enhanced_misses_eval, base_hits_eval, base_misses_eval, rewards_eval, psnr_eval = read_results(csv_path_eval)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Enhanced Layer: Hit rate
    axes[0].plot(episodes, enh_hit_rate, label="DRL-LRU", color="blue", alpha=0.9)
    axes[0].plot(episodes_lsr, [safe_pct(h, h + m) for h, m in zip(enhanced_hits_lsr, enhanced_misses_lsr)], label="LSR-LRU", color="red")
    axes[0].plot(episodes_eval, [safe_pct(h, h + m) for h, m in zip(enhanced_hits_eval, enhanced_misses_eval)], label="DRL-LRU (Opt)", color="green")
    axes[0].set_title("Enhanced Layer Hit Rate")
    axes[0].set_xlabel("Episode")
    axes[0].set_ylabel("Rate (%)")
    axes[0].set_ylim(enh_ylim)
    axes[0].grid(True, alpha=0.3)
    axes[0].legend()

    # Enhanced Layer: Miss rate
    axes[1].plot(episodes, enh_miss_rate, label="DRL-LRU", color="blue", alpha=0.9)
    axes[1].plot(episodes_lsr, [safe_pct(m, h + m) for h, m in zip(enhanced_hits_lsr, enhanced_misses_lsr)], label="LSR-LRU", color="red")
    axes[1].plot(episodes_eval, [safe_pct(m, h + m) for h, m in zip(enhanced_hits_eval, enhanced_misses_eval)], label="DRL-LRU (Opt)", color="green")
    axes[1].set_title("Enhanced Layer Miss Rate")
    axes[1].set_xlabel("Episode")
    axes[1].set_ylabel("Rate (%)")
    axes[1].set_ylim(enh_ylim)
    axes[1].grid(True, alpha=0.3)
    axes[1].legend()

    # Reward title        self.tile_size_bytes = {

    axes[2].plot(episodes, rewards, label="DRL-LRU", color="blue", alpha=0.9)
    axes[2].set_title("Rewards")
    axes[2].set_xlabel("Episode")
    axes[2].set_ylabel("Reward")
    axes[2].grid(True, alpha=0.3)
    axes[2].legend()

    # Average PSNR
    # axes[1].plot(episodes, psnr, label="DRL-LRU", color="blue", alpha=0.9)
    # axes[1].plot(episodes_lsr, psnr_lsr, label="LSR-LRU", color="red")
    # axes[1].set_title("Average PSNR")
    # axes[1].set_xlabel("Episode")
    # axes[1].set_ylabel("PSNR (dB)")
    # axes[1].grid(True, alpha=0.3)
    # axes[1].legend()
    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    # csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.csv'
    
    csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath += '/fov_predictor_ct_cp_E300_U200_V500_G30_L2_N4_cap500MB_AR10.0_Z0.5.csv'
    
    out_path = '/home/eduardo/Workspace/CacheVideoPredict360/Results/drl_vs_lsr_comparison_ar15_Z0.5.png'

    title = "FOV Predictor Double DQN Agent Cache Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=out_path, 
        title=title
    )
