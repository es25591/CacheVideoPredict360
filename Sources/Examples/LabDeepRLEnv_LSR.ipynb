# %%
import math
import csv
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from time import sleep
from collections import deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv
    from LabUserTileRequest import UserTileRequestEvents
    from LabEnvWrapper import EnvWrapper

import sys
# sys.path.append(r'c:\Users\es25591\Workspace\CacheVideoPredict360\Sources')
sys.path.append('/home/eduardo/Workspace/CacheVideoPredict360/Sources')
from Common.Utils import save_training_results

# %%
# Check PyTorch GPU availability and basic operation
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Using device: {torch.cuda.get_device_name(torch.cuda.current_device())}")
    x = torch.randn(2, 2, device="cuda")
    y = torch.randn(2, 2, device="cuda")
    print("Sample CUDA tensor sum:\n", (x + y))
else:
    print("GPU not detected; running on CPU.")
# Out:
# CUDA available: False
# GPU not detected; running on CPU.

# %%
class LastSampleReplication:
    def __init__(self, n, n_users):
        self.n = n
        self.n_users = n_users
        
        self.usersMap = np.array([[] for i in range(n_users)])
    
    def select_tiles_to_prefetch(self, state):
        n_tiles = self.n * self.n
        actions = []
        for user_id in range(self.n_users):
            user_state = state[user_id]
            last_sampled_tiles = user_state['last_sampled_tiles']
            action = np.zeros(n_tiles)
            for tile_idx in last_sampled_tiles:
                action[tile_idx] = 1
            actions.append(action)
        return actions

# %%
if __name__ == "__main__":
    n_episodes = 200
    n_nodes = 10
    n_users = 100
    step_size = 10
    arrival_rate = 15.0  # users per second
    alpha = 2.0
    n_videos = 100
    n_gops = 60
    n_layers = 2
    n = 4
    n_tiles = n * n
    max_capacity = 500e6  # 500 MB

    # Hyperparameters for RL
    epsilon_start = 1.0
    epsilon_min = 0.05
    epsilon_decay = 0.985
    gamma = 0.99
    learning_rate = 1e-3
    batch_size = 64
    capacity = 10000
    window_len = 5  # LSTM sequence length (history window)

    # CPT parameters
    theta = 0.5
    lam = 3.7183

    # du_caches = [
    #     CacheEngineEnv(
    #         n_users=n_users,
    #         n_videos=n_videos,
    #         n_layers=n_layers,
    #         n_tiles=n_tiles,
    #         n_gops=n_gops,
    #         cache_capacity=max_capacity,
    #     ) for _ in range(n_nodes)
    # ]
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=n_users,
        n_videos=n_videos,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n_gops=n_gops,
        cache_capacity=max_capacity,
    )

    # Initialize User Environment
    users_env = UserTileRequestEvents(
        n_nodes=n_nodes,
        n_users=n_users,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n=n,
        users_viewport_tiles=None,
        requested_videos=None,
        users_arrivals=None,
        arrival_rate=arrival_rate
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,   # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 40e6, dtype=float),    # 320 Mbps -> 40e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,    # 1 ms
        mec_fixed_delay=0.005,   # 5 ms
        cloud_fixed_delay=0.1   # 100 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=theta,
        lam=lam
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    agent = LastSampleReplication(
        n=n,
        n_users=n_users
    )

    results = []
    scores = []
    active_users_log = []  # Track active users per step

    for ep in range(n_episodes):

        obs, info = env.reset()

        cache_hits = 0
        cache_misses = 0
        enhanced_layer_cache_hits = 0
        enhanced_layer_cache_misses = 0
        base_layer_cache_hits = 0
        base_layer_cache_misses = 0
        total_reward = 0.0
        avg_psnr = []

        for step in count():

            # --- AGENT ACTIONS ---
            reqs_state = info['users_requests']
            active_users = [
                (req['u'], req['video'], req['gop']) 
                for req in reqs_state if req['gop'] < n_gops
            ]
            actions = []
            for req in reqs_state:
                u = req['u']
                video = req['video']
                gop = req['gop']

                if gop >= n_gops:
                    continue
                
                tiles = np.zeros(n*n)
                for tile in req['tiles']:
                    tiles[tile['tile']] = 1 if tile['layer'] == 1 else 0

                # chooses tiles
                actions.append({
                    'user': u,
                    'gop': gop,
                    'video': video,
                    'tiles': tiles
                })
                
            # --- STEP ENV ---
            obs, rewards, done, info = env.step(actions)

            total_reward += float(rewards)
            enhanced_layer_cache_hits += info["enh_layer_cache_hits"]
            enhanced_layer_cache_misses += info["enh_layer_cache_misses"]
            base_layer_cache_hits += info["base_layer_cache_hits"]
            base_layer_cache_misses += info["base_layer_cache_misses"]
            avg_psnr.append(info.get("average_psnr", 0.0))

            step_reward = float(rewards) / max(1, len(active_users))
            
            # print(f"Step {step}, Active Users: {len(active_users)}")
            # print(f"Request State: {reqs_state}")
            # print(f"Action: {actions}")
            # print(f"Next Request State: {reqs_next_state}")
            # print(
            #     f"Reward: {rewards}, "
            #     f"Cache Hits: {enhanced_layer_cache_hits + base_layer_cache_hits}, "
            #     f"Cache Misses: {enhanced_layer_cache_misses + base_layer_cache_misses}"
            # )
            # print("-----")
            
            if done:
                break

        avg_psnr = [x for x in avg_psnr if x != 0.0]

        cache_hits = enhanced_layer_cache_hits + base_layer_cache_hits
        cache_misses = enhanced_layer_cache_misses + base_layer_cache_misses

        print(
            f"Episode {ep+1}/{n_episodes}, "
            f"Total Reward: {total_reward:.4f}, "
            f"cache_hits: {cache_hits}, "
            f"cache_misses: {cache_misses}, "
            f"enh_layer_cache_hits: {enhanced_layer_cache_hits}, "
            f"enh_layer_cache_misses: {enhanced_layer_cache_misses}, "
            f"base_layer_cache_hits: {base_layer_cache_hits}, "
            f"base_layer_cache_misses: {base_layer_cache_misses}, "
            f"Average PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}, "
        )

        filename = (
            f"fov_lsr_"
            f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
            f"cap{int(max_capacity/1e6)}MB_AR{int(arrival_rate)}.csv"
        )

        
        save_training_results(
            # path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
            path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
            filename=filename,
            ep=ep,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            enhanced_layer_cache_hits=enhanced_layer_cache_hits,
            enhanced_layer_cache_misses=enhanced_layer_cache_misses,
            base_layer_cache_hits=base_layer_cache_hits,
            base_layer_cache_misses=base_layer_cache_misses,
            avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
            agent=None
        )
        scores.append(total_reward)

        results.append({
            "episode": ep,
            "total_reward": total_reward,
            "cache_hits": cache_hits,
            "cache_misses": cache_misses,
        })
# Out:
# Experiment ===================
# Total users: 100
# Cache capacity: 500000000.0MB
# Video matrix: 100x2x16
# ==============================
#
# Episode 1/200, Total Reward: 10676.2177, cache_hits: 117470, cache_misses: 3303, enh_layer_cache_hits: 21470, enh_layer_cache_misses: 3303, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 2/200, Total Reward: 10833.1008, cache_hits: 117598, cache_misses: 3199, enh_layer_cache_hits: 21598, enh_layer_cache_misses: 3199, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 3/200, Total Reward: 11064.6013, cache_hits: 117402, cache_misses: 3461, enh_layer_cache_hits: 21402, enh_layer_cache_misses: 3461, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 4/200, Total Reward: 10410.0482, cache_hits: 117438, cache_misses: 3372, enh_layer_cache_hits: 21438, enh_layer_cache_misses: 3372, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 5/200, Total Reward: 11057.1122, cache_hits: 117285, cache_misses: 3632, enh_layer_cache_hits: 21285, enh_layer_cache_misses: 3632, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.61,
# Episode 6/200, Total Reward: 10376.5486, cache_hits: 117247, cache_misses: 3559, enh_layer_cache_hits: 21247, enh_layer_cache_misses: 3559, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 7/200, Total Reward: 10415.1306, cache_hits: 116995, cache_misses: 3759, enh_layer_cache_hits: 20995, enh_layer_cache_misses: 3759, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 8/200, Total Reward: 10726.4332, cache_hits: 117474, cache_misses: 3425, enh_layer_cache_hits: 21474, enh_layer_cache_misses: 3425, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.61,
# Episode 9/200, Total Reward: 10907.9095, cache_hits: 117274, cache_misses: 3565, enh_layer_cache_hits: 21274, enh_layer_cache_misses: 3565, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 10/200, Total Reward: 11363.7333, cache_hits: 117451, cache_misses: 3477, enh_layer_cache_hits: 21451, enh_layer_cache_misses: 3477, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 11/200, Total Reward: 10757.4532, cache_hits: 117420, cache_misses: 3473, enh_layer_cache_hits: 21420, enh_layer_cache_misses: 3473, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 12/200, Total Reward: 10593.8781, cache_hits: 117688, cache_misses: 3252, enh_layer_cache_hits: 21688, enh_layer_cache_misses: 3252, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 13/200, Total Reward: 11326.4403, cache_hits: 117318, cache_misses: 3436, enh_layer_cache_hits: 21318, enh_layer_cache_misses: 3436, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 14/200, Total Reward: 10848.9073, cache_hits: 117382, cache_misses: 3361, enh_layer_cache_hits: 21382, enh_layer_cache_misses: 3361, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 15/200, Total Reward: 11072.1198, cache_hits: 117290, cache_misses: 3536, enh_layer_cache_hits: 21290, enh_layer_cache_misses: 3536, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 16/200, Total Reward: 10889.8943, cache_hits: 117597, cache_misses: 3018, enh_layer_cache_hits: 21597, enh_layer_cache_misses: 3018, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 17/200, Total Reward: 10426.2558, cache_hits: 117119, cache_misses: 3769, enh_layer_cache_hits: 21119, enh_layer_cache_misses: 3769, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 18/200, Total Reward: 10603.6030, cache_hits: 117362, cache_misses: 3694, enh_layer_cache_hits: 21362, enh_layer_cache_misses: 3694, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.34,
# Episode 19/200, Total Reward: 10729.9578, cache_hits: 117627, cache_misses: 3221, enh_layer_cache_hits: 21627, enh_layer_cache_misses: 3221, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 20/200, Total Reward: 10470.4737, cache_hits: 117356, cache_misses: 3380, enh_layer_cache_hits: 21356, enh_layer_cache_misses: 3380, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 21/200, Total Reward: 10838.0908, cache_hits: 117511, cache_misses: 3323, enh_layer_cache_hits: 21511, enh_layer_cache_misses: 3323, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 22/200, Total Reward: 10407.8988, cache_hits: 117127, cache_misses: 3714, enh_layer_cache_hits: 21127, enh_layer_cache_misses: 3714, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.33,
# Episode 23/200, Total Reward: 10654.8140, cache_hits: 117486, cache_misses: 3289, enh_layer_cache_hits: 21486, enh_layer_cache_misses: 3289, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 24/200, Total Reward: 10824.1887, cache_hits: 117707, cache_misses: 3286, enh_layer_cache_hits: 21707, enh_layer_cache_misses: 3286, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 25/200, Total Reward: 10703.3682, cache_hits: 117385, cache_misses: 3341, enh_layer_cache_hits: 21385, enh_layer_cache_misses: 3341, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 26/200, Total Reward: 10812.0798, cache_hits: 117344, cache_misses: 3458, enh_layer_cache_hits: 21344, enh_layer_cache_misses: 3458, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 27/200, Total Reward: 10808.8559, cache_hits: 117385, cache_misses: 3580, enh_layer_cache_hits: 21385, enh_layer_cache_misses: 3580, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54,
# Episode 28/200, Total Reward: 10719.1999, cache_hits: 117328, cache_misses: 3420, enh_layer_cache_hits: 21328, enh_layer_cache_misses: 3420, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 29/200, Total Reward: 10500.4790, cache_hits: 117232, cache_misses: 3609, enh_layer_cache_hits: 21232, enh_layer_cache_misses: 3609, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 30/200, Total Reward: 10526.3557, cache_hits: 117117, cache_misses: 3633, enh_layer_cache_hits: 21117, enh_layer_cache_misses: 3633, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 31/200, Total Reward: 11129.8037, cache_hits: 117694, cache_misses: 3171, enh_layer_cache_hits: 21694, enh_layer_cache_misses: 3171, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 32/200, Total Reward: 10985.5884, cache_hits: 117344, cache_misses: 3501, enh_layer_cache_hits: 21344, enh_layer_cache_misses: 3501, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 33/200, Total Reward: 10660.8964, cache_hits: 117177, cache_misses: 3519, enh_layer_cache_hits: 21177, enh_layer_cache_misses: 3519, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 34/200, Total Reward: 11060.4699, cache_hits: 117215, cache_misses: 3614, enh_layer_cache_hits: 21215, enh_layer_cache_misses: 3614, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 35/200, Total Reward: 10906.6422, cache_hits: 117563, cache_misses: 3318, enh_layer_cache_hits: 21563, enh_layer_cache_misses: 3318, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 36/200, Total Reward: 11697.5175, cache_hits: 117337, cache_misses: 3361, enh_layer_cache_hits: 21337, enh_layer_cache_misses: 3361, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 37/200, Total Reward: 11029.8604, cache_hits: 117537, cache_misses: 3311, enh_layer_cache_hits: 21537, enh_layer_cache_misses: 3311, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 38/200, Total Reward: 10583.6400, cache_hits: 117378, cache_misses: 3341, enh_layer_cache_hits: 21378, enh_layer_cache_misses: 3341, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 39/200, Total Reward: 10836.6070, cache_hits: 117370, cache_misses: 3562, enh_layer_cache_hits: 21370, enh_layer_cache_misses: 3562, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 40/200, Total Reward: 10639.1497, cache_hits: 117510, cache_misses: 3385, enh_layer_cache_hits: 21510, enh_layer_cache_misses: 3385, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 41/200, Total Reward: 10434.3278, cache_hits: 117369, cache_misses: 3366, enh_layer_cache_hits: 21369, enh_layer_cache_misses: 3366, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 42/200, Total Reward: 11136.3281, cache_hits: 117609, cache_misses: 3177, enh_layer_cache_hits: 21609, enh_layer_cache_misses: 3177, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 43/200, Total Reward: 10728.2379, cache_hits: 117365, cache_misses: 3544, enh_layer_cache_hits: 21365, enh_layer_cache_misses: 3544, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 44/200, Total Reward: 10978.3516, cache_hits: 117499, cache_misses: 3361, enh_layer_cache_hits: 21499, enh_layer_cache_misses: 3361, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 45/200, Total Reward: 10417.9522, cache_hits: 117296, cache_misses: 3538, enh_layer_cache_hits: 21296, enh_layer_cache_misses: 3538, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 46/200, Total Reward: 10730.7648, cache_hits: 117370, cache_misses: 3461, enh_layer_cache_hits: 21370, enh_layer_cache_misses: 3461, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 47/200, Total Reward: 10838.0279, cache_hits: 117602, cache_misses: 3228, enh_layer_cache_hits: 21602, enh_layer_cache_misses: 3228, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 48/200, Total Reward: 10570.7452, cache_hits: 117705, cache_misses: 3097, enh_layer_cache_hits: 21705, enh_layer_cache_misses: 3097, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 49/200, Total Reward: 10884.6198, cache_hits: 117480, cache_misses: 3531, enh_layer_cache_hits: 21480, enh_layer_cache_misses: 3531, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 50/200, Total Reward: 11148.4593, cache_hits: 117611, cache_misses: 3407, enh_layer_cache_hits: 21611, enh_layer_cache_misses: 3407, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 51/200, Total Reward: 10825.8982, cache_hits: 117512, cache_misses: 3368, enh_layer_cache_hits: 21512, enh_layer_cache_misses: 3368, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 52/200, Total Reward: 10968.5701, cache_hits: 117715, cache_misses: 3157, enh_layer_cache_hits: 21715, enh_layer_cache_misses: 3157, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 53/200, Total Reward: 10643.8130, cache_hits: 117333, cache_misses: 3409, enh_layer_cache_hits: 21333, enh_layer_cache_misses: 3409, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 54/200, Total Reward: 11047.8198, cache_hits: 117592, cache_misses: 3230, enh_layer_cache_hits: 21592, enh_layer_cache_misses: 3230, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 55/200, Total Reward: 10556.0556, cache_hits: 117408, cache_misses: 3466, enh_layer_cache_hits: 21408, enh_layer_cache_misses: 3466, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 56/200, Total Reward: 10706.6452, cache_hits: 117333, cache_misses: 3442, enh_layer_cache_hits: 21333, enh_layer_cache_misses: 3442, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 57/200, Total Reward: 10774.6223, cache_hits: 117479, cache_misses: 3292, enh_layer_cache_hits: 21479, enh_layer_cache_misses: 3292, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 58/200, Total Reward: 10869.6030, cache_hits: 117286, cache_misses: 3530, enh_layer_cache_hits: 21286, enh_layer_cache_misses: 3530, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 59/200, Total Reward: 10534.6318, cache_hits: 117470, cache_misses: 3252, enh_layer_cache_hits: 21470, enh_layer_cache_misses: 3252, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 60/200, Total Reward: 10930.7983, cache_hits: 117462, cache_misses: 3413, enh_layer_cache_hits: 21462, enh_layer_cache_misses: 3413, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 61/200, Total Reward: 11022.2049, cache_hits: 117335, cache_misses: 3422, enh_layer_cache_hits: 21335, enh_layer_cache_misses: 3422, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 62/200, Total Reward: 11135.4929, cache_hits: 117574, cache_misses: 3342, enh_layer_cache_hits: 21574, enh_layer_cache_misses: 3342, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 63/200, Total Reward: 10214.1631, cache_hits: 117127, cache_misses: 3658, enh_layer_cache_hits: 21127, enh_layer_cache_misses: 3658, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 64/200, Total Reward: 11025.4146, cache_hits: 117732, cache_misses: 3090, enh_layer_cache_hits: 21732, enh_layer_cache_misses: 3090, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 65/200, Total Reward: 10734.1417, cache_hits: 117439, cache_misses: 3373, enh_layer_cache_hits: 21439, enh_layer_cache_misses: 3373, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.61,
# Episode 66/200, Total Reward: 10686.2264, cache_hits: 117414, cache_misses: 3560, enh_layer_cache_hits: 21414, enh_layer_cache_misses: 3560, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 67/200, Total Reward: 10480.4220, cache_hits: 117218, cache_misses: 3624, enh_layer_cache_hits: 21218, enh_layer_cache_misses: 3624, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 68/200, Total Reward: 10773.6651, cache_hits: 117387, cache_misses: 3506, enh_layer_cache_hits: 21387, enh_layer_cache_misses: 3506, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 69/200, Total Reward: 11014.1763, cache_hits: 117480, cache_misses: 3371, enh_layer_cache_hits: 21480, enh_layer_cache_misses: 3371, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 70/200, Total Reward: 10645.7544, cache_hits: 117510, cache_misses: 3434, enh_layer_cache_hits: 21510, enh_layer_cache_misses: 3434, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 71/200, Total Reward: 10572.3101, cache_hits: 117637, cache_misses: 3115, enh_layer_cache_hits: 21637, enh_layer_cache_misses: 3115, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 72/200, Total Reward: 10922.0493, cache_hits: 117079, cache_misses: 3715, enh_layer_cache_hits: 21079, enh_layer_cache_misses: 3715, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 73/200, Total Reward: 10454.9045, cache_hits: 117444, cache_misses: 3286, enh_layer_cache_hits: 21444, enh_layer_cache_misses: 3286, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.55,
# Episode 74/200, Total Reward: 10764.3875, cache_hits: 117242, cache_misses: 3691, enh_layer_cache_hits: 21242, enh_layer_cache_misses: 3691, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 75/200, Total Reward: 10879.7015, cache_hits: 117729, cache_misses: 3226, enh_layer_cache_hits: 21729, enh_layer_cache_misses: 3226, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 76/200, Total Reward: 10681.2348, cache_hits: 117500, cache_misses: 3476, enh_layer_cache_hits: 21500, enh_layer_cache_misses: 3476, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 77/200, Total Reward: 10584.7518, cache_hits: 117330, cache_misses: 3643, enh_layer_cache_hits: 21330, enh_layer_cache_misses: 3643, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54,
# Episode 78/200, Total Reward: 10475.5399, cache_hits: 117532, cache_misses: 3318, enh_layer_cache_hits: 21532, enh_layer_cache_misses: 3318, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 79/200, Total Reward: 10516.5829, cache_hits: 117343, cache_misses: 3490, enh_layer_cache_hits: 21343, enh_layer_cache_misses: 3490, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 80/200, Total Reward: 10775.2191, cache_hits: 117424, cache_misses: 3436, enh_layer_cache_hits: 21424, enh_layer_cache_misses: 3436, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 81/200, Total Reward: 10740.3048, cache_hits: 117432, cache_misses: 3472, enh_layer_cache_hits: 21432, enh_layer_cache_misses: 3472, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 82/200, Total Reward: 11210.1502, cache_hits: 117517, cache_misses: 3430, enh_layer_cache_hits: 21517, enh_layer_cache_misses: 3430, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 83/200, Total Reward: 10618.1841, cache_hits: 117347, cache_misses: 3350, enh_layer_cache_hits: 21347, enh_layer_cache_misses: 3350, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.55,
# Episode 84/200, Total Reward: 10532.9002, cache_hits: 117449, cache_misses: 3478, enh_layer_cache_hits: 21449, enh_layer_cache_misses: 3478, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 85/200, Total Reward: 10423.4311, cache_hits: 117386, cache_misses: 3371, enh_layer_cache_hits: 21386, enh_layer_cache_misses: 3371, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 86/200, Total Reward: 11521.5881, cache_hits: 117782, cache_misses: 3163, enh_layer_cache_hits: 21782, enh_layer_cache_misses: 3163, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 87/200, Total Reward: 10621.7599, cache_hits: 117295, cache_misses: 3426, enh_layer_cache_hits: 21295, enh_layer_cache_misses: 3426, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 88/200, Total Reward: 10911.5233, cache_hits: 117726, cache_misses: 3140, enh_layer_cache_hits: 21726, enh_layer_cache_misses: 3140, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 89/200, Total Reward: 10915.5190, cache_hits: 117384, cache_misses: 3446, enh_layer_cache_hits: 21384, enh_layer_cache_misses: 3446, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 90/200, Total Reward: 11189.8941, cache_hits: 117332, cache_misses: 3558, enh_layer_cache_hits: 21332, enh_layer_cache_misses: 3558, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 91/200, Total Reward: 11060.0905, cache_hits: 117352, cache_misses: 3501, enh_layer_cache_hits: 21352, enh_layer_cache_misses: 3501, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.61,
# Episode 92/200, Total Reward: 11366.2066, cache_hits: 117431, cache_misses: 3540, enh_layer_cache_hits: 21431, enh_layer_cache_misses: 3540, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 93/200, Total Reward: 10910.7552, cache_hits: 117475, cache_misses: 3375, enh_layer_cache_hits: 21475, enh_layer_cache_misses: 3375, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 94/200, Total Reward: 10343.2245, cache_hits: 117483, cache_misses: 3574, enh_layer_cache_hits: 21483, enh_layer_cache_misses: 3574, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 95/200, Total Reward: 10895.1121, cache_hits: 117418, cache_misses: 3449, enh_layer_cache_hits: 21418, enh_layer_cache_misses: 3449, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 96/200, Total Reward: 10631.1110, cache_hits: 117325, cache_misses: 3416, enh_layer_cache_hits: 21325, enh_layer_cache_misses: 3416, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 97/200, Total Reward: 10811.0479, cache_hits: 117455, cache_misses: 3245, enh_layer_cache_hits: 21455, enh_layer_cache_misses: 3245, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 98/200, Total Reward: 10197.2666, cache_hits: 117450, cache_misses: 3480, enh_layer_cache_hits: 21450, enh_layer_cache_misses: 3480, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 99/200, Total Reward: 11049.5819, cache_hits: 117290, cache_misses: 3488, enh_layer_cache_hits: 21290, enh_layer_cache_misses: 3488, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 100/200, Total Reward: 10486.6041, cache_hits: 117201, cache_misses: 3717, enh_layer_cache_hits: 21201, enh_layer_cache_misses: 3717, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 101/200, Total Reward: 10656.7431, cache_hits: 117433, cache_misses: 3187, enh_layer_cache_hits: 21433, enh_layer_cache_misses: 3187, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 102/200, Total Reward: 10709.4396, cache_hits: 117314, cache_misses: 3342, enh_layer_cache_hits: 21314, enh_layer_cache_misses: 3342, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.62,
# Episode 103/200, Total Reward: 10623.0229, cache_hits: 117357, cache_misses: 3437, enh_layer_cache_hits: 21357, enh_layer_cache_misses: 3437, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 104/200, Total Reward: 11078.3494, cache_hits: 117631, cache_misses: 3245, enh_layer_cache_hits: 21631, enh_layer_cache_misses: 3245, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 105/200, Total Reward: 11155.4248, cache_hits: 117535, cache_misses: 3401, enh_layer_cache_hits: 21535, enh_layer_cache_misses: 3401, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.61,
# Episode 106/200, Total Reward: 10161.0524, cache_hits: 117351, cache_misses: 3463, enh_layer_cache_hits: 21351, enh_layer_cache_misses: 3463, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 107/200, Total Reward: 10802.7609, cache_hits: 117357, cache_misses: 3385, enh_layer_cache_hits: 21357, enh_layer_cache_misses: 3385, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 108/200, Total Reward: 11317.2691, cache_hits: 117444, cache_misses: 3284, enh_layer_cache_hits: 21444, enh_layer_cache_misses: 3284, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 109/200, Total Reward: 10977.9561, cache_hits: 117730, cache_misses: 3280, enh_layer_cache_hits: 21730, enh_layer_cache_misses: 3280, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 110/200, Total Reward: 10742.6970, cache_hits: 117221, cache_misses: 3617, enh_layer_cache_hits: 21221, enh_layer_cache_misses: 3617, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 111/200, Total Reward: 10909.5509, cache_hits: 117505, cache_misses: 3193, enh_layer_cache_hits: 21505, enh_layer_cache_misses: 3193, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 112/200, Total Reward: 11053.5388, cache_hits: 117731, cache_misses: 3157, enh_layer_cache_hits: 21731, enh_layer_cache_misses: 3157, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 113/200, Total Reward: 10867.2438, cache_hits: 117481, cache_misses: 3348, enh_layer_cache_hits: 21481, enh_layer_cache_misses: 3348, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 114/200, Total Reward: 10658.7746, cache_hits: 117550, cache_misses: 3264, enh_layer_cache_hits: 21550, enh_layer_cache_misses: 3264, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 115/200, Total Reward: 10594.3102, cache_hits: 117534, cache_misses: 3271, enh_layer_cache_hits: 21534, enh_layer_cache_misses: 3271, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 116/200, Total Reward: 10821.9192, cache_hits: 117170, cache_misses: 3499, enh_layer_cache_hits: 21170, enh_layer_cache_misses: 3499, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 117/200, Total Reward: 10870.1522, cache_hits: 117560, cache_misses: 3435, enh_layer_cache_hits: 21560, enh_layer_cache_misses: 3435, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 118/200, Total Reward: 10388.9581, cache_hits: 117229, cache_misses: 3710, enh_layer_cache_hits: 21229, enh_layer_cache_misses: 3710, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 119/200, Total Reward: 11009.3923, cache_hits: 117295, cache_misses: 3612, enh_layer_cache_hits: 21295, enh_layer_cache_misses: 3612, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 120/200, Total Reward: 10978.2482, cache_hits: 117442, cache_misses: 3344, enh_layer_cache_hits: 21442, enh_layer_cache_misses: 3344, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.61,
# Episode 121/200, Total Reward: 10653.4640, cache_hits: 117533, cache_misses: 3379, enh_layer_cache_hits: 21533, enh_layer_cache_misses: 3379, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 122/200, Total Reward: 10954.1661, cache_hits: 117410, cache_misses: 3439, enh_layer_cache_hits: 21410, enh_layer_cache_misses: 3439, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.55,
# Episode 123/200, Total Reward: 10747.1743, cache_hits: 117419, cache_misses: 3282, enh_layer_cache_hits: 21419, enh_layer_cache_misses: 3282, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 124/200, Total Reward: 10461.3128, cache_hits: 117431, cache_misses: 3439, enh_layer_cache_hits: 21431, enh_layer_cache_misses: 3439, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 125/200, Total Reward: 10110.9632, cache_hits: 117150, cache_misses: 3710, enh_layer_cache_hits: 21150, enh_layer_cache_misses: 3710, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.31,
# Episode 126/200, Total Reward: 10970.1230, cache_hits: 117379, cache_misses: 3413, enh_layer_cache_hits: 21379, enh_layer_cache_misses: 3413, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 127/200, Total Reward: 10888.9782, cache_hits: 117764, cache_misses: 3090, enh_layer_cache_hits: 21764, enh_layer_cache_misses: 3090, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 128/200, Total Reward: 10676.1765, cache_hits: 117517, cache_misses: 3382, enh_layer_cache_hits: 21517, enh_layer_cache_misses: 3382, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 129/200, Total Reward: 10857.4986, cache_hits: 117083, cache_misses: 3852, enh_layer_cache_hits: 21083, enh_layer_cache_misses: 3852, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 130/200, Total Reward: 10451.2849, cache_hits: 117454, cache_misses: 3297, enh_layer_cache_hits: 21454, enh_layer_cache_misses: 3297, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 131/200, Total Reward: 10610.5929, cache_hits: 117560, cache_misses: 3267, enh_layer_cache_hits: 21560, enh_layer_cache_misses: 3267, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 132/200, Total Reward: 10969.1812, cache_hits: 117358, cache_misses: 3410, enh_layer_cache_hits: 21358, enh_layer_cache_misses: 3410, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.61,
# Episode 133/200, Total Reward: 10958.4273, cache_hits: 117539, cache_misses: 3127, enh_layer_cache_hits: 21539, enh_layer_cache_misses: 3127, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 134/200, Total Reward: 10435.7880, cache_hits: 117381, cache_misses: 3314, enh_layer_cache_hits: 21381, enh_layer_cache_misses: 3314, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 135/200, Total Reward: 10876.9978, cache_hits: 117524, cache_misses: 3241, enh_layer_cache_hits: 21524, enh_layer_cache_misses: 3241, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 136/200, Total Reward: 10558.9981, cache_hits: 117490, cache_misses: 3266, enh_layer_cache_hits: 21490, enh_layer_cache_misses: 3266, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38,
# Episode 137/200, Total Reward: 10566.0322, cache_hits: 117468, cache_misses: 3357, enh_layer_cache_hits: 21468, enh_layer_cache_misses: 3357, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 138/200, Total Reward: 10669.8449, cache_hits: 117309, cache_misses: 3701, enh_layer_cache_hits: 21309, enh_layer_cache_misses: 3701, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 139/200, Total Reward: 10267.8078, cache_hits: 117221, cache_misses: 3626, enh_layer_cache_hits: 21221, enh_layer_cache_misses: 3626, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38,
# Episode 140/200, Total Reward: 10947.6618, cache_hits: 117392, cache_misses: 3321, enh_layer_cache_hits: 21392, enh_layer_cache_misses: 3321, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 141/200, Total Reward: 11165.1242, cache_hits: 117600, cache_misses: 3340, enh_layer_cache_hits: 21600, enh_layer_cache_misses: 3340, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 142/200, Total Reward: 10345.8013, cache_hits: 117474, cache_misses: 3391, enh_layer_cache_hits: 21474, enh_layer_cache_misses: 3391, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40,
# Episode 143/200, Total Reward: 10342.4895, cache_hits: 117144, cache_misses: 3747, enh_layer_cache_hits: 21144, enh_layer_cache_misses: 3747, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.34,
# Episode 144/200, Total Reward: 10772.6512, cache_hits: 117655, cache_misses: 3250, enh_layer_cache_hits: 21655, enh_layer_cache_misses: 3250, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 145/200, Total Reward: 11485.4603, cache_hits: 117402, cache_misses: 3386, enh_layer_cache_hits: 21402, enh_layer_cache_misses: 3386, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 146/200, Total Reward: 10625.7079, cache_hits: 117283, cache_misses: 3662, enh_layer_cache_hits: 21283, enh_layer_cache_misses: 3662, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 147/200, Total Reward: 10319.4739, cache_hits: 117616, cache_misses: 3213, enh_layer_cache_hits: 21616, enh_layer_cache_misses: 3213, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 148/200, Total Reward: 10686.1496, cache_hits: 117503, cache_misses: 3266, enh_layer_cache_hits: 21503, enh_layer_cache_misses: 3266, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 149/200, Total Reward: 10679.8437, cache_hits: 117391, cache_misses: 3347, enh_layer_cache_hits: 21391, enh_layer_cache_misses: 3347, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 150/200, Total Reward: 10945.8639, cache_hits: 117659, cache_misses: 3297, enh_layer_cache_hits: 21659, enh_layer_cache_misses: 3297, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 151/200, Total Reward: 11054.5713, cache_hits: 117761, cache_misses: 3051, enh_layer_cache_hits: 21761, enh_layer_cache_misses: 3051, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 152/200, Total Reward: 10861.9910, cache_hits: 117439, cache_misses: 3328, enh_layer_cache_hits: 21439, enh_layer_cache_misses: 3328, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 153/200, Total Reward: 11185.5843, cache_hits: 117465, cache_misses: 3334, enh_layer_cache_hits: 21465, enh_layer_cache_misses: 3334, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 154/200, Total Reward: 10761.5278, cache_hits: 117474, cache_misses: 3288, enh_layer_cache_hits: 21474, enh_layer_cache_misses: 3288, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 155/200, Total Reward: 10487.5655, cache_hits: 117292, cache_misses: 3535, enh_layer_cache_hits: 21292, enh_layer_cache_misses: 3535, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 156/200, Total Reward: 10826.4850, cache_hits: 117405, cache_misses: 3276, enh_layer_cache_hits: 21405, enh_layer_cache_misses: 3276, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 157/200, Total Reward: 10775.8797, cache_hits: 117345, cache_misses: 3368, enh_layer_cache_hits: 21345, enh_layer_cache_misses: 3368, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 158/200, Total Reward: 10394.1339, cache_hits: 117394, cache_misses: 3475, enh_layer_cache_hits: 21394, enh_layer_cache_misses: 3475, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 159/200, Total Reward: 10877.6699, cache_hits: 117109, cache_misses: 3715, enh_layer_cache_hits: 21109, enh_layer_cache_misses: 3715, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 160/200, Total Reward: 10716.0312, cache_hits: 117387, cache_misses: 3361, enh_layer_cache_hits: 21387, enh_layer_cache_misses: 3361, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 161/200, Total Reward: 10602.5300, cache_hits: 117265, cache_misses: 3497, enh_layer_cache_hits: 21265, enh_layer_cache_misses: 3497, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 162/200, Total Reward: 10747.3747, cache_hits: 117230, cache_misses: 3467, enh_layer_cache_hits: 21230, enh_layer_cache_misses: 3467, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 163/200, Total Reward: 10737.4507, cache_hits: 117159, cache_misses: 3660, enh_layer_cache_hits: 21159, enh_layer_cache_misses: 3660, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 164/200, Total Reward: 10670.2798, cache_hits: 117637, cache_misses: 3259, enh_layer_cache_hits: 21637, enh_layer_cache_misses: 3259, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.55,
# Episode 165/200, Total Reward: 10656.5131, cache_hits: 117264, cache_misses: 3626, enh_layer_cache_hits: 21264, enh_layer_cache_misses: 3626, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 166/200, Total Reward: 10362.0167, cache_hits: 117364, cache_misses: 3374, enh_layer_cache_hits: 21364, enh_layer_cache_misses: 3374, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 167/200, Total Reward: 10961.0150, cache_hits: 117379, cache_misses: 3384, enh_layer_cache_hits: 21379, enh_layer_cache_misses: 3384, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 168/200, Total Reward: 10988.8676, cache_hits: 117183, cache_misses: 3734, enh_layer_cache_hits: 21183, enh_layer_cache_misses: 3734, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 169/200, Total Reward: 11079.1226, cache_hits: 117487, cache_misses: 3283, enh_layer_cache_hits: 21487, enh_layer_cache_misses: 3283, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 170/200, Total Reward: 10777.4721, cache_hits: 117246, cache_misses: 3503, enh_layer_cache_hits: 21246, enh_layer_cache_misses: 3503, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 171/200, Total Reward: 10416.2927, cache_hits: 117247, cache_misses: 3577, enh_layer_cache_hits: 21247, enh_layer_cache_misses: 3577, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 172/200, Total Reward: 10526.9129, cache_hits: 117413, cache_misses: 3667, enh_layer_cache_hits: 21413, enh_layer_cache_misses: 3667, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 173/200, Total Reward: 10750.3505, cache_hits: 117510, cache_misses: 3258, enh_layer_cache_hits: 21510, enh_layer_cache_misses: 3258, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 174/200, Total Reward: 11083.8717, cache_hits: 117578, cache_misses: 3358, enh_layer_cache_hits: 21578, enh_layer_cache_misses: 3358, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 175/200, Total Reward: 10557.0595, cache_hits: 117314, cache_misses: 3559, enh_layer_cache_hits: 21314, enh_layer_cache_misses: 3559, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 176/200, Total Reward: 11141.3970, cache_hits: 117449, cache_misses: 3377, enh_layer_cache_hits: 21449, enh_layer_cache_misses: 3377, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 177/200, Total Reward: 10571.8226, cache_hits: 117211, cache_misses: 3513, enh_layer_cache_hits: 21211, enh_layer_cache_misses: 3513, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54,
# Episode 178/200, Total Reward: 10991.6796, cache_hits: 117745, cache_misses: 3094, enh_layer_cache_hits: 21745, enh_layer_cache_misses: 3094, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 179/200, Total Reward: 10876.5204, cache_hits: 117637, cache_misses: 3270, enh_layer_cache_hits: 21637, enh_layer_cache_misses: 3270, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 180/200, Total Reward: 10882.6674, cache_hits: 117626, cache_misses: 3209, enh_layer_cache_hits: 21626, enh_layer_cache_misses: 3209, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 181/200, Total Reward: 10937.0577, cache_hits: 117611, cache_misses: 3110, enh_layer_cache_hits: 21611, enh_layer_cache_misses: 3110, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 182/200, Total Reward: 10395.6042, cache_hits: 117029, cache_misses: 3717, enh_layer_cache_hits: 21029, enh_layer_cache_misses: 3717, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 183/200, Total Reward: 10394.8180, cache_hits: 117474, cache_misses: 3425, enh_layer_cache_hits: 21474, enh_layer_cache_misses: 3425, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 184/200, Total Reward: 10757.5831, cache_hits: 117318, cache_misses: 3515, enh_layer_cache_hits: 21318, enh_layer_cache_misses: 3515, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 185/200, Total Reward: 11124.5404, cache_hits: 117568, cache_misses: 3303, enh_layer_cache_hits: 21568, enh_layer_cache_misses: 3303, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.84,
# Episode 186/200, Total Reward: 11246.9489, cache_hits: 117445, cache_misses: 3282, enh_layer_cache_hits: 21445, enh_layer_cache_misses: 3282, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 187/200, Total Reward: 10929.6988, cache_hits: 117660, cache_misses: 3260, enh_layer_cache_hits: 21660, enh_layer_cache_misses: 3260, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 188/200, Total Reward: 11344.5391, cache_hits: 117496, cache_misses: 3386, enh_layer_cache_hits: 21496, enh_layer_cache_misses: 3386, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.61,
# Episode 189/200, Total Reward: 10360.9980, cache_hits: 117218, cache_misses: 3633, enh_layer_cache_hits: 21218, enh_layer_cache_misses: 3633, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 190/200, Total Reward: 11036.0297, cache_hits: 117674, cache_misses: 3318, enh_layer_cache_hits: 21674, enh_layer_cache_misses: 3318, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 191/200, Total Reward: 11040.7457, cache_hits: 117653, cache_misses: 3250, enh_layer_cache_hits: 21653, enh_layer_cache_misses: 3250, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 192/200, Total Reward: 10611.9858, cache_hits: 117409, cache_misses: 3320, enh_layer_cache_hits: 21409, enh_layer_cache_misses: 3320, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 193/200, Total Reward: 10749.5931, cache_hits: 117602, cache_misses: 3466, enh_layer_cache_hits: 21602, enh_layer_cache_misses: 3466, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 194/200, Total Reward: 10344.1174, cache_hits: 117431, cache_misses: 3424, enh_layer_cache_hits: 21431, enh_layer_cache_misses: 3424, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 195/200, Total Reward: 11685.3048, cache_hits: 117646, cache_misses: 3052, enh_layer_cache_hits: 21646, enh_layer_cache_misses: 3052, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 196/200, Total Reward: 11144.3608, cache_hits: 117405, cache_misses: 3331, enh_layer_cache_hits: 21405, enh_layer_cache_misses: 3331, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 197/200, Total Reward: 11076.5323, cache_hits: 117536, cache_misses: 3218, enh_layer_cache_hits: 21536, enh_layer_cache_misses: 3218, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 198/200, Total Reward: 10641.9448, cache_hits: 117322, cache_misses: 3600, enh_layer_cache_hits: 21322, enh_layer_cache_misses: 3600, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 199/200, Total Reward: 10893.4210, cache_hits: 117554, cache_misses: 3196, enh_layer_cache_hits: 21554, enh_layer_cache_misses: 3196, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 200/200, Total Reward: 10336.9576, cache_hits: 117136, cache_misses: 3696, enh_layer_cache_hits: 21136, enh_layer_cache_misses: 3696, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# 1. Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_yscale('log') 
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# 2. Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_yscale('log') 
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# 3. Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_yscale('log')
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\es25591\AppData\Local\Temp\ipykernel_12728\3657158268.py:17: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# C:\Users\es25591\AppData\Local\Temp\ipykernel_12728\3657158268.py:27: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# C:\Users\es25591\AppData\Local\Temp\ipykernel_12728\3657158268.py:37: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[2].set_ylim(bottom=0)

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
        ]
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]
    base_totals = [h + m for h, m in zip(base_hits, base_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]
    base_hit_rate = [safe_pct(h, t) for h, t in zip(base_hits, base_totals)]
    base_miss_rate = [safe_pct(m, t) for m, t in zip(base_misses, base_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)
    base_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Base Layer: Hit rate
    axes[1, 0].plot(episodes, base_hit_rate, label="Base hit rate (%)", color="green", alpha=0.9)
    axes[1, 0].set_title("Base Layer Hit Rate")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Rate (%)")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Base Layer: Miss rate
    axes[1, 1].plot(episodes, base_miss_rate, label="Base miss rate (%)", color="orange", alpha=0.9)
    axes[1, 1].set_title("Base Layer Miss Rate")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Rate (%)")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    # csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap150MB_eps0.05_2.csv'
    csv_filepath += '/fov_predictor_U500_V1000_G60_L2_N4_cap300MB_eps0.05_2.csv'
    
    #out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap150MB_eps0.05_2.png'
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 123
#     119 out_path = None
#     121 title = "FOV Predictor DQN Agent Cache Layers Performance"
# --> 123 plot_cache_layers(
#     124     csv_filepath,
#     125     out_path=None,
#     126     title=title
#     127 )
#
# Cell In[18], line 48, in plot_cache_layers(csv_path, out_path, title)
#      43 def plot_cache_layers(
#      44     csv_path: str,
#      45     out_path: str | None = None,
#      46     title: str | None = None,
#      47 ):
# ---> 48     episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)
#      50     # Compute per-episode percentages
#      51     def safe_pct(num, den):
#
# Cell In[18], line 12, in read_results(csv_path)
#       9 base_misses: List[float] = []
#      11 if not os.path.exists(csv_path):
# ---> 12     raise FileNotFoundError(f"CSV file not found: {csv_path}")
#      14 with open(csv_path, "r", newline="") as f:
#      15     reader = csv.DictReader(f)
#
# FileNotFoundError: CSV file not found: /home/eduardo/Workspace/CacheVideoPredict360/Results/fov_predictor_U500_V1000_G60_L2_N4_cap300MB_eps0.05_2.csv

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
        ]
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)

    # Compute shared y-lims per layer type
    def compute_ylim(a, b, pad=0.05, min_top=1.0):
        top = max(max(a or [0.0]), max(b or [0.0]))
        top = max(min_top, top)
        return (0, top * (1 + pad))

    enh_ylim = compute_ylim(enhanced_hits, enhanced_misses)
    base_ylim = compute_ylim(base_hits, base_misses)

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Plot 1: Enhanced Layer Cache Hits
    axes[0, 0].plot(episodes, enhanced_hits, label="Enhanced layer hits", color="blue", alpha=0.8)
    axes[0, 0].set_title("Enhanced Layer Cache Hits per Episode")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Hits")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Plot 2: Enhanced Layer Cache Misses
    axes[0, 1].plot(episodes, enhanced_misses, label="Enhanced layer misses", color="red", alpha=0.8)
    axes[0, 1].set_title("Enhanced Layer Cache Misses per Episode")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Misses")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Plot 3: Base Layer Cache Hits
    axes[1, 0].plot(episodes, base_hits, label="Base layer hits", color="green", alpha=0.8)
    axes[1, 0].set_title("Base Layer Cache Hits per Episode")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Hits")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Plot 4: Base Layer Cache Misses
    axes[1, 1].plot(episodes, base_misses, label="Base layer misses", color="orange", alpha=0.8)
    axes[1, 1].set_title("Base Layer Cache Misses per Episode")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Misses")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2.csv'
    
    out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2_layers.png'

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 108
#     104 out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2_layers.png'
#     106 title = "FOV Predictor DQN Agent Cache Layers Performance"
# --> 108 plot_cache_layers(
#     109     csv_filepath,
#     110     out_path=None,
#     111     title=title
#     112 )
#
# Cell In[27], line 48, in plot_cache_layers(csv_path, out_path, title)
#      43 def plot_cache_layers(
#      44     csv_path: str,
#      45     out_path: str | None = None,
#      46     title: str | None = None,
#      47 ):
# ---> 48     episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)
#      50     # Compute shared y-lims per layer type
#      51     def compute_ylim(a, b, pad=0.05, min_top=1.0):
#
# Cell In[27], line 12, in read_results(csv_path)
#       9 base_misses: List[float] = []
#      11 if not os.path.exists(csv_path):
# ---> 12     raise FileNotFoundError(f"CSV file not found: {csv_path}")
#      14 with open(csv_path, "r", newline="") as f:
#      15     reader = csv.DictReader(f)
#
# FileNotFoundError: CSV file not found: c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2.csv
