# %%
import math
import csv
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from time import sleep
from collections import deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv
    from LabUserTileRequest import UserTileRequestEvents
    from LabEnvWrapper import EnvWrapper

import sys
# sys.path.append(r'c:\Users\es25591\Workspace\CacheVideoPredict360\Sources')
sys.path.append('/home/eduardo/Workspace/CacheVideoPredict360/Sources')
from Common.Utils import save_training_results

# %%
# Check PyTorch GPU availability and basic operation
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Using device: {torch.cuda.get_device_name(torch.cuda.current_device())}")
    x = torch.randn(2, 2, device="cuda")
    y = torch.randn(2, 2, device="cuda")
    print("Sample CUDA tensor sum:\n", (x + y))
else:
    print("GPU not detected; running on CPU.")
# Out:
# CUDA available: False
# GPU not detected; running on CPU.

# %%
class LastSampleReplication:
    def __init__(self, n, n_users):
        self.n = n
        self.n_users = n_users
        
        self.usersMap = np.array([[] for i in range(n_users)])
    
    def select_tiles_to_prefetch(self, state):
        n_tiles = self.n * self.n
        actions = []
        for user_id in range(self.n_users):
            user_state = state[user_id]
            last_sampled_tiles = user_state['last_sampled_tiles']
            action = np.zeros(n_tiles)
            for tile_idx in last_sampled_tiles:
                action[tile_idx] = 1
            actions.append(action)
        return actions

# %%
if __name__ == "__main__":
    n_episodes = 200
    n_nodes = 10
    n_users = 100
    step_size = 10
    arrival_rate = 15.0  # users per second
    alpha = 2.0
    n_videos = 100
    n_gops = 60
    n_layers = 2
    n = 4
    n_tiles = n * n
    max_capacity = 500e6  # 500 MB

    # Hyperparameters for RL
    epsilon_start = 1.0
    epsilon_min = 0.05
    epsilon_decay = 0.985
    gamma = 0.99
    learning_rate = 1e-3
    batch_size = 64
    capacity = 10000
    window_len = 5  # LSTM sequence length (history window)

    # CPT parameters
    theta = 0.5
    lam = 3.7183

    # du_caches = [
    #     CacheEngineEnv(
    #         n_users=n_users,
    #         n_videos=n_videos,
    #         n_layers=n_layers,
    #         n_tiles=n_tiles,
    #         n_gops=n_gops,
    #         cache_capacity=max_capacity,
    #     ) for _ in range(n_nodes)
    # ]
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=n_users,
        n_videos=n_videos,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n_gops=n_gops,
        cache_capacity=max_capacity,
    )

    # Initialize User Environment
    users_env = UserTileRequestEvents(
        n_nodes=n_nodes,
        n_users=n_users,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n=n,
        users_viewport_tiles=None,
        requested_videos=None,
        users_arrivals=None,
        arrival_rate=arrival_rate
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,   # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 40e6, dtype=float),    # 320 Mbps -> 40e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,    # 1 ms
        mec_fixed_delay=0.005,   # 5 ms
        cloud_fixed_delay=0.1   # 100 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=theta,
        lam=lam
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    agent = LastSampleReplication(
        n=n,
        n_users=n_users
    )

    results = []
    scores = []
    active_users_log = []  # Track active users per step

    for ep in range(n_episodes):

        obs, info = env.reset()

        cache_hits = 0
        cache_misses = 0
        enhanced_layer_cache_hits = 0
        enhanced_layer_cache_misses = 0
        base_layer_cache_hits = 0
        base_layer_cache_misses = 0
        total_reward = 0.0
        avg_psnr = []

        for step in count():

            # --- AGENT ACTIONS ---
            reqs_state = info['users_requests']
            active_users = [
                (req['u'], req['video'], req['gop']) 
                for req in reqs_state if req['gop'] < n_gops
            ]
            actions = []
            for req in reqs_state:
                u = req['u']
                video = req['video']
                gop = req['gop']

                if gop >= n_gops:
                    continue
                
                tiles = np.zeros(n*n)
                for tile in req['tiles']:
                    tiles[tile['tile']] = 1 if tile['layer'] == 1 else 0

                # chooses tiles
                actions.append({
                    'user': u,
                    'gop': gop,
                    'video': video,
                    'tiles': tiles
                })
                
            # --- STEP ENV ---
            obs, rewards, done, info = env.step(actions)

            total_reward += float(rewards)
            enhanced_layer_cache_hits += info["enh_layer_cache_hits"]
            enhanced_layer_cache_misses += info["enh_layer_cache_misses"]
            base_layer_cache_hits += info["base_layer_cache_hits"]
            base_layer_cache_misses += info["base_layer_cache_misses"]
            avg_psnr.append(info.get("average_psnr", 0.0))

            step_reward = float(rewards) / max(1, len(active_users))
            
            # print(f"Step {step}, Active Users: {len(active_users)}")
            # print(f"Request State: {reqs_state}")
            # print(f"Action: {actions}")
            # print(f"Next Request State: {reqs_next_state}")
            # print(
            #     f"Reward: {rewards}, "
            #     f"Cache Hits: {enhanced_layer_cache_hits + base_layer_cache_hits}, "
            #     f"Cache Misses: {enhanced_layer_cache_misses + base_layer_cache_misses}"
            # )
            # print("-----")
            
            if done:
                break

        avg_psnr = [x for x in avg_psnr if x != 0.0]

        cache_hits = enhanced_layer_cache_hits + base_layer_cache_hits
        cache_misses = enhanced_layer_cache_misses + base_layer_cache_misses

        print(
            f"Episode {ep+1}/{n_episodes}, "
            f"Total Reward: {total_reward:.4f}, "
            f"cache_hits: {cache_hits}, "
            f"cache_misses: {cache_misses}, "
            f"enh_layer_cache_hits: {enhanced_layer_cache_hits}, "
            f"enh_layer_cache_misses: {enhanced_layer_cache_misses}, "
            f"base_layer_cache_hits: {base_layer_cache_hits}, "
            f"base_layer_cache_misses: {base_layer_cache_misses}, "
            f"Average PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}, "
        )

        filename = (
            f"fov_lsr_"
            f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
            f"cap{int(max_capacity/1e6)}MB_AR{int(arrival_rate)}.csv"
        )

        
        save_training_results(
            # path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
            path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
            filename=filename,
            ep=ep,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            enhanced_layer_cache_hits=enhanced_layer_cache_hits,
            enhanced_layer_cache_misses=enhanced_layer_cache_misses,
            base_layer_cache_hits=base_layer_cache_hits,
            base_layer_cache_misses=base_layer_cache_misses,
            avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
            agent=None
        )
        scores.append(total_reward)

        results.append({
            "episode": ep,
            "total_reward": total_reward,
            "cache_hits": cache_hits,
            "cache_misses": cache_misses,
        })
# Out:
# Experiment ===================
# Total users: 100
# Cache capacity: 500000000.0MB
# Video matrix: 100x2x16
# ==============================
#
# Episode 1/200, Total Reward: 10191.3482, cache_hits: 117343, cache_misses: 3624, enh_layer_cache_hits: 21343, enh_layer_cache_misses: 3624, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 2/200, Total Reward: 10261.6321, cache_hits: 117421, cache_misses: 3371, enh_layer_cache_hits: 21421, enh_layer_cache_misses: 3371, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 3/200, Total Reward: 10011.3729, cache_hits: 117248, cache_misses: 3560, enh_layer_cache_hits: 21248, enh_layer_cache_misses: 3560, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 4/200, Total Reward: 10599.3615, cache_hits: 117423, cache_misses: 3303, enh_layer_cache_hits: 21423, enh_layer_cache_misses: 3303, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 5/200, Total Reward: 10571.8749, cache_hits: 117349, cache_misses: 3281, enh_layer_cache_hits: 21349, enh_layer_cache_misses: 3281, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 6/200, Total Reward: 10620.4322, cache_hits: 117412, cache_misses: 3362, enh_layer_cache_hits: 21412, enh_layer_cache_misses: 3362, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 7/200, Total Reward: 10223.7199, cache_hits: 117229, cache_misses: 3505, enh_layer_cache_hits: 21229, enh_layer_cache_misses: 3505, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.37,
# Episode 8/200, Total Reward: 10434.6386, cache_hits: 117289, cache_misses: 3668, enh_layer_cache_hits: 21289, enh_layer_cache_misses: 3668, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 9/200, Total Reward: 10296.0377, cache_hits: 117593, cache_misses: 3244, enh_layer_cache_hits: 21593, enh_layer_cache_misses: 3244, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 10/200, Total Reward: 10179.7676, cache_hits: 117373, cache_misses: 3306, enh_layer_cache_hits: 21373, enh_layer_cache_misses: 3306, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 11/200, Total Reward: 10618.2028, cache_hits: 117589, cache_misses: 3437, enh_layer_cache_hits: 21589, enh_layer_cache_misses: 3437, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40,
# Episode 12/200, Total Reward: 10267.7773, cache_hits: 117234, cache_misses: 3575, enh_layer_cache_hits: 21234, enh_layer_cache_misses: 3575, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 13/200, Total Reward: 10228.9587, cache_hits: 117497, cache_misses: 3262, enh_layer_cache_hits: 21497, enh_layer_cache_misses: 3262, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 14/200, Total Reward: 10518.0097, cache_hits: 117624, cache_misses: 3182, enh_layer_cache_hits: 21624, enh_layer_cache_misses: 3182, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 15/200, Total Reward: 10454.6385, cache_hits: 117335, cache_misses: 3483, enh_layer_cache_hits: 21335, enh_layer_cache_misses: 3483, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 16/200, Total Reward: 9721.8925, cache_hits: 117362, cache_misses: 3496, enh_layer_cache_hits: 21362, enh_layer_cache_misses: 3496, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35,
# Episode 17/200, Total Reward: 10389.8366, cache_hits: 117491, cache_misses: 3273, enh_layer_cache_hits: 21491, enh_layer_cache_misses: 3273, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.27,
# Episode 18/200, Total Reward: 10127.2142, cache_hits: 117471, cache_misses: 3382, enh_layer_cache_hits: 21471, enh_layer_cache_misses: 3382, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 19/200, Total Reward: 10431.5848, cache_hits: 117585, cache_misses: 3312, enh_layer_cache_hits: 21585, enh_layer_cache_misses: 3312, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 20/200, Total Reward: 10283.2475, cache_hits: 117298, cache_misses: 3758, enh_layer_cache_hits: 21298, enh_layer_cache_misses: 3758, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.32,
# Episode 21/200, Total Reward: 10383.7309, cache_hits: 117468, cache_misses: 3289, enh_layer_cache_hits: 21468, enh_layer_cache_misses: 3289, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 22/200, Total Reward: 10715.6749, cache_hits: 117562, cache_misses: 3308, enh_layer_cache_hits: 21562, enh_layer_cache_misses: 3308, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54,
# Episode 23/200, Total Reward: 10864.3455, cache_hits: 117485, cache_misses: 3511, enh_layer_cache_hits: 21485, enh_layer_cache_misses: 3511, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 24/200, Total Reward: 10015.9480, cache_hits: 117432, cache_misses: 3294, enh_layer_cache_hits: 21432, enh_layer_cache_misses: 3294, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.37,
# Episode 25/200, Total Reward: 10194.8050, cache_hits: 117443, cache_misses: 3523, enh_layer_cache_hits: 21443, enh_layer_cache_misses: 3523, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.31,
# Episode 26/200, Total Reward: 10505.6809, cache_hits: 117606, cache_misses: 3376, enh_layer_cache_hits: 21606, enh_layer_cache_misses: 3376, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40,
# Episode 27/200, Total Reward: 10416.4546, cache_hits: 117506, cache_misses: 3140, enh_layer_cache_hits: 21506, enh_layer_cache_misses: 3140, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 28/200, Total Reward: 10321.3848, cache_hits: 117479, cache_misses: 3456, enh_layer_cache_hits: 21479, enh_layer_cache_misses: 3456, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 29/200, Total Reward: 10320.3309, cache_hits: 117651, cache_misses: 3358, enh_layer_cache_hits: 21651, enh_layer_cache_misses: 3358, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 30/200, Total Reward: 10776.7784, cache_hits: 117386, cache_misses: 3208, enh_layer_cache_hits: 21386, enh_layer_cache_misses: 3208, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 31/200, Total Reward: 10441.7430, cache_hits: 117460, cache_misses: 3372, enh_layer_cache_hits: 21460, enh_layer_cache_misses: 3372, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 32/200, Total Reward: 10580.9628, cache_hits: 117615, cache_misses: 3090, enh_layer_cache_hits: 21615, enh_layer_cache_misses: 3090, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 33/200, Total Reward: 10292.0117, cache_hits: 117571, cache_misses: 3353, enh_layer_cache_hits: 21571, enh_layer_cache_misses: 3353, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.30,
# Episode 34/200, Total Reward: 10606.8644, cache_hits: 117610, cache_misses: 3177, enh_layer_cache_hits: 21610, enh_layer_cache_misses: 3177, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 35/200, Total Reward: 10387.9781, cache_hits: 117547, cache_misses: 3397, enh_layer_cache_hits: 21547, enh_layer_cache_misses: 3397, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 36/200, Total Reward: 10362.6472, cache_hits: 117402, cache_misses: 3496, enh_layer_cache_hits: 21402, enh_layer_cache_misses: 3496, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.41,
# Episode 37/200, Total Reward: 10504.1760, cache_hits: 117221, cache_misses: 3489, enh_layer_cache_hits: 21221, enh_layer_cache_misses: 3489, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39,
# Episode 38/200, Total Reward: 10561.2119, cache_hits: 117117, cache_misses: 3583, enh_layer_cache_hits: 21117, enh_layer_cache_misses: 3583, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 39/200, Total Reward: 10289.3860, cache_hits: 117470, cache_misses: 3396, enh_layer_cache_hits: 21470, enh_layer_cache_misses: 3396, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 40/200, Total Reward: 10475.5810, cache_hits: 117476, cache_misses: 3443, enh_layer_cache_hits: 21476, enh_layer_cache_misses: 3443, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 41/200, Total Reward: 10441.8857, cache_hits: 117195, cache_misses: 3606, enh_layer_cache_hits: 21195, enh_layer_cache_misses: 3606, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.34,
# Episode 42/200, Total Reward: 10479.1709, cache_hits: 117489, cache_misses: 3238, enh_layer_cache_hits: 21489, enh_layer_cache_misses: 3238, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.55,
# Episode 43/200, Total Reward: 10533.8447, cache_hits: 117204, cache_misses: 3653, enh_layer_cache_hits: 21204, enh_layer_cache_misses: 3653, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.31,
# Episode 44/200, Total Reward: 10365.4534, cache_hits: 117470, cache_misses: 3322, enh_layer_cache_hits: 21470, enh_layer_cache_misses: 3322, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 45/200, Total Reward: 10281.8978, cache_hits: 116941, cache_misses: 3910, enh_layer_cache_hits: 20941, enh_layer_cache_misses: 3910, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 46/200, Total Reward: 10270.2210, cache_hits: 117691, cache_misses: 3105, enh_layer_cache_hits: 21691, enh_layer_cache_misses: 3105, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 47/200, Total Reward: 10224.5008, cache_hits: 117114, cache_misses: 3626, enh_layer_cache_hits: 21114, enh_layer_cache_misses: 3626, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 48/200, Total Reward: 10209.8008, cache_hits: 117447, cache_misses: 3435, enh_layer_cache_hits: 21447, enh_layer_cache_misses: 3435, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 49/200, Total Reward: 10734.1078, cache_hits: 117378, cache_misses: 3354, enh_layer_cache_hits: 21378, enh_layer_cache_misses: 3354, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 50/200, Total Reward: 10329.6906, cache_hits: 117376, cache_misses: 3500, enh_layer_cache_hits: 21376, enh_layer_cache_misses: 3500, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 51/200, Total Reward: 10346.3249, cache_hits: 117555, cache_misses: 3223, enh_layer_cache_hits: 21555, enh_layer_cache_misses: 3223, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 52/200, Total Reward: 10021.7186, cache_hits: 117189, cache_misses: 3432, enh_layer_cache_hits: 21189, enh_layer_cache_misses: 3432, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.41,
# Episode 53/200, Total Reward: 10472.0515, cache_hits: 117698, cache_misses: 3280, enh_layer_cache_hits: 21698, enh_layer_cache_misses: 3280, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 54/200, Total Reward: 10739.8128, cache_hits: 117694, cache_misses: 3299, enh_layer_cache_hits: 21694, enh_layer_cache_misses: 3299, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 55/200, Total Reward: 10146.9086, cache_hits: 117496, cache_misses: 3482, enh_layer_cache_hits: 21496, enh_layer_cache_misses: 3482, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.36,
# Episode 56/200, Total Reward: 10420.2607, cache_hits: 117411, cache_misses: 3461, enh_layer_cache_hits: 21411, enh_layer_cache_misses: 3461, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.32,
# Episode 57/200, Total Reward: 10300.9555, cache_hits: 117438, cache_misses: 3389, enh_layer_cache_hits: 21438, enh_layer_cache_misses: 3389, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.37,
# Episode 58/200, Total Reward: 10559.8394, cache_hits: 117336, cache_misses: 3541, enh_layer_cache_hits: 21336, enh_layer_cache_misses: 3541, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43,
# Episode 59/200, Total Reward: 10830.4243, cache_hits: 117380, cache_misses: 3431, enh_layer_cache_hits: 21380, enh_layer_cache_misses: 3431, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 60/200, Total Reward: 10179.1846, cache_hits: 117365, cache_misses: 3526, enh_layer_cache_hits: 21365, enh_layer_cache_misses: 3526, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 61/200, Total Reward: 10323.1961, cache_hits: 117331, cache_misses: 3475, enh_layer_cache_hits: 21331, enh_layer_cache_misses: 3475, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 62/200, Total Reward: 10471.4625, cache_hits: 117602, cache_misses: 3196, enh_layer_cache_hits: 21602, enh_layer_cache_misses: 3196, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.54,
# Episode 63/200, Total Reward: 10660.9003, cache_hits: 117248, cache_misses: 3456, enh_layer_cache_hits: 21248, enh_layer_cache_misses: 3456, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.29,
# Episode 64/200, Total Reward: 10082.6011, cache_hits: 117466, cache_misses: 3376, enh_layer_cache_hits: 21466, enh_layer_cache_misses: 3376, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.36,
# Episode 65/200, Total Reward: 10281.0264, cache_hits: 117527, cache_misses: 3277, enh_layer_cache_hits: 21527, enh_layer_cache_misses: 3277, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 66/200, Total Reward: 10333.0424, cache_hits: 117272, cache_misses: 3658, enh_layer_cache_hits: 21272, enh_layer_cache_misses: 3658, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39,
# Episode 67/200, Total Reward: 10630.0848, cache_hits: 117373, cache_misses: 3314, enh_layer_cache_hits: 21373, enh_layer_cache_misses: 3314, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 68/200, Total Reward: 10298.9873, cache_hits: 117083, cache_misses: 3735, enh_layer_cache_hits: 21083, enh_layer_cache_misses: 3735, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 69/200, Total Reward: 10453.2011, cache_hits: 117415, cache_misses: 3492, enh_layer_cache_hits: 21415, enh_layer_cache_misses: 3492, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 70/200, Total Reward: 10102.2451, cache_hits: 117057, cache_misses: 3617, enh_layer_cache_hits: 21057, enh_layer_cache_misses: 3617, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 71/200, Total Reward: 10350.1212, cache_hits: 117188, cache_misses: 3493, enh_layer_cache_hits: 21188, enh_layer_cache_misses: 3493, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38,
# Episode 72/200, Total Reward: 10282.5650, cache_hits: 117694, cache_misses: 3129, enh_layer_cache_hits: 21694, enh_layer_cache_misses: 3129, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 73/200, Total Reward: 10500.3933, cache_hits: 117402, cache_misses: 3448, enh_layer_cache_hits: 21402, enh_layer_cache_misses: 3448, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 74/200, Total Reward: 10189.8186, cache_hits: 117362, cache_misses: 3599, enh_layer_cache_hits: 21362, enh_layer_cache_misses: 3599, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 75/200, Total Reward: 9978.3751, cache_hits: 117180, cache_misses: 3623, enh_layer_cache_hits: 21180, enh_layer_cache_misses: 3623, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 76/200, Total Reward: 10299.9309, cache_hits: 117094, cache_misses: 3812, enh_layer_cache_hits: 21094, enh_layer_cache_misses: 3812, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.34,
# Episode 77/200, Total Reward: 10455.2830, cache_hits: 117449, cache_misses: 3354, enh_layer_cache_hits: 21449, enh_layer_cache_misses: 3354, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 78/200, Total Reward: 10551.4230, cache_hits: 117287, cache_misses: 3631, enh_layer_cache_hits: 21287, enh_layer_cache_misses: 3631, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 79/200, Total Reward: 10358.8104, cache_hits: 117442, cache_misses: 3453, enh_layer_cache_hits: 21442, enh_layer_cache_misses: 3453, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 80/200, Total Reward: 10586.7452, cache_hits: 117258, cache_misses: 3630, enh_layer_cache_hits: 21258, enh_layer_cache_misses: 3630, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 81/200, Total Reward: 10392.3789, cache_hits: 117453, cache_misses: 3478, enh_layer_cache_hits: 21453, enh_layer_cache_misses: 3478, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43,
# Episode 82/200, Total Reward: 10651.5894, cache_hits: 117346, cache_misses: 3391, enh_layer_cache_hits: 21346, enh_layer_cache_misses: 3391, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38,
# Episode 83/200, Total Reward: 10124.0791, cache_hits: 117510, cache_misses: 3350, enh_layer_cache_hits: 21510, enh_layer_cache_misses: 3350, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 84/200, Total Reward: 11062.1996, cache_hits: 117536, cache_misses: 3274, enh_layer_cache_hits: 21536, enh_layer_cache_misses: 3274, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 85/200, Total Reward: 10363.9404, cache_hits: 117422, cache_misses: 3269, enh_layer_cache_hits: 21422, enh_layer_cache_misses: 3269, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 86/200, Total Reward: 10545.2207, cache_hits: 117482, cache_misses: 3279, enh_layer_cache_hits: 21482, enh_layer_cache_misses: 3279, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,
# Episode 87/200, Total Reward: 10367.7459, cache_hits: 117255, cache_misses: 3540, enh_layer_cache_hits: 21255, enh_layer_cache_misses: 3540, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 88/200, Total Reward: 10722.0983, cache_hits: 117347, cache_misses: 3446, enh_layer_cache_hits: 21347, enh_layer_cache_misses: 3446, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 89/200, Total Reward: 10631.5021, cache_hits: 117329, cache_misses: 3478, enh_layer_cache_hits: 21329, enh_layer_cache_misses: 3478, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 90/200, Total Reward: 10687.3833, cache_hits: 117425, cache_misses: 3442, enh_layer_cache_hits: 21425, enh_layer_cache_misses: 3442, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 91/200, Total Reward: 10245.2611, cache_hits: 117459, cache_misses: 3292, enh_layer_cache_hits: 21459, enh_layer_cache_misses: 3292, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 92/200, Total Reward: 10427.0024, cache_hits: 117471, cache_misses: 3276, enh_layer_cache_hits: 21471, enh_layer_cache_misses: 3276, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 93/200, Total Reward: 9961.2332, cache_hits: 116925, cache_misses: 3911, enh_layer_cache_hits: 20925, enh_layer_cache_misses: 3911, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.29,
# Episode 94/200, Total Reward: 10543.6969, cache_hits: 117431, cache_misses: 3386, enh_layer_cache_hits: 21431, enh_layer_cache_misses: 3386, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 95/200, Total Reward: 9922.6339, cache_hits: 117562, cache_misses: 3451, enh_layer_cache_hits: 21562, enh_layer_cache_misses: 3451, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40,
# Episode 96/200, Total Reward: 10269.3391, cache_hits: 117316, cache_misses: 3566, enh_layer_cache_hits: 21316, enh_layer_cache_misses: 3566, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.30,
# Episode 97/200, Total Reward: 10775.6218, cache_hits: 117275, cache_misses: 3590, enh_layer_cache_hits: 21275, enh_layer_cache_misses: 3590, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35,
# Episode 98/200, Total Reward: 10501.2328, cache_hits: 117533, cache_misses: 3407, enh_layer_cache_hits: 21533, enh_layer_cache_misses: 3407, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 99/200, Total Reward: 10338.4340, cache_hits: 117238, cache_misses: 3537, enh_layer_cache_hits: 21238, enh_layer_cache_misses: 3537, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.29,
# Episode 100/200, Total Reward: 10742.8863, cache_hits: 117388, cache_misses: 3588, enh_layer_cache_hits: 21388, enh_layer_cache_misses: 3588, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 101/200, Total Reward: 9838.1208, cache_hits: 117468, cache_misses: 3328, enh_layer_cache_hits: 21468, enh_layer_cache_misses: 3328, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.32,
# Episode 102/200, Total Reward: 10299.7531, cache_hits: 117447, cache_misses: 3252, enh_layer_cache_hits: 21447, enh_layer_cache_misses: 3252, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 103/200, Total Reward: 10755.6018, cache_hits: 117433, cache_misses: 3449, enh_layer_cache_hits: 21433, enh_layer_cache_misses: 3449, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 104/200, Total Reward: 10514.1361, cache_hits: 117106, cache_misses: 3607, enh_layer_cache_hits: 21106, enh_layer_cache_misses: 3607, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.33,
# Episode 105/200, Total Reward: 10537.8520, cache_hits: 117643, cache_misses: 3251, enh_layer_cache_hits: 21643, enh_layer_cache_misses: 3251, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38,
# Episode 106/200, Total Reward: 10387.7392, cache_hits: 117219, cache_misses: 3660, enh_layer_cache_hits: 21219, enh_layer_cache_misses: 3660, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 107/200, Total Reward: 10386.5947, cache_hits: 117457, cache_misses: 3379, enh_layer_cache_hits: 21457, enh_layer_cache_misses: 3379, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 108/200, Total Reward: 10844.1904, cache_hits: 117402, cache_misses: 3343, enh_layer_cache_hits: 21402, enh_layer_cache_misses: 3343, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 109/200, Total Reward: 10720.7716, cache_hits: 117463, cache_misses: 3496, enh_layer_cache_hits: 21463, enh_layer_cache_misses: 3496, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 110/200, Total Reward: 10737.0101, cache_hits: 117594, cache_misses: 3084, enh_layer_cache_hits: 21594, enh_layer_cache_misses: 3084, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39,
# Episode 111/200, Total Reward: 10316.9612, cache_hits: 117417, cache_misses: 3360, enh_layer_cache_hits: 21417, enh_layer_cache_misses: 3360, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 112/200, Total Reward: 9930.7516, cache_hits: 117487, cache_misses: 3375, enh_layer_cache_hits: 21487, enh_layer_cache_misses: 3375, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 113/200, Total Reward: 9852.4091, cache_hits: 117268, cache_misses: 3518, enh_layer_cache_hits: 21268, enh_layer_cache_misses: 3518, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.29,
# Episode 114/200, Total Reward: 10146.0813, cache_hits: 117224, cache_misses: 3435, enh_layer_cache_hits: 21224, enh_layer_cache_misses: 3435, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 115/200, Total Reward: 10406.5645, cache_hits: 117272, cache_misses: 3482, enh_layer_cache_hits: 21272, enh_layer_cache_misses: 3482, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 116/200, Total Reward: 10272.2229, cache_hits: 117699, cache_misses: 3092, enh_layer_cache_hits: 21699, enh_layer_cache_misses: 3092, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 117/200, Total Reward: 10449.2117, cache_hits: 117667, cache_misses: 3100, enh_layer_cache_hits: 21667, enh_layer_cache_misses: 3100, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.63,
# Episode 118/200, Total Reward: 10583.4813, cache_hits: 117431, cache_misses: 3459, enh_layer_cache_hits: 21431, enh_layer_cache_misses: 3459, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 119/200, Total Reward: 10578.6382, cache_hits: 117278, cache_misses: 3554, enh_layer_cache_hits: 21278, enh_layer_cache_misses: 3554, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 120/200, Total Reward: 10029.6862, cache_hits: 117445, cache_misses: 3569, enh_layer_cache_hits: 21445, enh_layer_cache_misses: 3569, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 121/200, Total Reward: 10080.3561, cache_hits: 117201, cache_misses: 3574, enh_layer_cache_hits: 21201, enh_layer_cache_misses: 3574, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.41,
# Episode 122/200, Total Reward: 10275.5246, cache_hits: 117274, cache_misses: 3468, enh_layer_cache_hits: 21274, enh_layer_cache_misses: 3468, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.26,
# Episode 123/200, Total Reward: 10100.8826, cache_hits: 117521, cache_misses: 3320, enh_layer_cache_hits: 21521, enh_layer_cache_misses: 3320, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 124/200, Total Reward: 10393.1797, cache_hits: 117361, cache_misses: 3429, enh_layer_cache_hits: 21361, enh_layer_cache_misses: 3429, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43,
# Episode 125/200, Total Reward: 10438.7198, cache_hits: 117328, cache_misses: 3454, enh_layer_cache_hits: 21328, enh_layer_cache_misses: 3454, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.41,
# Episode 126/200, Total Reward: 10586.8059, cache_hits: 117391, cache_misses: 3254, enh_layer_cache_hits: 21391, enh_layer_cache_misses: 3254, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 127/200, Total Reward: 10272.3103, cache_hits: 117266, cache_misses: 3544, enh_layer_cache_hits: 21266, enh_layer_cache_misses: 3544, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 128/200, Total Reward: 10308.9420, cache_hits: 117393, cache_misses: 3418, enh_layer_cache_hits: 21393, enh_layer_cache_misses: 3418, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 129/200, Total Reward: 10356.7295, cache_hits: 117213, cache_misses: 3526, enh_layer_cache_hits: 21213, enh_layer_cache_misses: 3526, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39,
# Episode 130/200, Total Reward: 10688.8574, cache_hits: 117554, cache_misses: 3382, enh_layer_cache_hits: 21554, enh_layer_cache_misses: 3382, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 131/200, Total Reward: 10372.4022, cache_hits: 117464, cache_misses: 3427, enh_layer_cache_hits: 21464, enh_layer_cache_misses: 3427, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 132/200, Total Reward: 11069.0372, cache_hits: 117542, cache_misses: 3366, enh_layer_cache_hits: 21542, enh_layer_cache_misses: 3366, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 133/200, Total Reward: 10265.8866, cache_hits: 117403, cache_misses: 3432, enh_layer_cache_hits: 21403, enh_layer_cache_misses: 3432, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 134/200, Total Reward: 10676.4036, cache_hits: 117553, cache_misses: 3283, enh_layer_cache_hits: 21553, enh_layer_cache_misses: 3283, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 135/200, Total Reward: 10802.6635, cache_hits: 117583, cache_misses: 3199, enh_layer_cache_hits: 21583, enh_layer_cache_misses: 3199, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 136/200, Total Reward: 10427.2470, cache_hits: 117282, cache_misses: 3539, enh_layer_cache_hits: 21282, enh_layer_cache_misses: 3539, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 137/200, Total Reward: 10737.9666, cache_hits: 117395, cache_misses: 3502, enh_layer_cache_hits: 21395, enh_layer_cache_misses: 3502, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.60,
# Episode 138/200, Total Reward: 10526.3817, cache_hits: 117549, cache_misses: 3170, enh_layer_cache_hits: 21549, enh_layer_cache_misses: 3170, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 139/200, Total Reward: 10462.7072, cache_hits: 117452, cache_misses: 3348, enh_layer_cache_hits: 21452, enh_layer_cache_misses: 3348, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 140/200, Total Reward: 10276.4791, cache_hits: 117385, cache_misses: 3464, enh_layer_cache_hits: 21385, enh_layer_cache_misses: 3464, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 141/200, Total Reward: 10388.2814, cache_hits: 117220, cache_misses: 3705, enh_layer_cache_hits: 21220, enh_layer_cache_misses: 3705, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35,
# Episode 142/200, Total Reward: 10004.1370, cache_hits: 117472, cache_misses: 3461, enh_layer_cache_hits: 21472, enh_layer_cache_misses: 3461, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.28,
# Episode 143/200, Total Reward: 10612.7726, cache_hits: 117511, cache_misses: 3498, enh_layer_cache_hits: 21511, enh_layer_cache_misses: 3498, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 144/200, Total Reward: 10092.2434, cache_hits: 117363, cache_misses: 3437, enh_layer_cache_hits: 21363, enh_layer_cache_misses: 3437, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43,
# Episode 145/200, Total Reward: 10321.1936, cache_hits: 117472, cache_misses: 3446, enh_layer_cache_hits: 21472, enh_layer_cache_misses: 3446, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 146/200, Total Reward: 10874.7565, cache_hits: 117456, cache_misses: 3419, enh_layer_cache_hits: 21456, enh_layer_cache_misses: 3419, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.47,
# Episode 147/200, Total Reward: 9987.1874, cache_hits: 117238, cache_misses: 3724, enh_layer_cache_hits: 21238, enh_layer_cache_misses: 3724, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35,
# Episode 148/200, Total Reward: 10525.1193, cache_hits: 117465, cache_misses: 3343, enh_layer_cache_hits: 21465, enh_layer_cache_misses: 3343, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38,
# Episode 149/200, Total Reward: 10307.9639, cache_hits: 117405, cache_misses: 3449, enh_layer_cache_hits: 21405, enh_layer_cache_misses: 3449, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 150/200, Total Reward: 10303.8716, cache_hits: 117636, cache_misses: 3262, enh_layer_cache_hits: 21636, enh_layer_cache_misses: 3262, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 151/200, Total Reward: 10322.3359, cache_hits: 117195, cache_misses: 3668, enh_layer_cache_hits: 21195, enh_layer_cache_misses: 3668, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 152/200, Total Reward: 10782.2860, cache_hits: 117289, cache_misses: 3599, enh_layer_cache_hits: 21289, enh_layer_cache_misses: 3599, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38,
# Episode 153/200, Total Reward: 10428.7879, cache_hits: 117360, cache_misses: 3422, enh_layer_cache_hits: 21360, enh_layer_cache_misses: 3422, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 154/200, Total Reward: 10531.1091, cache_hits: 117653, cache_misses: 3268, enh_layer_cache_hits: 21653, enh_layer_cache_misses: 3268, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 155/200, Total Reward: 10414.6086, cache_hits: 117543, cache_misses: 3486, enh_layer_cache_hits: 21543, enh_layer_cache_misses: 3486, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.37,
# Episode 156/200, Total Reward: 10432.8726, cache_hits: 117455, cache_misses: 3285, enh_layer_cache_hits: 21455, enh_layer_cache_misses: 3285, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 157/200, Total Reward: 9701.0441, cache_hits: 117058, cache_misses: 3771, enh_layer_cache_hits: 21058, enh_layer_cache_misses: 3771, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.21,
# Episode 158/200, Total Reward: 9815.3948, cache_hits: 117258, cache_misses: 3745, enh_layer_cache_hits: 21258, enh_layer_cache_misses: 3745, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 159/200, Total Reward: 10612.6985, cache_hits: 117576, cache_misses: 3339, enh_layer_cache_hits: 21576, enh_layer_cache_misses: 3339, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 160/200, Total Reward: 10093.0370, cache_hits: 117287, cache_misses: 3690, enh_layer_cache_hits: 21287, enh_layer_cache_misses: 3690, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.33,
# Episode 161/200, Total Reward: 10000.2949, cache_hits: 117155, cache_misses: 3745, enh_layer_cache_hits: 21155, enh_layer_cache_misses: 3745, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.38,
# Episode 162/200, Total Reward: 10797.7453, cache_hits: 117288, cache_misses: 3517, enh_layer_cache_hits: 21288, enh_layer_cache_misses: 3517, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43,
# Episode 163/200, Total Reward: 10151.6048, cache_hits: 117431, cache_misses: 3465, enh_layer_cache_hits: 21431, enh_layer_cache_misses: 3465, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.35,
# Episode 164/200, Total Reward: 10355.9834, cache_hits: 117420, cache_misses: 3414, enh_layer_cache_hits: 21420, enh_layer_cache_misses: 3414, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 165/200, Total Reward: 10202.2833, cache_hits: 117415, cache_misses: 3428, enh_layer_cache_hits: 21415, enh_layer_cache_misses: 3428, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 166/200, Total Reward: 10130.0919, cache_hits: 117234, cache_misses: 3520, enh_layer_cache_hits: 21234, enh_layer_cache_misses: 3520, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.46,
# Episode 167/200, Total Reward: 10292.3449, cache_hits: 117522, cache_misses: 3229, enh_layer_cache_hits: 21522, enh_layer_cache_misses: 3229, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.52,
# Episode 168/200, Total Reward: 10288.8273, cache_hits: 117359, cache_misses: 3558, enh_layer_cache_hits: 21359, enh_layer_cache_misses: 3558, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 169/200, Total Reward: 10083.6019, cache_hits: 117467, cache_misses: 3444, enh_layer_cache_hits: 21467, enh_layer_cache_misses: 3444, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39,
# Episode 170/200, Total Reward: 10177.5346, cache_hits: 117379, cache_misses: 3420, enh_layer_cache_hits: 21379, enh_layer_cache_misses: 3420, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43,
# Episode 171/200, Total Reward: 10209.9024, cache_hits: 117487, cache_misses: 3285, enh_layer_cache_hits: 21487, enh_layer_cache_misses: 3285, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 172/200, Total Reward: 10476.4191, cache_hits: 117351, cache_misses: 3435, enh_layer_cache_hits: 21351, enh_layer_cache_misses: 3435, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 173/200, Total Reward: 10926.7311, cache_hits: 117383, cache_misses: 3357, enh_layer_cache_hits: 21383, enh_layer_cache_misses: 3357, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 174/200, Total Reward: 10332.0457, cache_hits: 117543, cache_misses: 3342, enh_layer_cache_hits: 21543, enh_layer_cache_misses: 3342, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.42,
# Episode 175/200, Total Reward: 10285.6891, cache_hits: 117373, cache_misses: 3426, enh_layer_cache_hits: 21373, enh_layer_cache_misses: 3426, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40,
# Episode 176/200, Total Reward: 10429.8688, cache_hits: 117424, cache_misses: 3377, enh_layer_cache_hits: 21424, enh_layer_cache_misses: 3377, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.41,
# Episode 177/200, Total Reward: 10532.1326, cache_hits: 117255, cache_misses: 3493, enh_layer_cache_hits: 21255, enh_layer_cache_misses: 3493, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.48,
# Episode 178/200, Total Reward: 9955.9306, cache_hits: 117382, cache_misses: 3462, enh_layer_cache_hits: 21382, enh_layer_cache_misses: 3462, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 179/200, Total Reward: 10109.4769, cache_hits: 117229, cache_misses: 3697, enh_layer_cache_hits: 21229, enh_layer_cache_misses: 3697, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.37,
# Episode 180/200, Total Reward: 10229.9265, cache_hits: 117518, cache_misses: 3502, enh_layer_cache_hits: 21518, enh_layer_cache_misses: 3502, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 181/200, Total Reward: 9966.9312, cache_hits: 117538, cache_misses: 3301, enh_layer_cache_hits: 21538, enh_layer_cache_misses: 3301, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.57,
# Episode 182/200, Total Reward: 10182.7672, cache_hits: 117471, cache_misses: 3472, enh_layer_cache_hits: 21471, enh_layer_cache_misses: 3472, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.51,
# Episode 183/200, Total Reward: 9971.1289, cache_hits: 117183, cache_misses: 3691, enh_layer_cache_hits: 21183, enh_layer_cache_misses: 3691, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.41,
# Episode 184/200, Total Reward: 10120.6075, cache_hits: 117457, cache_misses: 3466, enh_layer_cache_hits: 21457, enh_layer_cache_misses: 3466, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.49,
# Episode 185/200, Total Reward: 10419.3413, cache_hits: 117460, cache_misses: 3181, enh_layer_cache_hits: 21460, enh_layer_cache_misses: 3181, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 186/200, Total Reward: 9823.0172, cache_hits: 117312, cache_misses: 3603, enh_layer_cache_hits: 21312, enh_layer_cache_misses: 3603, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.40,
# Episode 187/200, Total Reward: 10276.3948, cache_hits: 117355, cache_misses: 3417, enh_layer_cache_hits: 21355, enh_layer_cache_misses: 3417, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39,
# Episode 188/200, Total Reward: 10570.9937, cache_hits: 117103, cache_misses: 3601, enh_layer_cache_hits: 21103, enh_layer_cache_misses: 3601, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 189/200, Total Reward: 9996.9207, cache_hits: 117347, cache_misses: 3298, enh_layer_cache_hits: 21347, enh_layer_cache_misses: 3298, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.28,
# Episode 190/200, Total Reward: 10894.0323, cache_hits: 117663, cache_misses: 3226, enh_layer_cache_hits: 21663, enh_layer_cache_misses: 3226, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.50,
# Episode 191/200, Total Reward: 10471.8706, cache_hits: 117496, cache_misses: 3491, enh_layer_cache_hits: 21496, enh_layer_cache_misses: 3491, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.45,
# Episode 192/200, Total Reward: 10505.5910, cache_hits: 117550, cache_misses: 3259, enh_layer_cache_hits: 21550, enh_layer_cache_misses: 3259, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.53,
# Episode 193/200, Total Reward: 10382.6924, cache_hits: 117549, cache_misses: 3277, enh_layer_cache_hits: 21549, enh_layer_cache_misses: 3277, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.56,
# Episode 194/200, Total Reward: 10009.4362, cache_hits: 117239, cache_misses: 3769, enh_layer_cache_hits: 21239, enh_layer_cache_misses: 3769, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39,
# Episode 195/200, Total Reward: 10434.4623, cache_hits: 117385, cache_misses: 3469, enh_layer_cache_hits: 21385, enh_layer_cache_misses: 3469, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.43,
# Episode 196/200, Total Reward: 11045.7649, cache_hits: 117577, cache_misses: 3069, enh_layer_cache_hits: 21577, enh_layer_cache_misses: 3069, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.64,
# Episode 197/200, Total Reward: 11138.1134, cache_hits: 117342, cache_misses: 3364, enh_layer_cache_hits: 21342, enh_layer_cache_misses: 3364, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.58,
# Episode 198/200, Total Reward: 10373.2210, cache_hits: 117469, cache_misses: 3314, enh_layer_cache_hits: 21469, enh_layer_cache_misses: 3314, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.39,
# Episode 199/200, Total Reward: 10488.0527, cache_hits: 117334, cache_misses: 3483, enh_layer_cache_hits: 21334, enh_layer_cache_misses: 3483, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.44,
# Episode 200/200, Total Reward: 10648.1931, cache_hits: 117601, cache_misses: 3132, enh_layer_cache_hits: 21601, enh_layer_cache_misses: 3132, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 38.59,

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# 1. Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_yscale('log') 
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# 2. Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_yscale('log') 
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# 3. Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_yscale('log')
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\es25591\AppData\Local\Temp\ipykernel_12728\3657158268.py:17: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# C:\Users\es25591\AppData\Local\Temp\ipykernel_12728\3657158268.py:27: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# C:\Users\es25591\AppData\Local\Temp\ipykernel_12728\3657158268.py:37: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[2].set_ylim(bottom=0)

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
        ]
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]
    base_totals = [h + m for h, m in zip(base_hits, base_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]
    base_hit_rate = [safe_pct(h, t) for h, t in zip(base_hits, base_totals)]
    base_miss_rate = [safe_pct(m, t) for m, t in zip(base_misses, base_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)
    base_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Base Layer: Hit rate
    axes[1, 0].plot(episodes, base_hit_rate, label="Base hit rate (%)", color="green", alpha=0.9)
    axes[1, 0].set_title("Base Layer Hit Rate")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Rate (%)")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Base Layer: Miss rate
    axes[1, 1].plot(episodes, base_miss_rate, label="Base miss rate (%)", color="orange", alpha=0.9)
    axes[1, 1].set_title("Base Layer Miss Rate")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Rate (%)")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    # csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap150MB_eps0.05_2.csv'
    csv_filepath += '/fov_predictor_U500_V1000_G60_L2_N4_cap300MB_eps0.05_2.csv'
    
    #out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap150MB_eps0.05_2.png'
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 123
#     119 out_path = None
#     121 title = "FOV Predictor DQN Agent Cache Layers Performance"
# --> 123 plot_cache_layers(
#     124     csv_filepath,
#     125     out_path=None,
#     126     title=title
#     127 )
#
# Cell In[11], line 48, in plot_cache_layers(csv_path, out_path, title)
#      43 def plot_cache_layers(
#      44     csv_path: str,
#      45     out_path: str | None = None,
#      46     title: str | None = None,
#      47 ):
# ---> 48     episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)
#      50     # Compute per-episode percentages
#      51     def safe_pct(num, den):
#
# Cell In[11], line 12, in read_results(csv_path)
#       9 base_misses: List[float] = []
#      11 if not os.path.exists(csv_path):
# ---> 12     raise FileNotFoundError(f"CSV file not found: {csv_path}")
#      14 with open(csv_path, "r", newline="") as f:
#      15     reader = csv.DictReader(f)
#
# FileNotFoundError: CSV file not found: /home/eduardo/Workspace/CacheVideoPredict360/Results/fov_predictor_U500_V1000_G60_L2_N4_cap300MB_eps0.05_2.csv

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
        ]
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)

    # Compute shared y-lims per layer type
    def compute_ylim(a, b, pad=0.05, min_top=1.0):
        top = max(max(a or [0.0]), max(b or [0.0]))
        top = max(min_top, top)
        return (0, top * (1 + pad))

    enh_ylim = compute_ylim(enhanced_hits, enhanced_misses)
    base_ylim = compute_ylim(base_hits, base_misses)

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Plot 1: Enhanced Layer Cache Hits
    axes[0, 0].plot(episodes, enhanced_hits, label="Enhanced layer hits", color="blue", alpha=0.8)
    axes[0, 0].set_title("Enhanced Layer Cache Hits per Episode")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Hits")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Plot 2: Enhanced Layer Cache Misses
    axes[0, 1].plot(episodes, enhanced_misses, label="Enhanced layer misses", color="red", alpha=0.8)
    axes[0, 1].set_title("Enhanced Layer Cache Misses per Episode")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Misses")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Plot 3: Base Layer Cache Hits
    axes[1, 0].plot(episodes, base_hits, label="Base layer hits", color="green", alpha=0.8)
    axes[1, 0].set_title("Base Layer Cache Hits per Episode")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Hits")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Plot 4: Base Layer Cache Misses
    axes[1, 1].plot(episodes, base_misses, label="Base layer misses", color="orange", alpha=0.8)
    axes[1, 1].set_title("Base Layer Cache Misses per Episode")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Misses")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2.csv'
    
    out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2_layers.png'

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 108
#     104 out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2_layers.png'
#     106 title = "FOV Predictor DQN Agent Cache Layers Performance"
# --> 108 plot_cache_layers(
#     109     csv_filepath,
#     110     out_path=None,
#     111     title=title
#     112 )
#
# Cell In[27], line 48, in plot_cache_layers(csv_path, out_path, title)
#      43 def plot_cache_layers(
#      44     csv_path: str,
#      45     out_path: str | None = None,
#      46     title: str | None = None,
#      47 ):
# ---> 48     episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)
#      50     # Compute shared y-lims per layer type
#      51     def compute_ylim(a, b, pad=0.05, min_top=1.0):
#
# Cell In[27], line 12, in read_results(csv_path)
#       9 base_misses: List[float] = []
#      11 if not os.path.exists(csv_path):
# ---> 12     raise FileNotFoundError(f"CSV file not found: {csv_path}")
#      14 with open(csv_path, "r", newline="") as f:
#      15     reader = csv.DictReader(f)
#
# FileNotFoundError: CSV file not found: c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2.csv
