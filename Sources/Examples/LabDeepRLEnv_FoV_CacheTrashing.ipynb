# %%
import os
import csv
import sys
import math
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd

from time import sleep
from collections import deque
from itertools import count
from typing import List

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv, LruPolicy, SvcLruPolicy
    from LabUserTileRequest import UserTileRequestEvents
    from LabEnvWrapper import EnvWrapper

# sys.path.append(r'c:\Users\es25591\Workspace\CacheVideoPredict360\Sources')
sys.path.append('/home/eduardo/Workspace/CacheVideoPredict360/Sources')
from Common.Utils import save_training_results

# %%
# Check PyTorch GPU availability and basic operation
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Using device: {torch.cuda.get_device_name(torch.cuda.current_device())}")
    x = torch.randn(2, 2, device="cuda")
    y = torch.randn(2, 2, device="cuda")
    print("Sample CUDA tensor sum:\n", (x + y))
else:
    print("GPU not detected; running on CPU.")
# Out:
# CUDA available: True
# Using device: NVIDIA GeForce RTX 3050 6GB Laptop GPU
# Sample CUDA tensor sum:
#  tensor([[ 1.0993, -1.8995],
#         [ 1.1797, -1.1914]], device='cuda:0')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        # state shape: (seq_len, input_size)
        self.memory.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

class LSTM_DQN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1):
        super(LSTM_DQN, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # LSTM Layer: Takes sequence of viewports
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        
        # Fully Connected Layer: Maps LSTM output to Q-values (one per tile index)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden=None):
        # x shape: (batch, seq_len, input_size)
        
        # LSTM output shape: (batch, seq_len, hidden_size)
        lstm_out, hidden = self.lstm(x, hidden)
        
        # We only care about the output of the last time step for prediction
        last_time_step = lstm_out[:, -1, :]
        
        # Q-values
        q_values = self.fc(last_time_step)
        return q_values, hidden

class DQNAgent:
    def __init__(
        self, 
        n_tiles, 
        seq_len, 
        learning_rate=1e-3, 
        gamma=0.99,
        batch_size=64,
        capacity=10000,
        epsilon_start=1.0,
        epsilon_min=0.05,
        epsilon_decay=0.995
    ):
        self.n_tiles = n_tiles
        self.seq_len = seq_len
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        
        self.policy_net = LSTM_DQN(n_tiles, 32, n_tiles + 1).to(device)
        self.target_net = LSTM_DQN(n_tiles, 32, n_tiles + 1).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        
        self.optimizer = optim.Adam(
            self.policy_net.parameters(), 
            lr=learning_rate
        )

        self.criterion = nn.MSELoss()
        self.memory = ReplayMemory(capacity=capacity)
        self.batch_size = batch_size

    def select_action(self, state_seq):
        if random.random() < self.epsilon:
            return random.randrange(self.n_tiles + 1), None
        else:
            with torch.no_grad():
                state_tensor = torch.FloatTensor(state_seq).unsqueeze(0).to(device)
                q_values, _ = self.policy_net(state_tensor)
                return q_values.argmax().item(), q_values.cpu().numpy()

    def select_optimal_action(self, state_seq):
        with torch.no_grad():
            state_tensor = torch.FloatTensor(state_seq).unsqueeze(0).to(device)
            q_values, _ = self.policy_net(state_tensor)
            return q_values.argmax().item(), q_values.cpu().numpy()

    def train_step(self):
        if len(self.memory) < self.batch_size:
            return 0.0
        
        batch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        # Convert to tensors
        states = torch.FloatTensor(np.array(states)).to(device)      # (B, Seq, Input)
        next_states = torch.FloatTensor(np.array(next_states)).to(device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(device)  # (B, 1)
        rewards = torch.FloatTensor(rewards).to(device)
        dones = torch.FloatTensor(np.array(dones, dtype=np.float32)).to(device)

        # Compute Q(s, a)
        q_values, _ = self.policy_net(states)
        state_action_values = q_values.gather(1, actions).squeeze(1)

        # Compute V(s')
        with torch.no_grad():
            next_q_values, _ = self.target_net(next_states)
            next_state_values = next_q_values.max(1)[0]
            expected_state_action_values = rewards + (self.gamma * next_state_values * (1 - dones))

        # Loss and Optimize
        loss = self.criterion(state_action_values, expected_state_action_values)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        return loss.item()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

# %%
def index_to_fov_mask(center_idx, n):
    mask = np.zeros(n*n, dtype=int)    
    cy, cx = divmod(center_idx, n)
    
    for dy in [-1, 0, 1]:
        for dx in [-1, 0, 1]:
            ny, nx = cy + dy, cx + dx
            if 0 <= ny < n and 0 <= nx < n:
                mask[ny * n + nx] = 1
                
    return mask

# %%
if __name__ == "__main__":
    n_episodes = 200
    n_nodes = 10
    n_users = 100
    step_size = 10.0
    arrival_rate = 10.0  # users per second
    alpha = 2.0
    n_videos = 100
    n_gops = 60
    n_layers = 2
    n = 4
    n_tiles = n * n
    max_capacity = 100e6  # 100 MB

    # Hyperparameters for RL
    epsilon_start = 1.0
    epsilon_min = 0.005
    epsilon_decay = 0.985
    gamma = 0.99
    learning_rate = 1e-3
    batch_size = 64
    capacity = 10000
    window_len = 3  # LSTM sequence length (history window)

    # CPT parameters
    theta = 0.5
    lam = 3.7183

    # du_caches = [
    #     CacheEngineEnv(
    #         n_users=n_users,
    #         n_videos=n_videos,
    #         n_layers=n_layers,
    #         n_tiles=n_tiles,
    #         n_gops=n_gops,
    #         cache_capacity=max_capacity,
    #     ) for _ in range(n_nodes)
    # ]
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=n_users,
        n_videos=n_videos,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n_gops=n_gops,
        cache_capacity=max_capacity,
        # policy=SvcLruPolicy(max_size=max_capacity)
    )

    # Initialize User Environment
    users_env = UserTileRequestEvents(
        n_nodes=n_nodes,
        n_users=n_users,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n=n,
        users_viewport_tiles=None,
        requested_videos=None,
        users_arrivals=None,
        arrival_rate=arrival_rate
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,  # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 40e6, dtype=float),    # 320 Mbps -> 40e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,  # 1 ms
        mec_fixed_delay=0.005, # 5 ms
        cloud_fixed_delay=0.1  # 100 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=theta,
        lam=lam
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    agent = DQNAgent(
        n_tiles=n_tiles, 
        seq_len=window_len,
        learning_rate=learning_rate,
        gamma=gamma,
        batch_size=batch_size,
        capacity=capacity,
        epsilon_start=epsilon_start,
        epsilon_min=epsilon_min,
        epsilon_decay=epsilon_decay
    )

    results = []
    scores = []
    cache_log = [] # Track active users per step

    for ep in range(n_episodes):

        obs, info = env.reset()

        user_histories = {
            u: deque(
                [np.zeros(n * n) for _ in range(window_len)],
                maxlen=window_len
            ) for u in range(n_users)
        }

        cache_hits = 0
        cache_misses = 0
        enhanced_layer_cache_hits = 0
        enhanced_layer_cache_misses = 0
        base_layer_cache_hits = 0
        base_layer_cache_misses = 0
        total_reward = 0.0
        avg_psnr = []

        for step in count():

            # --- AGENT ACTIONS ---
            reqs_state = info['users_requests']
            active_users = [
                (req['u'], req['video'], req['gop'])
                for req in reqs_state if req['gop'] < n_gops
            ]

            actions = []
            user_action_indices = {}

            for u, video, gop in active_users:
                cur_state_seq = np.array(user_histories[u])

                # Agent chooses center tile
                center_tile_idx, q_values = agent.select_action(cur_state_seq)
                user_action_indices[u] = center_tile_idx

                if center_tile_idx == n_tiles:
                    predicted_viewport = np.zeros(n*n, dtype=int)
                else:
                    predicted_viewport = index_to_fov_mask(center_idx=center_tile_idx, n=n)

                actions.append({
                    'user': u,
                    'gop': gop,
                    'video': video,
                    'tiles': predicted_viewport
                })

            # --- STEP ENV ---
            obs, rewards, done, info = env.step(actions)

            total_reward += float(rewards)
            enhanced_layer_cache_hits += info["enh_layer_cache_hits"]
            enhanced_layer_cache_misses += info["enh_layer_cache_misses"]
            base_layer_cache_hits += info["base_layer_cache_hits"]
            base_layer_cache_misses += info["base_layer_cache_misses"]
            avg_psnr.append(info.get("average_psnr", 0.0))

            step_reward = float(rewards) / max(1, len(active_users))

            # --- TRAINING / HISTORY UPDATE ---
            reqs_next_state = info['users_requests']

            for u, video, gop in active_users:
                state_seq = np.array(user_histories[u])

                target_indices = [
                    tile['tile'] 
                    for req in reqs_next_state 
                    if req['u'] == u 
                    for tile in req['tiles'] 
                    if tile['layer'] == 1
                ]
                actual_viewport = np.array([
                    1 if i in target_indices else 0 for i in range(n*n)
                ])

                user_histories[u].append(actual_viewport)
                next_state_seq = np.array(user_histories[u])

                dones = (gop == n_gops)
                agent.memory.push(
                    state_seq,
                    user_action_indices[u], 
                    step_reward, 
                    next_state_seq, 
                    dones
                )
            
            agent.train_step()
            
            # print(f"Step {step}, Active Users: {len(active_users)}")
            # print(f"Request State: {reqs_state}")
            # print(f"Action: {actions}")
            # print(f"Next Request State: {reqs_next_state}")
            # print(
            #     f"Reward: {rewards}, "
            #     f"Cache Hits: {enhanced_layer_cache_hits + base_layer_cache_hits}, "
            #     f"Cache Misses: {enhanced_layer_cache_misses + base_layer_cache_misses}"
            # )
            # print("-----")
            
            ### Store cache utilization info ###
            # cache_utilization = info.get('cache_utilization', 0.0)
            # current_cache_capacity = info.get('cache_current_capacity', 0)
            
            # cache_log.append({
            #     'episode': ep,
            #     'step': step,
            #     'active_users': len(active_users),
            #     'cache_current_capacity': current_cache_capacity,
            #     'cache_utilization': cache_utilization
            # })
            
            # df_active_users = pd.DataFrame(cache_log)
            # df_active_users.to_csv(
            #     f'/home/eduardo/Workspace/CacheVideoPredict360/Results/cache_log_C{int(max_capacity/1e6)}MB_U{n_users}.csv',
            #     index=False
            # )
            ### End store cache utilization info ###
            
            if done:
                break

        # Update Target Network and Decay Epsilon
        if ep % 5 == 0:
            agent.update_target_network()

        agent.update_epsilon()

        avg_psnr = [x for x in avg_psnr if x != 0.0]

        cache_hits = enhanced_layer_cache_hits + base_layer_cache_hits
        cache_misses = enhanced_layer_cache_misses + base_layer_cache_misses

        print(
            f"Episode {ep+1}/{n_episodes}, "
            f"Total Reward: {total_reward:.2f}, "
            f"cache_hits: {cache_hits}, "
            f"cache_misses: {cache_misses}, "
            f"enh_layer_cache_hits: {enhanced_layer_cache_hits}, "
            f"enh_layer_cache_misses: {enhanced_layer_cache_misses}, "
            f"base_layer_cache_hits: {base_layer_cache_hits}, "
            f"base_layer_cache_misses: {base_layer_cache_misses}, "
            f"Average PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}, "
            f"Epsilon: {agent.epsilon:.4f}"
        )

        filename = (
            f"fov_predictor_E{n_episodes}_W{window_len}_"
            f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
            f"cap{int(max_capacity/1e6)}MB_AR{arrival_rate}.csv"
        )

        save_training_results(
            path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
            # path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
            filename=filename,
            ep=ep,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            enhanced_layer_cache_hits=enhanced_layer_cache_hits,
            enhanced_layer_cache_misses=enhanced_layer_cache_misses,
            base_layer_cache_hits=base_layer_cache_hits,
            base_layer_cache_misses=base_layer_cache_misses,
            avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
            agent=agent
        )

        scores.append(total_reward)

        results.append({
            "episode": ep,
            "total_reward": total_reward,
            "cache_hits": cache_hits,
            "cache_misses": cache_misses,
        })
# Out:
# Experiment ===================
# Total users: 100
# Cache capacity: 100000000.0MB
# Video matrix: 100x2x16
# ==============================
#
# Episode 1/200, Total Reward: 6510.00, cache_hits: 107697, cache_misses: 13094, enh_layer_cache_hits: 11821, enh_layer_cache_misses: 12970, base_layer_cache_hits: 95876, base_layer_cache_misses: 124, Average PSNR: 37.49, Epsilon: 0.9850
# Episode 2/200, Total Reward: 4297.29, cache_hits: 102888, cache_misses: 18038, enh_layer_cache_hits: 11605, enh_layer_cache_misses: 13321, base_layer_cache_hits: 91283, base_layer_cache_misses: 4717, Average PSNR: 36.80, Epsilon: 0.9702
# Episode 3/200, Total Reward: 6393.48, cache_hits: 107337, cache_misses: 13386, enh_layer_cache_hits: 12192, enh_layer_cache_misses: 12531, base_layer_cache_hits: 95145, base_layer_cache_misses: 855, Average PSNR: 37.61, Epsilon: 0.9557
# Episode 4/200, Total Reward: 5715.80, cache_hits: 106136, cache_misses: 14589, enh_layer_cache_hits: 12451, enh_layer_cache_misses: 12274, base_layer_cache_hits: 93685, base_layer_cache_misses: 2315, Average PSNR: 37.17, Epsilon: 0.9413
# Episode 5/200, Total Reward: 6416.34, cache_hits: 107487, cache_misses: 13347, enh_layer_cache_hits: 12443, enh_layer_cache_misses: 12391, base_layer_cache_hits: 95044, base_layer_cache_misses: 956, Average PSNR: 37.30, Epsilon: 0.9272
# Episode 6/200, Total Reward: 4751.91, cache_hits: 103926, cache_misses: 17074, enh_layer_cache_hits: 12193, enh_layer_cache_misses: 12807, base_layer_cache_hits: 91733, base_layer_cache_misses: 4267, Average PSNR: 37.03, Epsilon: 0.9133
# Episode 7/200, Total Reward: 5383.25, cache_hits: 105032, cache_misses: 15737, enh_layer_cache_hits: 12174, enh_layer_cache_misses: 12595, base_layer_cache_hits: 92858, base_layer_cache_misses: 3142, Average PSNR: 37.31, Epsilon: 0.8996
# Episode 8/200, Total Reward: 3312.95, cache_hits: 100608, cache_misses: 20250, enh_layer_cache_hits: 12176, enh_layer_cache_misses: 12682, base_layer_cache_hits: 88432, base_layer_cache_misses: 7568, Average PSNR: 36.68, Epsilon: 0.8861
# Episode 9/200, Total Reward: 3611.91, cache_hits: 101583, cache_misses: 19161, enh_layer_cache_hits: 12117, enh_layer_cache_misses: 12627, base_layer_cache_hits: 89466, base_layer_cache_misses: 6534, Average PSNR: 35.95, Epsilon: 0.8728
# Episode 10/200, Total Reward: 6357.38, cache_hits: 107097, cache_misses: 13622, enh_layer_cache_hits: 12663, enh_layer_cache_misses: 12056, base_layer_cache_hits: 94434, base_layer_cache_misses: 1566, Average PSNR: 37.50, Epsilon: 0.8597
# Episode 11/200, Total Reward: 6210.76, cache_hits: 106632, cache_misses: 14178, enh_layer_cache_hits: 13085, enh_layer_cache_misses: 11725, base_layer_cache_hits: 93547, base_layer_cache_misses: 2453, Average PSNR: 37.34, Epsilon: 0.8468
# Episode 12/200, Total Reward: 5214.41, cache_hits: 104945, cache_misses: 15815, enh_layer_cache_hits: 12074, enh_layer_cache_misses: 12686, base_layer_cache_hits: 92871, base_layer_cache_misses: 3129, Average PSNR: 36.62, Epsilon: 0.8341
# Episode 13/200, Total Reward: 4136.83, cache_hits: 102023, cache_misses: 18683, enh_layer_cache_hits: 12047, enh_layer_cache_misses: 12659, base_layer_cache_hits: 89976, base_layer_cache_misses: 6024, Average PSNR: 36.89, Epsilon: 0.8216
# Episode 14/200, Total Reward: 5669.83, cache_hits: 105993, cache_misses: 14878, enh_layer_cache_hits: 11770, enh_layer_cache_misses: 13101, base_layer_cache_hits: 94223, base_layer_cache_misses: 1777, Average PSNR: 37.26, Epsilon: 0.8093
# Episode 15/200, Total Reward: 3982.61, cache_hits: 102634, cache_misses: 18207, enh_layer_cache_hits: 12037, enh_layer_cache_misses: 12804, base_layer_cache_hits: 90597, base_layer_cache_misses: 5403, Average PSNR: 36.48, Epsilon: 0.7972
# Episode 16/200, Total Reward: 5199.36, cache_hits: 104679, cache_misses: 15976, enh_layer_cache_hits: 12694, enh_layer_cache_misses: 11961, base_layer_cache_hits: 91985, base_layer_cache_misses: 4015, Average PSNR: 37.01, Epsilon: 0.7852
# Episode 17/200, Total Reward: 3984.67, cache_hits: 102262, cache_misses: 18563, enh_layer_cache_hits: 11816, enh_layer_cache_misses: 13009, base_layer_cache_hits: 90446, base_layer_cache_misses: 5554, Average PSNR: 36.56, Epsilon: 0.7734
# Episode 18/200, Total Reward: 2564.81, cache_hits: 99633, cache_misses: 21129, enh_layer_cache_hits: 11377, enh_layer_cache_misses: 13385, base_layer_cache_hits: 88256, base_layer_cache_misses: 7744, Average PSNR: 35.57, Epsilon: 0.7618
# Episode 19/200, Total Reward: 3613.62, cache_hits: 101962, cache_misses: 18941, enh_layer_cache_hits: 11376, enh_layer_cache_misses: 13527, base_layer_cache_hits: 90586, base_layer_cache_misses: 5414, Average PSNR: 36.09, Epsilon: 0.7504
# Episode 20/200, Total Reward: 5976.32, cache_hits: 106532, cache_misses: 14378, enh_layer_cache_hits: 12143, enh_layer_cache_misses: 12767, base_layer_cache_hits: 94389, base_layer_cache_misses: 1611, Average PSNR: 37.30, Epsilon: 0.7391
# Episode 21/200, Total Reward: 2638.30, cache_hits: 100024, cache_misses: 20972, enh_layer_cache_hits: 11544, enh_layer_cache_misses: 13452, base_layer_cache_hits: 88480, base_layer_cache_misses: 7520, Average PSNR: 35.40, Epsilon: 0.7280
# Episode 22/200, Total Reward: 3586.00, cache_hits: 101743, cache_misses: 19049, enh_layer_cache_hits: 12346, enh_layer_cache_misses: 12446, base_layer_cache_hits: 89397, base_layer_cache_misses: 6603, Average PSNR: 36.50, Epsilon: 0.7171
# Episode 23/200, Total Reward: 7610.56, cache_hits: 109559, cache_misses: 11278, enh_layer_cache_hits: 14708, enh_layer_cache_misses: 10129, base_layer_cache_hits: 94851, base_layer_cache_misses: 1149, Average PSNR: 37.94, Epsilon: 0.7064
# Episode 24/200, Total Reward: 5327.08, cache_hits: 105372, cache_misses: 15501, enh_layer_cache_hits: 14026, enh_layer_cache_misses: 10847, base_layer_cache_hits: 91346, base_layer_cache_misses: 4654, Average PSNR: 36.88, Epsilon: 0.6958
# Episode 25/200, Total Reward: 6086.63, cache_hits: 106172, cache_misses: 14680, enh_layer_cache_hits: 13924, enh_layer_cache_misses: 10928, base_layer_cache_hits: 92248, base_layer_cache_misses: 3752, Average PSNR: 37.49, Epsilon: 0.6853
# Episode 26/200, Total Reward: 538.39, cache_hits: 95431, cache_misses: 25367, enh_layer_cache_hits: 12320, enh_layer_cache_misses: 12478, base_layer_cache_hits: 83111, base_layer_cache_misses: 12889, Average PSNR: 34.82, Epsilon: 0.6751
# Episode 27/200, Total Reward: 4711.17, cache_hits: 104075, cache_misses: 16794, enh_layer_cache_hits: 13521, enh_layer_cache_misses: 11348, base_layer_cache_hits: 90554, base_layer_cache_misses: 5446, Average PSNR: 36.97, Epsilon: 0.6649
# Episode 28/200, Total Reward: 3091.92, cache_hits: 100880, cache_misses: 19967, enh_layer_cache_hits: 12761, enh_layer_cache_misses: 12086, base_layer_cache_hits: 88119, base_layer_cache_misses: 7881, Average PSNR: 35.62, Epsilon: 0.6550
# Episode 29/200, Total Reward: 5186.18, cache_hits: 105166, cache_misses: 15588, enh_layer_cache_hits: 11251, enh_layer_cache_misses: 13503, base_layer_cache_hits: 93915, base_layer_cache_misses: 2085, Average PSNR: 37.04, Epsilon: 0.6451
# Episode 30/200, Total Reward: 6503.05, cache_hits: 107672, cache_misses: 13219, enh_layer_cache_hits: 12433, enh_layer_cache_misses: 12458, base_layer_cache_hits: 95239, base_layer_cache_misses: 761, Average PSNR: 37.76, Epsilon: 0.6355
# Episode 31/200, Total Reward: 3661.76, cache_hits: 101812, cache_misses: 19043, enh_layer_cache_hits: 11822, enh_layer_cache_misses: 13033, base_layer_cache_hits: 89990, base_layer_cache_misses: 6010, Average PSNR: 36.68, Epsilon: 0.6259
# Episode 32/200, Total Reward: 5673.84, cache_hits: 105706, cache_misses: 15129, enh_layer_cache_hits: 13369, enh_layer_cache_misses: 11466, base_layer_cache_hits: 92337, base_layer_cache_misses: 3663, Average PSNR: 37.62, Epsilon: 0.6165
# Episode 33/200, Total Reward: 6524.32, cache_hits: 107688, cache_misses: 13166, enh_layer_cache_hits: 14312, enh_layer_cache_misses: 10542, base_layer_cache_hits: 93376, base_layer_cache_misses: 2624, Average PSNR: 37.67, Epsilon: 0.6073
# Episode 34/200, Total Reward: 7825.03, cache_hits: 109388, cache_misses: 11372, enh_layer_cache_hits: 15455, enh_layer_cache_misses: 9305, base_layer_cache_hits: 93933, base_layer_cache_misses: 2067, Average PSNR: 37.98, Epsilon: 0.5982
# Episode 35/200, Total Reward: 6180.18, cache_hits: 106764, cache_misses: 14220, enh_layer_cache_hits: 14607, enh_layer_cache_misses: 10377, base_layer_cache_hits: 92157, base_layer_cache_misses: 3843, Average PSNR: 37.50, Epsilon: 0.5892
# Episode 36/200, Total Reward: 6151.73, cache_hits: 106620, cache_misses: 13964, enh_layer_cache_hits: 13244, enh_layer_cache_misses: 11340, base_layer_cache_hits: 93376, base_layer_cache_misses: 2624, Average PSNR: 37.36, Epsilon: 0.5804
# Episode 37/200, Total Reward: 2624.66, cache_hits: 99635, cache_misses: 21157, enh_layer_cache_hits: 10908, enh_layer_cache_misses: 13884, base_layer_cache_hits: 88727, base_layer_cache_misses: 7273, Average PSNR: 36.12, Epsilon: 0.5717
# Episode 38/200, Total Reward: 5706.88, cache_hits: 106281, cache_misses: 14472, enh_layer_cache_hits: 12270, enh_layer_cache_misses: 12483, base_layer_cache_hits: 94011, base_layer_cache_misses: 1989, Average PSNR: 37.18, Epsilon: 0.5631
# Episode 39/200, Total Reward: 5219.61, cache_hits: 104755, cache_misses: 16172, enh_layer_cache_hits: 13965, enh_layer_cache_misses: 10962, base_layer_cache_hits: 90790, base_layer_cache_misses: 5210, Average PSNR: 37.10, Epsilon: 0.5546
# Episode 40/200, Total Reward: 7707.06, cache_hits: 109853, cache_misses: 11058, enh_layer_cache_hits: 15806, enh_layer_cache_misses: 9105, base_layer_cache_hits: 94047, base_layer_cache_misses: 1953, Average PSNR: 38.06, Epsilon: 0.5463
# Episode 41/200, Total Reward: 4648.79, cache_hits: 103337, cache_misses: 17534, enh_layer_cache_hits: 14054, enh_layer_cache_misses: 10817, base_layer_cache_hits: 89283, base_layer_cache_misses: 6717, Average PSNR: 36.71, Epsilon: 0.5381
# Episode 42/200, Total Reward: 4636.03, cache_hits: 103811, cache_misses: 16993, enh_layer_cache_hits: 11500, enh_layer_cache_misses: 13304, base_layer_cache_hits: 92311, base_layer_cache_misses: 3689, Average PSNR: 36.67, Epsilon: 0.5301
# Episode 43/200, Total Reward: 4515.58, cache_hits: 103532, cache_misses: 17261, enh_layer_cache_hits: 11807, enh_layer_cache_misses: 12986, base_layer_cache_hits: 91725, base_layer_cache_misses: 4275, Average PSNR: 36.50, Epsilon: 0.5221
# Episode 44/200, Total Reward: 3236.81, cache_hits: 100938, cache_misses: 20146, enh_layer_cache_hits: 10337, enh_layer_cache_misses: 14747, base_layer_cache_hits: 90601, base_layer_cache_misses: 5399, Average PSNR: 36.24, Epsilon: 0.5143
# Episode 45/200, Total Reward: 4721.70, cache_hits: 104301, cache_misses: 16637, enh_layer_cache_hits: 12002, enh_layer_cache_misses: 12936, base_layer_cache_hits: 92299, base_layer_cache_misses: 3701, Average PSNR: 36.65, Epsilon: 0.5066
# Episode 46/200, Total Reward: 2528.98, cache_hits: 98949, cache_misses: 21882, enh_layer_cache_hits: 13017, enh_layer_cache_misses: 11814, base_layer_cache_hits: 85932, base_layer_cache_misses: 10068, Average PSNR: 36.29, Epsilon: 0.4990
# Episode 47/200, Total Reward: 6000.61, cache_hits: 106497, cache_misses: 14332, enh_layer_cache_hits: 15049, enh_layer_cache_misses: 9780, base_layer_cache_hits: 91448, base_layer_cache_misses: 4552, Average PSNR: 37.27, Epsilon: 0.4915
# Episode 48/200, Total Reward: 7593.39, cache_hits: 109347, cache_misses: 11466, enh_layer_cache_hits: 15659, enh_layer_cache_misses: 9154, base_layer_cache_hits: 93688, base_layer_cache_misses: 2312, Average PSNR: 37.83, Epsilon: 0.4841
# Episode 49/200, Total Reward: 3079.79, cache_hits: 101013, cache_misses: 19913, enh_layer_cache_hits: 12809, enh_layer_cache_misses: 12117, base_layer_cache_hits: 88204, base_layer_cache_misses: 7796, Average PSNR: 36.12, Epsilon: 0.4768
# Episode 50/200, Total Reward: 6199.86, cache_hits: 106905, cache_misses: 14163, enh_layer_cache_hits: 11787, enh_layer_cache_misses: 13281, base_layer_cache_hits: 95118, base_layer_cache_misses: 882, Average PSNR: 37.91, Epsilon: 0.4697
# Episode 51/200, Total Reward: 7002.52, cache_hits: 107943, cache_misses: 12961, enh_layer_cache_hits: 16416, enh_layer_cache_misses: 8488, base_layer_cache_hits: 91527, base_layer_cache_misses: 4473, Average PSNR: 37.85, Epsilon: 0.4626
# Episode 52/200, Total Reward: 6961.91, cache_hits: 108314, cache_misses: 12535, enh_layer_cache_hits: 14567, enh_layer_cache_misses: 10282, base_layer_cache_hits: 93747, base_layer_cache_misses: 2253, Average PSNR: 37.51, Epsilon: 0.4557
# Episode 53/200, Total Reward: 6694.72, cache_hits: 107408, cache_misses: 13419, enh_layer_cache_hits: 15238, enh_layer_cache_misses: 9589, base_layer_cache_hits: 92170, base_layer_cache_misses: 3830, Average PSNR: 37.47, Epsilon: 0.4489
# Episode 54/200, Total Reward: 5445.27, cache_hits: 105321, cache_misses: 15467, enh_layer_cache_hits: 13550, enh_layer_cache_misses: 11238, base_layer_cache_hits: 91771, base_layer_cache_misses: 4229, Average PSNR: 37.29, Epsilon: 0.4421
# Episode 55/200, Total Reward: 5614.44, cache_hits: 105674, cache_misses: 15321, enh_layer_cache_hits: 12923, enh_layer_cache_misses: 12072, base_layer_cache_hits: 92751, base_layer_cache_misses: 3249, Average PSNR: 37.32, Epsilon: 0.4355
# Episode 56/200, Total Reward: 5151.58, cache_hits: 104646, cache_misses: 16226, enh_layer_cache_hits: 12856, enh_layer_cache_misses: 12016, base_layer_cache_hits: 91790, base_layer_cache_misses: 4210, Average PSNR: 37.32, Epsilon: 0.4290
# Episode 57/200, Total Reward: 5335.99, cache_hits: 105289, cache_misses: 15578, enh_layer_cache_hits: 12774, enh_layer_cache_misses: 12093, base_layer_cache_hits: 92515, base_layer_cache_misses: 3485, Average PSNR: 37.25, Epsilon: 0.4225
# Episode 58/200, Total Reward: 7168.68, cache_hits: 108945, cache_misses: 11956, enh_layer_cache_hits: 16327, enh_layer_cache_misses: 8574, base_layer_cache_hits: 92618, base_layer_cache_misses: 3382, Average PSNR: 37.82, Epsilon: 0.4162
# Episode 59/200, Total Reward: 6517.33, cache_hits: 107682, cache_misses: 13111, enh_layer_cache_hits: 14726, enh_layer_cache_misses: 10067, base_layer_cache_hits: 92956, base_layer_cache_misses: 3044, Average PSNR: 37.44, Epsilon: 0.4100
# Episode 60/200, Total Reward: 2592.64, cache_hits: 99360, cache_misses: 21489, enh_layer_cache_hits: 13498, enh_layer_cache_misses: 11351, base_layer_cache_hits: 85862, base_layer_cache_misses: 10138, Average PSNR: 36.31, Epsilon: 0.4038
# Episode 61/200, Total Reward: 2836.66, cache_hits: 100196, cache_misses: 20632, enh_layer_cache_hits: 14110, enh_layer_cache_misses: 10718, base_layer_cache_hits: 86086, base_layer_cache_misses: 9914, Average PSNR: 36.25, Epsilon: 0.3977
# Episode 62/200, Total Reward: 4973.27, cache_hits: 104659, cache_misses: 16223, enh_layer_cache_hits: 12106, enh_layer_cache_misses: 12776, base_layer_cache_hits: 92553, base_layer_cache_misses: 3447, Average PSNR: 37.06, Epsilon: 0.3918
# Episode 63/200, Total Reward: 3846.57, cache_hits: 102057, cache_misses: 18724, enh_layer_cache_hits: 13820, enh_layer_cache_misses: 10961, base_layer_cache_hits: 88237, base_layer_cache_misses: 7763, Average PSNR: 36.42, Epsilon: 0.3859
# Episode 64/200, Total Reward: 3375.97, cache_hits: 101127, cache_misses: 19845, enh_layer_cache_hits: 11942, enh_layer_cache_misses: 13030, base_layer_cache_hits: 89185, base_layer_cache_misses: 6815, Average PSNR: 36.52, Epsilon: 0.3801
# Episode 65/200, Total Reward: 6742.55, cache_hits: 108126, cache_misses: 12553, enh_layer_cache_hits: 12496, enh_layer_cache_misses: 12183, base_layer_cache_hits: 95630, base_layer_cache_misses: 370, Average PSNR: 37.90, Epsilon: 0.3744
# Episode 66/200, Total Reward: 7985.35, cache_hits: 110561, cache_misses: 10242, enh_layer_cache_hits: 17147, enh_layer_cache_misses: 7656, base_layer_cache_hits: 93414, base_layer_cache_misses: 2586, Average PSNR: 38.06, Epsilon: 0.3688
# Episode 67/200, Total Reward: -557.47, cache_hits: 92805, cache_misses: 28105, enh_layer_cache_hits: 12847, enh_layer_cache_misses: 12063, base_layer_cache_hits: 79958, base_layer_cache_misses: 16042, Average PSNR: 34.81, Epsilon: 0.3633
# Episode 68/200, Total Reward: 5182.40, cache_hits: 105120, cache_misses: 15790, enh_layer_cache_hits: 15028, enh_layer_cache_misses: 9882, base_layer_cache_hits: 90092, base_layer_cache_misses: 5908, Average PSNR: 37.17, Epsilon: 0.3578
# Episode 69/200, Total Reward: 3111.20, cache_hits: 100449, cache_misses: 20427, enh_layer_cache_hits: 11609, enh_layer_cache_misses: 13267, base_layer_cache_hits: 88840, base_layer_cache_misses: 7160, Average PSNR: 36.16, Epsilon: 0.3525
# Episode 70/200, Total Reward: 6202.53, cache_hits: 107398, cache_misses: 13563, enh_layer_cache_hits: 13208, enh_layer_cache_misses: 11753, base_layer_cache_hits: 94190, base_layer_cache_misses: 1810, Average PSNR: 37.70, Epsilon: 0.3472
# Episode 71/200, Total Reward: 7363.66, cache_hits: 109516, cache_misses: 11494, enh_layer_cache_hits: 17242, enh_layer_cache_misses: 7768, base_layer_cache_hits: 92274, base_layer_cache_misses: 3726, Average PSNR: 37.81, Epsilon: 0.3420
# Episode 72/200, Total Reward: -174.00, cache_hits: 94223, cache_misses: 26692, enh_layer_cache_hits: 13428, enh_layer_cache_misses: 11487, base_layer_cache_hits: 80795, base_layer_cache_misses: 15205, Average PSNR: 34.76, Epsilon: 0.3368
# Episode 73/200, Total Reward: 3308.90, cache_hits: 101255, cache_misses: 19530, enh_layer_cache_hits: 9523, enh_layer_cache_misses: 15262, base_layer_cache_hits: 91732, base_layer_cache_misses: 4268, Average PSNR: 36.39, Epsilon: 0.3318
# Episode 74/200, Total Reward: 5779.23, cache_hits: 106276, cache_misses: 14642, enh_layer_cache_hits: 11865, enh_layer_cache_misses: 13053, base_layer_cache_hits: 94411, base_layer_cache_misses: 1589, Average PSNR: 37.25, Epsilon: 0.3268
# Episode 75/200, Total Reward: 4411.94, cache_hits: 102816, cache_misses: 17943, enh_layer_cache_hits: 12103, enh_layer_cache_misses: 12656, base_layer_cache_hits: 90713, base_layer_cache_misses: 5287, Average PSNR: 37.43, Epsilon: 0.3219
# Episode 76/200, Total Reward: 6970.64, cache_hits: 108632, cache_misses: 12213, enh_layer_cache_hits: 13497, enh_layer_cache_misses: 11348, base_layer_cache_hits: 95135, base_layer_cache_misses: 865, Average PSNR: 37.99, Epsilon: 0.3171
# Episode 77/200, Total Reward: 7949.23, cache_hits: 110074, cache_misses: 10782, enh_layer_cache_hits: 17464, enh_layer_cache_misses: 7392, base_layer_cache_hits: 92610, base_layer_cache_misses: 3390, Average PSNR: 38.09, Epsilon: 0.3123
# Episode 78/200, Total Reward: 9514.77, cache_hits: 112830, cache_misses: 8036, enh_layer_cache_hits: 18632, enh_layer_cache_misses: 6234, base_layer_cache_hits: 94198, base_layer_cache_misses: 1802, Average PSNR: 38.60, Epsilon: 0.3076
# Episode 79/200, Total Reward: 5999.52, cache_hits: 106581, cache_misses: 14131, enh_layer_cache_hits: 16615, enh_layer_cache_misses: 8097, base_layer_cache_hits: 89966, base_layer_cache_misses: 6034, Average PSNR: 37.28, Epsilon: 0.3030
# Episode 80/200, Total Reward: 6402.79, cache_hits: 107198, cache_misses: 13723, enh_layer_cache_hits: 14207, enh_layer_cache_misses: 10714, base_layer_cache_hits: 92991, base_layer_cache_misses: 3009, Average PSNR: 37.67, Epsilon: 0.2985
# Episode 81/200, Total Reward: 6001.95, cache_hits: 106314, cache_misses: 14435, enh_layer_cache_hits: 15578, enh_layer_cache_misses: 9171, base_layer_cache_hits: 90736, base_layer_cache_misses: 5264, Average PSNR: 37.35, Epsilon: 0.2940
# Episode 82/200, Total Reward: 2356.32, cache_hits: 99435, cache_misses: 21364, enh_layer_cache_hits: 11620, enh_layer_cache_misses: 13179, base_layer_cache_hits: 87815, base_layer_cache_misses: 8185, Average PSNR: 35.41, Epsilon: 0.2896
# Episode 83/200, Total Reward: 5677.32, cache_hits: 105159, cache_misses: 15589, enh_layer_cache_hits: 10790, enh_layer_cache_misses: 13958, base_layer_cache_hits: 94369, base_layer_cache_misses: 1631, Average PSNR: 37.49, Epsilon: 0.2852
# Episode 84/200, Total Reward: 7570.30, cache_hits: 109716, cache_misses: 11130, enh_layer_cache_hits: 15377, enh_layer_cache_misses: 9469, base_layer_cache_hits: 94339, base_layer_cache_misses: 1661, Average PSNR: 37.76, Epsilon: 0.2810
# Episode 85/200, Total Reward: 4795.58, cache_hits: 104083, cache_misses: 16831, enh_layer_cache_hits: 13445, enh_layer_cache_misses: 11469, base_layer_cache_hits: 90638, base_layer_cache_misses: 5362, Average PSNR: 37.02, Epsilon: 0.2767
# Episode 86/200, Total Reward: 5607.51, cache_hits: 105402, cache_misses: 15387, enh_layer_cache_hits: 14262, enh_layer_cache_misses: 10527, base_layer_cache_hits: 91140, base_layer_cache_misses: 4860, Average PSNR: 37.34, Epsilon: 0.2726
# Episode 87/200, Total Reward: 5644.25, cache_hits: 105675, cache_misses: 15120, enh_layer_cache_hits: 15657, enh_layer_cache_misses: 9138, base_layer_cache_hits: 90018, base_layer_cache_misses: 5982, Average PSNR: 36.88, Epsilon: 0.2685
# Episode 88/200, Total Reward: 4203.03, cache_hits: 102613, cache_misses: 18351, enh_layer_cache_hits: 13534, enh_layer_cache_misses: 11430, base_layer_cache_hits: 89079, base_layer_cache_misses: 6921, Average PSNR: 36.62, Epsilon: 0.2645
# Episode 89/200, Total Reward: 4670.74, cache_hits: 103954, cache_misses: 16795, enh_layer_cache_hits: 14190, enh_layer_cache_misses: 10559, base_layer_cache_hits: 89764, base_layer_cache_misses: 6236, Average PSNR: 36.98, Epsilon: 0.2605
# Episode 90/200, Total Reward: 4343.72, cache_hits: 103001, cache_misses: 17817, enh_layer_cache_hits: 14589, enh_layer_cache_misses: 10229, base_layer_cache_hits: 88412, base_layer_cache_misses: 7588, Average PSNR: 36.85, Epsilon: 0.2566
# Episode 91/200, Total Reward: 8238.67, cache_hits: 110599, cache_misses: 10066, enh_layer_cache_hits: 15411, enh_layer_cache_misses: 9254, base_layer_cache_hits: 95188, base_layer_cache_misses: 812, Average PSNR: 38.28, Epsilon: 0.2528
# Episode 92/200, Total Reward: 4278.96, cache_hits: 103524, cache_misses: 17491, enh_layer_cache_hits: 15055, enh_layer_cache_misses: 9960, base_layer_cache_hits: 88469, base_layer_cache_misses: 7531, Average PSNR: 36.26, Epsilon: 0.2490
# Episode 93/200, Total Reward: 6475.13, cache_hits: 107459, cache_misses: 13381, enh_layer_cache_hits: 15261, enh_layer_cache_misses: 9579, base_layer_cache_hits: 92198, base_layer_cache_misses: 3802, Average PSNR: 37.62, Epsilon: 0.2452
# Episode 94/200, Total Reward: 5125.32, cache_hits: 104343, cache_misses: 16296, enh_layer_cache_hits: 16738, enh_layer_cache_misses: 7901, base_layer_cache_hits: 87605, base_layer_cache_misses: 8395, Average PSNR: 36.94, Epsilon: 0.2415
# Episode 95/200, Total Reward: 5282.34, cache_hits: 105424, cache_misses: 15458, enh_layer_cache_hits: 15129, enh_layer_cache_misses: 9753, base_layer_cache_hits: 90295, base_layer_cache_misses: 5705, Average PSNR: 36.88, Epsilon: 0.2379
# Episode 96/200, Total Reward: 1897.85, cache_hits: 97958, cache_misses: 22915, enh_layer_cache_hits: 11081, enh_layer_cache_misses: 13792, base_layer_cache_hits: 86877, base_layer_cache_misses: 9123, Average PSNR: 35.82, Epsilon: 0.2344
# Episode 97/200, Total Reward: 6208.08, cache_hits: 106780, cache_misses: 14103, enh_layer_cache_hits: 11840, enh_layer_cache_misses: 13043, base_layer_cache_hits: 94940, base_layer_cache_misses: 1060, Average PSNR: 37.67, Epsilon: 0.2308
# Episode 98/200, Total Reward: 6530.00, cache_hits: 107638, cache_misses: 13078, enh_layer_cache_hits: 15310, enh_layer_cache_misses: 9406, base_layer_cache_hits: 92328, base_layer_cache_misses: 3672, Average PSNR: 37.63, Epsilon: 0.2274
# Episode 99/200, Total Reward: 5927.63, cache_hits: 106662, cache_misses: 14062, enh_layer_cache_hits: 12498, enh_layer_cache_misses: 12226, base_layer_cache_hits: 94164, base_layer_cache_misses: 1836, Average PSNR: 37.45, Epsilon: 0.2240
# Episode 100/200, Total Reward: 4239.88, cache_hits: 103027, cache_misses: 17733, enh_layer_cache_hits: 11625, enh_layer_cache_misses: 13135, base_layer_cache_hits: 91402, base_layer_cache_misses: 4598, Average PSNR: 36.88, Epsilon: 0.2206
# Episode 101/200, Total Reward: 4164.84, cache_hits: 102984, cache_misses: 17962, enh_layer_cache_hits: 11159, enh_layer_cache_misses: 13787, base_layer_cache_hits: 91825, base_layer_cache_misses: 4175, Average PSNR: 36.22, Epsilon: 0.2173
# Episode 102/200, Total Reward: 7332.79, cache_hits: 109137, cache_misses: 11619, enh_layer_cache_hits: 17228, enh_layer_cache_misses: 7528, base_layer_cache_hits: 91909, base_layer_cache_misses: 4091, Average PSNR: 37.87, Epsilon: 0.2140
# Episode 103/200, Total Reward: 4969.12, cache_hits: 103370, cache_misses: 17380, enh_layer_cache_hits: 16355, enh_layer_cache_misses: 8395, base_layer_cache_hits: 87015, base_layer_cache_misses: 8985, Average PSNR: 37.04, Epsilon: 0.2108
# Episode 104/200, Total Reward: 3864.30, cache_hits: 102656, cache_misses: 18232, enh_layer_cache_hits: 13952, enh_layer_cache_misses: 10936, base_layer_cache_hits: 88704, base_layer_cache_misses: 7296, Average PSNR: 36.46, Epsilon: 0.2077
# Episode 105/200, Total Reward: 3619.39, cache_hits: 101779, cache_misses: 19244, enh_layer_cache_hits: 10971, enh_layer_cache_misses: 14052, base_layer_cache_hits: 90808, base_layer_cache_misses: 5192, Average PSNR: 36.12, Epsilon: 0.2046
# Episode 106/200, Total Reward: 5446.27, cache_hits: 105762, cache_misses: 15169, enh_layer_cache_hits: 11635, enh_layer_cache_misses: 13296, base_layer_cache_hits: 94127, base_layer_cache_misses: 1873, Average PSNR: 37.53, Epsilon: 0.2015
# Episode 107/200, Total Reward: 5861.79, cache_hits: 105803, cache_misses: 14912, enh_layer_cache_hits: 14395, enh_layer_cache_misses: 10320, base_layer_cache_hits: 91408, base_layer_cache_misses: 4592, Average PSNR: 37.38, Epsilon: 0.1985
# Episode 108/200, Total Reward: 6768.07, cache_hits: 107805, cache_misses: 13208, enh_layer_cache_hits: 12666, enh_layer_cache_misses: 12347, base_layer_cache_hits: 95139, base_layer_cache_misses: 861, Average PSNR: 37.94, Epsilon: 0.1955
# Episode 109/200, Total Reward: 5881.82, cache_hits: 106223, cache_misses: 14678, enh_layer_cache_hits: 13706, enh_layer_cache_misses: 11195, base_layer_cache_hits: 92517, base_layer_cache_misses: 3483, Average PSNR: 37.86, Epsilon: 0.1926
# Episode 110/200, Total Reward: 5158.53, cache_hits: 104793, cache_misses: 15950, enh_layer_cache_hits: 12748, enh_layer_cache_misses: 11995, base_layer_cache_hits: 92045, base_layer_cache_misses: 3955, Average PSNR: 37.36, Epsilon: 0.1897
# Episode 111/200, Total Reward: 4308.34, cache_hits: 102355, cache_misses: 18352, enh_layer_cache_hits: 14797, enh_layer_cache_misses: 9910, base_layer_cache_hits: 87558, base_layer_cache_misses: 8442, Average PSNR: 36.87, Epsilon: 0.1868
# Episode 112/200, Total Reward: 7137.43, cache_hits: 108246, cache_misses: 12506, enh_layer_cache_hits: 13888, enh_layer_cache_misses: 10864, base_layer_cache_hits: 94358, base_layer_cache_misses: 1642, Average PSNR: 38.05, Epsilon: 0.1840
# Episode 113/200, Total Reward: 5675.62, cache_hits: 105415, cache_misses: 15173, enh_layer_cache_hits: 15887, enh_layer_cache_misses: 8701, base_layer_cache_hits: 89528, base_layer_cache_misses: 6472, Average PSNR: 37.14, Epsilon: 0.1813
# Episode 114/200, Total Reward: 5648.79, cache_hits: 105493, cache_misses: 15378, enh_layer_cache_hits: 15274, enh_layer_cache_misses: 9597, base_layer_cache_hits: 90219, base_layer_cache_misses: 5781, Average PSNR: 37.15, Epsilon: 0.1785
# Episode 115/200, Total Reward: 4786.21, cache_hits: 103920, cache_misses: 16802, enh_layer_cache_hits: 14681, enh_layer_cache_misses: 10041, base_layer_cache_hits: 89239, base_layer_cache_misses: 6761, Average PSNR: 37.26, Epsilon: 0.1759
# Episode 116/200, Total Reward: 5941.73, cache_hits: 106325, cache_misses: 14426, enh_layer_cache_hits: 12732, enh_layer_cache_misses: 12019, base_layer_cache_hits: 93593, base_layer_cache_misses: 2407, Average PSNR: 37.76, Epsilon: 0.1732
# Episode 117/200, Total Reward: 2378.79, cache_hits: 99649, cache_misses: 21317, enh_layer_cache_hits: 11230, enh_layer_cache_misses: 13736, base_layer_cache_hits: 88419, base_layer_cache_misses: 7581, Average PSNR: 36.09, Epsilon: 0.1706
# Episode 118/200, Total Reward: 6654.62, cache_hits: 107578, cache_misses: 13194, enh_layer_cache_hits: 11804, enh_layer_cache_misses: 12968, base_layer_cache_hits: 95774, base_layer_cache_misses: 226, Average PSNR: 37.94, Epsilon: 0.1681
# Episode 119/200, Total Reward: 6024.11, cache_hits: 106482, cache_misses: 14491, enh_layer_cache_hits: 15792, enh_layer_cache_misses: 9181, base_layer_cache_hits: 90690, base_layer_cache_misses: 5310, Average PSNR: 37.42, Epsilon: 0.1655
# Episode 120/200, Total Reward: 2815.07, cache_hits: 99857, cache_misses: 21163, enh_layer_cache_hits: 15410, enh_layer_cache_misses: 9610, base_layer_cache_hits: 84447, base_layer_cache_misses: 11553, Average PSNR: 35.84, Epsilon: 0.1631
# Episode 121/200, Total Reward: 6196.01, cache_hits: 106950, cache_misses: 13983, enh_layer_cache_hits: 11805, enh_layer_cache_misses: 13128, base_layer_cache_hits: 95145, base_layer_cache_misses: 855, Average PSNR: 37.66, Epsilon: 0.1606
# Episode 122/200, Total Reward: 4275.16, cache_hits: 102364, cache_misses: 18312, enh_layer_cache_hits: 13605, enh_layer_cache_misses: 11071, base_layer_cache_hits: 88759, base_layer_cache_misses: 7241, Average PSNR: 36.78, Epsilon: 0.1582
# Episode 123/200, Total Reward: 5001.38, cache_hits: 103895, cache_misses: 17024, enh_layer_cache_hits: 13272, enh_layer_cache_misses: 11647, base_layer_cache_hits: 90623, base_layer_cache_misses: 5377, Average PSNR: 36.86, Epsilon: 0.1558
# Episode 124/200, Total Reward: 6443.33, cache_hits: 107309, cache_misses: 13503, enh_layer_cache_hits: 11889, enh_layer_cache_misses: 12923, base_layer_cache_hits: 95420, base_layer_cache_misses: 580, Average PSNR: 37.86, Epsilon: 0.1535
# Episode 125/200, Total Reward: 4200.25, cache_hits: 103322, cache_misses: 17501, enh_layer_cache_hits: 12408, enh_layer_cache_misses: 12415, base_layer_cache_hits: 90914, base_layer_cache_misses: 5086, Average PSNR: 36.89, Epsilon: 0.1512
# Episode 126/200, Total Reward: 5946.74, cache_hits: 106149, cache_misses: 14691, enh_layer_cache_hits: 11682, enh_layer_cache_misses: 13158, base_layer_cache_hits: 94467, base_layer_cache_misses: 1533, Average PSNR: 37.43, Epsilon: 0.1489
# Episode 127/200, Total Reward: 4652.16, cache_hits: 103822, cache_misses: 17062, enh_layer_cache_hits: 12653, enh_layer_cache_misses: 12231, base_layer_cache_hits: 91169, base_layer_cache_misses: 4831, Average PSNR: 36.94, Epsilon: 0.1467
# Episode 128/200, Total Reward: 2502.34, cache_hits: 99498, cache_misses: 21430, enh_layer_cache_hits: 14480, enh_layer_cache_misses: 10448, base_layer_cache_hits: 85018, base_layer_cache_misses: 10982, Average PSNR: 35.17, Epsilon: 0.1445
# Episode 129/200, Total Reward: 2637.71, cache_hits: 99054, cache_misses: 21855, enh_layer_cache_hits: 13211, enh_layer_cache_misses: 11698, base_layer_cache_hits: 85843, base_layer_cache_misses: 10157, Average PSNR: 35.88, Epsilon: 0.1423
# Episode 130/200, Total Reward: 5077.88, cache_hits: 104510, cache_misses: 16160, enh_layer_cache_hits: 11274, enh_layer_cache_misses: 13396, base_layer_cache_hits: 93236, base_layer_cache_misses: 2764, Average PSNR: 36.71, Epsilon: 0.1402
# Episode 131/200, Total Reward: 4722.11, cache_hits: 103679, cache_misses: 17127, enh_layer_cache_hits: 12159, enh_layer_cache_misses: 12647, base_layer_cache_hits: 91520, base_layer_cache_misses: 4480, Average PSNR: 36.47, Epsilon: 0.1381
# Episode 132/200, Total Reward: 3472.53, cache_hits: 100790, cache_misses: 20031, enh_layer_cache_hits: 13405, enh_layer_cache_misses: 11416, base_layer_cache_hits: 87385, base_layer_cache_misses: 8615, Average PSNR: 36.75, Epsilon: 0.1360
# Episode 133/200, Total Reward: 5572.13, cache_hits: 105954, cache_misses: 14963, enh_layer_cache_hits: 11491, enh_layer_cache_misses: 13426, base_layer_cache_hits: 94463, base_layer_cache_misses: 1537, Average PSNR: 37.69, Epsilon: 0.1340
# Episode 134/200, Total Reward: 6528.26, cache_hits: 107927, cache_misses: 12899, enh_layer_cache_hits: 16580, enh_layer_cache_misses: 8246, base_layer_cache_hits: 91347, base_layer_cache_misses: 4653, Average PSNR: 37.69, Epsilon: 0.1320
# Episode 135/200, Total Reward: 3394.98, cache_hits: 101209, cache_misses: 19639, enh_layer_cache_hits: 16231, enh_layer_cache_misses: 8617, base_layer_cache_hits: 84978, base_layer_cache_misses: 11022, Average PSNR: 36.11, Epsilon: 0.1300
# Episode 136/200, Total Reward: 7791.80, cache_hits: 109843, cache_misses: 11045, enh_layer_cache_hits: 19291, enh_layer_cache_misses: 5597, base_layer_cache_hits: 90552, base_layer_cache_misses: 5448, Average PSNR: 37.81, Epsilon: 0.1280
# Episode 137/200, Total Reward: 4685.43, cache_hits: 102979, cache_misses: 17795, enh_layer_cache_hits: 15742, enh_layer_cache_misses: 9032, base_layer_cache_hits: 87237, base_layer_cache_misses: 8763, Average PSNR: 36.59, Epsilon: 0.1261
# Episode 138/200, Total Reward: 4648.58, cache_hits: 103941, cache_misses: 16993, enh_layer_cache_hits: 13002, enh_layer_cache_misses: 11932, base_layer_cache_hits: 90939, base_layer_cache_misses: 5061, Average PSNR: 36.89, Epsilon: 0.1242
# Episode 139/200, Total Reward: 8838.27, cache_hits: 112075, cache_misses: 8895, enh_layer_cache_hits: 19387, enh_layer_cache_misses: 5583, base_layer_cache_hits: 92688, base_layer_cache_misses: 3312, Average PSNR: 38.24, Epsilon: 0.1224
# Episode 140/200, Total Reward: 6946.98, cache_hits: 108163, cache_misses: 12557, enh_layer_cache_hits: 16547, enh_layer_cache_misses: 8173, base_layer_cache_hits: 91616, base_layer_cache_misses: 4384, Average PSNR: 37.54, Epsilon: 0.1205
# Episode 141/200, Total Reward: 5346.78, cache_hits: 105164, cache_misses: 15748, enh_layer_cache_hits: 14414, enh_layer_cache_misses: 10498, base_layer_cache_hits: 90750, base_layer_cache_misses: 5250, Average PSNR: 37.11, Epsilon: 0.1187
# Episode 142/200, Total Reward: 6026.84, cache_hits: 106878, cache_misses: 13893, enh_layer_cache_hits: 12484, enh_layer_cache_misses: 12287, base_layer_cache_hits: 94394, base_layer_cache_misses: 1606, Average PSNR: 37.81, Epsilon: 0.1169
# Episode 143/200, Total Reward: 5125.32, cache_hits: 104940, cache_misses: 15918, enh_layer_cache_hits: 14902, enh_layer_cache_misses: 9956, base_layer_cache_hits: 90038, base_layer_cache_misses: 5962, Average PSNR: 37.04, Epsilon: 0.1152
# Episode 144/200, Total Reward: 5083.60, cache_hits: 104938, cache_misses: 15839, enh_layer_cache_hits: 11413, enh_layer_cache_misses: 13364, base_layer_cache_hits: 93525, base_layer_cache_misses: 2475, Average PSNR: 37.29, Epsilon: 0.1135
# Episode 145/200, Total Reward: 6251.60, cache_hits: 106732, cache_misses: 14048, enh_layer_cache_hits: 11871, enh_layer_cache_misses: 12909, base_layer_cache_hits: 94861, base_layer_cache_misses: 1139, Average PSNR: 38.12, Epsilon: 0.1118
# Episode 146/200, Total Reward: 1751.25, cache_hits: 97280, cache_misses: 23555, enh_layer_cache_hits: 10804, enh_layer_cache_misses: 14031, base_layer_cache_hits: 86476, base_layer_cache_misses: 9524, Average PSNR: 36.19, Epsilon: 0.1101
# Episode 147/200, Total Reward: 5554.07, cache_hits: 105308, cache_misses: 15503, enh_layer_cache_hits: 11620, enh_layer_cache_misses: 13191, base_layer_cache_hits: 93688, base_layer_cache_misses: 2312, Average PSNR: 37.54, Epsilon: 0.1084
# Episode 148/200, Total Reward: 5363.60, cache_hits: 105667, cache_misses: 15366, enh_layer_cache_hits: 12219, enh_layer_cache_misses: 12814, base_layer_cache_hits: 93448, base_layer_cache_misses: 2552, Average PSNR: 37.45, Epsilon: 0.1068
# Episode 149/200, Total Reward: 4739.53, cache_hits: 103692, cache_misses: 17131, enh_layer_cache_hits: 15032, enh_layer_cache_misses: 9791, base_layer_cache_hits: 88660, base_layer_cache_misses: 7340, Average PSNR: 36.54, Epsilon: 0.1052
# Episode 150/200, Total Reward: 3496.51, cache_hits: 101563, cache_misses: 19222, enh_layer_cache_hits: 11546, enh_layer_cache_misses: 13239, base_layer_cache_hits: 90017, base_layer_cache_misses: 5983, Average PSNR: 36.69, Epsilon: 0.1036
# Episode 151/200, Total Reward: 5616.48, cache_hits: 105514, cache_misses: 15443, enh_layer_cache_hits: 15379, enh_layer_cache_misses: 9578, base_layer_cache_hits: 90135, base_layer_cache_misses: 5865, Average PSNR: 37.25, Epsilon: 0.1021
# Episode 152/200, Total Reward: 3535.17, cache_hits: 101398, cache_misses: 19345, enh_layer_cache_hits: 11250, enh_layer_cache_misses: 13493, base_layer_cache_hits: 90148, base_layer_cache_misses: 5852, Average PSNR: 36.52, Epsilon: 0.1005
# Episode 153/200, Total Reward: 1293.01, cache_hits: 97434, cache_misses: 23478, enh_layer_cache_hits: 12350, enh_layer_cache_misses: 12562, base_layer_cache_hits: 85084, base_layer_cache_misses: 10916, Average PSNR: 34.91, Epsilon: 0.0990
# Episode 154/200, Total Reward: 5381.68, cache_hits: 105581, cache_misses: 15136, enh_layer_cache_hits: 10334, enh_layer_cache_misses: 14383, base_layer_cache_hits: 95247, base_layer_cache_misses: 753, Average PSNR: 37.15, Epsilon: 0.0975
# Episode 155/200, Total Reward: 4101.38, cache_hits: 102570, cache_misses: 18312, enh_layer_cache_hits: 12677, enh_layer_cache_misses: 12205, base_layer_cache_hits: 89893, base_layer_cache_misses: 6107, Average PSNR: 36.82, Epsilon: 0.0961
# Episode 156/200, Total Reward: 3954.06, cache_hits: 102430, cache_misses: 18386, enh_layer_cache_hits: 10749, enh_layer_cache_misses: 14067, base_layer_cache_hits: 91681, base_layer_cache_misses: 4319, Average PSNR: 36.86, Epsilon: 0.0946
# Episode 157/200, Total Reward: 3785.89, cache_hits: 102410, cache_misses: 18510, enh_layer_cache_hits: 11213, enh_layer_cache_misses: 13707, base_layer_cache_hits: 91197, base_layer_cache_misses: 4803, Average PSNR: 36.64, Epsilon: 0.0932
# Episode 158/200, Total Reward: 5270.49, cache_hits: 104995, cache_misses: 15814, enh_layer_cache_hits: 10521, enh_layer_cache_misses: 14288, base_layer_cache_hits: 94474, base_layer_cache_misses: 1526, Average PSNR: 37.46, Epsilon: 0.0918
# Episode 159/200, Total Reward: 5196.56, cache_hits: 105444, cache_misses: 15562, enh_layer_cache_hits: 11289, enh_layer_cache_misses: 13717, base_layer_cache_hits: 94155, base_layer_cache_misses: 1845, Average PSNR: 36.85, Epsilon: 0.0904
# Episode 160/200, Total Reward: 6446.10, cache_hits: 107411, cache_misses: 13465, enh_layer_cache_hits: 12141, enh_layer_cache_misses: 12735, base_layer_cache_hits: 95270, base_layer_cache_misses: 730, Average PSNR: 37.98, Epsilon: 0.0891
# Episode 161/200, Total Reward: 5891.61, cache_hits: 105736, cache_misses: 15123, enh_layer_cache_hits: 15689, enh_layer_cache_misses: 9170, base_layer_cache_hits: 90047, base_layer_cache_misses: 5953, Average PSNR: 37.14, Epsilon: 0.0877
# Episode 162/200, Total Reward: 5454.45, cache_hits: 105503, cache_misses: 15418, enh_layer_cache_hits: 13324, enh_layer_cache_misses: 11597, base_layer_cache_hits: 92179, base_layer_cache_misses: 3821, Average PSNR: 37.22, Epsilon: 0.0864
# Episode 163/200, Total Reward: 4569.45, cache_hits: 103767, cache_misses: 17077, enh_layer_cache_hits: 12795, enh_layer_cache_misses: 12049, base_layer_cache_hits: 90972, base_layer_cache_misses: 5028, Average PSNR: 36.83, Epsilon: 0.0851
# Episode 164/200, Total Reward: 3730.89, cache_hits: 101948, cache_misses: 18971, enh_layer_cache_hits: 11293, enh_layer_cache_misses: 13626, base_layer_cache_hits: 90655, base_layer_cache_misses: 5345, Average PSNR: 36.78, Epsilon: 0.0839
# Episode 165/200, Total Reward: 6007.34, cache_hits: 106344, cache_misses: 14472, enh_layer_cache_hits: 11307, enh_layer_cache_misses: 13509, base_layer_cache_hits: 95037, base_layer_cache_misses: 963, Average PSNR: 37.85, Epsilon: 0.0826
# Episode 166/200, Total Reward: 2729.35, cache_hits: 99806, cache_misses: 20930, enh_layer_cache_hits: 10631, enh_layer_cache_misses: 14105, base_layer_cache_hits: 89175, base_layer_cache_misses: 6825, Average PSNR: 36.39, Epsilon: 0.0814
# Episode 167/200, Total Reward: 5574.24, cache_hits: 105902, cache_misses: 14919, enh_layer_cache_hits: 11859, enh_layer_cache_misses: 12962, base_layer_cache_hits: 94043, base_layer_cache_misses: 1957, Average PSNR: 36.91, Epsilon: 0.0801
# Episode 168/200, Total Reward: 5809.95, cache_hits: 106400, cache_misses: 14547, enh_layer_cache_hits: 17913, enh_layer_cache_misses: 7034, base_layer_cache_hits: 88487, base_layer_cache_misses: 7513, Average PSNR: 37.40, Epsilon: 0.0789
# Episode 169/200, Total Reward: 5172.07, cache_hits: 104688, cache_misses: 16138, enh_layer_cache_hits: 12150, enh_layer_cache_misses: 12676, base_layer_cache_hits: 92538, base_layer_cache_misses: 3462, Average PSNR: 37.45, Epsilon: 0.0778
# Episode 170/200, Total Reward: 5781.32, cache_hits: 106009, cache_misses: 14793, enh_layer_cache_hits: 11436, enh_layer_cache_misses: 13366, base_layer_cache_hits: 94573, base_layer_cache_misses: 1427, Average PSNR: 37.87, Epsilon: 0.0766
# Episode 171/200, Total Reward: 6691.75, cache_hits: 107531, cache_misses: 13338, enh_layer_cache_hits: 18006, enh_layer_cache_misses: 6863, base_layer_cache_hits: 89525, base_layer_cache_misses: 6475, Average PSNR: 37.36, Epsilon: 0.0754
# Episode 172/200, Total Reward: 3690.25, cache_hits: 102132, cache_misses: 18732, enh_layer_cache_hits: 14002, enh_layer_cache_misses: 10862, base_layer_cache_hits: 88130, base_layer_cache_misses: 7870, Average PSNR: 36.21, Epsilon: 0.0743
# Episode 173/200, Total Reward: 4663.29, cache_hits: 103083, cache_misses: 17843, enh_layer_cache_hits: 11073, enh_layer_cache_misses: 13853, base_layer_cache_hits: 92010, base_layer_cache_misses: 3990, Average PSNR: 37.55, Epsilon: 0.0732
# Episode 174/200, Total Reward: 7136.34, cache_hits: 108298, cache_misses: 12431, enh_layer_cache_hits: 14177, enh_layer_cache_misses: 10552, base_layer_cache_hits: 94121, base_layer_cache_misses: 1879, Average PSNR: 38.13, Epsilon: 0.0721
# Episode 175/200, Total Reward: 2918.44, cache_hits: 100246, cache_misses: 20533, enh_layer_cache_hits: 13453, enh_layer_cache_misses: 11326, base_layer_cache_hits: 86793, base_layer_cache_misses: 9207, Average PSNR: 35.71, Epsilon: 0.0710
# Episode 176/200, Total Reward: 6282.23, cache_hits: 106636, cache_misses: 14093, enh_layer_cache_hits: 15654, enh_layer_cache_misses: 9075, base_layer_cache_hits: 90982, base_layer_cache_misses: 5018, Average PSNR: 37.30, Epsilon: 0.0699
# Episode 177/200, Total Reward: 2496.39, cache_hits: 99019, cache_misses: 21720, enh_layer_cache_hits: 14468, enh_layer_cache_misses: 10271, base_layer_cache_hits: 84551, base_layer_cache_misses: 11449, Average PSNR: 35.72, Epsilon: 0.0689
# Episode 178/200, Total Reward: 5200.10, cache_hits: 104679, cache_misses: 16244, enh_layer_cache_hits: 12262, enh_layer_cache_misses: 12661, base_layer_cache_hits: 92417, base_layer_cache_misses: 3583, Average PSNR: 37.26, Epsilon: 0.0679
# Episode 179/200, Total Reward: 4489.94, cache_hits: 103183, cache_misses: 17622, enh_layer_cache_hits: 15505, enh_layer_cache_misses: 9300, base_layer_cache_hits: 87678, base_layer_cache_misses: 8322, Average PSNR: 36.60, Epsilon: 0.0668
# Episode 180/200, Total Reward: 3566.86, cache_hits: 101396, cache_misses: 19437, enh_layer_cache_hits: 14219, enh_layer_cache_misses: 10614, base_layer_cache_hits: 87177, base_layer_cache_misses: 8823, Average PSNR: 36.38, Epsilon: 0.0658
# Episode 181/200, Total Reward: 2267.29, cache_hits: 99319, cache_misses: 21448, enh_layer_cache_hits: 9660, enh_layer_cache_misses: 15107, base_layer_cache_hits: 89659, base_layer_cache_misses: 6341, Average PSNR: 36.22, Epsilon: 0.0649
# Episode 182/200, Total Reward: 3224.90, cache_hits: 101377, cache_misses: 19586, enh_layer_cache_hits: 10196, enh_layer_cache_misses: 14767, base_layer_cache_hits: 91181, base_layer_cache_misses: 4819, Average PSNR: 36.02, Epsilon: 0.0639
# Episode 183/200, Total Reward: 5749.37, cache_hits: 105629, cache_misses: 15215, enh_layer_cache_hits: 10737, enh_layer_cache_misses: 14107, base_layer_cache_hits: 94892, base_layer_cache_misses: 1108, Average PSNR: 37.28, Epsilon: 0.0629
# Episode 184/200, Total Reward: 5171.45, cache_hits: 105102, cache_misses: 15766, enh_layer_cache_hits: 11257, enh_layer_cache_misses: 13611, base_layer_cache_hits: 93845, base_layer_cache_misses: 2155, Average PSNR: 37.38, Epsilon: 0.0620
# Episode 185/200, Total Reward: 5559.62, cache_hits: 105659, cache_misses: 15339, enh_layer_cache_hits: 11371, enh_layer_cache_misses: 13627, base_layer_cache_hits: 94288, base_layer_cache_misses: 1712, Average PSNR: 37.42, Epsilon: 0.0611
# Episode 186/200, Total Reward: 3116.65, cache_hits: 100435, cache_misses: 20333, enh_layer_cache_hits: 10615, enh_layer_cache_misses: 14153, base_layer_cache_hits: 89820, base_layer_cache_misses: 6180, Average PSNR: 36.15, Epsilon: 0.0601
# Episode 187/200, Total Reward: 2127.42, cache_hits: 98675, cache_misses: 22330, enh_layer_cache_hits: 10786, enh_layer_cache_misses: 14219, base_layer_cache_hits: 87889, base_layer_cache_misses: 8111, Average PSNR: 35.92, Epsilon: 0.0592
# Episode 188/200, Total Reward: 5686.66, cache_hits: 105810, cache_misses: 14972, enh_layer_cache_hits: 10852, enh_layer_cache_misses: 13930, base_layer_cache_hits: 94958, base_layer_cache_misses: 1042, Average PSNR: 37.17, Epsilon: 0.0583
# Episode 189/200, Total Reward: 4677.25, cache_hits: 104155, cache_misses: 16770, enh_layer_cache_hits: 12329, enh_layer_cache_misses: 12596, base_layer_cache_hits: 91826, base_layer_cache_misses: 4174, Average PSNR: 37.04, Epsilon: 0.0575
# Episode 190/200, Total Reward: 6146.24, cache_hits: 106680, cache_misses: 14233, enh_layer_cache_hits: 12871, enh_layer_cache_misses: 12042, base_layer_cache_hits: 93809, base_layer_cache_misses: 2191, Average PSNR: 37.86, Epsilon: 0.0566
# Episode 191/200, Total Reward: 1520.81, cache_hits: 97212, cache_misses: 23616, enh_layer_cache_hits: 11179, enh_layer_cache_misses: 13649, base_layer_cache_hits: 86033, base_layer_cache_misses: 9967, Average PSNR: 35.48, Epsilon: 0.0558
# Episode 192/200, Total Reward: 4046.44, cache_hits: 102672, cache_misses: 18101, enh_layer_cache_hits: 8798, enh_layer_cache_misses: 15975, base_layer_cache_hits: 93874, base_layer_cache_misses: 2126, Average PSNR: 36.47, Epsilon: 0.0549
# Episode 193/200, Total Reward: 2372.17, cache_hits: 99326, cache_misses: 21294, enh_layer_cache_hits: 7409, enh_layer_cache_misses: 17211, base_layer_cache_hits: 91917, base_layer_cache_misses: 4083, Average PSNR: 35.84, Epsilon: 0.0541
# Episode 194/200, Total Reward: 6226.60, cache_hits: 106909, cache_misses: 13986, enh_layer_cache_hits: 11890, enh_layer_cache_misses: 13005, base_layer_cache_hits: 95019, base_layer_cache_misses: 981, Average PSNR: 37.20, Epsilon: 0.0533
# Episode 195/200, Total Reward: 605.42, cache_hits: 95434, cache_misses: 25452, enh_layer_cache_hits: 10675, enh_layer_cache_misses: 14211, base_layer_cache_hits: 84759, base_layer_cache_misses: 11241, Average PSNR: 34.71, Epsilon: 0.0525
# Episode 196/200, Total Reward: 4094.96, cache_hits: 102841, cache_misses: 17928, enh_layer_cache_hits: 6841, enh_layer_cache_misses: 17928, base_layer_cache_hits: 96000, base_layer_cache_misses: 0, Average PSNR: 36.55, Epsilon: 0.0517
# Episode 197/200, Total Reward: 5255.99, cache_hits: 104660, cache_misses: 16193, enh_layer_cache_hits: 8868, enh_layer_cache_misses: 15985, base_layer_cache_hits: 95792, base_layer_cache_misses: 208, Average PSNR: 37.06, Epsilon: 0.0509
# Episode 198/200, Total Reward: 5112.32, cache_hits: 104476, cache_misses: 16321, enh_layer_cache_hits: 11199, enh_layer_cache_misses: 13598, base_layer_cache_hits: 93277, base_layer_cache_misses: 2723, Average PSNR: 37.64, Epsilon: 0.0502
# Episode 199/200, Total Reward: 5463.64, cache_hits: 105795, cache_misses: 15079, enh_layer_cache_hits: 11683, enh_layer_cache_misses: 13191, base_layer_cache_hits: 94112, base_layer_cache_misses: 1888, Average PSNR: 37.51, Epsilon: 0.0494
# Episode 200/200, Total Reward: 1784.38, cache_hits: 98343, cache_misses: 22354, enh_layer_cache_hits: 10358, enh_layer_cache_misses: 14339, base_layer_cache_hits: 87985, base_layer_cache_misses: 8015, Average PSNR: 35.58, Epsilon: 0.0487

# %%
eval_episodes = 200

results_eval = []
scores_eval = []

for ep in range(eval_episodes):
    obs, info = env.reset()
    user_histories = {
        u: deque(
            [np.zeros(n * n) for _ in range(window_len)], 
            maxlen=window_len
        ) for u in range(n_users)
    }

    enhanced_hits = enhanced_misses = 0
    base_hits = base_misses = 0
    total_reward = 0.0
    avg_psnr = []

    for step in count():
        reqs_state = info["users_requests"]
        active_users = [
            (req["u"], req["video"], req["gop"])
            for req in reqs_state
            if req["gop"] < n_gops
        ]

        actions = []
        user_action_indices = {}

        for u, video, gop in active_users:
            cur_state_seq = np.array(user_histories[u])
            center_idx, _ = agent.select_optimal_action(cur_state_seq)
            user_action_indices[u] = center_idx

            if center_idx == n_tiles:
                predicted_viewport = np.zeros(n * n, dtype=int)
            else:
                predicted_viewport = index_to_fov_mask(center_idx=center_idx, n=n)

            actions.append({
                "user": u, 
                "gop": gop, 
                "video": video, 
                "tiles": predicted_viewport
            })

        obs, rewards, done, info = env.step(actions)

        total_reward += float(rewards)
        enhanced_hits += info["enh_layer_cache_hits"]
        enhanced_misses += info["enh_layer_cache_misses"]
        base_hits += info["base_layer_cache_hits"]
        base_misses += info["base_layer_cache_misses"]
        avg_psnr.append(info.get("average_psnr", 0.0))

        step_reward = float(rewards) / max(1, len(active_users))
        reqs_next_state = info["users_requests"]

        for u, video, gop in active_users:
            state_seq = np.array(user_histories[u])
            target_indices = [
                tile["tile"]
                for req in reqs_next_state
                if req["u"] == u
                for tile in req["tiles"]
                if tile["layer"] == 1
            ]
            actual_viewport = np.array([1 if i in target_indices else 0 for i in range(n * n)])

            user_histories[u].append(actual_viewport)
            next_state_seq = np.array(user_histories[u])
            dones = gop == n_gops

            agent.memory.push(
                state_seq, 
                user_action_indices[u], 
                step_reward, 
                next_state_seq, 
                dones
            )

        agent.train_step()

        if done:
            break

    if ep % 5 == 0:
        agent.update_target_network()

    avg_psnr = [x for x in avg_psnr if x != 0.0]
    cache_hits_ep = enhanced_hits + base_hits
    cache_misses_ep = enhanced_misses + base_misses

    print(
        f"Episode {ep+1}/{eval_episodes} | "
        f"Reward: {total_reward:.2f} | "
        f"Cache_hit(H/M): {cache_hits_ep}/{cache_misses_ep} | "
        f"Enhanced(H/M): {enhanced_hits}/{enhanced_misses} | "
        f"Base(H/M): {base_hits}/{base_misses} | "
        f"Avg PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}"
    )

    scores_eval.append(total_reward)
    results_eval.append({
        "episode": ep, 
        "cache_hits": cache_hits_ep, 
        "cache_misses": cache_misses_ep, 
        "reward": total_reward
    })
    
    filename_eval = (
        f"fov_predictor_opt_E{eval_episodes}_W{window_len}_"
        f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
        f"cap{int(max_capacity/1e6)}MB_AR{arrival_rate}.csv"
    )
    
    save_training_results(
        path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
        # path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
        filename=filename_eval,
        ep=ep,
        total_reward=total_reward,
        cache_hits=cache_hits_ep,
        cache_misses=cache_misses_ep,
        enhanced_layer_cache_hits=enhanced_hits,
        enhanced_layer_cache_misses=enhanced_misses,
        base_layer_cache_hits=base_hits,
        base_layer_cache_misses=base_misses,
        avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
        agent=agent
    )
# Out:
# Episode 1/200 | Reward: 5629.88 | Cache_hit(H/M): 106058/14754 | Enhanced(H/M): 11562/13250 | Base(H/M): 94496/1504 | Avg PSNR: 37.69
# Episode 2/200 | Reward: 5476.86 | Cache_hit(H/M): 105623/15075 | Enhanced(H/M): 11191/13507 | Base(H/M): 94432/1568 | Avg PSNR: 37.60
# Episode 3/200 | Reward: 4201.27 | Cache_hit(H/M): 103016/17868 | Enhanced(H/M): 11064/13820 | Base(H/M): 91952/4048 | Avg PSNR: 36.86
# Episode 4/200 | Reward: 5334.13 | Cache_hit(H/M): 105131/15730 | Enhanced(H/M): 11323/13538 | Base(H/M): 93808/2192 | Avg PSNR: 37.83
# Episode 5/200 | Reward: 4726.90 | Cache_hit(H/M): 103861/17007 | Enhanced(H/M): 10981/13887 | Base(H/M): 92880/3120 | Avg PSNR: 37.44
# Episode 6/200 | Reward: 4365.86 | Cache_hit(H/M): 103443/17315 | Enhanced(H/M): 11651/13107 | Base(H/M): 91792/4208 | Avg PSNR: 37.42
# Episode 188/200 | Reward: 6060.64 | Cache_hit(H/M): 106418/14526 | Enhanced(H/M): 11602/13342 | Base(H/M): 94816/1184 | Avg PSNR: 37.94
# Episode 189/200 | Reward: 4969.47 | Cache_hit(H/M): 104841/15979 | Enhanced(H/M): 11753/13067 | Base(H/M): 93088/2912 | Avg PSNR: 37.62
# Episode 190/200 | Reward: 4480.00 | Cache_hit(H/M): 102771/17915 | Enhanced(H/M): 11219/13467 | Base(H/M): 91552/4448 | Avg PSNR: 37.39
# Episode 191/200 | Reward: 5554.37 | Cache_hit(H/M): 105600/15126 | Enhanced(H/M): 11168/13558 | Base(H/M): 94432/1568 | Avg PSNR: 37.61
# Episode 192/200 | Reward: 1632.22 | Cache_hit(H/M): 97975/22982 | Enhanced(H/M): 10295/14662 | Base(H/M): 87680/8320 | Avg PSNR: 35.71
# Episode 193/200 | Reward: 5467.18 | Cache_hit(H/M): 105146/15662 | Enhanced(H/M): 11434/13374 | Base(H/M): 93712/2288 | Avg PSNR: 37.67
# Episode 194/200 | Reward: 6032.62 | Cache_hit(H/M): 106127/14931 | Enhanced(H/M): 11519/13539 | Base(H/M): 94608/1392 | Avg PSNR: 37.96
# Episode 195/200 | Reward: 4313.52 | Cache_hit(H/M): 102892/17826 | Enhanced(H/M): 10828/13890 | Base(H/M): 92064/3936 | Avg PSNR: 37.20
# Episode 196/200 | Reward: 3082.41 | Cache_hit(H/M): 101184/19587 | Enhanced(H/M): 10832/13939 | Base(H/M): 90352/5648 | Avg PSNR: 36.72
# Episode 197/200 | Reward: 6613.73 | Cache_hit(H/M): 107568/13268 | Enhanced(H/M): 12000/12836 | Base(H/M): 95568/432 | Avg PSNR: 38.37
# Episode 198/200 | Reward: 6963.51 | Cache_hit(H/M): 107921/12904 | Enhanced(H/M): 11921/12904 | Base(H/M): 96000/0 | Avg PSNR: 38.41
# Episode 199/200 | Reward: 4998.20 | Cache_hit(H/M): 104775/16051 | Enhanced(H/M): 11095/13731 | Base(H/M): 93680/2320 | Avg PSNR: 37.51
# Episode 200/200 | Reward: 5393.47 | Cache_hit(H/M): 105409/15425 | Enhanced(H/M): 11841/12993 | Base(H/M): 93568/2432 | Avg PSNR: 37.81

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# 1. Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_yscale('log') 
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# 2. Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_yscale('log') 
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# 3. Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_yscale('log')
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_373706/3657158268.py:17: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_373706/3657158268.py:27: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_373706/3657158268.py:37: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[2].set_ylim(bottom=0)

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]
    base_totals = [h + m for h, m in zip(base_hits, base_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]
    base_hit_rate = [safe_pct(h, t) for h, t in zip(base_hits, base_totals)]
    base_miss_rate = [safe_pct(m, t) for m, t in zip(base_misses, base_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)
    base_ylim = (0, 100)

    fig, axes = plt.subplots(3, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Base Layer: Hit rate
    axes[1, 0].plot(episodes, base_hit_rate, label="Base hit rate (%)", color="green", alpha=0.9)
    axes[1, 0].set_title("Base Layer Hit Rate")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Rate (%)")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Base Layer: Miss rate
    axes[1, 1].plot(episodes, base_miss_rate, label="Base miss rate (%)", color="orange", alpha=0.9)
    axes[1, 1].set_title("Base Layer Miss Rate")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Rate (%)")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    # Reward title
    axes[2, 0].plot(episodes, rewards, label="Episode reward", color="purple", alpha=0.9)
    axes[2, 0].set_title("Episode Rewards")
    axes[2, 0].set_xlabel("Episode")
    axes[2, 0].set_ylabel("Reward")
    axes[2, 0].grid(True, alpha=0.3)
    axes[2, 0].legend()

    # Average PSNR
    axes[2, 1].plot(episodes, psnr, label="Average PSNR", color="brown", alpha=0.9)
    axes[2, 1].set_title("Average PSNR per Episode")
    axes[2, 1].set_xlabel("Episode")
    axes[2, 1].set_ylabel("PSNR (dB)")
    axes[2, 1].grid(True, alpha=0.3)
    axes[2, 1].legend()


    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.0.csv'
    
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 143
#     139 out_path = None
#     141 title = "FOV Predictor DQN Agent Cache Layers Performance"
# --> 143 plot_cache_layers(
#     144     csv_filepath,
#     145     out_path=None,
#     146     title=title
#     147 )
#
# Cell In[21], line 52, in plot_cache_layers(csv_path, out_path, title)
#      47 def plot_cache_layers(
#      48     csv_path: str,
#      49     out_path: str | None = None,
#      50     title: str | None = None,
#      51 ):
# ---> 52     episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)
#      54     # Compute per-episode percentages
#      55     def safe_pct(num, den):
#
# Cell In[21], line 11, in read_results(csv_path)
#       8 avg_psnr: List[float] = []
#      10 if not os.path.exists(csv_path):
# ---> 11     raise FileNotFoundError(f"CSV file not found: {csv_path}")
#      13 with open(csv_path, "r", newline="") as f:
#      14     reader = csv.DictReader(f)
#
# FileNotFoundError: CSV file not found: c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.0.csv

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Reward title
    axes[1, 0].plot(episodes, rewards, label="Episode reward", color="purple", alpha=0.9)
    axes[1, 0].set_title("Episode Rewards")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Reward")
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Average PSNR
    axes[1, 1].plot(episodes, psnr, label="Average PSNR", color="brown", alpha=0.9)
    axes[1, 1].set_title("Average PSNR per Episode")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("PSNR (dB)")
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.0.csv'
    
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []
    rewards: List[float] = []
    avg_psnr: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
            "total_reward",
            "average_psnr"
        ]
        
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
                rewards.append(float(row["total_reward"]))
                avg_psnr.append(float(row["average_psnr"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, avg_psnr


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses, rewards, psnr = read_results(csv_path)

    csv_path_lsr = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_path_lsr += r'\fov_lsr_U100_V100_G60_L2_N4_cap500MB_AR15.csv'

    episodes_lsr, enhanced_hits_lsr, enhanced_misses_lsr, base_hits_lsr, base_misses_lsr, rewards_lsr, psnr_lsr = read_results(csv_path_lsr)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(18, 16))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="DRL-LRU", color="blue", alpha=0.9)
    axes[0, 0].plot(episodes_lsr, [safe_pct(h, h + m) for h, m in zip(enhanced_hits_lsr, enhanced_misses_lsr)], label="LSR-LRU", color="red")
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="DRL-LRU", color="blue", alpha=0.9)
    axes[0, 1].plot(episodes_lsr, [safe_pct(m, h + m) for h, m in zip(enhanced_hits_lsr, enhanced_misses_lsr)], label="LSR-LRU", color="red")
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Reward title
    axes[1, 0].plot(episodes, rewards, label="DRL-LRU", color="blue", alpha=0.9)
    axes[1, 0].set_title("Rewards")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Reward")
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Average PSNR
    axes[1, 1].plot(episodes, psnr, label="DRL-LRU", color="blue", alpha=0.9)
    axes[1, 1].plot(episodes_lsr, psnr_lsr, label="LSR-LRU", color="red")
    axes[1, 1].set_title("Average PSNR")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("PSNR (dB)")
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    # csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results'
    csv_filepath += r'\fov_predictor_U100_V100_G60_L2_N4_cap500MB_AR15.csv'
    
    out_path = None

    title = "FOV Predictor Double DQN Agent Cache Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
