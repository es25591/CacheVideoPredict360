# %%
import math
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from itertools import count
from importnb import Notebook

with Notebook():
    from LabLatencyModel import LatencyModel
    from LabCacheEngine import CacheEngineEnv
    from LabUserTileRequest import UserTileRequestEvents

# %%
class EnvWrapper(gym.Env):
    """
    Simple wrapper that delegates all calls to an inner env.
    Subclass this to create your own wrappers.
    """

    def __init__(
        self, 
        n: int,
        n_layers: int,
        lam: float,
        theta: float,
        users_env: None,
        du_caches: None,
        mec_cache: None,
        latency_model: None 
    ):
        super().__init__()

        self.step_count = 0

        self.n = n  # number of tiles per row/column
        self.n_layers = n_layers  # number of layers (base + enhancement)
        
        self.gain_if_prefetched = 1.0
        self.loss_if_not_prefetched = -1.0

        self.theta = theta
        self.lam = lam

        self.users_env = users_env
        self.du_caches = du_caches
        self.mec_cache = mec_cache
        self.latency_model = latency_model

    def sample_action(self):
        n_users = self.users_env.n_users
        
        tiles = np.zeros(self.n * self.n, dtype=int)
        c = self.n // 2
        if self.n % 2 == 1:
            center_idx = c * self.n + c
            tiles[center_idx] = 1
        else:
            centers = [(c-1, c-1), (c-1, c), (c, c-1), (c, c)]
            for y, x in centers:
                tiles[y * self.n + x] = 1

        return [
            {
                'user': u,
                'video': np.random.randint(0, self.users_env.n_videos),
                'gop': np.random.randint(0, self.users_env.n_gops),
                'tiles': tiles.tolist()
            } for u in range(n_users)
        ]

    def step(self, action):
        reward = 0.0
        info = {}

        ### STEP 1: prefetching segments in the cache based on action taken ###        
        du_bitmaps = [ 
            cache.process_cache_prefetching(action) for cache in self.du_caches
        ] if self.du_caches else None
        mec_bitmap = self.mec_cache.process_cache_prefetching(action) if self.mec_cache else None

        ### STEP 2: Generate user requests ###
        reqs = self.users_env.step(du_bitmaps, mec_bitmap)
        info['users_requests'] = reqs

        users_per_node = {}
        for req in reqs:
            p_node = req["p"]
            users_per_node[p_node] = users_per_node.get(p_node, 0) + 1

        ### STEP 2.1: Compute Content Popularity Distribution ###
        for cache in self.du_caches:
            cache.update_content_popularity(reqs)
        info['content_popularity'] = [cache.get_content_popularity() for cache in self.du_caches]

        # print(f"Step {self.step_count}: Generated {len(reqs)} user requests.")
        # for req in reqs:
        #     print(
        #         f"  User {req['u']} requested video {req['video']} GOP {req['gop']} with {len(req['tiles'])} tiles."
        #     )

        ### STEP 3: compute latencies for each request ###
        total_latency = 0.0
        users_tiles_received = {}
        for req in reqs:
            p = req["p"]
            u = req["u"]
            tiles = req["tiles"]

            active_users_on_node = users_per_node.get(p, 1)
            
            req_latency, tile_latencies = self.latency_model.total_request_latency(
                p,
                u,
                tiles,
                active_users_on_node
            )

            total_latency += req_latency
            users_tiles_received[u] = tile_latencies

            # print(
            #     f"Step {self.step_count} User {u}, DU {p}, total latency: {req_latency:.4f}s, tiles requested: {len(tiles)}, tiles received: {len(tile_latencies)}"
            # )

            # print(
            #     f"User {u}, DU {p}, total latency: {req_latency:.4f}s, tiles requested: {len(tiles)}, tiles received: {len(tile_latencies)}"
            # )

        ### STEP 4: Calculate metrics: cache hits and misses, and reward ###
        cache_stats = self.compute_cache_stats(reqs)
        info.update(cache_stats)

        cache_current_capacity = sum(cache.get_current_capacity() for cache in self.du_caches) if self.du_caches else 0
        cache_current_capacity += self.mec_cache.get_current_capacity() if self.mec_cache else 0

        cache_total_capacity = sum(cache.max_capacity for cache in self.du_caches) if self.du_caches else 0
        cache_total_capacity += self.mec_cache.max_capacity if self.mec_cache else 0

        ### STEP 4.1: Compute QoE-based requests completed ###
        avg_psnr = 0.0
        for req in reqs:
            u = req["u"]
            tiles = req["tiles"]
            tile_latencies = users_tiles_received.get(u, [])
            tile_latency_dict = {
                (tid, layer): lat for (tid, layer, lat) in tile_latencies
            }

            psnr_sum = 0.0
            sum_tiles = 0
            for tile in tiles:
                tid = tile["tile"]
                layer = tile["layer"]
                
                psnr = 0.0    
                if layer == 1:
                    if (tid, 0) in tile_latency_dict:
                        psnr += 30.0
                    if (tid, 1) in tile_latency_dict:
                        psnr += 10.0
                    
                    sum_tiles += 1
                psnr_sum += psnr
            
            avg_psnr += psnr_sum / sum_tiles if sum_tiles else 0.0
        avg_psnr /= len(reqs) if reqs else 1.0

        info['average_psnr'] = avg_psnr
        info['cache_current_capacity'] = cache_current_capacity
        info['cache_total_capacity'] = cache_total_capacity
        info['cache_utilization'] = (cache_current_capacity / cache_total_capacity) if cache_total_capacity else 0.0
        info['cache_num_items'] = sum(cache.policy.get_stats().get('num_items', 0) for cache in self.du_caches)

        # compute reward for this video's action and add
        total_requests = sum(len(req.get('tiles', [])) for req in reqs)
        
        # Compute current_p: probability for each (vid, tile_idx) based on requests
        tile_counts = {}
        for req in reqs:
            vid = req["video"]
            tiles = req["tiles"]
            for tile in tiles:
                key = (vid, tile['layer'], tile['tile'])
                tile_counts[key] = tile_counts.get(key, 0) + 1

        # Normalize by total_requests to get probabilities
        current_p = {
            key: count / total_requests
            for key, count in tile_counts.items()
        }
    
        reward += self.compute_expected_cpt_reward(
            current_p=current_p,
            requests=reqs
        )

        done = (self.users_env.users_done >= self.users_env.n_users)

        self.step_count += 1
        return {}, reward, done, info

    def compute_cache_stats(self, reqs):
        enh_layer_cache_hits = 0
        base_layer_cache_hits = 0
        enh_layer_cache_misses = 0
        base_layer_cache_misses = 0
        
        for req in reqs:
            tiles = req['tiles']
            for tile in tiles:
                layer = tile['layer']
                # hit = tile['events']['alpha_p_u']
                hit = tile['events']['alpha_M_u']  # Considering MEC cache hits

                if layer == 0 and hit == 1:
                    base_layer_cache_hits += 1
                elif layer == 1 and hit == 1:
                    enh_layer_cache_hits += 1
                elif layer == 0 and hit == 0:
                    base_layer_cache_misses += 1
                elif layer == 1 and hit == 0:
                    enh_layer_cache_misses += 1

        return {
            'base_layer_cache_hits': int(base_layer_cache_hits),
            'enh_layer_cache_hits': int(enh_layer_cache_hits),
            'base_layer_cache_misses': int(base_layer_cache_misses),
            'enh_layer_cache_misses': int(enh_layer_cache_misses)
        }

    def compute_expected_cpt_reward(
        self, 
        current_p, 
        requests
    ) -> float:
        expected_reward = 0.0
        requested_tile_keys = set()
        for request in requests:
            vid = request['video']
            tiles = request['tiles']

            for tile in tiles:
                layer = tile['layer']
                tile_idx = tile['tile']
                tile_key = (vid, layer, tile_idx)
                
                p = float(current_p.get(tile_key, 0.0))
                w = self.prelec_w(p, theta=self.theta)

                prefetch = tile['events']['alpha_p_u']
                
                if prefetch == 1:
                    expected_outcome = self.gain_if_prefetched
                    requested_tile_keys.add(tile_key)
                else:
                    expected_outcome = self.loss_if_not_prefetched
                
                v = self.cpt_value(expected_outcome, lam=self.lam)
                expected_reward += w * v

        return float(expected_reward)

    def prelec_w(self, p: float, theta: float = 0.65) -> float:
        if p <= 0.0: return 0.0
        if p >= 1.0: return 1.0
        return math.exp(-((-math.log(p)) ** theta))

    def cpt_value(
        self,
        x: float, 
        lam: float = 1.5
    ) -> float:
        if x >= 0:
            return x
        else:
            return -lam * (-x)

    def reset(self, **kwargs):
        self.step_count = 0

        _, info_users = self.users_env.reset(**kwargs)
        info_cache_list = [cache.reset(**kwargs)[1] for cache in self.du_caches] if self.du_caches else []
        info_cache = {'du_caches_info': info_cache_list}
        # self.latency_model.reset(**kwargs)
        
        info = {
            **info_users, 
            **info_cache
        }

        return None, info

# %%
def getTiles(step, user, users_viewport_tiles, n) -> np.ndarray:
    mask = np.zeros(n * n, dtype=int)    
    for tx, ty in users_viewport_tiles[user][step]:
        if 0 <= tx < n and 0 <= ty < n:
            mask[ty * n + tx] = 1
    
    return mask

# %%
if __name__ == "__main__":
    n_episodes = 100
    n_nodes = 3
    n_users = 100
    step_size = 5.0
    alpha = 1.0
    n_gops = 60
    n_layers = 2
    n = 4
    max_capacity = 5000e6  # 5000 MB
    n_videos = 1000

    #### CPT parameters ####
    lam = 3.7183
    theta = 0.5

    users_env = UserTileRequestEvents(
        n_nodes=n_nodes,
        n_users=n_users,
        step_size=step_size,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n*n,
        n=n,
        alpha=alpha,
        users_viewport_tiles=None,
        requested_videos=None
    )

    # du_caches = [ 
    #     CacheEngineEnv(
    #         n_tiles=n*n,
    #         n_videos=n_videos,
    #         cache_capacity=max_capacity
    #     ) for _ in range(n_nodes)  # Number of DUs = n_nodes
    # ]
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_tiles=n*n,
        n_videos=n_videos,
        cache_capacity=max_capacity
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = LatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,       # 640 Mbps -> 80e6 B/s 
        R_C_M=1.25e9,     # 10 Gbps -> 1.25e9 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 40e6, dtype=float),    # 320 Mbps -> 40e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,    # 1 ms
        mec_fixed_delay=0.005,   # 5 ms
        cloud_fixed_delay=0.05   # 50 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        lam=lam,
        theta=theta
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    _, info = env.reset()
    viewport_tiles = info['viewport_tiles']
    requested_videos = info['requested_videos']

    done = False
    results = []
    total_reward = 0.0

    for step in count():
        actions = [
            {
                'user': user,
                'video': requested_videos[user],
                'tiles': getTiles(step % n_gops, user, viewport_tiles, n),
                'gop': step % n_gops
            } for user in range(n_users)
        ]

        obs, reward, done, info = env.step(actions)

        total_reward += float(reward)

        results.append({
            "step": step,
            "total_reward": total_reward,
            "cache_hits": info["base_layer_cache_hits"] + info["enh_layer_cache_hits"],
            "cache_misses": info["base_layer_cache_misses"] + info["enh_layer_cache_misses"],
            "info": info
        })

        print(
            f"Step {step} - "
            f"Reward: {reward:.4f} - "
            f"Total Reward: {total_reward:.4f} - "
            f"Cache Hits: {info['base_layer_cache_hits'] + info['enh_layer_cache_hits']} - "
            f"Cache Misses: {info['base_layer_cache_misses'] + info['enh_layer_cache_misses']}\n"
            f"Cache Utilization: {info['cache_utilization']:.2%} - "
            f"Items in Cache: {info['cache_num_items']} - "
            f"Final Capacity: {info['cache_current_capacity']/1e6:.2f}/{info['cache_total_capacity']/1e6:.1f} MB"
        )
        
        if done: 
            break
# Out:
# Experiment ===================
# Total users: 100
# Cache capacity: 5000000000.0MB
# Video matrix: 1000x2x16
# ==============================
#
# Step 0 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 7.28% - Items in Cache: 0 - Final Capacity: 364.12/5000.0 MB
# Step 1 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 15.20% - Items in Cache: 0 - Final Capacity: 760.12/5000.0 MB
# Step 2 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 23.27% - Items in Cache: 0 - Final Capacity: 1163.62/5000.0 MB
# Step 3 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 31.42% - Items in Cache: 0 - Final Capacity: 1570.88/5000.0 MB
# Step 4 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 39.64% - Items in Cache: 0 - Final Capacity: 1981.88/5000.0 MB
# Step 5 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 47.78% - Items in Cache: 0 - Final Capacity: 2389.12/5000.0 MB
# Step 6 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 55.82% - Items in Cache: 0 - Final Capacity: 2790.75/5000.0 MB
# Step 7 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 64.00% - Items in Cache: 0 - Final Capacity: 3199.88/5000.0 MB
# Step 8 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 72.12% - Items in Cache: 0 - Final Capacity: 3606.19/5000.0 MB
# Step 9 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 80.47% - Items in Cache: 0 - Final Capacity: 4023.75/5000.0 MB
# Step 10 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 88.75% - Items in Cache: 0 - Final Capacity: 4437.56/5000.0 MB
# Step 11 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 96.95% - Items in Cache: 0 - Final Capacity: 4847.62/5000.0 MB
# Step 12 - Reward: -13.1731 - Total Reward: -13.1731 - Cache Hits: 0 - Cache Misses: 20
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 13 - Reward: -13.1731 - Total Reward: -26.3463 - Cache Hits: 0 - Cache Misses: 20
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 14 - Reward: -29.4933 - Total Reward: -55.8396 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 15 - Reward: -29.4933 - Total Reward: -85.3329 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 16 - Reward: -29.4933 - Total Reward: -114.8261 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 17 - Reward: -30.9637 - Total Reward: -145.7898 - Cache Hits: 0 - Cache Misses: 64
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 18 - Reward: -36.6702 - Total Reward: -182.4600 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 19 - Reward: -43.4874 - Total Reward: -225.9474 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 20 - Reward: -44.1532 - Total Reward: -270.1006 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 21 - Reward: -43.4874 - Total Reward: -313.5879 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 22 - Reward: -44.1532 - Total Reward: -357.7411 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 23 - Reward: -44.1532 - Total Reward: -401.8943 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 24 - Reward: -50.6774 - Total Reward: -452.5716 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 25 - Reward: -50.6774 - Total Reward: -503.2490 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 26 - Reward: -56.9928 - Total Reward: -560.2418 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 27 - Reward: -57.6144 - Total Reward: -617.8562 - Cache Hits: 0 - Cache Misses: 144
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 28 - Reward: -63.1361 - Total Reward: -680.9923 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 29 - Reward: -62.5287 - Total Reward: -743.5210 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 30 - Reward: -63.7421 - Total Reward: -807.2631 - Cache Hits: 0 - Cache Misses: 164
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 31 - Reward: -62.5287 - Total Reward: -869.7918 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 32 - Reward: -63.7421 - Total Reward: -933.5338 - Cache Hits: 0 - Cache Misses: 164
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.75/5000.0 MB
# Step 33 - Reward: -62.5287 - Total Reward: -996.0626 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.19/5000.0 MB
# Step 34 - Reward: -68.5400 - Total Reward: -1064.6025 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 35 - Reward: -68.5400 - Total Reward: -1133.1425 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 36 - Reward: -68.5400 - Total Reward: -1201.6825 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 37 - Reward: -68.5400 - Total Reward: -1270.2225 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 38 - Reward: -75.0059 - Total Reward: -1345.2284 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 39 - Reward: -75.0059 - Total Reward: -1420.2343 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 40 - Reward: -74.4239 - Total Reward: -1494.6581 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 41 - Reward: -74.4239 - Total Reward: -1569.0820 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 42 - Reward: -74.4239 - Total Reward: -1643.5058 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 43 - Reward: -75.0059 - Total Reward: -1718.5117 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 44 - Reward: -75.0059 - Total Reward: -1793.5176 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 45 - Reward: -80.1962 - Total Reward: -1873.7138 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 46 - Reward: -85.8695 - Total Reward: -1959.5833 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 47 - Reward: -86.4318 - Total Reward: -2046.0151 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 48 - Reward: -86.4318 - Total Reward: -2132.4470 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 49 - Reward: -85.8695 - Total Reward: -2218.3165 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.31/5000.0 MB
# Step 50 - Reward: -92.0081 - Total Reward: -2310.3246 - Cache Hits: 0 - Cache Misses: 262
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 51 - Reward: -92.0081 - Total Reward: -2402.3328 - Cache Hits: 0 - Cache Misses: 262
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 52 - Reward: -92.0081 - Total Reward: -2494.3409 - Cache Hits: 0 - Cache Misses: 262
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 53 - Reward: -91.4542 - Total Reward: -2585.7951 - Cache Hits: 0 - Cache Misses: 260
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 54 - Reward: -92.0081 - Total Reward: -2677.8033 - Cache Hits: 0 - Cache Misses: 262
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 55 - Reward: -93.1136 - Total Reward: -2770.9169 - Cache Hits: 0 - Cache Misses: 266
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 56 - Reward: -92.5613 - Total Reward: -2863.4782 - Cache Hits: 0 - Cache Misses: 264
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 57 - Reward: -92.0081 - Total Reward: -2955.4863 - Cache Hits: 0 - Cache Misses: 262
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 58 - Reward: -92.0081 - Total Reward: -3047.4945 - Cache Hits: 0 - Cache Misses: 262
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 59 - Reward: -93.1136 - Total Reward: -3140.6081 - Cache Hits: 0 - Cache Misses: 266
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 60 - Reward: -92.5613 - Total Reward: -3233.1694 - Cache Hits: 0 - Cache Misses: 264
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 61 - Reward: -91.4542 - Total Reward: -3324.6236 - Cache Hits: 0 - Cache Misses: 260
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 62 - Reward: -92.5613 - Total Reward: -3417.1849 - Cache Hits: 0 - Cache Misses: 264
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 63 - Reward: -97.5050 - Total Reward: -3514.6899 - Cache Hits: 20 - Cache Misses: 262
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 64 - Reward: -97.5050 - Total Reward: -3612.1949 - Cache Hits: 20 - Cache Misses: 262
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 65 - Reward: -96.9587 - Total Reward: -3709.1536 - Cache Hits: 20 - Cache Misses: 260
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 66 - Reward: -97.5050 - Total Reward: -3806.6586 - Cache Hits: 20 - Cache Misses: 262
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 67 - Reward: -97.5050 - Total Reward: -3904.1636 - Cache Hits: 20 - Cache Misses: 262
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 68 - Reward: -104.3758 - Total Reward: -4008.5395 - Cache Hits: 40 - Cache Misses: 260
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 69 - Reward: -104.3758 - Total Reward: -4112.9153 - Cache Hits: 40 - Cache Misses: 260
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 70 - Reward: -104.2655 - Total Reward: -4217.1808 - Cache Hits: 40 - Cache Misses: 260
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 71 - Reward: -104.6909 - Total Reward: -4321.8718 - Cache Hits: 40 - Cache Misses: 262
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 72 - Reward: -99.3045 - Total Reward: -4421.1762 - Cache Hits: 40 - Cache Misses: 242
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 73 - Reward: -99.3045 - Total Reward: -4520.4807 - Cache Hits: 40 - Cache Misses: 242
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 74 - Reward: -92.5613 - Total Reward: -4613.0420 - Cache Hits: 40 - Cache Misses: 224
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 75 - Reward: -92.0081 - Total Reward: -4705.0501 - Cache Hits: 40 - Cache Misses: 222
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 76 - Reward: -91.4542 - Total Reward: -4796.5043 - Cache Hits: 40 - Cache Misses: 220
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 77 - Reward: -92.0081 - Total Reward: -4888.5125 - Cache Hits: 40 - Cache Misses: 222
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 78 - Reward: -86.4318 - Total Reward: -4974.9443 - Cache Hits: 40 - Cache Misses: 202
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 79 - Reward: -80.7678 - Total Reward: -5055.7121 - Cache Hits: 40 - Cache Misses: 182
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 80 - Reward: -81.3384 - Total Reward: -5137.0505 - Cache Hits: 40 - Cache Misses: 184
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 81 - Reward: -80.1962 - Total Reward: -5217.2466 - Cache Hits: 40 - Cache Misses: 180
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 82 - Reward: -80.7678 - Total Reward: -5298.0144 - Cache Hits: 40 - Cache Misses: 182
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 83 - Reward: -80.7678 - Total Reward: -5378.7822 - Cache Hits: 40 - Cache Misses: 182
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 84 - Reward: -74.4239 - Total Reward: -5453.2060 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 85 - Reward: -74.4239 - Total Reward: -5527.6299 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 86 - Reward: -68.5400 - Total Reward: -5596.1699 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 87 - Reward: -69.1338 - Total Reward: -5665.3037 - Cache Hits: 40 - Cache Misses: 142
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 88 - Reward: -63.1361 - Total Reward: -5728.4398 - Cache Hits: 40 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 89 - Reward: -63.1361 - Total Reward: -5791.5759 - Cache Hits: 40 - Cache Misses: 122
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 90 - Reward: -62.5287 - Total Reward: -5854.1046 - Cache Hits: 40 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 91 - Reward: -62.5287 - Total Reward: -5916.6333 - Cache Hits: 40 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 92 - Reward: -68.5400 - Total Reward: -5985.1733 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.75/5000.0 MB
# Step 93 - Reward: -69.1338 - Total Reward: -6054.3071 - Cache Hits: 40 - Cache Misses: 142
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.19/5000.0 MB
# Step 94 - Reward: -62.5287 - Total Reward: -6116.8358 - Cache Hits: 40 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 95 - Reward: -68.5400 - Total Reward: -6185.3758 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 96 - Reward: -68.5400 - Total Reward: -6253.9158 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 97 - Reward: -68.5400 - Total Reward: -6322.4558 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 98 - Reward: -62.5287 - Total Reward: -6384.9845 - Cache Hits: 40 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 99 - Reward: -62.5287 - Total Reward: -6447.5132 - Cache Hits: 40 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 100 - Reward: -76.9340 - Total Reward: -6524.4473 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 101 - Reward: -76.9340 - Total Reward: -6601.3813 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 102 - Reward: -77.2577 - Total Reward: -6678.6390 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 103 - Reward: -76.6830 - Total Reward: -6755.3220 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 104 - Reward: -77.0075 - Total Reward: -6832.3295 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 105 - Reward: -70.8788 - Total Reward: -6903.2083 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 106 - Reward: -76.9340 - Total Reward: -6980.1424 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 107 - Reward: -77.5079 - Total Reward: -7057.6503 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 108 - Reward: -77.2577 - Total Reward: -7134.9080 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 109 - Reward: -77.2577 - Total Reward: -7212.1657 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.31/5000.0 MB
# Step 110 - Reward: -71.4641 - Total Reward: -7283.6298 - Cache Hits: 40 - Cache Misses: 142
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 111 - Reward: -70.8788 - Total Reward: -7354.5086 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 112 - Reward: -71.4641 - Total Reward: -7425.9727 - Cache Hits: 40 - Cache Misses: 142
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 113 - Reward: -71.4641 - Total Reward: -7497.4368 - Cache Hits: 40 - Cache Misses: 142
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 114 - Reward: -71.1387 - Total Reward: -7568.5755 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 115 - Reward: -70.8788 - Total Reward: -7639.4543 - Cache Hits: 40 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 116 - Reward: -76.6830 - Total Reward: -7716.1373 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 117 - Reward: -77.2577 - Total Reward: -7793.3950 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 118 - Reward: -76.4320 - Total Reward: -7869.8270 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 119 - Reward: -78.1555 - Total Reward: -7947.9825 - Cache Hits: 40 - Cache Misses: 166
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 120 - Reward: -77.8314 - Total Reward: -8025.8140 - Cache Hits: 42 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 121 - Reward: -76.6830 - Total Reward: -8102.4970 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 122 - Reward: -83.1944 - Total Reward: -8185.6914 - Cache Hits: 60 - Cache Misses: 162
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 123 - Reward: -78.0808 - Total Reward: -8263.7722 - Cache Hits: 40 - Cache Misses: 164
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 124 - Reward: -77.2577 - Total Reward: -8341.0299 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 125 - Reward: -76.6830 - Total Reward: -8417.7130 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 126 - Reward: -77.2577 - Total Reward: -8494.9707 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 127 - Reward: -77.8314 - Total Reward: -8572.8021 - Cache Hits: 40 - Cache Misses: 164
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 128 - Reward: -69.1338 - Total Reward: -8641.9359 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 129 - Reward: -69.1338 - Total Reward: -8711.0697 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 130 - Reward: -69.7264 - Total Reward: -8780.7961 - Cache Hits: 20 - Cache Misses: 164
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 131 - Reward: -70.3177 - Total Reward: -8851.1139 - Cache Hits: 22 - Cache Misses: 164
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 132 - Reward: -70.3177 - Total Reward: -8921.4316 - Cache Hits: 20 - Cache Misses: 166
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 133 - Reward: -69.1338 - Total Reward: -8990.5654 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 134 - Reward: -62.5287 - Total Reward: -9053.0941 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 135 - Reward: -63.1361 - Total Reward: -9116.2302 - Cache Hits: 20 - Cache Misses: 142
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 136 - Reward: -63.1361 - Total Reward: -9179.3663 - Cache Hits: 20 - Cache Misses: 142
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 137 - Reward: -69.7264 - Total Reward: -9249.0927 - Cache Hits: 20 - Cache Misses: 164
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 138 - Reward: -82.3865 - Total Reward: -9331.4793 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 139 - Reward: -83.3951 - Total Reward: -9414.8743 - Cache Hits: 20 - Cache Misses: 204
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 140 - Reward: -82.6299 - Total Reward: -9497.5042 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 141 - Reward: -82.2648 - Total Reward: -9579.7691 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 142 - Reward: -82.1432 - Total Reward: -9661.9122 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 143 - Reward: -82.7091 - Total Reward: -9744.6213 - Cache Hits: 20 - Cache Misses: 202
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 144 - Reward: -82.8304 - Total Reward: -9827.4517 - Cache Hits: 20 - Cache Misses: 202
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 145 - Reward: -82.3865 - Total Reward: -9909.8383 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 146 - Reward: -82.1432 - Total Reward: -9991.9814 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 147 - Reward: -83.5161 - Total Reward: -10075.4975 - Cache Hits: 20 - Cache Misses: 204
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 148 - Reward: -82.3865 - Total Reward: -10157.8840 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 149 - Reward: -82.2648 - Total Reward: -10240.1489 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 150 - Reward: -82.2648 - Total Reward: -10322.4137 - Cache Hits: 20 - Cache Misses: 200
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 151 - Reward: -82.7091 - Total Reward: -10405.1228 - Cache Hits: 20 - Cache Misses: 202
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 152 - Reward: -76.6830 - Total Reward: -10481.8058 - Cache Hits: 20 - Cache Misses: 180
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.75/5000.0 MB
# Step 153 - Reward: -76.4320 - Total Reward: -10558.2378 - Cache Hits: 20 - Cache Misses: 180
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.19/5000.0 MB
# Step 154 - Reward: -77.2577 - Total Reward: -10635.4955 - Cache Hits: 20 - Cache Misses: 182
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 155 - Reward: -70.8788 - Total Reward: -10706.3743 - Cache Hits: 20 - Cache Misses: 160
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 156 - Reward: -71.4641 - Total Reward: -10777.8384 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 157 - Reward: -77.5079 - Total Reward: -10855.3463 - Cache Hits: 20 - Cache Misses: 182
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 158 - Reward: -77.5079 - Total Reward: -10932.8542 - Cache Hits: 20 - Cache Misses: 182
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 159 - Reward: -77.5079 - Total Reward: -11010.3622 - Cache Hits: 20 - Cache Misses: 182
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 160 - Reward: -63.1361 - Total Reward: -11073.4983 - Cache Hits: 20 - Cache Misses: 142
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 161 - Reward: -62.5287 - Total Reward: -11136.0270 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 162 - Reward: -62.5287 - Total Reward: -11198.5557 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 163 - Reward: -74.4239 - Total Reward: -11272.9795 - Cache Hits: 20 - Cache Misses: 180
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 164 - Reward: -74.4239 - Total Reward: -11347.4034 - Cache Hits: 20 - Cache Misses: 180
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 165 - Reward: -81.3384 - Total Reward: -11428.7418 - Cache Hits: 20 - Cache Misses: 204
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 166 - Reward: -69.1338 - Total Reward: -11497.8756 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 167 - Reward: -69.1338 - Total Reward: -11567.0094 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 168 - Reward: -68.5400 - Total Reward: -11635.5494 - Cache Hits: 20 - Cache Misses: 160
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 169 - Reward: -68.5400 - Total Reward: -11704.0894 - Cache Hits: 20 - Cache Misses: 160
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.31/5000.0 MB
# Step 170 - Reward: -69.1338 - Total Reward: -11773.2232 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 171 - Reward: -69.1338 - Total Reward: -11842.3571 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 172 - Reward: -69.7264 - Total Reward: -11912.0834 - Cache Hits: 20 - Cache Misses: 164
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 173 - Reward: -69.1338 - Total Reward: -11981.2173 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 174 - Reward: -70.3177 - Total Reward: -12051.5350 - Cache Hits: 20 - Cache Misses: 166
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 175 - Reward: -76.1666 - Total Reward: -12127.7016 - Cache Hits: 22 - Cache Misses: 184
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 176 - Reward: -70.3177 - Total Reward: -12198.0194 - Cache Hits: 20 - Cache Misses: 166
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 177 - Reward: -70.3177 - Total Reward: -12268.3371 - Cache Hits: 20 - Cache Misses: 166
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 178 - Reward: -70.3177 - Total Reward: -12338.6548 - Cache Hits: 20 - Cache Misses: 166
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 179 - Reward: -70.3177 - Total Reward: -12408.9726 - Cache Hits: 22 - Cache Misses: 164
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 180 - Reward: -69.7264 - Total Reward: -12478.6990 - Cache Hits: 20 - Cache Misses: 164
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 181 - Reward: -70.6129 - Total Reward: -12549.3119 - Cache Hits: 20 - Cache Misses: 167
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 182 - Reward: -63.7421 - Total Reward: -12613.0540 - Cache Hits: 0 - Cache Misses: 164
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 183 - Reward: -63.1361 - Total Reward: -12676.1901 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 184 - Reward: -62.5287 - Total Reward: -12738.7188 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 185 - Reward: -62.5287 - Total Reward: -12801.2475 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 186 - Reward: -63.1361 - Total Reward: -12864.3836 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 187 - Reward: -63.7421 - Total Reward: -12928.1257 - Cache Hits: 0 - Cache Misses: 164
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 188 - Reward: -63.1361 - Total Reward: -12991.2618 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 189 - Reward: -63.1361 - Total Reward: -13054.3979 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 190 - Reward: -62.5287 - Total Reward: -13116.9266 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 191 - Reward: -69.1338 - Total Reward: -13186.0604 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 192 - Reward: -70.3177 - Total Reward: -13256.3781 - Cache Hits: 22 - Cache Misses: 164
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 193 - Reward: -70.3177 - Total Reward: -13326.6959 - Cache Hits: 20 - Cache Misses: 166
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 194 - Reward: -69.7264 - Total Reward: -13396.4223 - Cache Hits: 20 - Cache Misses: 164
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 195 - Reward: -69.1338 - Total Reward: -13465.5561 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 196 - Reward: -69.1338 - Total Reward: -13534.6899 - Cache Hits: 20 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 197 - Reward: -62.5287 - Total Reward: -13597.2186 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 198 - Reward: -59.1979 - Total Reward: -13656.4165 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 199 - Reward: -59.8075 - Total Reward: -13716.2240 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 200 - Reward: -58.9151 - Total Reward: -13775.1391 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 201 - Reward: -59.5260 - Total Reward: -13834.6651 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 202 - Reward: -59.5260 - Total Reward: -13894.1911 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 203 - Reward: -59.5260 - Total Reward: -13953.7172 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 204 - Reward: -58.9151 - Total Reward: -14012.6322 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 205 - Reward: -58.9151 - Total Reward: -14071.5473 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 206 - Reward: -60.7435 - Total Reward: -14132.2909 - Cache Hits: 20 - Cache Misses: 126
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 207 - Reward: -59.8075 - Total Reward: -14192.0983 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 208 - Reward: -59.8075 - Total Reward: -14251.9058 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 209 - Reward: -59.1979 - Total Reward: -14311.1038 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 210 - Reward: -59.1979 - Total Reward: -14370.3017 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 211 - Reward: -60.1355 - Total Reward: -14430.4372 - Cache Hits: 20 - Cache Misses: 124
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 212 - Reward: -59.2445 - Total Reward: -14489.6817 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.75/5000.0 MB
# Step 213 - Reward: -58.6322 - Total Reward: -14548.3140 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.19/5000.0 MB
# Step 214 - Reward: -58.6322 - Total Reward: -14606.9462 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 215 - Reward: -58.6322 - Total Reward: -14665.5784 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 216 - Reward: -58.6322 - Total Reward: -14724.2107 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 217 - Reward: -58.6322 - Total Reward: -14782.8429 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 218 - Reward: -58.6322 - Total Reward: -14841.4751 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 219 - Reward: -59.5260 - Total Reward: -14901.0012 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 220 - Reward: -61.0224 - Total Reward: -14962.0235 - Cache Hits: 20 - Cache Misses: 126
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 221 - Reward: -59.8075 - Total Reward: -15021.8310 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 222 - Reward: -58.9151 - Total Reward: -15080.7461 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 223 - Reward: -52.7205 - Total Reward: -15133.4666 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 224 - Reward: -59.5260 - Total Reward: -15192.9926 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 225 - Reward: -53.6440 - Total Reward: -15246.6366 - Cache Hits: 20 - Cache Misses: 102
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 226 - Reward: -53.0189 - Total Reward: -15299.6555 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 227 - Reward: -53.0189 - Total Reward: -15352.6744 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 228 - Reward: -53.0189 - Total Reward: -15405.6933 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 229 - Reward: -53.0189 - Total Reward: -15458.7123 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.31/5000.0 MB
# Step 230 - Reward: -62.3407 - Total Reward: -15521.0530 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 231 - Reward: -61.7435 - Total Reward: -15582.7964 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 232 - Reward: -61.6021 - Total Reward: -15644.3985 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 233 - Reward: -62.6222 - Total Reward: -15707.0207 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 234 - Reward: -62.3407 - Total Reward: -15769.3614 - Cache Hits: 20 - Cache Misses: 122
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 235 - Reward: -52.7205 - Total Reward: -15822.0819 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 236 - Reward: -52.7205 - Total Reward: -15874.8025 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 237 - Reward: -52.5713 - Total Reward: -15927.3738 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 238 - Reward: -52.5713 - Total Reward: -15979.9451 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 239 - Reward: -53.8249 - Total Reward: -16033.7701 - Cache Hits: 22 - Cache Misses: 102
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 240 - Reward: -53.3473 - Total Reward: -16087.1174 - Cache Hits: 20 - Cache Misses: 102
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 241 - Reward: -53.3473 - Total Reward: -16140.4647 - Cache Hits: 22 - Cache Misses: 100
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 242 - Reward: -52.7205 - Total Reward: -16193.1852 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 243 - Reward: -52.5713 - Total Reward: -16245.7566 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 244 - Reward: -52.5713 - Total Reward: -16298.3279 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 245 - Reward: -53.8249 - Total Reward: -16352.1528 - Cache Hits: 20 - Cache Misses: 104
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 246 - Reward: -52.5713 - Total Reward: -16404.7242 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 247 - Reward: -52.7205 - Total Reward: -16457.4447 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 248 - Reward: -52.7205 - Total Reward: -16510.1652 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 249 - Reward: -52.7205 - Total Reward: -16562.8858 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 250 - Reward: -63.7713 - Total Reward: -16626.6571 - Cache Hits: 40 - Cache Misses: 102
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 251 - Reward: -57.0014 - Total Reward: -16683.6585 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 252 - Reward: -57.0014 - Total Reward: -16740.6598 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 253 - Reward: -57.4537 - Total Reward: -16798.1135 - Cache Hits: 20 - Cache Misses: 102
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 254 - Reward: -56.8522 - Total Reward: -16854.9657 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 255 - Reward: -63.6919 - Total Reward: -16918.6576 - Cache Hits: 22 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 256 - Reward: -62.4567 - Total Reward: -16981.1142 - Cache Hits: 20 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 257 - Reward: -73.3455 - Total Reward: -17054.4597 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 258 - Reward: -73.8262 - Total Reward: -17128.2859 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 259 - Reward: -73.7504 - Total Reward: -17202.0363 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 260 - Reward: -74.0982 - Total Reward: -17276.1345 - Cache Hits: 20 - Cache Misses: 142
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 261 - Reward: -73.2696 - Total Reward: -17349.4042 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 262 - Reward: -74.5231 - Total Reward: -17423.9273 - Cache Hits: 20 - Cache Misses: 144
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 263 - Reward: -73.6196 - Total Reward: -17497.5469 - Cache Hits: 20 - Cache Misses: 142
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 264 - Reward: -73.9051 - Total Reward: -17571.4520 - Cache Hits: 20 - Cache Misses: 142
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 265 - Reward: -73.5565 - Total Reward: -17645.0084 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 266 - Reward: -73.3455 - Total Reward: -17718.3539 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 267 - Reward: -73.5565 - Total Reward: -17791.9104 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 268 - Reward: -73.2696 - Total Reward: -17865.1800 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 269 - Reward: -73.2696 - Total Reward: -17938.4497 - Cache Hits: 20 - Cache Misses: 140
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 270 - Reward: -73.8296 - Total Reward: -18012.2793 - Cache Hits: 20 - Cache Misses: 142
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 271 - Reward: -74.8655 - Total Reward: -18087.1449 - Cache Hits: 20 - Cache Misses: 144
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 272 - Reward: -79.9509 - Total Reward: -18167.0957 - Cache Hits: 20 - Cache Misses: 164
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.75/5000.0 MB
# Step 273 - Reward: -84.4267 - Total Reward: -18251.5224 - Cache Hits: 20 - Cache Misses: 180
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.19/5000.0 MB
# Step 274 - Reward: -84.9051 - Total Reward: -18336.4275 - Cache Hits: 20 - Cache Misses: 182
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# ...
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 579 - Reward: -80.7678 - Total Reward: -43104.6958 - Cache Hits: 40 - Cache Misses: 182
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 580 - Reward: -80.1962 - Total Reward: -43184.8920 - Cache Hits: 40 - Cache Misses: 180
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 581 - Reward: -80.1962 - Total Reward: -43265.0881 - Cache Hits: 40 - Cache Misses: 180
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 582 - Reward: -80.1962 - Total Reward: -43345.2843 - Cache Hits: 40 - Cache Misses: 180
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 583 - Reward: -75.5868 - Total Reward: -43420.8711 - Cache Hits: 42 - Cache Misses: 162
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 584 - Reward: -75.0059 - Total Reward: -43495.8769 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 585 - Reward: -74.4239 - Total Reward: -43570.3008 - Cache Hits: 40 - Cache Misses: 160
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 586 - Reward: -75.0059 - Total Reward: -43645.3067 - Cache Hits: 40 - Cache Misses: 162
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 587 - Reward: -75.5868 - Total Reward: -43720.8935 - Cache Hits: 40 - Cache Misses: 164
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 588 - Reward: -63.7421 - Total Reward: -43784.6355 - Cache Hits: 40 - Cache Misses: 124
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 589 - Reward: -56.9928 - Total Reward: -43841.6283 - Cache Hits: 40 - Cache Misses: 102
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.31/5000.0 MB
# Step 590 - Reward: -56.3695 - Total Reward: -43897.9978 - Cache Hits: 40 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 591 - Reward: -56.3695 - Total Reward: -43954.3674 - Cache Hits: 40 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 592 - Reward: -62.5287 - Total Reward: -44016.8961 - Cache Hits: 40 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 593 - Reward: -63.1361 - Total Reward: -44080.0322 - Cache Hits: 40 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 594 - Reward: -63.1361 - Total Reward: -44143.1683 - Cache Hits: 40 - Cache Misses: 122
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 595 - Reward: -63.1361 - Total Reward: -44206.3044 - Cache Hits: 40 - Cache Misses: 122
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 596 - Reward: -62.5287 - Total Reward: -44268.8331 - Cache Hits: 40 - Cache Misses: 120
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 597 - Reward: -56.3695 - Total Reward: -44325.2026 - Cache Hits: 40 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 598 - Reward: -56.3695 - Total Reward: -44381.5721 - Cache Hits: 40 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 599 - Reward: -57.6144 - Total Reward: -44439.1865 - Cache Hits: 40 - Cache Misses: 104
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 600 - Reward: -51.3176 - Total Reward: -44490.5041 - Cache Hits: 20 - Cache Misses: 104
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 601 - Reward: -50.6774 - Total Reward: -44541.1815 - Cache Hits: 20 - Cache Misses: 102
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 602 - Reward: -50.0351 - Total Reward: -44591.2166 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 603 - Reward: -50.0351 - Total Reward: -44641.2517 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 604 - Reward: -43.4874 - Total Reward: -44684.7391 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 605 - Reward: -43.4874 - Total Reward: -44728.2264 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 606 - Reward: -43.4874 - Total Reward: -44771.7138 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 607 - Reward: -50.6774 - Total Reward: -44822.3912 - Cache Hits: 20 - Cache Misses: 102
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 608 - Reward: -50.0351 - Total Reward: -44872.4263 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 609 - Reward: -50.0351 - Total Reward: -44922.4614 - Cache Hits: 20 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 610 - Reward: -56.3695 - Total Reward: -44978.8309 - Cache Hits: 40 - Cache Misses: 100
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 611 - Reward: -56.3695 - Total Reward: -45035.2004 - Cache Hits: 40 - Cache Misses: 100
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 612 - Reward: -56.9928 - Total Reward: -45092.1932 - Cache Hits: 40 - Cache Misses: 102
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 613 - Reward: -56.9928 - Total Reward: -45149.1860 - Cache Hits: 42 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 614 - Reward: -56.9928 - Total Reward: -45206.1788 - Cache Hits: 40 - Cache Misses: 102
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 615 - Reward: -57.6144 - Total Reward: -45263.7932 - Cache Hits: 40 - Cache Misses: 104
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 616 - Reward: -56.3695 - Total Reward: -45320.1627 - Cache Hits: 40 - Cache Misses: 100
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 617 - Reward: -56.9928 - Total Reward: -45377.1555 - Cache Hits: 40 - Cache Misses: 102
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.88/5000.0 MB
# Step 618 - Reward: -50.6774 - Total Reward: -45427.8329 - Cache Hits: 40 - Cache Misses: 82
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 619 - Reward: -50.0351 - Total Reward: -45477.8680 - Cache Hits: 40 - Cache Misses: 80
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 620 - Reward: -43.4874 - Total Reward: -45521.3554 - Cache Hits: 40 - Cache Misses: 60
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 621 - Reward: -43.4874 - Total Reward: -45564.8427 - Cache Hits: 40 - Cache Misses: 60
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 622 - Reward: -43.4874 - Total Reward: -45608.3301 - Cache Hits: 40 - Cache Misses: 60
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 623 - Reward: -36.6702 - Total Reward: -45645.0003 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 624 - Reward: -36.6702 - Total Reward: -45681.6705 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 625 - Reward: -37.3662 - Total Reward: -45719.0367 - Cache Hits: 40 - Cache Misses: 42
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 626 - Reward: -37.3662 - Total Reward: -45756.4029 - Cache Hits: 40 - Cache Misses: 42
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 627 - Reward: -36.6702 - Total Reward: -45793.0731 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 628 - Reward: -36.6702 - Total Reward: -45829.7433 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 629 - Reward: -36.6702 - Total Reward: -45866.4135 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.38/5000.0 MB
# Step 630 - Reward: -36.6702 - Total Reward: -45903.0837 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.62/5000.0 MB
# Step 631 - Reward: -36.6702 - Total Reward: -45939.7539 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 632 - Reward: -37.3662 - Total Reward: -45977.1201 - Cache Hits: 42 - Cache Misses: 40
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.75/5000.0 MB
# Step 633 - Reward: -36.6702 - Total Reward: -46013.7903 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.19/5000.0 MB
# Step 634 - Reward: -37.3662 - Total Reward: -46051.1565 - Cache Hits: 40 - Cache Misses: 42
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 635 - Reward: -37.3662 - Total Reward: -46088.5227 - Cache Hits: 40 - Cache Misses: 42
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 636 - Reward: -36.6702 - Total Reward: -46125.1929 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 637 - Reward: -36.6702 - Total Reward: -46161.8631 - Cache Hits: 40 - Cache Misses: 40
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 638 - Reward: -29.4933 - Total Reward: -46191.3564 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 639 - Reward: -29.4933 - Total Reward: -46220.8497 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 640 - Reward: -30.9637 - Total Reward: -46251.8134 - Cache Hits: 42 - Cache Misses: 22
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 641 - Reward: -29.4933 - Total Reward: -46281.3067 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 642 - Reward: -29.4933 - Total Reward: -46310.7999 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 643 - Reward: -30.2309 - Total Reward: -46341.0309 - Cache Hits: 40 - Cache Misses: 22
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.56/5000.0 MB
# Step 644 - Reward: -29.4933 - Total Reward: -46370.5242 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 645 - Reward: -30.2309 - Total Reward: -46400.7551 - Cache Hits: 40 - Cache Misses: 22
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 646 - Reward: -29.4933 - Total Reward: -46430.2484 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 647 - Reward: -29.4933 - Total Reward: -46459.7417 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 648 - Reward: -29.4933 - Total Reward: -46489.2349 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 649 - Reward: -29.4933 - Total Reward: -46518.7282 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.31/5000.0 MB
# Step 650 - Reward: -29.4933 - Total Reward: -46548.2215 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 651 - Reward: -29.4933 - Total Reward: -46577.7148 - Cache Hits: 40 - Cache Misses: 20
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 652 - Reward: -21.7911 - Total Reward: -46599.5059 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 653 - Reward: -21.7911 - Total Reward: -46621.2969 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 654 - Reward: -21.7911 - Total Reward: -46643.0880 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.44/5000.0 MB
# Step 655 - Reward: -21.7911 - Total Reward: -46664.8791 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 656 - Reward: -22.5928 - Total Reward: -46687.4719 - Cache Hits: 42 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 657 - Reward: -21.7911 - Total Reward: -46709.2629 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 5000.00/5000.0 MB
# Step 658 - Reward: -22.5928 - Total Reward: -46731.8557 - Cache Hits: 42 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 659 - Reward: -21.7911 - Total Reward: -46753.6468 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 660 - Reward: -21.7911 - Total Reward: -46775.4379 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.69/5000.0 MB
# Step 661 - Reward: -21.7911 - Total Reward: -46797.2290 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 662 - Reward: -21.7911 - Total Reward: -46819.0200 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 663 - Reward: -21.7911 - Total Reward: -46840.8111 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 664 - Reward: -21.7911 - Total Reward: -46862.6022 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.81/5000.0 MB
# Step 665 - Reward: -21.7911 - Total Reward: -46884.3933 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB
# Step 666 - Reward: -21.7911 - Total Reward: -46906.1843 - Cache Hits: 40 - Cache Misses: 0
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.12/5000.0 MB
# Step 667 - Reward: -13.1731 - Total Reward: -46919.3575 - Cache Hits: 20 - Cache Misses: 0
# Cache Utilization: 99.98% - Items in Cache: 0 - Final Capacity: 4999.25/5000.0 MB
# Step 668 - Reward: -13.1731 - Total Reward: -46932.5306 - Cache Hits: 20 - Cache Misses: 0
# Cache Utilization: 99.99% - Items in Cache: 0 - Final Capacity: 4999.50/5000.0 MB
# Step 669 - Reward: -13.1731 - Total Reward: -46945.7038 - Cache Hits: 20 - Cache Misses: 0
# Cache Utilization: 100.00% - Items in Cache: 0 - Final Capacity: 4999.94/5000.0 MB

# %%
if __name__ == "__main__":
    steps = range(1, len(results) + 1)
    cache_hits_series = [r["cache_hits"] for r in results]
    cache_misses_series = [r["cache_misses"] for r in results]

    fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

    # Rewards with moving average
    axes[0].plot(steps, [r["total_reward"] for r in results], label="Step reward", alpha=0.7, color="blue")
    w = max(1, min(20, len(results) // 10))
    if w > 1:
        ma = [sum([r["total_reward"] for r in results][i - w:i]) / w for i in range(w, len(results) + 1)]
        axes[0].plot(range(w, len(results) + 1), ma, label=f"Moving avg (w={w})", color="orange")
    axes[0].set_xlabel("Step")
    axes[0].set_ylabel("Total reward")
    axes[0].set_title("Training Rewards")
    axes[0].grid(True, alpha=0.3)
    axes[0].legend()

    # Cache hits
    axes[1].plot(steps, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
    axes[1].set_title("Cache Hits per Step")
    axes[1].set_xlabel("Step")
    axes[1].set_ylabel("Hits")
    axes[1].grid(True, alpha=0.3)
    axes[1].legend()

    # Cache misses
    axes[2].plot(steps, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
    axes[2].set_title("Cache Misses per Step")
    axes[2].set_xlabel("Step")
    axes[2].set_ylabel("Misses")
    axes[2].grid(True, alpha=0.3)
    axes[2].legend()

    plt.tight_layout()
    plt.show()

# %%
if __name__ == "__main__":
    n_episodes = 100
    n_nodes = 3
    n_users = 100
    step_size = 5.0
    alpha = 1.0
    n_gops = 60
    n_layers = 2
    n = 4
    max_capacity = 5000e6  # 5000 MB
    n_videos = 1000

    #### CPT parameters ####
    lam = 3.7183
    theta = 0.5

    users_env = UserTileRequestEvents(
        n_users=n_users,
        step_size=step_size,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n*n,
        n=n,
        alpha=alpha,
        users_viewport_tiles=None,
        requested_videos=None
    )

    du_caches = []

    mec_cache = CacheEngineEnv(
        n_tiles=n*n,
        n_videos=n_videos,
        cache_capacity=max_capacity
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = LatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,       # 640 Mbps -> 80e6 B/s 
        R_C_M=1.25e9,     # 10 Gbps -> 1.25e9 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 40e6, dtype=float),    # 320 Mbps -> 40e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,    # 1 ms
        mec_fixed_delay=0.005,   # 5 ms
        cloud_fixed_delay=0.05   # 50 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=None,
        latency_model=lat_model,
        lam=lam,
        theta=theta
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    _, info = env.reset()
    viewport_tiles = info['viewport_tiles']
    requested_videos = info['requested_videos']

    done = False
    results = []
    total_reward = 0.0

    for step in count():
        actions = [
            {
                'user': user,
                'video': requested_videos[user],
                'tiles': getTiles(step % n_gops, user, viewport_tiles, n),
                'gop': step % n_gops
            } for user in range(n_users)
        ]

        obs, reward, done, info = env.step(actions)

        total_reward += float(reward)

        results.append({
            "step": step,
            "total_reward": total_reward,
            "cache_hits": info["base_layer_cache_hits"] + info["enh_layer_cache_hits"],
            "cache_misses": info["base_layer_cache_misses"] + info["enh_layer_cache_misses"],
            "info": info
        })

        print(
            f"Step {step} - "
            f"Reward: {reward:.4f} - "
            f"Total Reward: {total_reward:.4f} - "
            f"Cache Hits: {info['base_layer_cache_hits'] + info['enh_layer_cache_hits']} - "
            f"Cache Misses: {info['base_layer_cache_misses'] + info['enh_layer_cache_misses']}\n"
            f"Cache Utilization: {info['cache_utilization']:.2%} - "
            f"Items in Cache: {info['cache_num_items']} - "
            f"Final Capacity: {info['cache_current_capacity']/1e6:.2f}/{info['cache_total_capacity']/1e6:.1f} MB"
        )
        
        if done: 
            break
# Out:
# Experiment ===================
# Total users: 100
# Cache capacity: 5000000000.0MB
# Video matrix: 1000x2x16
# ==============================
#
# Step 0 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 1 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 2 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 3 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 4 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 5 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 6 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 7 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 8 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 9 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 10 - Reward: 0.0000 - Total Reward: 0.0000 - Cache Hits: 0 - Cache Misses: 0
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 11 - Reward: -13.1731 - Total Reward: -13.1731 - Cache Hits: 0 - Cache Misses: 20
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 12 - Reward: -13.1731 - Total Reward: -26.3463 - Cache Hits: 0 - Cache Misses: 20
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 13 - Reward: -21.7911 - Total Reward: -48.1374 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 14 - Reward: -21.7911 - Total Reward: -69.9284 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 15 - Reward: -21.7911 - Total Reward: -91.7195 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 16 - Reward: -21.7911 - Total Reward: -113.5106 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 17 - Reward: -21.7911 - Total Reward: -135.3017 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 18 - Reward: -22.5928 - Total Reward: -157.8945 - Cache Hits: 0 - Cache Misses: 42
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 19 - Reward: -22.5928 - Total Reward: -180.4872 - Cache Hits: 0 - Cache Misses: 42
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 20 - Reward: -21.7911 - Total Reward: -202.2783 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 21 - Reward: -21.7911 - Total Reward: -224.0694 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 22 - Reward: -21.7911 - Total Reward: -245.8605 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 23 - Reward: -22.5928 - Total Reward: -268.4533 - Cache Hits: 0 - Cache Misses: 42
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 24 - Reward: -29.4933 - Total Reward: -297.9465 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 25 - Reward: -29.4933 - Total Reward: -327.4398 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 26 - Reward: -30.2309 - Total Reward: -357.6708 - Cache Hits: 0 - Cache Misses: 62
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 27 - Reward: -29.4933 - Total Reward: -387.1640 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 28 - Reward: -30.2309 - Total Reward: -417.3950 - Cache Hits: 0 - Cache Misses: 62
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 29 - Reward: -29.4933 - Total Reward: -446.8883 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 30 - Reward: -29.4933 - Total Reward: -476.3815 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 31 - Reward: -29.4933 - Total Reward: -505.8748 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 32 - Reward: -29.4933 - Total Reward: -535.3681 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 33 - Reward: -29.4933 - Total Reward: -564.8614 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 34 - Reward: -29.4933 - Total Reward: -594.3547 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 35 - Reward: -29.4933 - Total Reward: -623.8479 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 36 - Reward: -29.4933 - Total Reward: -653.3412 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 37 - Reward: -29.4933 - Total Reward: -682.8345 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 38 - Reward: -29.4933 - Total Reward: -712.3278 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 39 - Reward: -29.4933 - Total Reward: -741.8211 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 40 - Reward: -29.4933 - Total Reward: -771.3143 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 41 - Reward: -29.4933 - Total Reward: -800.8076 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 42 - Reward: -36.6702 - Total Reward: -837.4778 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 43 - Reward: -36.6702 - Total Reward: -874.1480 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 44 - Reward: -37.3662 - Total Reward: -911.5142 - Cache Hits: 0 - Cache Misses: 82
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 45 - Reward: -43.4874 - Total Reward: -955.0016 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 46 - Reward: -56.3695 - Total Reward: -1011.3711 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 47 - Reward: -56.9928 - Total Reward: -1068.3639 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 48 - Reward: -56.9928 - Total Reward: -1125.3567 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 49 - Reward: -56.3695 - Total Reward: -1181.7262 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 50 - Reward: -56.3695 - Total Reward: -1238.0957 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 51 - Reward: -56.3695 - Total Reward: -1294.4653 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 52 - Reward: -56.9928 - Total Reward: -1351.4581 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 53 - Reward: -56.3695 - Total Reward: -1407.8276 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 54 - Reward: -63.1361 - Total Reward: -1470.9637 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 55 - Reward: -62.5287 - Total Reward: -1533.4924 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 56 - Reward: -68.5400 - Total Reward: -1602.0324 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 57 - Reward: -68.5400 - Total Reward: -1670.5724 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 58 - Reward: -74.4239 - Total Reward: -1744.9962 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 59 - Reward: -74.4239 - Total Reward: -1819.4201 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 60 - Reward: -74.4239 - Total Reward: -1893.8439 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 61 - Reward: -80.7678 - Total Reward: -1974.6117 - Cache Hits: 0 - Cache Misses: 222
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 62 - Reward: -80.1962 - Total Reward: -2054.8079 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 63 - Reward: -80.1962 - Total Reward: -2135.0040 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 64 - Reward: -80.1962 - Total Reward: -2215.2002 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 65 - Reward: -80.7678 - Total Reward: -2295.9680 - Cache Hits: 0 - Cache Misses: 222
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 66 - Reward: -80.7678 - Total Reward: -2376.7357 - Cache Hits: 0 - Cache Misses: 222
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 67 - Reward: -80.1962 - Total Reward: -2456.9319 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 68 - Reward: -92.0081 - Total Reward: -2548.9400 - Cache Hits: 0 - Cache Misses: 262
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 69 - Reward: -91.4542 - Total Reward: -2640.3942 - Cache Hits: 0 - Cache Misses: 260
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 70 - Reward: -97.5050 - Total Reward: -2737.8992 - Cache Hits: 0 - Cache Misses: 282
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 71 - Reward: -91.4542 - Total Reward: -2829.3535 - Cache Hits: 0 - Cache Misses: 260
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 72 - Reward: -91.4542 - Total Reward: -2920.8077 - Cache Hits: 0 - Cache Misses: 260
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 73 - Reward: -85.8695 - Total Reward: -3006.6772 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 74 - Reward: -86.4318 - Total Reward: -3093.1090 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 75 - Reward: -85.8695 - Total Reward: -3178.9786 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 76 - Reward: -85.8695 - Total Reward: -3264.8481 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 77 - Reward: -85.8695 - Total Reward: -3350.7176 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 78 - Reward: -86.4318 - Total Reward: -3437.1495 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 79 - Reward: -85.8695 - Total Reward: -3523.0190 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 80 - Reward: -85.8695 - Total Reward: -3608.8885 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 81 - Reward: -86.4318 - Total Reward: -3695.3204 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 82 - Reward: -85.8695 - Total Reward: -3781.1899 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 83 - Reward: -85.8695 - Total Reward: -3867.0594 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 84 - Reward: -80.7678 - Total Reward: -3947.8272 - Cache Hits: 0 - Cache Misses: 222
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 85 - Reward: -80.7678 - Total Reward: -4028.5950 - Cache Hits: 0 - Cache Misses: 222
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 86 - Reward: -80.1962 - Total Reward: -4108.7911 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 87 - Reward: -80.7678 - Total Reward: -4189.5589 - Cache Hits: 0 - Cache Misses: 222
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 88 - Reward: -81.3384 - Total Reward: -4270.8973 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 89 - Reward: -80.1962 - Total Reward: -4351.0934 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 90 - Reward: -86.4318 - Total Reward: -4437.5253 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 91 - Reward: -85.8695 - Total Reward: -4523.3948 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 92 - Reward: -85.8695 - Total Reward: -4609.2643 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 93 - Reward: -85.8695 - Total Reward: -4695.1339 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 94 - Reward: -85.8695 - Total Reward: -4781.0034 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 95 - Reward: -85.8695 - Total Reward: -4866.8729 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 96 - Reward: -86.9933 - Total Reward: -4953.8662 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 97 - Reward: -92.5613 - Total Reward: -5046.4275 - Cache Hits: 0 - Cache Misses: 264
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 98 - Reward: -92.0081 - Total Reward: -5138.4356 - Cache Hits: 0 - Cache Misses: 262
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 99 - Reward: -92.5613 - Total Reward: -5230.9969 - Cache Hits: 0 - Cache Misses: 264
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 100 - Reward: -91.4542 - Total Reward: -5322.4511 - Cache Hits: 0 - Cache Misses: 260
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 101 - Reward: -91.4542 - Total Reward: -5413.9053 - Cache Hits: 0 - Cache Misses: 260
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 102 - Reward: -86.4318 - Total Reward: -5500.3372 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 103 - Reward: -85.8695 - Total Reward: -5586.2067 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 104 - Reward: -86.4318 - Total Reward: -5672.6385 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 105 - Reward: -81.3384 - Total Reward: -5753.9769 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 106 - Reward: -69.1338 - Total Reward: -5823.1107 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 107 - Reward: -68.5400 - Total Reward: -5891.6507 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 108 - Reward: -68.5400 - Total Reward: -5960.1907 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 109 - Reward: -69.1338 - Total Reward: -6029.3245 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 110 - Reward: -69.1338 - Total Reward: -6098.4584 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 111 - Reward: -69.1338 - Total Reward: -6167.5922 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 112 - Reward: -68.5400 - Total Reward: -6236.1322 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 113 - Reward: -68.5400 - Total Reward: -6304.6722 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 114 - Reward: -62.5287 - Total Reward: -6367.2009 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 115 - Reward: -62.5287 - Total Reward: -6429.7296 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 116 - Reward: -56.3695 - Total Reward: -6486.0991 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 117 - Reward: -63.1361 - Total Reward: -6549.2352 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 118 - Reward: -62.5287 - Total Reward: -6611.7639 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 119 - Reward: -62.5287 - Total Reward: -6674.2926 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 120 - Reward: -63.7421 - Total Reward: -6738.0347 - Cache Hits: 0 - Cache Misses: 164
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 121 - Reward: -56.3695 - Total Reward: -6794.4042 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 122 - Reward: -62.5287 - Total Reward: -6856.9329 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 123 - Reward: -62.5287 - Total Reward: -6919.4616 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 124 - Reward: -63.1361 - Total Reward: -6982.5977 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 125 - Reward: -63.1361 - Total Reward: -7045.7338 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 126 - Reward: -71.7230 - Total Reward: -7117.4568 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 127 - Reward: -71.7230 - Total Reward: -7189.1798 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 128 - Reward: -59.8075 - Total Reward: -7248.9873 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 129 - Reward: -60.1355 - Total Reward: -7309.1228 - Cache Hits: 0 - Cache Misses: 144
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 130 - Reward: -53.9724 - Total Reward: -7363.0952 - Cache Hits: 0 - Cache Misses: 124
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 131 - Reward: -53.9724 - Total Reward: -7417.0676 - Cache Hits: 0 - Cache Misses: 124
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 132 - Reward: -53.0507 - Total Reward: -7470.1183 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 133 - Reward: -53.9724 - Total Reward: -7524.0907 - Cache Hits: 0 - Cache Misses: 124
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 134 - Reward: -53.6440 - Total Reward: -7577.7347 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 135 - Reward: -53.0189 - Total Reward: -7630.7536 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 136 - Reward: -53.0189 - Total Reward: -7683.7725 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 137 - Reward: -53.6440 - Total Reward: -7737.4165 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 138 - Reward: -59.5260 - Total Reward: -7796.9425 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 139 - Reward: -59.8075 - Total Reward: -7856.7500 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 140 - Reward: -59.8075 - Total Reward: -7916.5575 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 141 - Reward: -58.9151 - Total Reward: -7975.4726 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 142 - Reward: -58.9151 - Total Reward: -8034.3876 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 143 - Reward: -59.8075 - Total Reward: -8094.1951 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 144 - Reward: -59.5260 - Total Reward: -8153.7211 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 145 - Reward: -60.1355 - Total Reward: -8213.8566 - Cache Hits: 0 - Cache Misses: 144
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 146 - Reward: -59.9954 - Total Reward: -8273.8521 - Cache Hits: 0 - Cache Misses: 144
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 147 - Reward: -59.5260 - Total Reward: -8333.3781 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 148 - Reward: -60.4156 - Total Reward: -8393.7937 - Cache Hits: 0 - Cache Misses: 144
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 149 - Reward: -60.1355 - Total Reward: -8453.9292 - Cache Hits: 0 - Cache Misses: 144
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 150 - Reward: -51.3176 - Total Reward: -8505.2468 - Cache Hits: 0 - Cache Misses: 124
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 151 - Reward: -50.6774 - Total Reward: -8555.9242 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 152 - Reward: -50.6774 - Total Reward: -8606.6016 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 153 - Reward: -50.0351 - Total Reward: -8656.6367 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 154 - Reward: -50.0351 - Total Reward: -8706.6718 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 155 - Reward: -50.0351 - Total Reward: -8756.7069 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 156 - Reward: -50.0351 - Total Reward: -8806.7420 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 157 - Reward: -43.4874 - Total Reward: -8850.2294 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 158 - Reward: -43.4874 - Total Reward: -8893.7167 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 159 - Reward: -43.4874 - Total Reward: -8937.2041 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 160 - Reward: -43.4874 - Total Reward: -8980.6915 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 161 - Reward: -43.4874 - Total Reward: -9024.1789 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 162 - Reward: -43.4874 - Total Reward: -9067.6663 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 163 - Reward: -43.4874 - Total Reward: -9111.1536 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 164 - Reward: -44.1532 - Total Reward: -9155.3068 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 165 - Reward: -44.1532 - Total Reward: -9199.4599 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 166 - Reward: -43.4874 - Total Reward: -9242.9473 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 167 - Reward: -43.4874 - Total Reward: -9286.4347 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 168 - Reward: -44.1532 - Total Reward: -9330.5879 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 169 - Reward: -44.1532 - Total Reward: -9374.7410 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 170 - Reward: -44.8163 - Total Reward: -9419.5573 - Cache Hits: 0 - Cache Misses: 104
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 171 - Reward: -44.1532 - Total Reward: -9463.7105 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 172 - Reward: -44.1532 - Total Reward: -9507.8637 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 173 - Reward: -43.4874 - Total Reward: -9551.3510 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 174 - Reward: -50.6774 - Total Reward: -9602.0284 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 175 - Reward: -50.0351 - Total Reward: -9652.0635 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 176 - Reward: -50.0351 - Total Reward: -9702.0986 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 177 - Reward: -50.0351 - Total Reward: -9752.1337 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 178 - Reward: -44.8163 - Total Reward: -9796.9500 - Cache Hits: 0 - Cache Misses: 104
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 179 - Reward: -43.4874 - Total Reward: -9840.4374 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 180 - Reward: -43.4874 - Total Reward: -9883.9248 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 181 - Reward: -43.4874 - Total Reward: -9927.4122 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 182 - Reward: -37.3662 - Total Reward: -9964.7784 - Cache Hits: 0 - Cache Misses: 82
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 183 - Reward: -37.3662 - Total Reward: -10002.1446 - Cache Hits: 0 - Cache Misses: 82
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 184 - Reward: -37.3662 - Total Reward: -10039.5108 - Cache Hits: 0 - Cache Misses: 82
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 185 - Reward: -36.6702 - Total Reward: -10076.1810 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 186 - Reward: -29.4933 - Total Reward: -10105.6743 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 187 - Reward: -30.2309 - Total Reward: -10135.9052 - Cache Hits: 0 - Cache Misses: 62
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 188 - Reward: -29.4933 - Total Reward: -10165.3985 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 189 - Reward: -29.4933 - Total Reward: -10194.8918 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 190 - Reward: -29.4933 - Total Reward: -10224.3851 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 191 - Reward: -30.2309 - Total Reward: -10254.6160 - Cache Hits: 0 - Cache Misses: 62
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 192 - Reward: -29.4933 - Total Reward: -10284.1093 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 193 - Reward: -29.4933 - Total Reward: -10313.6026 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 194 - Reward: -29.4933 - Total Reward: -10343.0959 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 195 - Reward: -29.4933 - Total Reward: -10372.5891 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 196 - Reward: -29.4933 - Total Reward: -10402.0824 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 197 - Reward: -29.4933 - Total Reward: -10431.5757 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 198 - Reward: -21.7911 - Total Reward: -10453.3668 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 199 - Reward: -29.4933 - Total Reward: -10482.8601 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 200 - Reward: -36.6702 - Total Reward: -10519.5302 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 201 - Reward: -36.6702 - Total Reward: -10556.2004 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 202 - Reward: -36.6702 - Total Reward: -10592.8706 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 203 - Reward: -36.6702 - Total Reward: -10629.5408 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 204 - Reward: -36.6702 - Total Reward: -10666.2110 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 205 - Reward: -36.6702 - Total Reward: -10702.8812 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 206 - Reward: -37.3662 - Total Reward: -10740.2474 - Cache Hits: 0 - Cache Misses: 82
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 207 - Reward: -36.6702 - Total Reward: -10776.9176 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 208 - Reward: -36.6702 - Total Reward: -10813.5878 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 209 - Reward: -36.6702 - Total Reward: -10850.2580 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 210 - Reward: -43.4874 - Total Reward: -10893.7453 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 211 - Reward: -43.4874 - Total Reward: -10937.2327 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 212 - Reward: -43.4874 - Total Reward: -10980.7201 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 213 - Reward: -43.4874 - Total Reward: -11024.2075 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 214 - Reward: -65.2316 - Total Reward: -11089.4391 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 215 - Reward: -65.8278 - Total Reward: -11155.2669 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 216 - Reward: -64.9613 - Total Reward: -11220.2282 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 217 - Reward: -64.9613 - Total Reward: -11285.1895 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 218 - Reward: -65.2316 - Total Reward: -11350.4212 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 219 - Reward: -65.2316 - Total Reward: -11415.6528 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 220 - Reward: -65.2316 - Total Reward: -11480.8844 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 221 - Reward: -71.1387 - Total Reward: -11552.0231 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 222 - Reward: -70.8788 - Total Reward: -11622.9019 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 223 - Reward: -70.6189 - Total Reward: -11693.5208 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 224 - Reward: -70.8788 - Total Reward: -11764.3996 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 225 - Reward: -71.1387 - Total Reward: -11835.5383 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 226 - Reward: -71.1387 - Total Reward: -11906.6770 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 227 - Reward: -71.1387 - Total Reward: -11977.8156 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 228 - Reward: -80.8368 - Total Reward: -12058.6524 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 229 - Reward: -81.3973 - Total Reward: -12140.0498 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 230 - Reward: -81.3973 - Total Reward: -12221.4471 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 231 - Reward: -80.4465 - Total Reward: -12301.8936 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 232 - Reward: -80.8368 - Total Reward: -12382.7304 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 233 - Reward: -86.4076 - Total Reward: -12469.1380 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 234 - Reward: -80.4465 - Total Reward: -12549.5845 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 235 - Reward: -80.4465 - Total Reward: -12630.0310 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 236 - Reward: -80.4465 - Total Reward: -12710.4776 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 237 - Reward: -71.4641 - Total Reward: -12781.9416 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 238 - Reward: -71.4641 - Total Reward: -12853.4057 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 239 - Reward: -70.8788 - Total Reward: -12924.2845 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 240 - Reward: -70.8788 - Total Reward: -12995.1633 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 241 - Reward: -71.1387 - Total Reward: -13066.3020 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 242 - Reward: -76.9340 - Total Reward: -13143.2361 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 243 - Reward: -83.5161 - Total Reward: -13226.7521 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 244 - Reward: -91.4665 - Total Reward: -13318.2187 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 245 - Reward: -91.4665 - Total Reward: -13409.6852 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 246 - Reward: -92.0155 - Total Reward: -13501.7007 - Cache Hits: 0 - Cache Misses: 246
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 247 - Reward: -91.4665 - Total Reward: -13593.1672 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 248 - Reward: -91.4665 - Total Reward: -13684.6337 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 249 - Reward: -91.2311 - Total Reward: -13775.8648 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 250 - Reward: -90.6808 - Total Reward: -13866.5456 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 251 - Reward: -91.3488 - Total Reward: -13957.8944 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 252 - Reward: -90.9168 - Total Reward: -14048.8113 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 253 - Reward: -91.7020 - Total Reward: -14140.5132 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 254 - Reward: -92.4851 - Total Reward: -14232.9984 - Cache Hits: 0 - Cache Misses: 246
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 255 - Reward: -90.9168 - Total Reward: -14323.9152 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 256 - Reward: -90.7988 - Total Reward: -14414.7140 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 257 - Reward: -90.9168 - Total Reward: -14505.6308 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 258 - Reward: -91.5842 - Total Reward: -14597.2151 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 259 - Reward: -85.8148 - Total Reward: -14683.0298 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 260 - Reward: -78.5284 - Total Reward: -14761.5583 - Cache Hits: 0 - Cache Misses: 206
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 261 - Reward: -77.2577 - Total Reward: -14838.8160 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 262 - Reward: -78.3302 - Total Reward: -14917.1462 - Cache Hits: 0 - Cache Misses: 204
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 263 - Reward: -79.0998 - Total Reward: -14996.2460 - Cache Hits: 0 - Cache Misses: 208
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 264 - Reward: -77.2577 - Total Reward: -15073.5037 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 265 - Reward: -84.0795 - Total Reward: -15157.5832 - Cache Hits: 0 - Cache Misses: 226
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 266 - Reward: -82.3865 - Total Reward: -15239.9698 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 267 - Reward: -83.5161 - Total Reward: -15323.4859 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 268 - Reward: -83.5161 - Total Reward: -15407.0019 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 269 - Reward: -99.7675 - Total Reward: -15506.7694 - Cache Hits: 0 - Cache Misses: 264
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 270 - Reward: -99.7675 - Total Reward: -15606.5369 - Cache Hits: 0 - Cache Misses: 264
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 271 - Reward: -98.4651 - Total Reward: -15705.0020 - Cache Hits: 0 - Cache Misses: 260
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 272 - Reward: -104.5608 - Total Reward: -15809.5627 - Cache Hits: 0 - Cache Misses: 282
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 273 - Reward: -105.8436 - Total Reward: -15915.4064 - Cache Hits: 0 - Cache Misses: 286
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 274 - Reward: -85.6938 - Total Reward: -16001.1001 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 275 - Reward: -84.5769 - Total Reward: -16085.6770 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 276 - Reward: -84.6986 - Total Reward: -16170.3756 - Cache Hits: 0 - Cache Misses: 220
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 277 - Reward: -85.4518 - Total Reward: -16255.8274 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 278 - Reward: -85.5728 - Total Reward: -16341.4002 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 279 - Reward: -85.6938 - Total Reward: -16427.0940 - Cache Hits: 0 - Cache Misses: 224
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 280 - Reward: -84.8931 - Total Reward: -16511.9870 - Cache Hits: 0 - Cache Misses: 222
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 281 - Reward: -78.9422 - Total Reward: -16590.9292 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 282 - Reward: -79.5096 - Total Reward: -16670.4388 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 283 - Reward: -90.0114 - Total Reward: -16760.4501 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 284 - Reward: -90.6808 - Total Reward: -16851.1309 - Cache Hits: 0 - Cache Misses: 242
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 285 - Reward: -91.1134 - Total Reward: -16942.2443 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 286 - Reward: -90.0114 - Total Reward: -17032.2557 - Cache Hits: 0 - Cache Misses: 240
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 287 - Reward: -91.2311 - Total Reward: -17123.4868 - Cache Hits: 0 - Cache Misses: 244
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 288 - Reward: -82.9517 - Total Reward: -17206.4385 - Cache Hits: 0 - Cache Misses: 222
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# ...
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 610 - Reward: -69.1338 - Total Reward: -42136.0348 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 611 - Reward: -69.1338 - Total Reward: -42205.1686 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 612 - Reward: -56.3695 - Total Reward: -42261.5381 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 613 - Reward: -50.0351 - Total Reward: -42311.5732 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 614 - Reward: -50.0351 - Total Reward: -42361.6083 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 615 - Reward: -50.0351 - Total Reward: -42411.6434 - Cache Hits: 0 - Cache Misses: 120
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 616 - Reward: -56.9928 - Total Reward: -42468.6362 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 617 - Reward: -56.9928 - Total Reward: -42525.6290 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 618 - Reward: -56.9928 - Total Reward: -42582.6218 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 619 - Reward: -56.9928 - Total Reward: -42639.6146 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 620 - Reward: -56.3695 - Total Reward: -42695.9841 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 621 - Reward: -56.3695 - Total Reward: -42752.3536 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 622 - Reward: -56.3695 - Total Reward: -42808.7231 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 623 - Reward: -56.3695 - Total Reward: -42865.0926 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 624 - Reward: -56.3695 - Total Reward: -42921.4621 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 625 - Reward: -56.9928 - Total Reward: -42978.4549 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 626 - Reward: -56.9928 - Total Reward: -43035.4477 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 627 - Reward: -56.9928 - Total Reward: -43092.4405 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 628 - Reward: -56.9928 - Total Reward: -43149.4333 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 629 - Reward: -56.3695 - Total Reward: -43205.8028 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 630 - Reward: -56.3695 - Total Reward: -43262.1724 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 631 - Reward: -56.3695 - Total Reward: -43318.5419 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 632 - Reward: -56.9928 - Total Reward: -43375.5347 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 633 - Reward: -62.5287 - Total Reward: -43438.0634 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 634 - Reward: -62.5287 - Total Reward: -43500.5921 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 635 - Reward: -63.1361 - Total Reward: -43563.7282 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 636 - Reward: -69.1338 - Total Reward: -43632.8620 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 637 - Reward: -69.1338 - Total Reward: -43701.9958 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 638 - Reward: -69.1338 - Total Reward: -43771.1297 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 639 - Reward: -63.1361 - Total Reward: -43834.2658 - Cache Hits: 0 - Cache Misses: 162
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 640 - Reward: -71.7230 - Total Reward: -43905.9888 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 641 - Reward: -71.7230 - Total Reward: -43977.7118 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 642 - Reward: -76.9340 - Total Reward: -44054.6458 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 643 - Reward: -71.1387 - Total Reward: -44125.7845 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 644 - Reward: -71.1387 - Total Reward: -44196.9232 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 645 - Reward: -76.9340 - Total Reward: -44273.8572 - Cache Hits: 0 - Cache Misses: 200
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 646 - Reward: -77.5079 - Total Reward: -44351.3651 - Cache Hits: 0 - Cache Misses: 202
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 647 - Reward: -72.0483 - Total Reward: -44423.4134 - Cache Hits: 0 - Cache Misses: 184
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 648 - Reward: -72.0483 - Total Reward: -44495.4617 - Cache Hits: 0 - Cache Misses: 184
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 649 - Reward: -72.6313 - Total Reward: -44568.0930 - Cache Hits: 0 - Cache Misses: 186
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 650 - Reward: -72.3063 - Total Reward: -44640.3992 - Cache Hits: 0 - Cache Misses: 184
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 651 - Reward: -71.2052 - Total Reward: -44711.6044 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 652 - Reward: -71.3346 - Total Reward: -44782.9391 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 653 - Reward: -71.4641 - Total Reward: -44854.4031 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 654 - Reward: -72.3063 - Total Reward: -44926.7094 - Cache Hits: 0 - Cache Misses: 184
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 655 - Reward: -73.1791 - Total Reward: -44999.8885 - Cache Hits: 0 - Cache Misses: 187
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 656 - Reward: -72.3063 - Total Reward: -45072.1947 - Cache Hits: 0 - Cache Misses: 184
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 657 - Reward: -71.7230 - Total Reward: -45143.9177 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 658 - Reward: -71.1387 - Total Reward: -45215.0564 - Cache Hits: 0 - Cache Misses: 180
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 659 - Reward: -72.3063 - Total Reward: -45287.3627 - Cache Hits: 0 - Cache Misses: 184
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 660 - Reward: -71.7230 - Total Reward: -45359.0857 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 661 - Reward: -71.7230 - Total Reward: -45430.8087 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 662 - Reward: -71.4641 - Total Reward: -45502.2728 - Cache Hits: 0 - Cache Misses: 182
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 663 - Reward: -65.2316 - Total Reward: -45567.5044 - Cache Hits: 0 - Cache Misses: 160
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 664 - Reward: -59.1979 - Total Reward: -45626.7023 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 665 - Reward: -59.1979 - Total Reward: -45685.9003 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 666 - Reward: -59.1979 - Total Reward: -45745.0982 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 667 - Reward: -59.1979 - Total Reward: -45804.2961 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 668 - Reward: -58.9151 - Total Reward: -45863.2112 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 669 - Reward: -58.9151 - Total Reward: -45922.1262 - Cache Hits: 0 - Cache Misses: 140
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 670 - Reward: -59.8075 - Total Reward: -45981.9337 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 671 - Reward: -59.5260 - Total Reward: -46041.4597 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 672 - Reward: -59.5260 - Total Reward: -46100.9858 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 673 - Reward: -59.5260 - Total Reward: -46160.5118 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 674 - Reward: -59.5260 - Total Reward: -46220.0378 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 675 - Reward: -59.5260 - Total Reward: -46279.5638 - Cache Hits: 0 - Cache Misses: 142
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 676 - Reward: -53.3473 - Total Reward: -46332.9111 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 677 - Reward: -53.3473 - Total Reward: -46386.2585 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 678 - Reward: -53.3473 - Total Reward: -46439.6058 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 679 - Reward: -53.3473 - Total Reward: -46492.9531 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 680 - Reward: -53.0507 - Total Reward: -46546.0038 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 681 - Reward: -53.6440 - Total Reward: -46599.6477 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 682 - Reward: -53.6440 - Total Reward: -46653.2917 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 683 - Reward: -53.3473 - Total Reward: -46706.6390 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 684 - Reward: -53.3473 - Total Reward: -46759.9863 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 685 - Reward: -53.3473 - Total Reward: -46813.3337 - Cache Hits: 0 - Cache Misses: 122
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 686 - Reward: -44.1532 - Total Reward: -46857.4868 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 687 - Reward: -44.1532 - Total Reward: -46901.6400 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 688 - Reward: -44.1532 - Total Reward: -46945.7931 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 689 - Reward: -44.1532 - Total Reward: -46989.9463 - Cache Hits: 0 - Cache Misses: 102
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 690 - Reward: -43.4874 - Total Reward: -47033.4337 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 691 - Reward: -43.4874 - Total Reward: -47076.9210 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 692 - Reward: -43.4874 - Total Reward: -47120.4084 - Cache Hits: 0 - Cache Misses: 100
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 693 - Reward: -37.3662 - Total Reward: -47157.7746 - Cache Hits: 0 - Cache Misses: 82
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 694 - Reward: -36.6702 - Total Reward: -47194.4448 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 695 - Reward: -36.6702 - Total Reward: -47231.1150 - Cache Hits: 0 - Cache Misses: 80
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 696 - Reward: -29.4933 - Total Reward: -47260.6083 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 697 - Reward: -30.2309 - Total Reward: -47290.8392 - Cache Hits: 0 - Cache Misses: 62
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 698 - Reward: -29.4933 - Total Reward: -47320.3325 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 699 - Reward: -29.4933 - Total Reward: -47349.8258 - Cache Hits: 0 - Cache Misses: 60
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 700 - Reward: -21.7911 - Total Reward: -47371.6169 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 701 - Reward: -21.7911 - Total Reward: -47393.4079 - Cache Hits: 0 - Cache Misses: 40
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 702 - Reward: -13.1731 - Total Reward: -47406.5811 - Cache Hits: 0 - Cache Misses: 20
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 703 - Reward: -13.1731 - Total Reward: -47419.7542 - Cache Hits: 0 - Cache Misses: 20
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
# Step 704 - Reward: -13.1731 - Total Reward: -47432.9274 - Cache Hits: 0 - Cache Misses: 20
# Cache Utilization: 0.00% - Items in Cache: 0 - Final Capacity: 0.00/0.0 MB
