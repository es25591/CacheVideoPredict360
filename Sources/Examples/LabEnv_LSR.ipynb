# %%
import math
import csv
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from time import sleep
from collections import deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv
    from LabUserTileRequest import UserTileRequestEvents
    from LabEnvWrapper import EnvWrapper

import sys
# sys.path.append(r'c:\Users\es25591\Workspace\CacheVideoPredict360\Sources')
sys.path.append('/home/eduardo/Workspace/CacheVideoPredict360/Sources')
from Common.Utils import save_training_results

# %%
if __name__ == "__main__":
    n_episodes = 300
    n_nodes = 3
    n_users = 200
    step_size = 10
    arrival_rate = 10.0  # users per second
    alpha = 0.5
    n_videos = 500
    n_gops = 30
    n_layers = 2
    n = 4
    m = 3
    n_tiles = n * m
    max_capacity = 500e6  # 500 MB

    # CPT parameters
    theta = 0.5
    lam = 3.7183

    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=n_users,
        n_videos=n_videos,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n_gops=n_gops,
        cache_capacity=max_capacity,
    )

    # Initialize User Environment
    users_env = UserTileRequestEvents(
        n_nodes=n_nodes,
        n_users=n_users,
        n_videos=n_videos,
        n_gops=n_gops,
        n_layers=n_layers,
        n_tiles=n_tiles,
        n=n,
        m=m,
        users_viewport_tiles=None,
        requested_videos=None,
        users_arrivals=None,
        arrival_rate=arrival_rate,
        alpha=alpha
    )

    # Create latency model (replace numbers with your real config)
    P = n_nodes; max_U = n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,   # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),    # 160 Mbps -> 20e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,    # 1 ms
        mec_fixed_delay=0.005,   # 5 ms
        cloud_fixed_delay=0.1   # 100 ms
    )

    env = EnvWrapper(
        n=n,
        n_layers=n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=theta,
        lam=lam
    )

    print(
        f"Experiment ===================\n"
        f"Total users: {n_users}\n"
        f"Cache capacity: {max_capacity}MB\n"
        f"Video matrix: {n_videos}x{n_layers}x{n*n}\n"
        f"==============================\n"
    )

    results = []
    scores = []
    active_users_log = []  # Track active users per step

    for ep in range(n_episodes):

        obs, info = env.reset()

        cache_hits = 0
        cache_misses = 0
        enhanced_layer_cache_hits = 0
        enhanced_layer_cache_misses = 0
        base_layer_cache_hits = 0
        base_layer_cache_misses = 0
        total_reward = 0.0
        avg_psnr = []

        for step in count():

            # --- AGENT ACTIONS ---
            reqs_state = info['users_requests']
            active_users = [
                (req['u'], req['video'], req['gop']) 
                for req in reqs_state if req['gop'] < n_gops
            ]
            actions = []
            for req in reqs_state:
                u = req['u']
                video = req['video']
                gop = req['gop']

                if gop >= n_gops:
                    continue
                
                tiles = np.zeros(n*m)
                for tile in req['tiles']:
                    tiles[tile['tile']] = 1 if tile['layer'] == 1 else 0

                # chooses tiles
                actions.append({
                    'user': u,
                    'gop': gop,
                    'video': video,
                    'tiles': tiles
                })
                
            # --- STEP ENV ---
            obs, rewards, done, info = env.step(actions)

            total_reward += float(rewards)
            enhanced_layer_cache_hits += info["enh_layer_cache_hits"]
            enhanced_layer_cache_misses += info["enh_layer_cache_misses"]
            base_layer_cache_hits += info["base_layer_cache_hits"]
            base_layer_cache_misses += info["base_layer_cache_misses"]
            avg_psnr.append(info.get("average_psnr", 0.0))

            step_reward = float(rewards) / max(1, len(active_users))
            
            # print(f"Step {step}, Active Users: {len(active_users)}")
            # print(f"Request State: {reqs_state}")
            # print(f"Action: {actions}")
            # print(f"Next Request State: {reqs_next_state}")
            # print(
            #     f"Reward: {rewards}, "
            #     f"Cache Hits: {enhanced_layer_cache_hits + base_layer_cache_hits}, "
            #     f"Cache Misses: {enhanced_layer_cache_misses + base_layer_cache_misses}"
            # )
            # print("-----")
            
            if done:
                break

        avg_psnr = [x for x in avg_psnr if x != 0.0]

        cache_hits = enhanced_layer_cache_hits + base_layer_cache_hits
        cache_misses = enhanced_layer_cache_misses + base_layer_cache_misses

        print(
            f"Episode {ep+1}/{n_episodes}, "
            f"Total Reward: {total_reward:.4f}, "
            f"cache_hits: {cache_hits}, "
            f"cache_misses: {cache_misses}, "
            f"enh_layer_cache_hits: {enhanced_layer_cache_hits}, "
            f"enh_layer_cache_misses: {enhanced_layer_cache_misses}, "
            f"base_layer_cache_hits: {base_layer_cache_hits}, "
            f"base_layer_cache_misses: {base_layer_cache_misses}, "
            f"Average PSNR: {np.mean(avg_psnr) if avg_psnr else 0.0:.2f}, "
        )

        filename = (
            f"fov_lsr_"
            f"U{n_users}_V{n_videos}_G{n_gops}_L{n_layers}_N{n}_"
            f"cap{int(max_capacity/1e6)}MB_AR{int(arrival_rate)}_Z{alpha}.csv"
        )

        
        save_training_results(
            path_='/home/eduardo/Workspace/CacheVideoPredict360/Results',
            # path_=r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results',
            filename=filename,
            ep=ep,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            enhanced_layer_cache_hits=enhanced_layer_cache_hits,
            enhanced_layer_cache_misses=enhanced_layer_cache_misses,
            base_layer_cache_hits=base_layer_cache_hits,
            base_layer_cache_misses=base_layer_cache_misses,
            avg_psnr=np.mean(avg_psnr) if avg_psnr else 0.0,
            agent=None
        )
        scores.append(total_reward)

        results.append({
            "episode": ep,
            "total_reward": total_reward,
            "cache_hits": cache_hits,
            "cache_misses": cache_misses,
        })
# Out:
# Experiment ===================
# Total users: 200
# Cache capacity: 500000000.0MB
# Video matrix: 500x2x16
# ==============================
#
# Episode 1/300, Total Reward: 10125.9157, cache_hits: 91881, cache_misses: 4119, enh_layer_cache_hits: 19881, enh_layer_cache_misses: 4119, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 2/300, Total Reward: 9791.6082, cache_hits: 91862, cache_misses: 4138, enh_layer_cache_hits: 19862, enh_layer_cache_misses: 4138, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 3/300, Total Reward: 9801.2580, cache_hits: 92122, cache_misses: 3878, enh_layer_cache_hits: 20122, enh_layer_cache_misses: 3878, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 4/300, Total Reward: 9768.7114, cache_hits: 91811, cache_misses: 4189, enh_layer_cache_hits: 19811, enh_layer_cache_misses: 4189, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 5/300, Total Reward: 9903.8027, cache_hits: 91745, cache_misses: 4255, enh_layer_cache_hits: 19745, enh_layer_cache_misses: 4255, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 6/300, Total Reward: 9853.4972, cache_hits: 91755, cache_misses: 4245, enh_layer_cache_hits: 19755, enh_layer_cache_misses: 4245, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 7/300, Total Reward: 9851.9431, cache_hits: 91900, cache_misses: 4100, enh_layer_cache_hits: 19900, enh_layer_cache_misses: 4100, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 8/300, Total Reward: 10068.2341, cache_hits: 91815, cache_misses: 4185, enh_layer_cache_hits: 19815, enh_layer_cache_misses: 4185, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 9/300, Total Reward: 10083.6173, cache_hits: 91888, cache_misses: 4112, enh_layer_cache_hits: 19888, enh_layer_cache_misses: 4112, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 10/300, Total Reward: 9885.0746, cache_hits: 91909, cache_misses: 4091, enh_layer_cache_hits: 19909, enh_layer_cache_misses: 4091, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 11/300, Total Reward: 9919.7734, cache_hits: 91965, cache_misses: 4035, enh_layer_cache_hits: 19965, enh_layer_cache_misses: 4035, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 12/300, Total Reward: 10135.9912, cache_hits: 91958, cache_misses: 4042, enh_layer_cache_hits: 19958, enh_layer_cache_misses: 4042, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 13/300, Total Reward: 10136.4585, cache_hits: 92011, cache_misses: 3989, enh_layer_cache_hits: 20011, enh_layer_cache_misses: 3989, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 14/300, Total Reward: 9998.1505, cache_hits: 91786, cache_misses: 4214, enh_layer_cache_hits: 19786, enh_layer_cache_misses: 4214, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 15/300, Total Reward: 9712.9749, cache_hits: 92009, cache_misses: 3991, enh_layer_cache_hits: 20009, enh_layer_cache_misses: 3991, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 16/300, Total Reward: 9784.3060, cache_hits: 91868, cache_misses: 4132, enh_layer_cache_hits: 19868, enh_layer_cache_misses: 4132, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 17/300, Total Reward: 9540.3922, cache_hits: 91795, cache_misses: 4205, enh_layer_cache_hits: 19795, enh_layer_cache_misses: 4205, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 18/300, Total Reward: 9986.5003, cache_hits: 91897, cache_misses: 4103, enh_layer_cache_hits: 19897, enh_layer_cache_misses: 4103, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 19/300, Total Reward: 9954.3583, cache_hits: 92136, cache_misses: 3864, enh_layer_cache_hits: 20136, enh_layer_cache_misses: 3864, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 20/300, Total Reward: 9976.9770, cache_hits: 91963, cache_misses: 4037, enh_layer_cache_hits: 19963, enh_layer_cache_misses: 4037, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 21/300, Total Reward: 10018.3211, cache_hits: 92039, cache_misses: 3961, enh_layer_cache_hits: 20039, enh_layer_cache_misses: 3961, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 22/300, Total Reward: 10138.6284, cache_hits: 91997, cache_misses: 4003, enh_layer_cache_hits: 19997, enh_layer_cache_misses: 4003, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 23/300, Total Reward: 10125.1105, cache_hits: 91867, cache_misses: 4133, enh_layer_cache_hits: 19867, enh_layer_cache_misses: 4133, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 24/300, Total Reward: 9926.0247, cache_hits: 91777, cache_misses: 4223, enh_layer_cache_hits: 19777, enh_layer_cache_misses: 4223, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 25/300, Total Reward: 10007.0025, cache_hits: 91810, cache_misses: 4190, enh_layer_cache_hits: 19810, enh_layer_cache_misses: 4190, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 26/300, Total Reward: 9771.1570, cache_hits: 91803, cache_misses: 4197, enh_layer_cache_hits: 19803, enh_layer_cache_misses: 4197, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 27/300, Total Reward: 9971.7626, cache_hits: 92099, cache_misses: 3901, enh_layer_cache_hits: 20099, enh_layer_cache_misses: 3901, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 28/300, Total Reward: 9672.3026, cache_hits: 91863, cache_misses: 4137, enh_layer_cache_hits: 19863, enh_layer_cache_misses: 4137, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 29/300, Total Reward: 10201.3249, cache_hits: 91906, cache_misses: 4094, enh_layer_cache_hits: 19906, enh_layer_cache_misses: 4094, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 30/300, Total Reward: 9762.4328, cache_hits: 91856, cache_misses: 4144, enh_layer_cache_hits: 19856, enh_layer_cache_misses: 4144, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 31/300, Total Reward: 9733.5574, cache_hits: 91754, cache_misses: 4246, enh_layer_cache_hits: 19754, enh_layer_cache_misses: 4246, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 32/300, Total Reward: 9906.9758, cache_hits: 92083, cache_misses: 3917, enh_layer_cache_hits: 20083, enh_layer_cache_misses: 3917, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 33/300, Total Reward: 9924.9704, cache_hits: 91729, cache_misses: 4271, enh_layer_cache_hits: 19729, enh_layer_cache_misses: 4271, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 34/300, Total Reward: 9836.0797, cache_hits: 91986, cache_misses: 4014, enh_layer_cache_hits: 19986, enh_layer_cache_misses: 4014, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 35/300, Total Reward: 9410.3595, cache_hits: 91869, cache_misses: 4131, enh_layer_cache_hits: 19869, enh_layer_cache_misses: 4131, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 36/300, Total Reward: 9750.0521, cache_hits: 91767, cache_misses: 4233, enh_layer_cache_hits: 19767, enh_layer_cache_misses: 4233, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 37/300, Total Reward: 9822.4843, cache_hits: 92044, cache_misses: 3956, enh_layer_cache_hits: 20044, enh_layer_cache_misses: 3956, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 38/300, Total Reward: 9930.0966, cache_hits: 92010, cache_misses: 3990, enh_layer_cache_hits: 20010, enh_layer_cache_misses: 3990, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 39/300, Total Reward: 9751.0358, cache_hits: 91725, cache_misses: 4275, enh_layer_cache_hits: 19725, enh_layer_cache_misses: 4275, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 40/300, Total Reward: 9736.5170, cache_hits: 91869, cache_misses: 4131, enh_layer_cache_hits: 19869, enh_layer_cache_misses: 4131, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 41/300, Total Reward: 9805.9230, cache_hits: 91895, cache_misses: 4105, enh_layer_cache_hits: 19895, enh_layer_cache_misses: 4105, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 42/300, Total Reward: 9984.4416, cache_hits: 92005, cache_misses: 3995, enh_layer_cache_hits: 20005, enh_layer_cache_misses: 3995, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 43/300, Total Reward: 9999.0475, cache_hits: 91884, cache_misses: 4116, enh_layer_cache_hits: 19884, enh_layer_cache_misses: 4116, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 44/300, Total Reward: 9883.0655, cache_hits: 91782, cache_misses: 4218, enh_layer_cache_hits: 19782, enh_layer_cache_misses: 4218, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 45/300, Total Reward: 9917.5788, cache_hits: 92141, cache_misses: 3859, enh_layer_cache_hits: 20141, enh_layer_cache_misses: 3859, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 46/300, Total Reward: 10062.8549, cache_hits: 91894, cache_misses: 4106, enh_layer_cache_hits: 19894, enh_layer_cache_misses: 4106, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 47/300, Total Reward: 10029.0414, cache_hits: 91882, cache_misses: 4118, enh_layer_cache_hits: 19882, enh_layer_cache_misses: 4118, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 48/300, Total Reward: 9699.5726, cache_hits: 91746, cache_misses: 4254, enh_layer_cache_hits: 19746, enh_layer_cache_misses: 4254, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 49/300, Total Reward: 10114.0854, cache_hits: 92074, cache_misses: 3926, enh_layer_cache_hits: 20074, enh_layer_cache_misses: 3926, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 50/300, Total Reward: 9971.6145, cache_hits: 92112, cache_misses: 3888, enh_layer_cache_hits: 20112, enh_layer_cache_misses: 3888, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 51/300, Total Reward: 9736.6495, cache_hits: 91745, cache_misses: 4255, enh_layer_cache_hits: 19745, enh_layer_cache_misses: 4255, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 52/300, Total Reward: 9994.2131, cache_hits: 91935, cache_misses: 4065, enh_layer_cache_hits: 19935, enh_layer_cache_misses: 4065, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.82,
# Episode 53/300, Total Reward: 9838.4987, cache_hits: 92043, cache_misses: 3957, enh_layer_cache_hits: 20043, enh_layer_cache_misses: 3957, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 54/300, Total Reward: 10046.2219, cache_hits: 91871, cache_misses: 4129, enh_layer_cache_hits: 19871, enh_layer_cache_misses: 4129, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 55/300, Total Reward: 9929.8136, cache_hits: 91927, cache_misses: 4073, enh_layer_cache_hits: 19927, enh_layer_cache_misses: 4073, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 56/300, Total Reward: 10137.8382, cache_hits: 92078, cache_misses: 3922, enh_layer_cache_hits: 20078, enh_layer_cache_misses: 3922, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.81,
# Episode 57/300, Total Reward: 10007.5514, cache_hits: 91914, cache_misses: 4086, enh_layer_cache_hits: 19914, enh_layer_cache_misses: 4086, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 58/300, Total Reward: 10010.6906, cache_hits: 91990, cache_misses: 4010, enh_layer_cache_hits: 19990, enh_layer_cache_misses: 4010, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 59/300, Total Reward: 10087.0957, cache_hits: 92000, cache_misses: 4000, enh_layer_cache_hits: 20000, enh_layer_cache_misses: 4000, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 60/300, Total Reward: 10180.8850, cache_hits: 92032, cache_misses: 3968, enh_layer_cache_hits: 20032, enh_layer_cache_misses: 3968, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 61/300, Total Reward: 9824.5358, cache_hits: 91905, cache_misses: 4095, enh_layer_cache_hits: 19905, enh_layer_cache_misses: 4095, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 62/300, Total Reward: 10401.4742, cache_hits: 92005, cache_misses: 3995, enh_layer_cache_hits: 20005, enh_layer_cache_misses: 3995, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 63/300, Total Reward: 9567.6258, cache_hits: 91928, cache_misses: 4072, enh_layer_cache_hits: 19928, enh_layer_cache_misses: 4072, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 64/300, Total Reward: 9822.3350, cache_hits: 91670, cache_misses: 4330, enh_layer_cache_hits: 19670, enh_layer_cache_misses: 4330, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 65/300, Total Reward: 9897.6898, cache_hits: 91771, cache_misses: 4229, enh_layer_cache_hits: 19771, enh_layer_cache_misses: 4229, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 66/300, Total Reward: 9811.4275, cache_hits: 91834, cache_misses: 4166, enh_layer_cache_hits: 19834, enh_layer_cache_misses: 4166, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 67/300, Total Reward: 9958.6770, cache_hits: 91887, cache_misses: 4113, enh_layer_cache_hits: 19887, enh_layer_cache_misses: 4113, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79,
# Episode 68/300, Total Reward: 10063.1733, cache_hits: 92144, cache_misses: 3856, enh_layer_cache_hits: 20144, enh_layer_cache_misses: 3856, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 69/300, Total Reward: 9639.5620, cache_hits: 91665, cache_misses: 4335, enh_layer_cache_hits: 19665, enh_layer_cache_misses: 4335, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 70/300, Total Reward: 10157.2568, cache_hits: 92036, cache_misses: 3964, enh_layer_cache_hits: 20036, enh_layer_cache_misses: 3964, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 71/300, Total Reward: 10121.2473, cache_hits: 92082, cache_misses: 3918, enh_layer_cache_hits: 20082, enh_layer_cache_misses: 3918, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 72/300, Total Reward: 9796.9768, cache_hits: 91864, cache_misses: 4136, enh_layer_cache_hits: 19864, enh_layer_cache_misses: 4136, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 73/300, Total Reward: 9943.2333, cache_hits: 91928, cache_misses: 4072, enh_layer_cache_hits: 19928, enh_layer_cache_misses: 4072, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 74/300, Total Reward: 9746.9682, cache_hits: 91932, cache_misses: 4068, enh_layer_cache_hits: 19932, enh_layer_cache_misses: 4068, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 75/300, Total Reward: 10261.6469, cache_hits: 91949, cache_misses: 4051, enh_layer_cache_hits: 19949, enh_layer_cache_misses: 4051, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 76/300, Total Reward: 9903.9996, cache_hits: 91980, cache_misses: 4020, enh_layer_cache_hits: 19980, enh_layer_cache_misses: 4020, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 77/300, Total Reward: 9906.6837, cache_hits: 91897, cache_misses: 4103, enh_layer_cache_hits: 19897, enh_layer_cache_misses: 4103, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 78/300, Total Reward: 9870.0427, cache_hits: 91845, cache_misses: 4155, enh_layer_cache_hits: 19845, enh_layer_cache_misses: 4155, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 79/300, Total Reward: 9583.4003, cache_hits: 91761, cache_misses: 4239, enh_layer_cache_hits: 19761, enh_layer_cache_misses: 4239, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 80/300, Total Reward: 9933.0250, cache_hits: 92062, cache_misses: 3938, enh_layer_cache_hits: 20062, enh_layer_cache_misses: 3938, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 81/300, Total Reward: 10036.5294, cache_hits: 92006, cache_misses: 3994, enh_layer_cache_hits: 20006, enh_layer_cache_misses: 3994, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 82/300, Total Reward: 10232.7072, cache_hits: 91944, cache_misses: 4056, enh_layer_cache_hits: 19944, enh_layer_cache_misses: 4056, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 83/300, Total Reward: 9839.6276, cache_hits: 91787, cache_misses: 4213, enh_layer_cache_hits: 19787, enh_layer_cache_misses: 4213, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 84/300, Total Reward: 9961.2906, cache_hits: 91906, cache_misses: 4094, enh_layer_cache_hits: 19906, enh_layer_cache_misses: 4094, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 85/300, Total Reward: 9808.2382, cache_hits: 91817, cache_misses: 4183, enh_layer_cache_hits: 19817, enh_layer_cache_misses: 4183, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 86/300, Total Reward: 9751.3729, cache_hits: 91793, cache_misses: 4207, enh_layer_cache_hits: 19793, enh_layer_cache_misses: 4207, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 87/300, Total Reward: 9665.5249, cache_hits: 91879, cache_misses: 4121, enh_layer_cache_hits: 19879, enh_layer_cache_misses: 4121, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 88/300, Total Reward: 9493.2845, cache_hits: 91612, cache_misses: 4388, enh_layer_cache_hits: 19612, enh_layer_cache_misses: 4388, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 89/300, Total Reward: 9937.8733, cache_hits: 91818, cache_misses: 4182, enh_layer_cache_hits: 19818, enh_layer_cache_misses: 4182, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 90/300, Total Reward: 9301.5365, cache_hits: 91952, cache_misses: 4048, enh_layer_cache_hits: 19952, enh_layer_cache_misses: 4048, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 91/300, Total Reward: 9710.8505, cache_hits: 91799, cache_misses: 4201, enh_layer_cache_hits: 19799, enh_layer_cache_misses: 4201, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 92/300, Total Reward: 9795.1363, cache_hits: 91759, cache_misses: 4241, enh_layer_cache_hits: 19759, enh_layer_cache_misses: 4241, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 93/300, Total Reward: 10259.1553, cache_hits: 92025, cache_misses: 3975, enh_layer_cache_hits: 20025, enh_layer_cache_misses: 3975, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 94/300, Total Reward: 9988.5728, cache_hits: 91859, cache_misses: 4141, enh_layer_cache_hits: 19859, enh_layer_cache_misses: 4141, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 95/300, Total Reward: 9638.6142, cache_hits: 91906, cache_misses: 4094, enh_layer_cache_hits: 19906, enh_layer_cache_misses: 4094, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 96/300, Total Reward: 10022.2723, cache_hits: 91847, cache_misses: 4153, enh_layer_cache_hits: 19847, enh_layer_cache_misses: 4153, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79,
# Episode 97/300, Total Reward: 9553.8566, cache_hits: 91834, cache_misses: 4166, enh_layer_cache_hits: 19834, enh_layer_cache_misses: 4166, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 98/300, Total Reward: 9843.5618, cache_hits: 91933, cache_misses: 4067, enh_layer_cache_hits: 19933, enh_layer_cache_misses: 4067, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 99/300, Total Reward: 9998.2417, cache_hits: 91830, cache_misses: 4170, enh_layer_cache_hits: 19830, enh_layer_cache_misses: 4170, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 100/300, Total Reward: 9728.0033, cache_hits: 91894, cache_misses: 4106, enh_layer_cache_hits: 19894, enh_layer_cache_misses: 4106, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 101/300, Total Reward: 9857.2469, cache_hits: 91853, cache_misses: 4147, enh_layer_cache_hits: 19853, enh_layer_cache_misses: 4147, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 102/300, Total Reward: 10179.9119, cache_hits: 92079, cache_misses: 3921, enh_layer_cache_hits: 20079, enh_layer_cache_misses: 3921, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 103/300, Total Reward: 9890.8263, cache_hits: 91886, cache_misses: 4114, enh_layer_cache_hits: 19886, enh_layer_cache_misses: 4114, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 104/300, Total Reward: 9851.5520, cache_hits: 91869, cache_misses: 4131, enh_layer_cache_hits: 19869, enh_layer_cache_misses: 4131, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 105/300, Total Reward: 9936.7785, cache_hits: 91798, cache_misses: 4202, enh_layer_cache_hits: 19798, enh_layer_cache_misses: 4202, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 106/300, Total Reward: 9719.1045, cache_hits: 91815, cache_misses: 4185, enh_layer_cache_hits: 19815, enh_layer_cache_misses: 4185, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 107/300, Total Reward: 9989.2037, cache_hits: 91979, cache_misses: 4021, enh_layer_cache_hits: 19979, enh_layer_cache_misses: 4021, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 108/300, Total Reward: 9767.7571, cache_hits: 91751, cache_misses: 4249, enh_layer_cache_hits: 19751, enh_layer_cache_misses: 4249, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 109/300, Total Reward: 10085.4934, cache_hits: 91926, cache_misses: 4074, enh_layer_cache_hits: 19926, enh_layer_cache_misses: 4074, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 110/300, Total Reward: 10173.7691, cache_hits: 91965, cache_misses: 4035, enh_layer_cache_hits: 19965, enh_layer_cache_misses: 4035, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 111/300, Total Reward: 9761.8681, cache_hits: 91876, cache_misses: 4124, enh_layer_cache_hits: 19876, enh_layer_cache_misses: 4124, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 112/300, Total Reward: 9780.2468, cache_hits: 91687, cache_misses: 4313, enh_layer_cache_hits: 19687, enh_layer_cache_misses: 4313, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 113/300, Total Reward: 10168.0087, cache_hits: 92004, cache_misses: 3996, enh_layer_cache_hits: 20004, enh_layer_cache_misses: 3996, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 114/300, Total Reward: 9952.1942, cache_hits: 91787, cache_misses: 4213, enh_layer_cache_hits: 19787, enh_layer_cache_misses: 4213, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 115/300, Total Reward: 10158.9505, cache_hits: 91742, cache_misses: 4258, enh_layer_cache_hits: 19742, enh_layer_cache_misses: 4258, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.83,
# Episode 116/300, Total Reward: 9731.8213, cache_hits: 91879, cache_misses: 4121, enh_layer_cache_hits: 19879, enh_layer_cache_misses: 4121, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 117/300, Total Reward: 9687.2268, cache_hits: 91757, cache_misses: 4243, enh_layer_cache_hits: 19757, enh_layer_cache_misses: 4243, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 118/300, Total Reward: 10157.6117, cache_hits: 92006, cache_misses: 3994, enh_layer_cache_hits: 20006, enh_layer_cache_misses: 3994, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 119/300, Total Reward: 9874.4557, cache_hits: 92025, cache_misses: 3975, enh_layer_cache_hits: 20025, enh_layer_cache_misses: 3975, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 120/300, Total Reward: 9927.3434, cache_hits: 92073, cache_misses: 3927, enh_layer_cache_hits: 20073, enh_layer_cache_misses: 3927, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 121/300, Total Reward: 9873.1428, cache_hits: 91872, cache_misses: 4128, enh_layer_cache_hits: 19872, enh_layer_cache_misses: 4128, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 122/300, Total Reward: 10254.0745, cache_hits: 92004, cache_misses: 3996, enh_layer_cache_hits: 20004, enh_layer_cache_misses: 3996, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 123/300, Total Reward: 9738.3973, cache_hits: 91811, cache_misses: 4189, enh_layer_cache_hits: 19811, enh_layer_cache_misses: 4189, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 124/300, Total Reward: 10121.2760, cache_hits: 91973, cache_misses: 4027, enh_layer_cache_hits: 19973, enh_layer_cache_misses: 4027, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 125/300, Total Reward: 10106.7222, cache_hits: 92016, cache_misses: 3984, enh_layer_cache_hits: 20016, enh_layer_cache_misses: 3984, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 126/300, Total Reward: 9857.4127, cache_hits: 91844, cache_misses: 4156, enh_layer_cache_hits: 19844, enh_layer_cache_misses: 4156, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 127/300, Total Reward: 9901.4737, cache_hits: 91898, cache_misses: 4102, enh_layer_cache_hits: 19898, enh_layer_cache_misses: 4102, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79,
# Episode 128/300, Total Reward: 10014.1246, cache_hits: 91849, cache_misses: 4151, enh_layer_cache_hits: 19849, enh_layer_cache_misses: 4151, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 129/300, Total Reward: 9922.0228, cache_hits: 91901, cache_misses: 4099, enh_layer_cache_hits: 19901, enh_layer_cache_misses: 4099, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 130/300, Total Reward: 10059.0745, cache_hits: 91942, cache_misses: 4058, enh_layer_cache_hits: 19942, enh_layer_cache_misses: 4058, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 131/300, Total Reward: 9894.9145, cache_hits: 91917, cache_misses: 4083, enh_layer_cache_hits: 19917, enh_layer_cache_misses: 4083, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 132/300, Total Reward: 10015.9996, cache_hits: 91881, cache_misses: 4119, enh_layer_cache_hits: 19881, enh_layer_cache_misses: 4119, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 133/300, Total Reward: 9711.1535, cache_hits: 91854, cache_misses: 4146, enh_layer_cache_hits: 19854, enh_layer_cache_misses: 4146, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 134/300, Total Reward: 9876.5363, cache_hits: 91796, cache_misses: 4204, enh_layer_cache_hits: 19796, enh_layer_cache_misses: 4204, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 135/300, Total Reward: 9835.4532, cache_hits: 92079, cache_misses: 3921, enh_layer_cache_hits: 20079, enh_layer_cache_misses: 3921, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 136/300, Total Reward: 10093.5729, cache_hits: 91849, cache_misses: 4151, enh_layer_cache_hits: 19849, enh_layer_cache_misses: 4151, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 137/300, Total Reward: 9885.0880, cache_hits: 91812, cache_misses: 4188, enh_layer_cache_hits: 19812, enh_layer_cache_misses: 4188, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 138/300, Total Reward: 10260.7467, cache_hits: 92010, cache_misses: 3990, enh_layer_cache_hits: 20010, enh_layer_cache_misses: 3990, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 139/300, Total Reward: 9660.8905, cache_hits: 91774, cache_misses: 4226, enh_layer_cache_hits: 19774, enh_layer_cache_misses: 4226, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 140/300, Total Reward: 9688.2627, cache_hits: 91868, cache_misses: 4132, enh_layer_cache_hits: 19868, enh_layer_cache_misses: 4132, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 141/300, Total Reward: 10038.3007, cache_hits: 91855, cache_misses: 4145, enh_layer_cache_hits: 19855, enh_layer_cache_misses: 4145, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 142/300, Total Reward: 9836.9866, cache_hits: 91778, cache_misses: 4222, enh_layer_cache_hits: 19778, enh_layer_cache_misses: 4222, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 143/300, Total Reward: 9615.4862, cache_hits: 91603, cache_misses: 4397, enh_layer_cache_hits: 19603, enh_layer_cache_misses: 4397, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 144/300, Total Reward: 9558.6464, cache_hits: 92003, cache_misses: 3997, enh_layer_cache_hits: 20003, enh_layer_cache_misses: 3997, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 145/300, Total Reward: 9784.8075, cache_hits: 91872, cache_misses: 4128, enh_layer_cache_hits: 19872, enh_layer_cache_misses: 4128, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 146/300, Total Reward: 9935.2029, cache_hits: 91944, cache_misses: 4056, enh_layer_cache_hits: 19944, enh_layer_cache_misses: 4056, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 147/300, Total Reward: 9650.7460, cache_hits: 91621, cache_misses: 4379, enh_layer_cache_hits: 19621, enh_layer_cache_misses: 4379, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 148/300, Total Reward: 9883.8820, cache_hits: 92017, cache_misses: 3983, enh_layer_cache_hits: 20017, enh_layer_cache_misses: 3983, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 149/300, Total Reward: 10014.2553, cache_hits: 92015, cache_misses: 3985, enh_layer_cache_hits: 20015, enh_layer_cache_misses: 3985, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 150/300, Total Reward: 9524.2690, cache_hits: 91761, cache_misses: 4239, enh_layer_cache_hits: 19761, enh_layer_cache_misses: 4239, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 151/300, Total Reward: 9461.1022, cache_hits: 91737, cache_misses: 4263, enh_layer_cache_hits: 19737, enh_layer_cache_misses: 4263, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 152/300, Total Reward: 10224.6153, cache_hits: 91960, cache_misses: 4040, enh_layer_cache_hits: 19960, enh_layer_cache_misses: 4040, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 153/300, Total Reward: 9997.8130, cache_hits: 92100, cache_misses: 3900, enh_layer_cache_hits: 20100, enh_layer_cache_misses: 3900, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 154/300, Total Reward: 9822.4117, cache_hits: 92011, cache_misses: 3989, enh_layer_cache_hits: 20011, enh_layer_cache_misses: 3989, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 155/300, Total Reward: 9979.2551, cache_hits: 91995, cache_misses: 4005, enh_layer_cache_hits: 19995, enh_layer_cache_misses: 4005, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 156/300, Total Reward: 10139.8439, cache_hits: 91875, cache_misses: 4125, enh_layer_cache_hits: 19875, enh_layer_cache_misses: 4125, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 157/300, Total Reward: 9810.8320, cache_hits: 91919, cache_misses: 4081, enh_layer_cache_hits: 19919, enh_layer_cache_misses: 4081, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 158/300, Total Reward: 9759.7378, cache_hits: 91874, cache_misses: 4126, enh_layer_cache_hits: 19874, enh_layer_cache_misses: 4126, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 159/300, Total Reward: 9867.0629, cache_hits: 91834, cache_misses: 4166, enh_layer_cache_hits: 19834, enh_layer_cache_misses: 4166, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 160/300, Total Reward: 10118.2512, cache_hits: 91971, cache_misses: 4029, enh_layer_cache_hits: 19971, enh_layer_cache_misses: 4029, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 161/300, Total Reward: 9860.2594, cache_hits: 91971, cache_misses: 4029, enh_layer_cache_hits: 19971, enh_layer_cache_misses: 4029, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 162/300, Total Reward: 9716.0112, cache_hits: 91916, cache_misses: 4084, enh_layer_cache_hits: 19916, enh_layer_cache_misses: 4084, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 163/300, Total Reward: 9862.7780, cache_hits: 91827, cache_misses: 4173, enh_layer_cache_hits: 19827, enh_layer_cache_misses: 4173, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 164/300, Total Reward: 9995.0586, cache_hits: 91823, cache_misses: 4177, enh_layer_cache_hits: 19823, enh_layer_cache_misses: 4177, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 165/300, Total Reward: 10388.3042, cache_hits: 92270, cache_misses: 3730, enh_layer_cache_hits: 20270, enh_layer_cache_misses: 3730, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79,
# Episode 166/300, Total Reward: 9849.8404, cache_hits: 91957, cache_misses: 4043, enh_layer_cache_hits: 19957, enh_layer_cache_misses: 4043, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 167/300, Total Reward: 9999.5006, cache_hits: 91975, cache_misses: 4025, enh_layer_cache_hits: 19975, enh_layer_cache_misses: 4025, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 168/300, Total Reward: 10008.5694, cache_hits: 91876, cache_misses: 4124, enh_layer_cache_hits: 19876, enh_layer_cache_misses: 4124, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 169/300, Total Reward: 9981.4003, cache_hits: 91540, cache_misses: 4460, enh_layer_cache_hits: 19540, enh_layer_cache_misses: 4460, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 170/300, Total Reward: 9796.0573, cache_hits: 91715, cache_misses: 4285, enh_layer_cache_hits: 19715, enh_layer_cache_misses: 4285, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.80,
# Episode 171/300, Total Reward: 10168.4737, cache_hits: 92052, cache_misses: 3948, enh_layer_cache_hits: 20052, enh_layer_cache_misses: 3948, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 172/300, Total Reward: 9743.3420, cache_hits: 91760, cache_misses: 4240, enh_layer_cache_hits: 19760, enh_layer_cache_misses: 4240, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 173/300, Total Reward: 9779.9502, cache_hits: 91887, cache_misses: 4113, enh_layer_cache_hits: 19887, enh_layer_cache_misses: 4113, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 174/300, Total Reward: 9855.8448, cache_hits: 92127, cache_misses: 3873, enh_layer_cache_hits: 20127, enh_layer_cache_misses: 3873, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 175/300, Total Reward: 9817.8259, cache_hits: 91927, cache_misses: 4073, enh_layer_cache_hits: 19927, enh_layer_cache_misses: 4073, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 176/300, Total Reward: 9993.1397, cache_hits: 91693, cache_misses: 4307, enh_layer_cache_hits: 19693, enh_layer_cache_misses: 4307, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 177/300, Total Reward: 9875.8281, cache_hits: 91727, cache_misses: 4273, enh_layer_cache_hits: 19727, enh_layer_cache_misses: 4273, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 178/300, Total Reward: 9893.0735, cache_hits: 91698, cache_misses: 4302, enh_layer_cache_hits: 19698, enh_layer_cache_misses: 4302, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 179/300, Total Reward: 10375.7420, cache_hits: 91915, cache_misses: 4085, enh_layer_cache_hits: 19915, enh_layer_cache_misses: 4085, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 180/300, Total Reward: 9792.0099, cache_hits: 91874, cache_misses: 4126, enh_layer_cache_hits: 19874, enh_layer_cache_misses: 4126, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 181/300, Total Reward: 10016.3940, cache_hits: 91950, cache_misses: 4050, enh_layer_cache_hits: 19950, enh_layer_cache_misses: 4050, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 182/300, Total Reward: 9959.4320, cache_hits: 91837, cache_misses: 4163, enh_layer_cache_hits: 19837, enh_layer_cache_misses: 4163, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 183/300, Total Reward: 9921.0158, cache_hits: 91899, cache_misses: 4101, enh_layer_cache_hits: 19899, enh_layer_cache_misses: 4101, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 184/300, Total Reward: 10021.7231, cache_hits: 91837, cache_misses: 4163, enh_layer_cache_hits: 19837, enh_layer_cache_misses: 4163, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 185/300, Total Reward: 10104.6613, cache_hits: 91970, cache_misses: 4030, enh_layer_cache_hits: 19970, enh_layer_cache_misses: 4030, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 186/300, Total Reward: 9738.6649, cache_hits: 91882, cache_misses: 4118, enh_layer_cache_hits: 19882, enh_layer_cache_misses: 4118, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 187/300, Total Reward: 9740.4554, cache_hits: 92006, cache_misses: 3994, enh_layer_cache_hits: 20006, enh_layer_cache_misses: 3994, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 188/300, Total Reward: 10056.8250, cache_hits: 92047, cache_misses: 3953, enh_layer_cache_hits: 20047, enh_layer_cache_misses: 3953, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 189/300, Total Reward: 9911.7755, cache_hits: 91778, cache_misses: 4222, enh_layer_cache_hits: 19778, enh_layer_cache_misses: 4222, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 190/300, Total Reward: 10017.6596, cache_hits: 91966, cache_misses: 4034, enh_layer_cache_hits: 19966, enh_layer_cache_misses: 4034, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 191/300, Total Reward: 9915.5438, cache_hits: 92077, cache_misses: 3923, enh_layer_cache_hits: 20077, enh_layer_cache_misses: 3923, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 192/300, Total Reward: 9822.7126, cache_hits: 91800, cache_misses: 4200, enh_layer_cache_hits: 19800, enh_layer_cache_misses: 4200, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 193/300, Total Reward: 9905.0527, cache_hits: 91900, cache_misses: 4100, enh_layer_cache_hits: 19900, enh_layer_cache_misses: 4100, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 194/300, Total Reward: 9963.3739, cache_hits: 91743, cache_misses: 4257, enh_layer_cache_hits: 19743, enh_layer_cache_misses: 4257, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 195/300, Total Reward: 10068.2699, cache_hits: 91818, cache_misses: 4182, enh_layer_cache_hits: 19818, enh_layer_cache_misses: 4182, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 196/300, Total Reward: 10316.6146, cache_hits: 91969, cache_misses: 4031, enh_layer_cache_hits: 19969, enh_layer_cache_misses: 4031, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 197/300, Total Reward: 9714.5699, cache_hits: 91912, cache_misses: 4088, enh_layer_cache_hits: 19912, enh_layer_cache_misses: 4088, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 198/300, Total Reward: 10146.8429, cache_hits: 92241, cache_misses: 3759, enh_layer_cache_hits: 20241, enh_layer_cache_misses: 3759, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 199/300, Total Reward: 9681.1144, cache_hits: 91706, cache_misses: 4294, enh_layer_cache_hits: 19706, enh_layer_cache_misses: 4294, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 200/300, Total Reward: 10057.4770, cache_hits: 91923, cache_misses: 4077, enh_layer_cache_hits: 19923, enh_layer_cache_misses: 4077, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 201/300, Total Reward: 9783.7105, cache_hits: 91906, cache_misses: 4094, enh_layer_cache_hits: 19906, enh_layer_cache_misses: 4094, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 202/300, Total Reward: 9830.4453, cache_hits: 91926, cache_misses: 4074, enh_layer_cache_hits: 19926, enh_layer_cache_misses: 4074, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 203/300, Total Reward: 9934.7412, cache_hits: 91838, cache_misses: 4162, enh_layer_cache_hits: 19838, enh_layer_cache_misses: 4162, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 204/300, Total Reward: 9755.9856, cache_hits: 91908, cache_misses: 4092, enh_layer_cache_hits: 19908, enh_layer_cache_misses: 4092, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 205/300, Total Reward: 10133.0709, cache_hits: 92075, cache_misses: 3925, enh_layer_cache_hits: 20075, enh_layer_cache_misses: 3925, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 206/300, Total Reward: 9887.4579, cache_hits: 91679, cache_misses: 4321, enh_layer_cache_hits: 19679, enh_layer_cache_misses: 4321, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 207/300, Total Reward: 9642.2309, cache_hits: 91785, cache_misses: 4215, enh_layer_cache_hits: 19785, enh_layer_cache_misses: 4215, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 208/300, Total Reward: 9829.8018, cache_hits: 91965, cache_misses: 4035, enh_layer_cache_hits: 19965, enh_layer_cache_misses: 4035, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 209/300, Total Reward: 9635.7013, cache_hits: 91787, cache_misses: 4213, enh_layer_cache_hits: 19787, enh_layer_cache_misses: 4213, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 210/300, Total Reward: 10000.4218, cache_hits: 91789, cache_misses: 4211, enh_layer_cache_hits: 19789, enh_layer_cache_misses: 4211, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 211/300, Total Reward: 10029.9004, cache_hits: 91720, cache_misses: 4280, enh_layer_cache_hits: 19720, enh_layer_cache_misses: 4280, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 212/300, Total Reward: 10157.5176, cache_hits: 92306, cache_misses: 3694, enh_layer_cache_hits: 20306, enh_layer_cache_misses: 3694, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.79,
# Episode 213/300, Total Reward: 9677.0855, cache_hits: 91928, cache_misses: 4072, enh_layer_cache_hits: 19928, enh_layer_cache_misses: 4072, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 214/300, Total Reward: 9815.9302, cache_hits: 91730, cache_misses: 4270, enh_layer_cache_hits: 19730, enh_layer_cache_misses: 4270, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 215/300, Total Reward: 9812.3621, cache_hits: 91639, cache_misses: 4361, enh_layer_cache_hits: 19639, enh_layer_cache_misses: 4361, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 216/300, Total Reward: 9395.7615, cache_hits: 91800, cache_misses: 4200, enh_layer_cache_hits: 19800, enh_layer_cache_misses: 4200, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 217/300, Total Reward: 9887.7828, cache_hits: 91972, cache_misses: 4028, enh_layer_cache_hits: 19972, enh_layer_cache_misses: 4028, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# ...
# Episode 229/300, Total Reward: 10052.2048, cache_hits: 91780, cache_misses: 4220, enh_layer_cache_hits: 19780, enh_layer_cache_misses: 4220, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 230/300, Total Reward: 9763.0401, cache_hits: 92094, cache_misses: 3906, enh_layer_cache_hits: 20094, enh_layer_cache_misses: 3906, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 231/300, Total Reward: 10411.6450, cache_hits: 91911, cache_misses: 4089, enh_layer_cache_hits: 19911, enh_layer_cache_misses: 4089, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 232/300, Total Reward: 9897.5471, cache_hits: 91767, cache_misses: 4233, enh_layer_cache_hits: 19767, enh_layer_cache_misses: 4233, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 233/300, Total Reward: 9888.3532, cache_hits: 91971, cache_misses: 4029, enh_layer_cache_hits: 19971, enh_layer_cache_misses: 4029, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 234/300, Total Reward: 9668.6006, cache_hits: 91931, cache_misses: 4069, enh_layer_cache_hits: 19931, enh_layer_cache_misses: 4069, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.65,
# Episode 235/300, Total Reward: 9846.3804, cache_hits: 91672, cache_misses: 4328, enh_layer_cache_hits: 19672, enh_layer_cache_misses: 4328, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 236/300, Total Reward: 9940.0059, cache_hits: 91676, cache_misses: 4324, enh_layer_cache_hits: 19676, enh_layer_cache_misses: 4324, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 237/300, Total Reward: 9760.5651, cache_hits: 91810, cache_misses: 4190, enh_layer_cache_hits: 19810, enh_layer_cache_misses: 4190, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 238/300, Total Reward: 9915.9629, cache_hits: 91863, cache_misses: 4137, enh_layer_cache_hits: 19863, enh_layer_cache_misses: 4137, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 239/300, Total Reward: 9784.1758, cache_hits: 91835, cache_misses: 4165, enh_layer_cache_hits: 19835, enh_layer_cache_misses: 4165, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 240/300, Total Reward: 9848.2720, cache_hits: 92125, cache_misses: 3875, enh_layer_cache_hits: 20125, enh_layer_cache_misses: 3875, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 241/300, Total Reward: 9751.1040, cache_hits: 91874, cache_misses: 4126, enh_layer_cache_hits: 19874, enh_layer_cache_misses: 4126, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 242/300, Total Reward: 10152.5017, cache_hits: 91866, cache_misses: 4134, enh_layer_cache_hits: 19866, enh_layer_cache_misses: 4134, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 243/300, Total Reward: 9935.8777, cache_hits: 91956, cache_misses: 4044, enh_layer_cache_hits: 19956, enh_layer_cache_misses: 4044, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 244/300, Total Reward: 10217.9493, cache_hits: 91926, cache_misses: 4074, enh_layer_cache_hits: 19926, enh_layer_cache_misses: 4074, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 245/300, Total Reward: 10124.0906, cache_hits: 91726, cache_misses: 4274, enh_layer_cache_hits: 19726, enh_layer_cache_misses: 4274, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 246/300, Total Reward: 9660.1165, cache_hits: 91939, cache_misses: 4061, enh_layer_cache_hits: 19939, enh_layer_cache_misses: 4061, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 247/300, Total Reward: 10012.6944, cache_hits: 92030, cache_misses: 3970, enh_layer_cache_hits: 20030, enh_layer_cache_misses: 3970, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 248/300, Total Reward: 9690.5275, cache_hits: 91705, cache_misses: 4295, enh_layer_cache_hits: 19705, enh_layer_cache_misses: 4295, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 249/300, Total Reward: 9942.9308, cache_hits: 91556, cache_misses: 4444, enh_layer_cache_hits: 19556, enh_layer_cache_misses: 4444, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 250/300, Total Reward: 9846.3468, cache_hits: 91713, cache_misses: 4287, enh_layer_cache_hits: 19713, enh_layer_cache_misses: 4287, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.68,
# Episode 251/300, Total Reward: 9840.8459, cache_hits: 91735, cache_misses: 4265, enh_layer_cache_hits: 19735, enh_layer_cache_misses: 4265, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 252/300, Total Reward: 9980.0969, cache_hits: 91890, cache_misses: 4110, enh_layer_cache_hits: 19890, enh_layer_cache_misses: 4110, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 253/300, Total Reward: 9973.3217, cache_hits: 91896, cache_misses: 4104, enh_layer_cache_hits: 19896, enh_layer_cache_misses: 4104, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 254/300, Total Reward: 9550.7725, cache_hits: 91740, cache_misses: 4260, enh_layer_cache_hits: 19740, enh_layer_cache_misses: 4260, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 255/300, Total Reward: 9719.4390, cache_hits: 91903, cache_misses: 4097, enh_layer_cache_hits: 19903, enh_layer_cache_misses: 4097, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 256/300, Total Reward: 9946.9311, cache_hits: 91947, cache_misses: 4053, enh_layer_cache_hits: 19947, enh_layer_cache_misses: 4053, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 257/300, Total Reward: 10010.4551, cache_hits: 91735, cache_misses: 4265, enh_layer_cache_hits: 19735, enh_layer_cache_misses: 4265, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 258/300, Total Reward: 9754.2755, cache_hits: 91976, cache_misses: 4024, enh_layer_cache_hits: 19976, enh_layer_cache_misses: 4024, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 259/300, Total Reward: 9606.8085, cache_hits: 91782, cache_misses: 4218, enh_layer_cache_hits: 19782, enh_layer_cache_misses: 4218, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 260/300, Total Reward: 10012.9536, cache_hits: 91923, cache_misses: 4077, enh_layer_cache_hits: 19923, enh_layer_cache_misses: 4077, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 261/300, Total Reward: 9840.2227, cache_hits: 91909, cache_misses: 4091, enh_layer_cache_hits: 19909, enh_layer_cache_misses: 4091, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 262/300, Total Reward: 9634.7567, cache_hits: 91700, cache_misses: 4300, enh_layer_cache_hits: 19700, enh_layer_cache_misses: 4300, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 263/300, Total Reward: 10069.7989, cache_hits: 91794, cache_misses: 4206, enh_layer_cache_hits: 19794, enh_layer_cache_misses: 4206, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 264/300, Total Reward: 9966.9558, cache_hits: 91877, cache_misses: 4123, enh_layer_cache_hits: 19877, enh_layer_cache_misses: 4123, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 265/300, Total Reward: 10033.6949, cache_hits: 91934, cache_misses: 4066, enh_layer_cache_hits: 19934, enh_layer_cache_misses: 4066, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 266/300, Total Reward: 10174.4295, cache_hits: 91987, cache_misses: 4013, enh_layer_cache_hits: 19987, enh_layer_cache_misses: 4013, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 267/300, Total Reward: 9694.7920, cache_hits: 91871, cache_misses: 4129, enh_layer_cache_hits: 19871, enh_layer_cache_misses: 4129, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.66,
# Episode 268/300, Total Reward: 9876.3428, cache_hits: 91797, cache_misses: 4203, enh_layer_cache_hits: 19797, enh_layer_cache_misses: 4203, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 269/300, Total Reward: 9885.2352, cache_hits: 91796, cache_misses: 4204, enh_layer_cache_hits: 19796, enh_layer_cache_misses: 4204, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 270/300, Total Reward: 9714.2644, cache_hits: 91859, cache_misses: 4141, enh_layer_cache_hits: 19859, enh_layer_cache_misses: 4141, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 271/300, Total Reward: 9879.6496, cache_hits: 91994, cache_misses: 4006, enh_layer_cache_hits: 19994, enh_layer_cache_misses: 4006, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 272/300, Total Reward: 9948.8745, cache_hits: 91907, cache_misses: 4093, enh_layer_cache_hits: 19907, enh_layer_cache_misses: 4093, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 273/300, Total Reward: 9973.2267, cache_hits: 91865, cache_misses: 4135, enh_layer_cache_hits: 19865, enh_layer_cache_misses: 4135, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,
# Episode 274/300, Total Reward: 9739.6621, cache_hits: 91896, cache_misses: 4104, enh_layer_cache_hits: 19896, enh_layer_cache_misses: 4104, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.69,
# Episode 275/300, Total Reward: 10066.4492, cache_hits: 91764, cache_misses: 4236, enh_layer_cache_hits: 19764, enh_layer_cache_misses: 4236, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 276/300, Total Reward: 9955.5814, cache_hits: 91987, cache_misses: 4013, enh_layer_cache_hits: 19987, enh_layer_cache_misses: 4013, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 277/300, Total Reward: 9869.0891, cache_hits: 91769, cache_misses: 4231, enh_layer_cache_hits: 19769, enh_layer_cache_misses: 4231, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 278/300, Total Reward: 9807.9270, cache_hits: 91797, cache_misses: 4203, enh_layer_cache_hits: 19797, enh_layer_cache_misses: 4203, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 279/300, Total Reward: 9994.0397, cache_hits: 91983, cache_misses: 4017, enh_layer_cache_hits: 19983, enh_layer_cache_misses: 4017, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 280/300, Total Reward: 9814.3992, cache_hits: 91780, cache_misses: 4220, enh_layer_cache_hits: 19780, enh_layer_cache_misses: 4220, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 281/300, Total Reward: 9804.5579, cache_hits: 91782, cache_misses: 4218, enh_layer_cache_hits: 19782, enh_layer_cache_misses: 4218, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 282/300, Total Reward: 9815.5593, cache_hits: 91906, cache_misses: 4094, enh_layer_cache_hits: 19906, enh_layer_cache_misses: 4094, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.70,
# Episode 283/300, Total Reward: 9832.8377, cache_hits: 91746, cache_misses: 4254, enh_layer_cache_hits: 19746, enh_layer_cache_misses: 4254, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.76,
# Episode 284/300, Total Reward: 9873.7551, cache_hits: 91985, cache_misses: 4015, enh_layer_cache_hits: 19985, enh_layer_cache_misses: 4015, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 285/300, Total Reward: 9979.4644, cache_hits: 91908, cache_misses: 4092, enh_layer_cache_hits: 19908, enh_layer_cache_misses: 4092, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 286/300, Total Reward: 9897.9977, cache_hits: 91654, cache_misses: 4346, enh_layer_cache_hits: 19654, enh_layer_cache_misses: 4346, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 287/300, Total Reward: 9970.1982, cache_hits: 91975, cache_misses: 4025, enh_layer_cache_hits: 19975, enh_layer_cache_misses: 4025, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 288/300, Total Reward: 10349.1441, cache_hits: 91965, cache_misses: 4035, enh_layer_cache_hits: 19965, enh_layer_cache_misses: 4035, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 289/300, Total Reward: 10019.0907, cache_hits: 92014, cache_misses: 3986, enh_layer_cache_hits: 20014, enh_layer_cache_misses: 3986, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.77,
# Episode 290/300, Total Reward: 10085.8828, cache_hits: 91843, cache_misses: 4157, enh_layer_cache_hits: 19843, enh_layer_cache_misses: 4157, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.81,
# Episode 291/300, Total Reward: 9814.5338, cache_hits: 91862, cache_misses: 4138, enh_layer_cache_hits: 19862, enh_layer_cache_misses: 4138, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 292/300, Total Reward: 9801.5769, cache_hits: 91868, cache_misses: 4132, enh_layer_cache_hits: 19868, enh_layer_cache_misses: 4132, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.75,
# Episode 293/300, Total Reward: 9733.2732, cache_hits: 91831, cache_misses: 4169, enh_layer_cache_hits: 19831, enh_layer_cache_misses: 4169, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 294/300, Total Reward: 9830.9370, cache_hits: 91868, cache_misses: 4132, enh_layer_cache_hits: 19868, enh_layer_cache_misses: 4132, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.78,
# Episode 295/300, Total Reward: 9932.1457, cache_hits: 92007, cache_misses: 3993, enh_layer_cache_hits: 20007, enh_layer_cache_misses: 3993, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.72,
# Episode 296/300, Total Reward: 9919.1290, cache_hits: 91846, cache_misses: 4154, enh_layer_cache_hits: 19846, enh_layer_cache_misses: 4154, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 297/300, Total Reward: 9614.8836, cache_hits: 91966, cache_misses: 4034, enh_layer_cache_hits: 19966, enh_layer_cache_misses: 4034, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.67,
# Episode 298/300, Total Reward: 9701.5196, cache_hits: 91881, cache_misses: 4119, enh_layer_cache_hits: 19881, enh_layer_cache_misses: 4119, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.71,
# Episode 299/300, Total Reward: 9591.1497, cache_hits: 91719, cache_misses: 4281, enh_layer_cache_hits: 19719, enh_layer_cache_misses: 4281, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.73,
# Episode 300/300, Total Reward: 9909.1849, cache_hits: 91991, cache_misses: 4009, enh_layer_cache_hits: 19991, enh_layer_cache_misses: 4009, base_layer_cache_hits: 72000, base_layer_cache_misses: 0, Average PSNR: 38.74,

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# 1. Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_yscale('log') 
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# 2. Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_yscale('log') 
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# 3. Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_yscale('log')
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5519/3657158268.py:17: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[0].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_5519/3657158268.py:27: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[1].set_ylim(bottom=0)  # <--- Forces y-axis to start at 0
# /tmp/ipykernel_5519/3657158268.py:37: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   axes[2].set_ylim(bottom=0)

# %%
episodes = range(1, len(scores) + 1)
cache_hits_series = [r["cache_hits"] for r in results]
cache_misses_series = [r["cache_misses"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharex=True)

# Rewards with moving average
axes[0].plot(episodes, scores, label="Episode reward", alpha=0.7, color="blue")
w = max(1, min(20, len(scores) // 10))
if w > 1:
    ma = [sum(scores[i - w:i]) / w for i in range(w, len(scores) + 1)]
    axes[0].plot(range(w, len(scores) + 1), ma, label=f"Moving avg (w={w})", color="orange")
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Total reward")
axes[0].set_title("Training Rewards")
axes[0].set_ylim(bottom=0)
axes[0].grid(True, alpha=0.3)
axes[0].legend()

# Cache hits
axes[1].plot(episodes, cache_hits_series, label="Cache hits", color="green", alpha=0.8)
axes[1].set_title("Cache Hits per Episode")
axes[1].set_xlabel("Episode")
axes[1].set_ylabel("Hits")
axes[1].set_ylim(bottom=0)
axes[1].grid(True, alpha=0.3)
axes[1].legend()

# Cache misses
axes[2].plot(episodes, cache_misses_series, label="Cache misses", color="red", alpha=0.8)
axes[2].set_title("Cache Misses per Episode")
axes[2].set_xlabel("Episode")
axes[2].set_ylabel("Misses")
axes[2].set_ylim(bottom=0)
axes[2].grid(True, alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
        ]
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)

    # Compute per-episode percentages
    def safe_pct(num, den):
        return 0.0 if den == 0 else 100.0 * num / den

    enh_totals = [h + m for h, m in zip(enhanced_hits, enhanced_misses)]
    base_totals = [h + m for h, m in zip(base_hits, base_misses)]

    enh_hit_rate = [safe_pct(h, t) for h, t in zip(enhanced_hits, enh_totals)]
    enh_miss_rate = [safe_pct(m, t) for m, t in zip(enhanced_misses, enh_totals)]
    base_hit_rate = [safe_pct(h, t) for h, t in zip(base_hits, base_totals)]
    base_miss_rate = [safe_pct(m, t) for m, t in zip(base_misses, base_totals)]

    # Shared y-lims per layer type (percentages)
    enh_ylim = (0, 100)
    base_ylim = (0, 100)

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Enhanced Layer: Hit rate
    axes[0, 0].plot(episodes, enh_hit_rate, label="Enhanced hit rate (%)", color="blue", alpha=0.9)
    axes[0, 0].set_title("Enhanced Layer Hit Rate")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Rate (%)")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Enhanced Layer: Miss rate
    axes[0, 1].plot(episodes, enh_miss_rate, label="Enhanced miss rate (%)", color="red", alpha=0.9)
    axes[0, 1].set_title("Enhanced Layer Miss Rate")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Rate (%)")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Base Layer: Hit rate
    axes[1, 0].plot(episodes, base_hit_rate, label="Base hit rate (%)", color="green", alpha=0.9)
    axes[1, 0].set_title("Base Layer Hit Rate")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Rate (%)")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Base Layer: Miss rate
    axes[1, 1].plot(episodes, base_miss_rate, label="Base miss rate (%)", color="orange", alpha=0.9)
    axes[1, 1].set_title("Base Layer Miss Rate")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Rate (%)")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    if title:
        fig.suptitle(title, y=1.02)
    plt.tight_layout()

    if out_path:
        plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()


if __name__ == "__main__":
    csv_filepath = '/home/eduardo/Workspace/CacheVideoPredict360/Results'
    # csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap150MB_eps0.05_2.csv'
    csv_filepath += '/fov_predictor_U500_V1000_G60_L2_N4_cap300MB_eps0.05_2.csv'
    
    #out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap150MB_eps0.05_2.png'
    out_path = None

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 123
#     119 out_path = None
#     121 title = "FOV Predictor DQN Agent Cache Layers Performance"
# --> 123 plot_cache_layers(
#     124     csv_filepath,
#     125     out_path=None,
#     126     title=title
#     127 )
#
# Cell In[20], line 48, in plot_cache_layers(csv_path, out_path, title)
#      43 def plot_cache_layers(
#      44     csv_path: str,
#      45     out_path: str | None = None,
#      46     title: str | None = None,
#      47 ):
# ---> 48     episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)
#      50     # Compute per-episode percentages
#      51     def safe_pct(num, den):
#
# Cell In[20], line 12, in read_results(csv_path)
#       9 base_misses: List[float] = []
#      11 if not os.path.exists(csv_path):
# ---> 12     raise FileNotFoundError(f"CSV file not found: {csv_path}")
#      14 with open(csv_path, "r", newline="") as f:
#      15     reader = csv.DictReader(f)
#
# FileNotFoundError: CSV file not found: /home/eduardo/Workspace/CacheVideoPredict360/Results/fov_predictor_U500_V1000_G60_L2_N4_cap300MB_eps0.05_2.csv

# %%
from typing import List
import os

def read_results(csv_path: str):
    episodes: List[int] = []
    enhanced_hits: List[float] = []
    enhanced_misses: List[float] = []
    base_hits: List[float] = []
    base_misses: List[float] = []

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"CSV file not found: {csv_path}")

    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        required_cols = [
            "episode",
            "enhanced_layer_cache_hits",
            "enhanced_layer_cache_misses",
            "base_layer_cache_hits",
            "base_layer_cache_misses",
        ]
        missing = [c for c in required_cols if c not in reader.fieldnames]
        if missing:
            raise ValueError(
                f"CSV missing required columns: {missing}. Found: {reader.fieldnames}"
            )

        for row in reader:
            try:
                episodes.append(int(row["episode"]))
                enhanced_hits.append(float(row["enhanced_layer_cache_hits"]))
                enhanced_misses.append(float(row["enhanced_layer_cache_misses"]))
                base_hits.append(float(row["base_layer_cache_hits"]))
                base_misses.append(float(row["base_layer_cache_misses"]))
            except (ValueError, KeyError):
                # skip malformed rows
                continue

    return episodes, enhanced_hits, enhanced_misses, base_hits, base_misses


def plot_cache_layers(
    csv_path: str,
    out_path: str | None = None,
    title: str | None = None,
):
    episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)

    # Compute shared y-lims per layer type
    def compute_ylim(a, b, pad=0.05, min_top=1.0):
        top = max(max(a or [0.0]), max(b or [0.0]))
        top = max(min_top, top)
        return (0, top * (1 + pad))

    enh_ylim = compute_ylim(enhanced_hits, enhanced_misses)
    base_ylim = compute_ylim(base_hits, base_misses)

    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Plot 1: Enhanced Layer Cache Hits
    axes[0, 0].plot(episodes, enhanced_hits, label="Enhanced layer hits", color="blue", alpha=0.8)
    axes[0, 0].set_title("Enhanced Layer Cache Hits per Episode")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Hits")
    axes[0, 0].set_ylim(enh_ylim)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Plot 2: Enhanced Layer Cache Misses
    axes[0, 1].plot(episodes, enhanced_misses, label="Enhanced layer misses", color="red", alpha=0.8)
    axes[0, 1].set_title("Enhanced Layer Cache Misses per Episode")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Misses")
    axes[0, 1].set_ylim(enh_ylim)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Plot 3: Base Layer Cache Hits
    axes[1, 0].plot(episodes, base_hits, label="Base layer hits", color="green", alpha=0.8)
    axes[1, 0].set_title("Base Layer Cache Hits per Episode")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Hits")
    axes[1, 0].set_ylim(base_ylim)
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Plot 4: Base Layer Cache Misses
    axes[1, 1].plot(episodes, base_misses, label="Base layer misses", color="orange", alpha=0.8)
    axes[1, 1].set_title("Base Layer Cache Misses per Episode")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Misses")
    axes[1, 1].set_ylim(base_ylim)
    axes[1, 1].grid(True, alpha=0.3)
    axes[1, 1].legend()

    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    csv_filepath = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2.csv'
    
    out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2_layers.png'

    title = "FOV Predictor DQN Agent Cache Layers Performance"

    plot_cache_layers(
        csv_filepath, 
        out_path=None, 
        title=title
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 108
#     104 out_path = r'c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2_layers.png'
#     106 title = "FOV Predictor DQN Agent Cache Layers Performance"
# --> 108 plot_cache_layers(
#     109     csv_filepath,
#     110     out_path=None,
#     111     title=title
#     112 )
#
# Cell In[27], line 48, in plot_cache_layers(csv_path, out_path, title)
#      43 def plot_cache_layers(
#      44     csv_path: str,
#      45     out_path: str | None = None,
#      46     title: str | None = None,
#      47 ):
# ---> 48     episodes, enhanced_hits, enhanced_misses, base_hits, base_misses = read_results(csv_path)
#      50     # Compute shared y-lims per layer type
#      51     def compute_ylim(a, b, pad=0.05, min_top=1.0):
#
# Cell In[27], line 12, in read_results(csv_path)
#       9 base_misses: List[float] = []
#      11 if not os.path.exists(csv_path):
# ---> 12     raise FileNotFoundError(f"CSV file not found: {csv_path}")
#      14 with open(csv_path, "r", newline="") as f:
#      15     reader = csv.DictReader(f)
#
# FileNotFoundError: CSV file not found: c:\Users\es25591\Workspace\CacheVideoPredict360\Results\fov_predictor_U500_V1000_G60_L2_N4_cap100MB_eps0.05_2.csv
