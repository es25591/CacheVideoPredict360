# %%
import math
import csv
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import Any, Dict, Counter, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torch_optimizer as optim_extra

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv, DrlPolicy
    from LabUserRequest import UserRequestEvents
    from LabEnvWrapper import EnvWrapper

import os
import sys

sources_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if sources_path not in sys.path:
    sys.path.append(sources_path)

import Common.config as config
import Common.datatypes as datatypes
import Common.utils as utils

import importlib

importlib.reload(config)
importlib.reload(datatypes)
importlib.reload(utils)
# Out:
# <module 'Common.utils' from 'c:\\Users\\es25591\\Workspace\\CacheVideoPredict360\\Sources\\Common\\utils.py'>

# %%
cfg = config.Config()

# cfg.filename = f"drl_dqn_softup_lrdecay{cfg.learning_rate_decay}_u{cfg.n_users}_e{cfg.n_episodes}_c{cfg.cache_size}_ar{cfg.arrival_rate}_z{cfg.zipf_alpha}.csv"
cfg.filename = f"drl_dqn_softup_fixedlr{cfg.learning_rate}_e{cfg.n_episodes}_c{cfg.cache_size}_ar{cfg.arrival_rate}_z{cfg.zipf_alpha}.csv"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int):
        super().__init__()
        hidden = 128
        self.fc1 = nn.Linear(state_dim, hidden)
        self.fc2 = nn.Linear(hidden, hidden)
        self.out = nn.Linear(hidden, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.out(x)

class ReplayBuffer:
    def __init__(self, capacity: int = 10000):
        self.memory = deque(maxlen=capacity)
    
    def push(self, s, a, r, ns, d):
        self.memory.append((s, a, r, ns, d))
    
    def sample(self, batch_size: int):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

class DQNAgent:
    def __init__(self, cfg: Any):
        self.step = 0
        
        self.state_dim = cfg.state_dim
        self.action_dim = cfg.action_dim
        
        self.epsilon = cfg.epsilon_start
        self.epsilon_min = cfg.epsilon_min
        self.epsilon_decay = cfg.epsilon_decay
        self.gamma = cfg.gamma
        self.tau = cfg.tau
        self.batch_size = cfg.batch_size
        
        self.buffer = ReplayBuffer(cfg.buffer_capacity)
        
        self.policy_net = QNetwork(self.state_dim, self.action_dim).to(device)
        self.target_net = QNetwork(self.state_dim, self.action_dim).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=cfg.learning_rate)
        
        self.scheduler = torch.optim.lr_scheduler.ExponentialLR(
            self.optimizer, 
            gamma=cfg.learning_rate_decay
        )
        
        self.loss_fn = nn.MSELoss()
        self.nb_interval = cfg.nb_interval  # train every 5 requests

    def select_action(self, state):
        if random.random() < self.epsilon:
            action_idx = random.randint(0, self.action_dim - 1)
            return action_idx, None
        
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.policy_net(state)
        
        action_idx = q_values.argmax().item()
        return action_idx, q_values
        
    def remember(self, s, a, r, ns, done):
        self.buffer.push(s, a, r, ns, done)

    def train_step(self):
        self.step += 1
        if self.step % self.nb_interval == 0 and \
           len(self.buffer) >= self.batch_size:
            self.learn()

    def learn(self):
        batch = self.buffer.sample(self.batch_size)
        s, a, r, ns, d = zip(*batch)
        s = torch.tensor(np.stack(s), dtype=torch.float32).to(device)
        ns = torch.tensor(np.stack(ns), dtype=torch.float32).to(device)
        a = torch.tensor(a, dtype=torch.int64).to(device)
        r = torch.tensor(r, dtype=torch.float32).to(device)
        d = torch.tensor(d, dtype=torch.float32).to(device)

        with torch.no_grad():
            q_next = self.target_net(ns).max(1)[0]
            q_target = r + self.gamma * q_next * (1.0 - d)

        q_expected = self.policy_net(s).gather(1, a.unsqueeze(1)).squeeze(1)

        loss = self.loss_fn(q_expected, q_target)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        # self.scheduler.step()
        
        self.soft_update_target()

    def soft_update_target(self):
        for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
            target_param.data.copy_( 
                target_param.data * (1.0 - self.tau) + policy_param.data * self.tau
            )

    def update_target(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        
    def reset_step(self):
        self.step = 0

# %%
def save_training_results(
    path_,
    filename,
    ep, 
    total_reward, 
    cache_hits, 
    cache_misses, 
    soft_hits,
    agent
):
    with open(os.path.join(path_, filename), 'a', newline='') as f:
        fieldnames = [
            'episode', 
            'total_reward', 
            'cache_hits', 
            'cache_misses', 
            'soft_hits',
            'epsilon',
            'lr'
        ]
        writer_results = csv.DictWriter(f, fieldnames=fieldnames)

        if ep == 0:
            writer_results.writeheader()
        
        writer_results.writerow({
            'episode': ep,
            'total_reward': round(float(total_reward), 2),
            'cache_hits': cache_hits,
            'cache_misses': cache_misses,
            'soft_hits': soft_hits,
            'lr': f"{agent.scheduler.get_last_lr()[0]:.10f}" if agent else None,
            'epsilon': round(float(agent.epsilon), 4) if agent else None
        })

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, float]:
    enh_hits = info.get("enh_layer_cache_hits", 0)
    base_hits = info.get("base_layer_cache_hits", 0)
    enh_misses = info.get("enh_layer_cache_misses", 0)
    base_misses = info.get("base_layer_cache_misses", 0)
    soft_hits = info.get("soft_hits", 0.0)

    return reward, (enh_hits + base_hits), (enh_misses + base_misses), soft_hits

# %%
class FeatureAdapter:
    def __init__(self, env: CacheEngineEnv, cfg: Any):
        self.env = env
        self.cfg = cfg

        self.video_hist_short = deque(maxlen=cfg.h_short)
        self.video_hist_long = deque(maxlen=cfg.h_long)
        self.tile_hist_short = deque(maxlen=cfg.h_short)
        self.tile_hist_long = deque(maxlen=cfg.h_long)
        self.tiles_hist_short = deque(maxlen=cfg.h_short)
        self.tiles_hist_long = deque(maxlen=cfg.h_long)

        self.video_freq_short = defaultdict(int)
        self.video_freq_long = defaultdict(int)
        self.tile_freq_short = defaultdict(int)
        self.tile_freq_long = defaultdict(int)
        self.tiles_freq_short = defaultdict(int)
        self.tiles_freq_long = defaultdict(int)

    def reset_history(self):
        queues = (
            self.video_hist_short,
            self.video_hist_long,
            self.tiles_hist_short,
            self.tiles_hist_long,
            self.tile_hist_short,
            self.tile_hist_long,
        )
        freqs = (
            self.video_freq_short,
            self.video_freq_long,
            self.tiles_freq_short,
            self.tiles_freq_long,
            self.tile_freq_short,
            self.tile_freq_long,
        )
        
        for q in queues:
            q.clear()
        for f in freqs:
            f.clear()

    def update_history(self, vid: int, tiles: list[int]):       
        self._update_window(self.video_hist_short, self.video_freq_short, vid)
        self._update_window(self.video_hist_long, self.video_freq_long, vid)

        tiles = tuple(tiles) if tiles is not None else None

        if tiles is None:
            return

        self._update_window(self.tiles_hist_short, self.tiles_freq_short, tiles)
        self._update_window(self.tiles_hist_long, self.tiles_freq_long, tiles)

        for tile in tiles:
            self._update_window(self.tile_hist_short, self.tile_freq_short, (vid, tile))
            self._update_window(self.tile_hist_long, self.tile_freq_long, (vid, tile))

    def _update_window(self, hist_queue: deque, freq_dict: Dict, item):
        if len(hist_queue) == hist_queue.maxlen:
            old_item = hist_queue.popleft()
            freq_dict[old_item] -= 1
            if freq_dict[old_item] == 0:
                del freq_dict[old_item]
        hist_queue.append(item)
        freq_dict[item] += 1

# %%
class NetworkAdapter:
    def __init__(self, env: EnvWrapper, feature_adapter: FeatureAdapter, cfg: Any):
        self.env = env
        self.cfg = cfg
        self.features = feature_adapter

        self.C = self.cfg.cache_size  # paper's cache capacity (videos)
        self.k = self.cfg.viewport    # paper's tiles per video (enhancement)

        print(f"NetworkAdapter initialized with capacity: {self.C} videos, {self.k} tiles per video")

    def build_observation(self, vid: int) -> np.ndarray:

        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        # --- FIX: Create a list of (video_id, slot_index) ---
        alpha = 0.7  # weighting factor for frequency combination
        cached_items = []
        for slot_i, v_id in enumerate(video_cache_index):
            if v_id != -1:
                freq = alpha * self.features.video_freq_long.get(v_id, 0) + (1 - alpha) * self.features.video_freq_short.get(v_id, 0)
                cached_items.append((freq, v_id, slot_i))
            else:
                cached_items.append((-1, -1, slot_i))

        cached_items.sort(key=lambda x: x[0], reverse=True)
        # ----------------------------------------------------

        x_s = np.zeros(self.C, dtype=np.float32)
        x_l = np.zeros(self.C, dtype=np.float32)
        y_s = np.zeros(self.C * self.k, dtype=np.float32)
        y_l = np.zeros(self.C * self.k, dtype=np.float32)

        # Iterate through the SORTED items to build the state
        for i, (freq, v, original_slot) in enumerate(cached_items):
            if v == -1: continue # Skip empty placeholders
            
            # Fill video features
            x_s[i] = np.log1p(self.features.video_freq_short.get(v, 0))
            x_l[i] = np.log1p(self.features.video_freq_long.get(v, 0))

            # Fill tile features using the original slot to look up specific tiles
            tiles = tile_cache_index[original_slot]
            for til_i, t in enumerate(tiles):
                if t == -1: continue
                y_s[i * self.k + til_i] = np.log1p(self.features.tile_freq_short.get((v, t), 0))
                y_l[i * self.k + til_i] = np.log1p(self.features.tile_freq_long.get((v, t), 0))

        # 4. Candidate Features
        cand_s = np.log1p(self.features.video_freq_short.get(vid, 0))
        cand_l = np.log1p(self.features.video_freq_long.get(vid, 0))

        z_s = np.array([cand_s], dtype=np.float32)
        z_l = np.array([cand_l], dtype=np.float32)

        return np.concatenate([x_s, x_l, y_s, y_l, z_s, z_l], axis=0)

    def build_observation_with_tile_pop(self, vid: int, viewport: list[int]) -> np.ndarray:

        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        # --- FIX: Create a list of (video_id, slot_index) ---
        alpha = 0.7  # weighting factor for frequency combination
        cached_items = []
        for slot_i, v_id in enumerate(video_cache_index):
            if v_id != -1:
                freq = alpha * self.features.video_freq_long.get(v_id, 0) + (1 - alpha) * self.features.video_freq_short.get(v_id, 0)
                cached_items.append((freq, v_id, slot_i))
            else:
                cached_items.append((-1, -1, slot_i))

        cached_items.sort(key=lambda x: x[0], reverse=True)
        # ----------------------------------------------------

        x_s = np.zeros(self.C, dtype=np.float32)
        x_l = np.zeros(self.C, dtype=np.float32)
        y_s = np.zeros(self.C * self.k, dtype=np.float32)
        y_l = np.zeros(self.C * self.k, dtype=np.float32)

        # Iterate through the SORTED items to build the state
        for i, (freq, v, original_slot) in enumerate(cached_items):
            if v == -1: continue # Skip empty placeholders

            # Fill video features
            x_s[i] = np.log1p(self.features.video_freq_short.get(v, 0))
            x_l[i] = np.log1p(self.features.video_freq_long.get(v, 0))

            # Fill tile features using the original slot to look up specific tiles
            tiles = tile_cache_index[original_slot]
            for til_i, t in enumerate(tiles):
                if t == -1: continue
                y_s[i * self.k + til_i] = np.log1p(self.features.tile_freq_short.get((v, t), 0))
                y_l[i * self.k + til_i] = np.log1p(self.features.tile_freq_long.get((v, t), 0))

        # 2. NEW: Calculate Request Features WITH Viewport/Enhancement Info
        
        # Base Layer Popularity (Video Freq)
        vid_req_s = np.log1p(self.features.video_freq_short.get(vid, 0))
        vid_req_l = np.log1p(self.features.video_freq_long.get(vid, 0))
        
        # Enhancement Layer Popularity (Sum of frequencies of requested tiles)
        # This tells the agent if the requested VIEWPORT is popular
        enh_req_s = np.sum([self.features.tile_freq_short.get((vid, t), 0) for t in viewport])
        enh_req_l = np.sum([self.features.tile_freq_long.get((vid, t), 0) for t in viewport])
        
        enh_req_s = np.log1p(enh_req_s)
        enh_req_l = np.log1p(enh_req_l)

        # Update z_s/z_l to include Enhancement info
        # Current z shape was likely (1,), now it is (2,)
        z_s = np.array([vid_req_s, enh_req_s], dtype=np.float32) 
        z_l = np.array([vid_req_l, enh_req_l], dtype=np.float32)

        return np.concatenate([x_s, x_l, y_s, y_l, z_s, z_l], axis=0)


    def rank_viewport_tiles(
        self,
        vid: int,
        viewport: list[int],
        features: FeatureAdapter,
        alpha: float = 0.7,
        eps: float = 1e-6,
    ) -> list[int]:

        scores = {}

        for t in viewport:
            short_f = features.tile_freq_short.get((vid, t), 0)
            long_f = features.tile_freq_long.get((vid, t), 0)
        
            score = (alpha * short_f) + ((1.0 - alpha) * long_f) + eps
            scores[t] = score

        ranked = sorted(scores.keys(), key=lambda t: (-scores[t], t))
                
        return ranked
    
    def reset(self):
        
        obs, info = self.env.reset()
        self.features.reset_history()

        video_cache_index = [-1] * self.C
        tile_cache_index = [[-1] * self.k for _ in range(self.C)]

        cached_videos = random.sample(range(self.cfg.n_videos), k=self.C)
        video_cache_index = cached_videos

        # for each cached video, sample distinct tiles
        for i, _vid in enumerate(cached_videos):
            tiles = random.sample(range(self.cfg.n_tiles), k=self.k)
            tile_cache_index[i] = tiles

        self.env.mec_cache.policy.video_idx = video_cache_index
        self.env.mec_cache.policy.tile_idx = tile_cache_index
        
        self.env.mec_cache.cache_bitmap[:, :, :, :] = 0

        gop_id = 0  # default GOP for enhancement tiles
        for i, vid in enumerate(video_cache_index):
            if vid == -1:
                continue
            tiles = tile_cache_index[i][:self.k]
            
            # base layer cached for all GOPs
            self.env.mec_cache.cache_bitmap[vid, 0, :, :] = 1

            # enhancement tiles cached for GOP 0
            self.env.mec_cache.cache_bitmap[vid, 1, tiles, :] = 1
    
        # --- update feature history with cached contents ---
        for i, vid in enumerate(video_cache_index):
            if vid == -1:
                continue
            tiles = tile_cache_index[i]
            self.features.update_history(vid, tiles)
        # --- end feature update ---

        return obs, info
    
    def env_is_done(self) -> bool:
        return self.env.users_env.all_users_done()

# %%
if __name__ == "__main__":
    print("--- Starting DRL Caching System ---")

    # 2. Initialize Environment
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n_gops=cfg.n_gops,
        policy=DrlPolicy(
            capacity=int(cfg.cache_capacity), 
            cfg=cfg
        )
    )

    # Initialize User Environment
    users_env = UserRequestEvents(
        n_nodes=cfg.n_nodes,
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_gops=cfg.n_gops,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n=cfg.n,
        m=cfg.m,
        arrival_rate=cfg.arrival_rate,
        zipf_alpha=cfg.zipf_alpha
    )

    P = cfg.n_nodes; max_U = cfg.n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,  # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),    # 160 Mbps -> 20e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,  # 1 ms
        mec_fixed_delay=0.005, # 5 ms
        cloud_fixed_delay=0.1  # 100 ms
    )

    def prefetch_fn(cache, action):
        return cache.drl_prefetching(action)
    
    def reward_fn(env, reqs):
        return env.avg_psnr_reward(reqs)
    
    env = EnvWrapper(
        n=cfg.n,
        m=cfg.m,
        n_layers=cfg.n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=cfg.theta,
        lam=cfg.lam,
        max_steps=cfg.max_steps,
        prefetch_fn=prefetch_fn,
        reward_fn=reward_fn
    )

    # 3. Initialize Agent
    agent = DQNAgent(cfg)

    feature_adapter = FeatureAdapter(env, cfg)
    net_adapter = NetworkAdapter(env, feature_adapter, cfg)

    for episode in range(cfg.n_episodes):

        obs, info = net_adapter.reset()
        agent.reset_step()

        cache_hits = 0
        cache_misses = 0
        soft_hits = 0.0
        total_reward = 0.0
        avg_psnr = []
        
        for step in count():
            user_transition: Dict[int, datatypes.UserTransition] = {}

            reqs_state = info['users_requests']

            actions = []
            action_taken = False

            for req in reqs_state:
                u = req["u"]
                v = req["video"]
                g = req["gop"]
                tiles = req["tiles"]
                viewport = req["viewport"]
                base_req_init = req["base_req_init"]

                has_base_layer = any(
                    t.get("events", {}).get("alpha_M_u") == 1 for t in tiles
                )
                
                if g == 0 and not has_base_layer:
                    cur_state = net_adapter.build_observation(v)
                    action_idx, _ = agent.select_action(cur_state)

                    should_cache = (action_idx == 1)
                    if should_cache:
                        video_idx_list = env.mec_cache.policy.video_idx
                        freqs = [
                            net_adapter.features.video_freq_long.get(vid, 0) if vid != -1 else -1 for vid in video_idx_list
                        ]

                        victim_slot = np.argmin(freqs) 
                        a_idx = victim_slot + 1 
                    else:
                        a_idx = 0

                    actions.append({
                        'user': u,
                        'video': v,
                        'gop': 0,
                        'tiles': viewport,
                        'base_req_init': should_cache, 
                        'action_idx': a_idx
                    })

                    user_transition[u] = datatypes.UserTransition(
                        state=cur_state,
                        action=action_idx,
                        reward=0.0
                    )
                    action_taken = True
                elif has_base_layer:
                    bitmap = env.mec_cache.get_cache_bitmap()

                    cached_tiles =  np.argwhere(bitmap[v, 1, :, 0] == 1).flatten().tolist()

                    viewport_list = list(viewport)  # ensure Python list
                    ranked_tiles = net_adapter.rank_viewport_tiles(
                        v, viewport_list + cached_tiles, net_adapter.features, alpha=0.5
                    )

                    actions.append({
                        'user': u,
                        'video': v,
                        'gop': 0,
                        'tiles': ranked_tiles[:cfg.viewport],
                        'base_req_init': False
                    })

            # --- STEP ENV ---
            obs, reward, done, info = env.step(actions)

            # --- UPDATE USER HISTORY & VIDEO POPULARITY ---
            for req in reqs_state:
                v = req["video"]
                viewport = req["viewport"]
                net_adapter.features.update_history(v, viewport)
            
            reqs_next_state = info['users_requests']
            next_req_by_user = {r["u"]: r for r in reqs_next_state}
            
            for key, user_trans in user_transition.items():
                u = key
                
                if u not in next_req_by_user:
                    continue  # user not active in next state

                v = next_req_by_user[u]["video"]
                reward = info['reward_per_user'].get(u, 0.0)

                next_state = net_adapter.build_observation(v)

                agent.remember(
                    user_trans.state,
                    user_trans.action,
                    reward,
                    next_state,
                    float(done)
                )

            agent.train_step()

            total_reward_delta, hits_delta, misses_delta, soft_hits_delta = update_metrics(info, reward)
            total_reward += total_reward_delta
            cache_hits += hits_delta
            cache_misses += misses_delta
            soft_hits += soft_hits_delta

            if net_adapter.env_is_done():
                break

            # if req:
            #     print(f"Step {step}, Request State: User {req['u']}, Video {req['video']}, GOP {req['gop']}")
            # else:
            #     print(f"Step {step}, No active user requests.")

            # print(f"Episode {episode}, Step {step}, Active users: {len(reqs_state)} Reward: {reward:.2f}, Total Reward: {total_reward:.2f}, Cache Hits: {cache_hits}, Cache Misses: {cache_misses}, Soft Hits: {soft_hits:.2f}")
            # print("----------------------------------------------------------------")

        agent.update_epsilon()

        save_training_results(
            path_=cfg.path_results,
            filename=cfg.filename,
            ep=episode,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            soft_hits=soft_hits,
            agent=agent
        )

        print(f"--- Episode {episode} completed. Total Reward: {total_reward:.2f}, Cache Hits: {cache_hits}, Cache Misses: {cache_misses}, Total Requests: {len(env.total_gop_requests_per_user)} ---")
        # for key, val in env.total_gop_requests_per_user.items():
        #     print(f"User {key}: Total GOP Requests = {val}")
# Out:
# --- Starting DRL Caching System ---
# NetworkAdapter initialized with capacity: 50 videos, 4 tiles per video
# --- Episode 0 completed. Total Reward: 44025.66, Cache Hits: 132239, Cache Misses: 294465, Total Requests: 500 ---
# --- Episode 1 completed. Total Reward: 49135.83, Cache Hits: 121560, Cache Misses: 279256, Total Requests: 500 ---
# --- Episode 2 completed. Total Reward: 55541.18, Cache Hits: 125382, Cache Misses: 283802, Total Requests: 500 ---
# --- Episode 3 completed. Total Reward: 52889.80, Cache Hits: 138589, Cache Misses: 271811, Total Requests: 500 ---
# --- Episode 4 completed. Total Reward: 53539.08, Cache Hits: 135091, Cache Misses: 289373, Total Requests: 500 ---
# --- Episode 5 completed. Total Reward: 35910.98, Cache Hits: 139380, Cache Misses: 273420, Total Requests: 500 ---
# --- Episode 6 completed. Total Reward: 46723.76, Cache Hits: 135887, Cache Misses: 297169, Total Requests: 500 ---
# --- Episode 7 completed. Total Reward: 39912.22, Cache Hits: 134024, Cache Misses: 293560, Total Requests: 500 ---
# --- Episode 8 completed. Total Reward: 44869.53, Cache Hits: 121865, Cache Misses: 281543, Total Requests: 500 ---
# --- Episode 9 completed. Total Reward: 43012.19, Cache Hits: 132918, Cache Misses: 275578, Total Requests: 500 ---
# --- Episode 10 completed. Total Reward: 43039.44, Cache Hits: 134206, Cache Misses: 287138, Total Requests: 500 ---
# --- Episode 11 completed. Total Reward: 46383.17, Cache Hits: 131665, Cache Misses: 256719, Total Requests: 500 ---
# --- Episode 12 completed. Total Reward: 36692.01, Cache Hits: 124923, Cache Misses: 298181, Total Requests: 500 ---
# --- Episode 13 completed. Total Reward: 50335.68, Cache Hits: 137511, Cache Misses: 281753, Total Requests: 500 ---
# --- Episode 14 completed. Total Reward: 49340.62, Cache Hits: 139057, Cache Misses: 269967, Total Requests: 500 ---
# --- Episode 15 completed. Total Reward: 47316.79, Cache Hits: 130359, Cache Misses: 289337, Total Requests: 500 ---
# --- Episode 16 completed. Total Reward: 51515.26, Cache Hits: 144752, Cache Misses: 281920, Total Requests: 500 ---
# --- Episode 17 completed. Total Reward: 51274.55, Cache Hits: 126385, Cache Misses: 280287, Total Requests: 500 ---
# --- Episode 18 completed. Total Reward: 58829.88, Cache Hits: 137435, Cache Misses: 275013, Total Requests: 500 ---
# --- Episode 19 completed. Total Reward: 46919.22, Cache Hits: 136814, Cache Misses: 281842, Total Requests: 500 ---
# --- Episode 47 completed. Total Reward: 40618.37, Cache Hits: 143248, Cache Misses: 272944, Total Requests: 500 ---
# --- Episode 48 completed. Total Reward: 52447.10, Cache Hits: 146606, Cache Misses: 281426, Total Requests: 500 ---
# --- Episode 49 completed. Total Reward: 61777.99, Cache Hits: 140240, Cache Misses: 267712, Total Requests: 500 ---
# --- Episode 50 completed. Total Reward: 52413.83, Cache Hits: 140922, Cache Misses: 274838, Total Requests: 500 ---
# --- Episode 51 completed. Total Reward: 46179.52, Cache Hits: 142277, Cache Misses: 281499, Total Requests: 500 ---
# --- Episode 52 completed. Total Reward: 57834.43, Cache Hits: 140219, Cache Misses: 281605, Total Requests: 500 ---
# --- Episode 53 completed. Total Reward: 53370.68, Cache Hits: 142582, Cache Misses: 268906, Total Requests: 500 ---
# --- Episode 54 completed. Total Reward: 60181.48, Cache Hits: 146040, Cache Misses: 278184, Total Requests: 500 ---
# --- Episode 55 completed. Total Reward: 54617.32, Cache Hits: 150514, Cache Misses: 276334, Total Requests: 500 ---
# --- Episode 56 completed. Total Reward: 51504.94, Cache Hits: 140313, Cache Misses: 276743, Total Requests: 500 ---
# --- Episode 57 completed. Total Reward: 45184.54, Cache Hits: 142345, Cache Misses: 271191, Total Requests: 500 ---
# --- Episode 58 completed. Total Reward: 46323.74, Cache Hits: 145393, Cache Misses: 290527, Total Requests: 500 ---
# --- Episode 59 completed. Total Reward: 53636.80, Cache Hits: 136719, Cache Misses: 271105, Total Requests: 500 ---
# --- Episode 60 completed. Total Reward: 62782.48, Cache Hits: 143937, Cache Misses: 271791, Total Requests: 500 ---
# --- Episode 61 completed. Total Reward: 54416.44, Cache Hits: 144310, Cache Misses: 282554, Total Requests: 500 ---
# --- Episode 62 completed. Total Reward: 53137.69, Cache Hits: 139418, Cache Misses: 265974, Total Requests: 500 ---
# --- Episode 63 completed. Total Reward: 46191.78, Cache Hits: 146085, Cache Misses: 273371, Total Requests: 500 ---
# --- Episode 64 completed. Total Reward: 43688.16, Cache Hits: 131486, Cache Misses: 279474, Total Requests: 500 ---
# --- Episode 65 completed. Total Reward: 48955.40, Cache Hits: 142215, Cache Misses: 271241, Total Requests: 500 ---
# --- Episode 66 completed. Total Reward: 53818.56, Cache Hits: 153017, Cache Misses: 274519, Total Requests: 500 ---
# --- Episode 67 completed. Total Reward: 64623.30, Cache Hits: 151511, Cache Misses: 282825, Total Requests: 500 ---
# --- Episode 68 completed. Total Reward: 49737.11, Cache Hits: 141274, Cache Misses: 270134, Total Requests: 500 ---
# --- Episode 69 completed. Total Reward: 49908.03, Cache Hits: 146462, Cache Misses: 282530, Total Requests: 500 ---
# --- Episode 70 completed. Total Reward: 64839.18, Cache Hits: 143458, Cache Misses: 267406, Total Requests: 500 ---
# --- Episode 71 completed. Total Reward: 51396.55, Cache Hits: 147002, Cache Misses: 281174, Total Requests: 500 ---
# --- Episode 72 completed. Total Reward: 45897.30, Cache Hits: 147339, Cache Misses: 273941, Total Requests: 500 ---
# --- Episode 73 completed. Total Reward: 59230.09, Cache Hits: 148037, Cache Misses: 264811, Total Requests: 500 ---
# --- Episode 291 completed. Total Reward: 58836.13, Cache Hits: 156322, Cache Misses: 250078, Total Requests: 500 ---
# --- Episode 292 completed. Total Reward: 71294.26, Cache Hits: 170215, Cache Misses: 251177, Total Requests: 500 ---
# --- Episode 293 completed. Total Reward: 66224.05, Cache Hits: 163542, Cache Misses: 261066, Total Requests: 500 ---
# --- Episode 294 completed. Total Reward: 58247.44, Cache Hits: 157887, Cache Misses: 267169, Total Requests: 500 ---
# --- Episode 295 completed. Total Reward: 53195.43, Cache Hits: 155417, Cache Misses: 262039, Total Requests: 500 ---
# --- Episode 296 completed. Total Reward: 51521.49, Cache Hits: 156020, Cache Misses: 287932, Total Requests: 500 ---
# --- Episode 297 completed. Total Reward: 69112.34, Cache Hits: 165089, Cache Misses: 257055, Total Requests: 500 ---
# --- Episode 298 completed. Total Reward: 46695.58, Cache Hits: 155470, Cache Misses: 255890, Total Requests: 500 ---
# --- Episode 299 completed. Total Reward: 58523.62, Cache Hits: 165754, Cache Misses: 253446, Total Requests: 500 ---
# --- Episode 300 completed. Total Reward: 58578.98, Cache Hits: 152860, Cache Misses: 261476, Total Requests: 500 ---
# --- Episode 301 completed. Total Reward: 56022.07, Cache Hits: 156896, Cache Misses: 247536, Total Requests: 500 ---
# --- Episode 302 completed. Total Reward: 73443.84, Cache Hits: 167062, Cache Misses: 247594, Total Requests: 500 ---
# --- Episode 303 completed. Total Reward: 65294.64, Cache Hits: 159367, Cache Misses: 254345, Total Requests: 500 ---
# --- Episode 304 completed. Total Reward: 56562.98, Cache Hits: 154721, Cache Misses: 255631, Total Requests: 500 ---
# --- Episode 305 completed. Total Reward: 57628.49, Cache Hits: 155049, Cache Misses: 253607, Total Requests: 500 ---
# --- Episode 306 completed. Total Reward: 58625.67, Cache Hits: 156536, Cache Misses: 263880, Total Requests: 500 ---
# --- Episode 307 completed. Total Reward: 63946.36, Cache Hits: 157655, Cache Misses: 251145, Total Requests: 500 ---
# --- Episode 308 completed. Total Reward: 71491.27, Cache Hits: 173602, Cache Misses: 255182, Total Requests: 500 ---
# --- Episode 309 completed. Total Reward: 58678.14, Cache Hits: 160847, Cache Misses: 257985, Total Requests: 500 ---
# --- Episode 310 completed. Total Reward: 54850.62, Cache Hits: 156897, Cache Misses: 282575, Total Requests: 500 ---
# --- Episode 311 completed. Total Reward: 55936.61, Cache Hits: 160599, Cache Misses: 263689, Total Requests: 500 ---
# --- Episode 312 completed. Total Reward: 49292.27, Cache Hits: 151548, Cache Misses: 273668, Total Requests: 500 ---
# --- Episode 313 completed. Total Reward: 60396.05, Cache Hits: 166475, Cache Misses: 250293, Total Requests: 500 ---
# --- Episode 314 completed. Total Reward: 65887.13, Cache Hits: 158749, Cache Misses: 258515, Total Requests: 500 ---
# --- Episode 315 completed. Total Reward: 67710.24, Cache Hits: 150392, Cache Misses: 254792, Total Requests: 500 ---
# --- Episode 316 completed. Total Reward: 60018.54, Cache Hits: 148306, Cache Misses: 261630, Total Requests: 500 ---
# --- Episode 317 completed. Total Reward: 71349.26, Cache Hits: 159848, Cache Misses: 258952, Total Requests: 500 ---
# --- Episode 345 completed. Total Reward: 54417.06, Cache Hits: 165886, Cache Misses: 268658, Total Requests: 500 ---
# --- Episode 346 completed. Total Reward: 62209.03, Cache Hits: 151030, Cache Misses: 249754, Total Requests: 500 ---
# --- Episode 347 completed. Total Reward: 52884.89, Cache Hits: 150524, Cache Misses: 264564, Total Requests: 500 ---
# --- Episode 348 completed. Total Reward: 65949.35, Cache Hits: 159698, Cache Misses: 243918, Total Requests: 500 ---
# --- Episode 349 completed. Total Reward: 61397.55, Cache Hits: 168719, Cache Misses: 249745, Total Requests: 500 ---
# --- Episode 350 completed. Total Reward: 75275.27, Cache Hits: 159632, Cache Misses: 238224, Total Requests: 500 ---
# --- Episode 351 completed. Total Reward: 68201.20, Cache Hits: 165970, Cache Misses: 254686, Total Requests: 500 ---
# --- Episode 352 completed. Total Reward: 51283.35, Cache Hits: 162404, Cache Misses: 262572, Total Requests: 500 ---
# --- Episode 353 completed. Total Reward: 57101.23, Cache Hits: 154182, Cache Misses: 252394, Total Requests: 500 ---
# --- Episode 354 completed. Total Reward: 51612.16, Cache Hits: 165266, Cache Misses: 266222, Total Requests: 500 ---
# --- Episode 355 completed. Total Reward: 51911.05, Cache Hits: 157759, Cache Misses: 264897, Total Requests: 500 ---
# --- Episode 356 completed. Total Reward: 66012.55, Cache Hits: 160617, Cache Misses: 248151, Total Requests: 500 ---
# --- Episode 357 completed. Total Reward: 72369.27, Cache Hits: 166682, Cache Misses: 256742, Total Requests: 500 ---
# --- Episode 358 completed. Total Reward: 70125.03, Cache Hits: 166102, Cache Misses: 255930, Total Requests: 500 ---
# --- Episode 359 completed. Total Reward: 52902.23, Cache Hits: 152894, Cache Misses: 258738, Total Requests: 500 ---
# --- Episode 360 completed. Total Reward: 56868.50, Cache Hits: 166626, Cache Misses: 268622, Total Requests: 500 ---
# --- Episode 361 completed. Total Reward: 71545.11, Cache Hits: 172961, Cache Misses: 255375, Total Requests: 500 ---
# --- Episode 362 completed. Total Reward: 66560.30, Cache Hits: 166890, Cache Misses: 252374, Total Requests: 500 ---
# --- Episode 363 completed. Total Reward: 61290.79, Cache Hits: 160434, Cache Misses: 238478, Total Requests: 500 ---
# --- Episode 364 completed. Total Reward: 64149.79, Cache Hits: 164847, Cache Misses: 253073, Total Requests: 500 ---
# --- Episode 365 completed. Total Reward: 51512.79, Cache Hits: 152424, Cache Misses: 251016, Total Requests: 500 ---
# --- Episode 366 completed. Total Reward: 64882.24, Cache Hits: 154109, Cache Misses: 236963, Total Requests: 500 ---
# --- Episode 367 completed. Total Reward: 70986.85, Cache Hits: 166053, Cache Misses: 250907, Total Requests: 500 ---
# --- Episode 368 completed. Total Reward: 65085.96, Cache Hits: 158042, Cache Misses: 251334, Total Requests: 500 ---
# --- Episode 369 completed. Total Reward: 63314.03, Cache Hits: 168050, Cache Misses: 249582, Total Requests: 500 ---
# --- Episode 370 completed. Total Reward: 63714.59, Cache Hits: 153631, Cache Misses: 251169, Total Requests: 500 ---
# --- Episode 371 completed. Total Reward: 64123.06, Cache Hits: 159594, Cache Misses: 266166, Total Requests: 500 ---
# --- Episode 372 completed. Total Reward: 65459.87, Cache Hits: 172195, Cache Misses: 249629, Total Requests: 500 ---
# --- Episode 373 completed. Total Reward: 53672.90, Cache Hits: 174235, Cache Misses: 273509, Total Requests: 500 ---
# --- Episode 374 completed. Total Reward: 66506.08, Cache Hits: 166025, Cache Misses: 254663, Total Requests: 500 ---
# --- Episode 375 completed. Total Reward: 72149.10, Cache Hits: 158577, Cache Misses: 247983, Total Requests: 500 ---
# --- Episode 376 completed. Total Reward: 61748.63, Cache Hits: 156492, Cache Misses: 249460, Total Requests: 500 ---
# --- Episode 377 completed. Total Reward: 55643.82, Cache Hits: 158003, Cache Misses: 257421, Total Requests: 500 ---
# --- Episode 378 completed. Total Reward: 72274.11, Cache Hits: 159733, Cache Misses: 245787, Total Requests: 500 ---
# --- Episode 379 completed. Total Reward: 53586.87, Cache Hits: 151577, Cache Misses: 268583, Total Requests: 500 ---
# --- Episode 380 completed. Total Reward: 59334.13, Cache Hits: 160019, Cache Misses: 255949, Total Requests: 500 ---
# --- Episode 381 completed. Total Reward: 51825.08, Cache Hits: 167009, Cache Misses: 264159, Total Requests: 500 ---
# --- Episode 382 completed. Total Reward: 53179.43, Cache Hits: 153310, Cache Misses: 263410, Total Requests: 500 ---
# --- Episode 383 completed. Total Reward: 74667.04, Cache Hits: 176245, Cache Misses: 240411, Total Requests: 500 ---
# --- Episode 384 completed. Total Reward: 54130.38, Cache Hits: 151719, Cache Misses: 246841, Total Requests: 500 ---
# --- Episode 385 completed. Total Reward: 63249.49, Cache Hits: 156225, Cache Misses: 260031, Total Requests: 500 ---
# --- Episode 386 completed. Total Reward: 56502.24, Cache Hits: 156609, Cache Misses: 265823, Total Requests: 500 ---
# --- Episode 387 completed. Total Reward: 65076.59, Cache Hits: 159938, Cache Misses: 254542, Total Requests: 500 ---
# --- Episode 388 completed. Total Reward: 69221.54, Cache Hits: 164669, Cache Misses: 249299, Total Requests: 500 ---
# --- Episode 389 completed. Total Reward: 51245.36, Cache Hits: 155985, Cache Misses: 260111, Total Requests: 500 ---
# --- Episode 390 completed. Total Reward: 63970.54, Cache Hits: 163980, Cache Misses: 252052, Total Requests: 500 ---
# --- Episode 391 completed. Total Reward: 55606.87, Cache Hits: 160221, Cache Misses: 258307, Total Requests: 500 ---
# --- Episode 392 completed. Total Reward: 72953.75, Cache Hits: 162515, Cache Misses: 241869, Total Requests: 500 ---
# --- Episode 393 completed. Total Reward: 67405.15, Cache Hits: 154203, Cache Misses: 261813, Total Requests: 500 ---
# --- Episode 394 completed. Total Reward: 64025.27, Cache Hits: 153780, Cache Misses: 254572, Total Requests: 500 ---
# --- Episode 395 completed. Total Reward: 65693.85, Cache Hits: 163694, Cache Misses: 258562, Total Requests: 500 ---
# --- Episode 396 completed. Total Reward: 65755.36, Cache Hits: 171566, Cache Misses: 261650, Total Requests: 500 ---
# --- Episode 397 completed. Total Reward: 62433.51, Cache Hits: 162652, Cache Misses: 256868, Total Requests: 500 ---
# --- Episode 398 completed. Total Reward: 64441.08, Cache Hits: 157966, Cache Misses: 253010, Total Requests: 500 ---
# --- Episode 481 completed. Total Reward: 57338.70, Cache Hits: 159174, Cache Misses: 265594, Total Requests: 500 ---
# --- Episode 482 completed. Total Reward: 65367.19, Cache Hits: 164549, Cache Misses: 250491, Total Requests: 500 ---
# --- Episode 483 completed. Total Reward: 71304.32, Cache Hits: 171779, Cache Misses: 250125, Total Requests: 500 ---
# --- Episode 484 completed. Total Reward: 64016.54, Cache Hits: 152685, Cache Misses: 255443, Total Requests: 500 ---
# --- Episode 485 completed. Total Reward: 53664.18, Cache Hits: 157112, Cache Misses: 279736, Total Requests: 500 ---
# --- Episode 486 completed. Total Reward: 88646.16, Cache Hits: 174943, Cache Misses: 235569, Total Requests: 500 ---
# --- Episode 487 completed. Total Reward: 67522.87, Cache Hits: 163996, Cache Misses: 251236, Total Requests: 500 ---
# --- Episode 488 completed. Total Reward: 75327.08, Cache Hits: 168544, Cache Misses: 247456, Total Requests: 500 ---
# --- Episode 489 completed. Total Reward: 72551.08, Cache Hits: 174108, Cache Misses: 254292, Total Requests: 500 ---
# --- Episode 490 completed. Total Reward: 62284.93, Cache Hits: 168964, Cache Misses: 253932, Total Requests: 500 ---
# --- Episode 491 completed. Total Reward: 61690.81, Cache Hits: 158580, Cache Misses: 250636, Total Requests: 500 ---
# --- Episode 492 completed. Total Reward: 64186.60, Cache Hits: 175936, Cache Misses: 271056, Total Requests: 500 ---
# --- Episode 493 completed. Total Reward: 59948.67, Cache Hits: 159065, Cache Misses: 255879, Total Requests: 500 ---
# --- Episode 494 completed. Total Reward: 62837.22, Cache Hits: 162531, Cache Misses: 263053, Total Requests: 500 ---
# --- Episode 495 completed. Total Reward: 57398.94, Cache Hits: 158671, Cache Misses: 258017, Total Requests: 500 ---
# --- Episode 496 completed. Total Reward: 58344.13, Cache Hits: 163201, Cache Misses: 251855, Total Requests: 500 ---
# --- Episode 497 completed. Total Reward: 69099.02, Cache Hits: 171451, Cache Misses: 268917, Total Requests: 500 ---
# --- Episode 498 completed. Total Reward: 69517.91, Cache Hits: 164983, Cache Misses: 256089, Total Requests: 500 ---
# --- Episode 499 completed. Total Reward: 60708.43, Cache Hits: 165442, Cache Misses: 239998, Total Requests: 500 ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------      
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

# Professional color for line plots
PRIMARY_COLOR = "#2b7bba"

# ----------------------------------------------------------------
# 2. Data Loading & Smoothing
# ----------------------------------------------------------------
path = cfg.path_results + "/" + cfg.filename

print(f"Loading data from: {path}")

df = pd.read_csv(path)

total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
df["hit_rate"] = (df["cache_hits"] / total) * 100
df["miss_rate"] = (df["cache_misses"] / total) * 100

# Metrics to plot
metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
window_size = 10  # Adjust smoothing window as needed

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
# Adjusted figsize for a 4-column row (standard for full-width paper figures)
fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

for ax, col in zip(axes, metrics):
    # Plot raw data with transparency (alpha)
    ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, alpha=0.3, linewidth=0.8, label='Raw')
    
    # Plot moving average for clearer trend (except for epsilon which is usually linear)
    if col != "epsilon":
        smoothed = df[col].rolling(window=window_size).mean()
        ax.plot(df["episode"], smoothed, color=PRIMARY_COLOR, linewidth=1.5, label='Trend')
    else:
        # Just a solid line for Epsilon
        ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, linewidth=1.5)

    # Stylistic cleanup
    ax.set_title(col.replace("_", " ").title(), fontweight="bold")
    ax.set_xlabel("Episode")
    
    # Remove redundant Y-labels to save space, or keep for clarity
    ax.set_ylabel("Value") 
    
    series = df[col].dropna()
    if not series.empty:
        ymin = series.min()
        ymax = series.max()
        pad = (ymax - ymin) * 0.05 if ymax != ymin else 1.0
        ax.set_ylim(ymin - pad, ymax + pad)
    ax.grid(axis='y', linestyle='--', alpha=0.3)
    
    # Tufte-style: remove top/right spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# Optional: Add a single legend to the first plot if needed
# axes[0].legend(frameon=False)

plt.show()
fig.savefig("drl_caching_metrics.png", dpi=300)
# Out:
# Loading data from: c:\Users\es25591\Workspace\CacheVideoPredict360\Results/drl_dqn_softup_fixedlr0.001_e500_c50_ar60.0_z0.5.csv

# %%
if __name__ == "__main__":

    plt.rcParams.update({
        "font.family": "serif",
        "font.serif": ["Times New Roman", "DejaVu Serif"],
        "font.size": 10,
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "legend.fontsize": 9,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "axes.linewidth": 0.8,
        "savefig.dpi": 300,
        "figure.constrained_layout.use": True
    })

    COLORS = ["#2b7bba", "#d62728", "#2ca02c"]

    folder = r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\interval_100_3"
    folder = r"/home/eduardo/Workspace/CacheVideoPredict360/Results"
    files = [
        "drl_d3qn_softup_lrdecay0.9999_c50_ar10.0_z0.8.csv",
        "drl_dqn_softup_fixedlr0.001_e500_c50_ar10.0_z1.0.csv",
        # "drl_dqn_softup_lrdecay0.99999_c50_ar10.0_z0.8.csv",
    ]

    paths = [os.path.join(folder, f) for f in files]
    def _short_label(fname: str) -> str:
        stem = os.path.splitext(fname)[0]
        if "lrdecay" in stem:
            val = stem.split("lrdecay", 1)[1].split("_", 1)[0]
            return f"lr decay: {val}"
        if "fixedlr" in stem:
            val = stem.split("fixedlr", 1)[1].split("_", 1)[0]
            return f"fixed lr: {val}"
        return stem

    labels = [_short_label(f) for f in files]

    print(labels)
    metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
    window_size = 10

    fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

    for color, path, label in zip(COLORS, paths, labels):
        df = pd.read_csv(path)
        total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
        df["hit_rate"] = (df["cache_hits"] / total) * 100
        df["miss_rate"] = (df["cache_misses"] / total) * 100

        for ax, col in zip(axes, metrics):
            ax.plot(df["episode"], df[col], color=color, alpha=0.25, linewidth=0.8)

            if col != "epsilon":
                smoothed = df[col].rolling(window=window_size).mean()
                ax.plot(df["episode"], smoothed, color=color, linewidth=1.5, label=label)
            else:
                ax.plot(df["episode"], df[col], color=color, linewidth=1.5, label=label)

    for ax, col in zip(axes, metrics):
        ax.set_title(col.replace("_", " ").title(), fontweight="bold")
        ax.set_xlabel("Episode")
        ax.set_ylabel("Value")
        ax.grid(axis="y", linestyle="--", alpha=0.3)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.set_ylim(bottom=0)

    axes[0].legend(frameon=False, loc="best")
    plt.show()

    fig.savefig("interval_04_comparison.png", dpi=300)
# Out:
# ['lr decay: 0.9999', 'fixed lr: 0.001']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 47
#      44 fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)
#      46 for color, path, label in zip(COLORS, paths, labels):
# ---> 47     df = pd.read_csv(path)
#      48     total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
#      49     df["hit_rate"] = (df["cache_hits"] / total) * 100
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/eduardo/Workspace/CacheVideoPredict360/Results\\drl_d3qn_softup_lrdecay0.9999_c50_ar10.0_z0.8.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------      
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

COLORS = ["#2b7bba", "#d62728"]

# ----------------------------------------------------------------
# 2. Data Preparation with Variance
# ----------------------------------------------------------------
def get_metrics_with_error(path):
    """Returns mean and standard deviation for hit and miss rates."""
    try:
        df = pd.read_csv(path)
        total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
        
        hit_series = (df["cache_hits"] / total * 100)
        miss_series = (df["cache_misses"] / total * 100)
        
        # Calculate Mean and Standard Deviation
        return (hit_series.mean(), hit_series.std()), (miss_series.mean(), miss_series.std())
    except Exception as e:
        print(f"Error processing {path}: {e}")
        return (0, 0), (0, 0)

drl_files = {
    "5": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\drl_pan_opt_c25_ar10.0_z0.5.csv",
    "10": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\drl_pan_opt_c50_ar10.0_z0.5.csv",
}

lsr_files = {
    "5": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\lru_c25_ar10.0_z0.5.csv",
    "10": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\lru_c50_ar10.0_z0.5.csv",
}

caps = list(drl_files.keys())
# Structure: { Metric: { Algo: [means], Algo_err: [stds] } }
stats = {
    "Hit Rate": {"DRL-LSR": [], "DRL-LSR_err": [], "LRU-LSR": [], "LRU-LSR_err": []},
    "Miss Rate": {"DRL-LSR": [], "DRL-LSR_err": [], "LRU-LSR": [], "LRU-LSR_err": []}
}

for c in caps:
    (d_h, d_h_err), (d_m, d_m_err) = get_metrics_with_error(drl_files[c])
    (l_h, l_h_err), (l_m, l_m_err) = get_metrics_with_error(lsr_files[c])
    
    stats["Hit Rate"]["DRL-LSR"].append(d_h)
    stats["Hit Rate"]["DRL-LSR_err"].append(d_h_err)
    stats["Hit Rate"]["LRU-LSR"].append(l_h)
    stats["Hit Rate"]["LRU-LSR_err"].append(l_h_err)
    
    stats["Miss Rate"]["DRL-LSR"].append(d_m)
    stats["Miss Rate"]["DRL-LSR_err"].append(d_m_err)
    stats["Miss Rate"]["LRU-LSR"].append(l_m)
    stats["Miss Rate"]["LRU-LSR_err"].append(l_m_err)

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(7, 3.2), sharey=True)
x = np.arange(len(caps))
width = 0.35 

# Error bar styling
error_kw = dict(lw=1, capsize=3, capthick=1, ecolor='#333333')

metrics = ["Hit Rate", "Miss Rate"]
for i, metric in enumerate(metrics):
    ax = axes[i]
    
    ax.bar(x - width/2, stats[metric]["DRL-LSR"], width, 
           yerr=stats[metric]["DRL-LSR_err"], error_kw=error_kw,
           label="DRL-LSR", color=COLORS[0], edgecolor='black', linewidth=0.6, zorder=3)
    
    ax.bar(x + width/2, stats[metric]["LRU-LSR"], width, 
           yerr=stats[metric]["LRU-LSR_err"], error_kw=error_kw,
           label="LRU-LSR", color=COLORS[1], edgecolor='black', linewidth=0.6, zorder=3)

    ax.set_title(f"Average {metric}", fontweight="bold")
    ax.set_xlabel("Cache Size (%)")
    ax.set_xticks(x)
    ax.set_xticklabels(caps)
    ax.set_ylim(0, 110) # Increased to accommodate error bars
    
    ax.grid(axis='y', linestyle='--', alpha=0.3, zorder=0)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

axes[0].set_ylabel("Percentage (%)")
axes[1].legend(frameon=False, loc="upper right")

plt.tight_layout()
plt.show()

fig.savefig("drl_vs_lru_cache_performance.pdf")
# Out:
# C:\Users\es25591\AppData\Local\Temp\ipykernel_24328\1345644425.py:108: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
