# %%
import os
import math
import csv
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import Any, Dict, Counter, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torch_optimizer as optim_extra

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv, DrlPolicy
    from LabUserRequest import UserRequestEvents
    from LabEnvWrapper import EnvWrapper

import importlib
import config

importlib.reload(config)
# Out:
# <module 'config' from 'c:\\Users\\es25591\\Workspace\\CacheVideoPredict360\\Sources\\Examples\\config.py'>

# %%
cfg = config.Config()

# cfg.filename = f"drl_dqn_softup_lrdecay{cfg.learning_rate_decay}_c{cfg.cache_size}_ar{cfg.arrival_rate}_z{cfg.zipf_alpha}.csv"
cfg.filename = f"drl_dqn_softup_fixedlr{cfg.learning_rate}_c{cfg.cache_size}_ar{cfg.arrival_rate}_z{cfg.zipf_alpha}.csv"

cfg.state_dim = 10 * cfg.cache_size + 2

# %%
# --- DataClass for User Transition ---
@dataclass
class UserTransition:
    state: Any
    action: int
    reward: float

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int):
        super().__init__()
        hidden = 128
        self.fc1 = nn.Linear(state_dim, hidden)
        self.fc2 = nn.Linear(hidden, hidden)
        self.out = nn.Linear(hidden, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.out(x)

class ReplayBuffer:
    def __init__(self, capacity: int = 2000):
        self.memory = deque(maxlen=capacity)
    
    def push(self, s, a, r, ns, d):
        self.memory.append((s, a, r, ns, d))
    
    def sample(self, batch_size: int):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

class DQNAgent:
    def __init__(self, cfg: Any):
        self.step = 0
        
        self.state_dim = cfg.state_dim
        self.action_dim = cfg.action_dim
        
        self.epsilon = cfg.epsilon_start
        self.epsilon_min = cfg.epsilon_min
        self.epsilon_decay = cfg.epsilon_decay
        self.gamma = cfg.gamma
        self.tau = cfg.tau
        self.batch_size = cfg.batch_size
        
        self.buffer = ReplayBuffer(cfg.buffer_capacity)
        
        self.policy_net = QNetwork(self.state_dim, self.action_dim).to(device)
        self.target_net = QNetwork(self.state_dim, self.action_dim).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=cfg.learning_rate)
        # self.optimizer = optim_extra.Ranger(
        #     self.policy_net.parameters(), 
        #     lr=cfg.learning_rate,
        #     alpha=0.5,  # Lookahead step size (default is usually 0.5)
        #     k=6         # Lookahead step frequency
        # )
        
        self.scheduler = torch.optim.lr_scheduler.ExponentialLR(
            self.optimizer, 
            gamma=cfg.learning_rate_decay
        )
        
        self.loss_fn = nn.MSELoss()
        self.nb_interval = cfg.nb_interval  # train every 5 requests

    def select_action(self, state):
        if random.random() < self.epsilon:
            action_idx = random.randint(0, self.action_dim - 1)
            return action_idx, None
        
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.policy_net(state)
        
        action_idx = q_values.argmax().item()
        return action_idx, q_values
        
    def remember(self, s, a, r, ns, done):
        self.buffer.push(s, a, r, ns, done)

    def train_step(self):
        self.step += 1
        if self.step % self.nb_interval == 0 and \
           len(self.buffer) >= self.batch_size:
            self.learn()

    def learn(self):
        batch = self.buffer.sample(self.batch_size)
        s, a, r, ns, d = zip(*batch)
        s = torch.tensor(np.stack(s), dtype=torch.float32).to(device)
        ns = torch.tensor(np.stack(ns), dtype=torch.float32).to(device)
        a = torch.tensor(a, dtype=torch.int64).to(device)
        r = torch.tensor(r, dtype=torch.float32).to(device)
        d = torch.tensor(d, dtype=torch.float32).to(device)

        with torch.no_grad():
            q_next = self.target_net(ns).max(1)[0]
            q_target = r + self.gamma * q_next * (1.0 - d)

        q_expected = self.policy_net(s).gather(1, a.unsqueeze(1)).squeeze(1)

        loss = self.loss_fn(q_expected, q_target)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        # self.scheduler.step()
        
        self.soft_update_target()

    def soft_update_target(self):
        for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
            target_param.data.copy_( 
                target_param.data * (1.0 - self.tau) + policy_param.data * self.tau
            )

    def update_target(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        
    def reset_step(self):
        self.step = 0

# %%
def save_training_results(
    path_,
    filename,
    ep, 
    total_reward, 
    cache_hits, 
    cache_misses, 
    soft_hits,
    agent
):
    with open(os.path.join(path_, filename), 'a', newline='') as f:
        fieldnames = [
            'episode', 
            'total_reward', 
            'cache_hits', 
            'cache_misses', 
            'soft_hits',
            'epsilon',
            'lr'
        ]
        writer_results = csv.DictWriter(f, fieldnames=fieldnames)

        if ep == 0:
            writer_results.writeheader()
        
        writer_results.writerow({
            'episode': ep,
            'total_reward': round(float(total_reward), 2),
            'cache_hits': cache_hits,
            'cache_misses': cache_misses,
            'soft_hits': soft_hits,
            'lr': f"{agent.scheduler.get_last_lr()[0]:.10f}" if agent else None,
            'epsilon': round(float(agent.epsilon), 4) if agent else None
        })

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, float]:
    enh_hits = info.get("enh_layer_cache_hits", 0)
    base_hits = info.get("base_layer_cache_hits", 0)
    enh_misses = info.get("enh_layer_cache_misses", 0)
    base_misses = info.get("base_layer_cache_misses", 0)
    soft_hits = info.get("soft_hits", 0.0)

    return reward, (enh_hits + base_hits), (enh_misses + base_misses), soft_hits

# %%
class FeatureAdapter:
    def __init__(self, env: CacheEngineEnv, cfg: Any):
        self.env = env
        self.cfg = cfg

        self.video_hist_short = deque(maxlen=cfg.h_short)
        self.video_hist_long = deque(maxlen=cfg.h_long)
        self.tile_hist_short = deque(maxlen=cfg.h_short)
        self.tile_hist_long = deque(maxlen=cfg.h_long)
        self.tiles_hist_short = deque(maxlen=cfg.h_short)
        self.tiles_hist_long = deque(maxlen=cfg.h_long)

        self.video_freq_short = defaultdict(int)
        self.video_freq_long = defaultdict(int)
        self.tile_freq_short = defaultdict(int)
        self.tile_freq_long = defaultdict(int)
        self.tiles_freq_short = defaultdict(int)
        self.tiles_freq_long = defaultdict(int)

    def reset_history(self):
        queues = (
            self.video_hist_short,
            self.video_hist_long,
            self.tiles_hist_short,
            self.tiles_hist_long,
            self.tile_hist_short,
            self.tile_hist_long,
        )
        freqs = (
            self.video_freq_short,
            self.video_freq_long,
            self.tiles_freq_short,
            self.tiles_freq_long,
            self.tile_freq_short,
            self.tile_freq_long,
        )
        
        for q in queues:
            q.clear()
        for f in freqs:
            f.clear()

    def update_history(self, vid: int, tiles: list[int]):       
        self._update_window(self.video_hist_short, self.video_freq_short, vid)
        self._update_window(self.video_hist_long, self.video_freq_long, vid)

        tiles = tuple(tiles) if tiles is not None else None

        if tiles is None:
            return

        self._update_window(self.tiles_hist_short, self.tiles_freq_short, tiles)
        self._update_window(self.tiles_hist_long, self.tiles_freq_long, tiles)

        for tile in tiles:
            self._update_window(self.tile_hist_short, self.tile_freq_short, (vid, tile))
            self._update_window(self.tile_hist_long, self.tile_freq_long, (vid, tile))

    def _update_window(self, hist_queue: deque, freq_dict: Dict, item):
        if len(hist_queue) == hist_queue.maxlen:
            old_item = hist_queue.popleft()
            freq_dict[old_item] -= 1
            if freq_dict[old_item] == 0:
                del freq_dict[old_item]
        hist_queue.append(item)
        freq_dict[item] += 1

# %%
class NetworkAdapter:
    def __init__(self, env: EnvWrapper, feature_adapter: FeatureAdapter, cfg: Any):
        self.env = env
        self.cfg = cfg
        self.features = feature_adapter

        self.C = self.cfg.cache_size  # paper's cache capacity (videos)
        self.k = self.cfg.viewport    # paper's tiles per video (enhancement)

        print(f"NetworkAdapter initialized with capacity: {self.C} videos, {self.k} tiles per video")

    def build_observation(self, vid: int) -> np.ndarray:

        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        # --- FIX: Create a list of (video_id, slot_index) ---
        alpha = 0.7  # weighting factor for frequency combination
        cached_items = []
        for slot_i, v_id in enumerate(video_cache_index):
            if v_id != -1:
                freq = alpha * self.features.video_freq_long.get(v_id, 0) + (1 - alpha) * self.features.video_freq_short.get(v_id, 0)
                cached_items.append((freq, v_id, slot_i))
            else:
                cached_items.append((-1, -1, slot_i))

        cached_items.sort(key=lambda x: x[0], reverse=True)
        # ----------------------------------------------------

        x_s = np.zeros(self.C, dtype=np.float32)
        x_l = np.zeros(self.C, dtype=np.float32)
        y_s = np.zeros(self.C * self.k, dtype=np.float32)
        y_l = np.zeros(self.C * self.k, dtype=np.float32)

        # Iterate through the SORTED items to build the state
        for i, (freq, v, original_slot) in enumerate(cached_items):
            if v == -1: continue # Skip empty placeholders
            
            # Fill video features
            x_s[i] = np.log1p(self.features.video_freq_short.get(v, 0))
            x_l[i] = np.log1p(self.features.video_freq_long.get(v, 0))

            # Fill tile features using the original slot to look up specific tiles
            tiles = tile_cache_index[original_slot]
            for til_i, t in enumerate(tiles):
                if t == -1: continue
                y_s[i * self.k + til_i] = np.log1p(self.features.tile_freq_short.get((v, t), 0))
                y_l[i * self.k + til_i] = np.log1p(self.features.tile_freq_long.get((v, t), 0))

        # 4. Candidate Features
        cand_s = np.log1p(self.features.video_freq_short.get(vid, 0))
        cand_l = np.log1p(self.features.video_freq_long.get(vid, 0))

        z_s = np.array([cand_s], dtype=np.float32)
        z_l = np.array([cand_l], dtype=np.float32)

        return np.concatenate([x_s, x_l, y_s, y_l, z_s, z_l], axis=0)


    def build_observation_with_tile_pop(self, vid: int, viewport: list[int]) -> np.ndarray:

        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        # --- FIX: Create a list of (video_id, slot_index) ---
        alpha = 0.7  # weighting factor for frequency combination
        cached_items = []
        for slot_i, v_id in enumerate(video_cache_index):
            if v_id != -1:
                freq = alpha * self.features.video_freq_long.get(v_id, 0) + (1 - alpha) * self.features.video_freq_short.get(v_id, 0)
                cached_items.append((freq, v_id, slot_i))
            else:
                cached_items.append((-1, -1, slot_i))

        cached_items.sort(key=lambda x: x[0], reverse=True)
        # ----------------------------------------------------

        x_s = np.zeros(self.C, dtype=np.float32)
        x_l = np.zeros(self.C, dtype=np.float32)
        y_s = np.zeros(self.C * self.k, dtype=np.float32)
        y_l = np.zeros(self.C * self.k, dtype=np.float32)

        # Iterate through the SORTED items to build the state
        for i, (freq, v, original_slot) in enumerate(cached_items):
            if v == -1: continue # Skip empty placeholders

            # Fill video features
            x_s[i] = np.log1p(self.features.video_freq_short.get(v, 0))
            x_l[i] = np.log1p(self.features.video_freq_long.get(v, 0))

            # Fill tile features using the original slot to look up specific tiles
            tiles = tile_cache_index[original_slot]
            for til_i, t in enumerate(tiles):
                if t == -1: continue
                y_s[i * self.k + til_i] = np.log1p(self.features.tile_freq_short.get((v, t), 0))
                y_l[i * self.k + til_i] = np.log1p(self.features.tile_freq_long.get((v, t), 0))

        # 2. NEW: Calculate Request Features WITH Viewport/Enhancement Info
        
        # Base Layer Popularity (Video Freq)
        vid_req_s = np.log1p(self.features.video_freq_short.get(vid, 0))
        vid_req_l = np.log1p(self.features.video_freq_long.get(vid, 0))
        
        # Enhancement Layer Popularity (Sum of frequencies of requested tiles)
        # This tells the agent if the requested VIEWPORT is popular
        enh_req_s = np.sum([self.features.tile_freq_short.get((vid, t), 0) for t in viewport])
        enh_req_l = np.sum([self.features.tile_freq_long.get((vid, t), 0) for t in viewport])
        
        enh_req_s = np.log1p(enh_req_s)
        enh_req_l = np.log1p(enh_req_l)

        # Update z_s/z_l to include Enhancement info
        # Current z shape was likely (1,), now it is (2,)
        z_s = np.array([vid_req_s, enh_req_s], dtype=np.float32) 
        z_l = np.array([vid_req_l, enh_req_l], dtype=np.float32)

        return np.concatenate([x_s, x_l, y_s, y_l, z_s, z_l], axis=0)


    def rank_viewport_tiles(
        self,
        vid: int,
        viewport: list[int],
        features: FeatureAdapter,
        alpha: float = 0.7,
        eps: float = 1e-6,
    ) -> list[int]:

        scores = {}

        for t in viewport:
            short_f = features.tile_freq_short.get((vid, t), 0)
            long_f = features.tile_freq_long.get((vid, t), 0)
        
            score = (alpha * short_f) + ((1.0 - alpha) * long_f) + eps
            scores[t] = score

        ranked = sorted(scores.keys(), key=lambda t: (-scores[t], t))
                
        return ranked
    
    def reset(self):
        
        obs, info = self.env.reset()
        self.features.reset_history()

        video_cache_index = [-1] * self.C
        tile_cache_index = [[-1] * self.k for _ in range(self.C)]

        cached_videos = random.sample(range(self.cfg.n_videos), k=self.C)
        video_cache_index = cached_videos

        # for each cached video, sample distinct tiles
        for i, _vid in enumerate(cached_videos):
            tiles = random.sample(range(self.cfg.n_tiles), k=self.k)
            tile_cache_index[i] = tiles

        self.env.mec_cache.policy.video_idx = video_cache_index
        self.env.mec_cache.policy.tile_idx = tile_cache_index
        
        self.env.mec_cache.cache_bitmap[:, :, :, :] = 0

        gop_id = 0  # default GOP for enhancement tiles
        for i, vid in enumerate(video_cache_index):
            if vid == -1:
                continue
            tiles = tile_cache_index[i][:self.k]
            
            # base layer cached for all GOPs
            self.env.mec_cache.cache_bitmap[vid, 0, :, :] = 1

            # enhancement tiles cached for GOP 0
            self.env.mec_cache.cache_bitmap[vid, 1, tiles, :] = 1
    
        # --- update feature history with cached contents ---
        for i, vid in enumerate(video_cache_index):
            if vid == -1:
                continue
            tiles = tile_cache_index[i]
            self.features.update_history(vid, tiles)
        # --- end feature update ---

        return obs, info
    
    def env_is_done(self) -> bool:
        return self.env.users_env.all_users_done()

# %%
if __name__ == "__main__":
    print("--- Starting DRL Caching System ---")

    # 2. Initialize Environment
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n_gops=cfg.n_gops,
        policy=DrlPolicy(
            capacity=int(cfg.cache_capacity), 
            cfg=cfg
        )
    )

    # Initialize User Environment
    users_env = UserRequestEvents(
        n_nodes=cfg.n_nodes,
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_gops=cfg.n_gops,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n=cfg.n,
        m=cfg.m,
        arrival_rate=cfg.arrival_rate,
        zipf_alpha=cfg.zipf_alpha
    )

    P = cfg.n_nodes; max_U = cfg.n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,  # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),    # 160 Mbps -> 20e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,  # 1 ms
        mec_fixed_delay=0.005, # 5 ms
        cloud_fixed_delay=0.1  # 100 ms
    )

    def prefetch(cache, action):
        return cache.drl_prefetching(action)
    
    env = EnvWrapper(
        n=cfg.n,
        m=cfg.m,
        n_layers=cfg.n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=cfg.theta,
        lam=cfg.lam,
        prefetch_fn=prefetch,
        max_steps=cfg.max_steps
    )

    # 3. Initialize Agent
    agent = DQNAgent(cfg)

    feature_adapter = FeatureAdapter(env, cfg)
    net_adapter = NetworkAdapter(env, feature_adapter, cfg)

    for episode in range(cfg.n_episodes):

        obs, info = net_adapter.reset()
        agent.reset_step()

        cache_hits = 0
        cache_misses = 0
        soft_hits = 0.0
        total_reward = 0.0
        avg_psnr = []
        
        for step in count():
            user_transition: Dict[int, UserTransition] = {}

            reqs_state = info['users_requests']
            
            actions = []
            action_taken = False
            cur_states = {}
            cur_actions = {}
            
            for req in reqs_state:
                u = req["u"]
                v = req["video"]
                g = req["gop"]
                tiles = req["tiles"]
                viewport = req["viewport"]
                base_req_init = req["base_req_init"]

                has_base_layer = any(
                    t.get("events", {}).get("alpha_M_u") == 1 for t in tiles
                )
                if not has_base_layer:
                    cur_state = net_adapter.build_observation(v)
                    action_idx, _ = agent.select_action(cur_state)

                    should_cache = (action_idx == 1)
                    if should_cache:
                        video_idx_list = env.mec_cache.policy.video_idx
                        freqs = [
                            net_adapter.features.video_freq_long.get(vid, 0) if vid != -1 else -1 for vid in video_idx_list
                        ]

                        victim_slot = np.argmin(freqs) 
                        a_idx = victim_slot + 1 
                    else:
                        a_idx = 0

                    actions.append({
                        'video': v,
                        'gop': 0,
                        'tiles': viewport,
                        'base_req_init': should_cache, 
                        'action_idx': a_idx
                    })

                    user_transition[u] = UserTransition(
                        state=cur_state,
                        action=action_idx,
                        reward=0.0
                    )
                    action_taken = True
                elif has_base_layer:
                    bitmap = env.mec_cache.get_cache_bitmap()

                    cached_tiles =  np.argwhere(bitmap[v, 1, :, 0] == 1).flatten().tolist()

                    viewport_list = list(viewport)  # ensure Python list
                    ranked_tiles = net_adapter.rank_viewport_tiles(
                        v, viewport_list + cached_tiles, net_adapter.features, alpha=0.5
                    )

                    actions.append({
                        'video': v,
                        'gop': 0,
                        'tiles': ranked_tiles[:cfg.viewport],
                        'base_req_init': False
                    })

            # --- STEP ENV ---
            obs, reward, done, info = env.step(actions)

            # --- UPDATE USER HISTORY & VIDEO POPULARITY ---
            for req in reqs_state:
                v = req["video"]
                viewport = req["viewport"]
                net_adapter.features.update_history(v, viewport)
            
            reqs_next_state = info['users_requests']
            next_req_by_user = {r["u"]: r for r in reqs_next_state}
            
            for key, user_trans in user_transition.items():
                u = key
                
                if u not in next_req_by_user:
                    continue  # user not active in next state

                v = next_req_by_user[u]["video"]
                reward = info['reward_per_user'].get(u, 0.0)

                next_state = net_adapter.build_observation(v)

                agent.remember(
                    user_trans.state,
                    user_trans.action,
                    reward,
                    next_state,
                    float(done)
                )

            agent.train_step()

            total_reward_delta, hits_delta, misses_delta, soft_hits_delta = update_metrics(info, reward)
            total_reward += total_reward_delta
            cache_hits += hits_delta
            cache_misses += misses_delta
            soft_hits += soft_hits_delta

            if net_adapter.env_is_done():
                break

            # if req:
            #     print(f"Step {step}, Request State: User {req['u']}, Video {req['video']}, GOP {req['gop']}")
            # else:
            #     print(f"Step {step}, No active user requests.")

            print(f"Episode {episode}, Step {step}, Active users: {len(reqs_state)} Reward: {reward:.2f}, Total Reward: {total_reward:.2f}, Cache Hits: {cache_hits}, Cache Misses: {cache_misses}, Soft Hits: {soft_hits:.2f}")
            print("----------------------------------------------------------------")

        agent.update_epsilon()

        save_training_results(
            path_=cfg.path_results,
            filename=cfg.filename,
            ep=episode,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            soft_hits=soft_hits,
            agent=agent
        )

        print(f"--- Episode {episode} completed. Total Reward: {total_reward:.2f}, Cache Hits: {cache_hits}, Cache Misses: {cache_misses}, Soft Hits: {soft_hits:.2f} ---")
        for key, val in env.total_gop_requests_per_user.items():
            print(f"User {key}: Total GOP Requests = {val}")
# Out:
# --- Starting DRL Caching System ---
# NetworkAdapter initialized with capacity: 25 videos, 4 tiles per video
# Episode 0, Step 0, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 1, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 2, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 3, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 4, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 5, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 6, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 7, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 8, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 16, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 9, Active users: 1 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 32, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 10, Active users: 1 Reward: 10.00, Total Reward: 10.00, Cache Hits: 12, Cache Misses: 52, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 11, Active users: 2 Reward: 0.00, Total Reward: 10.00, Cache Hits: 24, Cache Misses: 72, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 12, Active users: 2 Reward: 0.00, Total Reward: 10.00, Cache Hits: 36, Cache Misses: 92, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 13, Active users: 2 Reward: 0.00, Total Reward: 10.00, Cache Hits: 48, Cache Misses: 112, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 14, Active users: 2 Reward: 6.00, Total Reward: 16.00, Cache Hits: 72, Cache Misses: 120, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 15, Active users: 2 Reward: 30.00, Total Reward: 46.00, Cache Hits: 96, Cache Misses: 128, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 16, Active users: 2 Reward: 30.00, Total Reward: 76.00, Cache Hits: 120, Cache Misses: 136, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 17, Active users: 2 Reward: 30.00, Total Reward: 106.00, Cache Hits: 144, Cache Misses: 144, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 18, Active users: 2 Reward: 30.00, Total Reward: 136.00, Cache Hits: 168, Cache Misses: 152, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 19, Active users: 2 Reward: 30.00, Total Reward: 166.00, Cache Hits: 192, Cache Misses: 160, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 20, Active users: 2 Reward: 30.00, Total Reward: 196.00, Cache Hits: 216, Cache Misses: 168, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 21, Active users: 2 Reward: 30.00, Total Reward: 226.00, Cache Hits: 240, Cache Misses: 176, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 22, Active users: 2 Reward: 30.00, Total Reward: 256.00, Cache Hits: 264, Cache Misses: 184, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 23, Active users: 2 Reward: 30.00, Total Reward: 286.00, Cache Hits: 288, Cache Misses: 192, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 24, Active users: 2 Reward: 30.00, Total Reward: 316.00, Cache Hits: 312, Cache Misses: 200, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 25, Active users: 2 Reward: 30.00, Total Reward: 346.00, Cache Hits: 336, Cache Misses: 208, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 26, Active users: 2 Reward: 30.00, Total Reward: 376.00, Cache Hits: 360, Cache Misses: 216, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 27, Active users: 2 Reward: 30.00, Total Reward: 406.00, Cache Hits: 384, Cache Misses: 224, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 28, Active users: 2 Reward: 30.00, Total Reward: 436.00, Cache Hits: 408, Cache Misses: 232, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 29, Active users: 2 Reward: 30.00, Total Reward: 466.00, Cache Hits: 432, Cache Misses: 240, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 30, Active users: 2 Reward: 30.00, Total Reward: 496.00, Cache Hits: 456, Cache Misses: 248, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 31, Active users: 2 Reward: 30.00, Total Reward: 526.00, Cache Hits: 480, Cache Misses: 256, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 32, Active users: 2 Reward: 30.00, Total Reward: 556.00, Cache Hits: 504, Cache Misses: 264, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 33, Active users: 2 Reward: 30.00, Total Reward: 586.00, Cache Hits: 528, Cache Misses: 272, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 34, Active users: 2 Reward: 30.00, Total Reward: 616.00, Cache Hits: 552, Cache Misses: 280, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 35, Active users: 2 Reward: 30.00, Total Reward: 646.00, Cache Hits: 576, Cache Misses: 288, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 36, Active users: 2 Reward: 30.00, Total Reward: 676.00, Cache Hits: 600, Cache Misses: 296, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 37, Active users: 2 Reward: 30.00, Total Reward: 706.00, Cache Hits: 624, Cache Misses: 304, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 0, Step 38, Active users: 2 Reward: 30.00, Total Reward: 736.00, Cache Hits: 636, Cache Misses: 308, Soft Hits: 0.00
# ----------------------------------------------------------------
# --- Episode 0 completed. Total Reward: 766.00, Cache Hits: 648, Cache Misses: 312, Soft Hits: 0.00 ---
# User 0: Total GOP Requests = 30
# User 1: Total GOP Requests = 30
# Episode 1, Step 0, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 16, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 1, Active users: 1 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 48, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 2, Active users: 2 Reward: 15.00, Total Reward: 15.00, Cache Hits: 12, Cache Misses: 68, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 3, Active users: 2 Reward: 0.00, Total Reward: 15.00, Cache Hits: 24, Cache Misses: 88, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 4, Active users: 2 Reward: 6.00, Total Reward: 21.00, Cache Hits: 48, Cache Misses: 96, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 5, Active users: 2 Reward: 30.00, Total Reward: 51.00, Cache Hits: 72, Cache Misses: 104, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 6, Active users: 2 Reward: 30.00, Total Reward: 81.00, Cache Hits: 96, Cache Misses: 112, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 7, Active users: 2 Reward: 30.00, Total Reward: 111.00, Cache Hits: 120, Cache Misses: 120, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 8, Active users: 2 Reward: 30.00, Total Reward: 141.00, Cache Hits: 144, Cache Misses: 128, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 9, Active users: 2 Reward: 30.00, Total Reward: 171.00, Cache Hits: 168, Cache Misses: 136, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 10, Active users: 2 Reward: 30.00, Total Reward: 201.00, Cache Hits: 192, Cache Misses: 144, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 11, Active users: 2 Reward: 30.00, Total Reward: 231.00, Cache Hits: 216, Cache Misses: 152, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 12, Active users: 2 Reward: 30.00, Total Reward: 261.00, Cache Hits: 228, Cache Misses: 156, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 13, Active users: 1 Reward: 15.00, Total Reward: 276.00, Cache Hits: 240, Cache Misses: 176, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 14, Active users: 2 Reward: 23.08, Total Reward: 299.08, Cache Hits: 252, Cache Misses: 196, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 15, Active users: 2 Reward: 21.43, Total Reward: 320.51, Cache Hits: 264, Cache Misses: 216, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 16, Active users: 2 Reward: 30.00, Total Reward: 350.51, Cache Hits: 276, Cache Misses: 220, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 17, Active users: 1 Reward: 15.00, Total Reward: 365.51, Cache Hits: 288, Cache Misses: 240, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 18, Active users: 2 Reward: 20.62, Total Reward: 386.13, Cache Hits: 312, Cache Misses: 248, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 19, Active users: 2 Reward: 30.00, Total Reward: 416.13, Cache Hits: 336, Cache Misses: 256, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 20, Active users: 2 Reward: 30.00, Total Reward: 446.13, Cache Hits: 360, Cache Misses: 264, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 21, Active users: 2 Reward: 30.00, Total Reward: 476.13, Cache Hits: 384, Cache Misses: 272, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 22, Active users: 2 Reward: 30.00, Total Reward: 506.13, Cache Hits: 408, Cache Misses: 280, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 23, Active users: 2 Reward: 30.00, Total Reward: 536.13, Cache Hits: 432, Cache Misses: 288, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 24, Active users: 2 Reward: 30.00, Total Reward: 566.13, Cache Hits: 444, Cache Misses: 292, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 25, Active users: 1 Reward: 15.00, Total Reward: 581.13, Cache Hits: 456, Cache Misses: 312, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 26, Active users: 2 Reward: 20.87, Total Reward: 602.00, Cache Hits: 468, Cache Misses: 332, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 27, Active users: 2 Reward: 21.25, Total Reward: 623.25, Cache Hits: 492, Cache Misses: 340, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 28, Active users: 2 Reward: 30.00, Total Reward: 653.25, Cache Hits: 516, Cache Misses: 348, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 29, Active users: 2 Reward: 30.00, Total Reward: 683.25, Cache Hits: 540, Cache Misses: 356, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 30, Active users: 2 Reward: 30.00, Total Reward: 713.25, Cache Hits: 552, Cache Misses: 360, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 31, Active users: 1 Reward: 30.00, Total Reward: 743.25, Cache Hits: 564, Cache Misses: 364, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 32, Active users: 1 Reward: 30.00, Total Reward: 773.25, Cache Hits: 576, Cache Misses: 368, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 33, Active users: 1 Reward: 30.00, Total Reward: 803.25, Cache Hits: 588, Cache Misses: 372, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 34, Active users: 1 Reward: 30.00, Total Reward: 833.25, Cache Hits: 600, Cache Misses: 376, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 35, Active users: 1 Reward: 30.00, Total Reward: 863.25, Cache Hits: 612, Cache Misses: 380, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 36, Active users: 1 Reward: 30.00, Total Reward: 893.25, Cache Hits: 624, Cache Misses: 384, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 37, Active users: 1 Reward: 30.00, Total Reward: 923.25, Cache Hits: 636, Cache Misses: 388, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 38, Active users: 1 Reward: 30.00, Total Reward: 953.25, Cache Hits: 648, Cache Misses: 392, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 39, Active users: 1 Reward: 30.00, Total Reward: 983.25, Cache Hits: 660, Cache Misses: 396, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 40, Active users: 1 Reward: 30.00, Total Reward: 1013.25, Cache Hits: 672, Cache Misses: 400, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 41, Active users: 1 Reward: 30.00, Total Reward: 1043.25, Cache Hits: 684, Cache Misses: 404, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 42, Active users: 1 Reward: 30.00, Total Reward: 1073.25, Cache Hits: 696, Cache Misses: 408, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 43, Active users: 1 Reward: 30.00, Total Reward: 1103.25, Cache Hits: 708, Cache Misses: 412, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 44, Active users: 1 Reward: 30.00, Total Reward: 1133.25, Cache Hits: 720, Cache Misses: 416, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 45, Active users: 1 Reward: 30.00, Total Reward: 1163.25, Cache Hits: 732, Cache Misses: 420, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 46, Active users: 1 Reward: 30.00, Total Reward: 1193.25, Cache Hits: 744, Cache Misses: 424, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 47, Active users: 1 Reward: 30.00, Total Reward: 1223.25, Cache Hits: 756, Cache Misses: 428, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 48, Active users: 1 Reward: 30.00, Total Reward: 1253.25, Cache Hits: 768, Cache Misses: 432, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 49, Active users: 1 Reward: 30.00, Total Reward: 1283.25, Cache Hits: 780, Cache Misses: 436, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 50, Active users: 1 Reward: 30.00, Total Reward: 1313.25, Cache Hits: 792, Cache Misses: 440, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 51, Active users: 1 Reward: 30.00, Total Reward: 1343.25, Cache Hits: 804, Cache Misses: 444, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 52, Active users: 1 Reward: 30.00, Total Reward: 1373.25, Cache Hits: 816, Cache Misses: 448, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 1, Step 53, Active users: 1 Reward: 30.00, Total Reward: 1403.25, Cache Hits: 828, Cache Misses: 452, Soft Hits: 0.00
# ----------------------------------------------------------------
# --- Episode 1 completed. Total Reward: 1433.25, Cache Hits: 840, Cache Misses: 456, Soft Hits: 0.00 ---
# User 0: Total GOP Requests = 30
# User 1: Total GOP Requests = 51
# Episode 2, Step 0, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 1, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 2, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 3, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 4, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 5, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 32, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 6, Active users: 2 Reward: 15.00, Total Reward: 15.00, Cache Hits: 12, Cache Misses: 52, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 7, Active users: 2 Reward: 10.00, Total Reward: 25.00, Cache Hits: 24, Cache Misses: 72, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 8, Active users: 2 Reward: 7.50, Total Reward: 32.50, Cache Hits: 36, Cache Misses: 92, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 9, Active users: 2 Reward: 12.00, Total Reward: 44.50, Cache Hits: 60, Cache Misses: 100, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 10, Active users: 2 Reward: 30.00, Total Reward: 74.50, Cache Hits: 84, Cache Misses: 108, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 11, Active users: 2 Reward: 30.00, Total Reward: 104.50, Cache Hits: 108, Cache Misses: 116, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 12, Active users: 2 Reward: 30.00, Total Reward: 134.50, Cache Hits: 132, Cache Misses: 124, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 13, Active users: 2 Reward: 30.00, Total Reward: 164.50, Cache Hits: 156, Cache Misses: 132, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 14, Active users: 2 Reward: 30.00, Total Reward: 194.50, Cache Hits: 180, Cache Misses: 140, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 15, Active users: 2 Reward: 30.00, Total Reward: 224.50, Cache Hits: 204, Cache Misses: 148, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 16, Active users: 2 Reward: 30.00, Total Reward: 254.50, Cache Hits: 228, Cache Misses: 156, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 17, Active users: 2 Reward: 30.00, Total Reward: 284.50, Cache Hits: 252, Cache Misses: 164, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 18, Active users: 2 Reward: 30.00, Total Reward: 314.50, Cache Hits: 276, Cache Misses: 172, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 19, Active users: 2 Reward: 30.00, Total Reward: 344.50, Cache Hits: 300, Cache Misses: 180, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 20, Active users: 2 Reward: 30.00, Total Reward: 374.50, Cache Hits: 324, Cache Misses: 188, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 21, Active users: 2 Reward: 30.00, Total Reward: 404.50, Cache Hits: 348, Cache Misses: 196, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 22, Active users: 2 Reward: 30.00, Total Reward: 434.50, Cache Hits: 372, Cache Misses: 204, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 23, Active users: 2 Reward: 30.00, Total Reward: 464.50, Cache Hits: 396, Cache Misses: 212, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 24, Active users: 2 Reward: 30.00, Total Reward: 494.50, Cache Hits: 420, Cache Misses: 220, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 25, Active users: 2 Reward: 30.00, Total Reward: 524.50, Cache Hits: 444, Cache Misses: 228, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 26, Active users: 2 Reward: 30.00, Total Reward: 554.50, Cache Hits: 468, Cache Misses: 236, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 27, Active users: 2 Reward: 30.00, Total Reward: 584.50, Cache Hits: 492, Cache Misses: 244, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 28, Active users: 2 Reward: 30.00, Total Reward: 614.50, Cache Hits: 516, Cache Misses: 252, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 29, Active users: 2 Reward: 30.00, Total Reward: 644.50, Cache Hits: 540, Cache Misses: 260, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 30, Active users: 2 Reward: 30.00, Total Reward: 674.50, Cache Hits: 564, Cache Misses: 268, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 31, Active users: 2 Reward: 30.00, Total Reward: 704.50, Cache Hits: 588, Cache Misses: 276, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 32, Active users: 2 Reward: 30.00, Total Reward: 734.50, Cache Hits: 612, Cache Misses: 284, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 2, Step 33, Active users: 2 Reward: 30.00, Total Reward: 764.50, Cache Hits: 636, Cache Misses: 292, Soft Hits: 0.00
# ----------------------------------------------------------------
# --- Episode 2 completed. Total Reward: 794.50, Cache Hits: 660, Cache Misses: 300, Soft Hits: 0.00 ---
# User 0: Total GOP Requests = 30
# User 1: Total GOP Requests = 30
# Episode 3, Step 0, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 1, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 2, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 3, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 4, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 5, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 6, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 7, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 0, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 8, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 16, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 9, Active users: 1 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 48, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 10, Active users: 2 Reward: 15.00, Total Reward: 15.00, Cache Hits: 12, Cache Misses: 68, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 11, Active users: 2 Reward: 7.50, Total Reward: 22.50, Cache Hits: 24, Cache Misses: 88, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 12, Active users: 2 Reward: 15.00, Total Reward: 37.50, Cache Hits: 48, Cache Misses: 96, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 13, Active users: 2 Reward: 30.00, Total Reward: 67.50, Cache Hits: 72, Cache Misses: 104, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 14, Active users: 2 Reward: 30.00, Total Reward: 97.50, Cache Hits: 96, Cache Misses: 112, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 15, Active users: 2 Reward: 30.00, Total Reward: 127.50, Cache Hits: 120, Cache Misses: 120, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 16, Active users: 2 Reward: 30.00, Total Reward: 157.50, Cache Hits: 144, Cache Misses: 128, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 17, Active users: 2 Reward: 30.00, Total Reward: 187.50, Cache Hits: 156, Cache Misses: 132, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 18, Active users: 1 Reward: 15.00, Total Reward: 202.50, Cache Hits: 168, Cache Misses: 152, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 19, Active users: 2 Reward: 21.00, Total Reward: 223.50, Cache Hits: 192, Cache Misses: 160, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 20, Active users: 2 Reward: 30.00, Total Reward: 253.50, Cache Hits: 216, Cache Misses: 168, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 21, Active users: 2 Reward: 30.00, Total Reward: 283.50, Cache Hits: 240, Cache Misses: 176, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 22, Active users: 2 Reward: 30.00, Total Reward: 313.50, Cache Hits: 264, Cache Misses: 184, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 23, Active users: 2 Reward: 30.00, Total Reward: 343.50, Cache Hits: 288, Cache Misses: 192, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 24, Active users: 2 Reward: 30.00, Total Reward: 373.50, Cache Hits: 312, Cache Misses: 200, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 25, Active users: 2 Reward: 30.00, Total Reward: 403.50, Cache Hits: 336, Cache Misses: 208, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 26, Active users: 2 Reward: 30.00, Total Reward: 433.50, Cache Hits: 348, Cache Misses: 212, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 27, Active users: 1 Reward: 32.50, Total Reward: 466.00, Cache Hits: 374, Cache Misses: 218, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 28, Active users: 2 Reward: 30.00, Total Reward: 496.00, Cache Hits: 398, Cache Misses: 226, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 29, Active users: 2 Reward: 30.00, Total Reward: 526.00, Cache Hits: 410, Cache Misses: 230, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 30, Active users: 1 Reward: 30.00, Total Reward: 556.00, Cache Hits: 434, Cache Misses: 238, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 31, Active users: 2 Reward: 30.00, Total Reward: 586.00, Cache Hits: 458, Cache Misses: 246, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 32, Active users: 2 Reward: 30.00, Total Reward: 616.00, Cache Hits: 482, Cache Misses: 254, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 33, Active users: 2 Reward: 30.00, Total Reward: 646.00, Cache Hits: 506, Cache Misses: 262, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 34, Active users: 2 Reward: 30.00, Total Reward: 676.00, Cache Hits: 530, Cache Misses: 270, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 35, Active users: 2 Reward: 30.00, Total Reward: 706.00, Cache Hits: 554, Cache Misses: 278, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 36, Active users: 2 Reward: 30.00, Total Reward: 736.00, Cache Hits: 578, Cache Misses: 286, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 37, Active users: 2 Reward: 30.00, Total Reward: 766.00, Cache Hits: 602, Cache Misses: 294, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 38, Active users: 2 Reward: 30.00, Total Reward: 796.00, Cache Hits: 626, Cache Misses: 302, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 39, Active users: 2 Reward: 30.00, Total Reward: 826.00, Cache Hits: 650, Cache Misses: 310, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 40, Active users: 2 Reward: 30.00, Total Reward: 856.00, Cache Hits: 662, Cache Misses: 314, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 41, Active users: 1 Reward: 0.00, Total Reward: 856.00, Cache Hits: 662, Cache Misses: 330, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 42, Active users: 1 Reward: 26.29, Total Reward: 882.29, Cache Hits: 674, Cache Misses: 350, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 43, Active users: 2 Reward: 26.47, Total Reward: 908.76, Cache Hits: 686, Cache Misses: 370, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 44, Active users: 2 Reward: 24.70, Total Reward: 933.46, Cache Hits: 698, Cache Misses: 390, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 45, Active users: 2 Reward: 23.97, Total Reward: 957.43, Cache Hits: 710, Cache Misses: 410, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 46, Active users: 2 Reward: 30.00, Total Reward: 987.43, Cache Hits: 722, Cache Misses: 414, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 47, Active users: 1 Reward: 15.00, Total Reward: 1002.43, Cache Hits: 734, Cache Misses: 434, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 48, Active users: 2 Reward: 23.47, Total Reward: 1025.90, Cache Hits: 758, Cache Misses: 442, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 49, Active users: 2 Reward: 30.00, Total Reward: 1055.90, Cache Hits: 782, Cache Misses: 450, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 50, Active users: 2 Reward: 30.00, Total Reward: 1085.90, Cache Hits: 806, Cache Misses: 458, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 51, Active users: 2 Reward: 30.00, Total Reward: 1115.90, Cache Hits: 830, Cache Misses: 466, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 52, Active users: 2 Reward: 30.00, Total Reward: 1145.90, Cache Hits: 854, Cache Misses: 474, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 53, Active users: 2 Reward: 30.00, Total Reward: 1175.90, Cache Hits: 878, Cache Misses: 482, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 54, Active users: 2 Reward: 30.00, Total Reward: 1205.90, Cache Hits: 902, Cache Misses: 490, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 55, Active users: 2 Reward: 30.00, Total Reward: 1235.90, Cache Hits: 926, Cache Misses: 498, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 56, Active users: 2 Reward: 30.00, Total Reward: 1265.90, Cache Hits: 950, Cache Misses: 506, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 57, Active users: 2 Reward: 30.00, Total Reward: 1295.90, Cache Hits: 974, Cache Misses: 514, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 58, Active users: 2 Reward: 30.00, Total Reward: 1325.90, Cache Hits: 998, Cache Misses: 522, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 59, Active users: 2 Reward: 30.00, Total Reward: 1355.90, Cache Hits: 1022, Cache Misses: 530, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 60, Active users: 2 Reward: 30.00, Total Reward: 1385.90, Cache Hits: 1046, Cache Misses: 538, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 61, Active users: 2 Reward: 30.00, Total Reward: 1415.90, Cache Hits: 1070, Cache Misses: 546, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 62, Active users: 2 Reward: 30.00, Total Reward: 1445.90, Cache Hits: 1094, Cache Misses: 554, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 63, Active users: 2 Reward: 30.00, Total Reward: 1475.90, Cache Hits: 1118, Cache Misses: 562, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 64, Active users: 2 Reward: 30.00, Total Reward: 1505.90, Cache Hits: 1142, Cache Misses: 570, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 65, Active users: 2 Reward: 30.00, Total Reward: 1535.90, Cache Hits: 1166, Cache Misses: 578, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 66, Active users: 2 Reward: 30.00, Total Reward: 1565.90, Cache Hits: 1190, Cache Misses: 586, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 67, Active users: 2 Reward: 30.00, Total Reward: 1595.90, Cache Hits: 1214, Cache Misses: 594, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 68, Active users: 2 Reward: 30.00, Total Reward: 1625.90, Cache Hits: 1238, Cache Misses: 602, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 69, Active users: 2 Reward: 30.00, Total Reward: 1655.90, Cache Hits: 1262, Cache Misses: 610, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 70, Active users: 2 Reward: 30.00, Total Reward: 1685.90, Cache Hits: 1286, Cache Misses: 618, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 71, Active users: 2 Reward: 30.00, Total Reward: 1715.90, Cache Hits: 1298, Cache Misses: 622, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 72, Active users: 1 Reward: 0.00, Total Reward: 1715.90, Cache Hits: 1298, Cache Misses: 638, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 73, Active users: 1 Reward: 25.08, Total Reward: 1740.98, Cache Hits: 1298, Cache Misses: 654, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 74, Active users: 1 Reward: 24.67, Total Reward: 1765.66, Cache Hits: 1298, Cache Misses: 670, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 75, Active users: 1 Reward: 24.76, Total Reward: 1790.41, Cache Hits: 1310, Cache Misses: 674, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 76, Active users: 1 Reward: 30.00, Total Reward: 1820.41, Cache Hits: 1322, Cache Misses: 678, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 77, Active users: 1 Reward: 30.00, Total Reward: 1850.41, Cache Hits: 1334, Cache Misses: 682, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 78, Active users: 1 Reward: 30.00, Total Reward: 1880.41, Cache Hits: 1346, Cache Misses: 686, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 79, Active users: 1 Reward: 30.00, Total Reward: 1910.41, Cache Hits: 1358, Cache Misses: 690, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 80, Active users: 1 Reward: 30.00, Total Reward: 1940.41, Cache Hits: 1370, Cache Misses: 694, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 81, Active users: 1 Reward: 30.00, Total Reward: 1970.41, Cache Hits: 1382, Cache Misses: 698, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 82, Active users: 1 Reward: 30.00, Total Reward: 2000.41, Cache Hits: 1394, Cache Misses: 702, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 83, Active users: 1 Reward: 30.00, Total Reward: 2030.41, Cache Hits: 1406, Cache Misses: 706, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 84, Active users: 1 Reward: 30.00, Total Reward: 2060.41, Cache Hits: 1418, Cache Misses: 710, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 85, Active users: 1 Reward: 30.00, Total Reward: 2090.41, Cache Hits: 1430, Cache Misses: 714, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 86, Active users: 1 Reward: 30.00, Total Reward: 2120.41, Cache Hits: 1442, Cache Misses: 718, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 87, Active users: 1 Reward: 30.00, Total Reward: 2150.41, Cache Hits: 1454, Cache Misses: 722, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 88, Active users: 1 Reward: 30.00, Total Reward: 2180.41, Cache Hits: 1466, Cache Misses: 726, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 89, Active users: 1 Reward: 30.00, Total Reward: 2210.41, Cache Hits: 1478, Cache Misses: 730, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 90, Active users: 1 Reward: 30.00, Total Reward: 2240.41, Cache Hits: 1490, Cache Misses: 734, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 91, Active users: 1 Reward: 30.00, Total Reward: 2270.41, Cache Hits: 1502, Cache Misses: 738, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 92, Active users: 1 Reward: 30.00, Total Reward: 2300.41, Cache Hits: 1514, Cache Misses: 742, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 93, Active users: 1 Reward: 30.00, Total Reward: 2330.41, Cache Hits: 1526, Cache Misses: 746, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 94, Active users: 1 Reward: 30.00, Total Reward: 2360.41, Cache Hits: 1538, Cache Misses: 750, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 95, Active users: 1 Reward: 30.00, Total Reward: 2390.41, Cache Hits: 1550, Cache Misses: 754, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 96, Active users: 1 Reward: 30.00, Total Reward: 2420.41, Cache Hits: 1562, Cache Misses: 758, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 97, Active users: 1 Reward: 30.00, Total Reward: 2450.41, Cache Hits: 1574, Cache Misses: 762, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 98, Active users: 1 Reward: 30.00, Total Reward: 2480.41, Cache Hits: 1586, Cache Misses: 766, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 99, Active users: 1 Reward: 30.00, Total Reward: 2510.41, Cache Hits: 1598, Cache Misses: 770, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 3, Step 100, Active users: 1 Reward: 30.00, Total Reward: 2540.41, Cache Hits: 1610, Cache Misses: 774, Soft Hits: 0.00
# ----------------------------------------------------------------
# --- Episode 3 completed. Total Reward: 2570.41, Cache Hits: 1622, Cache Misses: 778, Soft Hits: 0.00 ---
# User 0: Total GOP Requests = 62
# User 1: Total GOP Requests = 88
# Episode 4, Step 0, Active users: 0 Reward: 0.00, Total Reward: 0.00, Cache Hits: 0, Cache Misses: 16, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 1, Active users: 1 Reward: 15.00, Total Reward: 15.00, Cache Hits: 12, Cache Misses: 20, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 2, Active users: 1 Reward: 30.00, Total Reward: 45.00, Cache Hits: 24, Cache Misses: 24, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 3, Active users: 1 Reward: 30.00, Total Reward: 75.00, Cache Hits: 36, Cache Misses: 28, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 4, Active users: 1 Reward: 30.00, Total Reward: 105.00, Cache Hits: 48, Cache Misses: 32, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 5, Active users: 1 Reward: 30.00, Total Reward: 135.00, Cache Hits: 60, Cache Misses: 36, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 6, Active users: 1 Reward: 30.00, Total Reward: 165.00, Cache Hits: 72, Cache Misses: 40, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 7, Active users: 1 Reward: 15.00, Total Reward: 180.00, Cache Hits: 84, Cache Misses: 60, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 8, Active users: 2 Reward: 15.00, Total Reward: 195.00, Cache Hits: 108, Cache Misses: 68, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 9, Active users: 2 Reward: 30.00, Total Reward: 225.00, Cache Hits: 132, Cache Misses: 76, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 10, Active users: 2 Reward: 30.00, Total Reward: 255.00, Cache Hits: 156, Cache Misses: 84, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 11, Active users: 2 Reward: 30.00, Total Reward: 285.00, Cache Hits: 180, Cache Misses: 92, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 12, Active users: 2 Reward: 30.00, Total Reward: 315.00, Cache Hits: 204, Cache Misses: 100, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 13, Active users: 2 Reward: 30.00, Total Reward: 345.00, Cache Hits: 216, Cache Misses: 104, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 14, Active users: 1 Reward: 15.00, Total Reward: 360.00, Cache Hits: 228, Cache Misses: 124, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 15, Active users: 2 Reward: 24.00, Total Reward: 384.00, Cache Hits: 240, Cache Misses: 144, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 16, Active users: 2 Reward: 24.38, Total Reward: 408.38, Cache Hits: 264, Cache Misses: 152, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 17, Active users: 2 Reward: 30.00, Total Reward: 438.38, Cache Hits: 288, Cache Misses: 160, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 18, Active users: 2 Reward: 30.00, Total Reward: 468.38, Cache Hits: 312, Cache Misses: 168, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 19, Active users: 2 Reward: 30.00, Total Reward: 498.38, Cache Hits: 336, Cache Misses: 176, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 20, Active users: 2 Reward: 30.00, Total Reward: 528.38, Cache Hits: 348, Cache Misses: 180, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 4, Step 21, Active users: 1 Reward: 32.50, Total Reward: 560.88, Cache Hits: 374, Cache Misses: 186, Soft Hits: 0.00
# ...
# ----------------------------------------------------------------
# Episode 57, Step 48, Active users: 2 Reward: 30.00, Total Reward: 1111.61, Cache Hits: 876, Cache Misses: 500, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 49, Active users: 2 Reward: 30.00, Total Reward: 1141.61, Cache Hits: 900, Cache Misses: 508, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 50, Active users: 2 Reward: 30.00, Total Reward: 1171.61, Cache Hits: 912, Cache Misses: 512, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 51, Active users: 1 Reward: 30.00, Total Reward: 1201.61, Cache Hits: 924, Cache Misses: 516, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 52, Active users: 1 Reward: 30.00, Total Reward: 1231.61, Cache Hits: 936, Cache Misses: 520, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 53, Active users: 1 Reward: 30.00, Total Reward: 1261.61, Cache Hits: 948, Cache Misses: 524, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 54, Active users: 1 Reward: 30.00, Total Reward: 1291.61, Cache Hits: 960, Cache Misses: 528, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 55, Active users: 1 Reward: 30.00, Total Reward: 1321.61, Cache Hits: 972, Cache Misses: 532, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 56, Active users: 1 Reward: 30.00, Total Reward: 1351.61, Cache Hits: 984, Cache Misses: 536, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 57, Active users: 1 Reward: 30.00, Total Reward: 1381.61, Cache Hits: 996, Cache Misses: 540, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 58, Active users: 1 Reward: 0.00, Total Reward: 1381.61, Cache Hits: 996, Cache Misses: 540, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 59, Active users: 0 Reward: 0.00, Total Reward: 1381.61, Cache Hits: 996, Cache Misses: 556, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 60, Active users: 1 Reward: 23.21, Total Reward: 1404.82, Cache Hits: 996, Cache Misses: 572, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 61, Active users: 1 Reward: 23.33, Total Reward: 1428.15, Cache Hits: 1008, Cache Misses: 576, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 62, Active users: 1 Reward: 30.00, Total Reward: 1458.15, Cache Hits: 1020, Cache Misses: 580, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 63, Active users: 1 Reward: 30.00, Total Reward: 1488.15, Cache Hits: 1032, Cache Misses: 584, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 64, Active users: 1 Reward: 30.00, Total Reward: 1518.15, Cache Hits: 1044, Cache Misses: 588, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 65, Active users: 1 Reward: 30.00, Total Reward: 1548.15, Cache Hits: 1056, Cache Misses: 592, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 66, Active users: 1 Reward: 30.00, Total Reward: 1578.15, Cache Hits: 1068, Cache Misses: 596, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 67, Active users: 1 Reward: 30.00, Total Reward: 1608.15, Cache Hits: 1080, Cache Misses: 600, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 68, Active users: 1 Reward: 30.00, Total Reward: 1638.15, Cache Hits: 1092, Cache Misses: 604, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 69, Active users: 1 Reward: 0.00, Total Reward: 1638.15, Cache Hits: 1092, Cache Misses: 604, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 70, Active users: 0 Reward: 0.00, Total Reward: 1638.15, Cache Hits: 1092, Cache Misses: 620, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 71, Active users: 1 Reward: 23.81, Total Reward: 1661.96, Cache Hits: 1104, Cache Misses: 624, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 72, Active users: 1 Reward: 30.00, Total Reward: 1691.96, Cache Hits: 1116, Cache Misses: 628, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 73, Active users: 1 Reward: 30.00, Total Reward: 1721.96, Cache Hits: 1128, Cache Misses: 632, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 74, Active users: 1 Reward: 30.00, Total Reward: 1751.96, Cache Hits: 1140, Cache Misses: 636, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 75, Active users: 1 Reward: 30.00, Total Reward: 1781.96, Cache Hits: 1152, Cache Misses: 640, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 76, Active users: 1 Reward: 30.00, Total Reward: 1811.96, Cache Hits: 1164, Cache Misses: 644, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 77, Active users: 1 Reward: 30.00, Total Reward: 1841.96, Cache Hits: 1176, Cache Misses: 648, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 78, Active users: 1 Reward: 30.00, Total Reward: 1871.96, Cache Hits: 1188, Cache Misses: 652, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 79, Active users: 1 Reward: 30.00, Total Reward: 1901.96, Cache Hits: 1200, Cache Misses: 656, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 80, Active users: 1 Reward: 30.00, Total Reward: 1931.96, Cache Hits: 1212, Cache Misses: 660, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 81, Active users: 1 Reward: 30.00, Total Reward: 1961.96, Cache Hits: 1224, Cache Misses: 664, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 82, Active users: 1 Reward: 30.00, Total Reward: 1991.96, Cache Hits: 1236, Cache Misses: 668, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 83, Active users: 1 Reward: 30.00, Total Reward: 2021.96, Cache Hits: 1248, Cache Misses: 672, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 84, Active users: 1 Reward: 30.00, Total Reward: 2051.96, Cache Hits: 1260, Cache Misses: 676, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 85, Active users: 1 Reward: 30.00, Total Reward: 2081.96, Cache Hits: 1272, Cache Misses: 680, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 86, Active users: 1 Reward: 30.00, Total Reward: 2111.96, Cache Hits: 1284, Cache Misses: 684, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 87, Active users: 1 Reward: 30.00, Total Reward: 2141.96, Cache Hits: 1296, Cache Misses: 688, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 88, Active users: 1 Reward: 30.00, Total Reward: 2171.96, Cache Hits: 1308, Cache Misses: 692, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 89, Active users: 1 Reward: 30.00, Total Reward: 2201.96, Cache Hits: 1320, Cache Misses: 696, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 90, Active users: 1 Reward: 30.00, Total Reward: 2231.96, Cache Hits: 1332, Cache Misses: 700, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 91, Active users: 1 Reward: 30.00, Total Reward: 2261.96, Cache Hits: 1344, Cache Misses: 704, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 92, Active users: 1 Reward: 0.00, Total Reward: 2261.96, Cache Hits: 1344, Cache Misses: 704, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 93, Active users: 0 Reward: 0.00, Total Reward: 2261.96, Cache Hits: 1344, Cache Misses: 720, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 94, Active users: 1 Reward: 25.06, Total Reward: 2287.02, Cache Hits: 1356, Cache Misses: 724, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 95, Active users: 1 Reward: 30.00, Total Reward: 2317.02, Cache Hits: 1368, Cache Misses: 728, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 96, Active users: 1 Reward: 30.00, Total Reward: 2347.02, Cache Hits: 1380, Cache Misses: 732, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 97, Active users: 1 Reward: 30.00, Total Reward: 2377.02, Cache Hits: 1392, Cache Misses: 736, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 98, Active users: 1 Reward: 30.00, Total Reward: 2407.02, Cache Hits: 1404, Cache Misses: 740, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 99, Active users: 1 Reward: 30.00, Total Reward: 2437.02, Cache Hits: 1416, Cache Misses: 744, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 100, Active users: 1 Reward: 30.00, Total Reward: 2467.02, Cache Hits: 1428, Cache Misses: 748, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 101, Active users: 1 Reward: 30.00, Total Reward: 2497.02, Cache Hits: 1440, Cache Misses: 752, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 102, Active users: 1 Reward: 0.00, Total Reward: 2497.02, Cache Hits: 1440, Cache Misses: 752, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 103, Active users: 0 Reward: 0.00, Total Reward: 2497.02, Cache Hits: 1440, Cache Misses: 768, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 104, Active users: 1 Reward: 24.89, Total Reward: 2521.91, Cache Hits: 1440, Cache Misses: 784, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 105, Active users: 1 Reward: 24.95, Total Reward: 2546.86, Cache Hits: 1452, Cache Misses: 788, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 106, Active users: 1 Reward: 30.00, Total Reward: 2576.86, Cache Hits: 1464, Cache Misses: 792, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 107, Active users: 1 Reward: 30.00, Total Reward: 2606.86, Cache Hits: 1476, Cache Misses: 796, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 108, Active users: 1 Reward: 30.00, Total Reward: 2636.86, Cache Hits: 1488, Cache Misses: 800, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 109, Active users: 1 Reward: 30.00, Total Reward: 2666.86, Cache Hits: 1500, Cache Misses: 804, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 110, Active users: 1 Reward: 30.00, Total Reward: 2696.86, Cache Hits: 1512, Cache Misses: 808, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 111, Active users: 1 Reward: 30.00, Total Reward: 2726.86, Cache Hits: 1524, Cache Misses: 812, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 112, Active users: 1 Reward: 30.00, Total Reward: 2756.86, Cache Hits: 1536, Cache Misses: 816, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 113, Active users: 1 Reward: 30.00, Total Reward: 2786.86, Cache Hits: 1548, Cache Misses: 820, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 114, Active users: 1 Reward: 30.00, Total Reward: 2816.86, Cache Hits: 1560, Cache Misses: 824, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 115, Active users: 1 Reward: 0.00, Total Reward: 2816.86, Cache Hits: 1560, Cache Misses: 824, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 116, Active users: 0 Reward: 0.00, Total Reward: 2816.86, Cache Hits: 1560, Cache Misses: 840, Soft Hits: 0.00
# ----------------------------------------------------------------
# Episode 57, Step 117, Active users: 1 Reward: 25.19, Total Reward: 2842.05, Cache Hits: 1572, Cache Misses: 844, Soft Hits: 0.00
# ----------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 153
#     145         actions.append({
#     146             'video': v,
#     147             'gop': 0,
#     148             'tiles': ranked_tiles[:cfg.viewport],
#     149             'base_req_init': False
#     150         })
#     152 # --- STEP ENV ---
# --> 153 obs, reward, done, info = env.step(actions)
#     155 # --- UPDATE USER HISTORY & VIDEO POPULARITY ---
#     156 for req in reqs_state:
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\Sources\Examples\LabEnvWrapper.ipynb:133, in EnvWrapper.step(self, actions)
#     130 tiles = req['tiles']
#     132 users_per_du = self.users_env.n_users // self.users_env.n_nodes
# --> 133 latency, tiles_received = self.latency_model.total_request_latency_multi_du(
#     134     p,
#     135     u,
#     136     tiles,
#     137     users_per_du,
#     138     self.users_env.n_users
#     139 )
#     141 total_latency += latency
#     142 users_tiles_received[u] = tiles_received
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\Sources\Examples\LabLatencyModel.ipynb:381, in MultiDULatencyModel.total_request_latency_multi_du(self, p, u, tiles, users_per_du, total_system_users)
#     378 tid    = tile["tile"]
#     379 layer  = tile["layer"]
# --> 381 lat = self.tile_latency_multi_du(
#     382     p,
#     383     u,
#     384     sz,
#     385     events,
#     386     users_per_du,
#     387     total_system_users
#     388 )
#     390 if total + lat >= 1.0:
#     391     break
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\Sources\Examples\LabLatencyModel.ipynb:351, in MultiDULatencyModel.tile_latency_multi_du(self, p, u, tile_size_bytes, events, users_per_du, total_system_users)
#     338 T_vec = np.array(
#     339     self.time_vector_multi_du(p, u, users_per_du, total_system_users),
#     340     dtype=float
#     341 )
#     343 ES_vec = np.array([
#     344     events["alpha_p_u"], # Served at DU
#     345     events["alpha_M_u"], # Served at MEC
#    (...)    348     events["beta_M_u"],  # Transcoded at MEC
#     349 ], dtype=float)
# --> 351 per_byte_latency = float(np.dot(ES_vec, T_vec) * tile_size_bytes)
#     353 fixed = 0.0
#     354 if events["alpha_p_u"] == 1 or events["beta_p_u"] == 1:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------      
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

# Professional color for line plots
PRIMARY_COLOR = "#2b7bba"

# ----------------------------------------------------------------
# 2. Data Loading & Smoothing
# ----------------------------------------------------------------
path = cfg.path_results + "/" + cfg.filename

print(f"Loading data from: {path}")

df = pd.read_csv(path)

total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
df["hit_rate"] = (df["cache_hits"] / total) * 100
df["miss_rate"] = (df["cache_misses"] / total) * 100

# Metrics to plot
metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
window_size = 10  # Adjust smoothing window as needed

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
# Adjusted figsize for a 4-column row (standard for full-width paper figures)
fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

for ax, col in zip(axes, metrics):
    # Plot raw data with transparency (alpha)
    ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, alpha=0.3, linewidth=0.8, label='Raw')
    
    # Plot moving average for clearer trend (except for epsilon which is usually linear)
    if col != "epsilon":
        smoothed = df[col].rolling(window=window_size).mean()
        ax.plot(df["episode"], smoothed, color=PRIMARY_COLOR, linewidth=1.5, label='Trend')
    else:
        # Just a solid line for Epsilon
        ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, linewidth=1.5)

    # Stylistic cleanup
    ax.set_title(col.replace("_", " ").title(), fontweight="bold")
    ax.set_xlabel("Episode")
    
    # Remove redundant Y-labels to save space, or keep for clarity
    ax.set_ylabel("Value") 
    
    series = df[col].dropna()
    if not series.empty:
        ymin = series.min()
        ymax = series.max()
        pad = (ymax - ymin) * 0.05 if ymax != ymin else 1.0
        ax.set_ylim(ymin - pad, ymax + pad)
    ax.grid(axis='y', linestyle='--', alpha=0.3)
    
    # Tufte-style: remove top/right spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# Optional: Add a single legend to the first plot if needed
# axes[0].legend(frameon=False)

plt.show()
fig.savefig("drl_caching_metrics.png", dpi=300)
# Out:
# Loading data from: c:\Users\es25591\Workspace\CacheVideoPredict360\Results/drl_dqn_softup_fixedlr0.001_c25_ar10.0_z1.0.csv

# %%
if __name__ == "__main__":
    cfg = Config()

    plt.rcParams.update({
        "font.family": "serif",
        "font.serif": ["Times New Roman", "DejaVu Serif"],
        "font.size": 10,
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "legend.fontsize": 9,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "axes.linewidth": 0.8,
        "savefig.dpi": 300,
        "figure.constrained_layout.use": True
    })

    COLORS = ["#2b7bba", "#d62728", "#2ca02c"]

    folder = r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\interval_100_3"
    files = [
        "drl_pan_fixedlr0.001_c50_ar10.0_z1.0.csv",
        "drl_pan_lrdecay0.9999_c50_ar10.0_z1.0.csv",
        # "drl_pan_lrdecay0.99999_c50_ar10.0_z0.8.csv",
    ]

    paths = [os.path.join(folder, f) for f in files]
    def _short_label(fname: str) -> str:
        stem = os.path.splitext(fname)[0]
        if "lrdecay" in stem:
            val = stem.split("lrdecay", 1)[1].split("_", 1)[0]
            return f"lr decay: {val}"
        if "fixedlr" in stem:
            val = stem.split("fixedlr", 1)[1].split("_", 1)[0]
            return f"fixed lr: {val}"
        return stem

    labels = [_short_label(f) for f in files]

    print(labels)
    metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
    window_size = 10

    fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

    for color, path, label in zip(COLORS, paths, labels):
        df = pd.read_csv(path)
        total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
        df["hit_rate"] = (df["cache_hits"] / total) * 100
        df["miss_rate"] = (df["cache_misses"] / total) * 100

        for ax, col in zip(axes, metrics):
            ax.plot(df["episode"], df[col], color=color, alpha=0.25, linewidth=0.8)

            if col != "epsilon":
                smoothed = df[col].rolling(window=window_size).mean()
                ax.plot(df["episode"], smoothed, color=color, linewidth=1.5, label=label)
            else:
                ax.plot(df["episode"], df[col], color=color, linewidth=1.5, label=label)

    for ax, col in zip(axes, metrics):
        ax.set_title(col.replace("_", " ").title(), fontweight="bold")
        ax.set_xlabel("Episode")
        ax.set_ylabel("Value")
        ax.grid(axis="y", linestyle="--", alpha=0.3)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.set_ylim(bottom=0)

    axes[0].legend(frameon=False, loc="best")
    plt.show()

    fig.savefig("interval_04_comparison.png", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 if __name__ == "__main__":
# ----> 2     cfg = Config()
#       4     plt.rcParams.update({
#       5         "font.family": "serif",
#       6         "font.serif": ["Times New Roman", "DejaVu Serif"],
#    (...)     15         "figure.constrained_layout.use": True
#      16     })
#      18     COLORS = ["#2b7bba", "#d62728", "#2ca02c"]
#
# NameError: name 'Config' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------      
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

COLORS = ["#2b7bba", "#d62728"]

# ----------------------------------------------------------------
# 2. Data Preparation with Variance
# ----------------------------------------------------------------
def get_metrics_with_error(path):
    """Returns mean and standard deviation for hit and miss rates."""
    try:
        df = pd.read_csv(path)
        total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
        
        hit_series = (df["cache_hits"] / total * 100)
        miss_series = (df["cache_misses"] / total * 100)
        
        # Calculate Mean and Standard Deviation
        return (hit_series.mean(), hit_series.std()), (miss_series.mean(), miss_series.std())
    except Exception as e:
        print(f"Error processing {path}: {e}")
        return (0, 0), (0, 0)

drl_files = {
    "5": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\drl_pan_opt_c25_ar10.0_z0.5.csv",
    "10": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\drl_pan_opt_c50_ar10.0_z0.5.csv",
}

lsr_files = {
    "5": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\lru_c25_ar10.0_z0.5.csv",
    "10": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\lru_c50_ar10.0_z0.5.csv",
}

caps = list(drl_files.keys())
# Structure: { Metric: { Algo: [means], Algo_err: [stds] } }
stats = {
    "Hit Rate": {"DRL-LSR": [], "DRL-LSR_err": [], "LRU-LSR": [], "LRU-LSR_err": []},
    "Miss Rate": {"DRL-LSR": [], "DRL-LSR_err": [], "LRU-LSR": [], "LRU-LSR_err": []}
}

for c in caps:
    (d_h, d_h_err), (d_m, d_m_err) = get_metrics_with_error(drl_files[c])
    (l_h, l_h_err), (l_m, l_m_err) = get_metrics_with_error(lsr_files[c])
    
    stats["Hit Rate"]["DRL-LSR"].append(d_h)
    stats["Hit Rate"]["DRL-LSR_err"].append(d_h_err)
    stats["Hit Rate"]["LRU-LSR"].append(l_h)
    stats["Hit Rate"]["LRU-LSR_err"].append(l_h_err)
    
    stats["Miss Rate"]["DRL-LSR"].append(d_m)
    stats["Miss Rate"]["DRL-LSR_err"].append(d_m_err)
    stats["Miss Rate"]["LRU-LSR"].append(l_m)
    stats["Miss Rate"]["LRU-LSR_err"].append(l_m_err)

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(7, 3.2), sharey=True)
x = np.arange(len(caps))
width = 0.35 

# Error bar styling
error_kw = dict(lw=1, capsize=3, capthick=1, ecolor='#333333')

metrics = ["Hit Rate", "Miss Rate"]
for i, metric in enumerate(metrics):
    ax = axes[i]
    
    ax.bar(x - width/2, stats[metric]["DRL-LSR"], width, 
           yerr=stats[metric]["DRL-LSR_err"], error_kw=error_kw,
           label="DRL-LSR", color=COLORS[0], edgecolor='black', linewidth=0.6, zorder=3)
    
    ax.bar(x + width/2, stats[metric]["LRU-LSR"], width, 
           yerr=stats[metric]["LRU-LSR_err"], error_kw=error_kw,
           label="LRU-LSR", color=COLORS[1], edgecolor='black', linewidth=0.6, zorder=3)

    ax.set_title(f"Average {metric}", fontweight="bold")
    ax.set_xlabel("Cache Size (%)")
    ax.set_xticks(x)
    ax.set_xticklabels(caps)
    ax.set_ylim(0, 110) # Increased to accommodate error bars
    
    ax.grid(axis='y', linestyle='--', alpha=0.3, zorder=0)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

axes[0].set_ylabel("Percentage (%)")
axes[1].legend(frameon=False, loc="upper right")

plt.tight_layout()
plt.show()

fig.savefig("drl_vs_lru_cache_performance.pdf")
# Out:
# C:\Users\es25591\AppData\Local\Temp\ipykernel_24328\1345644425.py:108: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
