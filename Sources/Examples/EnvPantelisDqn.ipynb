# %%
import os
import math
import csv
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import Any, Dict, Counter, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torch_optimizer as optim_extra

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv, DrlPolicy
    from LabUserRequest import UserRequestEvents
    from LabEnvWrapper import EnvWrapper

import importlib
import config

importlib.reload(config)
# Out:
# <module 'config' from '/home/eduardo/Workspace/CacheVideoPredict360/Sources/Examples/config.py'>

# %%
cfg = config.Config()

cfg.filename = f"drl_dqn_softup_lrdecay{cfg.learning_rate_decay}_u{cfg.n_users}_e{cfg.n_episodes}_c{cfg.cache_size}_ar{cfg.arrival_rate}_z{cfg.zipf_alpha}.csv"
# cfg.filename = f"drl_dqn_softup_fixedlr{cfg.learning_rate}_e{cfg.n_episodes}_c{cfg.cache_size}_ar{cfg.arrival_rate}_z{cfg.zipf_alpha}.csv"

cfg.state_dim = 10 * cfg.cache_size + 2

# %%
# --- DataClass for User Transition ---
@dataclass
class UserTransition:
    state: Any
    action: int
    reward: float

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int):
        super().__init__()
        hidden = 128
        self.fc1 = nn.Linear(state_dim, hidden)
        self.fc2 = nn.Linear(hidden, hidden)
        self.out = nn.Linear(hidden, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.out(x)

class ReplayBuffer:
    def __init__(self, capacity: int = 2000):
        self.memory = deque(maxlen=capacity)
    
    def push(self, s, a, r, ns, d):
        self.memory.append((s, a, r, ns, d))
    
    def sample(self, batch_size: int):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

class DQNAgent:
    def __init__(self, cfg: Any):
        self.step = 0
        
        self.state_dim = cfg.state_dim
        self.action_dim = cfg.action_dim
        
        self.epsilon = cfg.epsilon_start
        self.epsilon_min = cfg.epsilon_min
        self.epsilon_decay = cfg.epsilon_decay
        self.gamma = cfg.gamma
        self.tau = cfg.tau
        self.batch_size = cfg.batch_size
        
        self.buffer = ReplayBuffer(cfg.buffer_capacity)
        
        self.policy_net = QNetwork(self.state_dim, self.action_dim).to(device)
        self.target_net = QNetwork(self.state_dim, self.action_dim).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=cfg.learning_rate)
        # self.optimizer = optim_extra.Ranger(
        #     self.policy_net.parameters(), 
        #     lr=cfg.learning_rate,
        #     alpha=0.5,  # Lookahead step size (default is usually 0.5)
        #     k=6         # Lookahead step frequency
        # )
        
        self.scheduler = torch.optim.lr_scheduler.ExponentialLR(
            self.optimizer, 
            gamma=cfg.learning_rate_decay
        )
        
        self.loss_fn = nn.MSELoss()
        self.nb_interval = cfg.nb_interval  # train every 5 requests

    def select_action(self, state):
        if random.random() < self.epsilon:
            action_idx = random.randint(0, self.action_dim - 1)
            return action_idx, None
        
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.policy_net(state)
        
        action_idx = q_values.argmax().item()
        return action_idx, q_values
        
    def remember(self, s, a, r, ns, done):
        self.buffer.push(s, a, r, ns, done)

    def train_step(self):
        self.step += 1
        if self.step % self.nb_interval == 0 and \
           len(self.buffer) >= self.batch_size:
            self.learn()

    def learn(self):
        batch = self.buffer.sample(self.batch_size)
        s, a, r, ns, d = zip(*batch)
        s = torch.tensor(np.stack(s), dtype=torch.float32).to(device)
        ns = torch.tensor(np.stack(ns), dtype=torch.float32).to(device)
        a = torch.tensor(a, dtype=torch.int64).to(device)
        r = torch.tensor(r, dtype=torch.float32).to(device)
        d = torch.tensor(d, dtype=torch.float32).to(device)

        with torch.no_grad():
            q_next = self.target_net(ns).max(1)[0]
            q_target = r + self.gamma * q_next * (1.0 - d)

        q_expected = self.policy_net(s).gather(1, a.unsqueeze(1)).squeeze(1)

        loss = self.loss_fn(q_expected, q_target)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.scheduler.step()
        
        self.soft_update_target()

    def soft_update_target(self):
        for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
            target_param.data.copy_( 
                target_param.data * (1.0 - self.tau) + policy_param.data * self.tau
            )

    def update_target(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        
    def reset_step(self):
        self.step = 0

# %%
def save_training_results(
    path_,
    filename,
    ep, 
    total_reward, 
    cache_hits, 
    cache_misses, 
    soft_hits,
    agent
):
    with open(os.path.join(path_, filename), 'a', newline='') as f:
        fieldnames = [
            'episode', 
            'total_reward', 
            'cache_hits', 
            'cache_misses', 
            'soft_hits',
            'epsilon',
            'lr'
        ]
        writer_results = csv.DictWriter(f, fieldnames=fieldnames)

        if ep == 0:
            writer_results.writeheader()
        
        writer_results.writerow({
            'episode': ep,
            'total_reward': round(float(total_reward), 2),
            'cache_hits': cache_hits,
            'cache_misses': cache_misses,
            'soft_hits': soft_hits,
            'lr': f"{agent.scheduler.get_last_lr()[0]:.10f}" if agent else None,
            'epsilon': round(float(agent.epsilon), 4) if agent else None
        })

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, float]:
    enh_hits = info.get("enh_layer_cache_hits", 0)
    base_hits = info.get("base_layer_cache_hits", 0)
    enh_misses = info.get("enh_layer_cache_misses", 0)
    base_misses = info.get("base_layer_cache_misses", 0)
    soft_hits = info.get("soft_hits", 0.0)

    return reward, (enh_hits + base_hits), (enh_misses + base_misses), soft_hits

# %%
class FeatureAdapter:
    def __init__(self, env: CacheEngineEnv, cfg: Any):
        self.env = env
        self.cfg = cfg

        self.video_hist_short = deque(maxlen=cfg.h_short)
        self.video_hist_long = deque(maxlen=cfg.h_long)
        self.tile_hist_short = deque(maxlen=cfg.h_short)
        self.tile_hist_long = deque(maxlen=cfg.h_long)
        self.tiles_hist_short = deque(maxlen=cfg.h_short)
        self.tiles_hist_long = deque(maxlen=cfg.h_long)

        self.video_freq_short = defaultdict(int)
        self.video_freq_long = defaultdict(int)
        self.tile_freq_short = defaultdict(int)
        self.tile_freq_long = defaultdict(int)
        self.tiles_freq_short = defaultdict(int)
        self.tiles_freq_long = defaultdict(int)

    def reset_history(self):
        queues = (
            self.video_hist_short,
            self.video_hist_long,
            self.tiles_hist_short,
            self.tiles_hist_long,
            self.tile_hist_short,
            self.tile_hist_long,
        )
        freqs = (
            self.video_freq_short,
            self.video_freq_long,
            self.tiles_freq_short,
            self.tiles_freq_long,
            self.tile_freq_short,
            self.tile_freq_long,
        )
        
        for q in queues:
            q.clear()
        for f in freqs:
            f.clear()

    def update_history(self, vid: int, tiles: list[int]):       
        self._update_window(self.video_hist_short, self.video_freq_short, vid)
        self._update_window(self.video_hist_long, self.video_freq_long, vid)

        tiles = tuple(tiles) if tiles is not None else None

        if tiles is None:
            return

        self._update_window(self.tiles_hist_short, self.tiles_freq_short, tiles)
        self._update_window(self.tiles_hist_long, self.tiles_freq_long, tiles)

        for tile in tiles:
            self._update_window(self.tile_hist_short, self.tile_freq_short, (vid, tile))
            self._update_window(self.tile_hist_long, self.tile_freq_long, (vid, tile))

    def _update_window(self, hist_queue: deque, freq_dict: Dict, item):
        if len(hist_queue) == hist_queue.maxlen:
            old_item = hist_queue.popleft()
            freq_dict[old_item] -= 1
            if freq_dict[old_item] == 0:
                del freq_dict[old_item]
        hist_queue.append(item)
        freq_dict[item] += 1

# %%
class NetworkAdapter:
    def __init__(self, env: EnvWrapper, feature_adapter: FeatureAdapter, cfg: Any):
        self.env = env
        self.cfg = cfg
        self.features = feature_adapter

        self.C = self.cfg.cache_size  # paper's cache capacity (videos)
        self.k = self.cfg.viewport    # paper's tiles per video (enhancement)

        print(f"NetworkAdapter initialized with capacity: {self.C} videos, {self.k} tiles per video")

    def build_observation(self, vid: int) -> np.ndarray:

        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        # --- FIX: Create a list of (video_id, slot_index) ---
        alpha = 0.7  # weighting factor for frequency combination
        cached_items = []
        for slot_i, v_id in enumerate(video_cache_index):
            if v_id != -1:
                freq = alpha * self.features.video_freq_long.get(v_id, 0) + (1 - alpha) * self.features.video_freq_short.get(v_id, 0)
                cached_items.append((freq, v_id, slot_i))
            else:
                cached_items.append((-1, -1, slot_i))

        cached_items.sort(key=lambda x: x[0], reverse=True)
        # ----------------------------------------------------

        x_s = np.zeros(self.C, dtype=np.float32)
        x_l = np.zeros(self.C, dtype=np.float32)
        y_s = np.zeros(self.C * self.k, dtype=np.float32)
        y_l = np.zeros(self.C * self.k, dtype=np.float32)

        # Iterate through the SORTED items to build the state
        for i, (freq, v, original_slot) in enumerate(cached_items):
            if v == -1: continue # Skip empty placeholders
            
            # Fill video features
            x_s[i] = np.log1p(self.features.video_freq_short.get(v, 0))
            x_l[i] = np.log1p(self.features.video_freq_long.get(v, 0))

            # Fill tile features using the original slot to look up specific tiles
            tiles = tile_cache_index[original_slot]
            for til_i, t in enumerate(tiles):
                if t == -1: continue
                y_s[i * self.k + til_i] = np.log1p(self.features.tile_freq_short.get((v, t), 0))
                y_l[i * self.k + til_i] = np.log1p(self.features.tile_freq_long.get((v, t), 0))

        # 4. Candidate Features
        cand_s = np.log1p(self.features.video_freq_short.get(vid, 0))
        cand_l = np.log1p(self.features.video_freq_long.get(vid, 0))

        z_s = np.array([cand_s], dtype=np.float32)
        z_l = np.array([cand_l], dtype=np.float32)

        return np.concatenate([x_s, x_l, y_s, y_l, z_s, z_l], axis=0)


    def build_observation_with_tile_pop(self, vid: int, viewport: list[int]) -> np.ndarray:

        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        # --- FIX: Create a list of (video_id, slot_index) ---
        alpha = 0.7  # weighting factor for frequency combination
        cached_items = []
        for slot_i, v_id in enumerate(video_cache_index):
            if v_id != -1:
                freq = alpha * self.features.video_freq_long.get(v_id, 0) + (1 - alpha) * self.features.video_freq_short.get(v_id, 0)
                cached_items.append((freq, v_id, slot_i))
            else:
                cached_items.append((-1, -1, slot_i))

        cached_items.sort(key=lambda x: x[0], reverse=True)
        # ----------------------------------------------------

        x_s = np.zeros(self.C, dtype=np.float32)
        x_l = np.zeros(self.C, dtype=np.float32)
        y_s = np.zeros(self.C * self.k, dtype=np.float32)
        y_l = np.zeros(self.C * self.k, dtype=np.float32)

        # Iterate through the SORTED items to build the state
        for i, (freq, v, original_slot) in enumerate(cached_items):
            if v == -1: continue # Skip empty placeholders

            # Fill video features
            x_s[i] = np.log1p(self.features.video_freq_short.get(v, 0))
            x_l[i] = np.log1p(self.features.video_freq_long.get(v, 0))

            # Fill tile features using the original slot to look up specific tiles
            tiles = tile_cache_index[original_slot]
            for til_i, t in enumerate(tiles):
                if t == -1: continue
                y_s[i * self.k + til_i] = np.log1p(self.features.tile_freq_short.get((v, t), 0))
                y_l[i * self.k + til_i] = np.log1p(self.features.tile_freq_long.get((v, t), 0))

        # 2. NEW: Calculate Request Features WITH Viewport/Enhancement Info
        
        # Base Layer Popularity (Video Freq)
        vid_req_s = np.log1p(self.features.video_freq_short.get(vid, 0))
        vid_req_l = np.log1p(self.features.video_freq_long.get(vid, 0))
        
        # Enhancement Layer Popularity (Sum of frequencies of requested tiles)
        # This tells the agent if the requested VIEWPORT is popular
        enh_req_s = np.sum([self.features.tile_freq_short.get((vid, t), 0) for t in viewport])
        enh_req_l = np.sum([self.features.tile_freq_long.get((vid, t), 0) for t in viewport])
        
        enh_req_s = np.log1p(enh_req_s)
        enh_req_l = np.log1p(enh_req_l)

        # Update z_s/z_l to include Enhancement info
        # Current z shape was likely (1,), now it is (2,)
        z_s = np.array([vid_req_s, enh_req_s], dtype=np.float32) 
        z_l = np.array([vid_req_l, enh_req_l], dtype=np.float32)

        return np.concatenate([x_s, x_l, y_s, y_l, z_s, z_l], axis=0)


    def rank_viewport_tiles(
        self,
        vid: int,
        viewport: list[int],
        features: FeatureAdapter,
        alpha: float = 0.7,
        eps: float = 1e-6,
    ) -> list[int]:

        scores = {}

        for t in viewport:
            short_f = features.tile_freq_short.get((vid, t), 0)
            long_f = features.tile_freq_long.get((vid, t), 0)
        
            score = (alpha * short_f) + ((1.0 - alpha) * long_f) + eps
            scores[t] = score

        ranked = sorted(scores.keys(), key=lambda t: (-scores[t], t))
                
        return ranked
    
    def reset(self):
        
        obs, info = self.env.reset()
        self.features.reset_history()

        video_cache_index = [-1] * self.C
        tile_cache_index = [[-1] * self.k for _ in range(self.C)]

        cached_videos = random.sample(range(self.cfg.n_videos), k=self.C)
        video_cache_index = cached_videos

        # for each cached video, sample distinct tiles
        for i, _vid in enumerate(cached_videos):
            tiles = random.sample(range(self.cfg.n_tiles), k=self.k)
            tile_cache_index[i] = tiles

        self.env.mec_cache.policy.video_idx = video_cache_index
        self.env.mec_cache.policy.tile_idx = tile_cache_index
        
        self.env.mec_cache.cache_bitmap[:, :, :, :] = 0

        gop_id = 0  # default GOP for enhancement tiles
        for i, vid in enumerate(video_cache_index):
            if vid == -1:
                continue
            tiles = tile_cache_index[i][:self.k]
            
            # base layer cached for all GOPs
            self.env.mec_cache.cache_bitmap[vid, 0, :, :] = 1

            # enhancement tiles cached for GOP 0
            self.env.mec_cache.cache_bitmap[vid, 1, tiles, :] = 1
    
        # --- update feature history with cached contents ---
        for i, vid in enumerate(video_cache_index):
            if vid == -1:
                continue
            tiles = tile_cache_index[i]
            self.features.update_history(vid, tiles)
        # --- end feature update ---

        return obs, info
    
    def env_is_done(self) -> bool:
        return self.env.users_env.all_users_done()

# %%
if __name__ == "__main__":
    print("--- Starting DRL Caching System ---")

    # 2. Initialize Environment
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n_gops=cfg.n_gops,
        policy=DrlPolicy(
            capacity=int(cfg.cache_capacity), 
            cfg=cfg
        )
    )

    # Initialize User Environment
    users_env = UserRequestEvents(
        n_nodes=cfg.n_nodes,
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_gops=cfg.n_gops,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n=cfg.n,
        m=cfg.m,
        arrival_rate=cfg.arrival_rate,
        zipf_alpha=cfg.zipf_alpha
    )

    P = cfg.n_nodes; max_U = cfg.n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,  # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),    # 160 Mbps -> 20e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,  # 1 ms
        mec_fixed_delay=0.005, # 5 ms
        cloud_fixed_delay=0.1  # 100 ms
    )

    def prefetch(cache, action):
        return cache.drl_prefetching(action)
    
    env = EnvWrapper(
        n=cfg.n,
        m=cfg.m,
        n_layers=cfg.n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=cfg.theta,
        lam=cfg.lam,
        prefetch_fn=prefetch,
        max_steps=cfg.max_steps
    )

    # 3. Initialize Agent
    agent = DQNAgent(cfg)

    feature_adapter = FeatureAdapter(env, cfg)
    net_adapter = NetworkAdapter(env, feature_adapter, cfg)

    for episode in range(cfg.n_episodes):

        obs, info = net_adapter.reset()
        agent.reset_step()

        cache_hits = 0
        cache_misses = 0
        soft_hits = 0.0
        total_reward = 0.0
        avg_psnr = []
        
        for step in count():
            user_transition: Dict[int, UserTransition] = {}

            reqs_state = info['users_requests']
            
            actions = []
            action_taken = False
            cur_states = {}
            cur_actions = {}
            
            for req in reqs_state:
                u = req["u"]
                v = req["video"]
                g = req["gop"]
                tiles = req["tiles"]
                viewport = req["viewport"]
                base_req_init = req["base_req_init"]

                has_base_layer = any(
                    t.get("events", {}).get("alpha_M_u") == 1 for t in tiles
                )
                if g == 0 and not has_base_layer:
                    cur_state = net_adapter.build_observation(v)
                    action_idx, _ = agent.select_action(cur_state)

                    should_cache = (action_idx == 1)
                    if should_cache:
                        video_idx_list = env.mec_cache.policy.video_idx
                        freqs = [
                            net_adapter.features.video_freq_long.get(vid, 0) if vid != -1 else -1 for vid in video_idx_list
                        ]

                        victim_slot = np.argmin(freqs) 
                        a_idx = victim_slot + 1 
                    else:
                        a_idx = 0

                    actions.append({
                        'video': v,
                        'gop': 0,
                        'tiles': viewport,
                        'base_req_init': should_cache, 
                        'action_idx': a_idx
                    })

                    user_transition[u] = UserTransition(
                        state=cur_state,
                        action=action_idx,
                        reward=0.0
                    )
                    action_taken = True
                elif has_base_layer:
                    bitmap = env.mec_cache.get_cache_bitmap()

                    cached_tiles =  np.argwhere(bitmap[v, 1, :, 0] == 1).flatten().tolist()

                    viewport_list = list(viewport)  # ensure Python list
                    ranked_tiles = net_adapter.rank_viewport_tiles(
                        v, viewport_list + cached_tiles, net_adapter.features, alpha=0.5
                    )

                    actions.append({
                        'video': v,
                        'gop': 0,
                        'tiles': ranked_tiles[:cfg.viewport],
                        'base_req_init': False
                    })

            # --- STEP ENV ---
            obs, reward, done, info = env.step(actions)

            # --- UPDATE USER HISTORY & VIDEO POPULARITY ---
            for req in reqs_state:
                v = req["video"]
                viewport = req["viewport"]
                net_adapter.features.update_history(v, viewport)
            
            reqs_next_state = info['users_requests']
            next_req_by_user = {r["u"]: r for r in reqs_next_state}
            
            for key, user_trans in user_transition.items():
                u = key
                
                if u not in next_req_by_user:
                    continue  # user not active in next state

                v = next_req_by_user[u]["video"]
                reward = info['reward_per_user'].get(u, 0.0)

                next_state = net_adapter.build_observation(v)

                agent.remember(
                    user_trans.state,
                    user_trans.action,
                    reward,
                    next_state,
                    float(done)
                )

            agent.train_step()

            total_reward_delta, hits_delta, misses_delta, soft_hits_delta = update_metrics(info, reward)
            total_reward += total_reward_delta
            cache_hits += hits_delta
            cache_misses += misses_delta
            soft_hits += soft_hits_delta

            if net_adapter.env_is_done():
                break

            # if req:
            #     print(f"Step {step}, Request State: User {req['u']}, Video {req['video']}, GOP {req['gop']}")
            # else:
            #     print(f"Step {step}, No active user requests.")

            # print(f"Episode {episode}, Step {step}, Active users: {len(reqs_state)} Reward: {reward:.2f}, Total Reward: {total_reward:.2f}, Cache Hits: {cache_hits}, Cache Misses: {cache_misses}, Soft Hits: {soft_hits:.2f}")
            # print("----------------------------------------------------------------")

        agent.update_epsilon()

        save_training_results(
            path_=cfg.path_results,
            filename=cfg.filename,
            ep=episode,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            soft_hits=soft_hits,
            agent=agent
        )

        print(f"--- Episode {episode} completed. Total Reward: {total_reward:.2f}, Cache Hits: {cache_hits}, Cache Misses: {cache_misses}, Total Requests: {len(env.total_gop_requests_per_user)} ---")
        # for key, val in env.total_gop_requests_per_user.items():
        #     print(f"User {key}: Total GOP Requests = {val}")
# Out:
# --- Starting DRL Caching System ---
# NetworkAdapter initialized with capacity: 50 videos, 4 tiles per video
# --- Episode 0 completed. Total Reward: 40018.38, Cache Hits: 148670, Cache Misses: 168530, Total Requests: 400 ---
# --- Episode 1 completed. Total Reward: 38057.13, Cache Hits: 151089, Cache Misses: 183839, Total Requests: 400 ---
# --- Episode 2 completed. Total Reward: 45520.65, Cache Hits: 157225, Cache Misses: 168391, Total Requests: 400 ---
# --- Episode 3 completed. Total Reward: 42669.90, Cache Hits: 154969, Cache Misses: 176759, Total Requests: 400 ---
# --- Episode 4 completed. Total Reward: 40411.09, Cache Hits: 149838, Cache Misses: 194194, Total Requests: 400 ---
# --- Episode 5 completed. Total Reward: 41586.61, Cache Hits: 152390, Cache Misses: 176170, Total Requests: 400 ---
# --- Episode 6 completed. Total Reward: 45986.96, Cache Hits: 152976, Cache Misses: 189904, Total Requests: 400 ---
# --- Episode 7 completed. Total Reward: 46688.81, Cache Hits: 158570, Cache Misses: 169254, Total Requests: 400 ---
# --- Episode 8 completed. Total Reward: 43168.45, Cache Hits: 149464, Cache Misses: 182680, Total Requests: 400 ---
# --- Episode 9 completed. Total Reward: 44233.30, Cache Hits: 157181, Cache Misses: 176147, Total Requests: 400 ---
# --- Episode 10 completed. Total Reward: 46217.68, Cache Hits: 154849, Cache Misses: 169279, Total Requests: 400 ---
# --- Episode 11 completed. Total Reward: 47872.26, Cache Hits: 163498, Cache Misses: 173254, Total Requests: 400 ---
# --- Episode 12 completed. Total Reward: 48719.85, Cache Hits: 167232, Cache Misses: 176928, Total Requests: 400 ---
# --- Episode 13 completed. Total Reward: 44326.61, Cache Hits: 157314, Cache Misses: 175662, Total Requests: 400 ---
# --- Episode 14 completed. Total Reward: 45526.69, Cache Hits: 159293, Cache Misses: 171699, Total Requests: 400 ---
# --- Episode 15 completed. Total Reward: 45121.94, Cache Hits: 159985, Cache Misses: 179007, Total Requests: 400 ---
# --- Episode 16 completed. Total Reward: 42865.28, Cache Hits: 158465, Cache Misses: 175887, Total Requests: 400 ---
# --- Episode 17 completed. Total Reward: 45339.20, Cache Hits: 155809, Cache Misses: 161967, Total Requests: 400 ---
# --- Episode 18 completed. Total Reward: 45458.75, Cache Hits: 163441, Cache Misses: 176159, Total Requests: 400 ---
# --- Episode 19 completed. Total Reward: 41024.16, Cache Hits: 155660, Cache Misses: 166420, Total Requests: 400 ---
# --- Episode 20 completed. Total Reward: 44045.21, Cache Hits: 162577, Cache Misses: 166527, Total Requests: 400 ---
# --- Episode 21 completed. Total Reward: 52699.60, Cache Hits: 173534, Cache Misses: 157938, Total Requests: 400 ---
# --- Episode 22 completed. Total Reward: 40889.39, Cache Hits: 146609, Cache Misses: 161215, Total Requests: 400 ---
# --- Episode 23 completed. Total Reward: 44600.39, Cache Hits: 162728, Cache Misses: 175528, Total Requests: 400 ---
# --- Episode 24 completed. Total Reward: 40487.77, Cache Hits: 159028, Cache Misses: 164796, Total Requests: 400 ---
# --- Episode 25 completed. Total Reward: 47955.35, Cache Hits: 171908, Cache Misses: 172732, Total Requests: 400 ---
# --- Episode 26 completed. Total Reward: 45103.22, Cache Hits: 164810, Cache Misses: 168854, Total Requests: 400 ---
# --- Episode 27 completed. Total Reward: 42823.73, Cache Hits: 157528, Cache Misses: 166728, Total Requests: 400 ---
# --- Episode 28 completed. Total Reward: 45285.35, Cache Hits: 168360, Cache Misses: 164264, Total Requests: 400 ---
# --- Episode 29 completed. Total Reward: 45385.21, Cache Hits: 159509, Cache Misses: 163403, Total Requests: 400 ---
# --- Episode 30 completed. Total Reward: 51094.05, Cache Hits: 170501, Cache Misses: 164395, Total Requests: 400 ---
# --- Episode 31 completed. Total Reward: 47867.18, Cache Hits: 161444, Cache Misses: 158604, Total Requests: 400 ---
# --- Episode 32 completed. Total Reward: 46269.63, Cache Hits: 165959, Cache Misses: 165081, Total Requests: 400 ---
# --- Episode 33 completed. Total Reward: 50980.13, Cache Hits: 176455, Cache Misses: 161049, Total Requests: 400 ---
# --- Episode 34 completed. Total Reward: 54968.94, Cache Hits: 175187, Cache Misses: 172605, Total Requests: 400 ---
# --- Episode 35 completed. Total Reward: 54529.17, Cache Hits: 171863, Cache Misses: 160857, Total Requests: 400 ---
# --- Episode 36 completed. Total Reward: 45328.84, Cache Hits: 171370, Cache Misses: 172438, Total Requests: 400 ---
# --- Episode 37 completed. Total Reward: 51610.09, Cache Hits: 172812, Cache Misses: 163764, Total Requests: 400 ---
# --- Episode 38 completed. Total Reward: 47338.36, Cache Hits: 170931, Cache Misses: 165117, Total Requests: 400 ---
# --- Episode 39 completed. Total Reward: 48634.59, Cache Hits: 173166, Cache Misses: 158562, Total Requests: 400 ---
# --- Episode 40 completed. Total Reward: 47728.94, Cache Hits: 170036, Cache Misses: 165708, Total Requests: 400 ---
# --- Episode 41 completed. Total Reward: 46935.17, Cache Hits: 168660, Cache Misses: 159564, Total Requests: 400 ---
# --- Episode 42 completed. Total Reward: 46791.77, Cache Hits: 159506, Cache Misses: 161918, Total Requests: 400 ---
# --- Episode 43 completed. Total Reward: 45854.34, Cache Hits: 165352, Cache Misses: 168712, Total Requests: 400 ---
# --- Episode 44 completed. Total Reward: 48794.85, Cache Hits: 160100, Cache Misses: 155228, Total Requests: 400 ---
# --- Episode 45 completed. Total Reward: 48707.97, Cache Hits: 175710, Cache Misses: 157554, Total Requests: 400 ---
# --- Episode 46 completed. Total Reward: 50903.36, Cache Hits: 168171, Cache Misses: 148661, Total Requests: 400 ---
# --- Episode 47 completed. Total Reward: 50491.06, Cache Hits: 173560, Cache Misses: 169288, Total Requests: 400 ---
# --- Episode 48 completed. Total Reward: 48058.80, Cache Hits: 163734, Cache Misses: 158970, Total Requests: 400 ---
# --- Episode 49 completed. Total Reward: 48332.20, Cache Hits: 172209, Cache Misses: 158639, Total Requests: 400 ---
# --- Episode 50 completed. Total Reward: 45972.52, Cache Hits: 172420, Cache Misses: 160268, Total Requests: 400 ---
# --- Episode 51 completed. Total Reward: 54413.90, Cache Hits: 169954, Cache Misses: 155550, Total Requests: 400 ---
# --- Episode 52 completed. Total Reward: 44493.22, Cache Hits: 174837, Cache Misses: 155419, Total Requests: 400 ---
# --- Episode 53 completed. Total Reward: 48746.11, Cache Hits: 174548, Cache Misses: 150924, Total Requests: 400 ---
# --- Episode 54 completed. Total Reward: 48803.37, Cache Hits: 169804, Cache Misses: 152276, Total Requests: 400 ---
# --- Episode 55 completed. Total Reward: 52352.47, Cache Hits: 176565, Cache Misses: 151835, Total Requests: 400 ---
# --- Episode 56 completed. Total Reward: 48534.26, Cache Hits: 170346, Cache Misses: 173446, Total Requests: 400 ---
# --- Episode 57 completed. Total Reward: 51653.84, Cache Hits: 171719, Cache Misses: 148393, Total Requests: 400 ---
# --- Episode 58 completed. Total Reward: 52348.53, Cache Hits: 171011, Cache Misses: 150813, Total Requests: 400 ---
# --- Episode 59 completed. Total Reward: 53774.67, Cache Hits: 171807, Cache Misses: 141713, Total Requests: 400 ---
# --- Episode 60 completed. Total Reward: 54304.40, Cache Hits: 181525, Cache Misses: 153035, Total Requests: 400 ---
# --- Episode 61 completed. Total Reward: 51689.30, Cache Hits: 182020, Cache Misses: 157628, Total Requests: 400 ---
# --- Episode 62 completed. Total Reward: 50155.91, Cache Hits: 177562, Cache Misses: 152518, Total Requests: 400 ---
# --- Episode 63 completed. Total Reward: 47569.05, Cache Hits: 164958, Cache Misses: 167842, Total Requests: 400 ---
# --- Episode 64 completed. Total Reward: 52061.49, Cache Hits: 177416, Cache Misses: 148936, Total Requests: 400 ---
# --- Episode 65 completed. Total Reward: 49570.34, Cache Hits: 168929, Cache Misses: 154607, Total Requests: 400 ---
# --- Episode 66 completed. Total Reward: 49344.38, Cache Hits: 181385, Cache Misses: 162967, Total Requests: 400 ---
# --- Episode 67 completed. Total Reward: 47919.29, Cache Hits: 175848, Cache Misses: 159784, Total Requests: 400 ---
# --- Episode 68 completed. Total Reward: 48658.76, Cache Hits: 179930, Cache Misses: 151702, Total Requests: 400 ---
# --- Episode 69 completed. Total Reward: 47889.96, Cache Hits: 168837, Cache Misses: 162667, Total Requests: 400 ---
# --- Episode 70 completed. Total Reward: 50417.74, Cache Hits: 176468, Cache Misses: 155324, Total Requests: 400 ---
# --- Episode 71 completed. Total Reward: 51389.32, Cache Hits: 174372, Cache Misses: 145548, Total Requests: 400 ---
# --- Episode 72 completed. Total Reward: 57823.82, Cache Hits: 169905, Cache Misses: 150799, Total Requests: 400 ---
# --- Episode 73 completed. Total Reward: 53865.55, Cache Hits: 184466, Cache Misses: 147454, Total Requests: 400 ---
# --- Episode 74 completed. Total Reward: 55318.61, Cache Hits: 182985, Cache Misses: 154743, Total Requests: 400 ---
# --- Episode 75 completed. Total Reward: 53338.63, Cache Hits: 182609, Cache Misses: 145311, Total Requests: 400 ---
# --- Episode 76 completed. Total Reward: 49203.34, Cache Hits: 181776, Cache Misses: 152032, Total Requests: 400 ---
# --- Episode 77 completed. Total Reward: 53250.24, Cache Hits: 172922, Cache Misses: 156406, Total Requests: 400 ---
# --- Episode 78 completed. Total Reward: 49386.36, Cache Hits: 177501, Cache Misses: 162323, Total Requests: 400 ---
# --- Episode 79 completed. Total Reward: 56619.25, Cache Hits: 177457, Cache Misses: 145407, Total Requests: 400 ---
# --- Episode 80 completed. Total Reward: 57298.21, Cache Hits: 189472, Cache Misses: 152912, Total Requests: 400 ---
# --- Episode 81 completed. Total Reward: 52559.40, Cache Hits: 188819, Cache Misses: 152925, Total Requests: 400 ---
# --- Episode 82 completed. Total Reward: 49451.42, Cache Hits: 180777, Cache Misses: 156503, Total Requests: 400 ---
# --- Episode 83 completed. Total Reward: 59247.18, Cache Hits: 186218, Cache Misses: 145046, Total Requests: 400 ---
# --- Episode 84 completed. Total Reward: 59011.15, Cache Hits: 175817, Cache Misses: 138919, Total Requests: 400 ---
# --- Episode 85 completed. Total Reward: 46580.09, Cache Hits: 174340, Cache Misses: 144828, Total Requests: 400 ---
# --- Episode 86 completed. Total Reward: 49861.25, Cache Hits: 180134, Cache Misses: 153898, Total Requests: 400 ---
# --- Episode 87 completed. Total Reward: 49338.91, Cache Hits: 181894, Cache Misses: 141946, Total Requests: 400 ---
# --- Episode 88 completed. Total Reward: 45727.05, Cache Hits: 171402, Cache Misses: 157158, Total Requests: 400 ---
# --- Episode 89 completed. Total Reward: 55086.13, Cache Hits: 186394, Cache Misses: 146950, Total Requests: 400 ---
# --- Episode 90 completed. Total Reward: 48303.40, Cache Hits: 182906, Cache Misses: 159142, Total Requests: 400 ---
# --- Episode 91 completed. Total Reward: 52209.09, Cache Hits: 179084, Cache Misses: 146052, Total Requests: 400 ---
# --- Episode 92 completed. Total Reward: 53987.07, Cache Hits: 187527, Cache Misses: 142073, Total Requests: 400 ---
# --- Episode 93 completed. Total Reward: 54331.08, Cache Hits: 178319, Cache Misses: 142689, Total Requests: 400 ---
# --- Episode 94 completed. Total Reward: 55089.26, Cache Hits: 188361, Cache Misses: 150903, Total Requests: 400 ---
# --- Episode 95 completed. Total Reward: 53491.00, Cache Hits: 188186, Cache Misses: 140182, Total Requests: 400 ---
# --- Episode 96 completed. Total Reward: 53094.99, Cache Hits: 177911, Cache Misses: 142841, Total Requests: 400 ---
# --- Episode 97 completed. Total Reward: 53133.38, Cache Hits: 183147, Cache Misses: 141765, Total Requests: 400 ---
# --- Episode 98 completed. Total Reward: 50006.87, Cache Hits: 175384, Cache Misses: 145752, Total Requests: 400 ---
# --- Episode 99 completed. Total Reward: 54521.87, Cache Hits: 184517, Cache Misses: 144811, Total Requests: 400 ---
# --- Episode 100 completed. Total Reward: 56002.64, Cache Hits: 179878, Cache Misses: 141562, Total Requests: 400 ---
# --- Episode 101 completed. Total Reward: 54964.02, Cache Hits: 201576, Cache Misses: 151096, Total Requests: 400 ---
# --- Episode 102 completed. Total Reward: 60475.62, Cache Hits: 194933, Cache Misses: 142827, Total Requests: 400 ---
# --- Episode 103 completed. Total Reward: 50602.09, Cache Hits: 186898, Cache Misses: 142190, Total Requests: 400 ---
# --- Episode 104 completed. Total Reward: 54406.86, Cache Hits: 185439, Cache Misses: 141185, Total Requests: 400 ---
# --- Episode 105 completed. Total Reward: 45473.13, Cache Hits: 196948, Cache Misses: 159436, Total Requests: 400 ---
# --- Episode 106 completed. Total Reward: 53342.59, Cache Hits: 191318, Cache Misses: 148058, Total Requests: 400 ---
# --- Episode 107 completed. Total Reward: 56400.61, Cache Hits: 182684, Cache Misses: 159732, Total Requests: 400 ---
# --- Episode 108 completed. Total Reward: 51983.03, Cache Hits: 185600, Cache Misses: 143216, Total Requests: 400 ---
# --- Episode 109 completed. Total Reward: 52520.45, Cache Hits: 185355, Cache Misses: 147125, Total Requests: 400 ---
# --- Episode 110 completed. Total Reward: 53788.54, Cache Hits: 179875, Cache Misses: 141437, Total Requests: 400 ---
# --- Episode 111 completed. Total Reward: 54717.70, Cache Hits: 182957, Cache Misses: 148147, Total Requests: 400 ---
# --- Episode 112 completed. Total Reward: 52422.15, Cache Hits: 189173, Cache Misses: 144763, Total Requests: 400 ---
# --- Episode 113 completed. Total Reward: 49740.31, Cache Hits: 180701, Cache Misses: 144787, Total Requests: 400 ---
# --- Episode 114 completed. Total Reward: 55735.41, Cache Hits: 186638, Cache Misses: 134098, Total Requests: 400 ---
# --- Episode 115 completed. Total Reward: 55286.35, Cache Hits: 177314, Cache Misses: 136238, Total Requests: 400 ---
# --- Episode 116 completed. Total Reward: 52062.48, Cache Hits: 192942, Cache Misses: 150402, Total Requests: 400 ---
# --- Episode 117 completed. Total Reward: 56406.93, Cache Hits: 189012, Cache Misses: 139772, Total Requests: 400 ---
# --- Episode 118 completed. Total Reward: 54810.79, Cache Hits: 195366, Cache Misses: 143210, Total Requests: 400 ---
# --- Episode 119 completed. Total Reward: 51506.42, Cache Hits: 197354, Cache Misses: 142454, Total Requests: 400 ---
# --- Episode 120 completed. Total Reward: 54391.27, Cache Hits: 198755, Cache Misses: 145597, Total Requests: 400 ---
# --- Episode 121 completed. Total Reward: 51891.63, Cache Hits: 190204, Cache Misses: 142900, Total Requests: 400 ---
# --- Episode 122 completed. Total Reward: 55191.58, Cache Hits: 201472, Cache Misses: 138672, Total Requests: 400 ---
# --- Episode 123 completed. Total Reward: 55519.53, Cache Hits: 190234, Cache Misses: 146198, Total Requests: 400 ---
# --- Episode 124 completed. Total Reward: 56517.99, Cache Hits: 188628, Cache Misses: 135564, Total Requests: 400 ---
# --- Episode 125 completed. Total Reward: 57343.65, Cache Hits: 188783, Cache Misses: 138113, Total Requests: 400 ---
# --- Episode 126 completed. Total Reward: 53034.34, Cache Hits: 190983, Cache Misses: 154761, Total Requests: 400 ---
# --- Episode 127 completed. Total Reward: 59702.12, Cache Hits: 195115, Cache Misses: 133221, Total Requests: 400 ---
# --- Episode 128 completed. Total Reward: 51013.18, Cache Hits: 198488, Cache Misses: 146104, Total Requests: 400 ---
# --- Episode 129 completed. Total Reward: 52498.84, Cache Hits: 192381, Cache Misses: 139155, Total Requests: 400 ---
# --- Episode 130 completed. Total Reward: 57824.03, Cache Hits: 192221, Cache Misses: 141955, Total Requests: 400 ---
# --- Episode 131 completed. Total Reward: 58701.39, Cache Hits: 198407, Cache Misses: 143737, Total Requests: 400 ---
# --- Episode 132 completed. Total Reward: 53074.87, Cache Hits: 186634, Cache Misses: 130310, Total Requests: 400 ---
# --- Episode 133 completed. Total Reward: 55048.16, Cache Hits: 191343, Cache Misses: 143521, Total Requests: 400 ---
# --- Episode 134 completed. Total Reward: 59117.87, Cache Hits: 202348, Cache Misses: 142372, Total Requests: 400 ---
# --- Episode 135 completed. Total Reward: 56155.23, Cache Hits: 201418, Cache Misses: 143702, Total Requests: 400 ---
# --- Episode 136 completed. Total Reward: 55622.29, Cache Hits: 186976, Cache Misses: 140832, Total Requests: 400 ---
# --- Episode 137 completed. Total Reward: 56912.16, Cache Hits: 188564, Cache Misses: 138044, Total Requests: 400 ---
# --- Episode 138 completed. Total Reward: 58098.92, Cache Hits: 195446, Cache Misses: 129866, Total Requests: 400 ---
# --- Episode 139 completed. Total Reward: 59473.23, Cache Hits: 199421, Cache Misses: 136835, Total Requests: 400 ---
# --- Episode 140 completed. Total Reward: 51617.61, Cache Hits: 187698, Cache Misses: 136542, Total Requests: 400 ---
# --- Episode 141 completed. Total Reward: 53843.24, Cache Hits: 192081, Cache Misses: 136271, Total Requests: 400 ---
# --- Episode 142 completed. Total Reward: 51908.75, Cache Hits: 187139, Cache Misses: 140621, Total Requests: 400 ---
# --- Episode 143 completed. Total Reward: 56948.58, Cache Hits: 201625, Cache Misses: 139735, Total Requests: 400 ---
# --- Episode 144 completed. Total Reward: 55518.66, Cache Hits: 189319, Cache Misses: 143881, Total Requests: 400 ---
# --- Episode 145 completed. Total Reward: 52879.76, Cache Hits: 196247, Cache Misses: 139177, Total Requests: 400 ---
# --- Episode 146 completed. Total Reward: 54946.01, Cache Hits: 191477, Cache Misses: 144027, Total Requests: 400 ---
# --- Episode 147 completed. Total Reward: 54661.53, Cache Hits: 193114, Cache Misses: 145878, Total Requests: 400 ---
# --- Episode 148 completed. Total Reward: 58081.72, Cache Hits: 204280, Cache Misses: 140696, Total Requests: 400 ---
# --- Episode 149 completed. Total Reward: 55445.07, Cache Hits: 190751, Cache Misses: 140993, Total Requests: 400 ---
# --- Episode 150 completed. Total Reward: 52442.45, Cache Hits: 195728, Cache Misses: 137872, Total Requests: 400 ---
# --- Episode 151 completed. Total Reward: 51642.57, Cache Hits: 201930, Cache Misses: 138534, Total Requests: 400 ---
# --- Episode 152 completed. Total Reward: 51206.04, Cache Hits: 193136, Cache Misses: 140544, Total Requests: 400 ---
# --- Episode 153 completed. Total Reward: 56867.96, Cache Hits: 196223, Cache Misses: 133121, Total Requests: 400 ---
# --- Episode 154 completed. Total Reward: 52534.05, Cache Hits: 193925, Cache Misses: 136587, Total Requests: 400 ---
# --- Episode 155 completed. Total Reward: 52135.67, Cache Hits: 197077, Cache Misses: 131883, Total Requests: 400 ---
# --- Episode 156 completed. Total Reward: 56235.93, Cache Hits: 192031, Cache Misses: 134769, Total Requests: 400 ---
# --- Episode 157 completed. Total Reward: 62453.05, Cache Hits: 208395, Cache Misses: 134021, Total Requests: 400 ---
# --- Episode 158 completed. Total Reward: 57464.96, Cache Hits: 208540, Cache Misses: 140756, Total Requests: 400 ---
# --- Episode 159 completed. Total Reward: 55309.87, Cache Hits: 200896, Cache Misses: 143632, Total Requests: 400 ---
# --- Episode 160 completed. Total Reward: 56543.78, Cache Hits: 201310, Cache Misses: 133010, Total Requests: 400 ---
# --- Episode 161 completed. Total Reward: 55863.45, Cache Hits: 195336, Cache Misses: 134936, Total Requests: 400 ---
# --- Episode 162 completed. Total Reward: 55978.71, Cache Hits: 190867, Cache Misses: 137997, Total Requests: 400 ---
# --- Episode 163 completed. Total Reward: 55443.27, Cache Hits: 193882, Cache Misses: 133750, Total Requests: 400 ---
# --- Episode 164 completed. Total Reward: 49336.97, Cache Hits: 192956, Cache Misses: 138836, Total Requests: 400 ---
# --- Episode 165 completed. Total Reward: 53497.84, Cache Hits: 197928, Cache Misses: 143000, Total Requests: 400 ---
# --- Episode 166 completed. Total Reward: 51046.63, Cache Hits: 190339, Cache Misses: 146109, Total Requests: 400 ---
# --- Episode 167 completed. Total Reward: 59008.54, Cache Hits: 193985, Cache Misses: 130767, Total Requests: 400 ---
# --- Episode 168 completed. Total Reward: 66262.16, Cache Hits: 210536, Cache Misses: 139336, Total Requests: 400 ---
# --- Episode 169 completed. Total Reward: 62794.38, Cache Hits: 205812, Cache Misses: 132764, Total Requests: 400 ---
# --- Episode 170 completed. Total Reward: 59473.21, Cache Hits: 201106, Cache Misses: 130206, Total Requests: 400 ---
# --- Episode 171 completed. Total Reward: 59135.37, Cache Hits: 203053, Cache Misses: 132003, Total Requests: 400 ---
# --- Episode 172 completed. Total Reward: 59894.45, Cache Hits: 204516, Cache Misses: 130524, Total Requests: 400 ---
# --- Episode 173 completed. Total Reward: 55914.17, Cache Hits: 203931, Cache Misses: 137029, Total Requests: 400 ---
# --- Episode 174 completed. Total Reward: 61030.70, Cache Hits: 204133, Cache Misses: 133675, Total Requests: 400 ---
# --- Episode 175 completed. Total Reward: 58366.19, Cache Hits: 207719, Cache Misses: 130841, Total Requests: 400 ---
# --- Episode 176 completed. Total Reward: 52930.05, Cache Hits: 196561, Cache Misses: 133231, Total Requests: 400 ---
# --- Episode 177 completed. Total Reward: 55563.33, Cache Hits: 194018, Cache Misses: 132910, Total Requests: 400 ---
# --- Episode 178 completed. Total Reward: 54289.98, Cache Hits: 204911, Cache Misses: 132465, Total Requests: 400 ---
# --- Episode 179 completed. Total Reward: 58897.04, Cache Hits: 197468, Cache Misses: 129844, Total Requests: 400 ---
# --- Episode 180 completed. Total Reward: 61289.52, Cache Hits: 196232, Cache Misses: 132584, Total Requests: 400 ---
# --- Episode 181 completed. Total Reward: 55764.59, Cache Hits: 198204, Cache Misses: 133348, Total Requests: 400 ---
# --- Episode 182 completed. Total Reward: 53106.32, Cache Hits: 197861, Cache Misses: 138699, Total Requests: 400 ---
# --- Episode 183 completed. Total Reward: 54958.64, Cache Hits: 193869, Cache Misses: 127651, Total Requests: 400 ---
# --- Episode 184 completed. Total Reward: 56047.99, Cache Hits: 194877, Cache Misses: 125395, Total Requests: 400 ---
# --- Episode 185 completed. Total Reward: 65505.56, Cache Hits: 208256, Cache Misses: 133472, Total Requests: 400 ---
# --- Episode 186 completed. Total Reward: 61149.09, Cache Hits: 196330, Cache Misses: 119766, Total Requests: 400 ---
# --- Episode 187 completed. Total Reward: 54623.19, Cache Hits: 190494, Cache Misses: 131074, Total Requests: 400 ---
# --- Episode 188 completed. Total Reward: 63377.00, Cache Hits: 205070, Cache Misses: 129938, Total Requests: 400 ---
# --- Episode 189 completed. Total Reward: 54605.64, Cache Hits: 211346, Cache Misses: 137390, Total Requests: 400 ---
# --- Episode 190 completed. Total Reward: 55822.32, Cache Hits: 194796, Cache Misses: 123876, Total Requests: 400 ---
# --- Episode 191 completed. Total Reward: 58523.71, Cache Hits: 201744, Cache Misses: 131984, Total Requests: 400 ---
# --- Episode 192 completed. Total Reward: 54674.05, Cache Hits: 194143, Cache Misses: 127377, Total Requests: 400 ---
# --- Episode 193 completed. Total Reward: 63481.53, Cache Hits: 202822, Cache Misses: 139610, Total Requests: 400 ---
# --- Episode 194 completed. Total Reward: 54432.58, Cache Hits: 196433, Cache Misses: 128287, Total Requests: 400 ---
# --- Episode 195 completed. Total Reward: 55842.26, Cache Hits: 207841, Cache Misses: 133599, Total Requests: 400 ---
# --- Episode 196 completed. Total Reward: 61129.94, Cache Hits: 208279, Cache Misses: 142121, Total Requests: 400 ---
# --- Episode 197 completed. Total Reward: 53209.76, Cache Hits: 196272, Cache Misses: 123792, Total Requests: 400 ---
# --- Episode 198 completed. Total Reward: 56898.70, Cache Hits: 193319, Cache Misses: 134537, Total Requests: 400 ---
# --- Episode 199 completed. Total Reward: 55819.47, Cache Hits: 192189, Cache Misses: 129267, Total Requests: 400 ---
# --- Episode 200 completed. Total Reward: 55197.40, Cache Hits: 206706, Cache Misses: 128110, Total Requests: 400 ---
# --- Episode 201 completed. Total Reward: 50287.43, Cache Hits: 198880, Cache Misses: 139744, Total Requests: 400 ---
# --- Episode 202 completed. Total Reward: 56881.66, Cache Hits: 202051, Cache Misses: 138589, Total Requests: 400 ---
# --- Episode 203 completed. Total Reward: 59940.08, Cache Hits: 212312, Cache Misses: 129160, Total Requests: 400 ---
# --- Episode 204 completed. Total Reward: 58371.60, Cache Hits: 200578, Cache Misses: 126318, Total Requests: 400 ---
# --- Episode 205 completed. Total Reward: 56970.56, Cache Hits: 199398, Cache Misses: 129866, Total Requests: 400 ---
# --- Episode 206 completed. Total Reward: 59769.17, Cache Hits: 195580, Cache Misses: 125220, Total Requests: 400 ---
# --- Episode 207 completed. Total Reward: 58510.10, Cache Hits: 194543, Cache Misses: 125457, Total Requests: 400 ---
# --- Episode 208 completed. Total Reward: 59684.98, Cache Hits: 215959, Cache Misses: 129945, Total Requests: 400 ---
# --- Episode 209 completed. Total Reward: 50777.22, Cache Hits: 198715, Cache Misses: 132885, Total Requests: 400 ---
# --- Episode 210 completed. Total Reward: 62572.00, Cache Hits: 197051, Cache Misses: 121333, Total Requests: 400 ---
# --- Episode 211 completed. Total Reward: 58629.35, Cache Hits: 204400, Cache Misses: 125920, Total Requests: 400 ---
# --- Episode 212 completed. Total Reward: 57573.71, Cache Hits: 200291, Cache Misses: 125181, Total Requests: 400 ---
# --- Episode 213 completed. Total Reward: 60138.41, Cache Hits: 211030, Cache Misses: 126170, Total Requests: 400 ---
# --- Episode 214 completed. Total Reward: 59318.97, Cache Hits: 214025, Cache Misses: 128727, Total Requests: 400 ---
# --- Episode 215 completed. Total Reward: 60395.76, Cache Hits: 201714, Cache Misses: 125278, Total Requests: 400 ---
# --- Episode 216 completed. Total Reward: 55471.49, Cache Hits: 208615, Cache Misses: 132473, Total Requests: 400 ---
# --- Episode 217 completed. Total Reward: 62500.42, Cache Hits: 196005, Cache Misses: 128459, Total Requests: 400 ---
# --- Episode 218 completed. Total Reward: 59771.86, Cache Hits: 196188, Cache Misses: 121236, Total Requests: 400 ---
# --- Episode 219 completed. Total Reward: 61477.37, Cache Hits: 217129, Cache Misses: 123495, Total Requests: 400 ---
# --- Episode 220 completed. Total Reward: 60254.98, Cache Hits: 208073, Cache Misses: 133079, Total Requests: 400 ---
# --- Episode 221 completed. Total Reward: 54488.28, Cache Hits: 203394, Cache Misses: 135230, Total Requests: 400 ---
# --- Episode 222 completed. Total Reward: 58929.15, Cache Hits: 211134, Cache Misses: 129682, Total Requests: 400 ---
# --- Episode 223 completed. Total Reward: 56549.01, Cache Hits: 203257, Cache Misses: 130359, Total Requests: 400 ---
# --- Episode 224 completed. Total Reward: 61453.29, Cache Hits: 209258, Cache Misses: 133254, Total Requests: 400 ---
# --- Episode 225 completed. Total Reward: 54348.85, Cache Hits: 194210, Cache Misses: 140142, Total Requests: 400 ---
# --- Episode 226 completed. Total Reward: 61908.49, Cache Hits: 209737, Cache Misses: 125575, Total Requests: 400 ---
# --- Episode 227 completed. Total Reward: 59122.49, Cache Hits: 201449, Cache Misses: 124375, Total Requests: 400 ---
# --- Episode 228 completed. Total Reward: 66932.98, Cache Hits: 203997, Cache Misses: 119171, Total Requests: 400 ---
# --- Episode 229 completed. Total Reward: 50688.30, Cache Hits: 199182, Cache Misses: 139506, Total Requests: 400 ---
# --- Episode 230 completed. Total Reward: 61493.53, Cache Hits: 206880, Cache Misses: 125712, Total Requests: 400 ---
# --- Episode 231 completed. Total Reward: 59758.78, Cache Hits: 213742, Cache Misses: 133362, Total Requests: 400 ---
# --- Episode 232 completed. Total Reward: 55312.89, Cache Hits: 196843, Cache Misses: 132949, Total Requests: 400 ---
# --- Episode 233 completed. Total Reward: 57151.56, Cache Hits: 202164, Cache Misses: 127148, Total Requests: 400 ---
# --- Episode 234 completed. Total Reward: 62657.87, Cache Hits: 201276, Cache Misses: 122548, Total Requests: 400 ---
# --- Episode 235 completed. Total Reward: 57520.50, Cache Hits: 194186, Cache Misses: 124902, Total Requests: 400 ---
# --- Episode 236 completed. Total Reward: 61410.38, Cache Hits: 198054, Cache Misses: 121690, Total Requests: 400 ---
# --- Episode 237 completed. Total Reward: 59933.08, Cache Hits: 207940, Cache Misses: 130876, Total Requests: 400 ---
# --- Episode 238 completed. Total Reward: 56583.72, Cache Hits: 203499, Cache Misses: 132437, Total Requests: 400 ---
# --- Episode 239 completed. Total Reward: 61871.28, Cache Hits: 207375, Cache Misses: 118961, Total Requests: 400 ---
# --- Episode 240 completed. Total Reward: 60611.78, Cache Hits: 210246, Cache Misses: 122362, Total Requests: 400 ---
# --- Episode 241 completed. Total Reward: 57423.49, Cache Hits: 197717, Cache Misses: 135291, Total Requests: 400 ---
# --- Episode 242 completed. Total Reward: 61574.98, Cache Hits: 196240, Cache Misses: 122256, Total Requests: 400 ---
# --- Episode 243 completed. Total Reward: 60221.48, Cache Hits: 208969, Cache Misses: 128775, Total Requests: 400 ---
# --- Episode 244 completed. Total Reward: 56925.26, Cache Hits: 199527, Cache Misses: 128249, Total Requests: 400 ---
# --- Episode 245 completed. Total Reward: 51837.33, Cache Hits: 202842, Cache Misses: 118662, Total Requests: 400 ---
# --- Episode 246 completed. Total Reward: 58791.88, Cache Hits: 193730, Cache Misses: 123966, Total Requests: 400 ---
# --- Episode 247 completed. Total Reward: 61413.47, Cache Hits: 198882, Cache Misses: 122446, Total Requests: 400 ---
# --- Episode 248 completed. Total Reward: 58764.72, Cache Hits: 209317, Cache Misses: 120283, Total Requests: 400 ---
# --- Episode 249 completed. Total Reward: 56317.18, Cache Hits: 213292, Cache Misses: 126388, Total Requests: 400 ---
# --- Episode 250 completed. Total Reward: 58178.70, Cache Hits: 210743, Cache Misses: 134777, Total Requests: 400 ---
# --- Episode 251 completed. Total Reward: 62071.65, Cache Hits: 203981, Cache Misses: 131027, Total Requests: 400 ---
# --- Episode 252 completed. Total Reward: 56066.60, Cache Hits: 213825, Cache Misses: 128591, Total Requests: 400 ---
# --- Episode 253 completed. Total Reward: 61295.21, Cache Hits: 188550, Cache Misses: 120154, Total Requests: 400 ---
# --- Episode 254 completed. Total Reward: 63108.39, Cache Hits: 206845, Cache Misses: 123283, Total Requests: 400 ---
# --- Episode 255 completed. Total Reward: 60247.11, Cache Hits: 193628, Cache Misses: 125780, Total Requests: 400 ---
# --- Episode 256 completed. Total Reward: 57853.97, Cache Hits: 204653, Cache Misses: 121635, Total Requests: 400 ---
# --- Episode 257 completed. Total Reward: 62712.72, Cache Hits: 214324, Cache Misses: 128652, Total Requests: 400 ---
# --- Episode 258 completed. Total Reward: 59498.61, Cache Hits: 203518, Cache Misses: 121410, Total Requests: 400 ---
# --- Episode 259 completed. Total Reward: 55145.05, Cache Hits: 214623, Cache Misses: 128529, Total Requests: 400 ---
# --- Episode 260 completed. Total Reward: 57303.53, Cache Hits: 209456, Cache Misses: 122528, Total Requests: 400 ---
# --- Episode 261 completed. Total Reward: 62660.13, Cache Hits: 201338, Cache Misses: 123654, Total Requests: 400 ---
# --- Episode 262 completed. Total Reward: 59747.36, Cache Hits: 215966, Cache Misses: 130498, Total Requests: 400 ---
# --- Episode 263 completed. Total Reward: 59872.58, Cache Hits: 208239, Cache Misses: 122161, Total Requests: 400 ---
# --- Episode 264 completed. Total Reward: 64436.63, Cache Hits: 210609, Cache Misses: 115871, Total Requests: 400 ---
# --- Episode 265 completed. Total Reward: 63521.69, Cache Hits: 209623, Cache Misses: 128393, Total Requests: 400 ---
# --- Episode 266 completed. Total Reward: 59158.53, Cache Hits: 202465, Cache Misses: 122927, Total Requests: 400 ---
# --- Episode 267 completed. Total Reward: 61490.25, Cache Hits: 220515, Cache Misses: 129213, Total Requests: 400 ---
# --- Episode 268 completed. Total Reward: 62359.19, Cache Hits: 210735, Cache Misses: 126289, Total Requests: 400 ---
# --- Episode 269 completed. Total Reward: 66069.27, Cache Hits: 211584, Cache Misses: 123408, Total Requests: 400 ---
# --- Episode 270 completed. Total Reward: 63408.17, Cache Hits: 208981, Cache Misses: 119131, Total Requests: 400 ---
# --- Episode 271 completed. Total Reward: 62501.54, Cache Hits: 202145, Cache Misses: 124399, Total Requests: 400 ---
# --- Episode 272 completed. Total Reward: 53932.55, Cache Hits: 201326, Cache Misses: 121570, Total Requests: 400 ---
# --- Episode 273 completed. Total Reward: 57857.94, Cache Hits: 212965, Cache Misses: 123563, Total Requests: 400 ---
# --- Episode 274 completed. Total Reward: 58960.89, Cache Hits: 202561, Cache Misses: 118863, Total Requests: 400 ---
# --- Episode 275 completed. Total Reward: 61041.65, Cache Hits: 206912, Cache Misses: 116672, Total Requests: 400 ---
# --- Episode 276 completed. Total Reward: 68050.37, Cache Hits: 214761, Cache Misses: 126023, Total Requests: 400 ---
# --- Episode 277 completed. Total Reward: 63200.18, Cache Hits: 209036, Cache Misses: 125764, Total Requests: 400 ---
# --- Episode 278 completed. Total Reward: 56291.70, Cache Hits: 206605, Cache Misses: 131539, Total Requests: 400 ---
# --- Episode 279 completed. Total Reward: 68376.08, Cache Hits: 211609, Cache Misses: 121799, Total Requests: 400 ---
# --- Episode 280 completed. Total Reward: 59009.91, Cache Hits: 210774, Cache Misses: 126602, Total Requests: 400 ---
# --- Episode 281 completed. Total Reward: 64044.22, Cache Hits: 211439, Cache Misses: 120049, Total Requests: 400 ---
# --- Episode 282 completed. Total Reward: 58755.93, Cache Hits: 218087, Cache Misses: 124201, Total Requests: 400 ---
# --- Episode 283 completed. Total Reward: 58389.18, Cache Hits: 205210, Cache Misses: 119798, Total Requests: 400 ---
# --- Episode 284 completed. Total Reward: 60141.62, Cache Hits: 210901, Cache Misses: 115803, Total Requests: 400 ---
# --- Episode 285 completed. Total Reward: 63492.22, Cache Hits: 200872, Cache Misses: 121640, Total Requests: 400 ---
# --- Episode 286 completed. Total Reward: 61074.97, Cache Hits: 209576, Cache Misses: 121480, Total Requests: 400 ---
# --- Episode 287 completed. Total Reward: 55644.08, Cache Hits: 210768, Cache Misses: 122672, Total Requests: 400 ---
# --- Episode 288 completed. Total Reward: 62020.58, Cache Hits: 205112, Cache Misses: 123512, Total Requests: 400 ---
# --- Episode 289 completed. Total Reward: 57961.26, Cache Hits: 195878, Cache Misses: 115066, Total Requests: 400 ---
# --- Episode 290 completed. Total Reward: 59939.00, Cache Hits: 210734, Cache Misses: 127554, Total Requests: 400 ---
# --- Episode 291 completed. Total Reward: 58265.32, Cache Hits: 208493, Cache Misses: 121667, Total Requests: 400 ---
# --- Episode 292 completed. Total Reward: 57648.66, Cache Hits: 223362, Cache Misses: 135374, Total Requests: 400 ---
# --- Episode 293 completed. Total Reward: 57351.40, Cache Hits: 207881, Cache Misses: 126439, Total Requests: 400 ---
# --- Episode 294 completed. Total Reward: 54323.47, Cache Hits: 208090, Cache Misses: 126422, Total Requests: 400 ---
# --- Episode 295 completed. Total Reward: 54033.05, Cache Hits: 206805, Cache Misses: 132699, Total Requests: 400 ---
# --- Episode 296 completed. Total Reward: 66630.89, Cache Hits: 208008, Cache Misses: 121176, Total Requests: 400 ---
# --- Episode 297 completed. Total Reward: 54715.85, Cache Hits: 211080, Cache Misses: 125272, Total Requests: 400 ---
# --- Episode 298 completed. Total Reward: 58954.36, Cache Hits: 205260, Cache Misses: 119172, Total Requests: 400 ---
# --- Episode 299 completed. Total Reward: 62079.44, Cache Hits: 209827, Cache Misses: 124141, Total Requests: 400 ---
# --- Episode 300 completed. Total Reward: 59860.36, Cache Hits: 204148, Cache Misses: 124156, Total Requests: 400 ---
# --- Episode 301 completed. Total Reward: 58986.56, Cache Hits: 210728, Cache Misses: 123528, Total Requests: 400 ---
# --- Episode 302 completed. Total Reward: 58001.22, Cache Hits: 214653, Cache Misses: 121347, Total Requests: 400 ---
# --- Episode 303 completed. Total Reward: 59922.27, Cache Hits: 207163, Cache Misses: 121909, Total Requests: 400 ---
# --- Episode 304 completed. Total Reward: 56217.86, Cache Hits: 205903, Cache Misses: 116113, Total Requests: 400 ---
# --- Episode 305 completed. Total Reward: 57190.60, Cache Hits: 212766, Cache Misses: 128322, Total Requests: 400 ---
# --- Episode 306 completed. Total Reward: 58981.60, Cache Hits: 202393, Cache Misses: 122583, Total Requests: 400 ---
# --- Episode 307 completed. Total Reward: 59559.14, Cache Hits: 220750, Cache Misses: 121250, Total Requests: 400 ---
# --- Episode 308 completed. Total Reward: 57616.68, Cache Hits: 217862, Cache Misses: 130570, Total Requests: 400 ---
# --- Episode 309 completed. Total Reward: 55772.13, Cache Hits: 216269, Cache Misses: 123795, Total Requests: 400 ---
# --- Episode 310 completed. Total Reward: 59003.43, Cache Hits: 204742, Cache Misses: 120154, Total Requests: 400 ---
# --- Episode 311 completed. Total Reward: 58902.98, Cache Hits: 207759, Cache Misses: 125393, Total Requests: 400 ---
# --- Episode 312 completed. Total Reward: 57813.85, Cache Hits: 203410, Cache Misses: 118974, Total Requests: 400 ---
# --- Episode 313 completed. Total Reward: 59220.15, Cache Hits: 216945, Cache Misses: 127871, Total Requests: 400 ---
# --- Episode 314 completed. Total Reward: 59689.62, Cache Hits: 213561, Cache Misses: 126407, Total Requests: 400 ---
# --- Episode 315 completed. Total Reward: 62265.71, Cache Hits: 213772, Cache Misses: 117316, Total Requests: 400 ---
# --- Episode 316 completed. Total Reward: 61160.94, Cache Hits: 210658, Cache Misses: 125934, Total Requests: 400 ---
# --- Episode 317 completed. Total Reward: 61277.75, Cache Hits: 210916, Cache Misses: 121980, Total Requests: 400 ---
# --- Episode 318 completed. Total Reward: 61584.32, Cache Hits: 204277, Cache Misses: 121803, Total Requests: 400 ---
# --- Episode 319 completed. Total Reward: 58888.60, Cache Hits: 202329, Cache Misses: 124583, Total Requests: 400 ---
# --- Episode 320 completed. Total Reward: 56092.78, Cache Hits: 217560, Cache Misses: 124424, Total Requests: 400 ---
# --- Episode 321 completed. Total Reward: 65392.73, Cache Hits: 211196, Cache Misses: 118500, Total Requests: 400 ---
# --- Episode 322 completed. Total Reward: 63493.84, Cache Hits: 216960, Cache Misses: 111264, Total Requests: 400 ---
# --- Episode 323 completed. Total Reward: 55757.57, Cache Hits: 214974, Cache Misses: 120258, Total Requests: 400 ---
# --- Episode 324 completed. Total Reward: 63784.55, Cache Hits: 214656, Cache Misses: 123872, Total Requests: 400 ---
# --- Episode 325 completed. Total Reward: 62440.90, Cache Hits: 218971, Cache Misses: 119429, Total Requests: 400 ---
# --- Episode 326 completed. Total Reward: 58794.31, Cache Hits: 215567, Cache Misses: 122913, Total Requests: 400 ---
# --- Episode 327 completed. Total Reward: 62881.63, Cache Hits: 223545, Cache Misses: 127031, Total Requests: 400 ---
# --- Episode 328 completed. Total Reward: 63806.67, Cache Hits: 212179, Cache Misses: 117501, Total Requests: 400 ---
# --- Episode 329 completed. Total Reward: 58625.54, Cache Hits: 216654, Cache Misses: 124642, Total Requests: 400 ---
# --- Episode 330 completed. Total Reward: 58693.73, Cache Hits: 206116, Cache Misses: 123772, Total Requests: 400 ---
# --- Episode 331 completed. Total Reward: 59267.97, Cache Hits: 218815, Cache Misses: 123121, Total Requests: 400 ---
# --- Episode 332 completed. Total Reward: 62298.52, Cache Hits: 215309, Cache Misses: 122291, Total Requests: 400 ---
# --- Episode 333 completed. Total Reward: 65026.25, Cache Hits: 211909, Cache Misses: 121115, Total Requests: 400 ---
# --- Episode 334 completed. Total Reward: 66136.25, Cache Hits: 213414, Cache Misses: 112602, Total Requests: 400 ---
# --- Episode 335 completed. Total Reward: 63858.44, Cache Hits: 210627, Cache Misses: 119549, Total Requests: 400 ---
# --- Episode 336 completed. Total Reward: 58226.68, Cache Hits: 214793, Cache Misses: 123783, Total Requests: 400 ---
# --- Episode 337 completed. Total Reward: 63343.39, Cache Hits: 206414, Cache Misses: 119298, Total Requests: 400 ---
# --- Episode 338 completed. Total Reward: 62541.59, Cache Hits: 204189, Cache Misses: 115795, Total Requests: 400 ---
# --- Episode 339 completed. Total Reward: 66344.11, Cache Hits: 213709, Cache Misses: 120275, Total Requests: 400 ---
# --- Episode 340 completed. Total Reward: 58141.50, Cache Hits: 210419, Cache Misses: 125005, Total Requests: 400 ---
# --- Episode 341 completed. Total Reward: 61822.11, Cache Hits: 207549, Cache Misses: 113315, Total Requests: 400 ---
# --- Episode 342 completed. Total Reward: 61042.71, Cache Hits: 206057, Cache Misses: 118487, Total Requests: 400 ---
# --- Episode 343 completed. Total Reward: 59604.15, Cache Hits: 206221, Cache Misses: 112883, Total Requests: 400 ---
# --- Episode 344 completed. Total Reward: 59857.29, Cache Hits: 206781, Cache Misses: 116147, Total Requests: 400 ---
# --- Episode 345 completed. Total Reward: 56677.09, Cache Hits: 207431, Cache Misses: 117161, Total Requests: 400 ---
# --- Episode 346 completed. Total Reward: 60633.88, Cache Hits: 212846, Cache Misses: 121234, Total Requests: 400 ---
# --- Episode 347 completed. Total Reward: 61686.45, Cache Hits: 220618, Cache Misses: 128934, Total Requests: 400 ---
# --- Episode 348 completed. Total Reward: 62084.93, Cache Hits: 210230, Cache Misses: 117450, Total Requests: 400 ---
# --- Episode 349 completed. Total Reward: 69165.75, Cache Hits: 215801, Cache Misses: 112375, Total Requests: 400 ---
# --- Episode 350 completed. Total Reward: 61980.02, Cache Hits: 217984, Cache Misses: 118048, Total Requests: 400 ---
# --- Episode 351 completed. Total Reward: 59809.05, Cache Hits: 204909, Cache Misses: 122131, Total Requests: 400 ---
# --- Episode 352 completed. Total Reward: 59732.84, Cache Hits: 218559, Cache Misses: 126593, Total Requests: 400 ---
# --- Episode 353 completed. Total Reward: 56142.31, Cache Hits: 212342, Cache Misses: 126170, Total Requests: 400 ---
# --- Episode 354 completed. Total Reward: 64580.77, Cache Hits: 216121, Cache Misses: 115767, Total Requests: 400 ---
# --- Episode 355 completed. Total Reward: 64613.00, Cache Hits: 219660, Cache Misses: 117188, Total Requests: 400 ---
# --- Episode 356 completed. Total Reward: 64682.43, Cache Hits: 216368, Cache Misses: 120176, Total Requests: 400 ---
# --- Episode 357 completed. Total Reward: 57175.02, Cache Hits: 207609, Cache Misses: 121815, Total Requests: 400 ---
# --- Episode 358 completed. Total Reward: 58962.91, Cache Hits: 219617, Cache Misses: 124959, Total Requests: 400 ---
# --- Episode 359 completed. Total Reward: 57267.04, Cache Hits: 218567, Cache Misses: 129753, Total Requests: 400 ---
# --- Episode 360 completed. Total Reward: 57977.07, Cache Hits: 210664, Cache Misses: 118456, Total Requests: 400 ---
# --- Episode 361 completed. Total Reward: 57285.30, Cache Hits: 214376, Cache Misses: 119880, Total Requests: 400 ---
# --- Episode 362 completed. Total Reward: 59100.03, Cache Hits: 214560, Cache Misses: 121504, Total Requests: 400 ---
# --- Episode 363 completed. Total Reward: 63432.52, Cache Hits: 209466, Cache Misses: 126374, Total Requests: 400 ---
# --- Episode 364 completed. Total Reward: 59582.05, Cache Hits: 207338, Cache Misses: 121078, Total Requests: 400 ---
# --- Episode 365 completed. Total Reward: 53761.54, Cache Hits: 204236, Cache Misses: 128404, Total Requests: 400 ---
# --- Episode 366 completed. Total Reward: 62991.98, Cache Hits: 216291, Cache Misses: 123421, Total Requests: 400 ---
# --- Episode 367 completed. Total Reward: 66396.65, Cache Hits: 212059, Cache Misses: 116581, Total Requests: 400 ---
# --- Episode 368 completed. Total Reward: 69015.00, Cache Hits: 219348, Cache Misses: 120108, Total Requests: 400 ---
# --- Episode 369 completed. Total Reward: 59287.77, Cache Hits: 213214, Cache Misses: 123922, Total Requests: 400 ---
# --- Episode 370 completed. Total Reward: 60977.07, Cache Hits: 213294, Cache Misses: 122050, Total Requests: 400 ---
# --- Episode 371 completed. Total Reward: 61120.70, Cache Hits: 207803, Cache Misses: 116485, Total Requests: 400 ---
# --- Episode 372 completed. Total Reward: 58074.91, Cache Hits: 203392, Cache Misses: 113776, Total Requests: 400 ---
# --- Episode 373 completed. Total Reward: 64477.46, Cache Hits: 216028, Cache Misses: 112996, Total Requests: 400 ---
# --- Episode 374 completed. Total Reward: 55802.93, Cache Hits: 206378, Cache Misses: 124086, Total Requests: 400 ---
# --- Episode 375 completed. Total Reward: 54496.58, Cache Hits: 212932, Cache Misses: 130108, Total Requests: 400 ---
# --- Episode 376 completed. Total Reward: 64216.98, Cache Hits: 219352, Cache Misses: 119112, Total Requests: 400 ---
# --- Episode 377 completed. Total Reward: 63463.10, Cache Hits: 217565, Cache Misses: 124931, Total Requests: 400 ---
# --- Episode 378 completed. Total Reward: 63787.43, Cache Hits: 223726, Cache Misses: 125778, Total Requests: 400 ---
# --- Episode 379 completed. Total Reward: 69184.33, Cache Hits: 217971, Cache Misses: 114493, Total Requests: 400 ---
# --- Episode 380 completed. Total Reward: 57406.45, Cache Hits: 216304, Cache Misses: 132816, Total Requests: 400 ---
# --- Episode 381 completed. Total Reward: 62207.71, Cache Hits: 217791, Cache Misses: 121201, Total Requests: 400 ---
# --- Episode 382 completed. Total Reward: 62239.26, Cache Hits: 210645, Cache Misses: 112603, Total Requests: 400 ---
# --- Episode 383 completed. Total Reward: 66378.41, Cache Hits: 211889, Cache Misses: 115743, Total Requests: 400 ---
# --- Episode 384 completed. Total Reward: 57787.48, Cache Hits: 206784, Cache Misses: 121888, Total Requests: 400 ---
# --- Episode 385 completed. Total Reward: 65639.12, Cache Hits: 213714, Cache Misses: 112174, Total Requests: 400 ---
# --- Episode 386 completed. Total Reward: 58817.51, Cache Hits: 206323, Cache Misses: 121597, Total Requests: 400 ---
# --- Episode 387 completed. Total Reward: 58015.78, Cache Hits: 212648, Cache Misses: 122040, Total Requests: 400 ---
# --- Episode 388 completed. Total Reward: 60835.45, Cache Hits: 207920, Cache Misses: 111248, Total Requests: 400 ---
# --- Episode 389 completed. Total Reward: 63627.83, Cache Hits: 217822, Cache Misses: 118194, Total Requests: 400 ---
# --- Episode 390 completed. Total Reward: 55534.70, Cache Hits: 205029, Cache Misses: 114427, Total Requests: 400 ---
# --- Episode 391 completed. Total Reward: 56825.01, Cache Hits: 210154, Cache Misses: 117286, Total Requests: 400 ---
# --- Episode 392 completed. Total Reward: 61367.15, Cache Hits: 212521, Cache Misses: 112999, Total Requests: 400 ---
# --- Episode 393 completed. Total Reward: 61098.93, Cache Hits: 217515, Cache Misses: 128661, Total Requests: 400 ---
# --- Episode 394 completed. Total Reward: 60800.04, Cache Hits: 217564, Cache Misses: 122068, Total Requests: 400 ---
# --- Episode 395 completed. Total Reward: 64813.17, Cache Hits: 210307, Cache Misses: 111965, Total Requests: 400 ---
# --- Episode 396 completed. Total Reward: 60966.23, Cache Hits: 229389, Cache Misses: 122147, Total Requests: 400 ---
# --- Episode 397 completed. Total Reward: 62313.09, Cache Hits: 218275, Cache Misses: 121117, Total Requests: 400 ---
# --- Episode 398 completed. Total Reward: 57127.17, Cache Hits: 212051, Cache Misses: 119341, Total Requests: 400 ---
# --- Episode 399 completed. Total Reward: 64775.81, Cache Hits: 200297, Cache Misses: 109143, Total Requests: 400 ---
# --- Episode 400 completed. Total Reward: 57328.08, Cache Hits: 210754, Cache Misses: 119166, Total Requests: 400 ---
# --- Episode 401 completed. Total Reward: 56257.55, Cache Hits: 215321, Cache Misses: 125719, Total Requests: 400 ---
# --- Episode 402 completed. Total Reward: 59633.93, Cache Hits: 207501, Cache Misses: 119923, Total Requests: 400 ---
# --- Episode 403 completed. Total Reward: 63504.27, Cache Hits: 210435, Cache Misses: 112301, Total Requests: 400 ---
# --- Episode 404 completed. Total Reward: 67461.78, Cache Hits: 213715, Cache Misses: 111549, Total Requests: 400 ---
# --- Episode 405 completed. Total Reward: 63369.97, Cache Hits: 211656, Cache Misses: 118056, Total Requests: 400 ---
# --- Episode 406 completed. Total Reward: 57407.45, Cache Hits: 202701, Cache Misses: 115411, Total Requests: 400 ---
# --- Episode 407 completed. Total Reward: 63912.94, Cache Hits: 208655, Cache Misses: 115921, Total Requests: 400 ---
# --- Episode 408 completed. Total Reward: 58534.95, Cache Hits: 207896, Cache Misses: 110760, Total Requests: 400 ---
# --- Episode 409 completed. Total Reward: 62445.34, Cache Hits: 221631, Cache Misses: 121249, Total Requests: 400 ---
# --- Episode 410 completed. Total Reward: 57883.78, Cache Hits: 210965, Cache Misses: 120187, Total Requests: 400 ---
# --- Episode 411 completed. Total Reward: 62706.99, Cache Hits: 216529, Cache Misses: 117791, Total Requests: 400 ---
# --- Episode 412 completed. Total Reward: 55228.74, Cache Hits: 200256, Cache Misses: 108000, Total Requests: 400 ---
# --- Episode 413 completed. Total Reward: 58001.88, Cache Hits: 208906, Cache Misses: 116006, Total Requests: 400 ---
# --- Episode 414 completed. Total Reward: 63492.96, Cache Hits: 211605, Cache Misses: 113387, Total Requests: 400 ---
# --- Episode 415 completed. Total Reward: 63774.46, Cache Hits: 216476, Cache Misses: 125156, Total Requests: 400 ---
# --- Episode 416 completed. Total Reward: 63197.99, Cache Hits: 219713, Cache Misses: 110991, Total Requests: 400 ---
# --- Episode 417 completed. Total Reward: 63314.76, Cache Hits: 211545, Cache Misses: 116023, Total Requests: 400 ---
# --- Episode 418 completed. Total Reward: 55073.56, Cache Hits: 207225, Cache Misses: 122055, Total Requests: 400 ---
# --- Episode 419 completed. Total Reward: 59106.51, Cache Hits: 213453, Cache Misses: 128739, Total Requests: 400 ---
# --- Episode 420 completed. Total Reward: 60969.52, Cache Hits: 210290, Cache Misses: 118110, Total Requests: 400 ---
# --- Episode 421 completed. Total Reward: 59997.48, Cache Hits: 210703, Cache Misses: 126161, Total Requests: 400 ---
# --- Episode 422 completed. Total Reward: 61143.03, Cache Hits: 205310, Cache Misses: 114402, Total Requests: 400 ---
# --- Episode 423 completed. Total Reward: 56905.21, Cache Hits: 212813, Cache Misses: 117843, Total Requests: 400 ---
# --- Episode 424 completed. Total Reward: 63957.24, Cache Hits: 211230, Cache Misses: 122594, Total Requests: 400 ---
# --- Episode 425 completed. Total Reward: 55555.85, Cache Hits: 202829, Cache Misses: 115443, Total Requests: 400 ---
# --- Episode 426 completed. Total Reward: 63093.71, Cache Hits: 207860, Cache Misses: 110748, Total Requests: 400 ---
# --- Episode 427 completed. Total Reward: 64571.92, Cache Hits: 214163, Cache Misses: 120157, Total Requests: 400 ---
# --- Episode 428 completed. Total Reward: 65292.51, Cache Hits: 211534, Cache Misses: 114866, Total Requests: 400 ---
# --- Episode 429 completed. Total Reward: 62763.49, Cache Hits: 212713, Cache Misses: 115479, Total Requests: 400 ---
# --- Episode 430 completed. Total Reward: 67232.09, Cache Hits: 218232, Cache Misses: 111128, Total Requests: 400 ---
# --- Episode 431 completed. Total Reward: 61552.09, Cache Hits: 217283, Cache Misses: 125805, Total Requests: 400 ---
# --- Episode 432 completed. Total Reward: 59150.96, Cache Hits: 218010, Cache Misses: 123526, Total Requests: 400 ---
# --- Episode 433 completed. Total Reward: 58775.77, Cache Hits: 207409, Cache Misses: 119055, Total Requests: 400 ---
# --- Episode 434 completed. Total Reward: 64631.58, Cache Hits: 217764, Cache Misses: 122204, Total Requests: 400 ---
# --- Episode 435 completed. Total Reward: 58778.24, Cache Hits: 213049, Cache Misses: 120231, Total Requests: 400 ---
# --- Episode 436 completed. Total Reward: 61250.32, Cache Hits: 201985, Cache Misses: 115023, Total Requests: 400 ---
# --- Episode 437 completed. Total Reward: 60358.59, Cache Hits: 209202, Cache Misses: 121822, Total Requests: 400 ---
# --- Episode 438 completed. Total Reward: 62109.00, Cache Hits: 211566, Cache Misses: 113794, Total Requests: 400 ---
# --- Episode 439 completed. Total Reward: 64980.62, Cache Hits: 222597, Cache Misses: 123995, Total Requests: 400 ---
# --- Episode 440 completed. Total Reward: 61721.24, Cache Hits: 220203, Cache Misses: 126053, Total Requests: 400 ---
# --- Episode 441 completed. Total Reward: 64652.45, Cache Hits: 222076, Cache Misses: 118644, Total Requests: 400 ---
# --- Episode 442 completed. Total Reward: 59100.85, Cache Hits: 219177, Cache Misses: 121879, Total Requests: 400 ---
# --- Episode 443 completed. Total Reward: 60864.12, Cache Hits: 215992, Cache Misses: 113576, Total Requests: 400 ---
# --- Episode 444 completed. Total Reward: 65076.54, Cache Hits: 217849, Cache Misses: 114487, Total Requests: 400 ---
# --- Episode 445 completed. Total Reward: 56887.42, Cache Hits: 217689, Cache Misses: 115463, Total Requests: 400 ---
# --- Episode 446 completed. Total Reward: 58775.77, Cache Hits: 212327, Cache Misses: 122825, Total Requests: 400 ---
# --- Episode 447 completed. Total Reward: 60824.08, Cache Hits: 214909, Cache Misses: 113859, Total Requests: 400 ---
# --- Episode 448 completed. Total Reward: 60356.18, Cache Hits: 237686, Cache Misses: 123914, Total Requests: 400 ---
# --- Episode 449 completed. Total Reward: 61847.08, Cache Hits: 223905, Cache Misses: 116303, Total Requests: 400 ---
# --- Episode 450 completed. Total Reward: 55551.16, Cache Hits: 213105, Cache Misses: 130495, Total Requests: 400 ---
# --- Episode 451 completed. Total Reward: 58458.40, Cache Hits: 222307, Cache Misses: 128045, Total Requests: 400 ---
# --- Episode 452 completed. Total Reward: 60771.89, Cache Hits: 207637, Cache Misses: 117691, Total Requests: 400 ---
# --- Episode 453 completed. Total Reward: 63376.51, Cache Hits: 218270, Cache Misses: 130754, Total Requests: 400 ---
# --- Episode 454 completed. Total Reward: 60465.90, Cache Hits: 210163, Cache Misses: 115789, Total Requests: 400 ---
# --- Episode 455 completed. Total Reward: 60260.13, Cache Hits: 222788, Cache Misses: 121708, Total Requests: 400 ---
# --- Episode 456 completed. Total Reward: 64397.37, Cache Hits: 224660, Cache Misses: 116620, Total Requests: 400 ---
# --- Episode 457 completed. Total Reward: 61417.71, Cache Hits: 208328, Cache Misses: 112264, Total Requests: 400 ---
# --- Episode 458 completed. Total Reward: 66169.96, Cache Hits: 215212, Cache Misses: 114756, Total Requests: 400 ---
# --- Episode 459 completed. Total Reward: 64937.42, Cache Hits: 207381, Cache Misses: 114987, Total Requests: 400 ---
# --- Episode 460 completed. Total Reward: 64650.65, Cache Hits: 215393, Cache Misses: 114687, Total Requests: 400 ---
# --- Episode 461 completed. Total Reward: 55994.17, Cache Hits: 202228, Cache Misses: 113132, Total Requests: 400 ---
# --- Episode 462 completed. Total Reward: 60943.37, Cache Hits: 205501, Cache Misses: 115187, Total Requests: 400 ---
# --- Episode 463 completed. Total Reward: 63480.85, Cache Hits: 224781, Cache Misses: 129027, Total Requests: 400 ---
# --- Episode 464 completed. Total Reward: 60321.97, Cache Hits: 221852, Cache Misses: 125988, Total Requests: 400 ---
# --- Episode 465 completed. Total Reward: 65471.29, Cache Hits: 219050, Cache Misses: 123654, Total Requests: 400 ---
# --- Episode 466 completed. Total Reward: 65585.06, Cache Hits: 217480, Cache Misses: 108440, Total Requests: 400 ---
# --- Episode 467 completed. Total Reward: 58570.55, Cache Hits: 210236, Cache Misses: 111828, Total Requests: 400 ---
# --- Episode 468 completed. Total Reward: 63089.14, Cache Hits: 211757, Cache Misses: 118307, Total Requests: 400 ---
# --- Episode 469 completed. Total Reward: 66661.25, Cache Hits: 213374, Cache Misses: 116338, Total Requests: 400 ---
# --- Episode 470 completed. Total Reward: 59292.16, Cache Hits: 211388, Cache Misses: 106932, Total Requests: 400 ---
# --- Episode 471 completed. Total Reward: 56130.72, Cache Hits: 208722, Cache Misses: 117102, Total Requests: 400 ---
# --- Episode 472 completed. Total Reward: 58833.41, Cache Hits: 213174, Cache Misses: 126730, Total Requests: 400 ---
# --- Episode 473 completed. Total Reward: 61193.84, Cache Hits: 213932, Cache Misses: 119700, Total Requests: 400 ---
# --- Episode 474 completed. Total Reward: 56155.20, Cache Hits: 218500, Cache Misses: 131132, Total Requests: 400 ---
# --- Episode 475 completed. Total Reward: 68355.70, Cache Hits: 213805, Cache Misses: 119651, Total Requests: 400 ---
# --- Episode 476 completed. Total Reward: 64362.93, Cache Hits: 211962, Cache Misses: 116022, Total Requests: 400 ---
# --- Episode 477 completed. Total Reward: 60439.27, Cache Hits: 202871, Cache Misses: 116137, Total Requests: 400 ---
# --- Episode 478 completed. Total Reward: 58910.23, Cache Hits: 209981, Cache Misses: 122627, Total Requests: 400 ---
# --- Episode 479 completed. Total Reward: 62982.90, Cache Hits: 215298, Cache Misses: 110974, Total Requests: 400 ---
# --- Episode 480 completed. Total Reward: 60574.06, Cache Hits: 213988, Cache Misses: 116300, Total Requests: 400 ---
# --- Episode 481 completed. Total Reward: 61119.21, Cache Hits: 214324, Cache Misses: 112860, Total Requests: 400 ---
# --- Episode 482 completed. Total Reward: 63158.29, Cache Hits: 216928, Cache Misses: 110624, Total Requests: 400 ---
# --- Episode 483 completed. Total Reward: 67312.56, Cache Hits: 223699, Cache Misses: 114589, Total Requests: 400 ---
# --- Episode 484 completed. Total Reward: 62551.80, Cache Hits: 212846, Cache Misses: 111970, Total Requests: 400 ---
# --- Episode 485 completed. Total Reward: 57647.13, Cache Hits: 222815, Cache Misses: 123137, Total Requests: 400 ---
# --- Episode 486 completed. Total Reward: 58820.55, Cache Hits: 217099, Cache Misses: 120597, Total Requests: 400 ---
# --- Episode 487 completed. Total Reward: 69370.62, Cache Hits: 218153, Cache Misses: 118967, Total Requests: 400 ---
# --- Episode 488 completed. Total Reward: 60603.79, Cache Hits: 220943, Cache Misses: 111585, Total Requests: 400 ---
# --- Episode 489 completed. Total Reward: 64364.04, Cache Hits: 213337, Cache Misses: 115543, Total Requests: 400 ---
# --- Episode 490 completed. Total Reward: 64083.59, Cache Hits: 214634, Cache Misses: 114486, Total Requests: 400 ---
# --- Episode 491 completed. Total Reward: 61405.88, Cache Hits: 217169, Cache Misses: 112671, Total Requests: 400 ---
# --- Episode 492 completed. Total Reward: 57808.96, Cache Hits: 203485, Cache Misses: 110563, Total Requests: 400 ---
# --- Episode 493 completed. Total Reward: 57291.13, Cache Hits: 220278, Cache Misses: 123274, Total Requests: 400 ---
# --- Episode 494 completed. Total Reward: 60887.17, Cache Hits: 215802, Cache Misses: 115430, Total Requests: 400 ---
# --- Episode 495 completed. Total Reward: 62112.98, Cache Hits: 214773, Cache Misses: 115899, Total Requests: 400 ---
# --- Episode 496 completed. Total Reward: 60839.73, Cache Hits: 209001, Cache Misses: 105127, Total Requests: 400 ---
# --- Episode 497 completed. Total Reward: 69966.20, Cache Hits: 211160, Cache Misses: 105576, Total Requests: 400 ---
# --- Episode 498 completed. Total Reward: 65881.32, Cache Hits: 213527, Cache Misses: 109353, Total Requests: 400 ---
# --- Episode 499 completed. Total Reward: 57881.12, Cache Hits: 210971, Cache Misses: 118613, Total Requests: 400 ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------      
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

# Professional color for line plots
PRIMARY_COLOR = "#2b7bba"

# ----------------------------------------------------------------
# 2. Data Loading & Smoothing
# ----------------------------------------------------------------
path = cfg.path_results + "/" + cfg.filename

print(f"Loading data from: {path}")

df = pd.read_csv(path)

total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
df["hit_rate"] = (df["cache_hits"] / total) * 100
df["miss_rate"] = (df["cache_misses"] / total) * 100

# Metrics to plot
metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
window_size = 10  # Adjust smoothing window as needed

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
# Adjusted figsize for a 4-column row (standard for full-width paper figures)
fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

for ax, col in zip(axes, metrics):
    # Plot raw data with transparency (alpha)
    ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, alpha=0.3, linewidth=0.8, label='Raw')
    
    # Plot moving average for clearer trend (except for epsilon which is usually linear)
    if col != "epsilon":
        smoothed = df[col].rolling(window=window_size).mean()
        ax.plot(df["episode"], smoothed, color=PRIMARY_COLOR, linewidth=1.5, label='Trend')
    else:
        # Just a solid line for Epsilon
        ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, linewidth=1.5)

    # Stylistic cleanup
    ax.set_title(col.replace("_", " ").title(), fontweight="bold")
    ax.set_xlabel("Episode")
    
    # Remove redundant Y-labels to save space, or keep for clarity
    ax.set_ylabel("Value") 
    
    series = df[col].dropna()
    if not series.empty:
        ymin = series.min()
        ymax = series.max()
        pad = (ymax - ymin) * 0.05 if ymax != ymin else 1.0
        ax.set_ylim(ymin - pad, ymax + pad)
    ax.grid(axis='y', linestyle='--', alpha=0.3)
    
    # Tufte-style: remove top/right spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# Optional: Add a single legend to the first plot if needed
# axes[0].legend(frameon=False)

plt.show()
fig.savefig("drl_caching_metrics.png", dpi=300)
# Out:
# Loading data from: /home/eduardo/Workspace/CacheVideoPredict360/Results/drl_dqn_softup_lrdecay0.9999_u400_e500_c50_ar10.0_z0.8.csv

# %%
if __name__ == "__main__":

    plt.rcParams.update({
        "font.family": "serif",
        "font.serif": ["Times New Roman", "DejaVu Serif"],
        "font.size": 10,
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "legend.fontsize": 9,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "axes.linewidth": 0.8,
        "savefig.dpi": 300,
        "figure.constrained_layout.use": True
    })

    COLORS = ["#2b7bba", "#d62728", "#2ca02c"]

    folder = r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\interval_100_3"
    folder = r"/home/eduardo/Workspace/CacheVideoPredict360/Results"
    files = [
        "drl_d3qn_softup_lrdecay0.9999_c50_ar10.0_z0.8.csv",
        "drl_dqn_softup_fixedlr0.001_e500_c50_ar10.0_z1.0.csv",
        # "drl_dqn_softup_lrdecay0.99999_c50_ar10.0_z0.8.csv",
    ]

    paths = [os.path.join(folder, f) for f in files]
    def _short_label(fname: str) -> str:
        stem = os.path.splitext(fname)[0]
        if "lrdecay" in stem:
            val = stem.split("lrdecay", 1)[1].split("_", 1)[0]
            return f"lr decay: {val}"
        if "fixedlr" in stem:
            val = stem.split("fixedlr", 1)[1].split("_", 1)[0]
            return f"fixed lr: {val}"
        return stem

    labels = [_short_label(f) for f in files]

    print(labels)
    metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
    window_size = 10

    fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

    for color, path, label in zip(COLORS, paths, labels):
        df = pd.read_csv(path)
        total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
        df["hit_rate"] = (df["cache_hits"] / total) * 100
        df["miss_rate"] = (df["cache_misses"] / total) * 100

        for ax, col in zip(axes, metrics):
            ax.plot(df["episode"], df[col], color=color, alpha=0.25, linewidth=0.8)

            if col != "epsilon":
                smoothed = df[col].rolling(window=window_size).mean()
                ax.plot(df["episode"], smoothed, color=color, linewidth=1.5, label=label)
            else:
                ax.plot(df["episode"], df[col], color=color, linewidth=1.5, label=label)

    for ax, col in zip(axes, metrics):
        ax.set_title(col.replace("_", " ").title(), fontweight="bold")
        ax.set_xlabel("Episode")
        ax.set_ylabel("Value")
        ax.grid(axis="y", linestyle="--", alpha=0.3)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.set_ylim(bottom=0)

    axes[0].legend(frameon=False, loc="best")
    plt.show()

    fig.savefig("interval_04_comparison.png", dpi=300)
# Out:
# ['fixed lr: 0.001', 'lr decay: 0.9999']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------      
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

COLORS = ["#2b7bba", "#d62728"]

# ----------------------------------------------------------------
# 2. Data Preparation with Variance
# ----------------------------------------------------------------
def get_metrics_with_error(path):
    """Returns mean and standard deviation for hit and miss rates."""
    try:
        df = pd.read_csv(path)
        total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
        
        hit_series = (df["cache_hits"] / total * 100)
        miss_series = (df["cache_misses"] / total * 100)
        
        # Calculate Mean and Standard Deviation
        return (hit_series.mean(), hit_series.std()), (miss_series.mean(), miss_series.std())
    except Exception as e:
        print(f"Error processing {path}: {e}")
        return (0, 0), (0, 0)

drl_files = {
    "5": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\drl_pan_opt_c25_ar10.0_z0.5.csv",
    "10": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\drl_pan_opt_c50_ar10.0_z0.5.csv",
}

lsr_files = {
    "5": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\lru_c25_ar10.0_z0.5.csv",
    "10": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\lru_c50_ar10.0_z0.5.csv",
}

caps = list(drl_files.keys())
# Structure: { Metric: { Algo: [means], Algo_err: [stds] } }
stats = {
    "Hit Rate": {"DRL-LSR": [], "DRL-LSR_err": [], "LRU-LSR": [], "LRU-LSR_err": []},
    "Miss Rate": {"DRL-LSR": [], "DRL-LSR_err": [], "LRU-LSR": [], "LRU-LSR_err": []}
}

for c in caps:
    (d_h, d_h_err), (d_m, d_m_err) = get_metrics_with_error(drl_files[c])
    (l_h, l_h_err), (l_m, l_m_err) = get_metrics_with_error(lsr_files[c])
    
    stats["Hit Rate"]["DRL-LSR"].append(d_h)
    stats["Hit Rate"]["DRL-LSR_err"].append(d_h_err)
    stats["Hit Rate"]["LRU-LSR"].append(l_h)
    stats["Hit Rate"]["LRU-LSR_err"].append(l_h_err)
    
    stats["Miss Rate"]["DRL-LSR"].append(d_m)
    stats["Miss Rate"]["DRL-LSR_err"].append(d_m_err)
    stats["Miss Rate"]["LRU-LSR"].append(l_m)
    stats["Miss Rate"]["LRU-LSR_err"].append(l_m_err)

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(7, 3.2), sharey=True)
x = np.arange(len(caps))
width = 0.35 

# Error bar styling
error_kw = dict(lw=1, capsize=3, capthick=1, ecolor='#333333')

metrics = ["Hit Rate", "Miss Rate"]
for i, metric in enumerate(metrics):
    ax = axes[i]
    
    ax.bar(x - width/2, stats[metric]["DRL-LSR"], width, 
           yerr=stats[metric]["DRL-LSR_err"], error_kw=error_kw,
           label="DRL-LSR", color=COLORS[0], edgecolor='black', linewidth=0.6, zorder=3)
    
    ax.bar(x + width/2, stats[metric]["LRU-LSR"], width, 
           yerr=stats[metric]["LRU-LSR_err"], error_kw=error_kw,
           label="LRU-LSR", color=COLORS[1], edgecolor='black', linewidth=0.6, zorder=3)

    ax.set_title(f"Average {metric}", fontweight="bold")
    ax.set_xlabel("Cache Size (%)")
    ax.set_xticks(x)
    ax.set_xticklabels(caps)
    ax.set_ylim(0, 110) # Increased to accommodate error bars
    
    ax.grid(axis='y', linestyle='--', alpha=0.3, zorder=0)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

axes[0].set_ylabel("Percentage (%)")
axes[1].legend(frameon=False, loc="upper right")

plt.tight_layout()
plt.show()

fig.savefig("drl_vs_lru_cache_performance.pdf")
# Out:
# C:\Users\es25591\AppData\Local\Temp\ipykernel_24328\1345644425.py:108: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
