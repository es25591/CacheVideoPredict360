# %%
import os
import math
import csv
import random
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import Any, Dict, Counter, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torch_optimizer as optim_extra

from importnb import Notebook
with Notebook():
    from LabLatencyModel import LatencyModel, MultiDULatencyModel
    from LabCacheEngine import CacheEngineEnv, DrlPolicy
    from LabUserRequest import UserRequestEvents
    from LabEnvWrapper import EnvWrapper

import importlib
import Common.config as config

importlib.reload(config)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 30
#      27     from LabEnvWrapper import EnvWrapper
#      29 import importlib
# ---> 30 import Sources.Common.config as config
#      32 importlib.reload(config)
#
# ModuleNotFoundError: No module named 'Sources'

# %%
cfg = config.Config()

# cfg.filename = f"drl_dqn_softup_lrdecay{cfg.learning_rate_decay}_u{cfg.n_users}_e{cfg.n_episodes}_c{cfg.cache_size}_ar{cfg.arrival_rate}_z{cfg.zipf_alpha}.csv"
cfg.filename = f"drl_dqn_softup_fixedlr{cfg.learning_rate}_e{cfg.n_episodes}_c{cfg.cache_size}_ar{cfg.arrival_rate}_z{cfg.zipf_alpha}.csv"

# %%
# --- DataClass for User Transition ---
@dataclass
class UserTransition:
    state: Any
    action: int
    reward: float

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class QNetwork(nn.Module):
    def __init__(self, state_dim: int, action_dim: int):
        super().__init__()
        hidden = 128
        self.fc1 = nn.Linear(state_dim, hidden)
        self.fc2 = nn.Linear(hidden, hidden)
        self.out = nn.Linear(hidden, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.out(x)

class ReplayBuffer:
    def __init__(self, capacity: int = 2000):
        self.memory = deque(maxlen=capacity)
    
    def push(self, s, a, r, ns, d):
        self.memory.append((s, a, r, ns, d))
    
    def sample(self, batch_size: int):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

class DQNAgent:
    def __init__(self, cfg: Any):
        self.step = 0
        
        self.state_dim = cfg.state_dim
        self.action_dim = cfg.action_dim
        
        self.epsilon = cfg.epsilon_start
        self.epsilon_min = cfg.epsilon_min
        self.epsilon_decay = cfg.epsilon_decay
        self.gamma = cfg.gamma
        self.tau = cfg.tau
        self.batch_size = cfg.batch_size
        
        self.buffer = ReplayBuffer(cfg.buffer_capacity)
        
        self.policy_net = QNetwork(self.state_dim, self.action_dim).to(device)
        self.target_net = QNetwork(self.state_dim, self.action_dim).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=cfg.learning_rate)
        # self.optimizer = optim_extra.Ranger(
        #     self.policy_net.parameters(), 
        #     lr=cfg.learning_rate,
        #     alpha=0.5,  # Lookahead step size (default is usually 0.5)
        #     k=6         # Lookahead step frequency
        # )
        
        self.scheduler = torch.optim.lr_scheduler.ExponentialLR(
            self.optimizer, 
            gamma=cfg.learning_rate_decay
        )
        
        self.loss_fn = nn.MSELoss()
        self.nb_interval = cfg.nb_interval  # train every 5 requests

    def select_action(self, state):
        if random.random() < self.epsilon:
            action_idx = random.randint(0, self.action_dim - 1)
            return action_idx, None
        
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.policy_net(state)
        
        action_idx = q_values.argmax().item()
        return action_idx, q_values
        
    def remember(self, s, a, r, ns, done):
        self.buffer.push(s, a, r, ns, done)

    def train_step(self):
        self.step += 1
        if self.step % self.nb_interval == 0 and \
           len(self.buffer) >= self.batch_size:
            self.learn()

    def learn(self):
        batch = self.buffer.sample(self.batch_size)
        s, a, r, ns, d = zip(*batch)
        s = torch.tensor(np.stack(s), dtype=torch.float32).to(device)
        ns = torch.tensor(np.stack(ns), dtype=torch.float32).to(device)
        a = torch.tensor(a, dtype=torch.int64).to(device)
        r = torch.tensor(r, dtype=torch.float32).to(device)
        d = torch.tensor(d, dtype=torch.float32).to(device)

        with torch.no_grad():
            q_next = self.target_net(ns).max(1)[0]
            q_target = r + self.gamma * q_next * (1.0 - d)

        q_expected = self.policy_net(s).gather(1, a.unsqueeze(1)).squeeze(1)

        loss = self.loss_fn(q_expected, q_target)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        # self.scheduler.step()
        
        self.soft_update_target()

    def soft_update_target(self):
        for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
            target_param.data.copy_( 
                target_param.data * (1.0 - self.tau) + policy_param.data * self.tau
            )

    def update_target(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def update_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        
    def reset_step(self):
        self.step = 0

# %%
def save_training_results(
    path_,
    filename,
    ep, 
    total_reward, 
    cache_hits, 
    cache_misses, 
    soft_hits,
    agent
):
    with open(os.path.join(path_, filename), 'a', newline='') as f:
        fieldnames = [
            'episode', 
            'total_reward', 
            'cache_hits', 
            'cache_misses', 
            'soft_hits',
            'epsilon',
            'lr'
        ]
        writer_results = csv.DictWriter(f, fieldnames=fieldnames)

        if ep == 0:
            writer_results.writeheader()
        
        writer_results.writerow({
            'episode': ep,
            'total_reward': round(float(total_reward), 2),
            'cache_hits': cache_hits,
            'cache_misses': cache_misses,
            'soft_hits': soft_hits,
            'lr': f"{agent.scheduler.get_last_lr()[0]:.10f}" if agent else None,
            'epsilon': round(float(agent.epsilon), 4) if agent else None
        })

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, float]:
    enh_hits = info.get("enh_layer_cache_hits", 0)
    base_hits = info.get("base_layer_cache_hits", 0)
    enh_misses = info.get("enh_layer_cache_misses", 0)
    base_misses = info.get("base_layer_cache_misses", 0)
    soft_hits = info.get("soft_hits", 0.0)

    return reward, (enh_hits + base_hits), (enh_misses + base_misses), soft_hits

# %%
class FeatureAdapter:
    def __init__(self, env: CacheEngineEnv, cfg: Any):
        self.env = env
        self.cfg = cfg

        self.video_hist_short = deque(maxlen=cfg.h_short)
        self.video_hist_long = deque(maxlen=cfg.h_long)
        self.tile_hist_short = deque(maxlen=cfg.h_short)
        self.tile_hist_long = deque(maxlen=cfg.h_long)
        self.tiles_hist_short = deque(maxlen=cfg.h_short)
        self.tiles_hist_long = deque(maxlen=cfg.h_long)

        self.video_freq_short = defaultdict(int)
        self.video_freq_long = defaultdict(int)
        self.tile_freq_short = defaultdict(int)
        self.tile_freq_long = defaultdict(int)
        self.tiles_freq_short = defaultdict(int)
        self.tiles_freq_long = defaultdict(int)

    def reset_history(self):
        queues = (
            self.video_hist_short,
            self.video_hist_long,
            self.tiles_hist_short,
            self.tiles_hist_long,
            self.tile_hist_short,
            self.tile_hist_long,
        )
        freqs = (
            self.video_freq_short,
            self.video_freq_long,
            self.tiles_freq_short,
            self.tiles_freq_long,
            self.tile_freq_short,
            self.tile_freq_long,
        )
        
        for q in queues:
            q.clear()
        for f in freqs:
            f.clear()

    def update_history(self, vid: int, tiles: list[int]):       
        self._update_window(self.video_hist_short, self.video_freq_short, vid)
        self._update_window(self.video_hist_long, self.video_freq_long, vid)

        tiles = tuple(tiles) if tiles is not None else None

        if tiles is None:
            return

        self._update_window(self.tiles_hist_short, self.tiles_freq_short, tiles)
        self._update_window(self.tiles_hist_long, self.tiles_freq_long, tiles)

        for tile in tiles:
            self._update_window(self.tile_hist_short, self.tile_freq_short, (vid, tile))
            self._update_window(self.tile_hist_long, self.tile_freq_long, (vid, tile))

    def _update_window(self, hist_queue: deque, freq_dict: Dict, item):
        if len(hist_queue) == hist_queue.maxlen:
            old_item = hist_queue.popleft()
            freq_dict[old_item] -= 1
            if freq_dict[old_item] == 0:
                del freq_dict[old_item]
        hist_queue.append(item)
        freq_dict[item] += 1

# %%
class NetworkAdapter:
    def __init__(self, env: EnvWrapper, feature_adapter: FeatureAdapter, cfg: Any):
        self.env = env
        self.cfg = cfg
        self.features = feature_adapter

        self.C = self.cfg.cache_size  # paper's cache capacity (videos)
        self.k = self.cfg.viewport    # paper's tiles per video (enhancement)

        print(f"NetworkAdapter initialized with capacity: {self.C} videos, {self.k} tiles per video")

    def build_observation(self, vid: int) -> np.ndarray:

        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        # --- FIX: Create a list of (video_id, slot_index) ---
        alpha = 0.7  # weighting factor for frequency combination
        cached_items = []
        for slot_i, v_id in enumerate(video_cache_index):
            if v_id != -1:
                freq = alpha * self.features.video_freq_long.get(v_id, 0) + (1 - alpha) * self.features.video_freq_short.get(v_id, 0)
                cached_items.append((freq, v_id, slot_i))
            else:
                cached_items.append((-1, -1, slot_i))

        cached_items.sort(key=lambda x: x[0], reverse=True)
        # ----------------------------------------------------

        x_s = np.zeros(self.C, dtype=np.float32)
        x_l = np.zeros(self.C, dtype=np.float32)
        y_s = np.zeros(self.C * self.k, dtype=np.float32)
        y_l = np.zeros(self.C * self.k, dtype=np.float32)

        # Iterate through the SORTED items to build the state
        for i, (freq, v, original_slot) in enumerate(cached_items):
            if v == -1: continue # Skip empty placeholders
            
            # Fill video features
            x_s[i] = np.log1p(self.features.video_freq_short.get(v, 0))
            x_l[i] = np.log1p(self.features.video_freq_long.get(v, 0))

            # Fill tile features using the original slot to look up specific tiles
            tiles = tile_cache_index[original_slot]
            for til_i, t in enumerate(tiles):
                if t == -1: continue
                y_s[i * self.k + til_i] = np.log1p(self.features.tile_freq_short.get((v, t), 0))
                y_l[i * self.k + til_i] = np.log1p(self.features.tile_freq_long.get((v, t), 0))

        # 4. Candidate Features
        cand_s = np.log1p(self.features.video_freq_short.get(vid, 0))
        cand_l = np.log1p(self.features.video_freq_long.get(vid, 0))

        z_s = np.array([cand_s], dtype=np.float32)
        z_l = np.array([cand_l], dtype=np.float32)

        return np.concatenate([x_s, x_l, y_s, y_l, z_s, z_l], axis=0)

    def build_observation_with_tile_pop(self, vid: int, viewport: list[int]) -> np.ndarray:

        video_cache_index = self.env.mec_cache.policy.video_idx
        tile_cache_index = self.env.mec_cache.policy.tile_idx

        # --- FIX: Create a list of (video_id, slot_index) ---
        alpha = 0.7  # weighting factor for frequency combination
        cached_items = []
        for slot_i, v_id in enumerate(video_cache_index):
            if v_id != -1:
                freq = alpha * self.features.video_freq_long.get(v_id, 0) + (1 - alpha) * self.features.video_freq_short.get(v_id, 0)
                cached_items.append((freq, v_id, slot_i))
            else:
                cached_items.append((-1, -1, slot_i))

        cached_items.sort(key=lambda x: x[0], reverse=True)
        # ----------------------------------------------------

        x_s = np.zeros(self.C, dtype=np.float32)
        x_l = np.zeros(self.C, dtype=np.float32)
        y_s = np.zeros(self.C * self.k, dtype=np.float32)
        y_l = np.zeros(self.C * self.k, dtype=np.float32)

        # Iterate through the SORTED items to build the state
        for i, (freq, v, original_slot) in enumerate(cached_items):
            if v == -1: continue # Skip empty placeholders

            # Fill video features
            x_s[i] = np.log1p(self.features.video_freq_short.get(v, 0))
            x_l[i] = np.log1p(self.features.video_freq_long.get(v, 0))

            # Fill tile features using the original slot to look up specific tiles
            tiles = tile_cache_index[original_slot]
            for til_i, t in enumerate(tiles):
                if t == -1: continue
                y_s[i * self.k + til_i] = np.log1p(self.features.tile_freq_short.get((v, t), 0))
                y_l[i * self.k + til_i] = np.log1p(self.features.tile_freq_long.get((v, t), 0))

        # 2. NEW: Calculate Request Features WITH Viewport/Enhancement Info
        
        # Base Layer Popularity (Video Freq)
        vid_req_s = np.log1p(self.features.video_freq_short.get(vid, 0))
        vid_req_l = np.log1p(self.features.video_freq_long.get(vid, 0))
        
        # Enhancement Layer Popularity (Sum of frequencies of requested tiles)
        # This tells the agent if the requested VIEWPORT is popular
        enh_req_s = np.sum([self.features.tile_freq_short.get((vid, t), 0) for t in viewport])
        enh_req_l = np.sum([self.features.tile_freq_long.get((vid, t), 0) for t in viewport])
        
        enh_req_s = np.log1p(enh_req_s)
        enh_req_l = np.log1p(enh_req_l)

        # Update z_s/z_l to include Enhancement info
        # Current z shape was likely (1,), now it is (2,)
        z_s = np.array([vid_req_s, enh_req_s], dtype=np.float32) 
        z_l = np.array([vid_req_l, enh_req_l], dtype=np.float32)

        return np.concatenate([x_s, x_l, y_s, y_l, z_s, z_l], axis=0)


    def rank_viewport_tiles(
        self,
        vid: int,
        viewport: list[int],
        features: FeatureAdapter,
        alpha: float = 0.7,
        eps: float = 1e-6,
    ) -> list[int]:

        scores = {}

        for t in viewport:
            short_f = features.tile_freq_short.get((vid, t), 0)
            long_f = features.tile_freq_long.get((vid, t), 0)
        
            score = (alpha * short_f) + ((1.0 - alpha) * long_f) + eps
            scores[t] = score

        ranked = sorted(scores.keys(), key=lambda t: (-scores[t], t))
                
        return ranked
    
    def reset(self):
        
        obs, info = self.env.reset()
        self.features.reset_history()

        video_cache_index = [-1] * self.C
        tile_cache_index = [[-1] * self.k for _ in range(self.C)]

        cached_videos = random.sample(range(self.cfg.n_videos), k=self.C)
        video_cache_index = cached_videos

        # for each cached video, sample distinct tiles
        for i, _vid in enumerate(cached_videos):
            tiles = random.sample(range(self.cfg.n_tiles), k=self.k)
            tile_cache_index[i] = tiles

        self.env.mec_cache.policy.video_idx = video_cache_index
        self.env.mec_cache.policy.tile_idx = tile_cache_index
        
        self.env.mec_cache.cache_bitmap[:, :, :, :] = 0

        gop_id = 0  # default GOP for enhancement tiles
        for i, vid in enumerate(video_cache_index):
            if vid == -1:
                continue
            tiles = tile_cache_index[i][:self.k]
            
            # base layer cached for all GOPs
            self.env.mec_cache.cache_bitmap[vid, 0, :, :] = 1

            # enhancement tiles cached for GOP 0
            self.env.mec_cache.cache_bitmap[vid, 1, tiles, :] = 1
    
        # --- update feature history with cached contents ---
        for i, vid in enumerate(video_cache_index):
            if vid == -1:
                continue
            tiles = tile_cache_index[i]
            self.features.update_history(vid, tiles)
        # --- end feature update ---

        return obs, info
    
    def env_is_done(self) -> bool:
        return self.env.users_env.all_users_done()

# %%
if __name__ == "__main__":
    print("--- Starting DRL Caching System ---")

    # 2. Initialize Environment
    du_caches = []

    mec_cache = CacheEngineEnv(
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n_gops=cfg.n_gops,
        policy=DrlPolicy(
            capacity=int(cfg.cache_capacity), 
            cfg=cfg
        )
    )

    # Initialize User Environment
    users_env = UserRequestEvents(
        n_nodes=cfg.n_nodes,
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_gops=cfg.n_gops,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n=cfg.n,
        m=cfg.m,
        arrival_rate=cfg.arrival_rate,
        zipf_alpha=cfg.zipf_alpha
    )

    P = cfg.n_nodes; max_U = cfg.n_users
    lat_model = MultiDULatencyModel(
        P=P, 
        max_U=max_U,
        R_M_D=80e6,  # 640 Mbps -> 80e6 B/s
        R_C_M=125e6, # 1 Gbps -> 125e6 B/s
        mu=2e7, 
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),    # 160 Mbps -> 20e6 B/s
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float), # SNRs
        rhoT_p=[0.2], 
        lambda_p=[0.05],
        du_fixed_delay=0.001,  # 1 ms
        mec_fixed_delay=0.005, # 5 ms
        cloud_fixed_delay=0.1  # 100 ms
    )

    def prefetch_fn(cache, action):
        return cache.drl_prefetching(action)
    
    def reward_fn(env, reqs):
        return env.avg_psnr_reward(reqs)
    
    env = EnvWrapper(
        n=cfg.n,
        m=cfg.m,
        n_layers=cfg.n_layers,
        users_env=users_env, 
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=lat_model,
        theta=cfg.theta,
        lam=cfg.lam,
        max_steps=cfg.max_steps,
        prefetch_fn=prefetch_fn,
        reward_fn=reward_fn
    )

    # 3. Initialize Agent
    agent = DQNAgent(cfg)

    feature_adapter = FeatureAdapter(env, cfg)
    net_adapter = NetworkAdapter(env, feature_adapter, cfg)

    for episode in range(cfg.n_episodes):

        obs, info = net_adapter.reset()
        agent.reset_step()

        cache_hits = 0
        cache_misses = 0
        soft_hits = 0.0
        total_reward = 0.0
        avg_psnr = []
        
        for step in count():
            user_transition: Dict[int, UserTransition] = {}

            reqs_state = info['users_requests']

            actions = []
            action_taken = False

            for req in reqs_state:
                u = req["u"]
                v = req["video"]
                g = req["gop"]
                tiles = req["tiles"]
                viewport = req["viewport"]
                base_req_init = req["base_req_init"]

                has_base_layer = any(
                    t.get("events", {}).get("alpha_M_u") == 1 for t in tiles
                )
                
                if g == 0 and not has_base_layer:
                    cur_state = net_adapter.build_observation(v)
                    action_idx, _ = agent.select_action(cur_state)

                    should_cache = (action_idx == 1)
                    if should_cache:
                        video_idx_list = env.mec_cache.policy.video_idx
                        freqs = [
                            net_adapter.features.video_freq_long.get(vid, 0) if vid != -1 else -1 for vid in video_idx_list
                        ]

                        victim_slot = np.argmin(freqs) 
                        a_idx = victim_slot + 1 
                    else:
                        a_idx = 0

                    actions.append({
                        'video': v,
                        'gop': 0,
                        'tiles': viewport,
                        'base_req_init': should_cache, 
                        'action_idx': a_idx
                    })

                    user_transition[u] = UserTransition(
                        state=cur_state,
                        action=action_idx,
                        reward=0.0
                    )
                    action_taken = True
                elif has_base_layer:
                    bitmap = env.mec_cache.get_cache_bitmap()

                    cached_tiles =  np.argwhere(bitmap[v, 1, :, 0] == 1).flatten().tolist()

                    viewport_list = list(viewport)  # ensure Python list
                    ranked_tiles = net_adapter.rank_viewport_tiles(
                        v, viewport_list + cached_tiles, net_adapter.features, alpha=0.5
                    )

                    actions.append({
                        'video': v,
                        'gop': 0,
                        'tiles': ranked_tiles[:cfg.viewport],
                        'base_req_init': False
                    })

            # --- STEP ENV ---
            obs, reward, done, info = env.step(actions)

            # --- UPDATE USER HISTORY & VIDEO POPULARITY ---
            for req in reqs_state:
                v = req["video"]
                viewport = req["viewport"]
                net_adapter.features.update_history(v, viewport)
            
            reqs_next_state = info['users_requests']
            next_req_by_user = {r["u"]: r for r in reqs_next_state}
            
            for key, user_trans in user_transition.items():
                u = key
                
                if u not in next_req_by_user:
                    continue  # user not active in next state

                v = next_req_by_user[u]["video"]
                reward = info['reward_per_user'].get(u, 0.0)

                next_state = net_adapter.build_observation(v)

                agent.remember(
                    user_trans.state,
                    user_trans.action,
                    reward,
                    next_state,
                    float(done)
                )

            agent.train_step()

            total_reward_delta, hits_delta, misses_delta, soft_hits_delta = update_metrics(info, reward)
            total_reward += total_reward_delta
            cache_hits += hits_delta
            cache_misses += misses_delta
            soft_hits += soft_hits_delta

            if net_adapter.env_is_done():
                break

            # if req:
            #     print(f"Step {step}, Request State: User {req['u']}, Video {req['video']}, GOP {req['gop']}")
            # else:
            #     print(f"Step {step}, No active user requests.")

            # print(f"Episode {episode}, Step {step}, Active users: {len(reqs_state)} Reward: {reward:.2f}, Total Reward: {total_reward:.2f}, Cache Hits: {cache_hits}, Cache Misses: {cache_misses}, Soft Hits: {soft_hits:.2f}")
            # print("----------------------------------------------------------------")

        agent.update_epsilon()

        save_training_results(
            path_=cfg.path_results,
            filename=cfg.filename,
            ep=episode,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            soft_hits=soft_hits,
            agent=agent
        )

        print(f"--- Episode {episode} completed. Total Reward: {total_reward:.2f}, Cache Hits: {cache_hits}, Cache Misses: {cache_misses}, Total Requests: {len(env.total_gop_requests_per_user)} ---")
        # for key, val in env.total_gop_requests_per_user.items():
        #     print(f"User {key}: Total GOP Requests = {val}")
# Out:
# --- Starting DRL Caching System ---
# NetworkAdapter initialized with capacity: 50 videos, 4 tiles per video
# --- Episode 0 completed. Total Reward: 23479.75, Cache Hits: 163370, Cache Misses: 170262, Total Requests: 400 ---
# --- Episode 1 completed. Total Reward: 20222.20, Cache Hits: 146720, Cache Misses: 184800, Total Requests: 400 ---
# --- Episode 2 completed. Total Reward: 21412.82, Cache Hits: 147422, Cache Misses: 173522, Total Requests: 400 ---
# --- Episode 3 completed. Total Reward: 21804.30, Cache Hits: 161152, Cache Misses: 180560, Total Requests: 400 ---
# --- Episode 4 completed. Total Reward: 18626.67, Cache Hits: 156378, Cache Misses: 185526, Total Requests: 400 ---
# --- Episode 5 completed. Total Reward: 18012.31, Cache Hits: 147927, Cache Misses: 189641, Total Requests: 400 ---
# --- Episode 6 completed. Total Reward: 21408.33, Cache Hits: 161585, Cache Misses: 179231, Total Requests: 400 ---
# --- Episode 7 completed. Total Reward: 22015.27, Cache Hits: 157373, Cache Misses: 178483, Total Requests: 400 ---
# --- Episode 8 completed. Total Reward: 22066.85, Cache Hits: 168662, Cache Misses: 174730, Total Requests: 400 ---
# --- Episode 9 completed. Total Reward: 21924.22, Cache Hits: 147539, Cache Misses: 172125, Total Requests: 400 ---
# --- Episode 10 completed. Total Reward: 21307.18, Cache Hits: 148077, Cache Misses: 184339, Total Requests: 400 ---
# --- Episode 11 completed. Total Reward: 22447.96, Cache Hits: 150251, Cache Misses: 178245, Total Requests: 400 ---
# --- Episode 12 completed. Total Reward: 21302.01, Cache Hits: 164840, Cache Misses: 179288, Total Requests: 400 ---
# --- Episode 13 completed. Total Reward: 21332.63, Cache Hits: 146440, Cache Misses: 173752, Total Requests: 400 ---
# --- Episode 14 completed. Total Reward: 23801.34, Cache Hits: 155512, Cache Misses: 165272, Total Requests: 400 ---
# --- Episode 15 completed. Total Reward: 25334.66, Cache Hits: 170373, Cache Misses: 183355, Total Requests: 400 ---
# --- Episode 16 completed. Total Reward: 18914.15, Cache Hits: 164928, Cache Misses: 186096, Total Requests: 400 ---
# --- Episode 17 completed. Total Reward: 23938.82, Cache Hits: 151593, Cache Misses: 171015, Total Requests: 400 ---
# --- Episode 18 completed. Total Reward: 20756.29, Cache Hits: 158156, Cache Misses: 192516, Total Requests: 400 ---
# --- Episode 19 completed. Total Reward: 21934.26, Cache Hits: 145845, Cache Misses: 181899, Total Requests: 400 ---
# --- Episode 20 completed. Total Reward: 21955.11, Cache Hits: 159000, Cache Misses: 170744, Total Requests: 400 ---
# --- Episode 21 completed. Total Reward: 18724.53, Cache Hits: 150594, Cache Misses: 178830, Total Requests: 400 ---
# --- Episode 22 completed. Total Reward: 21800.05, Cache Hits: 161824, Cache Misses: 172400, Total Requests: 400 ---
# --- Episode 23 completed. Total Reward: 24045.54, Cache Hits: 162460, Cache Misses: 166548, Total Requests: 400 ---
# --- Episode 24 completed. Total Reward: 22515.53, Cache Hits: 156628, Cache Misses: 171004, Total Requests: 400 ---
# --- Episode 25 completed. Total Reward: 22571.63, Cache Hits: 163300, Cache Misses: 178428, Total Requests: 400 ---
# --- Episode 26 completed. Total Reward: 19356.54, Cache Hits: 151099, Cache Misses: 178965, Total Requests: 400 ---
# --- Episode 27 completed. Total Reward: 22425.20, Cache Hits: 167626, Cache Misses: 173766, Total Requests: 400 ---
# --- Episode 28 completed. Total Reward: 21187.80, Cache Hits: 157181, Cache Misses: 175635, Total Requests: 400 ---
# --- Episode 29 completed. Total Reward: 25138.87, Cache Hits: 161985, Cache Misses: 170991, Total Requests: 400 ---
# --- Episode 30 completed. Total Reward: 22664.77, Cache Hits: 157485, Cache Misses: 163635, Total Requests: 400 ---
# --- Episode 31 completed. Total Reward: 21682.39, Cache Hits: 158172, Cache Misses: 182708, Total Requests: 400 ---
# --- Episode 32 completed. Total Reward: 23512.77, Cache Hits: 160533, Cache Misses: 175067, Total Requests: 400 ---
# --- Episode 33 completed. Total Reward: 23761.11, Cache Hits: 172956, Cache Misses: 162964, Total Requests: 400 ---
# --- Episode 34 completed. Total Reward: 21992.83, Cache Hits: 161967, Cache Misses: 160417, Total Requests: 400 ---
# --- Episode 35 completed. Total Reward: 26572.35, Cache Hits: 164880, Cache Misses: 171888, Total Requests: 400 ---
# --- Episode 36 completed. Total Reward: 26450.11, Cache Hits: 167299, Cache Misses: 161101, Total Requests: 400 ---
# --- Episode 37 completed. Total Reward: 23016.15, Cache Hits: 163225, Cache Misses: 176183, Total Requests: 400 ---
# --- Episode 38 completed. Total Reward: 23846.66, Cache Hits: 166151, Cache Misses: 176553, Total Requests: 400 ---
# --- Episode 39 completed. Total Reward: 24738.88, Cache Hits: 164353, Cache Misses: 171471, Total Requests: 400 ---
# --- Episode 40 completed. Total Reward: 22771.98, Cache Hits: 163529, Cache Misses: 173879, Total Requests: 400 ---
# --- Episode 41 completed. Total Reward: 25215.13, Cache Hits: 165716, Cache Misses: 151836, Total Requests: 400 ---
# --- Episode 42 completed. Total Reward: 25334.73, Cache Hits: 171435, Cache Misses: 159909, Total Requests: 400 ---
# --- Episode 43 completed. Total Reward: 27076.37, Cache Hits: 166096, Cache Misses: 169104, Total Requests: 400 ---
# --- Episode 44 completed. Total Reward: 22487.14, Cache Hits: 161566, Cache Misses: 176482, Total Requests: 400 ---
# --- Episode 45 completed. Total Reward: 22078.53, Cache Hits: 161883, Cache Misses: 162293, Total Requests: 400 ---
# --- Episode 46 completed. Total Reward: 23806.91, Cache Hits: 165102, Cache Misses: 171538, Total Requests: 400 ---
# --- Episode 47 completed. Total Reward: 22670.64, Cache Hits: 173487, Cache Misses: 173377, Total Requests: 400 ---
# --- Episode 48 completed. Total Reward: 21600.17, Cache Hits: 159794, Cache Misses: 172862, Total Requests: 400 ---
# --- Episode 49 completed. Total Reward: 23191.54, Cache Hits: 166991, Cache Misses: 173281, Total Requests: 400 ---
# --- Episode 50 completed. Total Reward: 24388.11, Cache Hits: 166874, Cache Misses: 161222, Total Requests: 400 ---
# --- Episode 51 completed. Total Reward: 22942.40, Cache Hits: 171830, Cache Misses: 167258, Total Requests: 400 ---
# --- Episode 52 completed. Total Reward: 26543.40, Cache Hits: 179040, Cache Misses: 164464, Total Requests: 400 ---
# --- Episode 53 completed. Total Reward: 24603.21, Cache Hits: 164770, Cache Misses: 149470, Total Requests: 400 ---
# --- Episode 54 completed. Total Reward: 27941.65, Cache Hits: 174494, Cache Misses: 162514, Total Requests: 400 ---
# --- Episode 55 completed. Total Reward: 24846.83, Cache Hits: 181582, Cache Misses: 175986, Total Requests: 400 ---
# --- Episode 56 completed. Total Reward: 24854.65, Cache Hits: 169939, Cache Misses: 165741, Total Requests: 400 ---
# --- Episode 57 completed. Total Reward: 24648.80, Cache Hits: 169546, Cache Misses: 152230, Total Requests: 400 ---
# --- Episode 58 completed. Total Reward: 22177.30, Cache Hits: 166378, Cache Misses: 163814, Total Requests: 400 ---
# --- Episode 59 completed. Total Reward: 25922.71, Cache Hits: 162407, Cache Misses: 155321, Total Requests: 400 ---
# --- Episode 60 completed. Total Reward: 24174.88, Cache Hits: 162411, Cache Misses: 158149, Total Requests: 400 ---
# --- Episode 61 completed. Total Reward: 25486.73, Cache Hits: 160800, Cache Misses: 154464, Total Requests: 400 ---
# --- Episode 62 completed. Total Reward: 23017.98, Cache Hits: 169643, Cache Misses: 158533, Total Requests: 400 ---
# --- Episode 63 completed. Total Reward: 25291.49, Cache Hits: 161727, Cache Misses: 165361, Total Requests: 400 ---
# --- Episode 64 completed. Total Reward: 23413.98, Cache Hits: 157819, Cache Misses: 161349, Total Requests: 400 ---
# --- Episode 65 completed. Total Reward: 24576.57, Cache Hits: 163671, Cache Misses: 159417, Total Requests: 400 ---
# --- Episode 66 completed. Total Reward: 25258.48, Cache Hits: 175044, Cache Misses: 172316, Total Requests: 400 ---
# --- Episode 67 completed. Total Reward: 24591.07, Cache Hits: 166505, Cache Misses: 154119, Total Requests: 400 ---
# --- Episode 68 completed. Total Reward: 25749.51, Cache Hits: 171524, Cache Misses: 152220, Total Requests: 400 ---
# --- Episode 69 completed. Total Reward: 25021.09, Cache Hits: 175103, Cache Misses: 161809, Total Requests: 400 ---
# --- Episode 70 completed. Total Reward: 25080.08, Cache Hits: 172282, Cache Misses: 165942, Total Requests: 400 ---
# --- Episode 71 completed. Total Reward: 25535.65, Cache Hits: 172886, Cache Misses: 160218, Total Requests: 400 ---
# --- Episode 72 completed. Total Reward: 23667.42, Cache Hits: 175437, Cache Misses: 163123, Total Requests: 400 ---
# --- Episode 73 completed. Total Reward: 24014.88, Cache Hits: 168364, Cache Misses: 158452, Total Requests: 400 ---
# --- Episode 74 completed. Total Reward: 22836.88, Cache Hits: 157238, Cache Misses: 159082, Total Requests: 400 ---
# --- Episode 75 completed. Total Reward: 25080.14, Cache Hits: 176056, Cache Misses: 161240, Total Requests: 400 ---
# --- Episode 76 completed. Total Reward: 24620.51, Cache Hits: 168114, Cache Misses: 153038, Total Requests: 400 ---
# --- Episode 77 completed. Total Reward: 25521.41, Cache Hits: 179218, Cache Misses: 158318, Total Requests: 400 ---
# --- Episode 78 completed. Total Reward: 24433.47, Cache Hits: 171476, Cache Misses: 159948, Total Requests: 400 ---
# --- Episode 79 completed. Total Reward: 24943.54, Cache Hits: 164691, Cache Misses: 149149, Total Requests: 400 ---
# --- Episode 80 completed. Total Reward: 24895.27, Cache Hits: 168417, Cache Misses: 162207, Total Requests: 400 ---
# --- Episode 81 completed. Total Reward: 26319.69, Cache Hits: 166952, Cache Misses: 158264, Total Requests: 400 ---
# --- Episode 82 completed. Total Reward: 23829.59, Cache Hits: 165578, Cache Misses: 162662, Total Requests: 400 ---
# --- Episode 83 completed. Total Reward: 25591.87, Cache Hits: 186207, Cache Misses: 155937, Total Requests: 400 ---
# --- Episode 84 completed. Total Reward: 26794.09, Cache Hits: 182216, Cache Misses: 156936, Total Requests: 400 ---
# --- Episode 85 completed. Total Reward: 24676.46, Cache Hits: 181649, Cache Misses: 160031, Total Requests: 400 ---
# --- Episode 86 completed. Total Reward: 26677.33, Cache Hits: 181572, Cache Misses: 151468, Total Requests: 400 ---
# --- Episode 87 completed. Total Reward: 23537.20, Cache Hits: 168914, Cache Misses: 164190, Total Requests: 400 ---
# --- Episode 88 completed. Total Reward: 26591.86, Cache Hits: 179060, Cache Misses: 156012, Total Requests: 400 ---
# --- Episode 89 completed. Total Reward: 28695.99, Cache Hits: 162275, Cache Misses: 153501, Total Requests: 400 ---
# --- Episode 90 completed. Total Reward: 23305.64, Cache Hits: 176644, Cache Misses: 157724, Total Requests: 400 ---
# --- Episode 91 completed. Total Reward: 26195.89, Cache Hits: 181039, Cache Misses: 147169, Total Requests: 400 ---
# --- Episode 92 completed. Total Reward: 23374.31, Cache Hits: 170010, Cache Misses: 155622, Total Requests: 400 ---
# --- Episode 93 completed. Total Reward: 20632.60, Cache Hits: 156524, Cache Misses: 171156, Total Requests: 400 ---
# --- Episode 94 completed. Total Reward: 26573.74, Cache Hits: 171924, Cache Misses: 163372, Total Requests: 400 ---
# --- Episode 95 completed. Total Reward: 27926.89, Cache Hits: 172957, Cache Misses: 147715, Total Requests: 400 ---
# --- Episode 96 completed. Total Reward: 23975.10, Cache Hits: 176734, Cache Misses: 152930, Total Requests: 400 ---
# --- Episode 97 completed. Total Reward: 24289.39, Cache Hits: 167881, Cache Misses: 159799, Total Requests: 400 ---
# --- Episode 98 completed. Total Reward: 23610.13, Cache Hits: 169345, Cache Misses: 165887, Total Requests: 400 ---
# --- Episode 99 completed. Total Reward: 24401.15, Cache Hits: 171832, Cache Misses: 155304, Total Requests: 400 ---
# --- Episode 100 completed. Total Reward: 25565.78, Cache Hits: 181499, Cache Misses: 149605, Total Requests: 400 ---
# --- Episode 101 completed. Total Reward: 24417.01, Cache Hits: 179478, Cache Misses: 160474, Total Requests: 400 ---
# --- Episode 102 completed. Total Reward: 26791.82, Cache Hits: 177943, Cache Misses: 150953, Total Requests: 400 ---
# --- Episode 103 completed. Total Reward: 24498.22, Cache Hits: 181206, Cache Misses: 146330, Total Requests: 400 ---
# --- Episode 104 completed. Total Reward: 28947.75, Cache Hits: 172688, Cache Misses: 150480, Total Requests: 400 ---
# --- Episode 105 completed. Total Reward: 24539.80, Cache Hits: 169605, Cache Misses: 154699, Total Requests: 400 ---
# --- Episode 106 completed. Total Reward: 26267.10, Cache Hits: 179716, Cache Misses: 149404, Total Requests: 400 ---
# --- Episode 107 completed. Total Reward: 24003.11, Cache Hits: 183353, Cache Misses: 163767, Total Requests: 400 ---
# --- Episode 108 completed. Total Reward: 27343.56, Cache Hits: 176032, Cache Misses: 140160, Total Requests: 400 ---
# --- Episode 109 completed. Total Reward: 24170.24, Cache Hits: 189103, Cache Misses: 155233, Total Requests: 400 ---
# --- Episode 110 completed. Total Reward: 24289.27, Cache Hits: 185736, Cache Misses: 150504, Total Requests: 400 ---
# --- Episode 111 completed. Total Reward: 26241.88, Cache Hits: 192348, Cache Misses: 160612, Total Requests: 400 ---
# --- Episode 112 completed. Total Reward: 27550.97, Cache Hits: 177202, Cache Misses: 149358, Total Requests: 400 ---
# --- Episode 113 completed. Total Reward: 24313.12, Cache Hits: 180119, Cache Misses: 153193, Total Requests: 400 ---
# --- Episode 114 completed. Total Reward: 25432.23, Cache Hits: 181641, Cache Misses: 147335, Total Requests: 400 ---
# --- Episode 115 completed. Total Reward: 29372.61, Cache Hits: 186123, Cache Misses: 161717, Total Requests: 400 ---
# --- Episode 116 completed. Total Reward: 28273.63, Cache Hits: 166715, Cache Misses: 142229, Total Requests: 400 ---
# --- Episode 117 completed. Total Reward: 26945.81, Cache Hits: 186520, Cache Misses: 160808, Total Requests: 400 ---
# --- Episode 118 completed. Total Reward: 23651.48, Cache Hits: 175238, Cache Misses: 145706, Total Requests: 400 ---
# --- Episode 119 completed. Total Reward: 27387.70, Cache Hits: 173576, Cache Misses: 154888, Total Requests: 400 ---
# --- Episode 120 completed. Total Reward: 24289.62, Cache Hits: 172211, Cache Misses: 161469, Total Requests: 400 ---
# --- Episode 121 completed. Total Reward: 24864.63, Cache Hits: 178059, Cache Misses: 163285, Total Requests: 400 ---
# --- Episode 122 completed. Total Reward: 25907.73, Cache Hits: 177446, Cache Misses: 148986, Total Requests: 400 ---
# --- Episode 123 completed. Total Reward: 26167.53, Cache Hits: 188755, Cache Misses: 161277, Total Requests: 400 ---
# --- Episode 124 completed. Total Reward: 25261.44, Cache Hits: 176480, Cache Misses: 146896, Total Requests: 400 ---
# --- Episode 125 completed. Total Reward: 25960.51, Cache Hits: 183579, Cache Misses: 157285, Total Requests: 400 ---
# --- Episode 126 completed. Total Reward: 24101.18, Cache Hits: 172205, Cache Misses: 140563, Total Requests: 400 ---
# --- Episode 127 completed. Total Reward: 29619.33, Cache Hits: 193339, Cache Misses: 160389, Total Requests: 400 ---
# --- Episode 128 completed. Total Reward: 26177.16, Cache Hits: 183750, Cache Misses: 151002, Total Requests: 400 ---
# --- Episode 129 completed. Total Reward: 27960.10, Cache Hits: 183299, Cache Misses: 149357, Total Requests: 400 ---
# --- Episode 130 completed. Total Reward: 24928.65, Cache Hits: 183340, Cache Misses: 152628, Total Requests: 400 ---
# --- Episode 131 completed. Total Reward: 25657.32, Cache Hits: 182193, Cache Misses: 156751, Total Requests: 400 ---
# --- Episode 132 completed. Total Reward: 29651.29, Cache Hits: 185629, Cache Misses: 147427, Total Requests: 400 ---
# --- Episode 133 completed. Total Reward: 25957.13, Cache Hits: 183232, Cache Misses: 152992, Total Requests: 400 ---
# --- Episode 134 completed. Total Reward: 31037.13, Cache Hits: 182879, Cache Misses: 148433, Total Requests: 400 ---
# --- Episode 135 completed. Total Reward: 30496.86, Cache Hits: 191889, Cache Misses: 149151, Total Requests: 400 ---
# --- Episode 136 completed. Total Reward: 25128.12, Cache Hits: 177561, Cache Misses: 153111, Total Requests: 400 ---
# --- Episode 137 completed. Total Reward: 26572.59, Cache Hits: 184759, Cache Misses: 140553, Total Requests: 400 ---
# --- Episode 138 completed. Total Reward: 28399.26, Cache Hits: 187091, Cache Misses: 160589, Total Requests: 400 ---
# --- Episode 139 completed. Total Reward: 25649.14, Cache Hits: 177972, Cache Misses: 155212, Total Requests: 400 ---
# --- Episode 140 completed. Total Reward: 25957.05, Cache Hits: 170446, Cache Misses: 133602, Total Requests: 400 ---
# --- Episode 141 completed. Total Reward: 27290.50, Cache Hits: 182553, Cache Misses: 152647, Total Requests: 400 ---
# --- Episode 142 completed. Total Reward: 24679.16, Cache Hits: 186101, Cache Misses: 164267, Total Requests: 400 ---
# --- Episode 143 completed. Total Reward: 25734.64, Cache Hits: 177606, Cache Misses: 145034, Total Requests: 400 ---
# --- Episode 144 completed. Total Reward: 28015.28, Cache Hits: 186946, Cache Misses: 151982, Total Requests: 400 ---
# --- Episode 145 completed. Total Reward: 28515.83, Cache Hits: 183820, Cache Misses: 143988, Total Requests: 400 ---
# --- Episode 146 completed. Total Reward: 28233.77, Cache Hits: 185159, Cache Misses: 150537, Total Requests: 400 ---
# --- Episode 147 completed. Total Reward: 28875.15, Cache Hits: 190212, Cache Misses: 142284, Total Requests: 400 ---
# --- Episode 148 completed. Total Reward: 26991.42, Cache Hits: 187248, Cache Misses: 147248, Total Requests: 400 ---
# --- Episode 149 completed. Total Reward: 28099.99, Cache Hits: 183328, Cache Misses: 142880, Total Requests: 400 ---
# --- Episode 150 completed. Total Reward: 27239.38, Cache Hits: 188532, Cache Misses: 152076, Total Requests: 400 ---
# --- Episode 151 completed. Total Reward: 26841.38, Cache Hits: 173161, Cache Misses: 141671, Total Requests: 400 ---
# --- Episode 152 completed. Total Reward: 25916.29, Cache Hits: 184234, Cache Misses: 146790, Total Requests: 400 ---
# --- Episode 153 completed. Total Reward: 26534.62, Cache Hits: 176432, Cache Misses: 147728, Total Requests: 400 ---
# --- Episode 154 completed. Total Reward: 25384.93, Cache Hits: 189398, Cache Misses: 150458, Total Requests: 400 ---
# --- Episode 155 completed. Total Reward: 28004.45, Cache Hits: 191541, Cache Misses: 149739, Total Requests: 400 ---
# --- Episode 156 completed. Total Reward: 26226.29, Cache Hits: 184993, Cache Misses: 151919, Total Requests: 400 ---
# --- Episode 157 completed. Total Reward: 26434.17, Cache Hits: 180609, Cache Misses: 146495, Total Requests: 400 ---
# --- Episode 158 completed. Total Reward: 25753.63, Cache Hits: 198228, Cache Misses: 153324, Total Requests: 400 ---
# --- Episode 159 completed. Total Reward: 25124.87, Cache Hits: 177511, Cache Misses: 151113, Total Requests: 400 ---
# --- Episode 160 completed. Total Reward: 25958.03, Cache Hits: 189294, Cache Misses: 150626, Total Requests: 400 ---
# --- Episode 161 completed. Total Reward: 27883.13, Cache Hits: 180291, Cache Misses: 145149, Total Requests: 400 ---
# --- Episode 162 completed. Total Reward: 25223.32, Cache Hits: 177505, Cache Misses: 146495, Total Requests: 400 ---
# --- Episode 163 completed. Total Reward: 25044.05, Cache Hits: 178505, Cache Misses: 144759, Total Requests: 400 ---
# --- Episode 164 completed. Total Reward: 27228.40, Cache Hits: 188509, Cache Misses: 143011, Total Requests: 400 ---
# --- Episode 165 completed. Total Reward: 29454.88, Cache Hits: 194688, Cache Misses: 150304, Total Requests: 400 ---
# --- Episode 166 completed. Total Reward: 28272.30, Cache Hits: 189879, Cache Misses: 140457, Total Requests: 400 ---
# --- Episode 167 completed. Total Reward: 28011.22, Cache Hits: 174533, Cache Misses: 144283, Total Requests: 400 ---
# --- Episode 168 completed. Total Reward: 26223.39, Cache Hits: 184254, Cache Misses: 153250, Total Requests: 400 ---
# --- Episode 169 completed. Total Reward: 28635.63, Cache Hits: 193902, Cache Misses: 147298, Total Requests: 400 ---
# --- Episode 170 completed. Total Reward: 24962.85, Cache Hits: 178999, Cache Misses: 153625, Total Requests: 400 ---
# --- Episode 171 completed. Total Reward: 24820.47, Cache Hits: 177028, Cache Misses: 148716, Total Requests: 400 ---
# --- Episode 172 completed. Total Reward: 25356.73, Cache Hits: 185317, Cache Misses: 135851, Total Requests: 400 ---
# --- Episode 173 completed. Total Reward: 25325.26, Cache Hits: 191063, Cache Misses: 154137, Total Requests: 400 ---
# --- Episode 174 completed. Total Reward: 28669.94, Cache Hits: 185987, Cache Misses: 142765, Total Requests: 400 ---
# --- Episode 175 completed. Total Reward: 26478.19, Cache Hits: 182362, Cache Misses: 141846, Total Requests: 400 ---
# --- Episode 176 completed. Total Reward: 26305.48, Cache Hits: 179998, Cache Misses: 140146, Total Requests: 400 ---
# --- Episode 177 completed. Total Reward: 29881.23, Cache Hits: 181433, Cache Misses: 137143, Total Requests: 400 ---
# --- Episode 178 completed. Total Reward: 29994.96, Cache Hits: 187779, Cache Misses: 148669, Total Requests: 400 ---
# --- Episode 179 completed. Total Reward: 28699.35, Cache Hits: 184377, Cache Misses: 134647, Total Requests: 400 ---
# --- Episode 180 completed. Total Reward: 28295.44, Cache Hits: 183819, Cache Misses: 143605, Total Requests: 400 ---
# --- Episode 181 completed. Total Reward: 27165.72, Cache Hits: 189885, Cache Misses: 146339, Total Requests: 400 ---
# --- Episode 182 completed. Total Reward: 27916.19, Cache Hits: 187172, Cache Misses: 152588, Total Requests: 400 ---
# --- Episode 183 completed. Total Reward: 28721.86, Cache Hits: 185152, Cache Misses: 136576, Total Requests: 400 ---
# --- Episode 184 completed. Total Reward: 27040.11, Cache Hits: 187323, Cache Misses: 153781, Total Requests: 400 ---
# --- Episode 185 completed. Total Reward: 26384.69, Cache Hits: 185380, Cache Misses: 147948, Total Requests: 400 ---
# --- Episode 186 completed. Total Reward: 28096.81, Cache Hits: 179775, Cache Misses: 142769, Total Requests: 400 ---
# --- Episode 187 completed. Total Reward: 26377.36, Cache Hits: 175501, Cache Misses: 140995, Total Requests: 400 ---
# --- Episode 188 completed. Total Reward: 27400.87, Cache Hits: 187551, Cache Misses: 145649, Total Requests: 400 ---
# --- Episode 189 completed. Total Reward: 28655.38, Cache Hits: 195693, Cache Misses: 149603, Total Requests: 400 ---
# --- Episode 190 completed. Total Reward: 27069.78, Cache Hits: 186488, Cache Misses: 143944, Total Requests: 400 ---
# --- Episode 191 completed. Total Reward: 27892.86, Cache Hits: 186991, Cache Misses: 137777, Total Requests: 400 ---
# --- Episode 192 completed. Total Reward: 27137.56, Cache Hits: 194293, Cache Misses: 148779, Total Requests: 400 ---
# --- Episode 193 completed. Total Reward: 26162.91, Cache Hits: 187148, Cache Misses: 151844, Total Requests: 400 ---
# --- Episode 194 completed. Total Reward: 25893.49, Cache Hits: 188675, Cache Misses: 147981, Total Requests: 400 ---
# --- Episode 195 completed. Total Reward: 28712.97, Cache Hits: 207403, Cache Misses: 149813, Total Requests: 400 ---
# --- Episode 196 completed. Total Reward: 26349.02, Cache Hits: 174868, Cache Misses: 134428, Total Requests: 400 ---
# --- Episode 197 completed. Total Reward: 27788.94, Cache Hits: 195776, Cache Misses: 135952, Total Requests: 400 ---
# --- Episode 198 completed. Total Reward: 28346.61, Cache Hits: 187423, Cache Misses: 139889, Total Requests: 400 ---
# --- Episode 199 completed. Total Reward: 30149.42, Cache Hits: 195999, Cache Misses: 138273, Total Requests: 400 ---
# --- Episode 200 completed. Total Reward: 25472.07, Cache Hits: 189696, Cache Misses: 150160, Total Requests: 400 ---
# --- Episode 201 completed. Total Reward: 28907.80, Cache Hits: 189130, Cache Misses: 140870, Total Requests: 400 ---
# --- Episode 202 completed. Total Reward: 27457.99, Cache Hits: 186250, Cache Misses: 140710, Total Requests: 400 ---
# --- Episode 203 completed. Total Reward: 29595.63, Cache Hits: 193046, Cache Misses: 137658, Total Requests: 400 ---
# --- Episode 204 completed. Total Reward: 27548.46, Cache Hits: 185426, Cache Misses: 141022, Total Requests: 400 ---
# --- Episode 205 completed. Total Reward: 30194.54, Cache Hits: 195026, Cache Misses: 137950, Total Requests: 400 ---
# --- Episode 206 completed. Total Reward: 27683.19, Cache Hits: 199425, Cache Misses: 147391, Total Requests: 400 ---
# --- Episode 207 completed. Total Reward: 29802.07, Cache Hits: 192028, Cache Misses: 139268, Total Requests: 400 ---
# --- Episode 208 completed. Total Reward: 30152.34, Cache Hits: 195113, Cache Misses: 141159, Total Requests: 400 ---
# --- Episode 209 completed. Total Reward: 25299.69, Cache Hits: 185488, Cache Misses: 145312, Total Requests: 400 ---
# --- Episode 210 completed. Total Reward: 28435.04, Cache Hits: 194262, Cache Misses: 136522, Total Requests: 400 ---
# --- Episode 211 completed. Total Reward: 26261.48, Cache Hits: 191435, Cache Misses: 147317, Total Requests: 400 ---
# --- Episode 212 completed. Total Reward: 27469.56, Cache Hits: 191688, Cache Misses: 147288, Total Requests: 400 ---
# --- Episode 213 completed. Total Reward: 26410.51, Cache Hits: 185820, Cache Misses: 148244, Total Requests: 400 ---
# --- Episode 214 completed. Total Reward: 25742.89, Cache Hits: 178779, Cache Misses: 134565, Total Requests: 400 ---
# --- Episode 215 completed. Total Reward: 31255.84, Cache Hits: 199509, Cache Misses: 143259, Total Requests: 400 ---
# --- Episode 216 completed. Total Reward: 28459.87, Cache Hits: 198266, Cache Misses: 139958, Total Requests: 400 ---
# --- Episode 217 completed. Total Reward: 26312.92, Cache Hits: 192038, Cache Misses: 142634, Total Requests: 400 ---
# --- Episode 218 completed. Total Reward: 28885.23, Cache Hits: 183992, Cache Misses: 143256, Total Requests: 400 ---
# --- Episode 219 completed. Total Reward: 27795.46, Cache Hits: 195306, Cache Misses: 147526, Total Requests: 400 ---
# --- Episode 220 completed. Total Reward: 28064.82, Cache Hits: 185540, Cache Misses: 139772, Total Requests: 400 ---
# --- Episode 221 completed. Total Reward: 29588.62, Cache Hits: 190314, Cache Misses: 140886, Total Requests: 400 ---
# --- Episode 222 completed. Total Reward: 26725.19, Cache Hits: 189215, Cache Misses: 143297, Total Requests: 400 ---
# --- Episode 223 completed. Total Reward: 26231.17, Cache Hits: 187900, Cache Misses: 143428, Total Requests: 400 ---
# --- Episode 224 completed. Total Reward: 29081.32, Cache Hits: 184587, Cache Misses: 141157, Total Requests: 400 ---
# --- Episode 225 completed. Total Reward: 28905.47, Cache Hits: 181824, Cache Misses: 137600, Total Requests: 400 ---
# --- Episode 226 completed. Total Reward: 28242.53, Cache Hits: 197943, Cache Misses: 141593, Total Requests: 400 ---
# --- Episode 227 completed. Total Reward: 24932.99, Cache Hits: 189189, Cache Misses: 144875, Total Requests: 400 ---
# --- Episode 228 completed. Total Reward: 26929.03, Cache Hits: 187975, Cache Misses: 137033, Total Requests: 400 ---
# --- Episode 229 completed. Total Reward: 26571.40, Cache Hits: 192440, Cache Misses: 146536, Total Requests: 400 ---
# --- Episode 230 completed. Total Reward: 29107.71, Cache Hits: 181747, Cache Misses: 144477, Total Requests: 400 ---
# --- Episode 231 completed. Total Reward: 27990.02, Cache Hits: 194033, Cache Misses: 141711, Total Requests: 400 ---
# --- Episode 232 completed. Total Reward: 28173.49, Cache Hits: 194526, Cache Misses: 137250, Total Requests: 400 ---
# --- Episode 233 completed. Total Reward: 28827.63, Cache Hits: 190181, Cache Misses: 140651, Total Requests: 400 ---
# --- Episode 234 completed. Total Reward: 30740.44, Cache Hits: 199780, Cache Misses: 135628, Total Requests: 400 ---
# --- Episode 235 completed. Total Reward: 29489.73, Cache Hits: 185444, Cache Misses: 132348, Total Requests: 400 ---
# --- Episode 236 completed. Total Reward: 27989.73, Cache Hits: 193648, Cache Misses: 141472, Total Requests: 400 ---
# --- Episode 237 completed. Total Reward: 28470.31, Cache Hits: 191150, Cache Misses: 143570, Total Requests: 400 ---
# --- Episode 238 completed. Total Reward: 30799.81, Cache Hits: 203017, Cache Misses: 145671, Total Requests: 400 ---
# --- Episode 239 completed. Total Reward: 28592.72, Cache Hits: 194436, Cache Misses: 142188, Total Requests: 400 ---
# --- Episode 240 completed. Total Reward: 26974.18, Cache Hits: 191642, Cache Misses: 135414, Total Requests: 400 ---
# --- Episode 241 completed. Total Reward: 28998.22, Cache Hits: 188343, Cache Misses: 144713, Total Requests: 400 ---
# --- Episode 242 completed. Total Reward: 27292.59, Cache Hits: 185763, Cache Misses: 131885, Total Requests: 400 ---
# --- Episode 243 completed. Total Reward: 28792.55, Cache Hits: 195075, Cache Misses: 132077, Total Requests: 400 ---
# --- Episode 244 completed. Total Reward: 24771.85, Cache Hits: 175608, Cache Misses: 140312, Total Requests: 400 ---
# --- Episode 245 completed. Total Reward: 30465.71, Cache Hits: 197928, Cache Misses: 141176, Total Requests: 400 ---
# --- Episode 246 completed. Total Reward: 26520.63, Cache Hits: 183933, Cache Misses: 124707, Total Requests: 400 ---
# --- Episode 247 completed. Total Reward: 26534.08, Cache Hits: 193703, Cache Misses: 141481, Total Requests: 400 ---
# --- Episode 248 completed. Total Reward: 29874.36, Cache Hits: 189672, Cache Misses: 139144, Total Requests: 400 ---
# --- Episode 249 completed. Total Reward: 31105.27, Cache Hits: 192168, Cache Misses: 135768, Total Requests: 400 ---
# --- Episode 250 completed. Total Reward: 27193.24, Cache Hits: 188691, Cache Misses: 131469, Total Requests: 400 ---
# --- Episode 251 completed. Total Reward: 26864.61, Cache Hits: 187271, Cache Misses: 142649, Total Requests: 400 ---
# --- Episode 252 completed. Total Reward: 30276.53, Cache Hits: 191199, Cache Misses: 132961, Total Requests: 400 ---
# --- Episode 253 completed. Total Reward: 26656.95, Cache Hits: 190105, Cache Misses: 142999, Total Requests: 400 ---
# --- Episode 254 completed. Total Reward: 29376.02, Cache Hits: 201011, Cache Misses: 135421, Total Requests: 400 ---
# --- Episode 255 completed. Total Reward: 26951.67, Cache Hits: 197321, Cache Misses: 140775, Total Requests: 400 ---
# --- Episode 256 completed. Total Reward: 28306.06, Cache Hits: 190860, Cache Misses: 134980, Total Requests: 400 ---
# --- Episode 257 completed. Total Reward: 27762.74, Cache Hits: 208046, Cache Misses: 142562, Total Requests: 400 ---
# --- Episode 258 completed. Total Reward: 31740.69, Cache Hits: 190464, Cache Misses: 129008, Total Requests: 400 ---
# --- Episode 259 completed. Total Reward: 27816.07, Cache Hits: 182324, Cache Misses: 139068, Total Requests: 400 ---
# --- Episode 260 completed. Total Reward: 26165.43, Cache Hits: 195132, Cache Misses: 139204, Total Requests: 400 ---
# --- Episode 261 completed. Total Reward: 25556.50, Cache Hits: 197948, Cache Misses: 150212, Total Requests: 400 ---
# --- Episode 262 completed. Total Reward: 27281.07, Cache Hits: 201364, Cache Misses: 139084, Total Requests: 400 ---
# --- Episode 263 completed. Total Reward: 30722.06, Cache Hits: 188863, Cache Misses: 133249, Total Requests: 400 ---
# --- Episode 264 completed. Total Reward: 28230.74, Cache Hits: 198390, Cache Misses: 133050, Total Requests: 400 ---
# --- Episode 265 completed. Total Reward: 27669.49, Cache Hits: 184492, Cache Misses: 134356, Total Requests: 400 ---
# --- Episode 266 completed. Total Reward: 27867.70, Cache Hits: 191178, Cache Misses: 138038, Total Requests: 400 ---
# --- Episode 267 completed. Total Reward: 24815.83, Cache Hits: 191859, Cache Misses: 139869, Total Requests: 400 ---
# --- Episode 268 completed. Total Reward: 27909.43, Cache Hits: 204728, Cache Misses: 147992, Total Requests: 400 ---
# --- Episode 269 completed. Total Reward: 28734.10, Cache Hits: 192740, Cache Misses: 140828, Total Requests: 400 ---
# --- Episode 270 completed. Total Reward: 28807.91, Cache Hits: 193701, Cache Misses: 129403, Total Requests: 400 ---
# --- Episode 271 completed. Total Reward: 28486.09, Cache Hits: 194924, Cache Misses: 144916, Total Requests: 400 ---
# --- Episode 272 completed. Total Reward: 30613.96, Cache Hits: 197748, Cache Misses: 134972, Total Requests: 400 ---
# --- Episode 273 completed. Total Reward: 28920.64, Cache Hits: 186664, Cache Misses: 138680, Total Requests: 400 ---
# --- Episode 274 completed. Total Reward: 29895.22, Cache Hits: 191559, Cache Misses: 129561, Total Requests: 400 ---
# --- Episode 275 completed. Total Reward: 27260.87, Cache Hits: 196758, Cache Misses: 150234, Total Requests: 400 ---
# --- Episode 276 completed. Total Reward: 28898.12, Cache Hits: 194920, Cache Misses: 144328, Total Requests: 400 ---
# --- Episode 277 completed. Total Reward: 29955.42, Cache Hits: 184700, Cache Misses: 132036, Total Requests: 400 ---
# --- Episode 278 completed. Total Reward: 28394.77, Cache Hits: 184235, Cache Misses: 136581, Total Requests: 400 ---
# --- Episode 279 completed. Total Reward: 29813.89, Cache Hits: 202057, Cache Misses: 138647, Total Requests: 400 ---
# --- Episode 280 completed. Total Reward: 26747.00, Cache Hits: 192499, Cache Misses: 135517, Total Requests: 400 ---
# --- Episode 281 completed. Total Reward: 25875.13, Cache Hits: 188320, Cache Misses: 146976, Total Requests: 400 ---
# --- Episode 282 completed. Total Reward: 31451.19, Cache Hits: 193204, Cache Misses: 139196, Total Requests: 400 ---
# --- Episode 283 completed. Total Reward: 29650.36, Cache Hits: 194378, Cache Misses: 137398, Total Requests: 400 ---
# --- Episode 284 completed. Total Reward: 30836.43, Cache Hits: 198286, Cache Misses: 135490, Total Requests: 400 ---
# --- Episode 285 completed. Total Reward: 29097.20, Cache Hits: 192092, Cache Misses: 136020, Total Requests: 400 ---
# --- Episode 286 completed. Total Reward: 28456.60, Cache Hits: 194858, Cache Misses: 132662, Total Requests: 400 ---
# --- Episode 287 completed. Total Reward: 28886.83, Cache Hits: 195485, Cache Misses: 145411, Total Requests: 400 ---
# --- Episode 288 completed. Total Reward: 23229.59, Cache Hits: 190343, Cache Misses: 135401, Total Requests: 400 ---
# --- Episode 289 completed. Total Reward: 31308.10, Cache Hits: 202308, Cache Misses: 138588, Total Requests: 400 ---
# --- Episode 290 completed. Total Reward: 31115.19, Cache Hits: 202368, Cache Misses: 141120, Total Requests: 400 ---
# --- Episode 291 completed. Total Reward: 26943.85, Cache Hits: 192454, Cache Misses: 149306, Total Requests: 400 ---
# --- Episode 292 completed. Total Reward: 27895.69, Cache Hits: 196196, Cache Misses: 139708, Total Requests: 400 ---
# --- Episode 293 completed. Total Reward: 29941.31, Cache Hits: 192112, Cache Misses: 141136, Total Requests: 400 ---
# --- Episode 294 completed. Total Reward: 30882.11, Cache Hits: 190703, Cache Misses: 141089, Total Requests: 400 ---
# --- Episode 295 completed. Total Reward: 27770.92, Cache Hits: 191600, Cache Misses: 141632, Total Requests: 400 ---
# --- Episode 296 completed. Total Reward: 28294.05, Cache Hits: 191691, Cache Misses: 133781, Total Requests: 400 ---
# --- Episode 297 completed. Total Reward: 27348.04, Cache Hits: 198721, Cache Misses: 137887, Total Requests: 400 ---
# --- Episode 298 completed. Total Reward: 30075.90, Cache Hits: 189331, Cache Misses: 134557, Total Requests: 400 ---
# --- Episode 299 completed. Total Reward: 29868.07, Cache Hits: 200743, Cache Misses: 137881, Total Requests: 400 ---
# --- Episode 300 completed. Total Reward: 29042.97, Cache Hits: 185478, Cache Misses: 133018, Total Requests: 400 ---
# --- Episode 301 completed. Total Reward: 28012.42, Cache Hits: 188820, Cache Misses: 144204, Total Requests: 400 ---
# --- Episode 302 completed. Total Reward: 34041.36, Cache Hits: 197344, Cache Misses: 148672, Total Requests: 400 ---
# --- Episode 303 completed. Total Reward: 30613.22, Cache Hits: 202050, Cache Misses: 134750, Total Requests: 400 ---
# --- Episode 304 completed. Total Reward: 27833.98, Cache Hits: 206056, Cache Misses: 150616, Total Requests: 400 ---
# --- Episode 305 completed. Total Reward: 29370.04, Cache Hits: 189337, Cache Misses: 137543, Total Requests: 400 ---
# --- Episode 306 completed. Total Reward: 25787.64, Cache Hits: 190659, Cache Misses: 132909, Total Requests: 400 ---
# --- Episode 307 completed. Total Reward: 27489.01, Cache Hits: 200443, Cache Misses: 139765, Total Requests: 400 ---
# --- Episode 308 completed. Total Reward: 29007.15, Cache Hits: 196509, Cache Misses: 147571, Total Requests: 400 ---
# --- Episode 309 completed. Total Reward: 26258.13, Cache Hits: 198035, Cache Misses: 136701, Total Requests: 400 ---
# --- Episode 310 completed. Total Reward: 28072.67, Cache Hits: 189509, Cache Misses: 130587, Total Requests: 400 ---
# --- Episode 311 completed. Total Reward: 27278.79, Cache Hits: 192578, Cache Misses: 125182, Total Requests: 400 ---
# --- Episode 312 completed. Total Reward: 24694.79, Cache Hits: 191873, Cache Misses: 143055, Total Requests: 400 ---
# --- Episode 313 completed. Total Reward: 27473.27, Cache Hits: 189835, Cache Misses: 138949, Total Requests: 400 ---
# --- Episode 314 completed. Total Reward: 28046.98, Cache Hits: 200205, Cache Misses: 148195, Total Requests: 400 ---
# --- Episode 315 completed. Total Reward: 27540.15, Cache Hits: 197937, Cache Misses: 137071, Total Requests: 400 ---
# --- Episode 316 completed. Total Reward: 30998.74, Cache Hits: 201188, Cache Misses: 139260, Total Requests: 400 ---
# --- Episode 317 completed. Total Reward: 28507.03, Cache Hits: 200606, Cache Misses: 127394, Total Requests: 400 ---
# --- Episode 318 completed. Total Reward: 28010.81, Cache Hits: 194035, Cache Misses: 141517, Total Requests: 400 ---
# --- Episode 319 completed. Total Reward: 27397.51, Cache Hits: 196071, Cache Misses: 135593, Total Requests: 400 ---
# --- Episode 320 completed. Total Reward: 28437.17, Cache Hits: 189943, Cache Misses: 132473, Total Requests: 400 ---
# --- Episode 321 completed. Total Reward: 32149.08, Cache Hits: 195905, Cache Misses: 133343, Total Requests: 400 ---
# --- Episode 322 completed. Total Reward: 29230.91, Cache Hits: 196612, Cache Misses: 135212, Total Requests: 400 ---
# --- Episode 323 completed. Total Reward: 30166.89, Cache Hits: 194063, Cache Misses: 128689, Total Requests: 400 ---
# --- Episode 324 completed. Total Reward: 24290.92, Cache Hits: 197942, Cache Misses: 144266, Total Requests: 400 ---
# --- Episode 325 completed. Total Reward: 25517.41, Cache Hits: 196788, Cache Misses: 150908, Total Requests: 400 ---
# --- Episode 326 completed. Total Reward: 31457.77, Cache Hits: 202333, Cache Misses: 134371, Total Requests: 400 ---
# --- Episode 327 completed. Total Reward: 28123.66, Cache Hits: 195232, Cache Misses: 135568, Total Requests: 400 ---
# --- Episode 328 completed. Total Reward: 31437.63, Cache Hits: 202480, Cache Misses: 127584, Total Requests: 400 ---
# --- Episode 329 completed. Total Reward: 27508.30, Cache Hits: 204336, Cache Misses: 141184, Total Requests: 400 ---
# --- Episode 330 completed. Total Reward: 27118.27, Cache Hits: 194868, Cache Misses: 148172, Total Requests: 400 ---
# --- Episode 331 completed. Total Reward: 30655.49, Cache Hits: 206046, Cache Misses: 134034, Total Requests: 400 ---
# --- Episode 332 completed. Total Reward: 31065.01, Cache Hits: 198789, Cache Misses: 129499, Total Requests: 400 ---
# --- Episode 333 completed. Total Reward: 28178.45, Cache Hits: 197949, Cache Misses: 135907, Total Requests: 400 ---
# --- Episode 334 completed. Total Reward: 31507.49, Cache Hits: 192812, Cache Misses: 140020, Total Requests: 400 ---
# --- Episode 335 completed. Total Reward: 26764.50, Cache Hits: 188192, Cache Misses: 139504, Total Requests: 400 ---
# --- Episode 336 completed. Total Reward: 30787.79, Cache Hits: 198115, Cache Misses: 129197, Total Requests: 400 ---
# --- Episode 337 completed. Total Reward: 29859.56, Cache Hits: 207900, Cache Misses: 145652, Total Requests: 400 ---
# --- Episode 338 completed. Total Reward: 28526.92, Cache Hits: 199468, Cache Misses: 128324, Total Requests: 400 ---
# --- Episode 339 completed. Total Reward: 27802.60, Cache Hits: 190437, Cache Misses: 133291, Total Requests: 400 ---
# --- Episode 340 completed. Total Reward: 30287.31, Cache Hits: 211562, Cache Misses: 136614, Total Requests: 400 ---
# --- Episode 341 completed. Total Reward: 28216.52, Cache Hits: 198956, Cache Misses: 138788, Total Requests: 400 ---
# --- Episode 342 completed. Total Reward: 28619.61, Cache Hits: 193849, Cache Misses: 136119, Total Requests: 400 ---
# --- Episode 343 completed. Total Reward: 28511.38, Cache Hits: 188446, Cache Misses: 127666, Total Requests: 400 ---
# --- Episode 344 completed. Total Reward: 30474.77, Cache Hits: 196902, Cache Misses: 137882, Total Requests: 400 ---
# --- Episode 345 completed. Total Reward: 22847.44, Cache Hits: 187566, Cache Misses: 156866, Total Requests: 400 ---
# --- Episode 346 completed. Total Reward: 26637.43, Cache Hits: 201568, Cache Misses: 135040, Total Requests: 400 ---
# --- Episode 347 completed. Total Reward: 26229.54, Cache Hits: 192771, Cache Misses: 146717, Total Requests: 400 ---
# --- Episode 348 completed. Total Reward: 27255.70, Cache Hits: 195181, Cache Misses: 132867, Total Requests: 400 ---
# --- Episode 349 completed. Total Reward: 29079.82, Cache Hits: 186140, Cache Misses: 125572, Total Requests: 400 ---
# --- Episode 350 completed. Total Reward: 35073.49, Cache Hits: 204996, Cache Misses: 123196, Total Requests: 400 ---
# --- Episode 351 completed. Total Reward: 30744.00, Cache Hits: 197689, Cache Misses: 141479, Total Requests: 400 ---
# --- Episode 352 completed. Total Reward: 29023.72, Cache Hits: 181990, Cache Misses: 139370, Total Requests: 400 ---
# --- Episode 353 completed. Total Reward: 33710.14, Cache Hits: 201586, Cache Misses: 133918, Total Requests: 400 ---
# --- Episode 354 completed. Total Reward: 26923.98, Cache Hits: 193633, Cache Misses: 135343, Total Requests: 400 ---
# --- Episode 355 completed. Total Reward: 24436.00, Cache Hits: 196031, Cache Misses: 136929, Total Requests: 400 ---
# --- Episode 356 completed. Total Reward: 30408.35, Cache Hits: 189591, Cache Misses: 126569, Total Requests: 400 ---
# --- Episode 357 completed. Total Reward: 28816.07, Cache Hits: 196738, Cache Misses: 134046, Total Requests: 400 ---
# --- Episode 358 completed. Total Reward: 30200.89, Cache Hits: 194414, Cache Misses: 138370, Total Requests: 400 ---
# --- Episode 359 completed. Total Reward: 28278.91, Cache Hits: 195499, Cache Misses: 135205, Total Requests: 400 ---
# --- Episode 360 completed. Total Reward: 30208.49, Cache Hits: 196146, Cache Misses: 134830, Total Requests: 400 ---
# --- Episode 361 completed. Total Reward: 29368.96, Cache Hits: 191335, Cache Misses: 126473, Total Requests: 400 ---
# --- Episode 362 completed. Total Reward: 32651.04, Cache Hits: 206749, Cache Misses: 146179, Total Requests: 400 ---
# --- Episode 363 completed. Total Reward: 30180.28, Cache Hits: 199064, Cache Misses: 140024, Total Requests: 400 ---
# --- Episode 364 completed. Total Reward: 35067.93, Cache Hits: 204573, Cache Misses: 132643, Total Requests: 400 ---
# --- Episode 365 completed. Total Reward: 29439.53, Cache Hits: 196998, Cache Misses: 130954, Total Requests: 400 ---
# --- Episode 366 completed. Total Reward: 27487.76, Cache Hits: 195199, Cache Misses: 140961, Total Requests: 400 ---
# --- Episode 367 completed. Total Reward: 27750.06, Cache Hits: 196549, Cache Misses: 132667, Total Requests: 400 ---
# --- Episode 368 completed. Total Reward: 28715.60, Cache Hits: 204819, Cache Misses: 141549, Total Requests: 400 ---
# --- Episode 369 completed. Total Reward: 28322.45, Cache Hits: 194414, Cache Misses: 138754, Total Requests: 400 ---
# --- Episode 370 completed. Total Reward: 26599.62, Cache Hits: 204745, Cache Misses: 143495, Total Requests: 400 ---
# --- Episode 371 completed. Total Reward: 33371.36, Cache Hits: 202465, Cache Misses: 135151, Total Requests: 400 ---
# --- Episode 372 completed. Total Reward: 32138.12, Cache Hits: 199315, Cache Misses: 138845, Total Requests: 400 ---
# --- Episode 373 completed. Total Reward: 28236.08, Cache Hits: 188248, Cache Misses: 128296, Total Requests: 400 ---
# --- Episode 374 completed. Total Reward: 29691.25, Cache Hits: 204210, Cache Misses: 133294, Total Requests: 400 ---
# --- Episode 375 completed. Total Reward: 28437.91, Cache Hits: 197506, Cache Misses: 135454, Total Requests: 400 ---
# --- Episode 376 completed. Total Reward: 26384.69, Cache Hits: 198726, Cache Misses: 144346, Total Requests: 400 ---
# --- Episode 377 completed. Total Reward: 27818.80, Cache Hits: 196778, Cache Misses: 128006, Total Requests: 400 ---
# --- Episode 378 completed. Total Reward: 28604.37, Cache Hits: 201369, Cache Misses: 131591, Total Requests: 400 ---
# --- Episode 379 completed. Total Reward: 26296.71, Cache Hits: 191659, Cache Misses: 129205, Total Requests: 400 ---
# --- Episode 380 completed. Total Reward: 29715.88, Cache Hits: 198079, Cache Misses: 129681, Total Requests: 400 ---
# --- Episode 381 completed. Total Reward: 29645.31, Cache Hits: 191034, Cache Misses: 138758, Total Requests: 400 ---
# --- Episode 382 completed. Total Reward: 29617.41, Cache Hits: 198706, Cache Misses: 137150, Total Requests: 400 ---
# --- Episode 383 completed. Total Reward: 32550.56, Cache Hits: 198637, Cache Misses: 131011, Total Requests: 400 ---
# --- Episode 384 completed. Total Reward: 27315.12, Cache Hits: 204091, Cache Misses: 146853, Total Requests: 400 ---
# --- Episode 385 completed. Total Reward: 29120.44, Cache Hits: 200803, Cache Misses: 132157, Total Requests: 400 ---
# --- Episode 386 completed. Total Reward: 28697.98, Cache Hits: 194064, Cache Misses: 132160, Total Requests: 400 ---
# --- Episode 387 completed. Total Reward: 30613.63, Cache Hits: 204175, Cache Misses: 136913, Total Requests: 400 ---
# --- Episode 388 completed. Total Reward: 29471.63, Cache Hits: 203011, Cache Misses: 142621, Total Requests: 400 ---
# --- Episode 389 completed. Total Reward: 25599.40, Cache Hits: 198784, Cache Misses: 145232, Total Requests: 400 ---
# --- Episode 390 completed. Total Reward: 27841.17, Cache Hits: 188262, Cache Misses: 130842, Total Requests: 400 ---
# --- Episode 391 completed. Total Reward: 28003.87, Cache Hits: 189483, Cache Misses: 127125, Total Requests: 400 ---
# --- Episode 392 completed. Total Reward: 33099.73, Cache Hits: 201400, Cache Misses: 124280, Total Requests: 400 ---
# --- Episode 393 completed. Total Reward: 29699.74, Cache Hits: 195107, Cache Misses: 137613, Total Requests: 400 ---
# --- Episode 394 completed. Total Reward: 31256.71, Cache Hits: 195231, Cache Misses: 124401, Total Requests: 400 ---
# --- Episode 395 completed. Total Reward: 30878.24, Cache Hits: 204519, Cache Misses: 138905, Total Requests: 400 ---
# --- Episode 396 completed. Total Reward: 29881.17, Cache Hits: 194525, Cache Misses: 134211, Total Requests: 400 ---
# --- Episode 397 completed. Total Reward: 27344.50, Cache Hits: 196761, Cache Misses: 129559, Total Requests: 400 ---
# --- Episode 398 completed. Total Reward: 29571.69, Cache Hits: 203888, Cache Misses: 142464, Total Requests: 400 ---
# --- Episode 399 completed. Total Reward: 28740.96, Cache Hits: 209242, Cache Misses: 137750, Total Requests: 400 ---
# --- Episode 400 completed. Total Reward: 31721.85, Cache Hits: 197097, Cache Misses: 123015, Total Requests: 400 ---
# --- Episode 401 completed. Total Reward: 28295.83, Cache Hits: 186984, Cache Misses: 125640, Total Requests: 400 ---
# --- Episode 402 completed. Total Reward: 29398.56, Cache Hits: 191453, Cache Misses: 145939, Total Requests: 400 ---
# --- Episode 403 completed. Total Reward: 31016.80, Cache Hits: 203900, Cache Misses: 126932, Total Requests: 400 ---
# --- Episode 404 completed. Total Reward: 28192.29, Cache Hits: 204705, Cache Misses: 140015, Total Requests: 400 ---
# --- Episode 405 completed. Total Reward: 30165.55, Cache Hits: 195549, Cache Misses: 128275, Total Requests: 400 ---
# --- Episode 406 completed. Total Reward: 27335.90, Cache Hits: 197909, Cache Misses: 129067, Total Requests: 400 ---
# --- Episode 407 completed. Total Reward: 25785.71, Cache Hits: 194535, Cache Misses: 128553, Total Requests: 400 ---
# --- Episode 408 completed. Total Reward: 29401.40, Cache Hits: 205846, Cache Misses: 135306, Total Requests: 400 ---
# --- Episode 409 completed. Total Reward: 27529.45, Cache Hits: 189428, Cache Misses: 136316, Total Requests: 400 ---
# --- Episode 410 completed. Total Reward: 30764.30, Cache Hits: 204226, Cache Misses: 130542, Total Requests: 400 ---
# --- Episode 411 completed. Total Reward: 31463.96, Cache Hits: 187484, Cache Misses: 127940, Total Requests: 400 ---
# --- Episode 412 completed. Total Reward: 32899.71, Cache Hits: 202029, Cache Misses: 123411, Total Requests: 400 ---
# --- Episode 413 completed. Total Reward: 29739.64, Cache Hits: 209579, Cache Misses: 144613, Total Requests: 400 ---
# --- Episode 414 completed. Total Reward: 27545.62, Cache Hits: 199923, Cache Misses: 145069, Total Requests: 400 ---
# --- Episode 415 completed. Total Reward: 29036.08, Cache Hits: 199779, Cache Misses: 135981, Total Requests: 400 ---
# --- Episode 416 completed. Total Reward: 32397.12, Cache Hits: 196737, Cache Misses: 133023, Total Requests: 400 ---
# --- Episode 417 completed. Total Reward: 29339.92, Cache Hits: 205066, Cache Misses: 135030, Total Requests: 400 ---
# --- Episode 418 completed. Total Reward: 30190.32, Cache Hits: 205239, Cache Misses: 130249, Total Requests: 400 ---
# --- Episode 419 completed. Total Reward: 28592.80, Cache Hits: 205081, Cache Misses: 132423, Total Requests: 400 ---
# --- Episode 420 completed. Total Reward: 29335.82, Cache Hits: 192541, Cache Misses: 136003, Total Requests: 400 ---
# --- Episode 421 completed. Total Reward: 27210.96, Cache Hits: 193849, Cache Misses: 122199, Total Requests: 400 ---
# --- Episode 422 completed. Total Reward: 29805.70, Cache Hits: 197278, Cache Misses: 127106, Total Requests: 400 ---
# --- Episode 423 completed. Total Reward: 29863.41, Cache Hits: 200528, Cache Misses: 127408, Total Requests: 400 ---
# --- Episode 424 completed. Total Reward: 31030.98, Cache Hits: 198972, Cache Misses: 126116, Total Requests: 400 ---
# --- Episode 425 completed. Total Reward: 32006.26, Cache Hits: 205005, Cache Misses: 138291, Total Requests: 400 ---
# --- Episode 426 completed. Total Reward: 30730.03, Cache Hits: 198941, Cache Misses: 129027, Total Requests: 400 ---
# --- Episode 427 completed. Total Reward: 32399.68, Cache Hits: 198970, Cache Misses: 127190, Total Requests: 400 ---
# --- Episode 428 completed. Total Reward: 27109.81, Cache Hits: 198380, Cache Misses: 140772, Total Requests: 400 ---
# --- Episode 429 completed. Total Reward: 27220.55, Cache Hits: 189607, Cache Misses: 127129, Total Requests: 400 ---
# --- Episode 430 completed. Total Reward: 29908.84, Cache Hits: 205183, Cache Misses: 149425, Total Requests: 400 ---
# --- Episode 431 completed. Total Reward: 26788.34, Cache Hits: 189105, Cache Misses: 129871, Total Requests: 400 ---
# --- Episode 432 completed. Total Reward: 28338.41, Cache Hits: 201417, Cache Misses: 139863, Total Requests: 400 ---
# --- Episode 433 completed. Total Reward: 26273.91, Cache Hits: 199925, Cache Misses: 124619, Total Requests: 400 ---
# --- Episode 434 completed. Total Reward: 28308.14, Cache Hits: 200755, Cache Misses: 140109, Total Requests: 400 ---
# --- Episode 435 completed. Total Reward: 31981.09, Cache Hits: 209201, Cache Misses: 137023, Total Requests: 400 ---
# --- Episode 436 completed. Total Reward: 28902.21, Cache Hits: 194910, Cache Misses: 131282, Total Requests: 400 ---
# --- Episode 437 completed. Total Reward: 29274.61, Cache Hits: 198895, Cache Misses: 131409, Total Requests: 400 ---
# --- Episode 438 completed. Total Reward: 28399.49, Cache Hits: 209458, Cache Misses: 142270, Total Requests: 400 ---
# --- Episode 439 completed. Total Reward: 30740.22, Cache Hits: 208452, Cache Misses: 128220, Total Requests: 400 ---
# --- Episode 440 completed. Total Reward: 30745.86, Cache Hits: 196664, Cache Misses: 126968, Total Requests: 400 ---
# --- Episode 441 completed. Total Reward: 27607.50, Cache Hits: 202796, Cache Misses: 140164, Total Requests: 400 ---
# --- Episode 442 completed. Total Reward: 30154.04, Cache Hits: 211974, Cache Misses: 142826, Total Requests: 400 ---
# --- Episode 443 completed. Total Reward: 31332.40, Cache Hits: 200650, Cache Misses: 141654, Total Requests: 400 ---
# --- Episode 444 completed. Total Reward: 31296.35, Cache Hits: 185842, Cache Misses: 121310, Total Requests: 400 ---
# --- Episode 445 completed. Total Reward: 25414.99, Cache Hits: 157462, Cache Misses: 174394, Total Requests: 400 ---
# --- Episode 446 completed. Total Reward: 30474.60, Cache Hits: 197663, Cache Misses: 130513, Total Requests: 400 ---
# --- Episode 447 completed. Total Reward: 30948.00, Cache Hits: 198591, Cache Misses: 129681, Total Requests: 400 ---
# --- Episode 448 completed. Total Reward: 29665.26, Cache Hits: 198531, Cache Misses: 122205, Total Requests: 400 ---
# --- Episode 449 completed. Total Reward: 31612.97, Cache Hits: 198243, Cache Misses: 123773, Total Requests: 400 ---
# --- Episode 450 completed. Total Reward: 31334.52, Cache Hits: 197991, Cache Misses: 140249, Total Requests: 400 ---
# --- Episode 451 completed. Total Reward: 30730.88, Cache Hits: 205486, Cache Misses: 134930, Total Requests: 400 ---
# --- Episode 452 completed. Total Reward: 31591.95, Cache Hits: 206868, Cache Misses: 143260, Total Requests: 400 ---
# --- Episode 453 completed. Total Reward: 28910.99, Cache Hits: 199358, Cache Misses: 138450, Total Requests: 400 ---
# --- Episode 454 completed. Total Reward: 33108.75, Cache Hits: 197152, Cache Misses: 128656, Total Requests: 400 ---
# --- Episode 455 completed. Total Reward: 28420.77, Cache Hits: 197100, Cache Misses: 128596, Total Requests: 400 ---
# --- Episode 456 completed. Total Reward: 25653.71, Cache Hits: 197005, Cache Misses: 146195, Total Requests: 400 ---
# --- Episode 457 completed. Total Reward: 29920.03, Cache Hits: 203823, Cache Misses: 128977, Total Requests: 400 ---
# --- Episode 458 completed. Total Reward: 31451.04, Cache Hits: 205660, Cache Misses: 133268, Total Requests: 400 ---
# --- Episode 459 completed. Total Reward: 29221.98, Cache Hits: 191964, Cache Misses: 132356, Total Requests: 400 ---
# --- Episode 460 completed. Total Reward: 30405.48, Cache Hits: 207462, Cache Misses: 131242, Total Requests: 400 ---
# --- Episode 461 completed. Total Reward: 32367.09, Cache Hits: 204515, Cache Misses: 131517, Total Requests: 400 ---
# --- Episode 462 completed. Total Reward: 27740.73, Cache Hits: 195315, Cache Misses: 128269, Total Requests: 400 ---
# --- Episode 463 completed. Total Reward: 30753.02, Cache Hits: 199741, Cache Misses: 131587, Total Requests: 400 ---
# --- Episode 464 completed. Total Reward: 28484.89, Cache Hits: 200035, Cache Misses: 133405, Total Requests: 400 ---
# --- Episode 465 completed. Total Reward: 30710.36, Cache Hits: 198040, Cache Misses: 127400, Total Requests: 400 ---
# --- Episode 466 completed. Total Reward: 29196.76, Cache Hits: 194283, Cache Misses: 137029, Total Requests: 400 ---
# --- Episode 467 completed. Total Reward: 28545.11, Cache Hits: 201465, Cache Misses: 134247, Total Requests: 400 ---
# --- Episode 468 completed. Total Reward: 25351.65, Cache Hits: 185436, Cache Misses: 129300, Total Requests: 400 ---
# --- Episode 469 completed. Total Reward: 28320.17, Cache Hits: 213091, Cache Misses: 140509, Total Requests: 400 ---
# --- Episode 470 completed. Total Reward: 30203.56, Cache Hits: 217530, Cache Misses: 136662, Total Requests: 400 ---
# --- Episode 471 completed. Total Reward: 32602.08, Cache Hits: 198329, Cache Misses: 114679, Total Requests: 400 ---
# --- Episode 472 completed. Total Reward: 30283.75, Cache Hits: 206015, Cache Misses: 123345, Total Requests: 400 ---
# --- Episode 473 completed. Total Reward: 30507.54, Cache Hits: 197121, Cache Misses: 134959, Total Requests: 400 ---
# --- Episode 474 completed. Total Reward: 29798.05, Cache Hits: 196760, Cache Misses: 124104, Total Requests: 400 ---
# --- Episode 475 completed. Total Reward: 30919.30, Cache Hits: 201498, Cache Misses: 131542, Total Requests: 400 ---
# --- Episode 476 completed. Total Reward: 31433.97, Cache Hits: 188605, Cache Misses: 126771, Total Requests: 400 ---
# --- Episode 477 completed. Total Reward: 33171.83, Cache Hits: 199845, Cache Misses: 128203, Total Requests: 400 ---
# --- Episode 478 completed. Total Reward: 29499.33, Cache Hits: 198308, Cache Misses: 134780, Total Requests: 400 ---
# --- Episode 479 completed. Total Reward: 31534.61, Cache Hits: 203121, Cache Misses: 126767, Total Requests: 400 ---
# --- Episode 480 completed. Total Reward: 26830.13, Cache Hits: 199908, Cache Misses: 139500, Total Requests: 400 ---
# --- Episode 481 completed. Total Reward: 30463.64, Cache Hits: 199512, Cache Misses: 126376, Total Requests: 400 ---
# --- Episode 482 completed. Total Reward: 32691.32, Cache Hits: 200687, Cache Misses: 121969, Total Requests: 400 ---
# --- Episode 483 completed. Total Reward: 29051.56, Cache Hits: 198511, Cache Misses: 136993, Total Requests: 400 ---
# --- Episode 484 completed. Total Reward: 28667.63, Cache Hits: 201584, Cache Misses: 138688, Total Requests: 400 ---
# --- Episode 485 completed. Total Reward: 30893.52, Cache Hits: 204625, Cache Misses: 135343, Total Requests: 400 ---
# --- Episode 486 completed. Total Reward: 29815.13, Cache Hits: 192776, Cache Misses: 136248, Total Requests: 400 ---
# --- Episode 487 completed. Total Reward: 27212.29, Cache Hits: 194439, Cache Misses: 135065, Total Requests: 400 ---
# --- Episode 488 completed. Total Reward: 27072.05, Cache Hits: 192750, Cache Misses: 141026, Total Requests: 400 ---
# --- Episode 489 completed. Total Reward: 28386.11, Cache Hits: 201050, Cache Misses: 131846, Total Requests: 400 ---
# --- Episode 490 completed. Total Reward: 24952.97, Cache Hits: 190879, Cache Misses: 130753, Total Requests: 400 ---
# --- Episode 491 completed. Total Reward: 25882.35, Cache Hits: 196911, Cache Misses: 133457, Total Requests: 400 ---
# --- Episode 492 completed. Total Reward: 31913.04, Cache Hits: 214298, Cache Misses: 130646, Total Requests: 400 ---
# --- Episode 493 completed. Total Reward: 28155.53, Cache Hits: 197173, Cache Misses: 131627, Total Requests: 400 ---
# --- Episode 494 completed. Total Reward: 26096.26, Cache Hits: 195798, Cache Misses: 131322, Total Requests: 400 ---
# --- Episode 495 completed. Total Reward: 33114.34, Cache Hits: 200045, Cache Misses: 132083, Total Requests: 400 ---
# --- Episode 496 completed. Total Reward: 28212.62, Cache Hits: 206144, Cache Misses: 138832, Total Requests: 400 ---
# --- Episode 497 completed. Total Reward: 28687.73, Cache Hits: 188159, Cache Misses: 136145, Total Requests: 400 ---
# --- Episode 498 completed. Total Reward: 29242.29, Cache Hits: 202113, Cache Misses: 132239, Total Requests: 400 ---
# --- Episode 499 completed. Total Reward: 33036.39, Cache Hits: 198375, Cache Misses: 123241, Total Requests: 400 ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------      
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

# Professional color for line plots
PRIMARY_COLOR = "#2b7bba"

# ----------------------------------------------------------------
# 2. Data Loading & Smoothing
# ----------------------------------------------------------------
path = cfg.path_results + "/" + cfg.filename

print(f"Loading data from: {path}")

df = pd.read_csv(path)

total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
df["hit_rate"] = (df["cache_hits"] / total) * 100
df["miss_rate"] = (df["cache_misses"] / total) * 100

# Metrics to plot
metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
window_size = 10  # Adjust smoothing window as needed

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
# Adjusted figsize for a 4-column row (standard for full-width paper figures)
fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

for ax, col in zip(axes, metrics):
    # Plot raw data with transparency (alpha)
    ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, alpha=0.3, linewidth=0.8, label='Raw')
    
    # Plot moving average for clearer trend (except for epsilon which is usually linear)
    if col != "epsilon":
        smoothed = df[col].rolling(window=window_size).mean()
        ax.plot(df["episode"], smoothed, color=PRIMARY_COLOR, linewidth=1.5, label='Trend')
    else:
        # Just a solid line for Epsilon
        ax.plot(df["episode"], df[col], color=PRIMARY_COLOR, linewidth=1.5)

    # Stylistic cleanup
    ax.set_title(col.replace("_", " ").title(), fontweight="bold")
    ax.set_xlabel("Episode")
    
    # Remove redundant Y-labels to save space, or keep for clarity
    ax.set_ylabel("Value") 
    
    series = df[col].dropna()
    if not series.empty:
        ymin = series.min()
        ymax = series.max()
        pad = (ymax - ymin) * 0.05 if ymax != ymin else 1.0
        ax.set_ylim(ymin - pad, ymax + pad)
    ax.grid(axis='y', linestyle='--', alpha=0.3)
    
    # Tufte-style: remove top/right spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# Optional: Add a single legend to the first plot if needed
# axes[0].legend(frameon=False)

plt.show()
fig.savefig("drl_caching_metrics.png", dpi=300)
# Out:
# Loading data from: c:\Users\es25591\Workspace\CacheVideoPredict360\Results/drl_dqn_softup_fixedlr0.001_e500_c50_ar20.0_z0.8.csv

# %%
if __name__ == "__main__":

    plt.rcParams.update({
        "font.family": "serif",
        "font.serif": ["Times New Roman", "DejaVu Serif"],
        "font.size": 10,
        "axes.titlesize": 11,
        "axes.labelsize": 10,
        "legend.fontsize": 9,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "axes.linewidth": 0.8,
        "savefig.dpi": 300,
        "figure.constrained_layout.use": True
    })

    COLORS = ["#2b7bba", "#d62728", "#2ca02c"]

    folder = r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\interval_100_3"
    folder = r"/home/eduardo/Workspace/CacheVideoPredict360/Results"
    files = [
        "drl_d3qn_softup_lrdecay0.9999_c50_ar10.0_z0.8.csv",
        "drl_dqn_softup_fixedlr0.001_e500_c50_ar10.0_z1.0.csv",
        # "drl_dqn_softup_lrdecay0.99999_c50_ar10.0_z0.8.csv",
    ]

    paths = [os.path.join(folder, f) for f in files]
    def _short_label(fname: str) -> str:
        stem = os.path.splitext(fname)[0]
        if "lrdecay" in stem:
            val = stem.split("lrdecay", 1)[1].split("_", 1)[0]
            return f"lr decay: {val}"
        if "fixedlr" in stem:
            val = stem.split("fixedlr", 1)[1].split("_", 1)[0]
            return f"fixed lr: {val}"
        return stem

    labels = [_short_label(f) for f in files]

    print(labels)
    metrics = ["total_reward", "hit_rate", "miss_rate", "epsilon", "lr"]
    window_size = 10

    fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)

    for color, path, label in zip(COLORS, paths, labels):
        df = pd.read_csv(path)
        total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
        df["hit_rate"] = (df["cache_hits"] / total) * 100
        df["miss_rate"] = (df["cache_misses"] / total) * 100

        for ax, col in zip(axes, metrics):
            ax.plot(df["episode"], df[col], color=color, alpha=0.25, linewidth=0.8)

            if col != "epsilon":
                smoothed = df[col].rolling(window=window_size).mean()
                ax.plot(df["episode"], smoothed, color=color, linewidth=1.5, label=label)
            else:
                ax.plot(df["episode"], df[col], color=color, linewidth=1.5, label=label)

    for ax, col in zip(axes, metrics):
        ax.set_title(col.replace("_", " ").title(), fontweight="bold")
        ax.set_xlabel("Episode")
        ax.set_ylabel("Value")
        ax.grid(axis="y", linestyle="--", alpha=0.3)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
        ax.set_ylim(bottom=0)

    axes[0].legend(frameon=False, loc="best")
    plt.show()

    fig.savefig("interval_04_comparison.png", dpi=300)
# Out:
# ['lr decay: 0.9999', 'fixed lr: 0.001']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 47
#      44 fig, axes = plt.subplots(1, len(metrics), figsize=(12, 3), sharex=True)
#      46 for color, path, label in zip(COLORS, paths, labels):
# ---> 47     df = pd.read_csv(path)
#      48     total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
#      49     df["hit_rate"] = (df["cache_hits"] / total) * 100
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/eduardo/Workspace/CacheVideoPredict360/Results\\drl_d3qn_softup_lrdecay0.9999_c50_ar10.0_z0.8.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------------------      
# 1. Publication Style Configuration
# ----------------------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "axes.linewidth": 0.8,
    "savefig.dpi": 300,
    "figure.constrained_layout.use": True
})

COLORS = ["#2b7bba", "#d62728"]

# ----------------------------------------------------------------
# 2. Data Preparation with Variance
# ----------------------------------------------------------------
def get_metrics_with_error(path):
    """Returns mean and standard deviation for hit and miss rates."""
    try:
        df = pd.read_csv(path)
        total = (df["cache_hits"] + df["cache_misses"]).replace(0, np.nan)
        
        hit_series = (df["cache_hits"] / total * 100)
        miss_series = (df["cache_misses"] / total * 100)
        
        # Calculate Mean and Standard Deviation
        return (hit_series.mean(), hit_series.std()), (miss_series.mean(), miss_series.std())
    except Exception as e:
        print(f"Error processing {path}: {e}")
        return (0, 0), (0, 0)

drl_files = {
    "5": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\drl_pan_opt_c25_ar10.0_z0.5.csv",
    "10": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\drl_pan_opt_c50_ar10.0_z0.5.csv",
}

lsr_files = {
    "5": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\lru_c25_ar10.0_z0.5.csv",
    "10": r"c:\Users\es25591\Workspace\CacheVideoPredict360\Results\lru_c50_ar10.0_z0.5.csv",
}

caps = list(drl_files.keys())
# Structure: { Metric: { Algo: [means], Algo_err: [stds] } }
stats = {
    "Hit Rate": {"DRL-LSR": [], "DRL-LSR_err": [], "LRU-LSR": [], "LRU-LSR_err": []},
    "Miss Rate": {"DRL-LSR": [], "DRL-LSR_err": [], "LRU-LSR": [], "LRU-LSR_err": []}
}

for c in caps:
    (d_h, d_h_err), (d_m, d_m_err) = get_metrics_with_error(drl_files[c])
    (l_h, l_h_err), (l_m, l_m_err) = get_metrics_with_error(lsr_files[c])
    
    stats["Hit Rate"]["DRL-LSR"].append(d_h)
    stats["Hit Rate"]["DRL-LSR_err"].append(d_h_err)
    stats["Hit Rate"]["LRU-LSR"].append(l_h)
    stats["Hit Rate"]["LRU-LSR_err"].append(l_h_err)
    
    stats["Miss Rate"]["DRL-LSR"].append(d_m)
    stats["Miss Rate"]["DRL-LSR_err"].append(d_m_err)
    stats["Miss Rate"]["LRU-LSR"].append(l_m)
    stats["Miss Rate"]["LRU-LSR_err"].append(l_m_err)

# ----------------------------------------------------------------
# 3. Plotting logic
# ----------------------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(7, 3.2), sharey=True)
x = np.arange(len(caps))
width = 0.35 

# Error bar styling
error_kw = dict(lw=1, capsize=3, capthick=1, ecolor='#333333')

metrics = ["Hit Rate", "Miss Rate"]
for i, metric in enumerate(metrics):
    ax = axes[i]
    
    ax.bar(x - width/2, stats[metric]["DRL-LSR"], width, 
           yerr=stats[metric]["DRL-LSR_err"], error_kw=error_kw,
           label="DRL-LSR", color=COLORS[0], edgecolor='black', linewidth=0.6, zorder=3)
    
    ax.bar(x + width/2, stats[metric]["LRU-LSR"], width, 
           yerr=stats[metric]["LRU-LSR_err"], error_kw=error_kw,
           label="LRU-LSR", color=COLORS[1], edgecolor='black', linewidth=0.6, zorder=3)

    ax.set_title(f"Average {metric}", fontweight="bold")
    ax.set_xlabel("Cache Size (%)")
    ax.set_xticks(x)
    ax.set_xticklabels(caps)
    ax.set_ylim(0, 110) # Increased to accommodate error bars
    
    ax.grid(axis='y', linestyle='--', alpha=0.3, zorder=0)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

axes[0].set_ylabel("Percentage (%)")
axes[1].legend(frameon=False, loc="upper right")

plt.tight_layout()
plt.show()

fig.savefig("drl_vs_lru_cache_performance.pdf")
# Out:
# C:\Users\es25591\AppData\Local\Temp\ipykernel_24328\1345644425.py:108: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
