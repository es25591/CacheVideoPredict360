# %%
import csv
import importlib
import json
import os
import random
import sys
import torch
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import Any, Dict, Counter, List

sources_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if sources_path not in sys.path:
    sys.path.append(sources_path)

from importnb import Notebook
with Notebook():
    from Labs.LatencyModel import LatencyModel, MultiDULatencyModel
    from Labs.Policy import DrlPolicy
    from Labs.CacheEngine import CacheEngineEnv
    from Labs.UserRequest import UserRequestEvents
    # from Labs.EnvWrapper import EnvWrapper
    from Labs.EnvCPTWrapper import EnvWrapper

from RL.Networks import QNetwork, MultiHeadQNetwork
from RL.Buffers import ReplayBuffer, NStepReplayBuffer
from RL.Adapters import FeatureAdapter, NetworkAdapter
from RL.FocusWorkers import BaseWorker, EnhWorker, FocusWorker
from Sources.RL.DqnHeuWorker import DqnHeuWorker
from RL.A2CWorker import A2CWorker

import Common.config as config
import Common.datatypes as datatypes
import Common.debugger as debugger
import Common.utils as utils
import Core.builders as builders

importlib.reload(builders)
importlib.reload(config)
importlib.reload(datatypes)
importlib.reload(debugger)
importlib.reload(utils)
# Out:
# <module 'Common.utils' from 'c:\\Users\\es25591\\Workspace\\CacheVideoPredict360\\Sources\\Common\\utils.py'>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

UserTransition = datatypes.UserTransition
CachePolicy = datatypes.CachePolicy
CacheKey = datatypes.CacheKey

# Note: The state and action dimensions are determined by the cache size and the specific 
# design of the state representation and action space. Adjust these calculations based on 
# your actual implementation of the state and action spaces.
cfg = config.Config()
cfg.filename = \
    f"focus_eps{cfg.epsilon_start}_" \
    f"lrdecay{cfg.learning_rate_decay}_" \
    f"gamma{cfg.gamma}.csv"
cfg.state_dim = cfg.cache_size * 10 + 4
cfg.action_dim = cfg.cache_size * 5 + 1

cfg.state_dim_base_focus = cfg.cache_size * 10 + 4
cfg.state_dim_enh_focus = cfg.cache_size * 10 + 4
cfg.action_dim_base_focus = cfg.cache_size * 5 + 1

debugger = debugger.debug

# %%
class NetworkAdapter:
    def __init__(self, cfg: Any, env: Any, feature_adapter: Any):
        self.env = env
        self.cfg = cfg
        self.features = feature_adapter

        self.C = self.cfg.cache_size  # paper's cache capacity (videos)
        self.k = self.cfg.viewport    # paper's tiles per video (enhancement)

    def build_observation(self, video, tile = None) -> np.ndarray:

        cache = self.env.mec_cache.policy.cache

        x_s = np.zeros(len(cache), dtype=np.float32)
        x_l = np.zeros(len(cache), dtype=np.float32)

        for idx, (v, t) in enumerate(cache):
            if v == -1:
                continue

            if t == -1:
                x_s[idx] = self.features.video_freq_short.get(v, 0) / self.features.video_hist_short.maxlen
                x_l[idx] = self.features.video_freq_long.get(v, 0) / self.features.video_hist_long.maxlen
            else:
                x_s[idx] = self.features.tile_freq_short.get((v, t), 0) / self.features.tile_hist_short.maxlen
                x_l[idx] = self.features.tile_freq_long.get((v, t), 0) / self.features.tile_hist_long.maxlen

        if tile is None:
            y_s = np.array(
                [self.features.video_freq_short.get(video, 0) / self.features.video_hist_short.maxlen], 
                dtype=np.float32
            )
            y_l = np.array(
                [self.features.video_freq_long.get(video, 0) / self.features.video_hist_long.maxlen], 
                dtype=np.float32
            )
        else:
            y_s = np.array(
                [self.features.tile_freq_short.get((video, tile), 0) / self.features.tile_hist_short.maxlen], 
                dtype=np.float32
            )
            y_l = np.array(
                [self.features.tile_freq_long.get((video, tile), 0) / self.features.tile_hist_long.maxlen], 
                dtype=np.float32
            )

        step_one_hot = int(tile is None)

        return np.concatenate(
            [x_s, x_l, y_s, y_l, [step_one_hot, not step_one_hot]], axis=0
        ), x_s, x_l, y_s, y_l

    def reset(self):
        
        obs, info = self.env.reset()
        self.features.reset_history()

        return obs, info
    
    def env_is_done(self) -> bool:
        return self.env.users_env.all_users_done()

# %%
def _append_csv_row(csv_path: str, fieldnames: list[str], row: dict) -> None:
    write_header = not os.path.exists(csv_path)
    with open(csv_path, 'a', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        if write_header:
            writer.writeheader()
        writer.writerow(row)


def save_episode_metrics(
    metrics_dir: str,
    ep: int,
    total_reward: float,
    cache_hits: int,
    cache_misses: int,
    agent,
):
    csv_path = os.path.join(metrics_dir, 'episode_metrics.csv')
    fieldnames = [
        'episode',
        'total_reward',
        'cache_hits',
        'cache_misses',
        'hit_rate',
        'epsilon',
        'lr',
    ]

    row = {
        'episode': ep,
        'total_reward': round(float(total_reward), 2),
        'cache_hits': cache_hits,
        'cache_misses': cache_misses,
        'hit_rate': float(cache_hits) / float(cache_hits + cache_misses + 1e-9),
        'epsilon': round(float(agent.epsilon), 6) if agent else None,
        'lr': float(agent.scheduler.get_last_lr()[0]) if agent else None,
    }
    _append_csv_row(csv_path, fieldnames, row)

def save_step_metrics(
    metrics_dir: str,
    episode: int,
    episode_step: int,
    global_step: int,
    reward: float,
    agent,
    train_metrics: dict | None,
):
    csv_path = os.path.join(metrics_dir, 'step_metrics.csv')
    fieldnames = [
        'episode',
        'episode_step',
        'global_step',
        'reward',
        'epsilon',
        'lr',
        'train_loss',
        'actor_loss',
        'critic_loss'
    ]

    row = {
        'episode': episode,
        'episode_step': episode_step,
        'global_step': global_step,
        'reward': float(reward),
        'epsilon': round(float(agent.epsilon), 6) if agent else None,
        'lr': float(agent.scheduler.get_last_lr()[0]) if agent else None,
        'train_loss': None,
        'actor_loss': None,
        'critic_loss': None
    }

    if train_metrics is not None:
        row.update({
            'train_loss': train_metrics.get('train_loss'),
            'actor_loss': train_metrics.get('actor_loss'),
            'critic_loss': train_metrics.get('critic_loss'),
    })

    _append_csv_row(csv_path, fieldnames, row)

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, int, int]:
    enh_hits = info.get("enh_layer_hits", 0)
    base_hits = info.get("base_layer_hits", 0)
    enh_misses = info.get("enh_layer_misses", 0)
    base_misses = info.get("base_layer_misses", 0)

    return reward, base_hits, base_misses, enh_hits, enh_misses

# %%
def process_missing_layer(
    agent,
    req_state,
    env,
    net_adapter,
    missing,
    transition,
    backhaul_usage: int,
    layer_idx: int,
    tile_idx: int | None,
    is_base: bool,
    bytes_cost: int,
    log_key: str,
) -> int:
    if missing[layer_idx] != 1:
        return backhaul_usage

    if tile_idx is None:
        state, _, _, _, _ = net_adapter.build_observation(req_state["video"])
        tiles = []
    else:
        tile = req_state["viewport"][tile_idx]
        state, _, _, _, _ = net_adapter.build_observation(req_state["video"], tile)
        tiles = [tile]

    action = agent.select_action(state)

    transition[layer_idx] = {
        'state': state,
        'action': action
    }

    message = {
        "video": req_state["video"],
        "tiles": tiles,
        "base_req_init": is_base,
        "action_idx": action,
    }
    env.prefetch_fn(env.mec_cache, message)

    if action != 0:
        backhaul_usage += bytes_cost

    debugger.log(log_key, action)
    
    return backhaul_usage

def select_action(agent, req_state, env, net_adapter=None):

    backhaul_usage = 0
    n_subreqs = 1 + cfg.viewport
    transition = [None] * n_subreqs

    if req_state is None:
        return None, np.zeros(n_subreqs, dtype=np.int32), transition

    missing = env._missing_items(req_state)

    backhaul_usage = process_missing_layer(
        agent=agent,
        req_state=req_state,
        env=env,
        net_adapter=net_adapter,
        missing=missing,
        transition=transition,
        backhaul_usage=backhaul_usage,
        layer_idx=0,
        tile_idx=None,
        is_base=True,
        bytes_cost=12 * env.mec_cache.tile_size_bytes[0],
        log_key="base_action",
    )

    for idx in range(cfg.viewport):
        backhaul_usage = process_missing_layer(
            agent=agent,
            req_state=req_state,
            env=env,
            net_adapter=net_adapter,
            missing=missing,
            transition=transition,
            backhaul_usage=backhaul_usage,
            layer_idx=idx + 1,
            tile_idx=idx,
            is_base=False,
            bytes_cost=env.mec_cache.tile_size_bytes[1],
            log_key=f"enh_{idx}_action",
        )

    debugger.log("backhaul_usage", backhaul_usage)

    debugger.log("base_layer_miss", missing[0])
    for i, is_missing in enumerate(missing[1:], start=1):
        debugger.log(f"enh_layer_missing_{i}", is_missing)

    return None, missing, transition


def run_episode(episode, env, agent, net_adapter, cfg, metrics_dir, global_step_start):
    """Run one full training episode and persist step-level metrics."""
    _, info = net_adapter.reset()

    total_reward = 0.0
    cache_hits = cache_misses = 0
    base_hits = base_misses = 0
    enh_hits = enh_misses = 0
    psnr_sum = 0.0

    global_step = global_step_start

    if cfg.has_warmup:
        env.warmup_phase(net_adapter, 1000)

    for step in range(cfg.max_steps):
        global_step += 1

        # --- Build State ---
        req_state = info.get("user_request", None)

        # --- Action Selection ---
        action, missing, transition = select_action(agent, req_state, env, net_adapter)

        # --- Environment Step ---
        _, reward, done, info = env.step(action, req_state, net_adapter)

        # --- Store Transition & Train ---
        nxt_req = info["user_request"]

        reward_0 = info["reward_layer_0"]
        reward_1 = info["reward_layer_1"]

        reward = reward_0 + reward_1
        
        queued_update = False

        if missing[0] == 1 or transition[0] is not None:
            next_state_base, _, _, _, _ = net_adapter.build_observation(nxt_req["video"])

            agent.remember(
                transition[0]['state'],
                transition[0]['action'],
                reward,
                next_state_base,
                done
            )
            queued_update = True

        for i in range(len(missing) - 1):
            if missing[i + 1] == 1 and transition[i + 1] is not None:
                next_state_enh, _, _, _, _ = net_adapter.build_observation(nxt_req["video"], nxt_req["viewport"][i])
                agent.remember(
                    transition[i + 1]['state'],
                    transition[i + 1]['action'],
                    reward,
                    next_state_enh,
                    done
                )
                queued_update = True

        if queued_update:
            train_metrics = agent.train_step()

            if train_metrics is not None:
                save_step_metrics(
                    metrics_dir=metrics_dir,
                    episode=episode,
                    episode_step=step,
                    global_step=global_step,
                    reward=reward,
                    agent=agent,
                    train_metrics=train_metrics,
                )
            

        delta_r, bs_hits, bs_miss, e_hits, e_miss = update_metrics(info, reward)
        total_reward += delta_r
        cache_hits += bs_hits + e_hits
        cache_misses += bs_miss + e_miss
        base_hits += bs_hits
        base_misses += bs_miss
        enh_hits += e_hits
        enh_misses += e_miss
        psnr_sum += info.get("psnr", 0.0)

        if done:
            break

        debugger.log('cache_hits', bs_hits + e_hits)
        debugger.log('cache_misses', bs_miss + e_miss)

    return total_reward, cache_hits, cache_misses, base_hits, base_misses, enh_hits, enh_misses, global_step, psnr_sum / (step + 1)

def train(cfg):
    env = builders.build_environment(cfg)

    agent = DqnHeuWorker(cfg, debugger=debugger)

    feature_adapter = FeatureAdapter(cfg, env)
    net_adapter = NetworkAdapter(cfg, env, feature_adapter)

    date_dir = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M")
    debug_path = os.path.join(cfg.path_results, date_dir)
    metrics_dir = os.path.join(debug_path, "metrics")
    os.makedirs(metrics_dir, exist_ok=True)

    print(f"Starting training for {cfg.n_episodes} episodes... {date_dir}")
    print(f"Warmup Phase: {'Enabled' if cfg.has_warmup else 'Disabled'}")
    print(f"Users Session Length: {cfg.user_session_length}")
    print(agent)

    global_log_path = os.path.join(debug_path, "global.log")
    with open(global_log_path, "a", encoding="utf-8") as f:
        f.write(f"{pd.Timestamp.now().isoformat()} | {agent}\n")
        f.write("-" * 50 + "\n")

    global_step = 0

    for episode in range(cfg.n_episodes):

        total_reward, hits, misses, bs_hits, bs_miss, enh_hits, enh_miss, global_step, psnr_rate = run_episode(
            episode, env, agent, net_adapter, cfg, metrics_dir, global_step
        )

        agent.update_epsilon() # Function used to clean buffer memory

        save_episode_metrics(
            metrics_dir=metrics_dir,
            ep=episode,
            total_reward=total_reward,
            cache_hits=hits,
            cache_misses=misses,
            agent=agent,
        )

        network_params = {"episode": episode, "networks": {}}

        for net_name in ("q_network", "policy_net", "actor", "critic", "model", "network"):
            net = getattr(agent, net_name, None)
            if net is not None and hasattr(net, "state_dict"):
                network_params["networks"][net_name] = {
                    k: v.detach().cpu().tolist()
                    for k, v in net.state_dict().items()
                }

        if network_params["networks"]:
            json_path = os.path.join(metrics_dir, f"network_params_ep{episode}.json")
            with open(json_path, "w", encoding="utf-8") as f:
                json.dump(network_params, f, indent=2)

        debugger.log('lr', agent.scheduler.get_last_lr()[0])
        debugger.log('epsilon', agent.epsilon) 

        debugger.save_results(filepath=f"{debug_path}/debug_ep{episode}")
        debugger.clear()

        print(
            f"Episode {episode} | R: {int(total_reward)} | "
            f"HR: {hits / (hits + misses + 1e-9):.2f} | "
            f"BHR: {bs_hits / (bs_hits + bs_miss + 1e-9):.2f} | "
            f"EHR: {enh_hits / (enh_hits + enh_miss + 1e-9):.2f} | "
            f"PSNR: {psnr_rate:.2f} | "
            f"Time: {pd.Timestamp.now().strftime('%H:%M:%S')}"
        )
        print("-" * 50)

if __name__ == "__main__":
    train(cfg)
# Out:
# Starting training for 400 episodes... 2026-04-16_15-27
# Warmup Phase: Enabled
# Users Session Length: 60
# DQNWorker(step=0, epsilon=0.0500, buffer_size=0, learning_rate=0.001000, gamma=0.6, tau=0.01
# policy_net_params=113531, target_net_params=113531), optimizer=Adam
# hiddens=128, Action Dim=251, State Dim=504
# Q-values before heuristic adjustment: 0.29508388
# Q-values before heuristic adjustment: 0.35036576
# Q-values before heuristic adjustment: 0.34884286
# Q-values before heuristic adjustment: 0.34894937
# Q-values before heuristic adjustment: 0.34887868
# Q-values before heuristic adjustment: 0.3491205
# Q-values before heuristic adjustment: 0.34936494
# Q-values before heuristic adjustment: 0.34948605
# Q-values before heuristic adjustment: 0.35011965
# Q-values before heuristic adjustment: 0.35147375
# Q-values before heuristic adjustment: 0.29624945
# Q-values before heuristic adjustment: 0.3510782
# Q-values before heuristic adjustment: 0.3489983
# Q-values before heuristic adjustment: 0.3489983
# Q-values before heuristic adjustment: 0.3489983
# Q-values before heuristic adjustment: 0.29327697
# Q-values before heuristic adjustment: 0.3486582
# Q-values before heuristic adjustment: 0.34888268
# Q-values before heuristic adjustment: 0.34895432
# Q-values before heuristic adjustment: 0.3489983
# Q-values before heuristic adjustment: 0.3494709
# Q-values before heuristic adjustment: 0.35053384
# Q-values before heuristic adjustment: 0.29654044
# Q-values before heuristic adjustment: 0.35038126
# Q-values before heuristic adjustment: 0.3492723
# Q-values before heuristic adjustment: 0.34936506
# Q-values before heuristic adjustment: 0.3492723
# Q-values before heuristic adjustment: 0.29459614
# Q-values before heuristic adjustment: 0.3487141
# Q-values before heuristic adjustment: 0.3489356
# Q-values before heuristic adjustment: 0.3489356
# Q-values before heuristic adjustment: 0.2930156
# Q-values before heuristic adjustment: 0.3489356
# Q-values before heuristic adjustment: 0.3492043
# Q-values before heuristic adjustment: 0.3492043
# Q-values before heuristic adjustment: 0.3492043
# Q-values before heuristic adjustment: 0.34967613
# Q-values before heuristic adjustment: 0.3511666
# Q-values before heuristic adjustment: 0.3495564
# Q-values before heuristic adjustment: 0.34963536
# Q-values before heuristic adjustment: 0.3495564
# Q-values before heuristic adjustment: 0.29625136
# Q-values before heuristic adjustment: 0.3497244
# Q-values before heuristic adjustment: 0.35000104
# Q-values before heuristic adjustment: 0.3500839
# Q-values before heuristic adjustment: 0.35033852
# Q-values before heuristic adjustment: 0.29574454
# Q-values before heuristic adjustment: 0.34945512
# Q-values before heuristic adjustment: 0.34972346
# Q-values before heuristic adjustment: 0.34972346
# Q-values before heuristic adjustment: 0.34972346
# Q-values before heuristic adjustment: 0.35057187
# Q-values before heuristic adjustment: 0.35135996
# Q-values before heuristic adjustment: 0.2947812
# Q-values before heuristic adjustment: 0.350662
# Q-values before heuristic adjustment: 0.34963655
# Q-values before heuristic adjustment: 0.34966427
# Q-values before heuristic adjustment: 0.34963655
# Q-values before heuristic adjustment: 0.3494475
# Q-values before heuristic adjustment: 0.34934646
# Q-values before heuristic adjustment: 0.34936297
# Q-values before heuristic adjustment: 0.34948605
# Q-values before heuristic adjustment: 0.2927305
# Q-values before heuristic adjustment: 0.34898007
# Q-values before heuristic adjustment: 0.34902364
# Q-values before heuristic adjustment: 0.34890842
# Q-values before heuristic adjustment: 0.34953147
# Q-values before heuristic adjustment: 0.3495534
# Q-values before heuristic adjustment: 0.29606783
# Q-values before heuristic adjustment: 0.349463
# Q-values before heuristic adjustment: 0.34951937
# Q-values before heuristic adjustment: 0.3500377
# Q-values before heuristic adjustment: 0.34927976
# Q-values before heuristic adjustment: 0.34956038
# Q-values before heuristic adjustment: 0.34956646
# Q-values before heuristic adjustment: 0.34975648
# Q-values before heuristic adjustment: 0.34963065
# Q-values before heuristic adjustment: 0.29547155
# Q-values before heuristic adjustment: 0.34995043
# Q-values before heuristic adjustment: 0.35007918
# Q-values before heuristic adjustment: 0.3500154
# Q-values before heuristic adjustment: 0.34994978
# Q-values before heuristic adjustment: 0.2942388
# Q-values before heuristic adjustment: 0.350038
# Q-values before heuristic adjustment: 0.35030627
# Q-values before heuristic adjustment: 0.35030627
# Q-values before heuristic adjustment: 0.35030627
# Q-values before heuristic adjustment: 0.35011905
# Q-values before heuristic adjustment: 0.35013282
# Q-values before heuristic adjustment: 0.2943024
# Q-values before heuristic adjustment: 0.35017365
# Q-values before heuristic adjustment: 0.35005343
# Q-values before heuristic adjustment: 0.35004723
# Q-values before heuristic adjustment: 0.35000062
# Q-values before heuristic adjustment: 0.35030556
# Q-values before heuristic adjustment: 0.3504017
# Q-values before heuristic adjustment: 0.34991026
# Q-values before heuristic adjustment: 0.3016597
# Q-values before heuristic adjustment: 0.35015225
# Q-values before heuristic adjustment: 0.35016465
# Q-values before heuristic adjustment: 0.35049808
# Q-values before heuristic adjustment: 0.35011613
# Q-values before heuristic adjustment: 0.29828006
# Q-values before heuristic adjustment: 0.34973675
# Q-values before heuristic adjustment: 0.34985453
# Q-values before heuristic adjustment: 0.34996134
# Q-values before heuristic adjustment: 0.34994268
# Q-values before heuristic adjustment: 0.29525173
# Q-values before heuristic adjustment: 0.34987533
# Q-values before heuristic adjustment: 0.3500998
# Q-values before heuristic adjustment: 0.35017115
# Q-values before heuristic adjustment: 0.35021526
# Q-values before heuristic adjustment: 0.30198747
# Q-values before heuristic adjustment: 0.35007697
# Q-values before heuristic adjustment: 0.35084605
# Q-values before heuristic adjustment: 0.35097384
# Q-values before heuristic adjustment: 0.35151315
# Q-values before heuristic adjustment: 0.30016643
# Q-values before heuristic adjustment: 0.35061085
# Q-values before heuristic adjustment: 0.35084355
# Q-values before heuristic adjustment: 0.3508572
# Q-values before heuristic adjustment: 0.35084355
# Q-values before heuristic adjustment: 0.29504883
# Q-values before heuristic adjustment: 0.35034353
# Q-values before heuristic adjustment: 0.35049152
# Q-values before heuristic adjustment: 0.35061175
# Q-values before heuristic adjustment: 0.35049152
# Q-values before heuristic adjustment: 0.29501563
# Q-values before heuristic adjustment: 0.35032225
# Q-values before heuristic adjustment: 0.3505906
# Q-values before heuristic adjustment: 0.35050958
# Q-values before heuristic adjustment: 0.30214
# Q-values before heuristic adjustment: 0.350703
# Q-values before heuristic adjustment: 0.3520614
# Q-values before heuristic adjustment: 0.35095763
# Q-values before heuristic adjustment: 0.30017775
# Q-values before heuristic adjustment: 0.34923363
# Q-values before heuristic adjustment: 0.34969127
# Q-values before heuristic adjustment: 0.34969127
# Q-values before heuristic adjustment: 0.34969127
# Q-values before heuristic adjustment: 0.34967512
# Q-values before heuristic adjustment: 0.3505435
# Q-values before heuristic adjustment: 0.35047704
# Q-values before heuristic adjustment: 0.3489461
# Q-values before heuristic adjustment: 0.34931082
# Q-values before heuristic adjustment: 0.34970224
# Q-values before heuristic adjustment: 0.35212457
# Q-values before heuristic adjustment: 0.35158145
# Q-values before heuristic adjustment: 0.35018885
# Q-values before heuristic adjustment: 0.34999448
# Q-values before heuristic adjustment: 0.34985334
# Q-values before heuristic adjustment: 0.3524204
# Q-values before heuristic adjustment: 0.29860222
# Q-values before heuristic adjustment: 0.3518359
# Q-values before heuristic adjustment: 0.34967685
# Q-values before heuristic adjustment: 0.34967685
# Q-values before heuristic adjustment: 0.34967685
# Q-values before heuristic adjustment: 0.3496428
# Q-values before heuristic adjustment: 0.3498376
# Q-values before heuristic adjustment: 0.34970522
# Q-values before heuristic adjustment: 0.34937084
# Q-values before heuristic adjustment: 0.34984344
# Q-values before heuristic adjustment: 0.3498599
# Q-values before heuristic adjustment: 0.34996396
# Q-values before heuristic adjustment: 0.34943503
# Q-values before heuristic adjustment: 0.34968436
# Q-values before heuristic adjustment: 0.2953058
# Q-values before heuristic adjustment: 0.35016418
# Q-values before heuristic adjustment: 0.3498659
# Q-values before heuristic adjustment: 0.34989077
# Q-values before heuristic adjustment: 0.34992045
# Q-values before heuristic adjustment: 0.3504973
# Q-values before heuristic adjustment: 0.35104185
# Q-values before heuristic adjustment: 0.29563373
# Q-values before heuristic adjustment: 0.35047966
# Q-values before heuristic adjustment: 0.35024
# Q-values before heuristic adjustment: 0.35021794
# Q-values before heuristic adjustment: 0.2955941
# Q-values before heuristic adjustment: 0.35037005
# Q-values before heuristic adjustment: 0.35050213
# Q-values before heuristic adjustment: 0.35050213
# Q-values before heuristic adjustment: 0.29610646
# Q-values before heuristic adjustment: 0.35016853
# Q-values before heuristic adjustment: 0.3504172
# Q-values before heuristic adjustment: 0.3504172
# Q-values before heuristic adjustment: 0.3504172
# Q-values before heuristic adjustment: 0.29645765
# Q-values before heuristic adjustment: 0.34995216
# Q-values before heuristic adjustment: 0.35001773
# Q-values before heuristic adjustment: 0.3501212
# Q-values before heuristic adjustment: 0.29489422
# Q-values before heuristic adjustment: 0.34894288
# Q-values before heuristic adjustment: 0.3491813
# Q-values before heuristic adjustment: 0.34916723
# Q-values before heuristic adjustment: 0.34925258
# Q-values before heuristic adjustment: 0.29452598
# Q-values before heuristic adjustment: 0.3488978
# Q-values before heuristic adjustment: 0.34909445
# Q-values before heuristic adjustment: 0.34901518
# Q-values before heuristic adjustment: 0.346954
# Q-values before heuristic adjustment: 0.34808993
# Q-values before heuristic adjustment: 0.3476712
# Q-values before heuristic adjustment: 0.34598613
# Q-values before heuristic adjustment: 0.34601885
# Q-values before heuristic adjustment: 0.34610426
# Q-values before heuristic adjustment: 0.2893322
# Q-values before heuristic adjustment: 0.3487677
# Q-values before heuristic adjustment: 0.3487677
# Q-values before heuristic adjustment: 0.3487677
# Q-values before heuristic adjustment: 0.2912047
# Q-values before heuristic adjustment: 0.34787577
# Q-values before heuristic adjustment: 0.3492089
# Q-values before heuristic adjustment: 0.34780186
# Q-values before heuristic adjustment: 0.3481015
# Q-values before heuristic adjustment: 0.3479842
# Q-values before heuristic adjustment: 0.34932268
# Q-values before heuristic adjustment: 0.34933335
# Q-values before heuristic adjustment: 0.34809887
# Q-values before heuristic adjustment: 0.34810686
# Q-values before heuristic adjustment: 0.3507232
# Q-values before heuristic adjustment: 0.29418582
# Q-values before heuristic adjustment: 0.3506574
# Q-values before heuristic adjustment: 0.34859222
# Q-values before heuristic adjustment: 0.34862936
# Q-values before heuristic adjustment: 0.3486536
# Q-values before heuristic adjustment: 0.28704154
# Q-values before heuristic adjustment: 0.3480714
# Q-values before heuristic adjustment: 0.34836024
# Q-values before heuristic adjustment: 0.34836024
# Q-values before heuristic adjustment: 0.34836024
# Q-values before heuristic adjustment: 0.28777975
# Q-values before heuristic adjustment: 0.34882903
# Q-values before heuristic adjustment: 0.3494361
# Q-values before heuristic adjustment: 0.34928513
# Q-values before heuristic adjustment: 0.3491752
# Q-values before heuristic adjustment: 0.349441
# Q-values before heuristic adjustment: 0.28918028
# Q-values before heuristic adjustment: 0.3497622
# Q-values before heuristic adjustment: 0.34926075
# Q-values before heuristic adjustment: 0.34934843
# Q-values before heuristic adjustment: 0.34926075
# Q-values before heuristic adjustment: 0.2882241
# Q-values before heuristic adjustment: 0.34882396
# Q-values before heuristic adjustment: 0.34916157
# Q-values before heuristic adjustment: 0.34907657
# Q-values before heuristic adjustment: 0.34905452
# Q-values before heuristic adjustment: 0.2878127
# Q-values before heuristic adjustment: 0.34877056
# Q-values before heuristic adjustment: 0.34897333
# Q-values before heuristic adjustment: 0.34902048
# Q-values before heuristic adjustment: 0.34899843
# Q-values before heuristic adjustment: 0.2873562
# Q-values before heuristic adjustment: 0.34884262
# Q-values before heuristic adjustment: 0.34913152
# Q-values before heuristic adjustment: 0.34913152
# Q-values before heuristic adjustment: 0.34913152
# Q-values before heuristic adjustment: 0.28747147
# Q-values before heuristic adjustment: 0.34877056
# Q-values before heuristic adjustment: 0.34897333
# Q-values before heuristic adjustment: 0.34898424
# Q-values before heuristic adjustment: 0.34897333
# Q-values before heuristic adjustment: 0.34793812
# Q-values before heuristic adjustment: 0.34801304
# Q-values before heuristic adjustment: 0.34801304
# Q-values before heuristic adjustment: 0.34801304
# Q-values before heuristic adjustment: 0.2868696
# Q-values before heuristic adjustment: 0.34811604
# Q-values before heuristic adjustment: 0.3479452
# Q-values before heuristic adjustment: 0.3480662
# Q-values before heuristic adjustment: 0.3479452
# Q-values before heuristic adjustment: 0.28652734
# Q-values before heuristic adjustment: 0.34777355
# Q-values before heuristic adjustment: 0.3480624
# Q-values before heuristic adjustment: 0.3479684
# Q-values before heuristic adjustment: 0.34778637
# Q-values before heuristic adjustment: 0.348669
# Q-values before heuristic adjustment: 0.34893847
# Q-values before heuristic adjustment: 0.3488506
# Q-values before heuristic adjustment: 0.34893847
# Q-values before heuristic adjustment: 0.34833252
# Q-values before heuristic adjustment: 0.34847617
# Q-values before heuristic adjustment: 0.28760332
# Q-values before heuristic adjustment: 0.348503
# Q-values before heuristic adjustment: 0.34817135
# Q-values before heuristic adjustment: 0.34858078
# Q-values before heuristic adjustment: 0.28761637
# Q-values before heuristic adjustment: 0.34759164
# Q-values before heuristic adjustment: 0.34821743
# Q-values before heuristic adjustment: 0.3482452
# Q-values before heuristic adjustment: 0.3482793
# Q-values before heuristic adjustment: 0.28900772
# Q-values before heuristic adjustment: 0.3478487
# Q-values before heuristic adjustment: 0.34825003
# Q-values before heuristic adjustment: 0.34836006
# Q-values before heuristic adjustment: 0.34825003
# Q-values before heuristic adjustment: 0.34798944
# Q-values before heuristic adjustment: 0.34778827
# Q-values before heuristic adjustment: 0.2869435
# Q-values before heuristic adjustment: 0.34792393
# Q-values before heuristic adjustment: 0.3478738
# Q-values before heuristic adjustment: 0.34794587
# Q-values before heuristic adjustment: 0.34799594
# Q-values before heuristic adjustment: 0.34898216
# Q-values before heuristic adjustment: 0.34980953
# Q-values before heuristic adjustment: 0.2894408
# Q-values before heuristic adjustment: 0.34952223
# Q-values before heuristic adjustment: 0.3485769
# Q-values before heuristic adjustment: 0.34844255
# Q-values before heuristic adjustment: 0.348543
# Q-values before heuristic adjustment: 0.34829384
# Q-values before heuristic adjustment: 0.3486325
# Q-values before heuristic adjustment: 0.2892676
# Q-values before heuristic adjustment: 0.34925258
# Q-values before heuristic adjustment: 0.34870952
# Q-values before heuristic adjustment: 0.34859782
# Q-values before heuristic adjustment: 0.34852523
# Q-values before heuristic adjustment: 0.2876135
# Q-values before heuristic adjustment: 0.34838074
# Q-values before heuristic adjustment: 0.34861082
# Q-values before heuristic adjustment: 0.3486582
# Q-values before heuristic adjustment: 0.34867227
# Q-values before heuristic adjustment: 0.28859955
# Q-values before heuristic adjustment: 0.34827524
# Q-values before heuristic adjustment: 0.34850216
# Q-values before heuristic adjustment: 0.34854895
# Q-values before heuristic adjustment: 0.34864634
# Q-values before heuristic adjustment: 0.29207295
# Q-values before heuristic adjustment: 0.3484496
# Q-values before heuristic adjustment: 0.3495376
# Q-values before heuristic adjustment: 0.3492959
# Q-values before heuristic adjustment: 0.34891808
# Q-values before heuristic adjustment: 0.29006183
# Q-values before heuristic adjustment: 0.34855872
# Q-values before heuristic adjustment: 0.34866422
# Q-values before heuristic adjustment: 0.34866422
# Q-values before heuristic adjustment: 0.34866422
# Q-values before heuristic adjustment: 0.2880693
# Q-values before heuristic adjustment: 0.34856105
# Q-values before heuristic adjustment: 0.34888488
# Q-values before heuristic adjustment: 0.34888488
# Q-values before heuristic adjustment: 0.28953606
# Q-values before heuristic adjustment: 0.35071146
# Q-values before heuristic adjustment: 0.35094327
# Q-values before heuristic adjustment: 0.3508191
# Q-values before heuristic adjustment: 0.35094327
# Q-values before heuristic adjustment: 0.35131228
# Q-values before heuristic adjustment: 0.354168
# Q-values before heuristic adjustment: 0.3539397
# Q-values before heuristic adjustment: 0.35333586
# Q-values before heuristic adjustment: 0.35318124
# Q-values before heuristic adjustment: 0.29097855
# Q-values before heuristic adjustment: 0.35223275
# Q-values before heuristic adjustment: 0.35050672
# Q-values before heuristic adjustment: 0.3504672
# Q-values before heuristic adjustment: 0.35031807
# Q-values before heuristic adjustment: 0.28803605
# Q-values before heuristic adjustment: 0.3502069
# Q-values before heuristic adjustment: 0.35051972
# Q-values before heuristic adjustment: 0.3504808
# Q-values before heuristic adjustment: 0.35051972
# Q-values before heuristic adjustment: 0.2879421
# Q-values before heuristic adjustment: 0.35002166
# Q-values before heuristic adjustment: 0.3501947
# Q-values before heuristic adjustment: 0.35014695
# Q-values before heuristic adjustment: 0.3502229
# Q-values before heuristic adjustment: 0.28836375
# Q-values before heuristic adjustment: 0.35009372
# Q-values before heuristic adjustment: 0.35026276
# Q-values before heuristic adjustment: 0.35023677
# Q-values before heuristic adjustment: 0.28924024
# Q-values before heuristic adjustment: 0.35025537
# Q-values before heuristic adjustment: 0.35088462
# Q-values before heuristic adjustment: 0.35088462
# Q-values before heuristic adjustment: 0.35088462
# Q-values before heuristic adjustment: 0.350945
# Q-values before heuristic adjustment: 0.35059762
# Q-values before heuristic adjustment: 0.35085
# Q-values before heuristic adjustment: 0.3514341
# Q-values before heuristic adjustment: 0.28933156
# Q-values before heuristic adjustment: 0.3509735
# Q-values before heuristic adjustment: 0.3509735
# Q-values before heuristic adjustment: 0.35089922
# Q-values before heuristic adjustment: 0.35085088
# Q-values before heuristic adjustment: 0.29514658
# Q-values before heuristic adjustment: 0.35008198
# Q-values before heuristic adjustment: 0.35060447
# Q-values before heuristic adjustment: 0.3513627
# Q-values before heuristic adjustment: 0.35077757
# Q-values before heuristic adjustment: 0.2939989
# Q-values before heuristic adjustment: 0.3500104
# Q-values before heuristic adjustment: 0.3502357
# Q-values before heuristic adjustment: 0.3503102
# Q-values before heuristic adjustment: 0.35028434
# Q-values before heuristic adjustment: 0.29013127
# Q-values before heuristic adjustment: 0.35030067
# Q-values before heuristic adjustment: 0.35076892
# Q-values before heuristic adjustment: 0.35064936
# Q-values before heuristic adjustment: 0.35076892
# Q-values before heuristic adjustment: 0.35066313
# Q-values before heuristic adjustment: 0.35093576
# Q-values before heuristic adjustment: 0.28919482
# Q-values before heuristic adjustment: 0.35024428
# Q-values before heuristic adjustment: 0.350174
# Q-values before heuristic adjustment: 0.35016072
# Q-values before heuristic adjustment: 0.3506171
# Q-values before heuristic adjustment: 0.35350257
# Q-values before heuristic adjustment: 0.35287917
# Q-values before heuristic adjustment: 0.35249752
# Q-values before heuristic adjustment: 0.29622442
# Q-values before heuristic adjustment: 0.35187745
# Q-values before heuristic adjustment: 0.35042524
# Q-values before heuristic adjustment: 0.35111254
# Q-values before heuristic adjustment: 0.3506269
# Q-values before heuristic adjustment: 0.29337382
# Q-values before heuristic adjustment: 0.34979635
# Q-values before heuristic adjustment: 0.35006994
# Q-values before heuristic adjustment: 0.35006994
# Q-values before heuristic adjustment: 0.35006994
# Q-values before heuristic adjustment: 0.2873543
# Q-values before heuristic adjustment: 0.34979635
# Q-values before heuristic adjustment: 0.34999555
# Q-values before heuristic adjustment: 0.34990972
# Q-values before heuristic adjustment: 0.34988552
# Q-values before heuristic adjustment: 0.29453558
# Q-values before heuristic adjustment: 0.3500995
# Q-values before heuristic adjustment: 0.3514493
# Q-values before heuristic adjustment: 0.3511604
# Q-values before heuristic adjustment: 0.35209888
# Q-values before heuristic adjustment: 0.35150385
# Q-values before heuristic adjustment: 0.35037
# Q-values before heuristic adjustment: 0.35032755
# Q-values before heuristic adjustment: 0.35314244
# Q-values before heuristic adjustment: 0.3531348
# Q-values before heuristic adjustment: 0.2979837
# Q-values before heuristic adjustment: 0.35279787
# Q-values before heuristic adjustment: 0.35164458
# Q-values before heuristic adjustment: 0.351492
# Q-values before heuristic adjustment: 0.35044676
# Q-values before heuristic adjustment: 0.34966367
# Q-values before heuristic adjustment: 0.34943372
# Q-values before heuristic adjustment: 0.3495199
# Q-values before heuristic adjustment: 0.35097104
# Q-values before heuristic adjustment: 0.34834826
# Q-values before heuristic adjustment: 0.29458016
# Q-values before heuristic adjustment: 0.34852344
# Q-values before heuristic adjustment: 0.3501516
# Q-values before heuristic adjustment: 0.3495806
# Q-values before heuristic adjustment: 0.34917837
# Q-values before heuristic adjustment: 0.34903067
# Q-values before heuristic adjustment: 0.34889424
# Q-values before heuristic adjustment: 0.29082298
# Q-values before heuristic adjustment: 0.34926116
# Q-values before heuristic adjustment: 0.3494234
# Q-values before heuristic adjustment: 0.3495431
# Q-values before heuristic adjustment: 0.3494234
# Q-values before heuristic adjustment: 0.34931672
# Q-values before heuristic adjustment: 0.3497997
# Q-values before heuristic adjustment: 0.34761178
# Q-values before heuristic adjustment: 0.34845173
# Q-values before heuristic adjustment: 0.3490768
# Q-values before heuristic adjustment: 0.35147262
# Q-values before heuristic adjustment: 0.29122376
# Q-values before heuristic adjustment: 0.35022533
# Q-values before heuristic adjustment: 0.34837884
# Q-values before heuristic adjustment: 0.34878993
# Q-values before heuristic adjustment: 0.3479035
# Q-values before heuristic adjustment: 0.3481062
# Q-values before heuristic adjustment: 0.34838152
# Q-values before heuristic adjustment: 0.34793335
# Q-values before heuristic adjustment: 0.3475051
# Q-values before heuristic adjustment: 0.3476246
# Q-values before heuristic adjustment: 0.34707588
# Q-values before heuristic adjustment: 0.34713078
# Q-values before heuristic adjustment: 0.34732634
# Q-values before heuristic adjustment: 0.3476053
# Q-values before heuristic adjustment: 0.348669
# Q-values before heuristic adjustment: 0.34923685
# Q-values before heuristic adjustment: 0.2868817
# Q-values before heuristic adjustment: 0.3473326
# Q-values before heuristic adjustment: 0.3474403
# Q-values before heuristic adjustment: 0.34746343
# Q-values before heuristic adjustment: 0.3478371
# Q-values before heuristic adjustment: 0.3475638
# Q-values before heuristic adjustment: 0.3479784
# Q-values before heuristic adjustment: 0.34919333
# Q-values before heuristic adjustment: 0.35101676
# Q-values before heuristic adjustment: 0.35034955
# Q-values before heuristic adjustment: 0.3510661
# Q-values before heuristic adjustment: 0.35075098
# Q-values before heuristic adjustment: 0.34810787
# Q-values before heuristic adjustment: 0.3481558
# Q-values before heuristic adjustment: 0.34856623
# Q-values before heuristic adjustment: 0.34857547
# Q-values before heuristic adjustment: 0.34836882
# Q-values before heuristic adjustment: 0.3482409
# Q-values before heuristic adjustment: 0.34755123
# Q-values before heuristic adjustment: 0.34734744
# Q-values before heuristic adjustment: 0.34729815
# Q-values before heuristic adjustment: 0.29327905
# Q-values before heuristic adjustment: 0.34678257
# Q-values before heuristic adjustment: 0.3484246
# Q-values before heuristic adjustment: 0.3478539
# Q-values before heuristic adjustment: 0.34745157
# Q-values before heuristic adjustment: 0.29310763
# Q-values before heuristic adjustment: 0.3471905
# Q-values before heuristic adjustment: 0.34744352
# Q-values before heuristic adjustment: 0.34765399
# Q-values before heuristic adjustment: 0.29175168
# Q-values before heuristic adjustment: 0.34735096
# Q-values before heuristic adjustment: 0.34828204
# Q-values before heuristic adjustment: 0.34835094
# Q-values before heuristic adjustment: 0.34876192
# Q-values before heuristic adjustment: 0.29178506
# Q-values before heuristic adjustment: 0.3472911
# Q-values before heuristic adjustment: 0.34792465
# Q-values before heuristic adjustment: 0.34805262
# Q-values before heuristic adjustment: 0.34792465
# Q-values before heuristic adjustment: 0.34786034
# Q-values before heuristic adjustment: 0.34727252
# Q-values before heuristic adjustment: 0.34766924
# Q-values before heuristic adjustment: 0.3503952
# Q-values before heuristic adjustment: 0.349675
# Q-values before heuristic adjustment: 0.34722906
# Q-values before heuristic adjustment: 0.34753382
# Q-values before heuristic adjustment: 0.3472606
# Q-values before heuristic adjustment: 0.34712648
# Q-values before heuristic adjustment: 0.34712648
# Q-values before heuristic adjustment: 0.34748477
# Q-values before heuristic adjustment: 0.3475139
# Q-values before heuristic adjustment: 0.3476007
# Q-values before heuristic adjustment: 0.34721196
# Q-values before heuristic adjustment: 0.34700483
# Q-values before heuristic adjustment: 0.3472556
# Q-values before heuristic adjustment: 0.34791172
# Q-values before heuristic adjustment: 0.2909317
# Q-values before heuristic adjustment: 0.3501969
# Q-values before heuristic adjustment: 0.34744447
# Q-values before heuristic adjustment: 0.34745258
# Q-values before heuristic adjustment: 0.34747386
# Q-values before heuristic adjustment: 0.34772402
# Q-values before heuristic adjustment: 0.34803516
# Q-values before heuristic adjustment: 0.3485719
# Q-values before heuristic adjustment: 0.34997588
# Q-values before heuristic adjustment: 0.28767192
# Q-values before heuristic adjustment: 0.3492105
# Q-values before heuristic adjustment: 0.34751123
# Q-values before heuristic adjustment: 0.34751123
# Q-values before heuristic adjustment: 0.34751123
# Q-values before heuristic adjustment: 0.28573197
# Q-values before heuristic adjustment: 0.34716737
# Q-values before heuristic adjustment: 0.34744895
# Q-values before heuristic adjustment: 0.34747803
# Q-values before heuristic adjustment: 0.34751123
# Q-values before heuristic adjustment: 0.34795785
# Q-values before heuristic adjustment: 0.35086638
# Q-values before heuristic adjustment: 0.35088712
# Q-values before heuristic adjustment: 0.29061788
# Q-values before heuristic adjustment: 0.3499965
# Q-values before heuristic adjustment: 0.34772223
# Q-values before heuristic adjustment: 0.34784627
# Q-values before heuristic adjustment: 0.34772223
# Q-values before heuristic adjustment: 0.28729564
# Q-values before heuristic adjustment: 0.34721076
# Q-values before heuristic adjustment: 0.34754086
# Q-values before heuristic adjustment: 0.34754086
# Q-values before heuristic adjustment: 0.34754086
# Q-values before heuristic adjustment: 0.28564298
# Q-values before heuristic adjustment: 0.34727436
# Q-values before heuristic adjustment: 0.34758878
# Q-values before heuristic adjustment: 0.34758878
# Q-values before heuristic adjustment: 0.34758878
# Q-values before heuristic adjustment: 0.3482039
# Q-values before heuristic adjustment: 0.35103184
# Q-values before heuristic adjustment: 0.35058928
# Q-values before heuristic adjustment: 0.34790748
# Q-values before heuristic adjustment: 0.3479194
# Q-values before heuristic adjustment: 0.34790748
# Q-values before heuristic adjustment: 0.28920895
# Q-values before heuristic adjustment: 0.34758472
# Q-values before heuristic adjustment: 0.34747702
# Q-values before heuristic adjustment: 0.3475843
# Q-values before heuristic adjustment: 0.3479321
# Q-values before heuristic adjustment: 0.28830957
# Q-values before heuristic adjustment: 0.34769243
# Q-values before heuristic adjustment: 0.3480069
# Q-values before heuristic adjustment: 0.3480069
# Q-values before heuristic adjustment: 0.34774673
# Q-values before heuristic adjustment: 0.3486911
# Q-values before heuristic adjustment: 0.3474211
# Q-values before heuristic adjustment: 0.34736252
# Q-values before heuristic adjustment: 0.28698492
# Q-values before heuristic adjustment: 0.34672737
# Q-values before heuristic adjustment: 0.34693438
# Q-values before heuristic adjustment: 0.3469146
# Q-values before heuristic adjustment: 0.34666634
# Q-values before heuristic adjustment: 0.2910657
# Q-values before heuristic adjustment: 0.34592617
# Q-values before heuristic adjustment: 0.34693187
# Q-values before heuristic adjustment: 0.34703034
# Q-values before heuristic adjustment: 0.34745568
# Q-values before heuristic adjustment: 0.29026252
# Q-values before heuristic adjustment: 0.34629804
# Q-values before heuristic adjustment: 0.34661263
# Q-values before heuristic adjustment: 0.3465832
# Q-values before heuristic adjustment: 0.3465503
# Q-values before heuristic adjustment: 0.34727305
# Q-values before heuristic adjustment: 0.3473059
# Q-values before heuristic adjustment: 0.28887385
# Q-values before heuristic adjustment: 0.34685695
# Q-values before heuristic adjustment: 0.34715044
# Q-values before heuristic adjustment: 0.34746057
# Q-values before heuristic adjustment: 0.3469187
# Q-values before heuristic adjustment: 0.34709162
# Q-values before heuristic adjustment: 0.34682631
# Q-values before heuristic adjustment: 0.34661943
# Q-values before heuristic adjustment: 0.34663838
# Q-values before heuristic adjustment: 0.34673816
# Q-values before heuristic adjustment: 0.2888047
# Q-values before heuristic adjustment: 0.34736615
# Q-values before heuristic adjustment: 0.34739548
# Q-values before heuristic adjustment: 0.34737015
# Q-values before heuristic adjustment: 0.34730375
# Q-values before heuristic adjustment: 0.28738493
# Q-values before heuristic adjustment: 0.34730572
# Q-values before heuristic adjustment: 0.34762043
# Q-values before heuristic adjustment: 0.34762043
# Q-values before heuristic adjustment: 0.34740448
# Q-values before heuristic adjustment: 0.34730518
# Q-values before heuristic adjustment: 0.28734398
# Q-values before heuristic adjustment: 0.34755325
# Q-values before heuristic adjustment: 0.3475572
# Q-values before heuristic adjustment: 0.34755784
# Q-values before heuristic adjustment: 0.3474543
# Q-values before heuristic adjustment: 0.28934884
# Q-values before heuristic adjustment: 0.34716904
# Q-values before heuristic adjustment: 0.3476283
# Q-values before heuristic adjustment: 0.35075986
# Q-values before heuristic adjustment: 0.35123336
# Q-values before heuristic adjustment: 0.30005932
# Q-values before heuristic adjustment: 0.35253364
# Q-values before heuristic adjustment: 0.35110724
# Q-values before heuristic adjustment: 0.35144717
# Q-values before heuristic adjustment: 0.35088778
# Q-values before heuristic adjustment: 0.3500902
# Q-values before heuristic adjustment: 0.35008258
# Q-values before heuristic adjustment: 0.3500902
# Q-values before heuristic adjustment: 0.3501979
# Q-values before heuristic adjustment: 0.2947064
# Q-values before heuristic adjustment: 0.351654
# Q-values before heuristic adjustment: 0.35136068
# Q-values before heuristic adjustment: 0.35126948
# Q-values before heuristic adjustment: 0.35139364
# Q-values before heuristic adjustment: 0.29735714
# Q-values before heuristic adjustment: 0.35068017
# Q-values before heuristic adjustment: 0.35238183
# Q-values before heuristic adjustment: 0.3518896
# Q-values before heuristic adjustment: 0.3515073
# Q-values before heuristic adjustment: 0.29617697
# Q-values before heuristic adjustment: 0.35126644
# Q-values before heuristic adjustment: 0.351552
# Q-values before heuristic adjustment: 0.35154778
# Q-values before heuristic adjustment: 0.351552
# Q-values before heuristic adjustment: 0.29033667
# Q-values before heuristic adjustment: 0.35113275
# Q-values before heuristic adjustment: 0.35136062
# Q-values before heuristic adjustment: 0.35119104
# Q-values before heuristic adjustment: 0.2899933
# Q-values before heuristic adjustment: 0.35131544
# Q-values before heuristic adjustment: 0.35163003
# Q-values before heuristic adjustment: 0.35157162
# Q-values before heuristic adjustment: 0.3515054
# Q-values before heuristic adjustment: 0.29752046
# Q-values before heuristic adjustment: 0.35082018
# Q-values before heuristic adjustment: 0.3525952
# Q-values before heuristic adjustment: 0.35210317
# Q-values before heuristic adjustment: 0.3517207
# Q-values before heuristic adjustment: 0.30104578
# Q-values before heuristic adjustment: 0.35110134
# Q-values before heuristic adjustment: 0.3521815
# Q-values before heuristic adjustment: 0.35231394
# Q-values before heuristic adjustment: 0.3526646
# Q-values before heuristic adjustment: 0.29629993
# Q-values before heuristic adjustment: 0.3514731
# Q-values before heuristic adjustment: 0.35202742
# Q-values before heuristic adjustment: 0.35202742
# Q-values before heuristic adjustment: 0.35202742
# Q-values before heuristic adjustment: 0.35170865
# Q-values before heuristic adjustment: 0.35440153
# Q-values before heuristic adjustment: 0.3535884
# Q-values before heuristic adjustment: 0.35116875
# Q-values before heuristic adjustment: 0.35227215
# Q-values before heuristic adjustment: 0.35223156
# Q-values before heuristic adjustment: 0.29311365
# Q-values before heuristic adjustment: 0.35214978
# Q-values before heuristic adjustment: 0.3522696
# Q-values before heuristic adjustment: 0.35237777
# Q-values before heuristic adjustment: 0.35259253
# Q-values before heuristic adjustment: 0.35266834
# Q-values before heuristic adjustment: 0.35526556
# Q-values before heuristic adjustment: 0.29564482
# Q-values before heuristic adjustment: 0.35473728
# Q-values before heuristic adjustment: 0.3522057
# Q-values before heuristic adjustment: 0.3522057
# Q-values before heuristic adjustment: 0.3521223
# Q-values before heuristic adjustment: 0.35237598
# Q-values before heuristic adjustment: 0.3519255
# Q-values before heuristic adjustment: 0.35226315
# Q-values before heuristic adjustment: 0.35242933
# Q-values before heuristic adjustment: 0.35243708
# Q-values before heuristic adjustment: 0.35275877
# Q-values before heuristic adjustment: 0.35518652
# Q-values before heuristic adjustment: 0.35442024
# Q-values before heuristic adjustment: 0.35265934
# Q-values before heuristic adjustment: 0.2905687
# Q-values before heuristic adjustment: 0.35267538
# Q-values before heuristic adjustment: 0.35219425
# Q-values before heuristic adjustment: 0.35228974
# Q-values before heuristic adjustment: 0.35226429
# Q-values before heuristic adjustment: 0.3527925
# Q-values before heuristic adjustment: 0.35326833
# Q-values before heuristic adjustment: 0.35303307
# Q-values before heuristic adjustment: 0.29016358
# Q-values before heuristic adjustment: 0.35266572
# Q-values before heuristic adjustment: 0.35243827
# Q-values before heuristic adjustment: 0.35225964
# Q-values before heuristic adjustment: 0.35234308
# Q-values before heuristic adjustment: 0.28995782
# Q-values before heuristic adjustment: 0.35217303
# Q-values before heuristic adjustment: 0.35248786
# Q-values before heuristic adjustment: 0.35248786
# Q-values before heuristic adjustment: 0.35248786
# Q-values before heuristic adjustment: 0.29007405
# Q-values before heuristic adjustment: 0.35232913
# Q-values before heuristic adjustment: 0.35264367
# Q-values before heuristic adjustment: 0.35264367
# Q-values before heuristic adjustment: 0.35264367
# Q-values before heuristic adjustment: 0.29099804
# Q-values before heuristic adjustment: 0.35223675
# Q-values before heuristic adjustment: 0.35266668
# Q-values before heuristic adjustment: 0.35262966
# Q-values before heuristic adjustment: 0.35254604
# Q-values before heuristic adjustment: 0.28963864
# Q-values before heuristic adjustment: 0.3516162
# Q-values before heuristic adjustment: 0.35184002
# Q-values before heuristic adjustment: 0.35178208
# Q-values before heuristic adjustment: 0.3519646
# Q-values before heuristic adjustment: 0.28882247
# Q-values before heuristic adjustment: 0.35146374
# Q-values before heuristic adjustment: 0.3517198
# Q-values before heuristic adjustment: 0.35165364
# Q-values before heuristic adjustment: 0.35165364
# Q-values before heuristic adjustment: 0.35229897
# Q-values before heuristic adjustment: 0.355408
# Q-values before heuristic adjustment: 0.35434568
# Q-values before heuristic adjustment: 0.35151994
# Q-values before heuristic adjustment: 0.35163623
# Q-values before heuristic adjustment: 0.35151994
# Q-values before heuristic adjustment: 0.28893077
# Q-values before heuristic adjustment: 0.35180014
# Q-values before heuristic adjustment: 0.35186636
# Q-values before heuristic adjustment: 0.35186636
# Q-values before heuristic adjustment: 0.35186636
# Q-values before heuristic adjustment: 0.29346627
# Q-values before heuristic adjustment: 0.35100007
# Q-values before heuristic adjustment: 0.35217094
# Q-values before heuristic adjustment: 0.35075015
# Q-values before heuristic adjustment: 0.35138273
# Q-values before heuristic adjustment: 0.35250294
# Q-values before heuristic adjustment: 0.3524922
# Q-values before heuristic adjustment: 0.29368347
# Q-values before heuristic adjustment: 0.35061765
# Q-values before heuristic adjustment: 0.35117233
# Q-values before heuristic adjustment: 0.35117233
# Q-values before heuristic adjustment: 0.35117233
# Q-values before heuristic adjustment: 0.35159063
# Q-values before heuristic adjustment: 0.29128152
# Q-values before heuristic adjustment: 0.35301042
# Q-values before heuristic adjustment: 0.3510483
# Q-values before heuristic adjustment: 0.3510483
# Q-values before heuristic adjustment: 0.3510483
# Q-values before heuristic adjustment: 0.28998458
# Q-values before heuristic adjustment: 0.35088128
# Q-values before heuristic adjustment: 0.35134637
# Q-values before heuristic adjustment: 0.351573
# Q-values before heuristic adjustment: 0.35156226
# Q-values before heuristic adjustment: 0.3516879
# Q-values before heuristic adjustment: 0.35140634
# Q-values before heuristic adjustment: 0.35133922
# Q-values before heuristic adjustment: 0.351794
# Q-values before heuristic adjustment: 0.29134375
# Q-values before heuristic adjustment: 0.3518014
# Q-values before heuristic adjustment: 0.35131264
# Q-values before heuristic adjustment: 0.35094208
# Q-values before heuristic adjustment: 0.29005742
# Q-values before heuristic adjustment: 0.350461
# Q-values before heuristic adjustment: 0.3508621
# Q-values before heuristic adjustment: 0.35072142
# Q-values before heuristic adjustment: 0.35072148
# Q-values before heuristic adjustment: 0.28947484
# Q-values before heuristic adjustment: 0.35052687
# Q-values before heuristic adjustment: 0.3507763
# Q-values before heuristic adjustment: 0.3507713
# Q-values before heuristic adjustment: 0.3507763
# Q-values before heuristic adjustment: 0.28902048
# Q-values before heuristic adjustment: 0.3505547
# Q-values before heuristic adjustment: 0.35086435
# Q-values before heuristic adjustment: 0.35086435
# Q-values before heuristic adjustment: 0.35086435
# Q-values before heuristic adjustment: 0.28909278
# Q-values before heuristic adjustment: 0.35049623
# Q-values before heuristic adjustment: 0.35062402
# Q-values before heuristic adjustment: 0.3507403
# Q-values before heuristic adjustment: 0.289034
# Q-values before heuristic adjustment: 0.35062033
# Q-values before heuristic adjustment: 0.35085785
# Q-values before heuristic adjustment: 0.35072613
# Q-values before heuristic adjustment: 0.35085785
# Q-values before heuristic adjustment: 0.2890566
# Q-values before heuristic adjustment: 0.35071546
# Q-values before heuristic adjustment: 0.3509655
# Q-values before heuristic adjustment: 0.35086375
# Q-values before heuristic adjustment: 0.35083055
# Q-values before heuristic adjustment: 0.28873998
# Q-values before heuristic adjustment: 0.3507784
# Q-values before heuristic adjustment: 0.35097164
# Q-values before heuristic adjustment: 0.35140896
# Q-values before heuristic adjustment: 0.35142446
# Q-values before heuristic adjustment: 0.35140896
# Q-values before heuristic adjustment: 0.35142446
# Q-values before heuristic adjustment: 0.35098076
# Q-values before heuristic adjustment: 0.2893498
# Q-values before heuristic adjustment: 0.3510462
# Q-values before heuristic adjustment: 0.35096377
# Q-values before heuristic adjustment: 0.35084236
# Q-values before heuristic adjustment: 0.35096377
# Q-values before heuristic adjustment: 0.35144764
# Q-values before heuristic adjustment: 0.3537426
# Q-values before heuristic adjustment: 0.2923683
# Q-values before heuristic adjustment: 0.3530301
# Q-values before heuristic adjustment: 0.35139078
# Q-values before heuristic adjustment: 0.35139078
# Q-values before heuristic adjustment: 0.35139078
# Q-values before heuristic adjustment: 0.29105806
# Q-values before heuristic adjustment: 0.35090226
# Q-values before heuristic adjustment: 0.35144347
# Q-values before heuristic adjustment: 0.35144866
# Q-values before heuristic adjustment: 0.35144347
# Q-values before heuristic adjustment: 0.29133707
# Q-values before heuristic adjustment: 0.35102415
# Q-values before heuristic adjustment: 0.35162127
# Q-values before heuristic adjustment: 0.3516668
# Q-values before heuristic adjustment: 0.35133815
# Q-values before heuristic adjustment: 0.2895136
# Q-values before heuristic adjustment: 0.3516119
# Q-values before heuristic adjustment: 0.3517176
# Q-values before heuristic adjustment: 0.3517176
# Q-values before heuristic adjustment: 0.3517176
# Q-values before heuristic adjustment: 0.352247
# Q-values before heuristic adjustment: 0.2910902
# Q-values before heuristic adjustment: 0.3525821
# Q-values before heuristic adjustment: 0.35223234
# Q-values before heuristic adjustment: 0.35222203
# Q-values before heuristic adjustment: 0.2914245
# Q-values before heuristic adjustment: 0.351757
# Q-values before heuristic adjustment: 0.35206693
# Q-values before heuristic adjustment: 0.3520115
# Q-values before heuristic adjustment: 0.35194612
# Q-values before heuristic adjustment: 0.29031122
# Q-values before heuristic adjustment: 0.351757
# Q-values before heuristic adjustment: 0.35203904
# Q-values before heuristic adjustment: 0.3520341
# Q-values before heuristic adjustment: 0.35203904
# Q-values before heuristic adjustment: 0.29126096
# Q-values before heuristic adjustment: 0.35162854
# Q-values before heuristic adjustment: 0.3518551
# Q-values before heuristic adjustment: 0.35180843
# Q-values before heuristic adjustment: 0.3522116
# Q-values before heuristic adjustment: 0.2944638
# Q-values before heuristic adjustment: 0.3519742
# Q-values before heuristic adjustment: 0.35299057
# Q-values before heuristic adjustment: 0.35244262
# Q-values before heuristic adjustment: 0.3524927
# Q-values before heuristic adjustment: 0.292731
# Q-values before heuristic adjustment: 0.3518818
# Q-values before heuristic adjustment: 0.35209322
# Q-values before heuristic adjustment: 0.35209322
# Q-values before heuristic adjustment: 0.35209322
# Q-values before heuristic adjustment: 0.29114026
# Q-values before heuristic adjustment: 0.35188514
# Q-values before heuristic adjustment: 0.35212278
# Q-values before heuristic adjustment: 0.35212278
# Q-values before heuristic adjustment: 0.2912047
# Q-values before heuristic adjustment: 0.35174328
# Q-values before heuristic adjustment: 0.35197008
# Q-values before heuristic adjustment: 0.35195476
# Q-values before heuristic adjustment: 0.35197008
# Q-values before heuristic adjustment: 0.35235834
# Q-values before heuristic adjustment: 0.35532016
# Q-values before heuristic adjustment: 0.35508734
# Q-values before heuristic adjustment: 0.35479772
# Q-values before heuristic adjustment: 0.35426134
# Q-values before heuristic adjustment: 0.29278755
# Q-values before heuristic adjustment: 0.35360265
# Q-values before heuristic adjustment: 0.3515479
# Q-values before heuristic adjustment: 0.35149288
# Q-values before heuristic adjustment: 0.35142738
# Q-values before heuristic adjustment: 0.2899322
# Q-values before heuristic adjustment: 0.35124332
# Q-values before heuristic adjustment: 0.3515429
# Q-values before heuristic adjustment: 0.35155308
# Q-values before heuristic adjustment: 0.3515429
# Q-values before heuristic adjustment: 0.2897182
# Q-values before heuristic adjustment: 0.3511821
# Q-values before heuristic adjustment: 0.3514591
# Q-values before heuristic adjustment: 0.35148686
# Q-values before heuristic adjustment: 0.35151947
# Q-values before heuristic adjustment: 0.29012495
# Q-values before heuristic adjustment: 0.35134578
# Q-values before heuristic adjustment: 0.35162276
# Q-values before heuristic adjustment: 0.35165042
# Q-values before heuristic adjustment: 0.35165542
# Q-values before heuristic adjustment: 0.29088974
# Q-values before heuristic adjustment: 0.3511529
# Q-values before heuristic adjustment: 0.35178334
# Q-values before heuristic adjustment: 0.35178334
# Q-values before heuristic adjustment: 0.35178334
# Q-values before heuristic adjustment: 0.3521524
# Q-values before heuristic adjustment: 0.3525228
# Q-values before heuristic adjustment: 0.29099268
# Q-values before heuristic adjustment: 0.35199845
# Q-values before heuristic adjustment: 0.35199845
# Q-values before heuristic adjustment: 0.35196924
# Q-values before heuristic adjustment: 0.35193628
# Q-values before heuristic adjustment: 0.2965775
# Q-values before heuristic adjustment: 0.3510182
# Q-values before heuristic adjustment: 0.35164613
# Q-values before heuristic adjustment: 0.3514989
# Q-values before heuristic adjustment: 0.35165787
# Q-values before heuristic adjustment: 0.29420543
# Q-values before heuristic adjustment: 0.3509155
# Q-values before heuristic adjustment: 0.351148
# Q-values before heuristic adjustment: 0.35104883
# Q-values before heuristic adjustment: 0.3512084
# Q-values before heuristic adjustment: 0.29156947
# Q-values before heuristic adjustment: 0.35103554
# Q-values before heuristic adjustment: 0.35162336
# Q-values before heuristic adjustment: 0.35138434
# Q-values before heuristic adjustment: 0.35162336
# Q-values before heuristic adjustment: 0.35131717
# Q-values before heuristic adjustment: 0.29046124
# Q-values before heuristic adjustment: 0.3511744
# Q-values before heuristic adjustment: 0.3510757
# Q-values before heuristic adjustment: 0.3510747
# Q-values before heuristic adjustment: 0.3510757
# Q-values before heuristic adjustment: 0.35116905
# Q-values before heuristic adjustment: 0.35275805
# Q-values before heuristic adjustment: 0.29638398
# Q-values before heuristic adjustment: 0.35196507
# Q-values before heuristic adjustment: 0.35158503
# Q-values before heuristic adjustment: 0.35178137
# Q-values before heuristic adjustment: 0.35156304
# Q-values before heuristic adjustment: 0.29487187
# Q-values before heuristic adjustment: 0.35065675
# Q-values before heuristic adjustment: 0.3508891
# Q-values before heuristic adjustment: 0.35076195
# Q-values before heuristic adjustment: 0.3508891
# Q-values before heuristic adjustment: 0.2883706
# Q-values before heuristic adjustment: 0.35065675
# Q-values before heuristic adjustment: 0.35090297
# Q-values before heuristic adjustment: 0.35083652
# Q-values before heuristic adjustment: 0.35083652
# Q-values before heuristic adjustment: 0.29567856
# Q-values before heuristic adjustment: 0.3510217
# Q-values before heuristic adjustment: 0.35222805
# Q-values before heuristic adjustment: 0.35200655
# Q-values before heuristic adjustment: 0.35299844
# Q-values before heuristic adjustment: 0.35235232
# Q-values before heuristic adjustment: 0.35427046
# Q-values before heuristic adjustment: 0.2993766
# Q-values before heuristic adjustment: 0.35376024
# ...
# Q-values before heuristic adjustment: 4.0907946
# Q-values before heuristic adjustment: 4.0931945
# Q-values before heuristic adjustment: 4.051046
# Q-values before heuristic adjustment: 4.125493
# Q-values before heuristic adjustment: 4.0842924
# Q-values before heuristic adjustment: 4.0884457
# Q-values before heuristic adjustment: 4.0838356
# Q-values before heuristic adjustment: 4.011961
# Q-values before heuristic adjustment: 4.0853786
# Q-values before heuristic adjustment: 4.0767503
# Q-values before heuristic adjustment: 4.078178
# Q-values before heuristic adjustment: 4.0780525
# Q-values before heuristic adjustment: 4.0111084
# Q-values before heuristic adjustment: 4.0862947
# Q-values before heuristic adjustment: 4.0766945
# Q-values before heuristic adjustment: 4.0790944
# Q-values before heuristic adjustment: 4.0790944
# Q-values before heuristic adjustment: 4.0104074
# Q-values before heuristic adjustment: 4.084923
# Q-values before heuristic adjustment: 4.075085
# Q-values before heuristic adjustment: 4.077583
# Q-values before heuristic adjustment: 4.07796
# Q-values before heuristic adjustment: 4.028933
# Q-values before heuristic adjustment: 4.1034355
# Q-values before heuristic adjustment: 4.0789886
# Q-values before heuristic adjustment: 4.0806494
# Q-values before heuristic adjustment: 4.0797844
# Q-values before heuristic adjustment: 4.0189447
# Q-values before heuristic adjustment: 4.0929394
# Q-values before heuristic adjustment: 4.075186
# Q-values before heuristic adjustment: 4.0776467
# Q-values before heuristic adjustment: 4.077586
# Q-values before heuristic adjustment: 4.010089
# Q-values before heuristic adjustment: 4.0833397
# Q-values before heuristic adjustment: 4.073739
# Q-values before heuristic adjustment: 4.0761395
# Q-values before heuristic adjustment: 4.0761395
# Q-values before heuristic adjustment: 4.0083876
# Q-values before heuristic adjustment: 4.0834284
# Q-values before heuristic adjustment: 4.0708623
# Q-values before heuristic adjustment: 4.0387893
# Q-values before heuristic adjustment: 4.1174717
# Q-values before heuristic adjustment: 4.073397
# Q-values before heuristic adjustment: 4.0812626
# Q-values before heuristic adjustment: 4.0214987
# Q-values before heuristic adjustment: 4.0915093
# Q-values before heuristic adjustment: 4.069746
# Q-values before heuristic adjustment: 4.0729737
# Q-values before heuristic adjustment: 4.073276
# Q-values before heuristic adjustment: 4.0044904
# Q-values before heuristic adjustment: 4.0776625
# Q-values before heuristic adjustment: 4.067825
# Q-values before heuristic adjustment: 4.0703225
# Q-values before heuristic adjustment: 4.0706987
# Q-values before heuristic adjustment: 4.002705
# Q-values before heuristic adjustment: 4.0781364
# Q-values before heuristic adjustment: 4.067825
# Q-values before heuristic adjustment: 4.0703225
# Q-values before heuristic adjustment: 4.0702243
# Q-values before heuristic adjustment: 4.0001144
# Q-values before heuristic adjustment: 4.075842
# Q-values before heuristic adjustment: 4.065349
# Q-values before heuristic adjustment: 4.067591
# Q-values before heuristic adjustment: 4.067749
# Q-values before heuristic adjustment: 4.085218
# Q-values before heuristic adjustment: 4.0708547
# Q-values before heuristic adjustment: 4.1339483
# Q-values before heuristic adjustment: 4.073514
# Q-values before heuristic adjustment: 4.079003
# Q-values before heuristic adjustment: 4.076239
# Q-values before heuristic adjustment: 4.036001
# Q-values before heuristic adjustment: 4.1118994
# Q-values before heuristic adjustment: 4.069689
# Q-values before heuristic adjustment: 4.07548
# Q-values before heuristic adjustment: 4.073354
# Q-values before heuristic adjustment: 4.0742493
# Q-values before heuristic adjustment: 4.0772686
# Q-values before heuristic adjustment: 4.038143
# Q-values before heuristic adjustment: 4.1123767
# Q-values before heuristic adjustment: 4.071176
# Q-values before heuristic adjustment: 4.0793343
# Q-values before heuristic adjustment: 4.082571
# Q-values before heuristic adjustment: 4.078393
# Q-values before heuristic adjustment: 4.0730495
# Q-values before heuristic adjustment: 4.073054
# Q-values before heuristic adjustment: 4.0730495
# Q-values before heuristic adjustment: 4.0712786
# Q-values before heuristic adjustment: 4.0705905
# Q-values before heuristic adjustment: 4.074456
# Q-values before heuristic adjustment: 4.075675
# Q-values before heuristic adjustment: 4.09008
# Q-values before heuristic adjustment: 4.0948005
# Q-values before heuristic adjustment: 4.080033
# Q-values before heuristic adjustment: 4.0470223
# Q-values before heuristic adjustment: 4.1252913
# Q-values before heuristic adjustment: 4.0779324
# Q-values before heuristic adjustment: 4.0925794
# Q-values before heuristic adjustment: 4.038227
# Q-values before heuristic adjustment: 4.1109056
# Q-values before heuristic adjustment: 4.0860677
# Q-values before heuristic adjustment: 4.0913696
# Q-values before heuristic adjustment: 4.091277
# Q-values before heuristic adjustment: 4.0275927
# Q-values before heuristic adjustment: 4.099046
# Q-values before heuristic adjustment: 4.082599
# Q-values before heuristic adjustment: 4.086711
# Q-values before heuristic adjustment: 4.0578346
# Q-values before heuristic adjustment: 4.1336927
# Q-values before heuristic adjustment: 4.0849
# Q-values before heuristic adjustment: 4.090056
# Q-values before heuristic adjustment: 4.0898395
# Q-values before heuristic adjustment: 4.0892644
# Q-values before heuristic adjustment: 4.0965805
# Q-values before heuristic adjustment: 4.106684
# Q-values before heuristic adjustment: 4.0503783
# Q-values before heuristic adjustment: 4.1166196
# Q-values before heuristic adjustment: 4.0908103
# Q-values before heuristic adjustment: 4.093652
# Q-values before heuristic adjustment: 4.0943313
# Q-values before heuristic adjustment: 4.097078
# Q-values before heuristic adjustment: 4.096621
# Q-values before heuristic adjustment: 4.095254
# Q-values before heuristic adjustment: 4.094845
# Q-values before heuristic adjustment: 4.1062117
# Q-values before heuristic adjustment: 4.113401
# Q-values before heuristic adjustment: 4.128037
# Q-values before heuristic adjustment: 4.1212873
# Q-values before heuristic adjustment: 4.1211905
# Q-values before heuristic adjustment: 4.1212873
# Q-values before heuristic adjustment: 4.1211452
# Q-values before heuristic adjustment: 4.1210146
# Q-values before heuristic adjustment: 4.1253304
# Q-values before heuristic adjustment: 4.1281567
# Q-values before heuristic adjustment: 4.1258397
# Q-values before heuristic adjustment: 4.125682
# Q-values before heuristic adjustment: 4.136133
# Q-values before heuristic adjustment: 4.142978
# Q-values before heuristic adjustment: 4.064254
# Q-values before heuristic adjustment: 4.136984
# Q-values before heuristic adjustment: 4.1286426
# Q-values before heuristic adjustment: 4.1310368
# Q-values before heuristic adjustment: 4.147201
# Q-values before heuristic adjustment: 4.1532288
# Q-values before heuristic adjustment: 4.1416335
# Q-values before heuristic adjustment: 4.1413746
# Q-values before heuristic adjustment: 4.1366653
# Q-values before heuristic adjustment: 4.1366653
# Q-values before heuristic adjustment: 4.1366653
# Q-values before heuristic adjustment: 4.1013045
# Q-values before heuristic adjustment: 4.179322
# Q-values before heuristic adjustment: 4.1403704
# Q-values before heuristic adjustment: 4.1427293
# Q-values before heuristic adjustment: 4.138008
# Q-values before heuristic adjustment: 4.084485
# Q-values before heuristic adjustment: 4.1564612
# Q-values before heuristic adjustment: 4.132812
# Q-values before heuristic adjustment: 4.134514
# Q-values before heuristic adjustment: 4.134595
# Q-values before heuristic adjustment: 4.0749297
# Q-values before heuristic adjustment: 4.1483955
# Q-values before heuristic adjustment: 4.132781
# Q-values before heuristic adjustment: 4.1363635
# Q-values before heuristic adjustment: 4.136396
# Q-values before heuristic adjustment: 4.132992
# Q-values before heuristic adjustment: 4.1309557
# Q-values before heuristic adjustment: 4.131667
# Q-values before heuristic adjustment: 4.1322775
# Q-values before heuristic adjustment: 4.060802
# Q-values before heuristic adjustment: 4.137293
# Q-values before heuristic adjustment: 4.126604
# Q-values before heuristic adjustment: 4.1283545
# Q-values before heuristic adjustment: 4.1282263
# Q-values before heuristic adjustment: 4.1286993
# Q-values before heuristic adjustment: 4.1286335
# Q-values before heuristic adjustment: 4.1286993
# Q-values before heuristic adjustment: 4.096811
# Q-values before heuristic adjustment: 4.177507
# Q-values before heuristic adjustment: 4.121471
# Q-values before heuristic adjustment: 4.1268682
# Q-values before heuristic adjustment: 4.054928
# Q-values before heuristic adjustment: 4.127582
# Q-values before heuristic adjustment: 4.1166153
# Q-values before heuristic adjustment: 4.1182995
# Q-values before heuristic adjustment: 4.117689
# Q-values before heuristic adjustment: 4.1224403
# Q-values before heuristic adjustment: 4.1431923
# Q-values before heuristic adjustment: 4.144288
# Q-values before heuristic adjustment: 4.144254
# Q-values before heuristic adjustment: 4.143611
# Q-values before heuristic adjustment: 4.141283
# Q-values before heuristic adjustment: 4.138404
# Q-values before heuristic adjustment: 4.138404
# Q-values before heuristic adjustment: 4.141982
# Q-values before heuristic adjustment: 4.143688
# Q-values before heuristic adjustment: 4.143688
# Q-values before heuristic adjustment: 4.143688
# Q-values before heuristic adjustment: 4.143919
# Q-values before heuristic adjustment: 4.1422124
# Q-values before heuristic adjustment: 4.1422124
# Q-values before heuristic adjustment: 4.0709143
# Q-values before heuristic adjustment: 4.1482964
# Q-values before heuristic adjustment: 4.1367397
# Q-values before heuristic adjustment: 4.1389303
# Q-values before heuristic adjustment: 4.140649
# Q-values before heuristic adjustment: 4.06719
# Q-values before heuristic adjustment: 4.1415305
# Q-values before heuristic adjustment: 4.1327696
# Q-values before heuristic adjustment: 4.1337457
# Q-values before heuristic adjustment: 4.132447
# Q-values before heuristic adjustment: 4.077942
# Q-values before heuristic adjustment: 4.1584177
# Q-values before heuristic adjustment: 4.133983
# Q-values before heuristic adjustment: 4.1377087
# Q-values before heuristic adjustment: 4.1366982
# Q-values before heuristic adjustment: 4.1158504
# Q-values before heuristic adjustment: 4.195654
# Q-values before heuristic adjustment: 4.1349297
# Q-values before heuristic adjustment: 4.14021
# Q-values before heuristic adjustment: 4.142756
# Q-values before heuristic adjustment: 4.063317
# Q-values before heuristic adjustment: 4.134453
# Q-values before heuristic adjustment: 4.130887
# Q-values before heuristic adjustment: 4.1317787
# Q-values before heuristic adjustment: 4.1317787
# Q-values before heuristic adjustment: 4.0630727
# Q-values before heuristic adjustment: 4.141913
# Q-values before heuristic adjustment: 4.130887
# Q-values before heuristic adjustment: 4.133229
# Q-values before heuristic adjustment: 4.1332803
# Q-values before heuristic adjustment: 4.068234
# Q-values before heuristic adjustment: 4.1483946
# Q-values before heuristic adjustment: 4.129835
# Q-values before heuristic adjustment: 4.1316185
# Q-values before heuristic adjustment: 4.1316185
# Q-values before heuristic adjustment: 4.062106
# Q-values before heuristic adjustment: 4.140122
# Q-values before heuristic adjustment: 4.1305456
# Q-values before heuristic adjustment: 4.1329393
# Q-values before heuristic adjustment: 4.1329393
# Q-values before heuristic adjustment: 4.0627384
# Q-values before heuristic adjustment: 4.138671
# Q-values before heuristic adjustment: 4.1290956
# Q-values before heuristic adjustment: 4.130697
# Q-values before heuristic adjustment: 4.1305976
# Q-values before heuristic adjustment: 4.133906
# Q-values before heuristic adjustment: 4.1360183
# Q-values before heuristic adjustment: 4.1353087
# Q-values before heuristic adjustment: 4.134698
# Q-values before heuristic adjustment: 4.0648985
# Q-values before heuristic adjustment: 4.1415224
# Q-values before heuristic adjustment: 4.131715
# Q-values before heuristic adjustment: 4.1334314
# Q-values before heuristic adjustment: 4.0636225
# Q-values before heuristic adjustment: 4.141526
# Q-values before heuristic adjustment: 4.131241
# Q-values before heuristic adjustment: 4.1337347
# Q-values before heuristic adjustment: 4.133635
# Q-values before heuristic adjustment: 4.061051
# Q-values before heuristic adjustment: 4.13758
# Q-values before heuristic adjustment: 4.1294556
# Q-values before heuristic adjustment: 4.1303988
# Q-values before heuristic adjustment: 4.1303473
# Q-values before heuristic adjustment: 4.140726
# Q-values before heuristic adjustment: 4.146479
# Q-values before heuristic adjustment: 4.151188
# Q-values before heuristic adjustment: 4.1474967
# Q-values before heuristic adjustment: 4.139501
# Q-values before heuristic adjustment: 4.139501
# Q-values before heuristic adjustment: 4.139501
# Q-values before heuristic adjustment: 4.119956
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 267
#     264         print("-" * 50)
#     266 if __name__ == "__main__":
# --> 267     train(cfg)
#
# Cell In[5], line 220, in train(cfg)
#     216 global_step = 0
#     218 for episode in range(cfg.n_episodes):
# --> 220     total_reward, hits, misses, bs_hits, bs_miss, enh_hits, enh_miss, global_step, psnr_rate = run_episode(
#     221         episode, env, agent, net_adapter, cfg, metrics_dir, global_step
#     222     )
#     224     agent.update_epsilon() # Function used to clean buffer memory
#     226     save_episode_metrics(
#     227         metrics_dir=metrics_dir,
#     228         ep=episode,
#    (...)
#     232         agent=agent,
#     233     )
#
# Cell In[5], line 121, in run_episode(episode, env, agent, net_adapter, cfg, metrics_dir, global_step_start)
#     118 req_state = info.get("user_request", None)
#     120 # --- Action Selection ---
# --> 121 action, missing, transition = select_action(agent, req_state, env, net_adapter)
#     123 # --- Environment Step ---
#     124 _, reward, done, info = env.step(action, req_state, net_adapter)
#
# Cell In[5], line 75, in select_action(agent, req_state, env, net_adapter)
#      59 backhaul_usage = process_missing_layer(
#      60     agent=agent,
#      61     req_state=req_state,
#    (...)
#      71     log_key="base_action",
#      72 )
#      74 for idx in range(cfg.viewport):
# ---> 75     backhaul_usage = process_missing_layer(
#      76         agent=agent,
#      77         req_state=req_state,
#      78         env=env,
#      79         net_adapter=net_adapter,
#      80         missing=missing,
#      81         transition=transition,
#      82         backhaul_usage=backhaul_usage,
#      83         layer_idx=idx + 1,
#      84         tile_idx=idx,
#      85         is_base=False,
#      86         bytes_cost=env.mec_cache.tile_size_bytes[1],
#      87         log_key=f"enh_{idx}_action",
#      88     )
#      90 debugger.log("backhaul_usage", backhaul_usage)
#      92 debugger.log("base_layer_miss", missing[0])
#
# Cell In[5], line 26, in process_missing_layer(agent, req_state, env, net_adapter, missing, transition, backhaul_usage, layer_idx, tile_idx, is_base, bytes_cost, log_key)
#      23     state, _, _, _, _ = net_adapter.build_observation(req_state["video"], tile)
#      24     tiles = [tile]
# ---> 26 action = agent.select_action(state)
#      28 transition[layer_idx] = {
#      29     'state': state,
#      30     'action': action
#      31 }
#      33 message = {
#      34     "video": req_state["video"],
#      35     "tiles": tiles,
#      36     "base_req_init": is_base,
#      37     "action_idx": action,
#      38 }
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\Sources\RL\DqnHeuWorker.py:171, in DqnHeuWorker.select_action(self, state)
#     168     return random.randint(0, self.action_dim - 1)
#     170 with torch.no_grad():
# --> 171     state_t = torch.tensor(state, dtype=torch.float32).to(self.device).unsqueeze(0)
#     172     qvals = self.policy_net(state_t)
#     174 print("Q-values before heuristic adjustment:", np.sum(qvals.cpu().numpy()))
#
# KeyboardInterrupt:
