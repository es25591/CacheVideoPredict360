# %%
import csv
import importlib
import os
import random
import sys
import torch
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd

from time import sleep
from collections import deque
from itertools import count
from typing import Any, Dict, List, Optional, Tuple, Set
from collections import defaultdict

sources_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if sources_path not in sys.path:
    sys.path.append(sources_path)

from importnb import Notebook
with Notebook():
    from Labs.LatencyModel import LatencyModel, MultiDULatencyModel
    from Labs.CacheEngine import CacheEngineEnv
    from Labs.UserRequest import UserRequestEvents
    from Labs.EnvWrapperLru import EnvWrapper

from RL.Adapters import FeatureAdapter, NetworkAdapter

import Common.config as config
import Common.datatypes as datatypes
import Common.debugger as debugger
import Common.utils as utils

importlib.reload(config)
importlib.reload(datatypes)
importlib.reload(debugger)
importlib.reload(utils)
# Out:
# <module 'Common.utils' from 'c:\\Users\\es25591\\Workspace\\CacheVideoPredict360\\Sources\\Common\\utils.py'>

# %%
CachePolicy = datatypes.CachePolicy
CacheKey = datatypes.CacheKey  # (vid, layer, tile, gop)

cfg = config.Config()

cfg.filename = f"lru.csv"
cfg.n_episodes = 100

debugger = debugger.debug

top_k = int(getattr(cfg, "topk_content_plot_k", 20))

# %%
class FifoPolicy(CachePolicy):

    def __init__(self, max_videos: int = 50, cfg: Any = None) -> None:
        self.cfg = cfg
        self.cur_size = 0

        # FIFO order: oldest inserted video at index 0.
        self.video_queue: List[int] = []

        # FIFO order per video for tiles: video -> tiles in insertion order.
        self.tile_queue: Dict[int, List[int]] = {}

        self.video_idx = [-1] * self.cfg.cache_size
        self.tile_idx = [[-1] * self.cfg.viewport for _ in range(self.cfg.cache_size)]

    def _ensure_video_slot(self, video: int) -> int:
        if video in self.video_idx:
            return self.video_idx.index(video)

        slot = self.video_idx.index(-1) if -1 in self.video_idx else None
        if slot is None:
            if not self.video_queue:
                raise RuntimeError("FIFO state is inconsistent: no free slot and no video to evict.")
            evicted_video = self.video_queue.pop(0)
            slot = self.video_idx.index(evicted_video)
            self.tile_queue.pop(evicted_video, None)

        self.video_idx[slot] = video
        self.tile_idx[slot] = [-1] * self.cfg.viewport
        self.tile_queue.setdefault(video, [])
        return slot

    def put(self, key: int, value: Any, size: int):
        new_video, new_tile = value
        slot = self._ensure_video_slot(new_video)

        if new_video not in self.video_queue:
            self.video_queue.append(new_video)

        if new_tile == -1:
            self.tile_idx[slot] = [-1] * self.cfg.viewport
            self.tile_queue.pop(new_video, None)
            self.cur_size = sum(1 for v in self.video_idx if v != -1)
            return []

        tiles = self.tile_queue.setdefault(new_video, [])
        if new_tile in tiles:
            self.cur_size = sum(1 for v in self.video_idx if v != -1)
            return []

        tiles.append(new_tile)
        slot_tiles = self.tile_idx[slot]
        slot_tiles.append(new_tile)
        if len(slot_tiles) > self.cfg.viewport:
            oldest_tile = slot_tiles.pop(0)
            if oldest_tile in tiles:
                tiles.remove(oldest_tile)

        self.cur_size = sum(1 for v in self.video_idx if v != -1)
        return []

    def get(self, key: CacheKey) -> Optional[Any]:
        raise NotImplementedError("FIFO policy does not support manual retrieval of individual keys.")

    def contains(self, key: CacheKey) -> bool:
        raise NotImplementedError("FIFO policy does not support manual checking of individual keys.")

    def keys(self):
        raise NotImplementedError("FIFO policy does not support manual retrieval of keys.")

    def remove(self, key: CacheKey) -> bool:
        raise NotImplementedError("FIFO policy does not support manual removal of individual keys.")

    def get_capacity(self) -> int:
        return self.cur_size

    def clear(self) -> None:
        self.video_queue.clear()
        self.tile_queue.clear()
        self.cur_size = 0
        self.video_idx = [-1] * self.cfg.cache_size
        self.tile_idx = [[-1] * self.cfg.viewport for _ in range(self.cfg.cache_size)]

    def stats(self) -> Dict[str, Any]:
        return {
            'current_size': self.cur_size,
            'capacity': self.cfg.cache_size,
            'num_items': len([v for v in self.video_idx if v != -1])
        }

# %%
def save_training_results(
    path_,
    filename,
    ep, 
    total_reward, 
    cache_hits, 
    cache_misses, 
    agent
):
    with open(os.path.join(path_, filename), 'a', newline='') as f:
        fieldnames = [
            'episode', 
            'total_reward', 
            'cache_hits', 
            'cache_misses', 
            'epsilon',
            'lr'
        ]
        writer_results = csv.DictWriter(f, fieldnames=fieldnames)

        if ep == 0:
            writer_results.writeheader()
        
        writer_results.writerow({
            'episode': ep,
            'total_reward': round(float(total_reward), 2),
            'cache_hits': cache_hits,
            'cache_misses': cache_misses,
            'lr': f"{agent.scheduler.get_last_lr()[0]:.10f}" if agent else None,
            'epsilon': round(float(agent.epsilon), 4) if agent else None
        })

def _append_csv_row(csv_path: str, fieldnames: list[str], row: dict) -> None:
    write_header = not os.path.exists(csv_path)
    with open(csv_path, 'a', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        if write_header:
            writer.writeheader()
        writer.writerow(row)

def save_episode_metrics(
    metrics_dir: str,
    ep: int,
    total_reward: float,
    cache_hits: int,
    cache_misses: int,
    chr: float,
    psnr: float,
    agent,
):
    csv_path = os.path.join(metrics_dir, 'episode_metrics.csv')
    fieldnames = [
        'episode',
        'total_reward',
        'cache_hits',
        'cache_misses',
        'hit_rate',
        'chr',
        'psnr',
        'epsilon',
        'lr',
    ]

    row = {
        'episode': ep,
        'total_reward': round(float(total_reward), 2),
        'cache_hits': cache_hits,
        'cache_misses': cache_misses,
        'hit_rate': float(cache_hits) / float(cache_hits + cache_misses + 1e-9),
        'chr': round(float(chr), 6) if chr is not None else None,
        'psnr': round(float(psnr), 6) if psnr is not None else None,
        'epsilon': round(float(agent.epsilon), 6) if agent else None,
        'lr': float(agent.scheduler.get_last_lr()[0]) if agent else None,
    }
    _append_csv_row(csv_path, fieldnames, row)

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, int, int]:
    enh_hits = info.get("enh_layer_hits", 0)
    base_hits = info.get("base_layer_hits", 0)
    enh_misses = info.get("enh_layer_misses", 0)
    base_misses = info.get("base_layer_misses", 0)

    return reward, base_hits, base_misses, enh_hits, enh_misses

def _print_video_psnr_ranking(
    video_watch_counts: dict[int, int],
    video_psnr_sums: dict[int, float],
    video_psnr_counts: dict[int, int],
    top_k: int,
) -> None:
    if not video_watch_counts:
        print("No watched videos recorded for this episode.")
        return

    ranked_videos = sorted(
        video_watch_counts.items(),
        key=lambda item: item[1],
        reverse=True,
    )[:max(1, int(top_k))]

    print(f"Mean PSNR across watched videos: {_mean_video_psnr(video_psnr_sums, video_psnr_counts):.2f}")
    print(f"Top {len(ranked_videos)} watched videos by rank:")
    for rank, (video_id, watch_count) in enumerate(ranked_videos, start=1):
        mean_psnr = 0.0
        if video_psnr_counts.get(video_id, 0) > 0:
            mean_psnr = video_psnr_sums[video_id] / video_psnr_counts[video_id]
        print(
            f"{rank:02d}. Video {video_id} | watches={watch_count} | mean_psnr={mean_psnr:.2f}"
        )

def _mean_video_psnr(video_psnr_sums: dict[int, float], video_psnr_counts: dict[int, int]) -> float:
    per_video_psnr = [
        video_psnr_sums[video_id] / video_psnr_counts[video_id]
        for video_id in video_psnr_counts
        if video_psnr_counts[video_id] > 0
    ]
    return float(np.mean(per_video_psnr)) if per_video_psnr else 0.0

def _snapshot_cache(env) -> set[tuple[int, int]]:
    cache_set: set[tuple[int, int]] = set()
    cache_entries = getattr(env.mec_cache.policy, "cache", [])

    for video, tile in cache_entries:
        if int(video) == -1:
            continue
        cache_set.add((int(video), int(tile)))

    return cache_set

def _content_key(video: int, tile: int | None) -> tuple[int, int]:
    return (int(video), -1 if tile is None else int(tile))

def build_latency_model(cfg):
    """Build and return the MultiDULatencyModel."""
    P = cfg.n_nodes
    max_U = cfg.n_users

    return MultiDULatencyModel(
        P=P,
        max_U=max_U,
        R_M_D=80e6,
        R_C_M=125e6,
        mu=2e7,
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float),
        rhoT_p=[0.2],
        lambda_p=[0.05],
        du_fixed_delay=0.001,
        mec_fixed_delay=0.005,
        cloud_fixed_delay=0.1
    )

def build_environment(cfg):
    """Construct the full multi-component environment wrapper."""
    du_caches = []

    policy=FifoPolicy(
        cfg=cfg,
        max_videos=cfg.cache_size,
    )

    # MEC Cache Engine
    mec_cache = CacheEngineEnv(
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n_gops=cfg.n_gops,
        cache_capacity=cfg.cache_capacity,
        policy=policy
    )

    # User request generator
    users_env = UserRequestEvents(
        n_nodes=cfg.n_nodes,
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_gops=cfg.n_gops,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n=cfg.n,
        m=cfg.m,
        arrival_rate=cfg.arrival_rate,
        zipf_alpha=cfg.zipf_alpha
    )

    # Latency Model
    latency_model = build_latency_model(cfg)
    
    # Wrapping all into the main training environment
    return EnvWrapper(
        cfg=cfg,
        n=cfg.n,
        m=cfg.m,
        n_layers=cfg.n_layers,
        users_env=users_env,
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=latency_model,
        theta=cfg.theta,
        lam=cfg.lam,
        max_steps=cfg.max_steps,
        prefetch_fn=lambda cache, action: cache.lru_live_prefetching(action),
        reward_fn=lambda env, reqs: env.compute_reward(reqs),
        debugger=debugger
    )

# %%
def run_episode(episode, env, net_adapter, cfg, metrics_dir, global_step_start):
    """Run one full training episode."""
    _, info = net_adapter.reset()

    total_reward = 0.0
    cache_hits = cache_misses = 0
    base_hits = base_misses = 0
    enh_hits = enh_misses = 0
    psnr_sum = 0.0
    popularity_bonus_sum = 0.0

    episode_request_counts: dict[tuple[int, int], int] = defaultdict(int)
    video_watch_counts: dict[int, int] = defaultdict(int)
    video_psnr_sums: dict[int, float] = defaultdict(float)
    video_psnr_counts: dict[int, int] = defaultdict(int)

    global_step = global_step_start

    if cfg.has_warmup and episode == 0:
        env.warmup_phase(net_adapter, 1000)

    for step in range(cfg.max_steps):
        global_step += 1
        req_state = info.get("user_request", None)
        
        current_video_id = None

        if req_state is not None:
            current_video_id = int(req_state["video"])
            episode_request_counts[_content_key(current_video_id, None)] += 1
            video_watch_counts[current_video_id] += 1
            for tile in req_state.get("viewport", []):
                episode_request_counts[_content_key(current_video_id, int(tile))] += 1

        _, reward, _, info = env.step(req_state, net_adapter)

        if current_video_id is not None:
            step_psnr = float(info.get("psnr", 0.0))
            video_psnr_sums[current_video_id] += step_psnr
            video_psnr_counts[current_video_id] += 1

        delta_r, bs_hits, bs_miss, e_hits, e_miss = update_metrics(info, reward)
        total_reward += delta_r
        cache_hits += bs_hits + e_hits
        cache_misses += bs_miss + e_miss
        base_hits += bs_hits
        base_misses += bs_miss
        enh_hits += e_hits
        enh_misses += e_miss
        psnr_sum += info.get("psnr", 0.0)

        if net_adapter.env_is_done():
            break

        debugger.log("cache_hits", cache_hits)
        debugger.log("cache_misses", cache_misses)

    cache_snapshot = _snapshot_cache(env)

    return (
        total_reward,
        cache_hits,
        cache_misses,
        base_hits,
        base_misses,
        enh_hits,
        enh_misses,
        global_step,
        psnr_sum / (step + 1),
        dict(episode_request_counts),
        dict(video_watch_counts),
        dict(video_psnr_sums),
        dict(video_psnr_counts),
        cache_snapshot,
        popularity_bonus_sum,
    )

def train(cfg):
    print("\n--- Starting DRL Caching System ---")

    env = build_environment(cfg)

    feature_adapter = FeatureAdapter(cfg, env)
    net_adapter = NetworkAdapter(cfg, env, feature_adapter)

    date_dir = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M")
    debug_path = os.path.join(cfg.path_results, date_dir)
    metrics_dir = os.path.join(debug_path, "metrics")
    os.makedirs(metrics_dir, exist_ok=True)

    global_log_path = os.path.join(cfg.path_results, "global.log")
    with open(global_log_path, "a", encoding="utf-8") as f:
        f.write(f"{pd.Timestamp.now().isoformat()} | Max Steps: {cfg.max_steps} | ")
        f.write("-" * 50 + "\n")

    global_step = 0

    for episode in range(cfg.n_episodes):
        (
            total_reward,
            cache_hits,
            cache_misses,
            base_hits,
            base_misses,
            enh_hits,
            enh_misses,
            global_step,
            psnr_rate,
            episode_request_counts,
            episode_video_watch_counts,
            episode_video_psnr_sums,
            episode_video_psnr_counts,
            cache_snapshot,
            popularity_bonus_sum,
        ) = run_episode(episode, env, net_adapter, cfg, metrics_dir, global_step)

        debugger.save_results(filepath=f"{debug_path}/json/debug_ep{episode}")
        debugger.clear()

        base_hit_rate = base_hits / (base_hits + base_misses + 1e-9)
        enh_hit_rate = enh_hits / (enh_hits + enh_misses + 1e-9)
        mean_video_psnr = _mean_video_psnr(episode_video_psnr_sums, episode_video_psnr_counts)

        print(
            f"Episode {episode} | R: {int(total_reward)} | "
            f"HR: {cache_hits / (cache_hits + cache_misses + 1e-9):.2f} | "
            f"HR_2: {(base_hit_rate + enh_hit_rate * 4) / 5:.2f} | "
            f"BHR: {base_hit_rate:.2f} | "
            f"EHR: {enh_hit_rate:.2f} | "
            f"PSNR: {psnr_rate:.2f} | "
            f"Mean video PSNR: {mean_video_psnr:.2f} | "
            f"Popularity bonus: {popularity_bonus_sum:.4f} | "
            f"Time: {pd.Timestamp.now().strftime('%H:%M:%S')}"
        )

        # _print_video_psnr_ranking(
        #     video_watch_counts=episode_video_watch_counts,
        #     video_psnr_sums=episode_video_psnr_sums,
        #     video_psnr_counts=episode_video_psnr_counts,
        #     top_k=top_k,
        # )
        print("-" * 50)

        save_episode_metrics(
            metrics_dir=metrics_dir,
            ep=episode,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            chr=(base_hit_rate + enh_hit_rate * 4) / 5, 
            psnr=mean_video_psnr,
            agent=None
        )


if __name__ == "__main__":
    train(cfg)
# Out:
# --- Starting DRL Caching System ---
# NetworkAdapter initialized with capacity: 100 videos, 4 tiles per video
# Episode 0 | R: 0 | HR: 0.74 | HR_2: 0.53 | BHR: 0.84 | EHR: 0.45 | PSNR: 35.21 | Mean video PSNR: 35.24 | Popularity bonus: 0.0000 | Time: 10:38:08
# Mean PSNR across watched videos: 35.24
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1307 | mean_psnr=35.35
# 02. Video 1 | watches=820 | mean_psnr=35.12
# 03. Video 2 | watches=475 | mean_psnr=35.27
# 04. Video 5 | watches=423 | mean_psnr=34.86
# 05. Video 3 | watches=293 | mean_psnr=35.12
# 06. Video 7 | watches=261 | mean_psnr=36.00
# 07. Video 4 | watches=248 | mean_psnr=35.72
# 08. Video 9 | watches=184 | mean_psnr=35.01
# 09. Video 10 | watches=176 | mean_psnr=35.34
# 10. Video 8 | watches=164 | mean_psnr=35.18
# 11. Video 16 | watches=160 | mean_psnr=34.73
# 12. Video 6 | watches=158 | mean_psnr=35.54
# 13. Video 12 | watches=117 | mean_psnr=34.83
# 14. Video 21 | watches=111 | mean_psnr=35.90
# 15. Video 11 | watches=110 | mean_psnr=34.73
# 16. Video 34 | watches=109 | mean_psnr=35.60
# 17. Video 27 | watches=109 | mean_psnr=34.72
# 18. Video 22 | watches=97 | mean_psnr=34.77
# 19. Video 58 | watches=89 | mean_psnr=35.31
# 20. Video 13 | watches=88 | mean_psnr=34.57
# --------------------------------------------------
# Episode 1 | R: 0 | HR: 0.77 | HR_2: 0.56 | BHR: 0.87 | EHR: 0.49 | PSNR: 35.50 | Mean video PSNR: 35.54 | Popularity bonus: 0.0000 | Time: 10:38:09
# Mean PSNR across watched videos: 35.54
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1697 | mean_psnr=35.51
# 02. Video 1 | watches=922 | mean_psnr=35.43
# 03. Video 2 | watches=553 | mean_psnr=35.72
# 04. Video 3 | watches=389 | mean_psnr=35.15
# 05. Video 4 | watches=351 | mean_psnr=35.30
# 06. Video 5 | watches=330 | mean_psnr=35.54
# 07. Video 8 | watches=283 | mean_psnr=35.87
# 08. Video 11 | watches=268 | mean_psnr=35.43
# 09. Video 14 | watches=206 | mean_psnr=36.06
# 10. Video 24 | watches=201 | mean_psnr=35.63
# 11. Video 9 | watches=180 | mean_psnr=35.97
# 12. Video 12 | watches=160 | mean_psnr=35.36
# 13. Video 6 | watches=118 | mean_psnr=34.94
# 14. Video 22 | watches=110 | mean_psnr=34.52
# 15. Video 19 | watches=109 | mean_psnr=36.19
# 16. Video 17 | watches=100 | mean_psnr=34.38
# 17. Video 115 | watches=90 | mean_psnr=34.97
# 18. Video 49 | watches=87 | mean_psnr=35.29
# 19. Video 13 | watches=86 | mean_psnr=35.84
# 20. Video 10 | watches=85 | mean_psnr=35.18
# --------------------------------------------------
# Episode 2 | R: 0 | HR: 0.82 | HR_2: 0.58 | BHR: 0.93 | EHR: 0.50 | PSNR: 35.71 | Mean video PSNR: 35.56 | Popularity bonus: 0.0000 | Time: 10:38:10
# Mean PSNR across watched videos: 35.56
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1633 | mean_psnr=36.04
# 02. Video 1 | watches=1051 | mean_psnr=35.64
# 03. Video 3 | watches=459 | mean_psnr=35.74
# 04. Video 2 | watches=450 | mean_psnr=35.48
# 05. Video 4 | watches=387 | mean_psnr=35.93
# 06. Video 6 | watches=241 | mean_psnr=36.14
# 07. Video 13 | watches=232 | mean_psnr=35.99
# 08. Video 12 | watches=227 | mean_psnr=35.51
# 09. Video 8 | watches=211 | mean_psnr=35.21
# 10. Video 9 | watches=200 | mean_psnr=35.42
# 11. Video 7 | watches=198 | mean_psnr=35.76
# 12. Video 26 | watches=193 | mean_psnr=35.19
# 13. Video 14 | watches=191 | mean_psnr=36.31
# 14. Video 10 | watches=188 | mean_psnr=35.08
# 15. Video 28 | watches=182 | mean_psnr=35.30
# 16. Video 20 | watches=140 | mean_psnr=36.45
# 17. Video 5 | watches=128 | mean_psnr=36.39
# 18. Video 15 | watches=117 | mean_psnr=36.73
# 19. Video 29 | watches=115 | mean_psnr=35.54
# 20. Video 21 | watches=95 | mean_psnr=35.37
# --------------------------------------------------
# Episode 3 | R: 0 | HR: 0.77 | HR_2: 0.55 | BHR: 0.87 | EHR: 0.47 | PSNR: 35.39 | Mean video PSNR: 35.32 | Popularity bonus: 0.0000 | Time: 10:38:11
# Mean PSNR across watched videos: 35.32
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1138 | mean_psnr=35.43
# 02. Video 1 | watches=757 | mean_psnr=35.31
# 03. Video 2 | watches=697 | mean_psnr=35.36
# 04. Video 3 | watches=549 | mean_psnr=35.31
# 05. Video 4 | watches=415 | mean_psnr=35.82
# 06. Video 5 | watches=339 | mean_psnr=36.03
# 07. Video 7 | watches=278 | mean_psnr=35.26
# 08. Video 13 | watches=236 | mean_psnr=35.39
# 09. Video 11 | watches=205 | mean_psnr=35.44
# 10. Video 16 | watches=193 | mean_psnr=35.22
# 11. Video 9 | watches=193 | mean_psnr=35.66
# 12. Video 6 | watches=166 | mean_psnr=35.30
# 13. Video 14 | watches=164 | mean_psnr=35.32
# 14. Video 39 | watches=120 | mean_psnr=35.17
# 15. Video 8 | watches=112 | mean_psnr=35.54
# 16. Video 41 | watches=101 | mean_psnr=35.54
# 17. Video 10 | watches=98 | mean_psnr=35.59
# 18. Video 12 | watches=94 | mean_psnr=35.51
# 19. Video 17 | watches=91 | mean_psnr=33.76
# 20. Video 58 | watches=90 | mean_psnr=35.33
# --------------------------------------------------
# Episode 4 | R: 0 | HR: 0.84 | HR_2: 0.61 | BHR: 0.95 | EHR: 0.53 | PSNR: 35.98 | Mean video PSNR: 36.00 | Popularity bonus: 0.0000 | Time: 10:38:12
# Mean PSNR across watched videos: 36.00
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1516 | mean_psnr=35.97
# 02. Video 1 | watches=989 | mean_psnr=35.88
# 03. Video 2 | watches=607 | mean_psnr=36.47
# 04. Video 3 | watches=496 | mean_psnr=35.48
# 05. Video 4 | watches=473 | mean_psnr=36.05
# 06. Video 6 | watches=294 | mean_psnr=36.50
# 07. Video 9 | watches=252 | mean_psnr=35.67
# 08. Video 5 | watches=211 | mean_psnr=36.23
# 09. Video 13 | watches=211 | mean_psnr=36.42
# 10. Video 43 | watches=190 | mean_psnr=36.07
# 11. Video 33 | watches=176 | mean_psnr=35.53
# 12. Video 17 | watches=159 | mean_psnr=36.27
# 13. Video 8 | watches=158 | mean_psnr=35.82
# 14. Video 19 | watches=138 | mean_psnr=35.27
# 15. Video 71 | watches=129 | mean_psnr=35.25
# 16. Video 22 | watches=120 | mean_psnr=35.31
# 17. Video 14 | watches=115 | mean_psnr=35.87
# 18. Video 23 | watches=109 | mean_psnr=35.46
# 19. Video 15 | watches=105 | mean_psnr=35.26
# 20. Video 37 | watches=101 | mean_psnr=36.56
# --------------------------------------------------
# Episode 5 | R: 0 | HR: 0.85 | HR_2: 0.59 | BHR: 0.96 | EHR: 0.50 | PSNR: 35.83 | Mean video PSNR: 35.86 | Popularity bonus: 0.0000 | Time: 10:38:13
# Mean PSNR across watched videos: 35.86
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1813 | mean_psnr=35.80
# 02. Video 1 | watches=1056 | mean_psnr=35.57
# 03. Video 2 | watches=641 | mean_psnr=35.85
# 04. Video 3 | watches=498 | mean_psnr=36.12
# 05. Video 4 | watches=442 | mean_psnr=35.80
# 06. Video 5 | watches=420 | mean_psnr=36.14
# 07. Video 7 | watches=231 | mean_psnr=35.67
# 08. Video 8 | watches=231 | mean_psnr=35.44
# 09. Video 10 | watches=216 | mean_psnr=35.38
# 10. Video 9 | watches=191 | mean_psnr=35.81
# 11. Video 6 | watches=174 | mean_psnr=36.05
# 12. Video 15 | watches=158 | mean_psnr=35.87
# 13. Video 18 | watches=148 | mean_psnr=35.93
# 14. Video 20 | watches=119 | mean_psnr=35.19
# 15. Video 39 | watches=119 | mean_psnr=36.11
# 16. Video 41 | watches=105 | mean_psnr=36.02
# 17. Video 12 | watches=97 | mean_psnr=36.13
# 18. Video 17 | watches=97 | mean_psnr=36.60
# 19. Video 13 | watches=86 | mean_psnr=35.93
# 20. Video 16 | watches=86 | mean_psnr=36.13
# --------------------------------------------------
# Episode 6 | R: 0 | HR: 0.79 | HR_2: 0.56 | BHR: 0.89 | EHR: 0.48 | PSNR: 35.52 | Mean video PSNR: 35.44 | Popularity bonus: 0.0000 | Time: 10:38:14
# Mean PSNR across watched videos: 35.44
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1981 | mean_psnr=35.72
# 02. Video 1 | watches=839 | mean_psnr=35.42
# 03. Video 3 | watches=509 | mean_psnr=35.22
# 04. Video 2 | watches=465 | mean_psnr=35.24
# 05. Video 5 | watches=321 | mean_psnr=35.69
# 06. Video 4 | watches=250 | mean_psnr=35.78
# 07. Video 7 | watches=213 | mean_psnr=35.59
# 08. Video 9 | watches=209 | mean_psnr=35.29
# 09. Video 8 | watches=199 | mean_psnr=35.70
# 10. Video 10 | watches=178 | mean_psnr=34.83
# 11. Video 6 | watches=161 | mean_psnr=35.34
# 12. Video 15 | watches=149 | mean_psnr=35.57
# 13. Video 14 | watches=145 | mean_psnr=35.03
# 14. Video 11 | watches=145 | mean_psnr=35.64
# 15. Video 13 | watches=118 | mean_psnr=36.69
# 16. Video 16 | watches=115 | mean_psnr=35.83
# 17. Video 31 | watches=102 | mean_psnr=36.27
# 18. Video 21 | watches=95 | mean_psnr=35.45
# 19. Video 254 | watches=89 | mean_psnr=35.76
# 20. Video 82 | watches=89 | mean_psnr=36.12
# --------------------------------------------------
# Episode 7 | R: 0 | HR: 0.83 | HR_2: 0.59 | BHR: 0.93 | EHR: 0.51 | PSNR: 35.81 | Mean video PSNR: 35.84 | Popularity bonus: 0.0000 | Time: 10:38:15
# Mean PSNR across watched videos: 35.84
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1470 | mean_psnr=35.87
# 02. Video 1 | watches=868 | mean_psnr=36.00
# 03. Video 4 | watches=538 | mean_psnr=35.70
# 04. Video 2 | watches=397 | mean_psnr=35.59
# 05. Video 5 | watches=384 | mean_psnr=35.77
# 06. Video 6 | watches=341 | mean_psnr=35.88
# 07. Video 3 | watches=296 | mean_psnr=36.62
# 08. Video 10 | watches=256 | mean_psnr=35.40
# 09. Video 7 | watches=198 | mean_psnr=35.48
# 10. Video 9 | watches=178 | mean_psnr=35.48
# 11. Video 8 | watches=170 | mean_psnr=35.79
# 12. Video 15 | watches=165 | mean_psnr=35.61
# 13. Video 11 | watches=163 | mean_psnr=36.81
# 14. Video 16 | watches=158 | mean_psnr=36.31
# 15. Video 25 | watches=148 | mean_psnr=35.66
# 16. Video 42 | watches=141 | mean_psnr=35.51
# 17. Video 17 | watches=139 | mean_psnr=36.06
# 18. Video 32 | watches=131 | mean_psnr=35.06
# 19. Video 12 | watches=121 | mean_psnr=35.68
# 20. Video 48 | watches=108 | mean_psnr=36.11
# --------------------------------------------------
# Episode 8 | R: 0 | HR: 0.72 | HR_2: 0.51 | BHR: 0.81 | EHR: 0.44 | PSNR: 35.01 | Mean video PSNR: 34.97 | Popularity bonus: 0.0000 | Time: 10:38:16
# Mean PSNR across watched videos: 34.97
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1633 | mean_psnr=35.14
# 02. Video 1 | watches=807 | mean_psnr=35.09
# 03. Video 2 | watches=484 | mean_psnr=34.66
# 04. Video 4 | watches=412 | mean_psnr=35.14
# 05. Video 6 | watches=330 | mean_psnr=34.81
# 06. Video 5 | watches=319 | mean_psnr=34.89
# 07. Video 3 | watches=283 | mean_psnr=35.13
# 08. Video 8 | watches=280 | mean_psnr=35.10
# 09. Video 7 | watches=244 | mean_psnr=34.91
# 10. Video 12 | watches=159 | mean_psnr=35.24
# 11. Video 14 | watches=135 | mean_psnr=35.74
# 12. Video 25 | watches=131 | mean_psnr=34.71
# 13. Video 9 | watches=104 | mean_psnr=35.07
# 14. Video 18 | watches=104 | mean_psnr=35.38
# 15. Video 15 | watches=103 | mean_psnr=34.44
# 16. Video 33 | watches=102 | mean_psnr=35.39
# 17. Video 67 | watches=101 | mean_psnr=34.85
# 18. Video 11 | watches=99 | mean_psnr=34.87
# 19. Video 24 | watches=94 | mean_psnr=35.37
# 20. Video 17 | watches=92 | mean_psnr=35.33
# --------------------------------------------------
# Episode 9 | R: 0 | HR: 0.71 | HR_2: 0.52 | BHR: 0.81 | EHR: 0.44 | PSNR: 35.06 | Mean video PSNR: 35.15 | Popularity bonus: 0.0000 | Time: 10:38:17
# Mean PSNR across watched videos: 35.15
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1608 | mean_psnr=35.05
# 02. Video 1 | watches=745 | mean_psnr=35.24
# 03. Video 3 | watches=585 | mean_psnr=34.67
# 04. Video 2 | watches=565 | mean_psnr=34.75
# 05. Video 5 | watches=324 | mean_psnr=35.14
# 06. Video 4 | watches=252 | mean_psnr=35.20
# 07. Video 8 | watches=224 | mean_psnr=35.27
# 08. Video 6 | watches=221 | mean_psnr=35.36
# 09. Video 11 | watches=192 | mean_psnr=35.17
# 10. Video 9 | watches=179 | mean_psnr=34.64
# 11. Video 7 | watches=169 | mean_psnr=34.59
# 12. Video 15 | watches=140 | mean_psnr=34.68
# 13. Video 43 | watches=140 | mean_psnr=35.12
# 14. Video 101 | watches=134 | mean_psnr=35.52
# 15. Video 13 | watches=121 | mean_psnr=35.04
# 16. Video 156 | watches=118 | mean_psnr=34.89
# 17. Video 28 | watches=115 | mean_psnr=35.11
# 18. Video 16 | watches=104 | mean_psnr=34.98
# 19. Video 10 | watches=97 | mean_psnr=34.56
# 20. Video 37 | watches=88 | mean_psnr=34.89
# --------------------------------------------------
# Episode 10 | R: 0 | HR: 0.79 | HR_2: 0.57 | BHR: 0.89 | EHR: 0.49 | PSNR: 35.57 | Mean video PSNR: 35.56 | Popularity bonus: 0.0000 | Time: 10:38:18
# Mean PSNR across watched videos: 35.56
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1458 | mean_psnr=35.59
# 02. Video 1 | watches=834 | mean_psnr=35.49
# 03. Video 2 | watches=598 | mean_psnr=35.73
# 04. Video 5 | watches=381 | mean_psnr=35.45
# 05. Video 4 | watches=379 | mean_psnr=35.63
# 06. Video 6 | watches=341 | mean_psnr=35.43
# 07. Video 3 | watches=327 | mean_psnr=35.50
# 08. Video 8 | watches=234 | mean_psnr=35.85
# 09. Video 12 | watches=216 | mean_psnr=35.32
# 10. Video 15 | watches=210 | mean_psnr=36.17
# 11. Video 7 | watches=200 | mean_psnr=35.71
# 12. Video 21 | watches=195 | mean_psnr=35.53
# 13. Video 13 | watches=177 | mean_psnr=35.20
# 14. Video 20 | watches=149 | mean_psnr=35.13
# 15. Video 16 | watches=148 | mean_psnr=35.37
# 16. Video 18 | watches=146 | mean_psnr=35.31
# 17. Video 11 | watches=123 | mean_psnr=35.49
# 18. Video 9 | watches=122 | mean_psnr=35.92
# 19. Video 10 | watches=117 | mean_psnr=35.19
# 20. Video 27 | watches=114 | mean_psnr=35.42
# --------------------------------------------------
# Episode 11 | R: 0 | HR: 0.82 | HR_2: 0.59 | BHR: 0.93 | EHR: 0.50 | PSNR: 35.75 | Mean video PSNR: 35.70 | Popularity bonus: 0.0000 | Time: 10:38:19
# Mean PSNR across watched videos: 35.70
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1563 | mean_psnr=35.93
# 02. Video 1 | watches=1126 | mean_psnr=35.72
# 03. Video 2 | watches=498 | mean_psnr=35.67
# 04. Video 5 | watches=358 | mean_psnr=35.68
# 05. Video 4 | watches=349 | mean_psnr=35.70
# 06. Video 3 | watches=339 | mean_psnr=36.17
# 07. Video 13 | watches=280 | mean_psnr=35.88
# 08. Video 11 | watches=260 | mean_psnr=35.59
# 09. Video 15 | watches=241 | mean_psnr=35.08
# 10. Video 6 | watches=229 | mean_psnr=35.38
# 11. Video 14 | watches=224 | mean_psnr=35.71
# 12. Video 9 | watches=170 | mean_psnr=36.22
# 13. Video 17 | watches=143 | mean_psnr=36.47
# 14. Video 26 | watches=139 | mean_psnr=35.68
# 15. Video 7 | watches=137 | mean_psnr=35.31
# 16. Video 18 | watches=137 | mean_psnr=35.69
# 17. Video 16 | watches=127 | mean_psnr=35.39
# 18. Video 12 | watches=123 | mean_psnr=35.65
# 19. Video 34 | watches=118 | mean_psnr=35.85
# 20. Video 81 | watches=107 | mean_psnr=36.05
# --------------------------------------------------
# Episode 12 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.94 | EHR: 0.51 | PSNR: 35.86 | Mean video PSNR: 35.79 | Popularity bonus: 0.0000 | Time: 10:38:20
# Mean PSNR across watched videos: 35.79
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1653 | mean_psnr=35.89
# 02. Video 1 | watches=938 | mean_psnr=35.82
# 03. Video 2 | watches=903 | mean_psnr=35.95
# 04. Video 4 | watches=405 | mean_psnr=35.73
# 05. Video 5 | watches=373 | mean_psnr=35.66
# 06. Video 9 | watches=297 | mean_psnr=36.03
# 07. Video 6 | watches=281 | mean_psnr=36.25
# 08. Video 7 | watches=253 | mean_psnr=36.22
# 09. Video 3 | watches=249 | mean_psnr=35.32
# 10. Video 12 | watches=231 | mean_psnr=36.35
# 11. Video 11 | watches=211 | mean_psnr=35.71
# 12. Video 10 | watches=174 | mean_psnr=36.02
# 13. Video 22 | watches=167 | mean_psnr=36.50
# 14. Video 14 | watches=151 | mean_psnr=35.17
# 15. Video 8 | watches=127 | mean_psnr=35.14
# 16. Video 29 | watches=115 | mean_psnr=35.72
# 17. Video 15 | watches=110 | mean_psnr=37.39
# 18. Video 49 | watches=91 | mean_psnr=37.34
# 19. Video 35 | watches=91 | mean_psnr=35.69
# 20. Video 21 | watches=87 | mean_psnr=35.37
# --------------------------------------------------
# Episode 13 | R: 0 | HR: 0.83 | HR_2: 0.59 | BHR: 0.94 | EHR: 0.51 | PSNR: 35.82 | Mean video PSNR: 35.70 | Popularity bonus: 0.0000 | Time: 10:38:21
# Mean PSNR across watched videos: 35.70
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1400 | mean_psnr=35.94
# 02. Video 1 | watches=1069 | mean_psnr=35.96
# 03. Video 2 | watches=614 | mean_psnr=35.79
# 04. Video 3 | watches=458 | mean_psnr=35.92
# 05. Video 4 | watches=328 | mean_psnr=35.58
# 06. Video 5 | watches=321 | mean_psnr=35.88
# 07. Video 9 | watches=255 | mean_psnr=35.98
# 08. Video 7 | watches=255 | mean_psnr=35.70
# 09. Video 11 | watches=241 | mean_psnr=35.91
# 10. Video 16 | watches=223 | mean_psnr=35.72
# 11. Video 6 | watches=198 | mean_psnr=35.76
# 12. Video 8 | watches=188 | mean_psnr=35.33
# 13. Video 12 | watches=177 | mean_psnr=36.30
# 14. Video 15 | watches=154 | mean_psnr=36.19
# 15. Video 19 | watches=145 | mean_psnr=35.86
# 16. Video 32 | watches=144 | mean_psnr=36.15
# 17. Video 17 | watches=136 | mean_psnr=35.86
# 18. Video 69 | watches=118 | mean_psnr=34.89
# 19. Video 47 | watches=116 | mean_psnr=36.83
# 20. Video 18 | watches=115 | mean_psnr=35.59
# --------------------------------------------------
# Episode 14 | R: 0 | HR: 0.73 | HR_2: 0.52 | BHR: 0.82 | EHR: 0.44 | PSNR: 35.06 | Mean video PSNR: 35.01 | Popularity bonus: 0.0000 | Time: 10:38:22
# Mean PSNR across watched videos: 35.01
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1657 | mean_psnr=35.13
# 02. Video 1 | watches=678 | mean_psnr=35.27
# 03. Video 2 | watches=569 | mean_psnr=34.93
# 04. Video 3 | watches=420 | mean_psnr=35.02
# 05. Video 5 | watches=334 | mean_psnr=34.89
# 06. Video 7 | watches=273 | mean_psnr=35.89
# 07. Video 6 | watches=254 | mean_psnr=34.66
# 08. Video 14 | watches=187 | mean_psnr=34.73
# 09. Video 27 | watches=176 | mean_psnr=36.26
# 10. Video 22 | watches=166 | mean_psnr=34.98
# 11. Video 9 | watches=166 | mean_psnr=34.92
# 12. Video 13 | watches=155 | mean_psnr=34.92
# 13. Video 4 | watches=148 | mean_psnr=35.24
# 14. Video 15 | watches=144 | mean_psnr=35.10
# 15. Video 11 | watches=132 | mean_psnr=34.58
# 16. Video 16 | watches=122 | mean_psnr=34.71
# 17. Video 8 | watches=114 | mean_psnr=35.72
# 18. Video 33 | watches=113 | mean_psnr=35.00
# 19. Video 31 | watches=113 | mean_psnr=34.78
# 20. Video 12 | watches=112 | mean_psnr=35.56
# --------------------------------------------------
# Episode 15 | R: 0 | HR: 0.83 | HR_2: 0.59 | BHR: 0.94 | EHR: 0.50 | PSNR: 35.79 | Mean video PSNR: 35.66 | Popularity bonus: 0.0000 | Time: 10:38:23
# Mean PSNR across watched videos: 35.66
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1880 | mean_psnr=35.83
# 02. Video 1 | watches=870 | mean_psnr=35.69
# 03. Video 2 | watches=497 | mean_psnr=35.87
# 04. Video 3 | watches=397 | mean_psnr=35.62
# 05. Video 4 | watches=296 | mean_psnr=35.88
# 06. Video 6 | watches=293 | mean_psnr=35.65
# 07. Video 7 | watches=269 | mean_psnr=35.68
# 08. Video 5 | watches=262 | mean_psnr=35.90
# 09. Video 8 | watches=260 | mean_psnr=36.14
# 10. Video 14 | watches=196 | mean_psnr=36.08
# 11. Video 17 | watches=193 | mean_psnr=35.82
# 12. Video 11 | watches=191 | mean_psnr=35.52
# 13. Video 10 | watches=179 | mean_psnr=36.69
# 14. Video 22 | watches=174 | mean_psnr=35.95
# 15. Video 48 | watches=163 | mean_psnr=35.72
# 16. Video 36 | watches=149 | mean_psnr=36.11
# 17. Video 9 | watches=144 | mean_psnr=35.61
# 18. Video 16 | watches=138 | mean_psnr=36.45
# 19. Video 13 | watches=133 | mean_psnr=35.75
# 20. Video 68 | watches=111 | mean_psnr=35.74
# --------------------------------------------------
# Episode 16 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.95 | EHR: 0.51 | PSNR: 35.86 | Mean video PSNR: 35.83 | Popularity bonus: 0.0000 | Time: 10:38:24
# Mean PSNR across watched videos: 35.83
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1444 | mean_psnr=36.04
# 02. Video 1 | watches=1150 | mean_psnr=35.56
# 03. Video 2 | watches=833 | mean_psnr=35.81
# 04. Video 4 | watches=415 | mean_psnr=36.32
# 05. Video 3 | watches=330 | mean_psnr=35.67
# 06. Video 9 | watches=241 | mean_psnr=35.96
# 07. Video 5 | watches=204 | mean_psnr=36.02
# 08. Video 7 | watches=186 | mean_psnr=35.46
# 09. Video 24 | watches=175 | mean_psnr=36.47
# 10. Video 6 | watches=171 | mean_psnr=36.27
# 11. Video 20 | watches=168 | mean_psnr=36.16
# 12. Video 13 | watches=159 | mean_psnr=35.82
# 13. Video 8 | watches=152 | mean_psnr=36.09
# 14. Video 18 | watches=148 | mean_psnr=34.98
# 15. Video 11 | watches=145 | mean_psnr=36.10
# 16. Video 19 | watches=127 | mean_psnr=35.22
# 17. Video 10 | watches=121 | mean_psnr=35.43
# 18. Video 33 | watches=119 | mean_psnr=36.05
# 19. Video 31 | watches=117 | mean_psnr=36.50
# 20. Video 35 | watches=116 | mean_psnr=36.19
# --------------------------------------------------
# Episode 17 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.96 | EHR: 0.53 | PSNR: 35.98 | Mean video PSNR: 35.91 | Popularity bonus: 0.0000 | Time: 10:38:25
# Mean PSNR across watched videos: 35.91
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1754 | mean_psnr=36.13
# 02. Video 1 | watches=980 | mean_psnr=35.91
# 03. Video 2 | watches=629 | mean_psnr=36.32
# 04. Video 3 | watches=444 | mean_psnr=35.82
# 05. Video 4 | watches=423 | mean_psnr=36.37
# 06. Video 7 | watches=397 | mean_psnr=36.13
# 07. Video 6 | watches=270 | mean_psnr=35.77
# 08. Video 5 | watches=236 | mean_psnr=35.69
# 09. Video 9 | watches=202 | mean_psnr=35.06
# 10. Video 8 | watches=165 | mean_psnr=37.48
# 11. Video 14 | watches=140 | mean_psnr=35.52
# 12. Video 15 | watches=134 | mean_psnr=35.34
# 13. Video 44 | watches=130 | mean_psnr=36.19
# 14. Video 11 | watches=118 | mean_psnr=35.64
# 15. Video 29 | watches=117 | mean_psnr=35.19
# 16. Video 13 | watches=114 | mean_psnr=36.21
# 17. Video 32 | watches=111 | mean_psnr=36.49
# 18. Video 20 | watches=108 | mean_psnr=36.13
# 19. Video 12 | watches=106 | mean_psnr=35.97
# 20. Video 63 | watches=105 | mean_psnr=36.02
# --------------------------------------------------
# Episode 18 | R: 0 | HR: 0.85 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.51 | PSNR: 35.91 | Mean video PSNR: 35.84 | Popularity bonus: 0.0000 | Time: 10:38:26
# Mean PSNR across watched videos: 35.84
# Top 20 watched videos by rank:
# 01. Video 0 | watches=2017 | mean_psnr=36.12
# 02. Video 1 | watches=1003 | mean_psnr=36.01
# 03. Video 2 | watches=596 | mean_psnr=35.86
# 04. Video 3 | watches=593 | mean_psnr=35.81
# 05. Video 5 | watches=286 | mean_psnr=35.17
# 06. Video 10 | watches=274 | mean_psnr=35.75
# 07. Video 13 | watches=247 | mean_psnr=36.17
# 08. Video 4 | watches=220 | mean_psnr=36.34
# 09. Video 11 | watches=211 | mean_psnr=35.53
# 10. Video 7 | watches=198 | mean_psnr=35.68
# 11. Video 9 | watches=190 | mean_psnr=35.58
# 12. Video 6 | watches=182 | mean_psnr=36.24
# 13. Video 8 | watches=150 | mean_psnr=36.52
# 14. Video 24 | watches=125 | mean_psnr=36.54
# 15. Video 23 | watches=118 | mean_psnr=35.21
# 16. Video 12 | watches=115 | mean_psnr=36.63
# 17. Video 43 | watches=102 | mean_psnr=36.62
# 18. Video 32 | watches=100 | mean_psnr=35.45
# 19. Video 25 | watches=93 | mean_psnr=35.54
# 20. Video 174 | watches=89 | mean_psnr=36.01
# --------------------------------------------------
# Episode 19 | R: 0 | HR: 0.85 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.51 | PSNR: 35.90 | Mean video PSNR: 35.80 | Popularity bonus: 0.0000 | Time: 10:38:27
# Mean PSNR across watched videos: 35.80
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1657 | mean_psnr=35.89
# 02. Video 2 | watches=666 | mean_psnr=35.86
# 03. Video 1 | watches=631 | mean_psnr=35.78
# 04. Video 3 | watches=501 | mean_psnr=35.45
# 05. Video 4 | watches=373 | mean_psnr=36.29
# 06. Video 5 | watches=363 | mean_psnr=36.48
# 07. Video 7 | watches=283 | mean_psnr=36.34
# 08. Video 9 | watches=270 | mean_psnr=35.20
# 09. Video 10 | watches=261 | mean_psnr=35.48
# 10. Video 8 | watches=246 | mean_psnr=36.31
# 11. Video 12 | watches=227 | mean_psnr=35.40
# 12. Video 6 | watches=207 | mean_psnr=36.44
# 13. Video 17 | watches=149 | mean_psnr=35.70
# 14. Video 18 | watches=148 | mean_psnr=36.03
# 15. Video 34 | watches=146 | mean_psnr=35.72
# 16. Video 56 | watches=125 | mean_psnr=35.78
# 17. Video 15 | watches=118 | mean_psnr=35.21
# 18. Video 27 | watches=112 | mean_psnr=35.92
# 19. Video 38 | watches=112 | mean_psnr=35.78
# 20. Video 25 | watches=108 | mean_psnr=36.99
# --------------------------------------------------
# Episode 20 | R: 0 | HR: 0.76 | HR_2: 0.54 | BHR: 0.86 | EHR: 0.47 | PSNR: 35.34 | Mean video PSNR: 35.21 | Popularity bonus: 0.0000 | Time: 10:38:28
# Mean PSNR across watched videos: 35.21
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1282 | mean_psnr=35.20
# 02. Video 1 | watches=635 | mean_psnr=35.61
# 03. Video 2 | watches=613 | mean_psnr=35.89
# 04. Video 4 | watches=529 | mean_psnr=35.57
# 05. Video 3 | watches=461 | mean_psnr=35.78
# 06. Video 5 | watches=222 | mean_psnr=35.15
# 07. Video 7 | watches=208 | mean_psnr=35.11
# 08. Video 6 | watches=206 | mean_psnr=35.34
# 09. Video 12 | watches=202 | mean_psnr=34.70
# 10. Video 10 | watches=192 | mean_psnr=35.65
# 11. Video 17 | watches=173 | mean_psnr=35.19
# 12. Video 30 | watches=167 | mean_psnr=35.03
# 13. Video 18 | watches=164 | mean_psnr=35.09
# 14. Video 14 | watches=150 | mean_psnr=34.35
# 15. Video 8 | watches=148 | mean_psnr=35.32
# 16. Video 13 | watches=141 | mean_psnr=35.69
# 17. Video 23 | watches=136 | mean_psnr=35.86
# 18. Video 22 | watches=130 | mean_psnr=35.75
# 19. Video 11 | watches=124 | mean_psnr=34.96
# 20. Video 27 | watches=116 | mean_psnr=35.39
# --------------------------------------------------
# Episode 21 | R: 0 | HR: 0.85 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.52 | PSNR: 35.91 | Mean video PSNR: 35.92 | Popularity bonus: 0.0000 | Time: 10:38:29
# Mean PSNR across watched videos: 35.92
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1779 | mean_psnr=35.81
# 02. Video 1 | watches=866 | mean_psnr=35.63
# 03. Video 3 | watches=569 | mean_psnr=35.57
# 04. Video 2 | watches=495 | mean_psnr=36.26
# 05. Video 6 | watches=378 | mean_psnr=35.94
# 06. Video 4 | watches=332 | mean_psnr=36.21
# 07. Video 5 | watches=250 | mean_psnr=35.65
# 08. Video 7 | watches=249 | mean_psnr=36.41
# 09. Video 8 | watches=235 | mean_psnr=35.72
# 10. Video 14 | watches=210 | mean_psnr=36.29
# 11. Video 10 | watches=166 | mean_psnr=36.69
# 12. Video 12 | watches=151 | mean_psnr=36.16
# 13. Video 29 | watches=141 | mean_psnr=35.94
# 14. Video 9 | watches=140 | mean_psnr=36.62
# 15. Video 31 | watches=127 | mean_psnr=35.65
# 16. Video 49 | watches=124 | mean_psnr=35.34
# 17. Video 18 | watches=117 | mean_psnr=35.68
# 18. Video 19 | watches=111 | mean_psnr=36.37
# 19. Video 34 | watches=111 | mean_psnr=35.50
# 20. Video 94 | watches=106 | mean_psnr=36.72
# --------------------------------------------------
# Episode 22 | R: 0 | HR: 0.81 | HR_2: 0.58 | BHR: 0.91 | EHR: 0.50 | PSNR: 35.69 | Mean video PSNR: 35.72 | Popularity bonus: 0.0000 | Time: 10:38:30
# Mean PSNR across watched videos: 35.72
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1753 | mean_psnr=35.59
# 02. Video 1 | watches=1115 | mean_psnr=35.65
# 03. Video 2 | watches=519 | mean_psnr=35.63
# 04. Video 3 | watches=456 | mean_psnr=35.66
# 05. Video 4 | watches=376 | mean_psnr=36.06
# 06. Video 8 | watches=224 | mean_psnr=35.49
# 07. Video 5 | watches=219 | mean_psnr=35.75
# 08. Video 9 | watches=197 | mean_psnr=36.02
# 09. Video 7 | watches=195 | mean_psnr=35.99
# 10. Video 6 | watches=188 | mean_psnr=35.65
# 11. Video 29 | watches=151 | mean_psnr=36.16
# 12. Video 12 | watches=143 | mean_psnr=36.50
# 13. Video 13 | watches=137 | mean_psnr=35.22
# 14. Video 17 | watches=133 | mean_psnr=36.26
# 15. Video 40 | watches=125 | mean_psnr=35.78
# 16. Video 11 | watches=121 | mean_psnr=35.50
# 17. Video 51 | watches=111 | mean_psnr=35.36
# 18. Video 22 | watches=106 | mean_psnr=35.45
# 19. Video 28 | watches=105 | mean_psnr=35.90
# 20. Video 10 | watches=100 | mean_psnr=36.52
# --------------------------------------------------
# Episode 23 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 35.94 | Mean video PSNR: 35.93 | Popularity bonus: 0.0000 | Time: 10:38:31
# Mean PSNR across watched videos: 35.93
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1623 | mean_psnr=36.17
# 02. Video 1 | watches=928 | mean_psnr=35.51
# 03. Video 2 | watches=751 | mean_psnr=35.95
# 04. Video 3 | watches=661 | mean_psnr=36.03
# 05. Video 4 | watches=346 | mean_psnr=36.29
# 06. Video 5 | watches=280 | mean_psnr=36.29
# 07. Video 15 | watches=255 | mean_psnr=35.66
# 08. Video 6 | watches=229 | mean_psnr=35.99
# 09. Video 10 | watches=215 | mean_psnr=35.88
# 10. Video 13 | watches=168 | mean_psnr=36.26
# 11. Video 7 | watches=152 | mean_psnr=36.84
# 12. Video 8 | watches=151 | mean_psnr=34.98
# 13. Video 14 | watches=151 | mean_psnr=35.65
# 14. Video 11 | watches=136 | mean_psnr=35.81
# 15. Video 37 | watches=121 | mean_psnr=36.07
# 16. Video 16 | watches=113 | mean_psnr=35.66
# 17. Video 25 | watches=111 | mean_psnr=36.01
# 18. Video 39 | watches=109 | mean_psnr=36.81
# 19. Video 19 | watches=104 | mean_psnr=36.56
# 20. Video 61 | watches=98 | mean_psnr=35.84
# --------------------------------------------------
# Episode 24 | R: 0 | HR: 0.76 | HR_2: 0.54 | BHR: 0.86 | EHR: 0.46 | PSNR: 35.27 | Mean video PSNR: 35.33 | Popularity bonus: 0.0000 | Time: 10:38:32
# Mean PSNR across watched videos: 35.33
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1414 | mean_psnr=35.56
# 02. Video 1 | watches=685 | mean_psnr=35.10
# 03. Video 2 | watches=566 | mean_psnr=35.01
# 04. Video 3 | watches=433 | mean_psnr=34.94
# 05. Video 5 | watches=355 | mean_psnr=35.30
# 06. Video 8 | watches=337 | mean_psnr=35.47
# 07. Video 6 | watches=291 | mean_psnr=34.97
# 08. Video 7 | watches=288 | mean_psnr=35.41
# 09. Video 4 | watches=279 | mean_psnr=35.35
# 10. Video 20 | watches=183 | mean_psnr=35.38
# 11. Video 12 | watches=165 | mean_psnr=34.98
# 12. Video 18 | watches=163 | mean_psnr=35.23
# 13. Video 13 | watches=147 | mean_psnr=35.36
# 14. Video 29 | watches=147 | mean_psnr=35.48
# 15. Video 15 | watches=145 | mean_psnr=35.53
# 16. Video 10 | watches=141 | mean_psnr=35.83
# 17. Video 9 | watches=139 | mean_psnr=34.87
# 18. Video 86 | watches=130 | mean_psnr=35.33
# 19. Video 16 | watches=130 | mean_psnr=35.88
# 20. Video 24 | watches=129 | mean_psnr=34.96
# --------------------------------------------------
# Episode 25 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.94 | EHR: 0.51 | PSNR: 35.86 | Mean video PSNR: 35.86 | Popularity bonus: 0.0000 | Time: 10:38:33
# Mean PSNR across watched videos: 35.86
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1641 | mean_psnr=35.68
# 02. Video 1 | watches=1368 | mean_psnr=35.98
# 03. Video 2 | watches=662 | mean_psnr=35.79
# 04. Video 3 | watches=433 | mean_psnr=35.40
# 05. Video 5 | watches=327 | mean_psnr=36.33
# 06. Video 4 | watches=308 | mean_psnr=36.04
# 07. Video 10 | watches=251 | mean_psnr=35.70
# 08. Video 11 | watches=220 | mean_psnr=36.45
# 09. Video 15 | watches=184 | mean_psnr=35.61
# 10. Video 8 | watches=175 | mean_psnr=35.59
# 11. Video 9 | watches=159 | mean_psnr=36.73
# 12. Video 22 | watches=138 | mean_psnr=35.42
# 13. Video 48 | watches=115 | mean_psnr=35.96
# 14. Video 13 | watches=111 | mean_psnr=35.77
# 15. Video 14 | watches=108 | mean_psnr=36.34
# 16. Video 33 | watches=105 | mean_psnr=35.38
# 17. Video 6 | watches=101 | mean_psnr=35.42
# 18. Video 50 | watches=87 | mean_psnr=36.78
# 19. Video 472 | watches=87 | mean_psnr=35.52
# 20. Video 18 | watches=85 | mean_psnr=36.18
# --------------------------------------------------
# Episode 26 | R: 0 | HR: 0.76 | HR_2: 0.55 | BHR: 0.85 | EHR: 0.47 | PSNR: 35.33 | Mean video PSNR: 35.34 | Popularity bonus: 0.0000 | Time: 10:38:34
# Mean PSNR across watched videos: 35.34
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1502 | mean_psnr=35.21
# 02. Video 1 | watches=877 | mean_psnr=35.24
# 03. Video 2 | watches=677 | mean_psnr=35.29
# 04. Video 6 | watches=446 | mean_psnr=35.68
# 05. Video 4 | watches=411 | mean_psnr=35.79
# 06. Video 3 | watches=411 | mean_psnr=35.89
# 07. Video 8 | watches=314 | mean_psnr=35.69
# 08. Video 7 | watches=310 | mean_psnr=34.81
# 09. Video 5 | watches=233 | mean_psnr=35.70
# 10. Video 13 | watches=168 | mean_psnr=34.93
# 11. Video 14 | watches=155 | mean_psnr=35.06
# 12. Video 10 | watches=145 | mean_psnr=35.41
# 13. Video 9 | watches=130 | mean_psnr=36.27
# 14. Video 11 | watches=124 | mean_psnr=35.52
# 15. Video 21 | watches=106 | mean_psnr=35.28
# 16. Video 19 | watches=104 | mean_psnr=35.94
# 17. Video 23 | watches=94 | mean_psnr=35.48
# 18. Video 18 | watches=91 | mean_psnr=34.78
# 19. Video 74 | watches=89 | mean_psnr=35.17
# 20. Video 41 | watches=86 | mean_psnr=35.49
# --------------------------------------------------
# Episode 27 | R: 0 | HR: 0.82 | HR_2: 0.59 | BHR: 0.93 | EHR: 0.50 | PSNR: 35.74 | Mean video PSNR: 35.68 | Popularity bonus: 0.0000 | Time: 10:38:35
# Mean PSNR across watched videos: 35.68
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1577 | mean_psnr=35.73
# 02. Video 1 | watches=716 | mean_psnr=35.73
# 03. Video 2 | watches=548 | mean_psnr=35.59
# 04. Video 4 | watches=538 | mean_psnr=35.84
# 05. Video 3 | watches=510 | mean_psnr=35.91
# 06. Video 5 | watches=311 | mean_psnr=35.70
# 07. Video 7 | watches=306 | mean_psnr=35.46
# 08. Video 6 | watches=261 | mean_psnr=35.92
# 09. Video 8 | watches=231 | mean_psnr=36.09
# 10. Video 10 | watches=199 | mean_psnr=35.54
# 11. Video 15 | watches=194 | mean_psnr=35.21
# 12. Video 22 | watches=153 | mean_psnr=35.62
# 13. Video 14 | watches=147 | mean_psnr=36.29
# 14. Video 11 | watches=133 | mean_psnr=35.47
# 15. Video 9 | watches=127 | mean_psnr=36.14
# 16. Video 16 | watches=126 | mean_psnr=35.89
# 17. Video 21 | watches=124 | mean_psnr=36.01
# 18. Video 25 | watches=123 | mean_psnr=35.75
# 19. Video 29 | watches=118 | mean_psnr=35.85
# 20. Video 38 | watches=112 | mean_psnr=36.03
# --------------------------------------------------
# Episode 28 | R: 0 | HR: 0.68 | HR_2: 0.49 | BHR: 0.77 | EHR: 0.41 | PSNR: 34.77 | Mean video PSNR: 34.71 | Popularity bonus: 0.0000 | Time: 10:38:36
# Mean PSNR across watched videos: 34.71
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1463 | mean_psnr=35.04
# 02. Video 1 | watches=789 | mean_psnr=34.48
# 03. Video 2 | watches=487 | mean_psnr=34.95
# 04. Video 4 | watches=432 | mean_psnr=34.59
# 05. Video 3 | watches=309 | mean_psnr=34.98
# 06. Video 9 | watches=277 | mean_psnr=35.09
# 07. Video 6 | watches=262 | mean_psnr=34.61
# 08. Video 10 | watches=219 | mean_psnr=35.09
# 09. Video 5 | watches=203 | mean_psnr=35.06
# 10. Video 7 | watches=198 | mean_psnr=34.81
# 11. Video 16 | watches=159 | mean_psnr=34.86
# 12. Video 11 | watches=157 | mean_psnr=34.73
# 13. Video 44 | watches=125 | mean_psnr=34.68
# 14. Video 46 | watches=120 | mean_psnr=35.04
# 15. Video 36 | watches=119 | mean_psnr=34.62
# 16. Video 19 | watches=113 | mean_psnr=34.78
# 17. Video 14 | watches=111 | mean_psnr=35.70
# 18. Video 30 | watches=110 | mean_psnr=34.55
# 19. Video 13 | watches=110 | mean_psnr=35.05
# 20. Video 73 | watches=106 | mean_psnr=35.07
# --------------------------------------------------
# Episode 29 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 35.97 | Mean video PSNR: 35.95 | Popularity bonus: 0.0000 | Time: 10:38:37
# Mean PSNR across watched videos: 35.95
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1510 | mean_psnr=36.09
# 02. Video 1 | watches=977 | mean_psnr=35.99
# 03. Video 2 | watches=663 | mean_psnr=36.04
# 04. Video 3 | watches=596 | mean_psnr=35.78
# 05. Video 4 | watches=341 | mean_psnr=36.21
# 06. Video 5 | watches=315 | mean_psnr=35.56
# 07. Video 7 | watches=300 | mean_psnr=36.46
# 08. Video 6 | watches=259 | mean_psnr=35.96
# 09. Video 13 | watches=201 | mean_psnr=36.44
# 10. Video 18 | watches=187 | mean_psnr=35.92
# 11. Video 19 | watches=169 | mean_psnr=35.75
# 12. Video 37 | watches=151 | mean_psnr=35.55
# 13. Video 9 | watches=142 | mean_psnr=35.67
# 14. Video 26 | watches=138 | mean_psnr=35.20
# 15. Video 20 | watches=136 | mean_psnr=35.28
# 16. Video 12 | watches=133 | mean_psnr=35.75
# 17. Video 42 | watches=130 | mean_psnr=36.79
# 18. Video 10 | watches=129 | mean_psnr=36.76
# 19. Video 11 | watches=118 | mean_psnr=35.87
# 20. Video 47 | watches=117 | mean_psnr=35.94
# --------------------------------------------------
# Episode 30 | R: 0 | HR: 0.80 | HR_2: 0.58 | BHR: 0.91 | EHR: 0.50 | PSNR: 35.65 | Mean video PSNR: 35.59 | Popularity bonus: 0.0000 | Time: 10:38:38
# Mean PSNR across watched videos: 35.59
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1845 | mean_psnr=35.67
# 02. Video 1 | watches=958 | mean_psnr=35.90
# 03. Video 2 | watches=389 | mean_psnr=35.84
# 04. Video 6 | watches=363 | mean_psnr=35.37
# 05. Video 4 | watches=355 | mean_psnr=35.48
# 06. Video 5 | watches=304 | mean_psnr=35.71
# 07. Video 3 | watches=289 | mean_psnr=35.69
# 08. Video 7 | watches=214 | mean_psnr=35.60
# 09. Video 11 | watches=206 | mean_psnr=35.91
# 10. Video 13 | watches=178 | mean_psnr=35.31
# 11. Video 9 | watches=161 | mean_psnr=35.12
# 12. Video 18 | watches=144 | mean_psnr=35.80
# 13. Video 10 | watches=133 | mean_psnr=35.88
# 14. Video 12 | watches=118 | mean_psnr=35.74
# 15. Video 194 | watches=113 | mean_psnr=35.44
# 16. Video 15 | watches=108 | mean_psnr=36.18
# 17. Video 30 | watches=105 | mean_psnr=35.43
# 18. Video 54 | watches=103 | mean_psnr=35.63
# 19. Video 47 | watches=103 | mean_psnr=36.29
# 20. Video 8 | watches=97 | mean_psnr=35.41
# --------------------------------------------------
# Episode 31 | R: 0 | HR: 0.78 | HR_2: 0.55 | BHR: 0.89 | EHR: 0.47 | PSNR: 35.43 | Mean video PSNR: 35.45 | Popularity bonus: 0.0000 | Time: 10:38:39
# Mean PSNR across watched videos: 35.45
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1454 | mean_psnr=35.44
# 02. Video 1 | watches=885 | mean_psnr=35.64
# 03. Video 2 | watches=424 | mean_psnr=35.06
# 04. Video 5 | watches=405 | mean_psnr=35.35
# 05. Video 4 | watches=385 | mean_psnr=35.61
# 06. Video 3 | watches=369 | mean_psnr=35.40
# 07. Video 6 | watches=367 | mean_psnr=35.20
# 08. Video 8 | watches=240 | mean_psnr=35.68
# 09. Video 10 | watches=231 | mean_psnr=34.99
# 10. Video 15 | watches=225 | mean_psnr=36.17
# 11. Video 12 | watches=174 | mean_psnr=35.89
# 12. Video 7 | watches=173 | mean_psnr=36.07
# 13. Video 16 | watches=160 | mean_psnr=35.86
# 14. Video 9 | watches=156 | mean_psnr=35.10
# 15. Video 19 | watches=150 | mean_psnr=34.98
# 16. Video 33 | watches=137 | mean_psnr=35.60
# 17. Video 25 | watches=132 | mean_psnr=35.64
# 18. Video 14 | watches=132 | mean_psnr=35.36
# 19. Video 20 | watches=106 | mean_psnr=35.42
# 20. Video 22 | watches=103 | mean_psnr=35.53
# --------------------------------------------------
# Episode 32 | R: 0 | HR: 0.84 | HR_2: 0.59 | BHR: 0.95 | EHR: 0.50 | PSNR: 35.80 | Mean video PSNR: 35.66 | Popularity bonus: 0.0000 | Time: 10:38:40
# Mean PSNR across watched videos: 35.66
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1579 | mean_psnr=35.85
# 02. Video 1 | watches=1054 | mean_psnr=36.21
# 03. Video 2 | watches=659 | mean_psnr=35.72
# 04. Video 4 | watches=399 | mean_psnr=36.20
# 05. Video 3 | watches=333 | mean_psnr=36.40
# 06. Video 5 | watches=325 | mean_psnr=35.81
# 07. Video 9 | watches=303 | mean_psnr=35.91
# 08. Video 6 | watches=261 | mean_psnr=35.77
# 09. Video 8 | watches=242 | mean_psnr=36.05
# 10. Video 7 | watches=184 | mean_psnr=35.92
# 11. Video 12 | watches=158 | mean_psnr=35.08
# 12. Video 27 | watches=150 | mean_psnr=36.22
# 13. Video 15 | watches=148 | mean_psnr=35.52
# 14. Video 11 | watches=125 | mean_psnr=35.22
# 15. Video 14 | watches=124 | mean_psnr=35.44
# 16. Video 17 | watches=118 | mean_psnr=35.89
# 17. Video 82 | watches=117 | mean_psnr=35.88
# 18. Video 116 | watches=113 | mean_psnr=36.50
# 19. Video 18 | watches=112 | mean_psnr=35.29
# 20. Video 35 | watches=110 | mean_psnr=34.82
# --------------------------------------------------
# Episode 33 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.96 | EHR: 0.52 | PSNR: 35.94 | Mean video PSNR: 35.84 | Popularity bonus: 0.0000 | Time: 10:38:41
# Mean PSNR across watched videos: 35.84
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1708 | mean_psnr=35.91
# 02. Video 1 | watches=844 | mean_psnr=35.98
# 03. Video 2 | watches=830 | mean_psnr=36.12
# 04. Video 5 | watches=358 | mean_psnr=35.42
# 05. Video 4 | watches=339 | mean_psnr=36.43
# 06. Video 7 | watches=331 | mean_psnr=36.24
# 07. Video 6 | watches=325 | mean_psnr=35.73
# 08. Video 3 | watches=303 | mean_psnr=36.22
# 09. Video 8 | watches=223 | mean_psnr=36.76
# 10. Video 22 | watches=193 | mean_psnr=36.20
# 11. Video 14 | watches=187 | mean_psnr=36.19
# 12. Video 9 | watches=160 | mean_psnr=35.20
# 13. Video 29 | watches=137 | mean_psnr=36.04
# 14. Video 19 | watches=135 | mean_psnr=36.94
# 15. Video 34 | watches=119 | mean_psnr=36.58
# 16. Video 75 | watches=111 | mean_psnr=36.71
# 17. Video 13 | watches=110 | mean_psnr=36.02
# 18. Video 16 | watches=104 | mean_psnr=35.67
# 19. Video 10 | watches=98 | mean_psnr=36.68
# 20. Video 91 | watches=89 | mean_psnr=34.94
# --------------------------------------------------
# Episode 34 | R: 0 | HR: 0.77 | HR_2: 0.55 | BHR: 0.88 | EHR: 0.47 | PSNR: 35.38 | Mean video PSNR: 35.45 | Popularity bonus: 0.0000 | Time: 10:38:42
# Mean PSNR across watched videos: 35.45
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1538 | mean_psnr=35.41
# 02. Video 1 | watches=755 | mean_psnr=35.41
# 03. Video 2 | watches=615 | mean_psnr=35.69
# 04. Video 3 | watches=563 | mean_psnr=35.38
# 05. Video 5 | watches=459 | mean_psnr=35.72
# 06. Video 4 | watches=439 | mean_psnr=35.15
# 07. Video 6 | watches=308 | mean_psnr=34.88
# 08. Video 7 | watches=269 | mean_psnr=34.92
# 09. Video 13 | watches=228 | mean_psnr=35.79
# 10. Video 14 | watches=186 | mean_psnr=35.59
# 11. Video 8 | watches=168 | mean_psnr=35.45
# 12. Video 11 | watches=155 | mean_psnr=34.89
# 13. Video 9 | watches=144 | mean_psnr=35.03
# 14. Video 12 | watches=137 | mean_psnr=34.62
# 15. Video 21 | watches=129 | mean_psnr=35.27
# 16. Video 39 | watches=117 | mean_psnr=35.15
# 17. Video 32 | watches=116 | mean_psnr=35.43
# 18. Video 22 | watches=113 | mean_psnr=35.13
# 19. Video 15 | watches=96 | mean_psnr=36.28
# 20. Video 29 | watches=95 | mean_psnr=35.47
# --------------------------------------------------
# Episode 35 | R: 0 | HR: 0.82 | HR_2: 0.58 | BHR: 0.93 | EHR: 0.50 | PSNR: 35.71 | Mean video PSNR: 35.72 | Popularity bonus: 0.0000 | Time: 10:38:43
# Mean PSNR across watched videos: 35.72
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1587 | mean_psnr=35.81
# 02. Video 1 | watches=708 | mean_psnr=35.99
# 03. Video 2 | watches=612 | mean_psnr=35.58
# 04. Video 3 | watches=550 | mean_psnr=35.87
# 05. Video 4 | watches=384 | mean_psnr=35.61
# 06. Video 7 | watches=349 | mean_psnr=35.91
# 07. Video 8 | watches=288 | mean_psnr=35.03
# 08. Video 12 | watches=210 | mean_psnr=35.61
# 09. Video 5 | watches=204 | mean_psnr=35.70
# 10. Video 14 | watches=170 | mean_psnr=35.68
# 11. Video 10 | watches=164 | mean_psnr=35.78
# 12. Video 9 | watches=153 | mean_psnr=35.00
# 13. Video 6 | watches=144 | mean_psnr=35.89
# 14. Video 15 | watches=137 | mean_psnr=36.46
# 15. Video 48 | watches=135 | mean_psnr=35.80
# 16. Video 13 | watches=120 | mean_psnr=35.52
# 17. Video 89 | watches=115 | mean_psnr=36.20
# 18. Video 11 | watches=112 | mean_psnr=34.38
# 19. Video 27 | watches=106 | mean_psnr=36.46
# 20. Video 22 | watches=103 | mean_psnr=35.56
# --------------------------------------------------
# Episode 36 | R: 0 | HR: 0.82 | HR_2: 0.58 | BHR: 0.93 | EHR: 0.50 | PSNR: 35.71 | Mean video PSNR: 35.68 | Popularity bonus: 0.0000 | Time: 10:38:44
# Mean PSNR across watched videos: 35.68
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1472 | mean_psnr=35.83
# 02. Video 1 | watches=920 | mean_psnr=35.83
# 03. Video 2 | watches=831 | mean_psnr=35.67
# 04. Video 6 | watches=599 | mean_psnr=35.53
# 05. Video 3 | watches=321 | mean_psnr=35.54
# 06. Video 11 | watches=305 | mean_psnr=35.78
# 07. Video 4 | watches=276 | mean_psnr=35.99
# 08. Video 7 | watches=229 | mean_psnr=35.74
# 09. Video 9 | watches=223 | mean_psnr=35.90
# 10. Video 5 | watches=188 | mean_psnr=35.04
# 11. Video 18 | watches=172 | mean_psnr=35.89
# 12. Video 16 | watches=156 | mean_psnr=35.24
# 13. Video 14 | watches=146 | mean_psnr=35.02
# 14. Video 24 | watches=144 | mean_psnr=35.30
# 15. Video 15 | watches=129 | mean_psnr=34.94
# 16. Video 8 | watches=129 | mean_psnr=35.25
# 17. Video 19 | watches=119 | mean_psnr=35.86
# 18. Video 38 | watches=119 | mean_psnr=35.44
# 19. Video 12 | watches=117 | mean_psnr=35.88
# 20. Video 141 | watches=107 | mean_psnr=35.91
# --------------------------------------------------
# Episode 37 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.51 | PSNR: 35.89 | Mean video PSNR: 35.87 | Popularity bonus: 0.0000 | Time: 10:38:45
# Mean PSNR across watched videos: 35.87
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1755 | mean_psnr=35.85
# 02. Video 1 | watches=794 | mean_psnr=35.70
# 03. Video 2 | watches=649 | mean_psnr=36.15
# 04. Video 3 | watches=615 | mean_psnr=35.76
# 05. Video 4 | watches=446 | mean_psnr=35.86
# 06. Video 5 | watches=377 | mean_psnr=35.95
# 07. Video 7 | watches=187 | mean_psnr=35.99
# 08. Video 16 | watches=184 | mean_psnr=35.80
# 09. Video 18 | watches=163 | mean_psnr=36.90
# 10. Video 6 | watches=160 | mean_psnr=35.41
# 11. Video 31 | watches=132 | mean_psnr=35.59
# 12. Video 11 | watches=130 | mean_psnr=36.25
# 13. Video 9 | watches=125 | mean_psnr=35.82
# 14. Video 22 | watches=110 | mean_psnr=36.14
# 15. Video 23 | watches=109 | mean_psnr=36.28
# 16. Video 14 | watches=108 | mean_psnr=35.37
# 17. Video 28 | watches=108 | mean_psnr=35.16
# 18. Video 8 | watches=107 | mean_psnr=36.05
# 19. Video 17 | watches=100 | mean_psnr=36.12
# 20. Video 15 | watches=100 | mean_psnr=37.27
# --------------------------------------------------
# Episode 38 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.95 | EHR: 0.53 | PSNR: 35.99 | Mean video PSNR: 36.03 | Popularity bonus: 0.0000 | Time: 10:38:46
# Mean PSNR across watched videos: 36.03
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1244 | mean_psnr=36.07
# 02. Video 1 | watches=1005 | mean_psnr=36.13
# 03. Video 2 | watches=472 | mean_psnr=36.02
# 04. Video 4 | watches=456 | mean_psnr=36.18
# 05. Video 3 | watches=453 | mean_psnr=35.68
# 06. Video 6 | watches=313 | mean_psnr=36.41
# 07. Video 14 | watches=258 | mean_psnr=35.89
# 08. Video 5 | watches=248 | mean_psnr=35.82
# 09. Video 7 | watches=229 | mean_psnr=36.15
# 10. Video 8 | watches=226 | mean_psnr=36.10
# 11. Video 12 | watches=205 | mean_psnr=35.80
# 12. Video 22 | watches=172 | mean_psnr=35.93
# 13. Video 13 | watches=161 | mean_psnr=36.10
# 14. Video 29 | watches=144 | mean_psnr=35.95
# 15. Video 28 | watches=136 | mean_psnr=36.47
# 16. Video 18 | watches=134 | mean_psnr=35.65
# 17. Video 9 | watches=130 | mean_psnr=35.29
# 18. Video 25 | watches=127 | mean_psnr=35.94
# 19. Video 145 | watches=120 | mean_psnr=36.02
# 20. Video 43 | watches=120 | mean_psnr=35.62
# --------------------------------------------------
# Episode 39 | R: 0 | HR: 0.74 | HR_2: 0.53 | BHR: 0.84 | EHR: 0.45 | PSNR: 35.24 | Mean video PSNR: 35.18 | Popularity bonus: 0.0000 | Time: 10:38:47
# Mean PSNR across watched videos: 35.18
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1571 | mean_psnr=35.19
# 02. Video 1 | watches=867 | mean_psnr=35.39
# 03. Video 2 | watches=669 | mean_psnr=35.72
# 04. Video 3 | watches=573 | mean_psnr=35.44
# 05. Video 4 | watches=366 | mean_psnr=35.26
# 06. Video 9 | watches=220 | mean_psnr=35.03
# 07. Video 7 | watches=204 | mean_psnr=35.54
# 08. Video 6 | watches=193 | mean_psnr=35.26
# 09. Video 8 | watches=182 | mean_psnr=35.45
# 10. Video 15 | watches=153 | mean_psnr=34.59
# 11. Video 5 | watches=153 | mean_psnr=35.85
# 12. Video 56 | watches=149 | mean_psnr=34.95
# 13. Video 12 | watches=148 | mean_psnr=35.41
# 14. Video 16 | watches=138 | mean_psnr=35.20
# 15. Video 79 | watches=129 | mean_psnr=35.35
# 16. Video 17 | watches=125 | mean_psnr=35.38
# 17. Video 11 | watches=125 | mean_psnr=35.24
# 18. Video 22 | watches=123 | mean_psnr=35.61
# 19. Video 25 | watches=110 | mean_psnr=35.39
# 20. Video 88 | watches=109 | mean_psnr=33.85
# --------------------------------------------------
# Episode 40 | R: 0 | HR: 0.77 | HR_2: 0.55 | BHR: 0.87 | EHR: 0.47 | PSNR: 35.38 | Mean video PSNR: 35.39 | Popularity bonus: 0.0000 | Time: 10:38:48
# Mean PSNR across watched videos: 35.39
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1562 | mean_psnr=35.48
# 02. Video 1 | watches=705 | mean_psnr=35.21
# 03. Video 3 | watches=506 | mean_psnr=35.68
# 04. Video 2 | watches=470 | mean_psnr=35.20
# 05. Video 4 | watches=358 | mean_psnr=35.18
# 06. Video 6 | watches=323 | mean_psnr=35.19
# 07. Video 7 | watches=264 | mean_psnr=35.69
# 08. Video 5 | watches=221 | mean_psnr=36.04
# 09. Video 14 | watches=198 | mean_psnr=35.56
# 10. Video 12 | watches=192 | mean_psnr=35.61
# 11. Video 16 | watches=160 | mean_psnr=35.55
# 12. Video 15 | watches=151 | mean_psnr=35.00
# 13. Video 19 | watches=148 | mean_psnr=35.20
# 14. Video 13 | watches=148 | mean_psnr=35.41
# 15. Video 11 | watches=124 | mean_psnr=35.12
# 16. Video 9 | watches=121 | mean_psnr=35.25
# 17. Video 25 | watches=119 | mean_psnr=36.11
# 18. Video 31 | watches=118 | mean_psnr=35.38
# 19. Video 18 | watches=112 | mean_psnr=35.87
# 20. Video 26 | watches=108 | mean_psnr=36.27
# --------------------------------------------------
# Episode 41 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 36.01 | Mean video PSNR: 36.00 | Popularity bonus: 0.0000 | Time: 10:38:49
# Mean PSNR across watched videos: 36.00
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1874 | mean_psnr=36.17
# 02. Video 1 | watches=1044 | mean_psnr=35.91
# ...
# 02. Video 1 | watches=1070 | mean_psnr=35.08
# 03. Video 2 | watches=571 | mean_psnr=34.78
# 04. Video 6 | watches=355 | mean_psnr=35.27
# 05. Video 4 | watches=338 | mean_psnr=35.52
# 06. Video 5 | watches=270 | mean_psnr=34.64
# 07. Video 3 | watches=255 | mean_psnr=35.03
# 08. Video 8 | watches=239 | mean_psnr=35.97
# 09. Video 7 | watches=217 | mean_psnr=34.94
# 10. Video 19 | watches=210 | mean_psnr=35.24
# 11. Video 9 | watches=210 | mean_psnr=35.19
# 12. Video 12 | watches=188 | mean_psnr=34.84
# 13. Video 39 | watches=137 | mean_psnr=34.82
# 14. Video 10 | watches=137 | mean_psnr=35.35
# 15. Video 17 | watches=130 | mean_psnr=35.15
# 16. Video 13 | watches=112 | mean_psnr=34.89
# 17. Video 20 | watches=107 | mean_psnr=34.39
# 18. Video 26 | watches=104 | mean_psnr=35.00
# 19. Video 15 | watches=99 | mean_psnr=35.48
# 20. Video 27 | watches=92 | mean_psnr=35.27
# --------------------------------------------------
# Episode 87 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.95 | EHR: 0.51 | PSNR: 35.87 | Mean video PSNR: 35.79 | Popularity bonus: 0.0000 | Time: 10:39:33
# Mean PSNR across watched videos: 35.79
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1602 | mean_psnr=35.86
# 02. Video 1 | watches=1160 | mean_psnr=36.06
# 03. Video 5 | watches=569 | mean_psnr=35.45
# 04. Video 2 | watches=471 | mean_psnr=35.78
# 05. Video 3 | watches=408 | mean_psnr=36.07
# 06. Video 4 | watches=370 | mean_psnr=36.03
# 07. Video 8 | watches=304 | mean_psnr=36.43
# 08. Video 7 | watches=231 | mean_psnr=36.22
# 09. Video 10 | watches=191 | mean_psnr=35.76
# 10. Video 15 | watches=168 | mean_psnr=36.65
# 11. Video 6 | watches=158 | mean_psnr=35.87
# 12. Video 23 | watches=155 | mean_psnr=36.60
# 13. Video 9 | watches=154 | mean_psnr=35.42
# 14. Video 25 | watches=146 | mean_psnr=36.22
# 15. Video 35 | watches=107 | mean_psnr=35.02
# 16. Video 17 | watches=106 | mean_psnr=34.93
# 17. Video 16 | watches=103 | mean_psnr=36.84
# 18. Video 49 | watches=103 | mean_psnr=36.46
# 19. Video 13 | watches=99 | mean_psnr=36.04
# 20. Video 89 | watches=96 | mean_psnr=34.87
# --------------------------------------------------
# Episode 88 | R: 0 | HR: 0.84 | HR_2: 0.59 | BHR: 0.94 | EHR: 0.51 | PSNR: 35.82 | Mean video PSNR: 35.83 | Popularity bonus: 0.0000 | Time: 10:39:34
# Mean PSNR across watched videos: 35.83
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1653 | mean_psnr=35.90
# 02. Video 1 | watches=955 | mean_psnr=35.78
# 03. Video 4 | watches=526 | mean_psnr=35.27
# 04. Video 3 | watches=413 | mean_psnr=35.99
# 05. Video 2 | watches=367 | mean_psnr=35.30
# 06. Video 9 | watches=274 | mean_psnr=36.12
# 07. Video 5 | watches=274 | mean_psnr=36.15
# 08. Video 8 | watches=231 | mean_psnr=36.05
# 09. Video 6 | watches=216 | mean_psnr=36.04
# 10. Video 48 | watches=177 | mean_psnr=35.75
# 11. Video 14 | watches=168 | mean_psnr=35.98
# 12. Video 13 | watches=157 | mean_psnr=35.73
# 13. Video 10 | watches=143 | mean_psnr=36.38
# 14. Video 22 | watches=137 | mean_psnr=35.75
# 15. Video 19 | watches=127 | mean_psnr=35.75
# 16. Video 24 | watches=120 | mean_psnr=35.94
# 17. Video 11 | watches=112 | mean_psnr=34.42
# 18. Video 73 | watches=112 | mean_psnr=34.98
# 19. Video 18 | watches=111 | mean_psnr=35.41
# 20. Video 29 | watches=109 | mean_psnr=35.85
# --------------------------------------------------
# Episode 89 | R: 0 | HR: 0.85 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.51 | PSNR: 35.89 | Mean video PSNR: 35.88 | Popularity bonus: 0.0000 | Time: 10:39:35
# Mean PSNR across watched videos: 35.88
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1862 | mean_psnr=35.72
# 02. Video 1 | watches=927 | mean_psnr=35.85
# 03. Video 2 | watches=545 | mean_psnr=36.05
# 04. Video 3 | watches=369 | mean_psnr=35.88
# 05. Video 4 | watches=362 | mean_psnr=35.52
# 06. Video 6 | watches=319 | mean_psnr=36.32
# 07. Video 10 | watches=305 | mean_psnr=36.44
# 08. Video 5 | watches=268 | mean_psnr=36.43
# 09. Video 11 | watches=236 | mean_psnr=36.48
# 10. Video 8 | watches=220 | mean_psnr=35.55
# 11. Video 13 | watches=217 | mean_psnr=36.01
# 12. Video 7 | watches=207 | mean_psnr=36.00
# 13. Video 9 | watches=176 | mean_psnr=35.92
# 14. Video 21 | watches=174 | mean_psnr=36.09
# 15. Video 12 | watches=153 | mean_psnr=35.62
# 16. Video 16 | watches=151 | mean_psnr=36.09
# 17. Video 44 | watches=139 | mean_psnr=35.52
# 18. Video 36 | watches=127 | mean_psnr=35.47
# 19. Video 142 | watches=113 | mean_psnr=35.75
# 20. Video 35 | watches=112 | mean_psnr=35.80
# --------------------------------------------------
# Episode 90 | R: 0 | HR: 0.80 | HR_2: 0.57 | BHR: 0.90 | EHR: 0.49 | PSNR: 35.62 | Mean video PSNR: 35.63 | Popularity bonus: 0.0000 | Time: 10:39:35
# Mean PSNR across watched videos: 35.63
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1437 | mean_psnr=35.78
# 02. Video 2 | watches=908 | mean_psnr=35.24
# 03. Video 1 | watches=884 | mean_psnr=35.66
# 04. Video 3 | watches=491 | mean_psnr=35.88
# 05. Video 7 | watches=306 | mean_psnr=35.51
# 06. Video 8 | watches=248 | mean_psnr=35.82
# 07. Video 14 | watches=218 | mean_psnr=36.19
# 08. Video 17 | watches=214 | mean_psnr=35.43
# 09. Video 5 | watches=208 | mean_psnr=35.23
# 10. Video 9 | watches=186 | mean_psnr=35.62
# 11. Video 15 | watches=166 | mean_psnr=35.41
# 12. Video 11 | watches=165 | mean_psnr=35.65
# 13. Video 6 | watches=160 | mean_psnr=35.59
# 14. Video 23 | watches=160 | mean_psnr=35.56
# 15. Video 59 | watches=146 | mean_psnr=35.62
# 16. Video 10 | watches=132 | mean_psnr=35.57
# 17. Video 16 | watches=121 | mean_psnr=35.79
# 18. Video 71 | watches=118 | mean_psnr=35.64
# 19. Video 36 | watches=103 | mean_psnr=36.89
# 20. Video 31 | watches=102 | mean_psnr=36.20
# --------------------------------------------------
# Episode 91 | R: 0 | HR: 0.75 | HR_2: 0.53 | BHR: 0.85 | EHR: 0.46 | PSNR: 35.24 | Mean video PSNR: 35.17 | Popularity bonus: 0.0000 | Time: 10:39:36
# Mean PSNR across watched videos: 35.17
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1601 | mean_psnr=35.36
# 02. Video 1 | watches=703 | mean_psnr=35.84
# 03. Video 2 | watches=677 | mean_psnr=35.27
# 04. Video 5 | watches=440 | mean_psnr=35.22
# 05. Video 4 | watches=336 | mean_psnr=34.99
# 06. Video 3 | watches=306 | mean_psnr=35.52
# 07. Video 6 | watches=259 | mean_psnr=35.41
# 08. Video 13 | watches=258 | mean_psnr=35.23
# 09. Video 12 | watches=249 | mean_psnr=36.03
# 10. Video 8 | watches=224 | mean_psnr=35.70
# 11. Video 7 | watches=200 | mean_psnr=35.86
# 12. Video 14 | watches=177 | mean_psnr=35.18
# 13. Video 11 | watches=150 | mean_psnr=35.30
# 14. Video 19 | watches=141 | mean_psnr=34.79
# 15. Video 15 | watches=126 | mean_psnr=36.29
# 16. Video 10 | watches=123 | mean_psnr=35.69
# 17. Video 18 | watches=117 | mean_psnr=34.32
# 18. Video 35 | watches=110 | mean_psnr=34.91
# 19. Video 22 | watches=103 | mean_psnr=34.85
# 20. Video 9 | watches=91 | mean_psnr=35.85
# --------------------------------------------------
# Episode 92 | R: 0 | HR: 0.85 | HR_2: 0.60 | BHR: 0.97 | EHR: 0.51 | PSNR: 35.88 | Mean video PSNR: 35.98 | Popularity bonus: 0.0000 | Time: 10:39:37
# Mean PSNR across watched videos: 35.98
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1759 | mean_psnr=36.01
# 02. Video 1 | watches=1132 | mean_psnr=35.72
# 03. Video 2 | watches=633 | mean_psnr=35.77
# 04. Video 4 | watches=448 | mean_psnr=35.52
# 05. Video 3 | watches=341 | mean_psnr=35.73
# 06. Video 5 | watches=338 | mean_psnr=35.65
# 07. Video 10 | watches=270 | mean_psnr=35.95
# 08. Video 13 | watches=217 | mean_psnr=36.19
# 09. Video 8 | watches=196 | mean_psnr=35.55
# 10. Video 11 | watches=173 | mean_psnr=36.37
# 11. Video 6 | watches=164 | mean_psnr=34.92
# 12. Video 16 | watches=159 | mean_psnr=35.25
# 13. Video 7 | watches=153 | mean_psnr=35.83
# 14. Video 26 | watches=142 | mean_psnr=36.69
# 15. Video 22 | watches=140 | mean_psnr=36.27
# 16. Video 51 | watches=140 | mean_psnr=35.45
# 17. Video 17 | watches=109 | mean_psnr=35.87
# 18. Video 21 | watches=109 | mean_psnr=36.12
# 19. Video 12 | watches=95 | mean_psnr=36.03
# 20. Video 32 | watches=90 | mean_psnr=36.17
# --------------------------------------------------
# Episode 93 | R: 0 | HR: 0.83 | HR_2: 0.60 | BHR: 0.93 | EHR: 0.51 | PSNR: 35.83 | Mean video PSNR: 35.91 | Popularity bonus: 0.0000 | Time: 10:39:38
# Mean PSNR across watched videos: 35.91
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1366 | mean_psnr=35.65
# 02. Video 1 | watches=689 | mean_psnr=35.66
# 03. Video 4 | watches=579 | mean_psnr=35.78
# 04. Video 3 | watches=460 | mean_psnr=36.25
# 05. Video 5 | watches=374 | mean_psnr=36.17
# 06. Video 2 | watches=366 | mean_psnr=35.70
# 07. Video 7 | watches=276 | mean_psnr=35.79
# 08. Video 6 | watches=271 | mean_psnr=35.52
# 09. Video 11 | watches=209 | mean_psnr=35.49
# 10. Video 8 | watches=196 | mean_psnr=35.78
# 11. Video 15 | watches=166 | mean_psnr=35.87
# 12. Video 9 | watches=165 | mean_psnr=35.83
# 13. Video 13 | watches=154 | mean_psnr=35.52
# 14. Video 19 | watches=152 | mean_psnr=35.38
# 15. Video 10 | watches=145 | mean_psnr=35.50
# 16. Video 14 | watches=133 | mean_psnr=36.03
# 17. Video 12 | watches=131 | mean_psnr=36.07
# 18. Video 103 | watches=131 | mean_psnr=35.78
# 19. Video 20 | watches=130 | mean_psnr=36.73
# 20. Video 26 | watches=120 | mean_psnr=35.21
# --------------------------------------------------
# Episode 94 | R: 0 | HR: 0.85 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.51 | PSNR: 35.90 | Mean video PSNR: 35.94 | Popularity bonus: 0.0000 | Time: 10:39:39
# Mean PSNR across watched videos: 35.94
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1747 | mean_psnr=35.78
# 02. Video 1 | watches=793 | mean_psnr=35.98
# 03. Video 2 | watches=688 | mean_psnr=36.04
# 04. Video 3 | watches=451 | mean_psnr=35.77
# 05. Video 4 | watches=401 | mean_psnr=35.73
# 06. Video 5 | watches=282 | mean_psnr=35.94
# 07. Video 8 | watches=268 | mean_psnr=36.54
# 08. Video 12 | watches=265 | mean_psnr=36.09
# 09. Video 14 | watches=257 | mean_psnr=35.68
# 10. Video 6 | watches=167 | mean_psnr=36.80
# 11. Video 18 | watches=164 | mean_psnr=35.09
# 12. Video 47 | watches=154 | mean_psnr=36.02
# 13. Video 26 | watches=143 | mean_psnr=36.43
# 14. Video 39 | watches=142 | mean_psnr=36.20
# 15. Video 9 | watches=137 | mean_psnr=36.50
# 16. Video 23 | watches=119 | mean_psnr=35.67
# 17. Video 7 | watches=118 | mean_psnr=35.74
# 18. Video 10 | watches=115 | mean_psnr=36.20
# 19. Video 27 | watches=109 | mean_psnr=35.11
# 20. Video 54 | watches=108 | mean_psnr=35.65
# --------------------------------------------------
# Episode 95 | R: 0 | HR: 0.80 | HR_2: 0.58 | BHR: 0.91 | EHR: 0.49 | PSNR: 35.65 | Mean video PSNR: 35.64 | Popularity bonus: 0.0000 | Time: 10:39:40
# Mean PSNR across watched videos: 35.64
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1581 | mean_psnr=35.78
# 02. Video 1 | watches=1084 | mean_psnr=35.37
# 03. Video 2 | watches=648 | mean_psnr=35.96
# 04. Video 3 | watches=383 | mean_psnr=36.12
# 05. Video 5 | watches=337 | mean_psnr=35.41
# 06. Video 4 | watches=282 | mean_psnr=35.11
# 07. Video 6 | watches=277 | mean_psnr=35.07
# 08. Video 8 | watches=190 | mean_psnr=35.95
# 09. Video 18 | watches=158 | mean_psnr=35.35
# 10. Video 7 | watches=157 | mean_psnr=35.61
# 11. Video 33 | watches=150 | mean_psnr=36.33
# 12. Video 13 | watches=142 | mean_psnr=35.40
# 13. Video 16 | watches=136 | mean_psnr=35.18
# 14. Video 22 | watches=130 | mean_psnr=35.62
# 15. Video 24 | watches=122 | mean_psnr=36.80
# 16. Video 12 | watches=121 | mean_psnr=35.02
# 17. Video 23 | watches=120 | mean_psnr=35.85
# 18. Video 27 | watches=110 | mean_psnr=35.52
# 19. Video 178 | watches=110 | mean_psnr=35.73
# 20. Video 11 | watches=104 | mean_psnr=36.27
# --------------------------------------------------
# Episode 96 | R: 0 | HR: 0.80 | HR_2: 0.58 | BHR: 0.90 | EHR: 0.50 | PSNR: 35.64 | Mean video PSNR: 35.68 | Popularity bonus: 0.0000 | Time: 10:39:41
# Mean PSNR across watched videos: 35.68
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1600 | mean_psnr=35.50
# 02. Video 1 | watches=850 | mean_psnr=35.45
# 03. Video 2 | watches=712 | mean_psnr=35.73
# 04. Video 4 | watches=460 | mean_psnr=35.92
# 05. Video 3 | watches=417 | mean_psnr=35.64
# 06. Video 12 | watches=268 | mean_psnr=35.90
# 07. Video 6 | watches=264 | mean_psnr=35.98
# 08. Video 5 | watches=255 | mean_psnr=35.82
# 09. Video 8 | watches=198 | mean_psnr=35.45
# 10. Video 9 | watches=160 | mean_psnr=35.81
# 11. Video 7 | watches=134 | mean_psnr=36.19
# 12. Video 13 | watches=133 | mean_psnr=35.81
# 13. Video 21 | watches=120 | mean_psnr=35.44
# 14. Video 25 | watches=119 | mean_psnr=35.78
# 15. Video 64 | watches=112 | mean_psnr=35.49
# 16. Video 15 | watches=109 | mean_psnr=35.57
# 17. Video 10 | watches=109 | mean_psnr=35.83
# 18. Video 22 | watches=108 | mean_psnr=35.62
# 19. Video 16 | watches=102 | mean_psnr=34.93
# 20. Video 11 | watches=101 | mean_psnr=35.77
# --------------------------------------------------
# Episode 97 | R: 0 | HR: 0.73 | HR_2: 0.52 | BHR: 0.82 | EHR: 0.45 | PSNR: 35.11 | Mean video PSNR: 35.15 | Popularity bonus: 0.0000 | Time: 10:39:42
# Mean PSNR across watched videos: 35.15
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1464 | mean_psnr=35.01
# 02. Video 1 | watches=635 | mean_psnr=35.33
# 03. Video 2 | watches=632 | mean_psnr=35.06
# 04. Video 4 | watches=351 | mean_psnr=35.09
# 05. Video 9 | watches=334 | mean_psnr=34.99
# 06. Video 11 | watches=294 | mean_psnr=35.47
# 07. Video 3 | watches=285 | mean_psnr=35.04
# 08. Video 6 | watches=253 | mean_psnr=35.32
# 09. Video 7 | watches=204 | mean_psnr=35.50
# 10. Video 10 | watches=202 | mean_psnr=35.24
# 11. Video 5 | watches=168 | mean_psnr=35.49
# 12. Video 14 | watches=155 | mean_psnr=34.92
# 13. Video 18 | watches=155 | mean_psnr=34.95
# 14. Video 16 | watches=138 | mean_psnr=33.80
# 15. Video 22 | watches=133 | mean_psnr=35.70
# 16. Video 15 | watches=132 | mean_psnr=35.81
# 17. Video 24 | watches=112 | mean_psnr=35.11
# 18. Video 20 | watches=112 | mean_psnr=33.73
# 19. Video 25 | watches=111 | mean_psnr=34.19
# 20. Video 17 | watches=107 | mean_psnr=35.30
# --------------------------------------------------
# Episode 98 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.51 | PSNR: 35.93 | Mean video PSNR: 36.08 | Popularity bonus: 0.0000 | Time: 10:39:43
# Mean PSNR across watched videos: 36.08
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1598 | mean_psnr=35.82
# 02. Video 1 | watches=1142 | mean_psnr=36.07
# 03. Video 2 | watches=567 | mean_psnr=36.16
# 04. Video 3 | watches=493 | mean_psnr=35.97
# 05. Video 4 | watches=418 | mean_psnr=35.88
# 06. Video 7 | watches=406 | mean_psnr=35.50
# 07. Video 6 | watches=344 | mean_psnr=35.35
# 08. Video 5 | watches=332 | mean_psnr=35.88
# 09. Video 8 | watches=184 | mean_psnr=35.79
# 10. Video 21 | watches=182 | mean_psnr=35.58
# 11. Video 11 | watches=178 | mean_psnr=36.38
# 12. Video 31 | watches=166 | mean_psnr=35.56
# 13. Video 12 | watches=160 | mean_psnr=36.03
# 14. Video 10 | watches=128 | mean_psnr=35.10
# 15. Video 9 | watches=124 | mean_psnr=36.55
# 16. Video 13 | watches=115 | mean_psnr=36.15
# 17. Video 60 | watches=112 | mean_psnr=35.76
# 18. Video 15 | watches=106 | mean_psnr=35.71
# 19. Video 40 | watches=103 | mean_psnr=36.36
# 20. Video 44 | watches=96 | mean_psnr=35.05
# --------------------------------------------------
# Episode 99 | R: 0 | HR: 0.72 | HR_2: 0.52 | BHR: 0.82 | EHR: 0.44 | PSNR: 35.08 | Mean video PSNR: 35.07 | Popularity bonus: 0.0000 | Time: 10:39:44
# Mean PSNR across watched videos: 35.07
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1491 | mean_psnr=35.14
# 02. Video 1 | watches=724 | mean_psnr=34.92
# 03. Video 2 | watches=623 | mean_psnr=35.10
# 04. Video 3 | watches=437 | mean_psnr=35.23
# 05. Video 4 | watches=372 | mean_psnr=35.21
# 06. Video 5 | watches=300 | mean_psnr=35.03
# 07. Video 6 | watches=260 | mean_psnr=34.73
# 08. Video 12 | watches=226 | mean_psnr=35.00
# 09. Video 13 | watches=185 | mean_psnr=34.82
# 10. Video 14 | watches=172 | mean_psnr=34.96
# 11. Video 8 | watches=153 | mean_psnr=35.77
# 12. Video 16 | watches=145 | mean_psnr=35.07
# 13. Video 11 | watches=145 | mean_psnr=35.02
# 14. Video 26 | watches=128 | mean_psnr=34.61
# 15. Video 7 | watches=126 | mean_psnr=34.86
# 16. Video 9 | watches=114 | mean_psnr=35.04
# 17. Video 15 | watches=109 | mean_psnr=34.79
# 18. Video 25 | watches=108 | mean_psnr=34.54
# 19. Video 20 | watches=102 | mean_psnr=34.63
# 20. Video 23 | watches=95 | mean_psnr=34.84
# --------------------------------------------------
