# %%
import csv
import importlib
import os
import random
import sys
import torch
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd

from time import sleep
from collections import deque
from itertools import count
from typing import Any, Dict, List, Optional, Tuple, Set
from collections import defaultdict

sources_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if sources_path not in sys.path:
    sys.path.append(sources_path)

from importnb import Notebook
with Notebook():
    from Labs.LatencyModel import LatencyModel, MultiDULatencyModel
    from Labs.CacheEngine import CacheEngineEnv
    from Labs.UserRequest import UserRequestEvents
    from Labs.EnvWrapperLru import EnvWrapper

from RL.Adapters import FeatureAdapter, NetworkAdapter

import Common.config as config
import Common.datatypes as datatypes
import Common.debugger as debugger
import Common.utils as utils

importlib.reload(config)
importlib.reload(datatypes)
importlib.reload(debugger)
importlib.reload(utils)
# Out:
# <module 'Common.utils' from 'c:\\Users\\es25591\\Workspace\\CacheVideoPredict360\\Sources\\Common\\utils.py'>

# %%
CachePolicy = datatypes.CachePolicy
CacheKey = datatypes.CacheKey  # (vid, layer, tile, gop)

cfg = config.Config()

cfg.filename = f"lru.csv"
cfg.n_episodes = 100

debugger = debugger.debug

top_k = int(getattr(cfg, "topk_content_plot_k", 20))

# %%
class FifoPolicy(CachePolicy):

    def __init__(self, max_videos: int = 50, cfg: Any = None) -> None:
        self.cfg = cfg
        self.cur_size = 0

        # FIFO order: oldest inserted video at index 0.
        self.video_queue: List[int] = []

        # FIFO order per video for tiles: video -> tiles in insertion order.
        self.tile_queue: Dict[int, List[int]] = {}

        self.video_idx = [-1] * self.cfg.cache_size
        self.tile_idx = [[-1] * self.cfg.viewport for _ in range(self.cfg.cache_size)]

    def _ensure_video_slot(self, video: int) -> int:
        if video in self.video_idx:
            return self.video_idx.index(video)

        slot = self.video_idx.index(-1) if -1 in self.video_idx else None
        if slot is None:
            if not self.video_queue:
                raise RuntimeError("FIFO state is inconsistent: no free slot and no video to evict.")
            evicted_video = self.video_queue.pop(0)
            slot = self.video_idx.index(evicted_video)
            self.tile_queue.pop(evicted_video, None)

        self.video_idx[slot] = video
        self.tile_idx[slot] = [-1] * self.cfg.viewport
        self.tile_queue.setdefault(video, [])
        return slot

    def put(self, key: int, value: Any, size: int):
        new_video, new_tile = value
        slot = self._ensure_video_slot(new_video)

        if new_video not in self.video_queue:
            self.video_queue.append(new_video)

        if new_tile == -1:
            self.tile_idx[slot] = [-1] * self.cfg.viewport
            self.tile_queue.pop(new_video, None)
            self.cur_size = sum(1 for v in self.video_idx if v != -1)
            return []

        tiles = self.tile_queue.setdefault(new_video, [])
        if new_tile in tiles:
            self.cur_size = sum(1 for v in self.video_idx if v != -1)
            return []

        tiles.append(new_tile)
        slot_tiles = self.tile_idx[slot]
        slot_tiles.append(new_tile)
        if len(slot_tiles) > self.cfg.viewport:
            oldest_tile = slot_tiles.pop(0)
            if oldest_tile in tiles:
                tiles.remove(oldest_tile)

        self.cur_size = sum(1 for v in self.video_idx if v != -1)
        return []

    def get(self, key: CacheKey) -> Optional[Any]:
        raise NotImplementedError("FIFO policy does not support manual retrieval of individual keys.")

    def contains(self, key: CacheKey) -> bool:
        raise NotImplementedError("FIFO policy does not support manual checking of individual keys.")

    def keys(self):
        raise NotImplementedError("FIFO policy does not support manual retrieval of keys.")

    def remove(self, key: CacheKey) -> bool:
        raise NotImplementedError("FIFO policy does not support manual removal of individual keys.")

    def get_capacity(self) -> int:
        return self.cur_size

    def clear(self) -> None:
        self.video_queue.clear()
        self.tile_queue.clear()
        self.cur_size = 0
        self.video_idx = [-1] * self.cfg.cache_size
        self.tile_idx = [[-1] * self.cfg.viewport for _ in range(self.cfg.cache_size)]

    def stats(self) -> Dict[str, Any]:
        return {
            'current_size': self.cur_size,
            'capacity': self.cfg.cache_size,
            'num_items': len([v for v in self.video_idx if v != -1])
        }

# %%
def save_training_results(
    path_,
    filename,
    ep, 
    total_reward, 
    cache_hits, 
    cache_misses, 
    agent
):
    with open(os.path.join(path_, filename), 'a', newline='') as f:
        fieldnames = [
            'episode', 
            'total_reward', 
            'cache_hits', 
            'cache_misses', 
            'epsilon',
            'lr'
        ]
        writer_results = csv.DictWriter(f, fieldnames=fieldnames)

        if ep == 0:
            writer_results.writeheader()
        
        writer_results.writerow({
            'episode': ep,
            'total_reward': round(float(total_reward), 2),
            'cache_hits': cache_hits,
            'cache_misses': cache_misses,
            'lr': f"{agent.scheduler.get_last_lr()[0]:.10f}" if agent else None,
            'epsilon': round(float(agent.epsilon), 4) if agent else None
        })

def _append_csv_row(csv_path: str, fieldnames: list[str], row: dict) -> None:
    write_header = not os.path.exists(csv_path)
    with open(csv_path, 'a', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        if write_header:
            writer.writeheader()
        writer.writerow(row)

def save_episode_metrics(
    metrics_dir: str,
    ep: int,
    total_reward: float,
    cache_hits: int,
    cache_misses: int,
    agent,
):
    csv_path = os.path.join(metrics_dir, 'episode_metrics.csv')
    fieldnames = [
        'episode',
        'total_reward',
        'cache_hits',
        'cache_misses',
        'hit_rate',
        'epsilon',
        'lr',
    ]

    row = {
        'episode': ep,
        'total_reward': round(float(total_reward), 2),
        'cache_hits': cache_hits,
        'cache_misses': cache_misses,
        'hit_rate': float(cache_hits) / float(cache_hits + cache_misses + 1e-9),
        'epsilon': round(float(agent.epsilon), 6) if agent else None,
        'lr': float(agent.scheduler.get_last_lr()[0]) if agent else None,
    }
    _append_csv_row(csv_path, fieldnames, row)

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, int, int]:
    enh_hits = info.get("enh_layer_hits", 0)
    base_hits = info.get("base_layer_hits", 0)
    enh_misses = info.get("enh_layer_misses", 0)
    base_misses = info.get("base_layer_misses", 0)

    return reward, base_hits, base_misses, enh_hits, enh_misses

def _print_video_psnr_ranking(
    video_watch_counts: dict[int, int],
    video_psnr_sums: dict[int, float],
    video_psnr_counts: dict[int, int],
    top_k: int,
) -> None:
    if not video_watch_counts:
        print("No watched videos recorded for this episode.")
        return

    ranked_videos = sorted(
        video_watch_counts.items(),
        key=lambda item: item[1],
        reverse=True,
    )[:max(1, int(top_k))]

    print(f"Mean PSNR across watched videos: {_mean_video_psnr(video_psnr_sums, video_psnr_counts):.2f}")
    print(f"Top {len(ranked_videos)} watched videos by rank:")
    for rank, (video_id, watch_count) in enumerate(ranked_videos, start=1):
        mean_psnr = 0.0
        if video_psnr_counts.get(video_id, 0) > 0:
            mean_psnr = video_psnr_sums[video_id] / video_psnr_counts[video_id]
        print(
            f"{rank:02d}. Video {video_id} | watches={watch_count} | mean_psnr={mean_psnr:.2f}"
        )

def _mean_video_psnr(video_psnr_sums: dict[int, float], video_psnr_counts: dict[int, int]) -> float:
    per_video_psnr = [
        video_psnr_sums[video_id] / video_psnr_counts[video_id]
        for video_id in video_psnr_counts
        if video_psnr_counts[video_id] > 0
    ]
    return float(np.mean(per_video_psnr)) if per_video_psnr else 0.0

def _snapshot_cache(env) -> set[tuple[int, int]]:
    cache_set: set[tuple[int, int]] = set()
    cache_entries = getattr(env.mec_cache.policy, "cache", [])

    for video, tile in cache_entries:
        if int(video) == -1:
            continue
        cache_set.add((int(video), int(tile)))

    return cache_set

def _content_key(video: int, tile: int | None) -> tuple[int, int]:
    return (int(video), -1 if tile is None else int(tile))

def build_latency_model(cfg):
    """Build and return the MultiDULatencyModel."""
    P = cfg.n_nodes
    max_U = cfg.n_users

    return MultiDULatencyModel(
        P=P,
        max_U=max_U,
        R_M_D=80e6,
        R_C_M=125e6,
        mu=2e7,
        eta=2e5,
        B_pu_matrix=np.full((P, max_U), 20e6, dtype=float),
        gamma_pu_matrix=np.full((P, max_U), 5.0, dtype=float),
        rhoT_p=[0.2],
        lambda_p=[0.05],
        du_fixed_delay=0.001,
        mec_fixed_delay=0.005,
        cloud_fixed_delay=0.1
    )

def build_environment(cfg):
    """Construct the full multi-component environment wrapper."""
    du_caches = []

    policy=FifoPolicy(
        cfg=cfg,
        max_videos=cfg.cache_size,
    )

    # MEC Cache Engine
    mec_cache = CacheEngineEnv(
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n_gops=cfg.n_gops,
        cache_capacity=cfg.cache_capacity,
        policy=policy
    )

    # User request generator
    users_env = UserRequestEvents(
        n_nodes=cfg.n_nodes,
        n_users=cfg.n_users,
        n_videos=cfg.n_videos,
        n_gops=cfg.n_gops,
        n_layers=cfg.n_layers,
        n_tiles=cfg.n_tiles,
        n=cfg.n,
        m=cfg.m,
        arrival_rate=cfg.arrival_rate,
        zipf_alpha=cfg.zipf_alpha
    )

    # Latency Model
    latency_model = build_latency_model(cfg)
    
    # Wrapping all into the main training environment
    return EnvWrapper(
        cfg=cfg,
        n=cfg.n,
        m=cfg.m,
        n_layers=cfg.n_layers,
        users_env=users_env,
        du_caches=du_caches,
        mec_cache=mec_cache,
        latency_model=latency_model,
        theta=cfg.theta,
        lam=cfg.lam,
        max_steps=cfg.max_steps,
        prefetch_fn=lambda cache, action: cache.lru_live_prefetching(action),
        reward_fn=lambda env, reqs: env.compute_reward(reqs),
        debugger=debugger
    )

# %%
def run_episode(episode, env, net_adapter, cfg, metrics_dir, global_step_start):
    """Run one full training episode."""
    _, info = net_adapter.reset()

    total_reward = 0.0
    cache_hits = cache_misses = 0
    base_hits = base_misses = 0
    enh_hits = enh_misses = 0
    psnr_sum = 0.0
    popularity_bonus_sum = 0.0

    episode_request_counts: dict[tuple[int, int], int] = defaultdict(int)
    video_watch_counts: dict[int, int] = defaultdict(int)
    video_psnr_sums: dict[int, float] = defaultdict(float)
    video_psnr_counts: dict[int, int] = defaultdict(int)

    global_step = global_step_start

    if cfg.has_warmup and episode == 0:
        env.warmup_phase(net_adapter, 1000)

    for step in range(cfg.max_steps):
        global_step += 1
        req_state = info.get("user_request", None)
        
        current_video_id = None

        if req_state is not None:
            current_video_id = int(req_state["video"])
            episode_request_counts[_content_key(current_video_id, None)] += 1
            video_watch_counts[current_video_id] += 1
            for tile in req_state.get("viewport", []):
                episode_request_counts[_content_key(current_video_id, int(tile))] += 1

        _, reward, _, info = env.step(req_state, net_adapter)

        if current_video_id is not None:
            step_psnr = float(info.get("psnr", 0.0))
            video_psnr_sums[current_video_id] += step_psnr
            video_psnr_counts[current_video_id] += 1

        delta_r, bs_hits, bs_miss, e_hits, e_miss = update_metrics(info, reward)
        total_reward += delta_r
        cache_hits += bs_hits + e_hits
        cache_misses += bs_miss + e_miss
        base_hits += bs_hits
        base_misses += bs_miss
        enh_hits += e_hits
        enh_misses += e_miss
        psnr_sum += info.get("psnr", 0.0)

        if net_adapter.env_is_done():
            break

        debugger.log("cache_hits", cache_hits)
        debugger.log("cache_misses", cache_misses)

    cache_snapshot = _snapshot_cache(env)

    return (
        total_reward,
        cache_hits,
        cache_misses,
        base_hits,
        base_misses,
        enh_hits,
        enh_misses,
        global_step,
        psnr_sum / (step + 1),
        dict(episode_request_counts),
        dict(video_watch_counts),
        dict(video_psnr_sums),
        dict(video_psnr_counts),
        cache_snapshot,
        popularity_bonus_sum,
    )

def train(cfg):
    print("\n--- Starting DRL Caching System ---")

    env = build_environment(cfg)

    feature_adapter = FeatureAdapter(cfg, env)
    net_adapter = NetworkAdapter(cfg, env, feature_adapter)

    date_dir = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M")
    debug_path = os.path.join(cfg.path_results, date_dir)
    metrics_dir = os.path.join(debug_path, "metrics")
    os.makedirs(metrics_dir, exist_ok=True)

    global_log_path = os.path.join(cfg.path_results, "global.log")
    with open(global_log_path, "a", encoding="utf-8") as f:
        f.write(f"{pd.Timestamp.now().isoformat()} | Max Steps: {cfg.max_steps} | ")
        f.write("-" * 50 + "\n")

    global_step = 0

    for episode in range(cfg.n_episodes):
        (
            total_reward,
            cache_hits,
            cache_misses,
            base_hits,
            base_misses,
            enh_hits,
            enh_misses,
            global_step,
            psnr_rate,
            episode_request_counts,
            episode_video_watch_counts,
            episode_video_psnr_sums,
            episode_video_psnr_counts,
            cache_snapshot,
            popularity_bonus_sum,
        ) = run_episode(episode, env, net_adapter, cfg, metrics_dir, global_step)

        save_episode_metrics(
            metrics_dir=metrics_dir,
            ep=episode,
            total_reward=total_reward,
            cache_hits=cache_hits,
            cache_misses=cache_misses,
            agent=None
        )

        debugger.save_results(filepath=f"{debug_path}/json/debug_ep{episode}")
        debugger.clear()

        base_hit_rate = base_hits / (base_hits + base_misses + 1e-9)
        enh_hit_rate = enh_hits / (enh_hits + enh_misses + 1e-9)
        mean_video_psnr = _mean_video_psnr(episode_video_psnr_sums, episode_video_psnr_counts)

        print(
            f"Episode {episode} | R: {int(total_reward)} | "
            f"HR: {cache_hits / (cache_hits + cache_misses + 1e-9):.2f} | "
            f"HR_2: {(base_hit_rate + enh_hit_rate * 4) / 5:.2f} | "
            f"BHR: {base_hit_rate:.2f} | "
            f"EHR: {enh_hit_rate:.2f} | "
            f"PSNR: {psnr_rate:.2f} | "
            f"Mean video PSNR: {mean_video_psnr:.2f} | "
            f"Popularity bonus: {popularity_bonus_sum:.4f} | "
            f"Time: {pd.Timestamp.now().strftime('%H:%M:%S')}"
        )

        _print_video_psnr_ranking(
            video_watch_counts=episode_video_watch_counts,
            video_psnr_sums=episode_video_psnr_sums,
            video_psnr_counts=episode_video_psnr_counts,
            top_k=top_k,
        )
        print("-" * 50)


if __name__ == "__main__":
    train(cfg)
# Out:
# --- Starting DRL Caching System ---
# NetworkAdapter initialized with capacity: 100 videos, 4 tiles per video
# Episode 0 | R: 0 | HR: 0.83 | HR_2: 0.59 | BHR: 0.94 | EHR: 0.50 | PSNR: 35.81 | Mean video PSNR: 35.91 | Popularity bonus: 0.0000 | Time: 13:30:46
# Mean PSNR across watched videos: 35.91
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1573 | mean_psnr=35.79
# 02. Video 1 | watches=911 | mean_psnr=36.08
# 03. Video 2 | watches=391 | mean_psnr=35.69
# 04. Video 11 | watches=359 | mean_psnr=35.13
# 05. Video 3 | watches=340 | mean_psnr=36.07
# 06. Video 9 | watches=286 | mean_psnr=36.00
# 07. Video 14 | watches=280 | mean_psnr=36.03
# 08. Video 17 | watches=250 | mean_psnr=35.42
# 09. Video 4 | watches=203 | mean_psnr=36.01
# 10. Video 8 | watches=162 | mean_psnr=36.42
# 11. Video 13 | watches=159 | mean_psnr=35.60
# 12. Video 5 | watches=157 | mean_psnr=35.83
# 13. Video 7 | watches=144 | mean_psnr=36.15
# 14. Video 6 | watches=140 | mean_psnr=35.84
# 15. Video 10 | watches=134 | mean_psnr=35.54
# 16. Video 16 | watches=124 | mean_psnr=35.54
# 17. Video 44 | watches=113 | mean_psnr=34.49
# 18. Video 36 | watches=104 | mean_psnr=35.31
# 19. Video 27 | watches=101 | mean_psnr=36.04
# 20. Video 15 | watches=95 | mean_psnr=35.61
# --------------------------------------------------
# Episode 1 | R: 0 | HR: 0.66 | HR_2: 0.46 | BHR: 0.75 | EHR: 0.39 | PSNR: 34.50 | Mean video PSNR: 34.57 | Popularity bonus: 0.0000 | Time: 13:30:47
# Mean PSNR across watched videos: 34.57
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1585 | mean_psnr=34.10
# 02. Video 1 | watches=781 | mean_psnr=34.45
# 03. Video 4 | watches=520 | mean_psnr=34.61
# 04. Video 2 | watches=461 | mean_psnr=34.75
# 05. Video 7 | watches=318 | mean_psnr=34.78
# 06. Video 3 | watches=296 | mean_psnr=34.91
# 07. Video 5 | watches=263 | mean_psnr=35.43
# 08. Video 9 | watches=243 | mean_psnr=34.83
# 09. Video 13 | watches=188 | mean_psnr=35.65
# 10. Video 12 | watches=186 | mean_psnr=34.50
# 11. Video 8 | watches=156 | mean_psnr=33.93
# 12. Video 16 | watches=154 | mean_psnr=34.06
# 13. Video 6 | watches=148 | mean_psnr=33.29
# 14. Video 11 | watches=124 | mean_psnr=35.02
# 15. Video 15 | watches=110 | mean_psnr=35.98
# 16. Video 32 | watches=109 | mean_psnr=35.23
# 17. Video 48 | watches=106 | mean_psnr=33.82
# 18. Video 111 | watches=104 | mean_psnr=34.64
# 19. Video 18 | watches=102 | mean_psnr=35.69
# 20. Video 10 | watches=98 | mean_psnr=33.80
# --------------------------------------------------
# Episode 2 | R: 0 | HR: 0.81 | HR_2: 0.58 | BHR: 0.92 | EHR: 0.49 | PSNR: 35.68 | Mean video PSNR: 35.61 | Popularity bonus: 0.0000 | Time: 13:30:48
# Mean PSNR across watched videos: 35.61
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1386 | mean_psnr=35.65
# 02. Video 1 | watches=844 | mean_psnr=36.00
# 03. Video 2 | watches=546 | mean_psnr=35.75
# 04. Video 4 | watches=475 | mean_psnr=35.68
# 05. Video 3 | watches=449 | mean_psnr=35.78
# 06. Video 14 | watches=339 | mean_psnr=35.73
# 07. Video 6 | watches=336 | mean_psnr=35.67
# 08. Video 5 | watches=216 | mean_psnr=35.62
# 09. Video 8 | watches=215 | mean_psnr=35.24
# 10. Video 15 | watches=177 | mean_psnr=36.09
# 11. Video 7 | watches=174 | mean_psnr=35.26
# 12. Video 26 | watches=166 | mean_psnr=35.06
# 13. Video 9 | watches=158 | mean_psnr=35.41
# 14. Video 13 | watches=131 | mean_psnr=35.25
# 15. Video 30 | watches=130 | mean_psnr=36.00
# 16. Video 11 | watches=125 | mean_psnr=35.66
# 17. Video 50 | watches=118 | mean_psnr=36.29
# 18. Video 34 | watches=111 | mean_psnr=35.00
# 19. Video 12 | watches=107 | mean_psnr=36.10
# 20. Video 10 | watches=95 | mean_psnr=35.00
# --------------------------------------------------
# Episode 3 | R: 0 | HR: 0.81 | HR_2: 0.57 | BHR: 0.92 | EHR: 0.49 | PSNR: 35.60 | Mean video PSNR: 35.57 | Popularity bonus: 0.0000 | Time: 13:30:49
# Mean PSNR across watched videos: 35.57
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1492 | mean_psnr=35.68
# 02. Video 1 | watches=888 | mean_psnr=35.73
# 03. Video 6 | watches=456 | mean_psnr=35.89
# 04. Video 5 | watches=358 | mean_psnr=35.73
# 05. Video 2 | watches=354 | mean_psnr=35.70
# 06. Video 3 | watches=330 | mean_psnr=35.45
# 07. Video 9 | watches=302 | mean_psnr=35.34
# 08. Video 4 | watches=301 | mean_psnr=35.78
# 09. Video 7 | watches=261 | mean_psnr=34.75
# 10. Video 10 | watches=189 | mean_psnr=35.56
# 11. Video 15 | watches=160 | mean_psnr=35.30
# 12. Video 8 | watches=159 | mean_psnr=35.64
# 13. Video 34 | watches=151 | mean_psnr=35.96
# 14. Video 11 | watches=145 | mean_psnr=35.22
# 15. Video 24 | watches=127 | mean_psnr=35.18
# 16. Video 43 | watches=126 | mean_psnr=35.22
# 17. Video 14 | watches=125 | mean_psnr=35.40
# 18. Video 70 | watches=120 | mean_psnr=35.02
# 19. Video 17 | watches=118 | mean_psnr=35.95
# 20. Video 32 | watches=112 | mean_psnr=35.65
# --------------------------------------------------
# Episode 4 | R: 0 | HR: 0.85 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.51 | PSNR: 35.91 | Mean video PSNR: 35.96 | Popularity bonus: 0.0000 | Time: 13:30:50
# Mean PSNR across watched videos: 35.96
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1475 | mean_psnr=35.93
# 02. Video 1 | watches=1040 | mean_psnr=35.54
# 03. Video 4 | watches=507 | mean_psnr=36.06
# 04. Video 2 | watches=503 | mean_psnr=35.89
# 05. Video 3 | watches=308 | mean_psnr=35.58
# 06. Video 6 | watches=253 | mean_psnr=36.13
# 07. Video 8 | watches=214 | mean_psnr=35.61
# 08. Video 15 | watches=202 | mean_psnr=35.68
# 09. Video 7 | watches=190 | mean_psnr=36.08
# 10. Video 9 | watches=183 | mean_psnr=35.96
# 11. Video 11 | watches=183 | mean_psnr=35.93
# 12. Video 12 | watches=180 | mean_psnr=35.68
# 13. Video 5 | watches=142 | mean_psnr=36.29
# 14. Video 13 | watches=138 | mean_psnr=36.59
# 15. Video 16 | watches=129 | mean_psnr=35.27
# 16. Video 10 | watches=113 | mean_psnr=35.27
# 17. Video 19 | watches=108 | mean_psnr=35.67
# 18. Video 14 | watches=108 | mean_psnr=36.09
# 19. Video 59 | watches=107 | mean_psnr=35.79
# 20. Video 61 | watches=105 | mean_psnr=37.64
# --------------------------------------------------
# Episode 5 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 35.99 | Mean video PSNR: 35.92 | Popularity bonus: 0.0000 | Time: 13:30:51
# Mean PSNR across watched videos: 35.92
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1287 | mean_psnr=35.83
# 02. Video 1 | watches=873 | mean_psnr=36.11
# 03. Video 2 | watches=770 | mean_psnr=36.08
# 04. Video 3 | watches=389 | mean_psnr=36.00
# 05. Video 6 | watches=329 | mean_psnr=36.05
# 06. Video 7 | watches=324 | mean_psnr=36.40
# 07. Video 12 | watches=228 | mean_psnr=36.00
# 08. Video 5 | watches=224 | mean_psnr=36.14
# 09. Video 4 | watches=216 | mean_psnr=35.65
# 10. Video 20 | watches=216 | mean_psnr=36.04
# 11. Video 18 | watches=189 | mean_psnr=35.57
# 12. Video 10 | watches=179 | mean_psnr=35.88
# 13. Video 26 | watches=142 | mean_psnr=36.09
# 14. Video 8 | watches=125 | mean_psnr=35.22
# 15. Video 35 | watches=119 | mean_psnr=35.78
# 16. Video 14 | watches=116 | mean_psnr=36.01
# 17. Video 13 | watches=110 | mean_psnr=36.05
# 18. Video 28 | watches=105 | mean_psnr=35.71
# 19. Video 45 | watches=103 | mean_psnr=36.38
# 20. Video 34 | watches=101 | mean_psnr=36.21
# --------------------------------------------------
# Episode 6 | R: 0 | HR: 0.87 | HR_2: 0.61 | BHR: 0.98 | EHR: 0.52 | PSNR: 36.04 | Mean video PSNR: 36.05 | Popularity bonus: 0.0000 | Time: 13:30:52
# Mean PSNR across watched videos: 36.05
# Top 20 watched videos by rank:
# 01. Video 0 | watches=2024 | mean_psnr=36.13
# 02. Video 1 | watches=787 | mean_psnr=36.11
# 03. Video 2 | watches=577 | mean_psnr=35.96
# 04. Video 3 | watches=508 | mean_psnr=36.43
# 05. Video 9 | watches=344 | mean_psnr=36.19
# 06. Video 4 | watches=314 | mean_psnr=35.28
# 07. Video 7 | watches=307 | mean_psnr=36.03
# 08. Video 11 | watches=246 | mean_psnr=36.31
# 09. Video 6 | watches=219 | mean_psnr=35.80
# 10. Video 8 | watches=191 | mean_psnr=35.00
# 11. Video 5 | watches=189 | mean_psnr=35.46
# 12. Video 18 | watches=158 | mean_psnr=37.52
# 13. Video 10 | watches=155 | mean_psnr=36.82
# 14. Video 19 | watches=144 | mean_psnr=35.95
# 15. Video 24 | watches=141 | mean_psnr=36.29
# 16. Video 15 | watches=118 | mean_psnr=35.83
# 17. Video 12 | watches=117 | mean_psnr=35.85
# 18. Video 13 | watches=109 | mean_psnr=36.79
# 19. Video 58 | watches=101 | mean_psnr=35.64
# 20. Video 16 | watches=98 | mean_psnr=36.05
# --------------------------------------------------
# Episode 7 | R: 0 | HR: 0.78 | HR_2: 0.54 | BHR: 0.89 | EHR: 0.45 | PSNR: 35.34 | Mean video PSNR: 35.40 | Popularity bonus: 0.0000 | Time: 13:30:53
# Mean PSNR across watched videos: 35.40
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1611 | mean_psnr=35.31
# 02. Video 1 | watches=1130 | mean_psnr=35.34
# 03. Video 2 | watches=495 | mean_psnr=34.91
# 04. Video 3 | watches=428 | mean_psnr=35.11
# 05. Video 5 | watches=418 | mean_psnr=35.27
# 06. Video 6 | watches=312 | mean_psnr=35.52
# 07. Video 4 | watches=292 | mean_psnr=35.70
# 08. Video 7 | watches=285 | mean_psnr=35.11
# 09. Video 11 | watches=270 | mean_psnr=35.57
# 10. Video 10 | watches=229 | mean_psnr=35.21
# 11. Video 14 | watches=203 | mean_psnr=35.53
# 12. Video 8 | watches=198 | mean_psnr=35.01
# 13. Video 9 | watches=175 | mean_psnr=35.26
# 14. Video 15 | watches=146 | mean_psnr=34.86
# 15. Video 17 | watches=96 | mean_psnr=34.95
# 16. Video 35 | watches=94 | mean_psnr=35.37
# 17. Video 31 | watches=93 | mean_psnr=35.97
# 18. Video 38 | watches=89 | mean_psnr=35.25
# 19. Video 23 | watches=82 | mean_psnr=34.73
# 20. Video 27 | watches=82 | mean_psnr=36.16
# --------------------------------------------------
# Episode 8 | R: 0 | HR: 0.84 | HR_2: 0.61 | BHR: 0.95 | EHR: 0.53 | PSNR: 35.97 | Mean video PSNR: 36.00 | Popularity bonus: 0.0000 | Time: 13:30:54
# Mean PSNR across watched videos: 36.00
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1568 | mean_psnr=35.73
# 02. Video 1 | watches=1029 | mean_psnr=35.94
# 03. Video 4 | watches=440 | mean_psnr=35.90
# 04. Video 5 | watches=404 | mean_psnr=36.24
# 05. Video 3 | watches=394 | mean_psnr=36.28
# 06. Video 2 | watches=389 | mean_psnr=35.82
# 07. Video 6 | watches=301 | mean_psnr=36.40
# 08. Video 9 | watches=236 | mean_psnr=35.78
# 09. Video 24 | watches=205 | mean_psnr=36.12
# 10. Video 10 | watches=196 | mean_psnr=36.01
# 11. Video 7 | watches=196 | mean_psnr=36.68
# 12. Video 25 | watches=185 | mean_psnr=36.27
# 13. Video 11 | watches=166 | mean_psnr=35.69
# 14. Video 8 | watches=164 | mean_psnr=35.87
# 15. Video 12 | watches=138 | mean_psnr=36.34
# 16. Video 14 | watches=127 | mean_psnr=36.06
# 17. Video 17 | watches=112 | mean_psnr=36.16
# 18. Video 15 | watches=105 | mean_psnr=36.10
# 19. Video 34 | watches=104 | mean_psnr=35.75
# 20. Video 29 | watches=101 | mean_psnr=35.27
# --------------------------------------------------
# Episode 9 | R: 0 | HR: 0.85 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.52 | PSNR: 35.92 | Mean video PSNR: 35.86 | Popularity bonus: 0.0000 | Time: 13:30:55
# Mean PSNR across watched videos: 35.86
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1738 | mean_psnr=36.08
# 02. Video 1 | watches=813 | mean_psnr=35.91
# 03. Video 3 | watches=533 | mean_psnr=35.68
# 04. Video 2 | watches=516 | mean_psnr=36.36
# 05. Video 5 | watches=296 | mean_psnr=35.91
# 06. Video 7 | watches=271 | mean_psnr=35.97
# 07. Video 4 | watches=253 | mean_psnr=35.83
# 08. Video 13 | watches=194 | mean_psnr=36.42
# 09. Video 12 | watches=183 | mean_psnr=35.87
# 10. Video 14 | watches=180 | mean_psnr=34.93
# 11. Video 8 | watches=179 | mean_psnr=35.81
# 12. Video 11 | watches=160 | mean_psnr=35.36
# 13. Video 6 | watches=149 | mean_psnr=35.91
# 14. Video 19 | watches=120 | mean_psnr=36.06
# 15. Video 10 | watches=116 | mean_psnr=35.84
# 16. Video 16 | watches=114 | mean_psnr=34.80
# 17. Video 15 | watches=113 | mean_psnr=35.55
# 18. Video 30 | watches=110 | mean_psnr=35.77
# 19. Video 18 | watches=103 | mean_psnr=36.17
# 20. Video 26 | watches=102 | mean_psnr=35.47
# --------------------------------------------------
# Episode 10 | R: 0 | HR: 0.80 | HR_2: 0.57 | BHR: 0.90 | EHR: 0.48 | PSNR: 35.57 | Mean video PSNR: 35.52 | Popularity bonus: 0.0000 | Time: 13:30:56
# Mean PSNR across watched videos: 35.52
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1371 | mean_psnr=35.25
# 02. Video 1 | watches=885 | mean_psnr=35.55
# 03. Video 2 | watches=551 | mean_psnr=35.53
# 04. Video 3 | watches=313 | mean_psnr=35.48
# 05. Video 4 | watches=257 | mean_psnr=35.51
# 06. Video 6 | watches=253 | mean_psnr=35.43
# 07. Video 5 | watches=247 | mean_psnr=35.94
# 08. Video 7 | watches=223 | mean_psnr=35.93
# 09. Video 8 | watches=213 | mean_psnr=35.36
# 10. Video 17 | watches=182 | mean_psnr=35.80
# 11. Video 9 | watches=168 | mean_psnr=35.80
# 12. Video 12 | watches=167 | mean_psnr=35.75
# 13. Video 11 | watches=151 | mean_psnr=36.08
# 14. Video 13 | watches=142 | mean_psnr=35.60
# 15. Video 38 | watches=119 | mean_psnr=35.92
# 16. Video 30 | watches=112 | mean_psnr=35.22
# 17. Video 19 | watches=112 | mean_psnr=35.67
# 18. Video 75 | watches=106 | mean_psnr=35.92
# 19. Video 69 | watches=104 | mean_psnr=35.43
# 20. Video 26 | watches=102 | mean_psnr=35.88
# --------------------------------------------------
# Episode 11 | R: 0 | HR: 0.65 | HR_2: 0.45 | BHR: 0.74 | EHR: 0.37 | PSNR: 34.37 | Mean video PSNR: 34.52 | Popularity bonus: 0.0000 | Time: 13:30:57
# Mean PSNR across watched videos: 34.52
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1416 | mean_psnr=34.37
# 02. Video 1 | watches=790 | mean_psnr=34.28
# 03. Video 2 | watches=541 | mean_psnr=34.24
# 04. Video 3 | watches=347 | mean_psnr=33.76
# 05. Video 4 | watches=336 | mean_psnr=33.20
# 06. Video 5 | watches=306 | mean_psnr=34.22
# 07. Video 6 | watches=280 | mean_psnr=34.96
# 08. Video 7 | watches=220 | mean_psnr=35.34
# 09. Video 13 | watches=203 | mean_psnr=34.01
# 10. Video 10 | watches=174 | mean_psnr=33.35
# 11. Video 8 | watches=162 | mean_psnr=34.54
# 12. Video 9 | watches=152 | mean_psnr=33.78
# 13. Video 26 | watches=149 | mean_psnr=35.08
# 14. Video 12 | watches=145 | mean_psnr=33.71
# 15. Video 14 | watches=141 | mean_psnr=34.89
# 16. Video 25 | watches=141 | mean_psnr=34.79
# 17. Video 18 | watches=131 | mean_psnr=34.87
# 18. Video 29 | watches=117 | mean_psnr=34.23
# 19. Video 24 | watches=113 | mean_psnr=36.55
# 20. Video 11 | watches=100 | mean_psnr=36.30
# --------------------------------------------------
# Episode 12 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 35.96 | Mean video PSNR: 35.93 | Popularity bonus: 0.0000 | Time: 13:30:58
# Mean PSNR across watched videos: 35.93
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1666 | mean_psnr=35.94
# 02. Video 1 | watches=1126 | mean_psnr=35.88
# 03. Video 3 | watches=387 | mean_psnr=36.01
# 04. Video 6 | watches=361 | mean_psnr=35.96
# 05. Video 2 | watches=306 | mean_psnr=35.80
# 06. Video 4 | watches=249 | mean_psnr=36.04
# 07. Video 7 | watches=240 | mean_psnr=36.60
# 08. Video 5 | watches=233 | mean_psnr=36.29
# 09. Video 11 | watches=205 | mean_psnr=36.60
# 10. Video 10 | watches=203 | mean_psnr=35.50
# 11. Video 8 | watches=195 | mean_psnr=35.44
# 12. Video 15 | watches=194 | mean_psnr=35.76
# 13. Video 9 | watches=182 | mean_psnr=35.65
# 14. Video 26 | watches=179 | mean_psnr=35.95
# 15. Video 27 | watches=135 | mean_psnr=36.31
# 16. Video 17 | watches=122 | mean_psnr=35.70
# 17. Video 32 | watches=118 | mean_psnr=35.21
# 18. Video 41 | watches=111 | mean_psnr=36.10
# 19. Video 62 | watches=109 | mean_psnr=35.07
# 20. Video 13 | watches=108 | mean_psnr=36.27
# --------------------------------------------------
# Episode 13 | R: 0 | HR: 0.66 | HR_2: 0.45 | BHR: 0.75 | EHR: 0.38 | PSNR: 34.45 | Mean video PSNR: 34.47 | Popularity bonus: 0.0000 | Time: 13:30:59
# Mean PSNR across watched videos: 34.47
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1216 | mean_psnr=33.93
# 02. Video 1 | watches=880 | mean_psnr=34.53
# 03. Video 2 | watches=575 | mean_psnr=34.79
# 04. Video 4 | watches=359 | mean_psnr=35.03
# 05. Video 6 | watches=302 | mean_psnr=35.07
# 06. Video 3 | watches=271 | mean_psnr=34.82
# 07. Video 9 | watches=268 | mean_psnr=35.90
# 08. Video 8 | watches=262 | mean_psnr=34.74
# 09. Video 7 | watches=261 | mean_psnr=34.78
# 10. Video 12 | watches=244 | mean_psnr=34.93
# 11. Video 5 | watches=183 | mean_psnr=32.94
# 12. Video 10 | watches=183 | mean_psnr=35.30
# 13. Video 18 | watches=169 | mean_psnr=33.49
# 14. Video 13 | watches=158 | mean_psnr=33.67
# 15. Video 15 | watches=140 | mean_psnr=36.05
# 16. Video 14 | watches=139 | mean_psnr=34.39
# 17. Video 11 | watches=119 | mean_psnr=34.60
# 18. Video 25 | watches=109 | mean_psnr=33.92
# 19. Video 17 | watches=101 | mean_psnr=32.48
# 20. Video 44 | watches=100 | mean_psnr=34.62
# --------------------------------------------------
# Episode 14 | R: 0 | HR: 0.87 | HR_2: 0.62 | BHR: 0.98 | EHR: 0.52 | PSNR: 36.03 | Mean video PSNR: 36.00 | Popularity bonus: 0.0000 | Time: 13:31:00
# Mean PSNR across watched videos: 36.00
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1810 | mean_psnr=36.11
# 02. Video 1 | watches=1130 | mean_psnr=35.99
# 03. Video 2 | watches=450 | mean_psnr=36.11
# 04. Video 4 | watches=427 | mean_psnr=35.73
# 05. Video 5 | watches=380 | mean_psnr=36.49
# 06. Video 3 | watches=374 | mean_psnr=36.26
# 07. Video 8 | watches=311 | mean_psnr=36.34
# 08. Video 6 | watches=210 | mean_psnr=35.71
# 09. Video 7 | watches=206 | mean_psnr=36.07
# 10. Video 102 | watches=177 | mean_psnr=36.29
# 11. Video 13 | watches=144 | mean_psnr=35.59
# 12. Video 17 | watches=142 | mean_psnr=36.27
# 13. Video 18 | watches=135 | mean_psnr=37.15
# 14. Video 9 | watches=132 | mean_psnr=35.62
# 15. Video 11 | watches=129 | mean_psnr=35.23
# 16. Video 27 | watches=112 | mean_psnr=35.65
# 17. Video 10 | watches=107 | mean_psnr=35.84
# 18. Video 15 | watches=107 | mean_psnr=34.93
# 19. Video 25 | watches=105 | mean_psnr=36.57
# 20. Video 19 | watches=104 | mean_psnr=35.31
# --------------------------------------------------
# Episode 15 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 35.97 | Mean video PSNR: 35.94 | Popularity bonus: 0.0000 | Time: 13:31:01
# Mean PSNR across watched videos: 35.94
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1447 | mean_psnr=35.79
# 02. Video 1 | watches=1054 | mean_psnr=36.02
# 03. Video 2 | watches=607 | mean_psnr=35.94
# 04. Video 3 | watches=503 | mean_psnr=36.05
# 05. Video 7 | watches=331 | mean_psnr=36.06
# 06. Video 4 | watches=286 | mean_psnr=35.82
# 07. Video 6 | watches=275 | mean_psnr=35.44
# 08. Video 9 | watches=255 | mean_psnr=36.22
# 09. Video 5 | watches=227 | mean_psnr=35.83
# 10. Video 8 | watches=225 | mean_psnr=36.12
# 11. Video 14 | watches=158 | mean_psnr=35.73
# 12. Video 11 | watches=150 | mean_psnr=35.70
# 13. Video 24 | watches=146 | mean_psnr=35.77
# 14. Video 17 | watches=137 | mean_psnr=35.80
# 15. Video 15 | watches=129 | mean_psnr=36.26
# 16. Video 22 | watches=123 | mean_psnr=35.39
# 17. Video 10 | watches=98 | mean_psnr=35.48
# 18. Video 19 | watches=98 | mean_psnr=35.46
# 19. Video 27 | watches=97 | mean_psnr=36.26
# 20. Video 53 | watches=96 | mean_psnr=36.74
# --------------------------------------------------
# Episode 16 | R: 0 | HR: 0.79 | HR_2: 0.55 | BHR: 0.89 | EHR: 0.47 | PSNR: 35.44 | Mean video PSNR: 35.44 | Popularity bonus: 0.0000 | Time: 13:31:02
# Mean PSNR across watched videos: 35.44
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1638 | mean_psnr=35.47
# 02. Video 1 | watches=1075 | mean_psnr=35.17
# 03. Video 5 | watches=367 | mean_psnr=35.48
# 04. Video 2 | watches=367 | mean_psnr=35.55
# 05. Video 4 | watches=322 | mean_psnr=35.57
# 06. Video 3 | watches=287 | mean_psnr=35.45
# 07. Video 10 | watches=242 | mean_psnr=35.21
# 08. Video 6 | watches=242 | mean_psnr=35.28
# 09. Video 7 | watches=206 | mean_psnr=35.44
# 10. Video 8 | watches=199 | mean_psnr=35.67
# 11. Video 9 | watches=194 | mean_psnr=35.61
# 12. Video 22 | watches=165 | mean_psnr=35.02
# 13. Video 11 | watches=153 | mean_psnr=35.57
# 14. Video 17 | watches=148 | mean_psnr=35.15
# 15. Video 15 | watches=147 | mean_psnr=36.04
# 16. Video 20 | watches=123 | mean_psnr=35.69
# 17. Video 33 | watches=121 | mean_psnr=36.43
# 18. Video 25 | watches=118 | mean_psnr=35.17
# 19. Video 12 | watches=114 | mean_psnr=36.14
# 20. Video 19 | watches=108 | mean_psnr=36.53
# --------------------------------------------------
# Episode 17 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.96 | EHR: 0.53 | PSNR: 35.99 | Mean video PSNR: 36.03 | Popularity bonus: 0.0000 | Time: 13:31:03
# Mean PSNR across watched videos: 36.03
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1579 | mean_psnr=36.08
# 02. Video 1 | watches=947 | mean_psnr=35.98
# 03. Video 2 | watches=570 | mean_psnr=36.35
# 04. Video 3 | watches=431 | mean_psnr=35.66
# 05. Video 4 | watches=425 | mean_psnr=36.04
# 06. Video 6 | watches=283 | mean_psnr=35.64
# 07. Video 10 | watches=276 | mean_psnr=35.61
# 08. Video 9 | watches=261 | mean_psnr=35.26
# 09. Video 7 | watches=220 | mean_psnr=35.44
# 10. Video 20 | watches=218 | mean_psnr=35.92
# 11. Video 12 | watches=206 | mean_psnr=35.81
# 12. Video 11 | watches=144 | mean_psnr=35.56
# 13. Video 17 | watches=138 | mean_psnr=36.34
# 14. Video 13 | watches=123 | mean_psnr=36.22
# 15. Video 23 | watches=115 | mean_psnr=35.46
# 16. Video 15 | watches=115 | mean_psnr=36.39
# 17. Video 8 | watches=95 | mean_psnr=36.61
# 18. Video 37 | watches=90 | mean_psnr=35.39
# 19. Video 184 | watches=89 | mean_psnr=34.92
# 20. Video 22 | watches=88 | mean_psnr=35.48
# --------------------------------------------------
# Episode 18 | R: 0 | HR: 0.86 | HR_2: 0.60 | BHR: 0.97 | EHR: 0.51 | PSNR: 35.92 | Mean video PSNR: 35.89 | Popularity bonus: 0.0000 | Time: 13:31:04
# Mean PSNR across watched videos: 35.89
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1901 | mean_psnr=35.95
# 02. Video 1 | watches=589 | mean_psnr=35.73
# 03. Video 2 | watches=557 | mean_psnr=35.66
# 04. Video 4 | watches=438 | mean_psnr=36.17
# 05. Video 3 | watches=432 | mean_psnr=35.74
# 06. Video 5 | watches=393 | mean_psnr=36.02
# 07. Video 15 | watches=206 | mean_psnr=35.90
# 08. Video 11 | watches=185 | mean_psnr=35.96
# 09. Video 8 | watches=183 | mean_psnr=35.59
# 10. Video 20 | watches=179 | mean_psnr=36.24
# 11. Video 25 | watches=167 | mean_psnr=36.66
# 12. Video 17 | watches=154 | mean_psnr=36.41
# 13. Video 12 | watches=153 | mean_psnr=35.83
# 14. Video 48 | watches=152 | mean_psnr=35.86
# 15. Video 6 | watches=149 | mean_psnr=35.62
# 16. Video 10 | watches=140 | mean_psnr=36.16
# 17. Video 7 | watches=125 | mean_psnr=36.10
# 18. Video 16 | watches=121 | mean_psnr=36.47
# 19. Video 29 | watches=115 | mean_psnr=35.46
# 20. Video 46 | watches=102 | mean_psnr=36.13
# --------------------------------------------------
# Episode 19 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 35.98 | Mean video PSNR: 36.04 | Popularity bonus: 0.0000 | Time: 13:31:05
# Mean PSNR across watched videos: 36.04
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1490 | mean_psnr=35.81
# 02. Video 1 | watches=1056 | mean_psnr=35.97
# 03. Video 2 | watches=565 | mean_psnr=35.96
# 04. Video 6 | watches=423 | mean_psnr=36.24
# 05. Video 3 | watches=367 | mean_psnr=35.87
# 06. Video 4 | watches=330 | mean_psnr=35.78
# 07. Video 5 | watches=276 | mean_psnr=35.90
# 08. Video 9 | watches=217 | mean_psnr=36.43
# 09. Video 7 | watches=215 | mean_psnr=35.66
# 10. Video 8 | watches=162 | mean_psnr=36.17
# 11. Video 25 | watches=153 | mean_psnr=35.20
# 12. Video 14 | watches=148 | mean_psnr=35.91
# 13. Video 12 | watches=147 | mean_psnr=35.82
# 14. Video 10 | watches=142 | mean_psnr=36.25
# 15. Video 64 | watches=139 | mean_psnr=35.59
# 16. Video 27 | watches=133 | mean_psnr=35.60
# 17. Video 17 | watches=130 | mean_psnr=37.19
# 18. Video 15 | watches=128 | mean_psnr=36.33
# 19. Video 47 | watches=117 | mean_psnr=35.53
# 20. Video 23 | watches=91 | mean_psnr=36.35
# --------------------------------------------------
# Episode 20 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 35.95 | Mean video PSNR: 35.91 | Popularity bonus: 0.0000 | Time: 13:31:06
# Mean PSNR across watched videos: 35.91
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1880 | mean_psnr=35.72
# 02. Video 1 | watches=867 | mean_psnr=36.30
# 03. Video 4 | watches=511 | mean_psnr=35.80
# 04. Video 3 | watches=383 | mean_psnr=36.35
# 05. Video 2 | watches=373 | mean_psnr=35.74
# 06. Video 5 | watches=359 | mean_psnr=36.19
# 07. Video 11 | watches=275 | mean_psnr=36.05
# 08. Video 6 | watches=254 | mean_psnr=36.38
# 09. Video 7 | watches=229 | mean_psnr=36.51
# 10. Video 8 | watches=193 | mean_psnr=35.91
# 11. Video 12 | watches=168 | mean_psnr=35.73
# 12. Video 21 | watches=148 | mean_psnr=35.62
# 13. Video 13 | watches=143 | mean_psnr=36.38
# 14. Video 63 | watches=111 | mean_psnr=36.98
# 15. Video 9 | watches=111 | mean_psnr=35.92
# 16. Video 14 | watches=108 | mean_psnr=35.79
# 17. Video 10 | watches=106 | mean_psnr=35.68
# 18. Video 20 | watches=91 | mean_psnr=36.26
# 19. Video 24 | watches=90 | mean_psnr=36.25
# 20. Video 16 | watches=89 | mean_psnr=34.49
# --------------------------------------------------
# Episode 21 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.95 | EHR: 0.51 | PSNR: 35.88 | Mean video PSNR: 35.91 | Popularity bonus: 0.0000 | Time: 13:31:07
# Mean PSNR across watched videos: 35.91
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1631 | mean_psnr=35.61
# 02. Video 1 | watches=922 | mean_psnr=35.70
# 03. Video 2 | watches=608 | mean_psnr=36.25
# 04. Video 5 | watches=397 | mean_psnr=35.60
# 05. Video 3 | watches=361 | mean_psnr=35.64
# 06. Video 6 | watches=342 | mean_psnr=35.94
# 07. Video 9 | watches=230 | mean_psnr=35.87
# 08. Video 4 | watches=204 | mean_psnr=35.71
# 09. Video 13 | watches=169 | mean_psnr=35.93
# 10. Video 7 | watches=145 | mean_psnr=37.10
# 11. Video 92 | watches=143 | mean_psnr=35.93
# 12. Video 8 | watches=140 | mean_psnr=36.43
# 13. Video 20 | watches=125 | mean_psnr=36.22
# 14. Video 26 | watches=119 | mean_psnr=36.53
# 15. Video 51 | watches=114 | mean_psnr=36.40
# 16. Video 35 | watches=108 | mean_psnr=35.23
# 17. Video 12 | watches=106 | mean_psnr=36.30
# 18. Video 19 | watches=104 | mean_psnr=36.01
# 19. Video 44 | watches=102 | mean_psnr=35.76
# 20. Video 28 | watches=101 | mean_psnr=36.29
# --------------------------------------------------
# Episode 22 | R: 0 | HR: 0.81 | HR_2: 0.58 | BHR: 0.92 | EHR: 0.50 | PSNR: 35.68 | Mean video PSNR: 35.72 | Popularity bonus: 0.0000 | Time: 13:31:08
# Mean PSNR across watched videos: 35.72
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1753 | mean_psnr=35.50
# 02. Video 1 | watches=860 | mean_psnr=35.92
# 03. Video 3 | watches=560 | mean_psnr=35.27
# 04. Video 2 | watches=499 | mean_psnr=35.77
# 05. Video 6 | watches=318 | mean_psnr=35.50
# 06. Video 5 | watches=316 | mean_psnr=35.78
# 07. Video 4 | watches=249 | mean_psnr=35.82
# 08. Video 14 | watches=196 | mean_psnr=35.06
# 09. Video 18 | watches=182 | mean_psnr=36.02
# 10. Video 24 | watches=168 | mean_psnr=36.32
# 11. Video 8 | watches=162 | mean_psnr=36.02
# 12. Video 9 | watches=161 | mean_psnr=36.65
# 13. Video 15 | watches=159 | mean_psnr=35.72
# 14. Video 7 | watches=147 | mean_psnr=35.46
# 15. Video 10 | watches=140 | mean_psnr=35.38
# 16. Video 12 | watches=138 | mean_psnr=35.24
# 17. Video 36 | watches=101 | mean_psnr=35.72
# 18. Video 88 | watches=90 | mean_psnr=36.03
# 19. Video 26 | watches=90 | mean_psnr=35.89
# 20. Video 31 | watches=90 | mean_psnr=35.33
# --------------------------------------------------
# Episode 23 | R: 0 | HR: 0.87 | HR_2: 0.61 | BHR: 0.98 | EHR: 0.52 | PSNR: 36.00 | Mean video PSNR: 35.99 | Popularity bonus: 0.0000 | Time: 13:31:09
# Mean PSNR across watched videos: 35.99
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1565 | mean_psnr=36.14
# 02. Video 1 | watches=1025 | mean_psnr=36.10
# 03. Video 2 | watches=762 | mean_psnr=35.97
# 04. Video 4 | watches=469 | mean_psnr=35.46
# 05. Video 5 | watches=286 | mean_psnr=35.46
# 06. Video 10 | watches=255 | mean_psnr=37.03
# 07. Video 6 | watches=250 | mean_psnr=35.83
# 08. Video 3 | watches=248 | mean_psnr=35.87
# 09. Video 9 | watches=228 | mean_psnr=36.36
# 10. Video 15 | watches=219 | mean_psnr=36.51
# 11. Video 7 | watches=181 | mean_psnr=35.87
# 12. Video 8 | watches=175 | mean_psnr=35.31
# 13. Video 11 | watches=168 | mean_psnr=36.03
# 14. Video 19 | watches=153 | mean_psnr=36.37
# 15. Video 13 | watches=137 | mean_psnr=35.53
# 16. Video 21 | watches=129 | mean_psnr=37.29
# 17. Video 14 | watches=129 | mean_psnr=36.20
# 18. Video 40 | watches=125 | mean_psnr=35.70
# 19. Video 17 | watches=120 | mean_psnr=35.12
# 20. Video 22 | watches=115 | mean_psnr=36.00
# --------------------------------------------------
# Episode 24 | R: 0 | HR: 0.65 | HR_2: 0.44 | BHR: 0.74 | EHR: 0.37 | PSNR: 34.37 | Mean video PSNR: 34.38 | Popularity bonus: 0.0000 | Time: 13:31:10
# Mean PSNR across watched videos: 34.38
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1635 | mean_psnr=33.95
# 02. Video 1 | watches=906 | mean_psnr=34.81
# 03. Video 2 | watches=629 | mean_psnr=34.61
# 04. Video 3 | watches=377 | mean_psnr=35.07
# 05. Video 9 | watches=341 | mean_psnr=34.57
# 06. Video 5 | watches=324 | mean_psnr=33.33
# 07. Video 4 | watches=287 | mean_psnr=34.64
# 08. Video 6 | watches=217 | mean_psnr=34.83
# 09. Video 11 | watches=199 | mean_psnr=34.77
# 10. Video 16 | watches=186 | mean_psnr=34.77
# 11. Video 8 | watches=182 | mean_psnr=33.06
# 12. Video 7 | watches=158 | mean_psnr=35.00
# 13. Video 20 | watches=137 | mean_psnr=35.35
# 14. Video 10 | watches=114 | mean_psnr=36.21
# 15. Video 14 | watches=108 | mean_psnr=34.38
# 16. Video 12 | watches=108 | mean_psnr=35.46
# 17. Video 15 | watches=105 | mean_psnr=35.81
# 18. Video 26 | watches=88 | mean_psnr=35.94
# 19. Video 13 | watches=85 | mean_psnr=33.71
# 20. Video 40 | watches=81 | mean_psnr=33.58
# --------------------------------------------------
# Episode 25 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.95 | EHR: 0.51 | PSNR: 35.89 | Mean video PSNR: 35.88 | Popularity bonus: 0.0000 | Time: 13:31:11
# Mean PSNR across watched videos: 35.88
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1564 | mean_psnr=35.88
# 02. Video 1 | watches=1184 | mean_psnr=35.96
# 03. Video 2 | watches=650 | mean_psnr=36.29
# 04. Video 4 | watches=316 | mean_psnr=36.26
# 05. Video 8 | watches=307 | mean_psnr=36.14
# 06. Video 3 | watches=268 | mean_psnr=35.48
# 07. Video 7 | watches=255 | mean_psnr=36.00
# 08. Video 5 | watches=218 | mean_psnr=35.61
# 09. Video 11 | watches=202 | mean_psnr=36.29
# 10. Video 12 | watches=197 | mean_psnr=36.60
# 11. Video 16 | watches=193 | mean_psnr=35.34
# 12. Video 6 | watches=193 | mean_psnr=35.40
# 13. Video 29 | watches=138 | mean_psnr=36.30
# 14. Video 129 | watches=132 | mean_psnr=35.30
# 15. Video 10 | watches=131 | mean_psnr=36.32
# 16. Video 9 | watches=126 | mean_psnr=35.30
# 17. Video 20 | watches=119 | mean_psnr=35.25
# 18. Video 18 | watches=109 | mean_psnr=37.36
# 19. Video 31 | watches=109 | mean_psnr=36.17
# 20. Video 23 | watches=105 | mean_psnr=35.43
# --------------------------------------------------
# Episode 26 | R: 0 | HR: 0.83 | HR_2: 0.58 | BHR: 0.94 | EHR: 0.49 | PSNR: 35.70 | Mean video PSNR: 35.66 | Popularity bonus: 0.0000 | Time: 13:31:13
# Mean PSNR across watched videos: 35.66
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1416 | mean_psnr=35.80
# 02. Video 1 | watches=1009 | mean_psnr=35.63
# 03. Video 2 | watches=494 | mean_psnr=35.77
# 04. Video 4 | watches=479 | mean_psnr=35.33
# 05. Video 6 | watches=347 | mean_psnr=35.48
# 06. Video 5 | watches=290 | mean_psnr=35.89
# 07. Video 3 | watches=280 | mean_psnr=35.84
# 08. Video 8 | watches=218 | mean_psnr=35.28
# 09. Video 10 | watches=210 | mean_psnr=35.35
# 10. Video 13 | watches=200 | mean_psnr=36.10
# 11. Video 11 | watches=190 | mean_psnr=35.89
# 12. Video 57 | watches=176 | mean_psnr=35.99
# 13. Video 7 | watches=150 | mean_psnr=35.28
# 14. Video 17 | watches=148 | mean_psnr=35.88
# 15. Video 9 | watches=146 | mean_psnr=35.82
# 16. Video 24 | watches=130 | mean_psnr=35.48
# 17. Video 19 | watches=129 | mean_psnr=35.27
# 18. Video 55 | watches=122 | mean_psnr=36.07
# 19. Video 14 | watches=122 | mean_psnr=36.17
# 20. Video 21 | watches=110 | mean_psnr=36.23
# --------------------------------------------------
# Episode 27 | R: 0 | HR: 0.86 | HR_2: 0.62 | BHR: 0.98 | EHR: 0.53 | PSNR: 36.10 | Mean video PSNR: 36.03 | Popularity bonus: 0.0000 | Time: 13:31:14
# Mean PSNR across watched videos: 36.03
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1511 | mean_psnr=36.26
# 02. Video 1 | watches=1197 | mean_psnr=36.09
# 03. Video 2 | watches=691 | mean_psnr=36.10
# 04. Video 3 | watches=469 | mean_psnr=35.78
# 05. Video 4 | watches=437 | mean_psnr=36.06
# 06. Video 5 | watches=273 | mean_psnr=36.30
# 07. Video 18 | watches=230 | mean_psnr=36.14
# 08. Video 10 | watches=207 | mean_psnr=36.62
# 09. Video 6 | watches=204 | mean_psnr=35.54
# 10. Video 11 | watches=195 | mean_psnr=35.78
# 11. Video 23 | watches=195 | mean_psnr=35.36
# 12. Video 35 | watches=177 | mean_psnr=36.29
# 13. Video 12 | watches=171 | mean_psnr=35.95
# 14. Video 9 | watches=171 | mean_psnr=36.40
# 15. Video 7 | watches=138 | mean_psnr=36.29
# 16. Video 13 | watches=138 | mean_psnr=36.56
# 17. Video 61 | watches=115 | mean_psnr=35.87
# 18. Video 124 | watches=102 | mean_psnr=35.71
# 19. Video 31 | watches=101 | mean_psnr=36.53
# 20. Video 30 | watches=95 | mean_psnr=36.05
# --------------------------------------------------
# Episode 28 | R: 0 | HR: 0.81 | HR_2: 0.58 | BHR: 0.92 | EHR: 0.49 | PSNR: 35.68 | Mean video PSNR: 35.64 | Popularity bonus: 0.0000 | Time: 13:31:15
# Mean PSNR across watched videos: 35.64
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1495 | mean_psnr=35.74
# 02. Video 1 | watches=979 | mean_psnr=35.60
# 03. Video 2 | watches=743 | mean_psnr=35.67
# 04. Video 11 | watches=304 | mean_psnr=35.35
# 05. Video 3 | watches=244 | mean_psnr=35.23
# 06. Video 8 | watches=236 | mean_psnr=36.19
# 07. Video 7 | watches=235 | mean_psnr=35.73
# 08. Video 4 | watches=231 | mean_psnr=35.90
# 09. Video 10 | watches=216 | mean_psnr=35.71
# 10. Video 13 | watches=215 | mean_psnr=35.35
# 11. Video 5 | watches=194 | mean_psnr=35.54
# 12. Video 9 | watches=192 | mean_psnr=35.62
# 13. Video 12 | watches=164 | mean_psnr=35.72
# 14. Video 6 | watches=144 | mean_psnr=35.83
# 15. Video 23 | watches=138 | mean_psnr=35.51
# 16. Video 15 | watches=135 | mean_psnr=35.48
# 17. Video 84 | watches=111 | mean_psnr=35.86
# 18. Video 81 | watches=111 | mean_psnr=35.32
# 19. Video 26 | watches=100 | mean_psnr=35.62
# 20. Video 24 | watches=98 | mean_psnr=35.03
# --------------------------------------------------
# Episode 29 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.96 | EHR: 0.52 | PSNR: 35.97 | Mean video PSNR: 35.96 | Popularity bonus: 0.0000 | Time: 13:31:16
# Mean PSNR across watched videos: 35.96
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1648 | mean_psnr=36.17
# 02. Video 1 | watches=956 | mean_psnr=35.89
# 03. Video 2 | watches=666 | mean_psnr=35.56
# 04. Video 3 | watches=528 | mean_psnr=35.89
# 05. Video 14 | watches=314 | mean_psnr=36.28
# 06. Video 7 | watches=293 | mean_psnr=35.53
# 07. Video 4 | watches=275 | mean_psnr=35.79
# 08. Video 9 | watches=242 | mean_psnr=36.14
# 09. Video 5 | watches=239 | mean_psnr=36.13
# 10. Video 6 | watches=232 | mean_psnr=35.84
# 11. Video 15 | watches=146 | mean_psnr=35.75
# 12. Video 30 | watches=140 | mean_psnr=36.30
# 13. Video 10 | watches=136 | mean_psnr=36.12
# 14. Video 8 | watches=129 | mean_psnr=35.68
# 15. Video 11 | watches=125 | mean_psnr=35.72
# 16. Video 17 | watches=121 | mean_psnr=35.12
# 17. Video 12 | watches=105 | mean_psnr=36.45
# 18. Video 31 | watches=103 | mean_psnr=35.75
# 19. Video 21 | watches=97 | mean_psnr=34.48
# 20. Video 23 | watches=95 | mean_psnr=36.11
# --------------------------------------------------
# Episode 30 | R: 0 | HR: 0.77 | HR_2: 0.54 | BHR: 0.88 | EHR: 0.46 | PSNR: 35.29 | Mean video PSNR: 35.26 | Popularity bonus: 0.0000 | Time: 13:31:17
# Mean PSNR across watched videos: 35.26
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1424 | mean_psnr=35.32
# 02. Video 1 | watches=838 | mean_psnr=35.24
# 03. Video 2 | watches=447 | mean_psnr=35.46
# 04. Video 3 | watches=429 | mean_psnr=35.52
# 05. Video 4 | watches=336 | mean_psnr=35.14
# 06. Video 5 | watches=302 | mean_psnr=35.19
# 07. Video 6 | watches=294 | mean_psnr=35.34
# 08. Video 13 | watches=273 | mean_psnr=35.67
# 09. Video 11 | watches=268 | mean_psnr=35.33
# 10. Video 8 | watches=205 | mean_psnr=35.20
# 11. Video 7 | watches=204 | mean_psnr=34.26
# 12. Video 45 | watches=186 | mean_psnr=35.00
# 13. Video 21 | watches=174 | mean_psnr=36.19
# 14. Video 18 | watches=167 | mean_psnr=35.22
# 15. Video 12 | watches=143 | mean_psnr=34.25
# 16. Video 19 | watches=137 | mean_psnr=34.89
# 17. Video 38 | watches=126 | mean_psnr=35.18
# 18. Video 10 | watches=117 | mean_psnr=34.81
# 19. Video 16 | watches=116 | mean_psnr=36.10
# 20. Video 100 | watches=115 | mean_psnr=36.13
# --------------------------------------------------
# Episode 31 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.96 | EHR: 0.53 | PSNR: 36.00 | Mean video PSNR: 35.98 | Popularity bonus: 0.0000 | Time: 13:31:18
# Mean PSNR across watched videos: 35.98
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1647 | mean_psnr=35.99
# 02. Video 1 | watches=1258 | mean_psnr=36.05
# 03. Video 2 | watches=558 | mean_psnr=35.48
# 04. Video 3 | watches=456 | mean_psnr=36.13
# 05. Video 4 | watches=342 | mean_psnr=35.66
# 06. Video 8 | watches=281 | mean_psnr=35.83
# 07. Video 15 | watches=203 | mean_psnr=35.96
# 08. Video 9 | watches=195 | mean_psnr=36.54
# 09. Video 5 | watches=177 | mean_psnr=36.47
# 10. Video 7 | watches=176 | mean_psnr=35.54
# 11. Video 31 | watches=162 | mean_psnr=36.13
# 12. Video 12 | watches=145 | mean_psnr=35.86
# 13. Video 108 | watches=138 | mean_psnr=36.50
# 14. Video 10 | watches=128 | mean_psnr=36.02
# 15. Video 11 | watches=115 | mean_psnr=36.50
# 16. Video 23 | watches=114 | mean_psnr=36.01
# 17. Video 22 | watches=111 | mean_psnr=35.99
# 18. Video 24 | watches=111 | mean_psnr=35.70
# 19. Video 37 | watches=108 | mean_psnr=36.27
# 20. Video 6 | watches=102 | mean_psnr=35.96
# --------------------------------------------------
# Episode 32 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.96 | EHR: 0.53 | PSNR: 36.00 | Mean video PSNR: 35.89 | Popularity bonus: 0.0000 | Time: 13:31:19
# Mean PSNR across watched videos: 35.89
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1303 | mean_psnr=35.94
# 02. Video 1 | watches=703 | mean_psnr=35.84
# 03. Video 2 | watches=590 | mean_psnr=36.23
# 04. Video 3 | watches=505 | mean_psnr=36.19
# 05. Video 4 | watches=418 | mean_psnr=35.35
# 06. Video 11 | watches=308 | mean_psnr=35.79
# 07. Video 7 | watches=300 | mean_psnr=36.09
# 08. Video 6 | watches=281 | mean_psnr=35.87
# 09. Video 8 | watches=263 | mean_psnr=35.79
# 10. Video 9 | watches=260 | mean_psnr=35.92
# 11. Video 5 | watches=249 | mean_psnr=36.47
# 12. Video 10 | watches=194 | mean_psnr=35.95
# 13. Video 18 | watches=190 | mean_psnr=36.18
# 14. Video 13 | watches=188 | mean_psnr=36.00
# 15. Video 26 | watches=145 | mean_psnr=36.62
# 16. Video 12 | watches=133 | mean_psnr=34.94
# 17. Video 17 | watches=130 | mean_psnr=35.63
# 18. Video 15 | watches=125 | mean_psnr=35.80
# 19. Video 19 | watches=121 | mean_psnr=34.83
# 20. Video 22 | watches=107 | mean_psnr=36.38
# --------------------------------------------------
# Episode 33 | R: 0 | HR: 0.82 | HR_2: 0.58 | BHR: 0.93 | EHR: 0.49 | PSNR: 35.72 | Mean video PSNR: 35.65 | Popularity bonus: 0.0000 | Time: 13:31:20
# Mean PSNR across watched videos: 35.65
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1238 | mean_psnr=35.73
# 02. Video 1 | watches=1127 | mean_psnr=35.64
# 03. Video 2 | watches=598 | mean_psnr=35.73
# 04. Video 3 | watches=575 | mean_psnr=35.52
# 05. Video 5 | watches=358 | mean_psnr=35.92
# 06. Video 7 | watches=297 | mean_psnr=36.15
# 07. Video 6 | watches=217 | mean_psnr=35.53
# 08. Video 11 | watches=214 | mean_psnr=35.98
# 09. Video 4 | watches=195 | mean_psnr=35.58
# 10. Video 13 | watches=178 | mean_psnr=35.59
# 11. Video 8 | watches=178 | mean_psnr=35.87
# 12. Video 9 | watches=153 | mean_psnr=35.64
# 13. Video 27 | watches=150 | mean_psnr=35.65
# 14. Video 10 | watches=124 | mean_psnr=35.18
# 15. Video 14 | watches=119 | mean_psnr=35.80
# 16. Video 36 | watches=118 | mean_psnr=35.74
# 17. Video 26 | watches=103 | mean_psnr=35.53
# 18. Video 52 | watches=92 | mean_psnr=35.49
# 19. Video 19 | watches=91 | mean_psnr=35.44
# 20. Video 119 | watches=89 | mean_psnr=35.51
# --------------------------------------------------
# Episode 34 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.96 | EHR: 0.51 | PSNR: 35.89 | Mean video PSNR: 35.87 | Popularity bonus: 0.0000 | Time: 13:31:21
# Mean PSNR across watched videos: 35.87
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1182 | mean_psnr=35.80
# 02. Video 1 | watches=1123 | mean_psnr=35.79
# 03. Video 2 | watches=748 | mean_psnr=36.09
# 04. Video 5 | watches=432 | mean_psnr=35.46
# 05. Video 4 | watches=426 | mean_psnr=35.90
# 06. Video 8 | watches=315 | mean_psnr=35.87
# 07. Video 3 | watches=304 | mean_psnr=36.13
# 08. Video 9 | watches=250 | mean_psnr=35.96
# 09. Video 24 | watches=213 | mean_psnr=36.00
# 10. Video 10 | watches=155 | mean_psnr=35.56
# 11. Video 14 | watches=149 | mean_psnr=35.60
# 12. Video 11 | watches=130 | mean_psnr=35.46
# 13. Video 33 | watches=127 | mean_psnr=35.83
# 14. Video 19 | watches=119 | mean_psnr=34.62
# 15. Video 6 | watches=118 | mean_psnr=36.10
# 16. Video 27 | watches=114 | mean_psnr=35.68
# 17. Video 29 | watches=106 | mean_psnr=35.38
# 18. Video 12 | watches=100 | mean_psnr=35.73
# 19. Video 42 | watches=98 | mean_psnr=35.94
# 20. Video 13 | watches=96 | mean_psnr=35.23
# --------------------------------------------------
# Episode 35 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 36.01 | Mean video PSNR: 36.01 | Popularity bonus: 0.0000 | Time: 13:31:22
# Mean PSNR across watched videos: 36.01
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1380 | mean_psnr=36.18
# 02. Video 1 | watches=891 | mean_psnr=35.63
# 03. Video 2 | watches=686 | mean_psnr=36.27
# 04. Video 6 | watches=398 | mean_psnr=36.49
# 05. Video 3 | watches=346 | mean_psnr=36.32
# 06. Video 5 | watches=333 | mean_psnr=36.02
# 07. Video 8 | watches=321 | mean_psnr=35.51
# 08. Video 4 | watches=305 | mean_psnr=35.93
# 09. Video 7 | watches=284 | mean_psnr=36.52
# 10. Video 14 | watches=186 | mean_psnr=35.62
# 11. Video 19 | watches=169 | mean_psnr=36.07
# 12. Video 26 | watches=162 | mean_psnr=35.19
# 13. Video 11 | watches=149 | mean_psnr=36.41
# 14. Video 9 | watches=148 | mean_psnr=36.08
# 15. Video 21 | watches=134 | mean_psnr=35.49
# 16. Video 15 | watches=127 | mean_psnr=36.81
# 17. Video 12 | watches=119 | mean_psnr=35.82
# 18. Video 31 | watches=114 | mean_psnr=36.60
# 19. Video 42 | watches=113 | mean_psnr=35.88
# 20. Video 10 | watches=107 | mean_psnr=35.96
# --------------------------------------------------
# Episode 36 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.95 | EHR: 0.51 | PSNR: 35.84 | Mean video PSNR: 35.81 | Popularity bonus: 0.0000 | Time: 13:31:23
# Mean PSNR across watched videos: 35.81
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1441 | mean_psnr=35.86
# 02. Video 1 | watches=1042 | mean_psnr=35.90
# 03. Video 2 | watches=574 | mean_psnr=35.64
# 04. Video 3 | watches=425 | mean_psnr=35.79
# 05. Video 8 | watches=378 | mean_psnr=36.07
# 06. Video 6 | watches=271 | mean_psnr=35.83
# 07. Video 5 | watches=245 | mean_psnr=36.04
# 08. Video 10 | watches=231 | mean_psnr=35.73
# 09. Video 7 | watches=210 | mean_psnr=35.79
# 10. Video 4 | watches=194 | mean_psnr=35.00
# 11. Video 23 | watches=174 | mean_psnr=36.09
# 12. Video 9 | watches=174 | mean_psnr=36.15
# 13. Video 18 | watches=157 | mean_psnr=35.59
# 14. Video 19 | watches=151 | mean_psnr=36.14
# 15. Video 14 | watches=150 | mean_psnr=35.75
# 16. Video 15 | watches=141 | mean_psnr=35.73
# 17. Video 40 | watches=134 | mean_psnr=35.63
# 18. Video 13 | watches=125 | mean_psnr=35.66
# 19. Video 12 | watches=121 | mean_psnr=36.55
# 20. Video 36 | watches=118 | mean_psnr=35.72
# --------------------------------------------------
# Episode 37 | R: 0 | HR: 0.82 | HR_2: 0.58 | BHR: 0.93 | EHR: 0.49 | PSNR: 35.67 | Mean video PSNR: 35.65 | Popularity bonus: 0.0000 | Time: 13:31:24
# Mean PSNR across watched videos: 35.65
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1538 | mean_psnr=35.60
# 02. Video 1 | watches=924 | mean_psnr=35.71
# 03. Video 2 | watches=846 | mean_psnr=35.93
# 04. Video 3 | watches=559 | mean_psnr=35.65
# 05. Video 8 | watches=465 | mean_psnr=36.05
# 06. Video 5 | watches=297 | mean_psnr=35.97
# 07. Video 6 | watches=252 | mean_psnr=35.93
# 08. Video 23 | watches=221 | mean_psnr=35.18
# 09. Video 7 | watches=167 | mean_psnr=36.09
# 10. Video 11 | watches=150 | mean_psnr=35.13
# 11. Video 9 | watches=144 | mean_psnr=35.49
# 12. Video 14 | watches=118 | mean_psnr=35.38
# 13. Video 10 | watches=108 | mean_psnr=35.09
# 14. Video 18 | watches=108 | mean_psnr=35.74
# 15. Video 33 | watches=107 | mean_psnr=36.05
# 16. Video 41 | watches=104 | mean_psnr=35.50
# 17. Video 53 | watches=97 | mean_psnr=35.98
# 18. Video 4 | watches=93 | mean_psnr=36.10
# 19. Video 17 | watches=90 | mean_psnr=35.33
# 20. Video 71 | watches=89 | mean_psnr=35.90
# --------------------------------------------------
# Episode 38 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.53 | PSNR: 36.03 | Mean video PSNR: 36.00 | Popularity bonus: 0.0000 | Time: 13:31:25
# Mean PSNR across watched videos: 36.00
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1845 | mean_psnr=36.06
# 02. Video 1 | watches=938 | mean_psnr=35.92
# 03. Video 2 | watches=459 | mean_psnr=35.62
# 04. Video 5 | watches=436 | mean_psnr=36.50
# 05. Video 3 | watches=424 | mean_psnr=36.23
# 06. Video 4 | watches=373 | mean_psnr=35.93
# 07. Video 7 | watches=287 | mean_psnr=35.58
# 08. Video 12 | watches=187 | mean_psnr=36.54
# 09. Video 10 | watches=182 | mean_psnr=36.00
# 10. Video 9 | watches=177 | mean_psnr=36.29
# 11. Video 8 | watches=176 | mean_psnr=36.28
# 12. Video 6 | watches=157 | mean_psnr=35.99
# 13. Video 11 | watches=153 | mean_psnr=36.26
# 14. Video 58 | watches=141 | mean_psnr=36.28
# 15. Video 16 | watches=135 | mean_psnr=36.46
# 16. Video 15 | watches=133 | mean_psnr=35.86
# 17. Video 24 | watches=127 | mean_psnr=36.65
# 18. Video 17 | watches=113 | mean_psnr=37.06
# 19. Video 25 | watches=111 | mean_psnr=36.13
# 20. Video 22 | watches=108 | mean_psnr=35.90
# --------------------------------------------------
# Episode 39 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.95 | EHR: 0.51 | PSNR: 35.86 | Mean video PSNR: 35.76 | Popularity bonus: 0.0000 | Time: 13:31:26
# Mean PSNR across watched videos: 35.76
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1616 | mean_psnr=36.09
# 02. Video 1 | watches=1028 | mean_psnr=35.67
# 03. Video 2 | watches=548 | mean_psnr=36.06
# 04. Video 3 | watches=354 | mean_psnr=35.85
# 05. Video 6 | watches=330 | mean_psnr=36.75
# 06. Video 4 | watches=301 | mean_psnr=36.10
# 07. Video 11 | watches=264 | mean_psnr=35.38
# 08. Video 9 | watches=252 | mean_psnr=35.71
# 09. Video 15 | watches=236 | mean_psnr=35.58
# 10. Video 8 | watches=235 | mean_psnr=35.48
# 11. Video 10 | watches=191 | mean_psnr=35.94
# 12. Video 7 | watches=169 | mean_psnr=35.46
# 13. Video 5 | watches=132 | mean_psnr=36.36
# 14. Video 33 | watches=128 | mean_psnr=36.17
# 15. Video 45 | watches=126 | mean_psnr=35.62
# 16. Video 14 | watches=125 | mean_psnr=35.46
# 17. Video 22 | watches=113 | mean_psnr=35.66
# 18. Video 20 | watches=110 | mean_psnr=35.73
# 19. Video 12 | watches=105 | mean_psnr=35.81
# 20. Video 26 | watches=105 | mean_psnr=35.95
# --------------------------------------------------
# Episode 40 | R: 0 | HR: 0.81 | HR_2: 0.58 | BHR: 0.92 | EHR: 0.49 | PSNR: 35.66 | Mean video PSNR: 35.52 | Popularity bonus: 0.0000 | Time: 13:31:27
# Mean PSNR across watched videos: 35.52
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1558 | mean_psnr=35.68
# 02. Video 1 | watches=1047 | mean_psnr=35.76
# 03. Video 2 | watches=599 | mean_psnr=36.09
# 04. Video 4 | watches=583 | mean_psnr=36.07
# 05. Video 5 | watches=316 | mean_psnr=36.19
# 06. Video 3 | watches=278 | mean_psnr=35.65
# 07. Video 9 | watches=229 | mean_psnr=35.73
# 08. Video 8 | watches=202 | mean_psnr=35.01
# 09. Video 6 | watches=202 | mean_psnr=35.61
# 10. Video 18 | watches=161 | mean_psnr=35.56
# 11. Video 11 | watches=153 | mean_psnr=35.39
# 12. Video 24 | watches=149 | mean_psnr=36.07
# 13. Video 28 | watches=144 | mean_psnr=36.23
# 14. Video 7 | watches=136 | mean_psnr=35.22
# 15. Video 33 | watches=129 | mean_psnr=36.57
# 16. Video 42 | watches=129 | mean_psnr=34.98
# 17. Video 53 | watches=113 | mean_psnr=35.15
# 18. Video 16 | watches=101 | mean_psnr=35.22
# 19. Video 14 | watches=98 | mean_psnr=35.48
# 20. Video 38 | watches=93 | mean_psnr=35.54
# --------------------------------------------------
# Episode 41 | R: 0 | HR: 0.81 | HR_2: 0.58 | BHR: 0.92 | EHR: 0.49 | PSNR: 35.69 | Mean video PSNR: 35.66 | Popularity bonus: 0.0000 | Time: 13:31:28
# Mean PSNR across watched videos: 35.66
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1579 | mean_psnr=35.92
# 02. Video 1 | watches=1083 | mean_psnr=35.60
# ...
# 02. Video 1 | watches=861 | mean_psnr=36.00
# 03. Video 5 | watches=493 | mean_psnr=35.96
# 04. Video 2 | watches=476 | mean_psnr=35.90
# 05. Video 3 | watches=453 | mean_psnr=35.94
# 06. Video 6 | watches=247 | mean_psnr=35.90
# 07. Video 4 | watches=245 | mean_psnr=36.03
# 08. Video 8 | watches=210 | mean_psnr=36.00
# 09. Video 10 | watches=201 | mean_psnr=35.98
# 10. Video 9 | watches=184 | mean_psnr=35.22
# 11. Video 12 | watches=164 | mean_psnr=35.88
# 12. Video 11 | watches=164 | mean_psnr=35.73
# 13. Video 16 | watches=158 | mean_psnr=35.46
# 14. Video 7 | watches=148 | mean_psnr=35.78
# 15. Video 41 | watches=147 | mean_psnr=36.50
# 16. Video 13 | watches=130 | mean_psnr=36.06
# 17. Video 36 | watches=130 | mean_psnr=35.58
# 18. Video 31 | watches=113 | mean_psnr=35.75
# 19. Video 20 | watches=111 | mean_psnr=35.81
# 20. Video 25 | watches=109 | mean_psnr=34.98
# --------------------------------------------------
# Episode 87 | R: 0 | HR: 0.86 | HR_2: 0.61 | BHR: 0.98 | EHR: 0.52 | PSNR: 35.99 | Mean video PSNR: 35.94 | Popularity bonus: 0.0000 | Time: 13:32:18
# Mean PSNR across watched videos: 35.94
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1439 | mean_psnr=35.99
# 02. Video 1 | watches=1012 | mean_psnr=36.01
# 03. Video 2 | watches=812 | mean_psnr=35.75
# 04. Video 3 | watches=454 | mean_psnr=36.07
# 05. Video 4 | watches=417 | mean_psnr=35.67
# 06. Video 5 | watches=317 | mean_psnr=35.72
# 07. Video 6 | watches=271 | mean_psnr=35.67
# 08. Video 13 | watches=225 | mean_psnr=36.50
# 09. Video 9 | watches=222 | mean_psnr=36.57
# 10. Video 19 | watches=185 | mean_psnr=36.82
# 11. Video 17 | watches=180 | mean_psnr=35.76
# 12. Video 15 | watches=174 | mean_psnr=35.65
# 13. Video 11 | watches=164 | mean_psnr=36.40
# 14. Video 29 | watches=161 | mean_psnr=35.08
# 15. Video 14 | watches=157 | mean_psnr=36.42
# 16. Video 12 | watches=150 | mean_psnr=36.37
# 17. Video 10 | watches=142 | mean_psnr=35.53
# 18. Video 7 | watches=138 | mean_psnr=35.85
# 19. Video 32 | watches=138 | mean_psnr=36.45
# 20. Video 16 | watches=122 | mean_psnr=37.09
# --------------------------------------------------
# Episode 88 | R: 0 | HR: 0.83 | HR_2: 0.59 | BHR: 0.95 | EHR: 0.50 | PSNR: 35.75 | Mean video PSNR: 35.77 | Popularity bonus: 0.0000 | Time: 13:32:19
# Mean PSNR across watched videos: 35.77
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1425 | mean_psnr=35.56
# 02. Video 1 | watches=685 | mean_psnr=35.83
# 03. Video 2 | watches=521 | mean_psnr=35.76
# 04. Video 3 | watches=477 | mean_psnr=35.71
# 05. Video 5 | watches=351 | mean_psnr=35.68
# 06. Video 11 | watches=331 | mean_psnr=35.53
# 07. Video 8 | watches=289 | mean_psnr=35.82
# 08. Video 7 | watches=229 | mean_psnr=35.36
# 09. Video 6 | watches=224 | mean_psnr=35.80
# 10. Video 17 | watches=216 | mean_psnr=35.83
# 11. Video 23 | watches=166 | mean_psnr=35.60
# 12. Video 30 | watches=153 | mean_psnr=35.90
# 13. Video 19 | watches=144 | mean_psnr=35.56
# 14. Video 4 | watches=140 | mean_psnr=36.38
# 15. Video 15 | watches=129 | mean_psnr=35.99
# 16. Video 18 | watches=127 | mean_psnr=35.28
# 17. Video 41 | watches=119 | mean_psnr=35.44
# 18. Video 38 | watches=118 | mean_psnr=36.65
# 19. Video 14 | watches=110 | mean_psnr=34.86
# 20. Video 27 | watches=109 | mean_psnr=35.89
# --------------------------------------------------
# Episode 89 | R: 0 | HR: 0.84 | HR_2: 0.60 | BHR: 0.95 | EHR: 0.51 | PSNR: 35.89 | Mean video PSNR: 35.80 | Popularity bonus: 0.0000 | Time: 13:32:20
# Mean PSNR across watched videos: 35.80
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1584 | mean_psnr=35.85
# 02. Video 2 | watches=676 | mean_psnr=36.04
# 03. Video 1 | watches=633 | mean_psnr=35.73
# 04. Video 5 | watches=461 | mean_psnr=36.06
# 05. Video 8 | watches=427 | mean_psnr=35.50
# 06. Video 4 | watches=409 | mean_psnr=36.05
# 07. Video 3 | watches=381 | mean_psnr=36.42
# 08. Video 9 | watches=255 | mean_psnr=36.12
# 09. Video 6 | watches=243 | mean_psnr=36.44
# 10. Video 14 | watches=193 | mean_psnr=35.65
# 11. Video 7 | watches=152 | mean_psnr=35.49
# 12. Video 22 | watches=148 | mean_psnr=36.06
# 13. Video 10 | watches=138 | mean_psnr=36.50
# 14. Video 18 | watches=134 | mean_psnr=35.19
# 15. Video 54 | watches=122 | mean_psnr=36.11
# 16. Video 27 | watches=120 | mean_psnr=36.73
# 17. Video 23 | watches=116 | mean_psnr=35.60
# 18. Video 33 | watches=115 | mean_psnr=35.72
# 19. Video 16 | watches=114 | mean_psnr=35.59
# 20. Video 82 | watches=98 | mean_psnr=35.71
# --------------------------------------------------
# Episode 90 | R: 0 | HR: 0.84 | HR_2: 0.61 | BHR: 0.94 | EHR: 0.53 | PSNR: 35.96 | Mean video PSNR: 35.89 | Popularity bonus: 0.0000 | Time: 13:32:21
# Mean PSNR across watched videos: 35.89
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1514 | mean_psnr=36.01
# 02. Video 1 | watches=830 | mean_psnr=35.86
# 03. Video 3 | watches=675 | mean_psnr=36.17
# 04. Video 2 | watches=497 | mean_psnr=35.71
# 05. Video 4 | watches=405 | mean_psnr=35.97
# 06. Video 9 | watches=327 | mean_psnr=36.24
# 07. Video 6 | watches=242 | mean_psnr=35.93
# 08. Video 12 | watches=241 | mean_psnr=35.93
# 09. Video 5 | watches=200 | mean_psnr=35.84
# 10. Video 15 | watches=168 | mean_psnr=35.45
# 11. Video 7 | watches=156 | mean_psnr=36.23
# 12. Video 14 | watches=149 | mean_psnr=35.97
# 13. Video 8 | watches=146 | mean_psnr=36.82
# 14. Video 17 | watches=140 | mean_psnr=35.79
# 15. Video 10 | watches=124 | mean_psnr=36.17
# 16. Video 33 | watches=118 | mean_psnr=35.95
# 17. Video 13 | watches=100 | mean_psnr=36.08
# 18. Video 21 | watches=97 | mean_psnr=35.85
# 19. Video 11 | watches=95 | mean_psnr=36.37
# 20. Video 52 | watches=89 | mean_psnr=35.81
# --------------------------------------------------
# Episode 91 | R: 0 | HR: 0.86 | HR_2: 0.62 | BHR: 0.97 | EHR: 0.53 | PSNR: 36.09 | Mean video PSNR: 36.05 | Popularity bonus: 0.0000 | Time: 13:32:22
# Mean PSNR across watched videos: 36.05
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1668 | mean_psnr=36.11
# 02. Video 1 | watches=828 | mean_psnr=35.78
# 03. Video 2 | watches=628 | mean_psnr=36.17
# 04. Video 4 | watches=420 | mean_psnr=36.28
# 05. Video 3 | watches=341 | mean_psnr=36.23
# 06. Video 8 | watches=239 | mean_psnr=35.94
# 07. Video 6 | watches=231 | mean_psnr=36.17
# 08. Video 5 | watches=222 | mean_psnr=36.53
# 09. Video 11 | watches=212 | mean_psnr=35.80
# 10. Video 7 | watches=195 | mean_psnr=36.23
# 11. Video 9 | watches=171 | mean_psnr=35.61
# 12. Video 18 | watches=159 | mean_psnr=36.08
# 13. Video 17 | watches=158 | mean_psnr=37.26
# 14. Video 14 | watches=138 | mean_psnr=36.52
# 15. Video 19 | watches=133 | mean_psnr=35.36
# 16. Video 15 | watches=132 | mean_psnr=35.62
# 17. Video 21 | watches=132 | mean_psnr=36.70
# 18. Video 10 | watches=119 | mean_psnr=36.32
# 19. Video 31 | watches=115 | mean_psnr=35.09
# 20. Video 23 | watches=111 | mean_psnr=36.62
# --------------------------------------------------
# Episode 92 | R: 0 | HR: 0.86 | HR_2: 0.62 | BHR: 0.97 | EHR: 0.53 | PSNR: 36.07 | Mean video PSNR: 36.01 | Popularity bonus: 0.0000 | Time: 13:32:23
# Mean PSNR across watched videos: 36.01
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1762 | mean_psnr=36.13
# 02. Video 1 | watches=1206 | mean_psnr=36.02
# 03. Video 2 | watches=597 | mean_psnr=35.86
# 04. Video 9 | watches=297 | mean_psnr=36.50
# 05. Video 5 | watches=274 | mean_psnr=35.82
# 06. Video 11 | watches=249 | mean_psnr=35.74
# 07. Video 7 | watches=248 | mean_psnr=35.22
# 08. Video 4 | watches=240 | mean_psnr=36.54
# 09. Video 10 | watches=227 | mean_psnr=36.46
# 10. Video 6 | watches=205 | mean_psnr=36.50
# 11. Video 3 | watches=204 | mean_psnr=35.82
# 12. Video 8 | watches=194 | mean_psnr=36.39
# 13. Video 12 | watches=128 | mean_psnr=36.29
# 14. Video 13 | watches=120 | mean_psnr=36.04
# 15. Video 28 | watches=120 | mean_psnr=36.29
# 16. Video 25 | watches=115 | mean_psnr=35.09
# 17. Video 35 | watches=99 | mean_psnr=35.93
# 18. Video 27 | watches=98 | mean_psnr=36.53
# 19. Video 18 | watches=90 | mean_psnr=36.75
# 20. Video 14 | watches=89 | mean_psnr=36.26
# --------------------------------------------------
# Episode 93 | R: 0 | HR: 0.86 | HR_2: 0.62 | BHR: 0.97 | EHR: 0.53 | PSNR: 36.04 | Mean video PSNR: 36.05 | Popularity bonus: 0.0000 | Time: 13:32:24
# Mean PSNR across watched videos: 36.05
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1601 | mean_psnr=35.80
# 02. Video 1 | watches=890 | mean_psnr=36.17
# 03. Video 2 | watches=889 | mean_psnr=36.09
# 04. Video 4 | watches=409 | mean_psnr=36.08
# 05. Video 3 | watches=394 | mean_psnr=36.42
# 06. Video 8 | watches=301 | mean_psnr=35.92
# 07. Video 5 | watches=293 | mean_psnr=36.35
# 08. Video 7 | watches=253 | mean_psnr=35.86
# 09. Video 9 | watches=241 | mean_psnr=36.02
# 10. Video 6 | watches=220 | mean_psnr=35.41
# 11. Video 14 | watches=190 | mean_psnr=37.08
# 12. Video 13 | watches=184 | mean_psnr=36.24
# 13. Video 17 | watches=147 | mean_psnr=36.31
# 14. Video 49 | watches=132 | mean_psnr=37.23
# 15. Video 15 | watches=131 | mean_psnr=36.97
# 16. Video 10 | watches=120 | mean_psnr=36.60
# 17. Video 12 | watches=117 | mean_psnr=35.62
# 18. Video 30 | watches=108 | mean_psnr=35.56
# 19. Video 27 | watches=87 | mean_psnr=36.35
# 20. Video 77 | watches=83 | mean_psnr=35.81
# --------------------------------------------------
# Episode 94 | R: 0 | HR: 0.81 | HR_2: 0.57 | BHR: 0.91 | EHR: 0.48 | PSNR: 35.58 | Mean video PSNR: 35.53 | Popularity bonus: 0.0000 | Time: 13:32:25
# Mean PSNR across watched videos: 35.53
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1614 | mean_psnr=35.64
# 02. Video 1 | watches=972 | mean_psnr=35.72
# 03. Video 2 | watches=440 | mean_psnr=35.64
# 04. Video 5 | watches=362 | mean_psnr=35.57
# 05. Video 3 | watches=276 | mean_psnr=35.21
# 06. Video 6 | watches=238 | mean_psnr=35.46
# 07. Video 8 | watches=229 | mean_psnr=35.47
# 08. Video 11 | watches=210 | mean_psnr=35.15
# 09. Video 17 | watches=200 | mean_psnr=36.29
# 10. Video 13 | watches=180 | mean_psnr=35.64
# 11. Video 4 | watches=166 | mean_psnr=35.99
# 12. Video 29 | watches=152 | mean_psnr=35.61
# 13. Video 12 | watches=139 | mean_psnr=35.36
# 14. Video 24 | watches=135 | mean_psnr=35.28
# 15. Video 19 | watches=133 | mean_psnr=35.34
# 16. Video 44 | watches=127 | mean_psnr=35.45
# 17. Video 7 | watches=119 | mean_psnr=35.57
# 18. Video 16 | watches=110 | mean_psnr=35.18
# 19. Video 27 | watches=106 | mean_psnr=36.23
# 20. Video 14 | watches=105 | mean_psnr=35.95
# --------------------------------------------------
# Episode 95 | R: 0 | HR: 0.85 | HR_2: 0.61 | BHR: 0.97 | EHR: 0.52 | PSNR: 35.94 | Mean video PSNR: 36.06 | Popularity bonus: 0.0000 | Time: 13:32:26
# Mean PSNR across watched videos: 36.06
# Top 20 watched videos by rank:
# 01. Video 1 | watches=1337 | mean_psnr=35.82
# 02. Video 0 | watches=1318 | mean_psnr=35.89
# 03. Video 2 | watches=689 | mean_psnr=35.58
# 04. Video 4 | watches=300 | mean_psnr=35.92
# 05. Video 8 | watches=287 | mean_psnr=35.95
# 06. Video 6 | watches=271 | mean_psnr=36.37
# 07. Video 3 | watches=236 | mean_psnr=35.37
# 08. Video 9 | watches=220 | mean_psnr=36.90
# 09. Video 7 | watches=218 | mean_psnr=36.23
# 10. Video 5 | watches=216 | mean_psnr=35.88
# 11. Video 13 | watches=175 | mean_psnr=36.01
# 12. Video 11 | watches=168 | mean_psnr=36.22
# 13. Video 15 | watches=143 | mean_psnr=36.12
# 14. Video 10 | watches=142 | mean_psnr=35.90
# 15. Video 25 | watches=134 | mean_psnr=35.43
# 16. Video 16 | watches=129 | mean_psnr=35.31
# 17. Video 49 | watches=127 | mean_psnr=36.06
# 18. Video 17 | watches=127 | mean_psnr=35.49
# 19. Video 20 | watches=119 | mean_psnr=35.04
# 20. Video 21 | watches=116 | mean_psnr=35.56
# --------------------------------------------------
# Episode 96 | R: 0 | HR: 0.76 | HR_2: 0.53 | BHR: 0.87 | EHR: 0.45 | PSNR: 35.20 | Mean video PSNR: 35.29 | Popularity bonus: 0.0000 | Time: 13:32:27
# Mean PSNR across watched videos: 35.29
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1457 | mean_psnr=35.28
# 02. Video 1 | watches=1013 | mean_psnr=35.24
# 03. Video 2 | watches=476 | mean_psnr=34.97
# 04. Video 4 | watches=441 | mean_psnr=35.48
# 05. Video 6 | watches=393 | mean_psnr=35.17
# 06. Video 5 | watches=307 | mean_psnr=34.27
# 07. Video 18 | watches=281 | mean_psnr=35.69
# 08. Video 3 | watches=264 | mean_psnr=33.97
# 09. Video 38 | watches=208 | mean_psnr=34.68
# 10. Video 17 | watches=195 | mean_psnr=35.51
# 11. Video 8 | watches=188 | mean_psnr=35.61
# 12. Video 9 | watches=175 | mean_psnr=35.31
# 13. Video 10 | watches=156 | mean_psnr=34.95
# 14. Video 7 | watches=151 | mean_psnr=36.08
# 15. Video 11 | watches=150 | mean_psnr=35.15
# 16. Video 24 | watches=141 | mean_psnr=34.63
# 17. Video 32 | watches=133 | mean_psnr=34.40
# 18. Video 21 | watches=120 | mean_psnr=36.10
# 19. Video 77 | watches=106 | mean_psnr=36.37
# 20. Video 34 | watches=101 | mean_psnr=34.60
# --------------------------------------------------
# Episode 97 | R: 0 | HR: 0.67 | HR_2: 0.46 | BHR: 0.77 | EHR: 0.38 | PSNR: 34.50 | Mean video PSNR: 34.52 | Popularity bonus: 0.0000 | Time: 13:32:29
# Mean PSNR across watched videos: 34.52
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1563 | mean_psnr=34.82
# 02. Video 1 | watches=1056 | mean_psnr=34.48
# 03. Video 4 | watches=418 | mean_psnr=34.75
# 04. Video 2 | watches=402 | mean_psnr=34.61
# 05. Video 3 | watches=396 | mean_psnr=34.76
# 06. Video 8 | watches=365 | mean_psnr=33.66
# 07. Video 5 | watches=299 | mean_psnr=34.27
# 08. Video 6 | watches=256 | mean_psnr=34.98
# 09. Video 7 | watches=198 | mean_psnr=34.52
# 10. Video 15 | watches=193 | mean_psnr=33.42
# 11. Video 9 | watches=178 | mean_psnr=33.41
# 12. Video 17 | watches=169 | mean_psnr=34.96
# 13. Video 12 | watches=143 | mean_psnr=35.00
# 14. Video 13 | watches=142 | mean_psnr=33.49
# 15. Video 14 | watches=139 | mean_psnr=34.05
# 16. Video 11 | watches=136 | mean_psnr=33.01
# 17. Video 10 | watches=127 | mean_psnr=35.22
# 18. Video 20 | watches=115 | mean_psnr=35.65
# 19. Video 41 | watches=110 | mean_psnr=33.57
# 20. Video 113 | watches=104 | mean_psnr=34.16
# --------------------------------------------------
# Episode 98 | R: 0 | HR: 0.87 | HR_2: 0.62 | BHR: 0.98 | EHR: 0.53 | PSNR: 36.07 | Mean video PSNR: 35.89 | Popularity bonus: 0.0000 | Time: 13:32:30
# Mean PSNR across watched videos: 35.89
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1912 | mean_psnr=36.17
# 02. Video 1 | watches=685 | mean_psnr=35.93
# 03. Video 2 | watches=609 | mean_psnr=36.09
# 04. Video 3 | watches=461 | mean_psnr=35.84
# 05. Video 6 | watches=405 | mean_psnr=36.90
# 06. Video 4 | watches=286 | mean_psnr=36.12
# 07. Video 5 | watches=278 | mean_psnr=35.77
# 08. Video 7 | watches=220 | mean_psnr=36.47
# 09. Video 9 | watches=219 | mean_psnr=35.80
# 10. Video 14 | watches=200 | mean_psnr=36.06
# 11. Video 16 | watches=198 | mean_psnr=36.16
# 12. Video 15 | watches=176 | mean_psnr=36.12
# 13. Video 22 | watches=173 | mean_psnr=35.71
# 14. Video 11 | watches=159 | mean_psnr=36.46
# 15. Video 18 | watches=158 | mean_psnr=36.46
# 16. Video 10 | watches=121 | mean_psnr=36.16
# 17. Video 13 | watches=121 | mean_psnr=36.76
# 18. Video 67 | watches=117 | mean_psnr=35.81
# 19. Video 28 | watches=116 | mean_psnr=35.58
# 20. Video 12 | watches=116 | mean_psnr=36.68
# --------------------------------------------------
# Episode 99 | R: 0 | HR: 0.65 | HR_2: 0.44 | BHR: 0.74 | EHR: 0.36 | PSNR: 34.30 | Mean video PSNR: 34.47 | Popularity bonus: 0.0000 | Time: 13:32:31
# Mean PSNR across watched videos: 34.47
# Top 20 watched videos by rank:
# 01. Video 0 | watches=1608 | mean_psnr=34.12
# 02. Video 1 | watches=670 | mean_psnr=35.02
# 03. Video 2 | watches=471 | mean_psnr=33.92
# 04. Video 4 | watches=380 | mean_psnr=35.30
# 05. Video 3 | watches=357 | mean_psnr=34.31
# 06. Video 7 | watches=338 | mean_psnr=34.71
# 07. Video 6 | watches=233 | mean_psnr=35.38
# 08. Video 8 | watches=229 | mean_psnr=34.86
# 09. Video 17 | watches=225 | mean_psnr=33.39
# 10. Video 10 | watches=215 | mean_psnr=34.20
# 11. Video 5 | watches=213 | mean_psnr=34.40
# 12. Video 9 | watches=188 | mean_psnr=34.10
# 13. Video 14 | watches=137 | mean_psnr=34.34
# 14. Video 22 | watches=135 | mean_psnr=33.74
# 15. Video 19 | watches=133 | mean_psnr=33.06
# 16. Video 11 | watches=108 | mean_psnr=33.38
# 17. Video 41 | watches=104 | mean_psnr=32.86
# 18. Video 12 | watches=103 | mean_psnr=32.57
# 19. Video 23 | watches=101 | mean_psnr=33.56
# 20. Video 13 | watches=100 | mean_psnr=34.67
# --------------------------------------------------
