# %%
import csv
import importlib
import os
import random
import sys
import torch
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from time import sleep
from collections import deque, defaultdict
from itertools import count
from typing import Any, Dict, Counter, List

sources_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if sources_path not in sys.path:
    sys.path.append(sources_path)

from importnb import Notebook
with Notebook():
    from Labs.LatencyModel import LatencyModel, MultiDULatencyModel
    from Labs.Policy import DrlPolicy, MMSPPolicy
    from Labs.CacheEngine import CacheEngineEnv
    from Labs.UserRequest import UserRequestEvents
    from Labs.EnvWrapper import EnvWrapper

from RL.Networks import QNetwork, MultiHeadQNetwork
from RL.Buffers import ReplayBuffer, NStepReplayBuffer
from RL.Adapters import FeatureAdapter, NetworkAdapter
from RL.FocusWorkers import BaseWorker, EnhWorker, FocusWorker, PDQNWorker

import Common.config as config
import Common.datatypes as datatypes
import Common.debugger as debugger
import Common.utils as utils
import Core.builders as builders


importlib.reload(builders)
importlib.reload(config)
importlib.reload(datatypes)
importlib.reload(debugger)
importlib.reload(utils)
# Out:
# <module 'Common.utils' from 'c:\\Users\\es25591\\Workspace\\CacheVideoPredict360\\Sources\\Common\\utils.py'>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

UserTransition = datatypes.UserTransition
CachePolicy = datatypes.CachePolicy
CacheKey = datatypes.CacheKey

cfg = config.Config()
cfg.filename = \
    f"focus_eps{cfg.epsilon_start}_" \
    f"lrdecay{cfg.learning_rate_decay}_" \
    f"gamma{cfg.gamma}.csv"
cfg.state_dim_base_focus = cfg.state_dim_base_focus + cfg.state_dim_enh_focus
cfg.state_dim = 10 * cfg.cache_size + 2 * (cfg.viewport + 1)
cfg.action_dim = cfg.cache_size * (cfg.viewport + 1) + 1
cfg.hidden_dim = 256

debugger = debugger.debug

# %%
def save_training_results(
    path_,
    filename,
    ep, 
    total_reward, 
    cache_hits, 
    cache_misses, 
    agent
):
    with open(os.path.join(path_, filename), 'a', newline='') as f:
        fieldnames = [
            'episode', 
            'total_reward', 
            'cache_hits', 
            'cache_misses', 
            'epsilon',
            'lr'
        ]
        writer_results = csv.DictWriter(f, fieldnames=fieldnames)

        if ep == 0:
            writer_results.writeheader()
        
        writer_results.writerow({
            'episode': ep,
            'total_reward': round(float(total_reward), 2),
            'cache_hits': cache_hits,
            'cache_misses': cache_misses,
            'lr': f"{agent.scheduler.get_last_lr()[0]:.10f}" if agent else None,
            'epsilon': round(float(agent.epsilon), 4) if agent else None
        })

def update_metrics(info: dict, reward: float) -> tuple[float, int, int, int, int]:
    enh_hits = info.get("enh_layer_hits", 0)
    base_hits = info.get("base_layer_hits", 0)
    enh_misses = info.get("enh_layer_misses", 0)
    base_misses = info.get("base_layer_misses", 0)

    return reward, base_hits, base_misses, enh_hits, enh_misses

# %%
def run_episode(episode, env, agent, net_adapter, cfg):
    """Run one full training episode."""
    _, info = net_adapter.reset()

    total_reward = 0.0
    cache_hits = cache_misses = 0
    base_hits = base_misses = 0
    enh_hits = enh_misses = 0

    if cfg.has_warmup:
        env.warmup_phase(net_adapter, 1000)

    for step in range(cfg.max_steps):
        
        req_state = info.get("user_request", None)
        
        # --- Build State ---
        state = net_adapter.build_observation(req_state)

        # --- Action Selection --- 
        action = agent.select_action(state)
        
        # --- Environment Step ---
        _, _, done, info = env.step(action, req_state, net_adapter)

        # --- Store Transition & Train ---
        nxt_req = info["user_request"]

        reward_0 = info["reward_layer_0"]
        reward_1 = info["reward_layer_1"]
        
        prefetch_base = info["prefetch_base"]
        prefetch_enh = info["prefetch_enh"]

        next_state = net_adapter.build_observation(nxt_req)

        if prefetch_base or prefetch_enh:
            agent.remember(
                state, action, reward_0 + reward_1, next_state, done
            )
            agent.train_step()

        delta_r, bs_hits, bs_miss, e_hits, e_miss = update_metrics(info, reward_0 + reward_1)
        total_reward += delta_r
        cache_hits += bs_hits + e_hits
        cache_misses += bs_miss + e_miss
        base_hits += bs_hits
        base_misses += bs_miss
        enh_hits += e_hits
        enh_misses += e_miss

        if done:
            break

        debugger.log('cache_hits', bs_hits + e_hits)
        debugger.log('cache_misses', bs_miss + e_miss)

    return total_reward, cache_hits, cache_misses, base_hits, base_misses, enh_hits, enh_misses

def train(cfg):
    env = builders.build_environment(cfg)

    # agent = FocusWorker(cfg, debugger=debugger)

    agent = PDQNWorker(cfg, debugger=debugger)

    feature_adapter = FeatureAdapter(cfg, env)
    net_adapter = NetworkAdapter(cfg, env, feature_adapter)

    date_dir = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M")
    debug_path = os.path.join(cfg.path_results, date_dir)
    os.makedirs(debug_path, exist_ok=True)

    print(f"Starting training for {cfg.n_episodes} episodes... {date_dir}")
    print(f"Warmup Phase: {'Enabled' if cfg.has_warmup else 'Disabled'}")
    print(f"Users Session Length: {cfg.user_session_length}")
    print(
        f"State Dim Base: {agent.state_dim}, Action Dim Base: {agent.action_dim_base}, Hidden Dim Base: {cfg.hidden_dim_base_focus}\n"
        f"State Dim Enh: {agent.state_dim}, Action Dim Enh: {agent.action_dim_enh}, Hidden Dim Enh: {cfg.hidden_dim_enh_focus}"
    )

    for episode in range(cfg.n_episodes):

        total_reward, hits, misses, bs_hits, bs_miss, enh_hits, enh_miss = run_episode(
            episode, env, agent, net_adapter, cfg
        )

        agent.update_epsilon()

        save_training_results(
            path_=cfg.path_results + "/" + date_dir,
            filename=cfg.filename,
            ep=episode,
            total_reward=total_reward,
            cache_hits=hits,
            cache_misses=misses,
            agent=agent
        )

        debugger.log('lr', agent.scheduler.get_last_lr()[0])
        debugger.log('epsilon', agent.epsilon)

        print(
            f"--- Episode {episode} | R: {total_reward:.2f} | "
            f"HR: {hits / (hits + misses + 1e-9):.2f} | "
            f"BHR: {bs_hits / (bs_hits + bs_miss + 1e-9):.2f} | "
            f"EHR: {enh_hits / (enh_hits + enh_miss + 1e-9):.2f} ---"
        )

        debugger.save_results(filepath=f"{debug_path}/debug_ep{episode}")
        debugger.clear()

        print("-" * 50)

    return agent
    
if __name__ == "__main__":
    agent = train(cfg)
# Out:
# NetworkAdapter initialized with capacity: 125 videos, 4 tiles per video
# Starting training for 400 episodes... 2026-03-13_13-07
# Warmup Phase: Enabled
# Users Session Length: 60
# State Dim Base: 1260, Action Dim Base: 626, Hidden Dim Base: 256
# State Dim Enh: 1260, Action Dim Enh: 626, Hidden Dim Enh: 128
# --- Episode 0 | R: 0.00 | HR: 0.55 | BHR: 0.63 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 1 | R: 0.00 | HR: 0.52 | BHR: 0.59 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 2 | R: 0.00 | HR: 0.50 | BHR: 0.56 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 3 | R: 0.00 | HR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 4 | R: 0.00 | HR: 0.49 | BHR: 0.55 | EHR: 0.31 ---
# --------------------------------------------------
# --- Episode 5 | R: 0.00 | HR: 0.52 | BHR: 0.60 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 6 | R: 0.00 | HR: 0.47 | BHR: 0.53 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 7 | R: 0.00 | HR: 0.50 | BHR: 0.57 | EHR: 0.31 ---
# --------------------------------------------------
# --- Episode 8 | R: 0.00 | HR: 0.49 | BHR: 0.55 | EHR: 0.31 ---
# --------------------------------------------------
# --- Episode 9 | R: 0.00 | HR: 0.50 | BHR: 0.57 | EHR: 0.29 ---
# --------------------------------------------------
# --- Episode 10 | R: 0.00 | HR: 0.51 | BHR: 0.58 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 11 | R: 0.00 | HR: 0.52 | BHR: 0.59 | EHR: 0.31 ---
# --------------------------------------------------
# --- Episode 12 | R: 0.00 | HR: 0.49 | BHR: 0.56 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 13 | R: 0.00 | HR: 0.52 | BHR: 0.59 | EHR: 0.29 ---
# --------------------------------------------------
# --- Episode 14 | R: 0.00 | HR: 0.52 | BHR: 0.59 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 15 | R: 0.00 | HR: 0.55 | BHR: 0.63 | EHR: 0.31 ---
# --------------------------------------------------
# --- Episode 16 | R: 0.00 | HR: 0.51 | BHR: 0.58 | EHR: 0.29 ---
# --------------------------------------------------
# --- Episode 17 | R: 0.00 | HR: 0.53 | BHR: 0.61 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode 18 | R: 0.00 | HR: 0.51 | BHR: 0.57 | EHR: 0.31 ---
# --------------------------------------------------
# --- Episode 19 | R: 0.00 | HR: 0.53 | BHR: 0.60 | EHR: 0.30 ---
# --------------------------------------------------
# --- Episode
| EHR: 0.37 ---
# --------------------------------------------------
# --- Episode 254 | R: 0.00 | HR: 0.67 | BHR: 0.76 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 255 | R: 0.00 | HR: 0.64 | BHR: 0.73 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 256 | R: 0.00 | HR: 0.67 | BHR: 0.75 | EHR: 0.42 ---
# --------------------------------------------------
# --- Episode 257 | R: 0.00 | HR: 0.63 | BHR: 0.70 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 258 | R: 0.00 | HR: 0.61 | BHR: 0.68 | EHR: 0.37 ---
# --------------------------------------------------
# --- Episode 259 | R: 0.00 | HR: 0.63 | BHR: 0.71 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 260 | R: 0.00 | HR: 0.63 | BHR: 0.70 | EHR: 0.41 ---
# --------------------------------------------------
# --- Episode 261 | R: 0.00 | HR: 0.62 | BHR: 0.70 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 262 | R: 0.00 | HR: 0.59 | BHR: 0.65 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 263 | R: 0.00 | HR: 0.61 | BHR: 0.69 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 264 | R: 0.00 | HR: 0.61 | BHR: 0.68 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 265 | R: 0.00 | HR: 0.61 | BHR: 0.68 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 266 | R: 0.00 | HR: 0.64 | BHR: 0.72 | EHR: 0.41 ---
# --------------------------------------------------
# --- Episode 267 | R: 0.00 | HR: 0.62 | BHR: 0.70 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 268 | R: 0.00 | HR: 0.66 | BHR: 0.74 | EHR: 0.42 ---
# --------------------------------------------------
# --- Episode 269 | R: 0.00 | HR: 0.62 | BHR: 0.69 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 270 | R: 0.00 | HR: 0.62 | BHR: 0.70 | EHR: 0.36 ---
# --------------------------------------------------
# --- Episode 271 | R: 0.00 | HR: 0.63 | BHR: 0.71 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 272 | R: 0.00 | HR: 0.65 | BHR: 0.73 | EHR: 0.42 ---
# --------------------------------------------------
# --- Episode 273 | R: 0.00 | HR: 0.61 | BHR: 0.68 | EHR: 0.37 ---
# --------------------------------------------------
# --- Episode 274 | R: 0.00 | HR: 0.64 | BHR: 0.73 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 275 | R: 0.00 | HR: 0.64 | BHR: 0.73 | EHR: 0.37 ---
# --------------------------------------------------
# --- Episode 276 | R: 0.00 | HR: 0.60 | BHR: 0.67 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 277 | R: 0.00 | HR: 0.63 | BHR: 0.71 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 278 | R: 0.00 | HR: 0.59 | BHR: 0.65 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 279 | R: 0.00 | HR: 0.61 | BHR: 0.69 | EHR: 0.37 ---
# --------------------------------------------------
# --- Episode 280 | R: 0.00 | HR: 0.66 | BHR: 0.74 | EHR: 0.41 ---
# --------------------------------------------------
# --- Episode 281 | R: 0.00 | HR: 0.65 | BHR: 0.75 | EHR: 0.35 ---
# --------------------------------------------------
# --- Episode 282 | R: 0.00 | HR: 0.59 | BHR: 0.67 | EHR: 0.35 ---
# --------------------------------------------------
# --- Episode 283 | R: 0.00 | HR: 0.64 | BHR: 0.72 | EHR: 0.37 ---
# --------------------------------------------------
# --- Episode 284 | R: 0.00 | HR: 0.63 | BHR: 0.71 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 285 | R: 0.00 | HR: 0.62 | BHR: 0.70 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 286 | R: 0.00 | HR: 0.62 | BHR: 0.69 | EHR: 0.41 ---
# --------------------------------------------------
# --- Episode 287 | R: 0.00 | HR: 0.61 | BHR: 0.69 | EHR: 0.36 ---
# --------------------------------------------------
# --- Episode 288 | R: 0.00 | HR: 0.61 | BHR: 0.69 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 289 | R: 0.00 | HR: 0.63 | BHR: 0.71 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 290 | R: 0.00 | HR: 0.62 | BHR: 0.70 | EHR: 0.37 ---
# --------------------------------------------------
# --- Episode 291 | R: 0.00 | HR: 0.64 | BHR: 0.73 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 292 | R: 0.00 | HR: 0.66 | BHR: 0.74 | EHR: 0.43 ---
# --------------------------------------------------
# --- Episode 293 | R: 0.00 | HR: 0.61 | BHR: 0.69 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 294 | R: 0.00 | HR: 0.62 | BHR: 0.70 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 295 | R: 0.00 | HR: 0.63 | BHR: 0.71 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 296 | R: 0.00 | HR: 0.65 | BHR: 0.74 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 297 | R: 0.00 | HR: 0.63 | BHR: 0.70 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 298 | R: 0.00 | HR: 0.61 | BHR: 0.68 | EHR: 0.40 ---
# --------------------------------------------------
# --- Episode 299 | R: 0.00 | HR: 0.63 | BHR: 0.70 | EHR: 0.42 ---
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 118
#     115     return agent
#     117 if __name__ == "__main__":
# --> 118     agent = train(cfg)
#
# Cell In[4], line 84, in train(cfg)
#      77 print(
#      78     f"State Dim Base: {agent.state_dim}, Action Dim Base: {agent.action_dim_base}, Hidden Dim Base: {cfg.hidden_dim_base_focus}\n"
#      79     f"State Dim Enh: {agent.state_dim}, Action Dim Enh: {agent.action_dim_enh}, Hidden Dim Enh: {cfg.hidden_dim_enh_focus}"
#      80 )
#      82 for episode in range(cfg.n_episodes):
# ---> 84     total_reward, hits, misses, bs_hits, bs_miss, enh_hits, enh_miss = run_episode(
#      85         episode, env, agent, net_adapter, cfg
#      86     )
#      88     agent.update_epsilon()
#      90     save_training_results(
#      91         path_=cfg.path_results + "/" + date_dir,
#      92         filename=cfg.filename,
#    (...)
#      97         agent=agent
#      98     )
#
# Cell In[4], line 21, in run_episode(episode, env, agent, net_adapter, cfg)
#      18 state = net_adapter.build_observation(req_state)
#      20 # --- Action Selection ---
# ---> 21 action = agent.select_action(state)
#      23 # --- Environment Step ---
#      24 _, _, done, info = env.step(action, req_state, net_adapter)
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\Sources\RL\FocusWorkers.py:260, in PDQNWorker.select_action(self, state)
#     257     return [a_base] + a_enh
#     259 with torch.no_grad():
# --> 260     state_t = torch.tensor(state, dtype=torch.float32).to(self.device).unsqueeze(0)
#     262     # The network returns the base Q-values, enh Q-values, and the greedily chosen enhancements
#     263     _, _, chosen_base, chosen_enh = self.policy_net(state_t)
#
# KeyboardInterrupt:

# %%
if __name__ == "__main__":

    cfg_optimal_100 = cfg
    cfg_optimal_100.n_episodes = 100

    # Force greedy action selection (no exploration)
    cfg_optimal_100.epsilon_start = 0.00
    cfg_optimal_100.epsilon_min = 0.00
    cfg_optimal_100.epsilon_decay = 1.0

    cfg_optimal_100.filename = (
        f"pdqn_optimal_eps0.0_lrdecay{cfg_optimal_100.learning_rate_decay}_"
        f"gamma{cfg_optimal_100.gamma}_100ep.csv"
    )
    cfg = cfg_optimal_100

    env = builders.build_environment(cfg)

    feature_adapter = FeatureAdapter(cfg, env)
    net_adapter = NetworkAdapter(cfg, env, feature_adapter)

    date_dir = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M")
    debug_path = os.path.join(cfg.path_results, date_dir)
    os.makedirs(debug_path, exist_ok=True)

    print(f"Starting training for {cfg.n_episodes} episodes... {date_dir}")
    print(f"Warmup Phase: {'Enabled' if cfg.has_warmup else 'Disabled'}")
    print(f"Users Session Length: {cfg.user_session_length}")
    print(
        f"State Dim Base: {agent.state_dim}, Action Dim Base: {agent.action_dim_base}, Hidden Dim Base: {cfg.hidden_dim_base_focus}\n"
        f"State Dim Enh: {agent.state_dim}, Action Dim Enh: {agent.action_dim_enh}, Hidden Dim Enh: {cfg.hidden_dim_enh_focus}"
    )

    for episode in range(cfg.n_episodes):

        total_reward, hits, misses, bs_hits, bs_miss, enh_hits, enh_miss = run_episode(
            episode, env, agent, net_adapter, cfg
        )

        agent.update_epsilon()

        save_training_results(
            path_=cfg.path_results + "/" + date_dir,
            filename=cfg.filename,
            ep=episode,
            total_reward=total_reward,
            cache_hits=hits,
            cache_misses=misses,
            agent=agent
        )

        debugger.log('lr', agent.scheduler.get_last_lr()[0])
        debugger.log('epsilon', agent.epsilon)

        print(
            f"--- Episode {episode} | R: {total_reward:.2f} | "
            f"HR: {hits / (hits + misses + 1e-9):.2f} | "
            f"BHR: {bs_hits / (bs_hits + bs_miss + 1e-9):.2f} | "
            f"EHR: {enh_hits / (enh_hits + enh_miss + 1e-9):.2f} ---"
        )

        debugger.save_results(filepath=f"{debug_path}/debug_ep{episode}")
        debugger.clear()

        print("-" * 50)
# Out:
# NetworkAdapter initialized with capacity: 100 videos, 4 tiles per video
# Starting training for 100 episodes... 2026-03-13_13-05
# Warmup Phase: Enabled
# Users Session Length: 60
# State Dim Base: 1010, Action Dim Base: 501, Hidden Dim Base: 256
# State Dim Enh: 1010, Action Dim Enh: 501, Hidden Dim Enh: 128
# --- Episode 0 | R: 0.00 | HR: 0.61 | BHR: 0.68 | EHR: 0.41 ---
# --------------------------------------------------
# --- Episode 1 | R: 0.00 | HR: 0.56 | BHR: 0.63 | EHR: 0.36 ---
# --------------------------------------------------
# --- Episode 2 | R: 0.00 | HR: 0.57 | BHR: 0.63 | EHR: 0.38 ---
# --------------------------------------------------
# --- Episode 3 | R: 0.00 | HR: 0.59 | BHR: 0.65 | EHR: 0.39 ---
# --------------------------------------------------
# --- Episode 4 | R: 0.00 | HR: 0.60 | BHR: 0.67 | EHR: 0.39 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 62
#      53 debugger.log('epsilon', agent.epsilon)
#      55 print(
#      56     f"--- Episode {episode} | R: {total_reward:.2f} | "
#      57     f"HR: {hits / (hits + misses + 1e-9):.2f} | "
#      58     f"BHR: {bs_hits / (bs_hits + bs_miss + 1e-9):.2f} | "
#      59     f"EHR: {enh_hits / (enh_hits + enh_miss + 1e-9):.2f} ---"
#      60 )
# ---> 62 debugger.save_results(filepath=f"{debug_path}/debug_ep{episode}")
#      63 debugger.clear()
#      65 print("-" * 50)
#
# File c:\Users\es25591\Workspace\CacheVideoPredict360\Sources\Common\debugger.py:174, in AgentDebugger.save_results(self, filepath, format)
#     168 serializable_data = {
#     169     key: [self._to_python(v) for v in values]
#     170     for key, values in self.data.items()
#     171 }
#     173 with open(f"{filepath}.json", "w") as f:
# --> 174     json.dump(serializable_data, f, indent=2)
#     176 keys = list(serializable_data.keys())
#     177 rows = zip(*serializable_data.values())
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:180, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
#     179 for chunk in iterable:
# --> 180     fp.write(chunk)
#
# KeyboardInterrupt:
