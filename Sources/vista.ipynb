# %%
import numpy as np
import gymnasium as gym

from gymnasium import spaces
# vista.py

# %%
class Environment(gym.Env):
    """A simple OpenAI Gym environment skeleton."""
    
    def __init__(self):
        super(Environment, self).__init__()
        
        self.action_space = spaces.Discrete(2)  # Example: two discrete actions
        self.observation_space = spaces.Box(low=0, high=1, shape=(4,), dtype=np.float32)  # Example: 4D continuous observation
        
    def reset(self):
        """Reset the state of the environment to an initial state."""
        self.state = np.random.rand(4)  # Example initial state
        return self.state
    
    def step(self, action):
        """Execute one time step within the environment."""
        # Example dynamics: random next state
        self.state = np.random.rand(4)
        
        # Example reward: random reward
        reward = np.random.rand()
        
        # Example done condition
        done = np.random.rand() > 0.95
        
        info = {}
        
        return self.state, reward, done, info
    
    def render(self, mode='human'):
        """Render the environment to the screen."""
        pass  # Implement rendering logic if needed

# %%
n = 100
env = Environment()

reset_res = env.reset()
obs = reset_res[0] if isinstance(reset_res, tuple) else reset_res

for step in range(n):
    action = env.action_space.sample()
    res = env.step(action)
    
    if len(res) == 4: # (obs, reward, done, info)
        obs, reward, done, info = res
    elif len(res) == 5: # (obs, reward, terminated, truncated, info)
        obs, reward, terminated, truncated, info = res
        done = terminated or truncated

    
    print(f"Step {step+1}/{n} - action: {action}, reward: {reward}, done: {done}")
    
    if done:
        break

print("Episode finished.")
# Out:
# Step 1/100 - action: 1, reward: 0.1157266596477573, done: False
# Step 2/100 - action: 1, reward: 0.8337871450437919, done: False
# Step 3/100 - action: 0, reward: 0.6717579956785039, done: False
# Step 4/100 - action: 1, reward: 0.1080079008562762, done: False
# Step 5/100 - action: 0, reward: 0.6116591365692671, done: False
# Step 6/100 - action: 0, reward: 0.46690088190427814, done: False
# Step 7/100 - action: 1, reward: 0.03127470941589083, done: False
# Step 8/100 - action: 0, reward: 0.3772849503742134, done: False
# Step 9/100 - action: 1, reward: 0.010284517665628767, done: False
# Step 10/100 - action: 1, reward: 0.9661770293049483, done: False
# Step 11/100 - action: 0, reward: 0.162241783959853, done: False
# Step 12/100 - action: 0, reward: 0.8548147190421468, done: False
# Step 13/100 - action: 1, reward: 0.21516680670454302, done: False
# Step 14/100 - action: 0, reward: 0.5074188954038346, done: False
# Step 15/100 - action: 0, reward: 0.22461587068700317, done: False
# Step 16/100 - action: 1, reward: 0.36053147223146575, done: False
# Step 17/100 - action: 1, reward: 0.3873254196049257, done: False
# Step 18/100 - action: 0, reward: 0.4318683565715321, done: False
# Step 19/100 - action: 0, reward: 0.32893781842499825, done: False
# Step 20/100 - action: 0, reward: 0.16640964430897354, done: False
# Step 21/100 - action: 0, reward: 0.8216192481632419, done: False
# Step 22/100 - action: 1, reward: 0.8649066193188006, done: False
# Step 23/100 - action: 0, reward: 0.6639478144553308, done: False
# Step 24/100 - action: 0, reward: 0.5538148787526204, done: False
# Step 25/100 - action: 1, reward: 0.07493084242919779, done: False
# Step 26/100 - action: 1, reward: 0.5850458990582018, done: False
# Step 27/100 - action: 1, reward: 0.2577670598708858, done: False
# Step 28/100 - action: 0, reward: 0.5234690242940603, done: False
# Step 29/100 - action: 1, reward: 0.26911862585078006, done: False
# Step 30/100 - action: 1, reward: 0.8650505382222313, done: False
# Step 31/100 - action: 0, reward: 0.10725273505786381, done: False
# Step 32/100 - action: 1, reward: 0.42830297369126513, done: False
# Step 33/100 - action: 1, reward: 0.9709374101937417, done: False
# Step 34/100 - action: 0, reward: 0.8754458297323443, done: False
# Step 35/100 - action: 1, reward: 0.8031742815687775, done: False
# Step 36/100 - action: 1, reward: 0.4710308316891627, done: False
# Step 37/100 - action: 1, reward: 0.8836978384739353, done: False
# Step 38/100 - action: 0, reward: 0.04566179186912056, done: False
# Step 39/100 - action: 0, reward: 0.9681971096007485, done: False
# Step 40/100 - action: 0, reward: 0.9305017501335251, done: False
# Step 41/100 - action: 0, reward: 0.14936009633371072, done: False
# Step 42/100 - action: 1, reward: 0.19695894507338163, done: False
# Step 43/100 - action: 0, reward: 0.9097970356228128, done: True
# Episode finished.
